# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler,StandardScaler
import torch
from sklearn.model_selection import train_test_split
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %% [markdown]
# # Pre-processing Stage

# %%
no = pd.read_csv('no_discount.csv')
all = pd.read_csv('all_discount.csv')
half = pd.read_csv('half_discount.csv')
prod = pd.read_csv('product.csv')

# %% [markdown]
# ## Data Preparation

# %%
# Map user features to number
dataframes = {'all': all, 'half': half, 'no': no}
feature_cols = ['user_feature_1', 'user_feature_2', 'user_feature_3']
category_maps = {}

# 1. Build mapping for each feature across all dataframes
for col in feature_cols:
    # Collect unique values from all dataframes for this column
    unique_vals = pd.concat([df[col] for df in dataframes.values()]).unique()
    cat_map = {cat: i+1 for i, cat in enumerate(sorted(unique_vals))}
    category_maps[col] = cat_map

# 2. Apply the mapping to each dataframe
for df in dataframes.values():
    for col in feature_cols:
        df[col + '_num'] = df[col].map(category_maps[col])

# 3. Show mapping for each feature
for col in feature_cols:
    print(f"\nMapping for {col}:")
    for cat, idx in category_maps[col].items():
        print(f"{idx}: {cat}")
# Out:
# Mapping for user_feature_1:
# 1: Female
# 2: Male
# 3: Non-binary / third gender
# 4: Prefer not to say
#
# Mapping for user_feature_2:
# 1: 1-2 years ago
# 2: 2-3 years ago
# 3: 3-4 yeas ago
# 4: Currently, I don't have a phone
# 5: Less than 1 year ago
# 6: More than 4 years ago
#
# Mapping for user_feature_3:
# 1: Brand reputation
# 2: Design and appearance
# 3: Good price
# 4: Product quality

# %%
# Map choice to number (no discount)
# Define the mapping for 'choice'
choice_map = {
    "Do not purchase; save the $30 or use it for other expenses ($30 is roughly enough to cover two meals at a fast-food restaurant in the U.S.)": 0,
    "Color: Black; Style: Solid color; Weight: 2.66 pounds; Price: $24 (MSRP: $24)": 1,
    "Color: Black; Style: Gradient color; Weight: 2.66 pounds; Price: $26 (MSRP: $26)": 2,
    "Color: Dark blue; Style: Solid color; Weight: 2.61 pounds; Price: $25 (MSRP: $25)": 3,
    "Color: Dark blue; Style: Gradient color; Weight: 2.64 pounds; Price: $25 (MSRP: $25)": 4,
    "Color: Light blue; Style: Gradient color; Weight: 2.68 pounds; Price: $26 (MSRP: $26)": 5,
    "Color: White; Style: Solid color; Weight: 2.68 pounds; Price: $27 (MSRP: $27)": 6
}

# Apply the mapping
no['choice_num'] = no['choice'].map(choice_map)

# %%
# Map choice to number (all discount)
# Define the mapping for 'choice'
choice_map = {
    "Do not purchase; save the $30 or use it for other expenses ($30 is roughly enough to cover two meals at a fast-food restaurant in the U.S.)": 0,
    "Color: Black; Style: Solid color; Weight: 2.66 pounds; Price: $4.8 (MSRP: $24)": 1,
    "Color: Black; Style: Gradient color; Weight: 2.66 pounds; Price: $5.2 (MSRP: $26)": 2,
    "Color: Dark blue; Style: Solid color; Weight: 2.61 pounds; Price: $5 (MSRP: $25)": 3,
    "Color: Dark blue; Style: Gradient color; Weight: 2.64 pounds; Price: $5 (MSRP: $25)": 4,
    "Color: Light blue; Style: Gradient color; Weight: 2.68 pounds; Price: $5.2 (MSRP: $26)": 5,
    "Color: White; Style: Solid color; Weight: 2.68 pounds; Price: $5.4 (MSRP: $27)": 6
}

# Apply the mapping
all['choice_num'] = all['choice'].map(choice_map)

# %%
# Map choice to number (half discount)
# Define the mapping for 'choice'
choice_map = {
    "Do not purchase; save the $30 or use it for other expenses ($30 is roughly enough to cover two meals at a fast-food restaurant in the U.S.)": 0,
    "Color: Black; Style: Solid color; Weight: 2.66 pounds; Price: $4.8 (MSRP: $24)": 1,
    "Color: Black; Style: Gradient color; Weight: 2.66 pounds; Price: $26 (MSRP: $26)": 2,
    "Color: Dark blue; Style: Solid color; Weight: 2.61 pounds; Price: $25 (MSRP: $25)": 3,
    "Color: Dark blue; Style: Gradient color; Weight: 2.64 pounds; Price: $25 (MSRP: $25)": 4,
    "Color: Light blue; Style: Gradient color; Weight: 2.68 pounds; Price: $5.2 (MSRP: $26)": 5,
    "Color: White; Style: Solid color; Weight: 2.68 pounds; Price: $5.4 (MSRP: $27)": 6
}

# Apply the mapping
half['choice_num'] = half['choice'].map(choice_map)

# %%
# Normalization:  price
# Define the columns to scale
columns_to_scale = ['price']

# Initialize the scaler
scaler = MinMaxScaler()

# Fit and transform the selected columns
prod[columns_to_scale] = scaler.fit_transform(prod[columns_to_scale])

# %%
# Set parameters
discount_percentage = 0.2
num_product = 6

# %%
# Check the number of valid data
num_row_no = len(no)
num_row_all = len(all)
num_row_half = len(half)
print(num_row_no)
print(num_row_all)
print(num_row_half)
# Out:
# 291
# 278
# 266

# %%
# print the number of male and female
print(len(no[no['user_feature_1_num'] == 1]))
print(len(no[no['user_feature_1_num'] == 2]))

# print the number of phone usage less than 2 years and more than 2 years
# less than 2 years: categories 1 or 5
print((no["user_feature_2_num"].isin([1, 5])).sum())
# more than 2 years: categories 2, 3, or 6
print((no["user_feature_2_num"].isin([2, 3, 6])).sum())
# Out:
# 151
# 137
# 133
# 157

# %%
# print the number of male and female
print(len(all[all['user_feature_1_num'] == 1]))
print(len(all[all['user_feature_1_num'] == 2]))

# print the number of phone usage less than 2 years and more than 2 years
# less than 2 years: categories 1 or 5
print((all["user_feature_2_num"].isin([1, 5])).sum())
# more than 2 years: categories 2, 3, or 6
print((all["user_feature_2_num"].isin([2, 3, 6])).sum())
# Out:
# 132
# 142
# 152
# 126

# %%
# print the number of male and female
print(len(half[half['user_feature_1_num'] == 1]))
print(len(half[half['user_feature_1_num'] == 2]))

# print the number of phone usage less than 2 years and more than 2 years
# less than 2 years: categories 1 or 5
print((half["user_feature_2_num"].isin([1, 5])).sum())
# more than 2 years: categories 2, 3, or 6
print((half["user_feature_2_num"].isin([2, 3, 6])).sum())
# Out:
# 134
# 127
# 132
# 134

# %% [markdown]
# # Analysis Stage

# %% [markdown]
# ## True GTE

# %%
# All products are control (no discount)
# Merge the purchasing data with the product data
merged_no = no.merge(prod, left_on='choice_num', right_on='product_id', how='left')

# Calculate the total revenue
revenue_control = 0
revenue_control = merged_no['price'].sum() * 300/291

# All products are treated (all discount)
# Merge the purchasing data with the product data
merged_all = all.merge(prod, left_on='choice_num', right_on='product_id', how='left')

# Calculate the total revenue
revenue_treated = 0
revenue_treated = merged_all['price'].sum() * discount_percentage * 300/278

# Calculate the GTE
true = revenue_treated - revenue_control
print(true)
# Out:
# -68.6551789496238

# %%
# true GTE of male
merged_no_male = merged_no[merged_no['user_feature_1_num'] == 2]
merged_all_male = merged_all[merged_all['user_feature_1_num'] == 2]

true_male = merged_all_male['price'].sum() * discount_percentage * 300/142 - merged_no_male['price'].sum() * 300/137
print(true_male)
# Out:
# -80.69268816467334

# %%
# true GTE of female
merged_no_female = merged_no[merged_no['user_feature_1_num'] == 1]
merged_all_female = merged_all[merged_all['user_feature_1_num'] == 1]

true_female = merged_all_female['price'].sum() * discount_percentage * 300/132 - merged_no_female['price'].sum() * 300/151
print(true_female)
# Out:
# -57.54788503132873

# %%
# true GTE of phone usage less than 2 years
merged_no_phone_less_than_2_years = merged_no[merged_no['user_feature_2_num'].isin([1, 5])]
merged_all_phone_less_than_2_years = merged_all[merged_all['user_feature_2_num'].isin([1, 5])]

true_phone_less_than_2_years = merged_all_phone_less_than_2_years['price'].sum() * discount_percentage * 300/152- merged_no_phone_less_than_2_years['price'].sum() * 300/133
print(true_phone_less_than_2_years)
# Out:
# -93.18713450292398

# %%
# true GTE of phone usage more than 2 years
merged_no_phone_more_than_2_years = merged_no[merged_no['user_feature_2_num'].isin([2, 3, 6])]
merged_all_phone_more_than_2_years = merged_all[merged_all['user_feature_2_num'].isin([2, 3, 6])]

true_phone_more_than_2_years = merged_all_phone_more_than_2_years['price'].sum() * discount_percentage * 300/126 - merged_no_phone_more_than_2_years['price'].sum() * 300/157
print(true_phone_more_than_2_years)
# Out:
# -48.602208517282826

# %% [markdown]
# ## DIM Estimator

# %%
# Define the function to calculate the revenue
def calculate_total_revenue(df):
    revenue_treated = 0.0
    revenue_control = 0.0
    df['adjusted_price'] = df.apply(
        lambda row: row['price'] * discount_percentage if row['if_treated'] == 1 else row['price'], axis=1
    )
    for _, row in df.iterrows():
        if row['if_treated'] == 0:
            revenue_control += row['adjusted_price']
        elif row['if_treated'] == 1:
            revenue_treated += row['adjusted_price']
    return revenue_control, revenue_treated

# Merge the purchasing data with the product data
merged_half = half.merge(prod, left_on='choice_num', right_on='product_id', how='left')

# Calculate the revenue difference
revenue_control, revenue_treated = calculate_total_revenue(merged_half)

# Calculate the GTE
naive = (revenue_treated - revenue_control) * 600/266
naive
naive_pe = abs((naive - true)/true)
print(naive_pe)
# Out:
# 0.11024849998145407

# %%
# DIM Estimator of male
merged_half_male = merged_half.loc[merged_half['user_feature_1_num'] == 2].copy()

revenue_control, revenue_treated = calculate_total_revenue(merged_half_male)
naive_m = (revenue_treated - revenue_control) * 600/127
naive_m= abs((naive_m - true_male)/true_male)
print(naive_m)
# Out:
# 0.340102621429012

# %%
# DIM Estimator of female
merged_half_female = merged_half.loc[merged_half['user_feature_1_num'] == 1].copy()

revenue_control, revenue_treated = calculate_total_revenue(merged_half_female)
naive_f = (revenue_treated - revenue_control) * 600/134
naive_f= abs((naive_f - true_female)/true_female)
print(naive_f)
# Out:
# 0.6599558342892351

# %%
# DIM Estimator of phone usage less than 2 years
merged_half_phone_less_than_2_years = merged_half.loc[merged_half['user_feature_2_num'].isin([1, 5])].copy()

revenue_control, revenue_treated = calculate_total_revenue(merged_half_phone_less_than_2_years)
naive_phone_less_than_2_years = (revenue_treated - revenue_control) * 600/132
naive_phone_less_than_2_years= abs((naive_phone_less_than_2_years - true_phone_less_than_2_years)/true_phone_less_than_2_years)
print(naive_phone_less_than_2_years)
# Out:
# 0.2690570594555532

# %%
# DIM Estimator of phone usage more than 2 years
merged_half_phone_more_than_2_years = merged_half.loc[merged_half['user_feature_2_num'].isin([2, 3, 6])].copy()

revenue_control, revenue_treated = calculate_total_revenue(merged_half_phone_more_than_2_years)
naive_phone_more_than_2_years = (revenue_treated - revenue_control) * 600/134
naive_phone_more_than_2_years= abs((naive_phone_more_than_2_years - true_phone_more_than_2_years)/true_phone_more_than_2_years)
print(naive_phone_more_than_2_years)
# Out:
# 0.11440451744954902

# %% [markdown]
# ## MNL Estimator

# %%
feature_cols = ['product_feature_1', 'product_feature_2', 'product_feature_3']
encoded_features = pd.get_dummies(prod[feature_cols], dtype=float)
X_product = torch.tensor(encoded_features.iloc[1:].to_numpy(), dtype=torch.float)

user_num_cols = ['user_feature_1_num', 'user_feature_2_num', 'user_feature_3_num']
encoded_features = pd.get_dummies(merged_half[user_num_cols], dtype=float)
X_user = torch.tensor(encoded_features.to_numpy(), dtype=torch.float)

# %%
# Price (skip first row)
price = torch.tensor(prod['price'].iloc[1:].to_numpy(), dtype=torch.float)

# Product randomization (skip first row)
prod_randomization = torch.tensor(prod['if_treated'].iloc[1:].to_numpy(), dtype=torch.bool)

# User choice
choice = torch.tensor(
    merged_half['choice_num'].to_numpy(),
    dtype=torch.long
)

# %%
# Split the training and test set
X_user_train, X_user_test, choice_train, choice_test = train_test_split(
    X_user, choice, test_size=0.5, random_state=42
)

# Validation set
X_user_train1, X_user_val, choice_train1, choice_val = train_test_split(X_user_train, choice_train,test_size=0.1,random_state=34)

# To GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
X_user_train = X_user_train.to(device)
X_user_test  = X_user_test.to(device)
X_product    = X_product.to(device)
price        = price.to(device)
prod_randomization = prod_randomization.to(device)
choice_train = choice_train.to(device)
choice_test  = choice_test.to(device)
X_user_train1 = X_user_train1.to(device)
X_user_val = X_user_val.to(device)
choice_train1 = choice_train1.to(device)
choice_val = choice_val.to(device)

# %%
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)

# %% [markdown]
# ### No features

# %%
class LinearMNLModel_No(nn.Module):
    def __init__(self):
        super(LinearMNLModel_No, self).__init__()
        # v is the same constant value for all products.
        self.v = nn.Parameter(torch.tensor(1.0))
        # gamma is the price sensitivity parameter.
        self.gamma = nn.Parameter(torch.tensor(-1.0))

    def forward(self, x_user, X_product, price, prod_randomization):
        N = x_user.shape[0]
        # Adjust prices for treated products (discounted)
        adjusted_price = torch.where(
            prod_randomization,
            price * discount_percentage,
            price
        )
        # Compute utilities: shape [M]
        utility = self.v + self.gamma * adjusted_price
        # Expand to shape [N, M]
        utility = utility.expand(N, -1)
        # Add outside option (utility = 0)
        zero_utilities = torch.zeros(N, 1, device=utility.device)
        utilities_with_outside = torch.cat((zero_utilities, utility), dim=1)
        return utilities_with_outside

# %%
model = LinearMNLModel_No().to(device)
optimizer = optim.Adam(model.parameters(), lr=0.01) 

num_epochs = 1000
l2_lambda = 0
best_val_loss = float('inf')
patience = 10
patience_counter = 0

for epoch in range(num_epochs):
    # Set model to training mode
    model.train()
    optimizer.zero_grad()

    # Forward pass (Training)
    utilities = model(X_user_train1, X_product, price, prod_randomization)
    
    choice_probabilities = F.log_softmax(utilities, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])

    # L2 Regularization
    l2_norm = sum(param.pow(2.0).sum() for param in model.parameters())
    loss = loss + l2_lambda * l2_norm

    # Backward pass
    loss.backward()
    optimizer.step()
    model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        val_utilities = model(X_user_val, X_product, price, prod_randomization)
        
        # val_utilities = val_utilities - val_utilities.max(dim=1, keepdim=True).values
        
        val_choice_probabilities = F.log_softmax(val_utilities, dim=1)
        val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])

    if epoch % 100 == 0: 
        print(f"Epoch {epoch+1}, Training Loss: {loss.item()}, Validation Loss: {val_loss.item()}")

    if (val_loss < best_val_loss) | (val_loss < loss):
        best_val_loss = val_loss
        patience_counter = 0  # Reset counter
        # torch.save(model.state_dict(), 'best_model_linear_mnl.pth')  # Save best model
    else:
        patience_counter += 1  

    if patience_counter >= patience:
        print(f"Early stopping triggered at epoch {epoch}")
        break
# Out:
# Epoch 1, Training Loss: 2.2338318824768066, Validation Loss: 2.309324026107788
# Epoch 101, Training Loss: 1.6284080743789673, Validation Loss: 1.7031511068344116
# Epoch 201, Training Loss: 1.3864697217941284, Validation Loss: 1.4477146863937378
# Epoch 301, Training Loss: 1.3063338994979858, Validation Loss: 1.3437798023223877
# Epoch 401, Training Loss: 1.2679235935211182, Validation Loss: 1.2784843444824219
# Epoch 501, Training Loss: 1.2447000741958618, Validation Loss: 1.2307268381118774
# Epoch 601, Training Loss: 1.2312276363372803, Validation Loss: 1.1973267793655396
# Epoch 701, Training Loss: 1.223976492881775, Validation Loss: 1.174850344657898
# Epoch 801, Training Loss: 1.2203092575073242, Validation Loss: 1.1599458456039429
# Epoch 901, Training Loss: 1.2185577154159546, Validation Loss: 1.1501318216323853

# %%
# All control and all treated in test set
all_product_control = np.random.choice([0,1], num_product, p=[1, 0])
all_product_treated = np.random.choice([0,1], num_product, p=[0, 1])
all_product_control = torch.from_numpy(all_product_control).to(X_user_train.device).bool()
all_product_treated = torch.from_numpy(all_product_treated).to(X_user_train.device).bool()
X_user_test, X_product, price = X_user_test.to(device), X_product.to(device), price.to(device)

# Calculate expected revenue if all control
utilities = model(X_user_test, X_product, price, all_product_control)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum()
print(f"Expected Revenue: ${expected_revenue.item():.2f}")

# Calculate expected revenue if all treated
utilities = model(X_user_test, X_product, price, all_product_treated)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue_treated = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum() * discount_percentage
print(f"Expected Revenue: ${expected_revenue_treated.item():.2f}")

# Calculate GTE
linear = (expected_revenue_treated-expected_revenue).cpu().detach().numpy()
linear = linear * 600 / 266 # For comparison purpose
print(linear)
linear_no = abs((linear - true)/true)
print(linear_no)
# Out:
# Expected Revenue: $36.79
# Expected Revenue: $9.34
# -61.91161593100182
# 0.09822366093561738

# %%
def expected_revenue_for_users(Xu, X_product, price, treat_mask, discount_percentage=1.0):
    """
    Xu: [N_g, d_user]
    X_product: [M, d_prod] (or whatever your model expects)
    price: [M]
    treat_mask: [M] bool, indicates treated products (your model uses it)
    discount_percentage: scalar, multiply revenue by this in treated regime (your current logic)
    """
    utilities = model(Xu, X_product, price, treat_mask)              # [N_g, M+1] presumably
    probs = F.softmax(utilities, dim=1)                              # [N_g, M+1]
    price_with_outside = torch.cat((torch.zeros(1, device=price.device), price), dim=0)  # [M+1]
    rev_total = (probs * price_with_outside.unsqueeze(0)).sum()      # sum over i,j
    return rev_total * discount_percentage

# %%
# --- split test set by gender (column 1: 1=female, 2=male) ---
male_mask = (X_user_test[:, 1] == 2)
female_mask = (X_user_test[:, 1] == 1)

X_male = X_user_test[male_mask]
X_female = X_user_test[female_mask]

print(f"N_male={X_male.shape[0]}, N_female={X_female.shape[0]}, N_total={X_user_test.shape[0]}")

# --- male/female revenues and GTEs ---
rev_control_male = expected_revenue_for_users(X_male, X_product, price, all_product_control, 1.0)
rev_treated_male  = expected_revenue_for_users(X_male, X_product, price, all_product_treated, discount_percentage)
gte_male = rev_treated_male - rev_control_male

rev_control_female = expected_revenue_for_users(X_female, X_product, price, all_product_control, 1.0)
rev_treated_female  = expected_revenue_for_users(X_female, X_product, price, all_product_treated, discount_percentage)
gte_female = rev_treated_female - rev_control_female

# --- compare to overall ---
gte_male_scaled = (gte_male * 300/38).detach().cpu().numpy()
gte_female_scaled = (gte_female * 300/37).detach().cpu().numpy()

linear_no_m = abs((gte_male_scaled - true_male)/true_male)
linear_no_f = abs((gte_female_scaled - true_female)/true_female)

print(linear_no_m)
print(linear_no_f)
# Out:
# N_male=38, N_female=37, N_total=133
# 0.23274797095867503
# 0.07582778117130018

# %%
# split test set by phone usage
phone_less_than_2_years_mask = (X_user_test[:, 2] == 1) | (X_user_test[:, 2] == 5)
phone_more_than_2_years_mask = (X_user_test[:, 2] == 2) | (X_user_test[:, 2] == 3) | (X_user_test[:, 2] == 6)

X_phone_less_than_2_years = X_user_test[phone_less_than_2_years_mask]
X_phone_more_than_2_years = X_user_test[phone_more_than_2_years_mask]

print(f"N_phone_less_than_2_years={X_phone_less_than_2_years.shape[0]}, N_phone_more_than_2_years={X_phone_more_than_2_years.shape[0]}, N_total={X_user_test.shape[0]}")

# --- phone usage revenues and GTEs ---
rev_control_phone_less_than_2_years = expected_revenue_for_users(X_phone_less_than_2_years, X_product, price, all_product_control, 1.0)
rev_treated_phone_less_than_2_years  = expected_revenue_for_users(X_phone_less_than_2_years, X_product, price, all_product_treated, discount_percentage)
gte_phone_less_than_2_years = rev_treated_phone_less_than_2_years - rev_control_phone_less_than_2_years

rev_control_phone_more_than_2_years = expected_revenue_for_users(X_phone_more_than_2_years, X_product, price, all_product_control, 1.0)
rev_treated_phone_more_than_2_years  = expected_revenue_for_users(X_phone_more_than_2_years, X_product, price, all_product_treated, discount_percentage)
gte_phone_more_than_2_years = rev_treated_phone_more_than_2_years - rev_control_phone_more_than_2_years

gte_phone_less_than_2_years_scaled = (gte_phone_less_than_2_years * 300/7).detach().cpu().numpy()
gte_phone_more_than_2_years_scaled = (gte_phone_more_than_2_years * 300/50).detach().cpu().numpy()

linear_no_phone_less_than_2_years = abs((gte_phone_less_than_2_years_scaled - true_phone_less_than_2_years)/true_phone_less_than_2_years)
linear_no_phone_more_than_2_years = abs((gte_phone_more_than_2_years_scaled - true_phone_more_than_2_years)/true_phone_more_than_2_years)

print(linear_no_phone_less_than_2_years)
print(linear_no_phone_more_than_2_years)
# Out:
# N_phone_less_than_2_years=7, N_phone_more_than_2_years=50, N_total=133
# 0.3356205488096632
# 0.27384378164079476

# %% [markdown]
# ### Only user features

# %%
class LinearMNLModel_UserOnly(nn.Module):
    def __init__(self, user_feature_dim):
        super(LinearMNLModel_UserOnly, self).__init__()
        self.beta_user = nn.Parameter(torch.randn(user_feature_dim))
        self.beta_price = nn.Parameter(torch.tensor(-1.0))

    def forward(self, x_user, X_product, price, prod_randomization):
        N, M = x_user.shape[0], X_product.shape[0]

        # Expand user features
        x_user_expanded = x_user.unsqueeze(1).expand(-1, M, -1).detach()
        utility_user = torch.sum(x_user_expanded * self.beta_user, dim=2)

        # Price adjustment
        adjusted_price = torch.where(
            prod_randomization.unsqueeze(0),
            price * discount_percentage,
            price
        )
        utility_price = adjusted_price * self.beta_price
        utility_price = utility_price.expand(N, M)

        total_utility = utility_user + utility_price

        # Outside option
        zero_utilities = torch.zeros(N, 1, device=total_utility.device)
        utilities_with_outside = torch.cat((zero_utilities,total_utility), dim=1)
        return utilities_with_outside

# %%
# Model training
model = LinearMNLModel_UserOnly(user_feature_dim=X_user.shape[1]).to(device)

model.apply(init_weights)
optimizer = optim.Adam(model.parameters(), lr=0.01) 

num_epochs = 1000
l2_lambda = 0
best_val_loss = float('inf')
patience = 20
patience_counter = 0

for epoch in range(num_epochs):
    # Set model to training mode
    model.train()
    optimizer.zero_grad()

    # Forward pass (Training)
    utilities = model(X_user_train1, X_product, price, prod_randomization)
    
    choice_probabilities = F.log_softmax(utilities, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])

    # L2 Regularization
    l2_norm = sum(param.pow(2.0).sum() for param in model.parameters())
    loss = loss + l2_lambda * l2_norm

    # Backward pass
    loss.backward()
    optimizer.step()

    # --- 4. Validation phase ---
    model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        val_utilities = model(X_user_val, X_product, price, prod_randomization)
        
        val_utilities = val_utilities - val_utilities.max(dim=1, keepdim=True).values
        
        val_choice_probabilities = F.log_softmax(val_utilities, dim=1)
        val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])

    if epoch % 100 == 0: 
        print(f"Epoch {epoch+1}, Training Loss: {loss.item()}, Validation Loss: {val_loss.item()}")

    if (val_loss < best_val_loss) | (val_loss < loss):
        best_val_loss = val_loss
        patience_counter = 0  # Reset counter
        torch.save(model.state_dict(), 'best_model_linear_mnl.pth')  # Save best model
    else:
        patience_counter += 1  

    if patience_counter >= patience:
        print(f"Early stopping triggered at epoch {epoch}")
        break
# Out:
# Epoch 1, Training Loss: 1.4502323865890503, Validation Loss: 1.6980628967285156
# Epoch 101, Training Loss: 1.2196969985961914, Validation Loss: 1.1374529600143433
# Epoch 201, Training Loss: 1.2007864713668823, Validation Loss: 1.0574724674224854
# Epoch 301, Training Loss: 1.2006142139434814, Validation Loss: 1.055580735206604
# Epoch 401, Training Loss: 1.2006142139434814, Validation Loss: 1.0555391311645508
# Epoch 501, Training Loss: 1.2006142139434814, Validation Loss: 1.0555391311645508
# Epoch 601, Training Loss: 1.200614094734192, Validation Loss: 1.0555392503738403
# Epoch 701, Training Loss: 1.200614094734192, Validation Loss: 1.0555391311645508
# Epoch 801, Training Loss: 1.200614094734192, Validation Loss: 1.0555392503738403
# Epoch 901, Training Loss: 1.200614094734192, Validation Loss: 1.0555392503738403

# %%
# All control and all treated in test set
all_product_control = np.random.choice([0,1], num_product, p=[1, 0])
all_product_treated = np.random.choice([0,1], num_product, p=[0, 1])
all_product_control = torch.from_numpy(all_product_control).to(X_user_train.device).bool()
all_product_treated = torch.from_numpy(all_product_treated).to(X_user_train.device).bool()
X_user_test, X_product, price = X_user_test.to(device), X_product.to(device), price.to(device)

# Calculate expected revenue if all control
utilities = model(X_user_test, X_product, price, all_product_control)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum()
print(f"Expected Revenue: ${expected_revenue.item():.2f}")

# Calculate expected revenue if all treated
utilities = model(X_user_test, X_product, price, all_product_treated)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue_treated = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum() * discount_percentage
print(f"Expected Revenue: ${expected_revenue_treated.item():.2f}")

# Calculate GTE
linear = (expected_revenue_treated-expected_revenue).cpu().detach().numpy()
linear = linear * 600 / 266
print(linear)
linear_user_only = abs((linear - true)/true)
print(linear_user_only)
# Out:
# Expected Revenue: $36.35
# Expected Revenue: $8.86
# -61.990889929291
# 0.09706899205991101

# %%
# --- split test set by gender (column 1: 1=female, 2=male) ---
male_mask = (X_user_test[:, 1] == 2)
female_mask = (X_user_test[:, 1] == 1)

X_male = X_user_test[male_mask]
X_female = X_user_test[female_mask]

print(f"N_male={X_male.shape[0]}, N_female={X_female.shape[0]}, N_total={X_user_test.shape[0]}")

# --- male/female revenues and GTEs ---
rev_control_male = expected_revenue_for_users(X_male, X_product, price, all_product_control, 1.0)
rev_treated_male  = expected_revenue_for_users(X_male, X_product, price, all_product_treated, discount_percentage)
gte_male = rev_treated_male - rev_control_male

rev_control_female = expected_revenue_for_users(X_female, X_product, price, all_product_control, 1.0)
rev_treated_female  = expected_revenue_for_users(X_female, X_product, price, all_product_treated, discount_percentage)
gte_female = rev_treated_female - rev_control_female

# --- compare to overall ---
gte_male_scaled = (gte_male * 300/38).detach().cpu().numpy()
gte_female_scaled = (gte_female * 300/37).detach().cpu().numpy()

linear_user_m = abs((gte_male_scaled - true_male)/true_male)
linear_user_f = abs((gte_female_scaled - true_female)/true_female)

print(linear_user_m)
print(linear_user_f)
# Out:
# N_male=38, N_female=37, N_total=133
# 0.12584498428320687
# 0.6035545642696922

# %%
# split test set by phone usage
phone_less_than_2_years_mask = (X_user_test[:, 2] == 1) | (X_user_test[:, 2] == 5)
phone_more_than_2_years_mask = (X_user_test[:, 2] == 2) | (X_user_test[:, 2] == 3) | (X_user_test[:, 2] == 6)

X_phone_less_than_2_years = X_user_test[phone_less_than_2_years_mask]
X_phone_more_than_2_years = X_user_test[phone_more_than_2_years_mask]

print(f"N_phone_less_than_2_years={X_phone_less_than_2_years.shape[0]}, N_phone_more_than_2_years={X_phone_more_than_2_years.shape[0]}, N_total={X_user_test.shape[0]}")

# --- phone usage revenues and GTEs ---
rev_control_phone_less_than_2_years = expected_revenue_for_users(X_phone_less_than_2_years, X_product, price, all_product_control, 1.0)
rev_treated_phone_less_than_2_years  = expected_revenue_for_users(X_phone_less_than_2_years, X_product, price, all_product_treated, discount_percentage)
gte_phone_less_than_2_years = rev_treated_phone_less_than_2_years - rev_control_phone_less_than_2_years

rev_control_phone_more_than_2_years = expected_revenue_for_users(X_phone_more_than_2_years, X_product, price, all_product_control, 1.0)
rev_treated_phone_more_than_2_years  = expected_revenue_for_users(X_phone_more_than_2_years, X_product, price, all_product_treated, discount_percentage)
gte_phone_more_than_2_years = rev_treated_phone_more_than_2_years - rev_control_phone_more_than_2_years

gte_phone_less_than_2_years_scaled = (gte_phone_less_than_2_years * 300/7).detach().cpu().numpy()
gte_phone_more_than_2_years_scaled = (gte_phone_more_than_2_years * 300/50).detach().cpu().numpy()

linear_user_phone_less_than_2_years = abs((gte_phone_less_than_2_years_scaled - true_phone_less_than_2_years)/true_phone_less_than_2_years)
linear_user_phone_more_than_2_years = abs((gte_phone_more_than_2_years_scaled - true_phone_more_than_2_years)/true_phone_more_than_2_years)

print(linear_user_phone_less_than_2_years)
print(linear_user_phone_more_than_2_years)
# Out:
# N_phone_less_than_2_years=7, N_phone_more_than_2_years=50, N_total=133
# 0.19910989742799723
# 0.4221554543242563

# %% [markdown]
# ### Only product features

# %%
class LinearMNLModel_ProductOnly(nn.Module):
    def __init__(self, product_feature_dim):
        super(LinearMNLModel_ProductOnly, self).__init__()
        self.beta_product = nn.Parameter(torch.randn(product_feature_dim))
        self.beta_price = nn.Parameter(torch.tensor(-1.0))

    def forward(self, x_user, X_product, price, prod_randomization):
        N, M = x_user.shape[0], X_product.shape[0]

        # Expand product features
        X_product_expanded = X_product.unsqueeze(0).expand(N, -1, -1).detach()
        utility_product = torch.sum(X_product_expanded * self.beta_product, dim=2)

        # Price adjustment
        adjusted_price = torch.where(
            prod_randomization.unsqueeze(0),
            price * discount_percentage,
            price
        )
        utility_price = adjusted_price * self.beta_price
        utility_price = utility_price.expand(N, M)

        total_utility = utility_product + utility_price

        # Outside option
        zero_utilities = torch.zeros(N, 1, device=total_utility.device)
        utilities_with_outside = torch.cat((zero_utilities,total_utility), dim=1)
        return utilities_with_outside

# %%
# Model training
model = LinearMNLModel_ProductOnly(product_feature_dim=X_product.shape[1]).to(device)
model.apply(init_weights)
optimizer = optim.Adam(model.parameters(), lr=0.01) 


num_epochs = 1000
l2_lambda = 0
best_val_loss = float('inf')
patience = 20
patience_counter = 0

for epoch in range(num_epochs):
    # Set model to training mode
    model.train()
    optimizer.zero_grad()

    # Forward pass (Training)
    utilities = model(X_user_train1, X_product, price, prod_randomization)
    
    choice_probabilities = F.log_softmax(utilities, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])

    # L2 Regularization
    l2_norm = sum(param.pow(2.0).sum() for param in model.parameters())
    loss = loss + l2_lambda * l2_norm

    # Backward pass
    loss.backward()
    optimizer.step()


    model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        val_utilities = model(X_user_val, X_product, price, prod_randomization)
        
        # val_utilities = val_utilities - val_utilities.max(dim=1, keepdim=True).values
        
        val_choice_probabilities = F.log_softmax(val_utilities, dim=1)
        val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])

    if epoch % 100 == 0: 
        print(f"Epoch {epoch+1}, Training Loss: {loss.item()}, Validation Loss: {val_loss.item()}")

    if (val_loss < best_val_loss) | (val_loss < loss):
        best_val_loss = val_loss
        patience_counter = 0  # Reset counter
        torch.save(model.state_dict(), 'best_model_linear_mnl.pth')  # Save best model
    else:
        patience_counter += 1  

    if patience_counter >= patience:
        print(f"Early stopping triggered at epoch {epoch}")
        break
# Out:
# Epoch 1, Training Loss: 1.614937663078308, Validation Loss: 1.352612853050232
# Epoch 101, Training Loss: 1.3400852680206299, Validation Loss: 1.1078518629074097
# Epoch 201, Training Loss: 1.2386335134506226, Validation Loss: 1.1208598613739014
# Epoch 301, Training Loss: 1.1982858180999756, Validation Loss: 1.1638256311416626
# Early stopping triggered at epoch 383

# %%
# All control and all treated in test set
all_product_control = np.random.choice([0,1], num_product, p=[1, 0])
all_product_treated = np.random.choice([0,1], num_product, p=[0, 1])
all_product_control = torch.from_numpy(all_product_control).to(X_user_train.device).bool()
all_product_treated = torch.from_numpy(all_product_treated).to(X_user_train.device).bool()
X_user_test, X_product, price = X_user_test.to(device), X_product.to(device), price.to(device)

# Calculate expected revenue if all control
utilities = model(X_user_test, X_product, price, all_product_control)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum()
print(f"Expected Revenue: ${expected_revenue.item():.2f}")

# Calculate expected revenue if all treated
utilities = model(X_user_test, X_product, price, all_product_treated)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue_treated = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum() * discount_percentage
print(f"Expected Revenue: ${expected_revenue_treated.item():.2f}")

# Calculate GTE
linear = (expected_revenue_treated-expected_revenue).cpu().detach().numpy()
linear = linear * 600 / 266
print(linear)
linear_product_only = abs((linear - true)/true)
print(linear_product_only)
# Out:
# Expected Revenue: $32.10
# Expected Revenue: $10.87
# -47.88741491791001
# 0.30249377176559805

# %%
# --- split test set by gender (column 1: 1=female, 2=male) ---
male_mask = (X_user_test[:, 1] == 2)
female_mask = (X_user_test[:, 1] == 1)

X_male = X_user_test[male_mask]
X_female = X_user_test[female_mask]

print(f"N_male={X_male.shape[0]}, N_female={X_female.shape[0]}, N_total={X_user_test.shape[0]}")

# --- male/female revenues and GTEs ---
rev_control_male = expected_revenue_for_users(X_male, X_product, price, all_product_control, 1.0)
rev_treated_male  = expected_revenue_for_users(X_male, X_product, price, all_product_treated, discount_percentage)
gte_male = rev_treated_male - rev_control_male

rev_control_female = expected_revenue_for_users(X_female, X_product, price, all_product_control, 1.0)
rev_treated_female  = expected_revenue_for_users(X_female, X_product, price, all_product_treated, discount_percentage)
gte_female = rev_treated_female - rev_control_female

# --- compare to overall ---
gte_male_scaled = (gte_male * 300/38).detach().cpu().numpy()
gte_female_scaled = (gte_female * 300/37).detach().cpu().numpy()

linear_prod_m = abs((gte_male_scaled - true_male)/true_male)
linear_prod_f = abs((gte_female_scaled - true_female)/true_female)

print(linear_prod_m)
print(linear_prod_f)
# Out:
# N_male=38, N_female=37, N_total=133
# 0.40654586804099274
# 0.16786847711022826

# %%
# split test set by phone usage
phone_less_than_2_years_mask = (X_user_test[:, 2] == 1) | (X_user_test[:, 2] == 5)
phone_more_than_2_years_mask = (X_user_test[:, 2] == 2) | (X_user_test[:, 2] == 3) | (X_user_test[:, 2] == 6)

X_phone_less_than_2_years = X_user_test[phone_less_than_2_years_mask]
X_phone_more_than_2_years = X_user_test[phone_more_than_2_years_mask]

print(f"N_phone_less_than_2_years={X_phone_less_than_2_years.shape[0]}, N_phone_more_than_2_years={X_phone_more_than_2_years.shape[0]}, N_total={X_user_test.shape[0]}")

# --- phone usage revenues and GTEs ---
rev_control_phone_less_than_2_years = expected_revenue_for_users(X_phone_less_than_2_years, X_product, price, all_product_control, 1.0)
rev_treated_phone_less_than_2_years  = expected_revenue_for_users(X_phone_less_than_2_years, X_product, price, all_product_treated, discount_percentage)
gte_phone_less_than_2_years = rev_treated_phone_less_than_2_years - rev_control_phone_less_than_2_years

rev_control_phone_more_than_2_years = expected_revenue_for_users(X_phone_more_than_2_years, X_product, price, all_product_control, 1.0)
rev_treated_phone_more_than_2_years  = expected_revenue_for_users(X_phone_more_than_2_years, X_product, price, all_product_treated, discount_percentage)
gte_phone_more_than_2_years = rev_treated_phone_more_than_2_years - rev_control_phone_more_than_2_years

gte_phone_less_than_2_years_scaled = (gte_phone_less_than_2_years * 300/7).detach().cpu().numpy()
gte_phone_more_than_2_years_scaled = (gte_phone_more_than_2_years * 300/50).detach().cpu().numpy()

linear_prod_phone_less_than_2_years = abs((gte_phone_less_than_2_years_scaled - true_phone_less_than_2_years)/true_phone_less_than_2_years)
linear_prod_phone_more_than_2_years = abs((gte_phone_more_than_2_years_scaled - true_phone_more_than_2_years)/true_phone_more_than_2_years)

print(linear_prod_phone_less_than_2_years)
print(linear_prod_phone_more_than_2_years)
# Out:
# N_phone_less_than_2_years=7, N_phone_more_than_2_years=50, N_total=133
# 0.48611561799445874
# 0.014707057851626276

# %% [markdown]
# ### All features

# %%
# MNL choice model
class LinearMNLModel(nn.Module):
    def __init__(self, user_feature_dim, product_feature_dim):
        super(LinearMNLModel, self).__init__()
        # Initialize parameters for user and product features
        self.beta_user = nn.Parameter(torch.randn(user_feature_dim))
        self.beta_product = nn.Parameter(torch.randn(product_feature_dim))
        self.beta_price = nn.Parameter(torch.tensor(-1.0))
    def forward(self, x_user, X_product, price, prod_randomization):
        N, M = x_user.shape[0], X_product.shape[0]

        # Expand user and product features to create a [N, M, F] shaped tensor for each
        x_user_expanded = x_user.unsqueeze(1).expand(-1, M, -1).detach()
        X_product_expanded = X_product.unsqueeze(0).expand(N, -1, -1).detach()

        # Calculate linear utility from features
        utility_user = torch.sum(x_user_expanded * self.beta_user, dim=2)
        utility_product = torch.sum(X_product_expanded * self.beta_product, dim=2)

        # Adjust prices based on randomization
        adjusted_price = torch.where(
            prod_randomization.unsqueeze(0),
            price * discount_percentage,
            price
        )

        # Calculate utility from price, properly expanding its dimension
        utility_price = adjusted_price * self.beta_price  # [M]
        utility_price = utility_price.expand(N, M)  # [N, M]

        # Total utility including features and price
        total_utility = utility_user + utility_product + utility_price

        # Incorporate the outside option with utility 0
        zero_utilities = torch.zeros(N, 1, device=total_utility.device)
        utilities_with_outside = torch.cat((zero_utilities,total_utility), dim=1)

        return utilities_with_outside

# %%
# Model training
model = LinearMNLModel(user_feature_dim=X_user.shape[1], product_feature_dim=X_product.shape[1]).to(device)

model.apply(init_weights)
optimizer = optim.Adam(model.parameters(), lr=0.01) 
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)

num_epochs = 1000
l2_lambda = 0
best_val_loss = float('inf')
patience = 10
patience_counter = 0

for epoch in range(num_epochs):
    # Set model to training mode
    model.train()
    optimizer.zero_grad()

    # Forward pass (Training)
    utilities = model(X_user_train1, X_product, price, prod_randomization)
    
    choice_probabilities = F.log_softmax(utilities, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])

    # L2 Regularization
    l2_norm = sum(param.pow(2.0).sum() for param in model.parameters())
    loss = loss + l2_lambda * l2_norm

    # Backward pass
    loss.backward()
    optimizer.step()
    scheduler.step()

    # --- 4. Validation phase ---
    model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        val_utilities = model(X_user_val, X_product, price, prod_randomization)
        
        # val_utilities = val_utilities - val_utilities.max(dim=1, keepdim=True).values
        
        val_choice_probabilities = F.log_softmax(val_utilities, dim=1)
        val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])

    if epoch % 100 == 0: 
        print(f"Epoch {epoch+1}, Training Loss: {loss.item()}, Validation Loss: {val_loss.item()}")

    if (val_loss < best_val_loss) | (val_loss < loss):
        best_val_loss = val_loss
        patience_counter = 0  # Reset counter
        torch.save(model.state_dict(), 'best_model_linear_mnl.pth')  # Save best model
    else:
        patience_counter += 1  

    if patience_counter >= patience:
        print(f"Early stopping triggered at epoch {epoch}")
        break
# Out:
# Epoch 1, Training Loss: 1.4160881042480469, Validation Loss: 1.4592772722244263
# Epoch 101, Training Loss: 1.2002477645874023, Validation Loss: 1.222179651260376
# Early stopping triggered at epoch 186

# %%
# All control and all treated in test set
all_product_control = np.random.choice([0,1], num_product, p=[1, 0])
all_product_treated = np.random.choice([0,1], num_product, p=[0, 1])
all_product_control = torch.from_numpy(all_product_control).to(X_user_train.device).bool()
all_product_treated = torch.from_numpy(all_product_treated).to(X_user_train.device).bool()
X_user_test, X_product, price = X_user_test.to(device), X_product.to(device), price.to(device)

# Calculate expected revenue if all control
utilities = model(X_user_test, X_product, price, all_product_control)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum()
print(f"Expected Revenue: ${expected_revenue.item():.2f}")

# Calculate expected revenue if all treated
utilities = model(X_user_test, X_product, price, all_product_treated)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue_treated = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum() * discount_percentage
print(f"Expected Revenue: ${expected_revenue_treated.item():.2f}")

# Calculate GTE
linear = (expected_revenue_treated-expected_revenue).cpu().detach().numpy()
linear = linear * 600 / 266
print(linear)
linear_all = abs((linear - true)/true)
print(linear_all)
# Out:
# Expected Revenue: $32.09
# Expected Revenue: $10.10
# -49.600337322493246
# 0.2775441258570191

# %%
# --- split test set by gender (column 1: 1=female, 2=male) ---
male_mask = (X_user_test[:, 1] == 2)
female_mask = (X_user_test[:, 1] == 1)

X_male = X_user_test[male_mask]
X_female = X_user_test[female_mask]

print(f"N_male={X_male.shape[0]}, N_female={X_female.shape[0]}, N_total={X_user_test.shape[0]}")

# --- male/female revenues and GTEs ---
rev_control_male = expected_revenue_for_users(X_male, X_product, price, all_product_control, 1.0)
rev_treated_male  = expected_revenue_for_users(X_male, X_product, price, all_product_treated, discount_percentage)
gte_male = rev_treated_male - rev_control_male

rev_control_female = expected_revenue_for_users(X_female, X_product, price, all_product_control, 1.0)
rev_treated_female  = expected_revenue_for_users(X_female, X_product, price, all_product_treated, discount_percentage)
gte_female = rev_treated_female - rev_control_female

# --- compare to overall ---
gte_male_scaled = (gte_male * 300/38).detach().cpu().numpy()
gte_female_scaled = (gte_female * 300/37).detach().cpu().numpy()

linear_all_m = abs((gte_male_scaled - true_male)/true_male)
linear_all_f = abs((gte_female_scaled - true_female)/true_female)

print(linear_all_m)
print(linear_all_f)
# Out:
# N_male=38, N_female=37, N_total=133
# 0.29523043202494703
# 0.19761237387928132

# %%
# split test set by phone usage
phone_less_than_2_years_mask = (X_user_test[:, 2] == 1) | (X_user_test[:, 2] == 5)
phone_more_than_2_years_mask = (X_user_test[:, 2] == 2) | (X_user_test[:, 2] == 3) | (X_user_test[:, 2] == 6)

X_phone_less_than_2_years = X_user_test[phone_less_than_2_years_mask]
X_phone_more_than_2_years = X_user_test[phone_more_than_2_years_mask]

print(f"N_phone_less_than_2_years={X_phone_less_than_2_years.shape[0]}, N_phone_more_than_2_years={X_phone_more_than_2_years.shape[0]}, N_total={X_user_test.shape[0]}")

# --- phone usage revenues and GTEs ---
rev_control_phone_less_than_2_years = expected_revenue_for_users(X_phone_less_than_2_years, X_product, price, all_product_control, 1.0)
rev_treated_phone_less_than_2_years  = expected_revenue_for_users(X_phone_less_than_2_years, X_product, price, all_product_treated, discount_percentage)
gte_phone_less_than_2_years = rev_treated_phone_less_than_2_years - rev_control_phone_less_than_2_years

rev_control_phone_more_than_2_years = expected_revenue_for_users(X_phone_more_than_2_years, X_product, price, all_product_control, 1.0)
rev_treated_phone_more_than_2_years  = expected_revenue_for_users(X_phone_more_than_2_years, X_product, price, all_product_treated, discount_percentage)
gte_phone_more_than_2_years = rev_treated_phone_more_than_2_years - rev_control_phone_more_than_2_years

gte_phone_less_than_2_years_scaled = (gte_phone_less_than_2_years * 300/7).detach().cpu().numpy()
gte_phone_more_than_2_years_scaled = (gte_phone_more_than_2_years * 300/50).detach().cpu().numpy()

linear_all_phone_less_than_2_years = abs((gte_phone_less_than_2_years_scaled - true_phone_less_than_2_years)/true_phone_less_than_2_years)
linear_all_phone_more_than_2_years = abs((gte_phone_more_than_2_years_scaled - true_phone_more_than_2_years)/true_phone_more_than_2_years)

print(linear_all_phone_less_than_2_years)
print(linear_all_phone_more_than_2_years)
# Out:
# N_phone_less_than_2_years=7, N_phone_more_than_2_years=50, N_total=133
# 0.3705567016697319
# 0.039714582286700134

# %% [markdown]
# ## PDL Estimator

# %%
# Prepare data
def prepare_data(user_features, product_features, prices):
    num_products = product_features.shape[0]
    all_x_other_products = []
    all_other_prices = []
    for i in range(num_products):
        indices = [j for j in range(num_products) if j != i]
        other_products = product_features[indices].reshape(-1)
        other_product_prices = prices[indices]
        all_x_other_products.append(other_products)
        all_other_prices.append(other_product_prices)
    # Convert lists to tensor
    all_x_other_products = torch.stack(all_x_other_products, dim=0)
    all_other_prices = torch.stack(all_other_prices, dim=0)
    return user_features, product_features, prices, all_x_other_products, all_other_prices

# %% [markdown]
# ### No features

# %%
class DeepMNLModel_No(nn.Module):
    """
    Price-only Deep MNL:
    u_ij = theta(p_j)
    Outside option utility = 0.
    """
    def __init__(self, num_product, hidden=5):
        super(DeepMNLModel_No, self).__init__()

        # theta(p_j):
        # Input:  [1]
        # Output: scalar utility
        self.theta = nn.Sequential(
        nn.Linear(1, hidden),
        nn.ReLU(),
        nn.Linear(hidden, 1)

)

    def forward(self, x_user, X_product, X_other_products, x_other_prices, price, prod_randomization):
        """
        Inputs used:
        - price: [M]  own price p_j
        - prod_randomization: [M]  treatment indicator
        """
        device = price.device
        N, M = x_user.shape[0], price.shape[0]


        # Prepare input for theta: [M, 1]
        pj_input = price.unsqueeze(1)

        # Expand to all users: [N, M, 1]
        theta_input_exp = pj_input.unsqueeze(0).expand(N, -1, -1)

        # u_ij = theta(p_j): [N, M]
        utilities = self.theta(theta_input_exp).squeeze(-1)

        # Outside option utility = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utilities], dim=1)

        return utilities_with_outside

# %%
# Apply the model
model = DeepMNLModel_No(
    num_product=X_product.shape[0],
    hidden=5
).to(device)

model.apply(init_weights)
# Out:
# DeepMNLModel_No(
#   (theta): Sequential(
#     (0): Linear(in_features=1, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# ----- Prepare validation data -----
prepared_val = prepare_data(
    X_user_val,
    X_product,
    price * (1 - (1 - discount_percentage) * prod_randomization)
)
user_features_val, product_features_val, price_val, all_x_other_products_val, all_other_prices_val = prepared_val

user_features_val = user_features_val.to(device)
product_features_val = product_features_val.to(device)
all_x_other_products_val = all_x_other_products_val.to(device)
all_other_prices_val = all_other_prices_val.to(device)
choice_val = choice_val.to(device)

# ----- Optimizer and scheduler -----
optimizer = optim.Adam(model.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)
l2_lambda = 0  # L2 regularization coefficient

# Early stopping setup
best_val_loss = float('inf')
patience = 10
patience_counter = 0

# ----- Training loop -----
for epoch in range(5000):
    model.train()
    optimizer.zero_grad()

    # Forward pass (train): use prepared prices and other-prices matrix
    outputs = model(
        user_features,         # x_user (not used inside DeepMNLModel_No, but kept for interface)
        product_features,      # X_product (not used)
        all_x_other_products,  # X_other_products (not used in No model)
        all_other_prices,      # x_other_prices: p_-j
        prices,                # price: experimental p_j (after discount)
        prod_randomization     # can be ignored inside No model
    )
    choice_probabilities = F.log_softmax(outputs, dim=1)

    # Training loss
    loss = -torch.mean(
        choice_probabilities[
            torch.arange(choice_probabilities.shape[0], device=device),
            choice_train1
        ]
    )

    # L2 regularization
    l2_norm = sum(param.pow(2.0).sum() for param in model.parameters())
    loss = loss + l2_lambda * l2_norm

    # Backward
    loss.backward()
    optimizer.step()

    # ----- Validation -----
    model.eval()
    with torch.no_grad():
        val_outputs = model(
            user_features_val,
            product_features_val,
            all_x_other_products_val,
            all_other_prices_val,
            price_val,              # same product prices for validation
            prod_randomization
        )
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(
            val_choice_probabilities[
                torch.arange(val_choice_probabilities.shape[0], device=device),
                choice_val
            ]
        )

    print(
        f"Epoch {epoch+1}, "
        f"Training Loss: {loss.item():.4f}, "
        f"Validation Loss: {val_loss.item():.4f}"
    )

    # Early stopping logic
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        torch.save(model.state_dict(), 'best_model.pth')
    else:
        patience_counter += 1

    if patience_counter >= patience:
        print("Early stopping triggered")
        break

    scheduler.step()
# Out:
# Epoch 1, Training Loss: 2.2551, Validation Loss: 2.1917
# Epoch 2, Training Loss: 2.2225, Validation Loss: 2.1610
# Epoch 3, Training Loss: 2.1918, Validation Loss: 2.1322
# Epoch 4, Training Loss: 2.1626, Validation Loss: 2.1050
# Epoch 5, Training Loss: 2.1348, Validation Loss: 2.0786
# Epoch 6, Training Loss: 2.1079, Validation Loss: 2.0556
# Epoch 7, Training Loss: 2.0850, Validation Loss: 2.0335
# Epoch 8, Training Loss: 2.0630, Validation Loss: 2.0140
# Epoch 9, Training Loss: 2.0428, Validation Loss: 1.9962
# Epoch 10, Training Loss: 2.0241, Validation Loss: 1.9807
# Epoch 11, Training Loss: 2.0069, Validation Loss: 1.9662
# Epoch 12, Training Loss: 1.9906, Validation Loss: 1.9522
# Epoch 13, Training Loss: 1.9751, Validation Loss: 1.9388
# Epoch 14, Training Loss: 1.9601, Validation Loss: 1.9259
# Epoch 15, Training Loss: 1.9458, Validation Loss: 1.9136
# Epoch 16, Training Loss: 1.9320, Validation Loss: 1.9017
# Epoch 17, Training Loss: 1.9188, Validation Loss: 1.8902
# Epoch 18, Training Loss: 1.9061, Validation Loss: 1.8791
# Epoch 19, Training Loss: 1.8938, Validation Loss: 1.8684
# Epoch 20, Training Loss: 1.8820, Validation Loss: 1.8581
# Epoch 21, Training Loss: 1.8705, Validation Loss: 1.8481
# Epoch 22, Training Loss: 1.8595, Validation Loss: 1.8400
# Epoch 23, Training Loss: 1.8516, Validation Loss: 1.8329
# Epoch 24, Training Loss: 1.8443, Validation Loss: 1.8260
# Epoch 25, Training Loss: 1.8372, Validation Loss: 1.8191
# Epoch 26, Training Loss: 1.8302, Validation Loss: 1.8123
# Epoch 27, Training Loss: 1.8233, Validation Loss: 1.8056
# Epoch 28, Training Loss: 1.8165, Validation Loss: 1.7991
# Epoch 29, Training Loss: 1.8100, Validation Loss: 1.7934
# Epoch 30, Training Loss: 1.8050, Validation Loss: 1.7882
# Epoch 31, Training Loss: 1.8002, Validation Loss: 1.7831
# Epoch 32, Training Loss: 1.7955, Validation Loss: 1.7780
# Epoch 33, Training Loss: 1.7908, Validation Loss: 1.7730
# Epoch 34, Training Loss: 1.7862, Validation Loss: 1.7679
# Epoch 35, Training Loss: 1.7815, Validation Loss: 1.7629
# Epoch 36, Training Loss: 1.7769, Validation Loss: 1.7579
# Epoch 37, Training Loss: 1.7723, Validation Loss: 1.7529
# Epoch 38, Training Loss: 1.7677, Validation Loss: 1.7480
# Epoch 39, Training Loss: 1.7631, Validation Loss: 1.7430
# Epoch 40, Training Loss: 1.7586, Validation Loss: 1.7381
# Epoch 41, Training Loss: 1.7541, Validation Loss: 1.7332
# Epoch 42, Training Loss: 1.7496, Validation Loss: 1.7283
# Epoch 43, Training Loss: 1.7451, Validation Loss: 1.7234
# Epoch 44, Training Loss: 1.7406, Validation Loss: 1.7186
# Epoch 45, Training Loss: 1.7362, Validation Loss: 1.7138
# Epoch 46, Training Loss: 1.7318, Validation Loss: 1.7090
# Epoch 47, Training Loss: 1.7274, Validation Loss: 1.7042
# Epoch 48, Training Loss: 1.7230, Validation Loss: 1.6995
# Epoch 49, Training Loss: 1.7186, Validation Loss: 1.6947
# Epoch 50, Training Loss: 1.7143, Validation Loss: 1.6900
# Epoch 51, Training Loss: 1.7100, Validation Loss: 1.6853
# Epoch 52, Training Loss: 1.7057, Validation Loss: 1.6806
# Epoch 53, Training Loss: 1.7014, Validation Loss: 1.6760
# Epoch 54, Training Loss: 1.6971, Validation Loss: 1.6714
# Epoch 55, Training Loss: 1.6929, Validation Loss: 1.6668
# Epoch 56, Training Loss: 1.6887, Validation Loss: 1.6622
# Epoch 57, Training Loss: 1.6845, Validation Loss: 1.6576
# Epoch 58, Training Loss: 1.6803, Validation Loss: 1.6531
# Epoch 59, Training Loss: 1.6762, Validation Loss: 1.6486
# Epoch 60, Training Loss: 1.6720, Validation Loss: 1.6441
# Epoch 61, Training Loss: 1.6679, Validation Loss: 1.6396
# Epoch 62, Training Loss: 1.6638, Validation Loss: 1.6351
# Epoch 63, Training Loss: 1.6598, Validation Loss: 1.6307
# Epoch 64, Training Loss: 1.6557, Validation Loss: 1.6263
# Epoch 65, Training Loss: 1.6517, Validation Loss: 1.6219
# Epoch 66, Training Loss: 1.6477, Validation Loss: 1.6176
# Epoch 67, Training Loss: 1.6437, Validation Loss: 1.6132
# Epoch 68, Training Loss: 1.6398, Validation Loss: 1.6089
# Epoch 69, Training Loss: 1.6358, Validation Loss: 1.6046
# Epoch 70, Training Loss: 1.6319, Validation Loss: 1.6004
# Epoch 71, Training Loss: 1.6280, Validation Loss: 1.5961
# Epoch 72, Training Loss: 1.6242, Validation Loss: 1.5919
# Epoch 73, Training Loss: 1.6203, Validation Loss: 1.5877
# Epoch 74, Training Loss: 1.6165, Validation Loss: 1.5835
# Epoch 75, Training Loss: 1.6127, Validation Loss: 1.5794
# Epoch 76, Training Loss: 1.6089, Validation Loss: 1.5752
# Epoch 77, Training Loss: 1.6052, Validation Loss: 1.5711
# Epoch 78, Training Loss: 1.6015, Validation Loss: 1.5671
# Epoch 79, Training Loss: 1.5978, Validation Loss: 1.5630
# Epoch 80, Training Loss: 1.5941, Validation Loss: 1.5590
# Epoch 81, Training Loss: 1.5904, Validation Loss: 1.5550
# Epoch 82, Training Loss: 1.5868, Validation Loss: 1.5510
# Epoch 83, Training Loss: 1.5832, Validation Loss: 1.5470
# Epoch 84, Training Loss: 1.5796, Validation Loss: 1.5431
# Epoch 85, Training Loss: 1.5760, Validation Loss: 1.5392
# Epoch 86, Training Loss: 1.5725, Validation Loss: 1.5353
# Epoch 87, Training Loss: 1.5689, Validation Loss: 1.5314
# Epoch 88, Training Loss: 1.5654, Validation Loss: 1.5276
# Epoch 89, Training Loss: 1.5620, Validation Loss: 1.5237
# Epoch 90, Training Loss: 1.5585, Validation Loss: 1.5199
# Epoch 91, Training Loss: 1.5551, Validation Loss: 1.5162
# Epoch 92, Training Loss: 1.5517, Validation Loss: 1.5124
# Epoch 93, Training Loss: 1.5483, Validation Loss: 1.5087
# Epoch 94, Training Loss: 1.5449, Validation Loss: 1.5050
# Epoch 95, Training Loss: 1.5416, Validation Loss: 1.5013
# Epoch 96, Training Loss: 1.5383, Validation Loss: 1.4977
# Epoch 97, Training Loss: 1.5350, Validation Loss: 1.4941
# Epoch 98, Training Loss: 1.5317, Validation Loss: 1.4905
# Epoch 99, Training Loss: 1.5285, Validation Loss: 1.4869
# Epoch 100, Training Loss: 1.5252, Validation Loss: 1.4833
# Epoch 101, Training Loss: 1.5221, Validation Loss: 1.4798
# Epoch 102, Training Loss: 1.5189, Validation Loss: 1.4763
# Epoch 103, Training Loss: 1.5157, Validation Loss: 1.4728
# Epoch 104, Training Loss: 1.5126, Validation Loss: 1.4694
# Epoch 105, Training Loss: 1.5095, Validation Loss: 1.4659
# Epoch 106, Training Loss: 1.5064, Validation Loss: 1.4625
# Epoch 107, Training Loss: 1.5033, Validation Loss: 1.4591
# Epoch 108, Training Loss: 1.5003, Validation Loss: 1.4558
# Epoch 109, Training Loss: 1.4973, Validation Loss: 1.4524
# Epoch 110, Training Loss: 1.4943, Validation Loss: 1.4491
# Epoch 111, Training Loss: 1.4913, Validation Loss: 1.4458
# Epoch 112, Training Loss: 1.4884, Validation Loss: 1.4426
# Epoch 113, Training Loss: 1.4855, Validation Loss: 1.4393
# Epoch 114, Training Loss: 1.4826, Validation Loss: 1.4361
# Epoch 115, Training Loss: 1.4797, Validation Loss: 1.4329
# Epoch 116, Training Loss: 1.4769, Validation Loss: 1.4297
# Epoch 117, Training Loss: 1.4740, Validation Loss: 1.4266
# Epoch 118, Training Loss: 1.4712, Validation Loss: 1.4235
# Epoch 119, Training Loss: 1.4684, Validation Loss: 1.4204
# Epoch 120, Training Loss: 1.4657, Validation Loss: 1.4173
# Epoch 121, Training Loss: 1.4629, Validation Loss: 1.4142
# Epoch 122, Training Loss: 1.4602, Validation Loss: 1.4112
# Epoch 123, Training Loss: 1.4575, Validation Loss: 1.4082
# Epoch 124, Training Loss: 1.4548, Validation Loss: 1.4052
# Epoch 125, Training Loss: 1.4522, Validation Loss: 1.4023
# Epoch 126, Training Loss: 1.4496, Validation Loss: 1.3993
# Epoch 127, Training Loss: 1.4470, Validation Loss: 1.3964
# Epoch 128, Training Loss: 1.4444, Validation Loss: 1.3935
# Epoch 129, Training Loss: 1.4418, Validation Loss: 1.3907
# Epoch 130, Training Loss: 1.4393, Validation Loss: 1.3878
# Epoch 131, Training Loss: 1.4368, Validation Loss: 1.3850
# Epoch 132, Training Loss: 1.4343, Validation Loss: 1.3822
# Epoch 133, Training Loss: 1.4318, Validation Loss: 1.3794
# Epoch 134, Training Loss: 1.4293, Validation Loss: 1.3767
# Epoch 135, Training Loss: 1.4269, Validation Loss: 1.3739
# Epoch 136, Training Loss: 1.4245, Validation Loss: 1.3712
# Epoch 137, Training Loss: 1.4221, Validation Loss: 1.3686
# Epoch 138, Training Loss: 1.4197, Validation Loss: 1.3659
# Epoch 139, Training Loss: 1.4174, Validation Loss: 1.3633
# Epoch 140, Training Loss: 1.4151, Validation Loss: 1.3606
# Epoch 141, Training Loss: 1.4128, Validation Loss: 1.3580
# Epoch 142, Training Loss: 1.4105, Validation Loss: 1.3555
# Epoch 143, Training Loss: 1.4082, Validation Loss: 1.3529
# Epoch 144, Training Loss: 1.4060, Validation Loss: 1.3504
# Epoch 145, Training Loss: 1.4038, Validation Loss: 1.3479
# Epoch 146, Training Loss: 1.4016, Validation Loss: 1.3454
# Epoch 147, Training Loss: 1.3994, Validation Loss: 1.3429
# Epoch 148, Training Loss: 1.3972, Validation Loss: 1.3405
# Epoch 149, Training Loss: 1.3951, Validation Loss: 1.3381
# Epoch 150, Training Loss: 1.3930, Validation Loss: 1.3357
# Epoch 151, Training Loss: 1.3909, Validation Loss: 1.3333
# Epoch 152, Training Loss: 1.3888, Validation Loss: 1.3309
# Epoch 153, Training Loss: 1.3867, Validation Loss: 1.3286
# Epoch 154, Training Loss: 1.3847, Validation Loss: 1.3263
# Epoch 155, Training Loss: 1.3827, Validation Loss: 1.3240
# Epoch 156, Training Loss: 1.3807, Validation Loss: 1.3217
# Epoch 157, Training Loss: 1.3787, Validation Loss: 1.3194
# Epoch 158, Training Loss: 1.3768, Validation Loss: 1.3172
# Epoch 159, Training Loss: 1.3748, Validation Loss: 1.3150
# Epoch 160, Training Loss: 1.3729, Validation Loss: 1.3128
# Epoch 161, Training Loss: 1.3710, Validation Loss: 1.3106
# Epoch 162, Training Loss: 1.3691, Validation Loss: 1.3085
# Epoch 163, Training Loss: 1.3673, Validation Loss: 1.3063
# Epoch 164, Training Loss: 1.3654, Validation Loss: 1.3042
# Epoch 165, Training Loss: 1.3636, Validation Loss: 1.3021
# Epoch 166, Training Loss: 1.3618, Validation Loss: 1.3001
# Epoch 167, Training Loss: 1.3600, Validation Loss: 1.2980
# Epoch 168, Training Loss: 1.3582, Validation Loss: 1.2960
# Epoch 169, Training Loss: 1.3565, Validation Loss: 1.2940
# Epoch 170, Training Loss: 1.3547, Validation Loss: 1.2920
# Epoch 171, Training Loss: 1.3530, Validation Loss: 1.2900
# Epoch 172, Training Loss: 1.3513, Validation Loss: 1.2880
# Epoch 173, Training Loss: 1.3496, Validation Loss: 1.2861
# Epoch 174, Training Loss: 1.3480, Validation Loss: 1.2842
# Epoch 175, Training Loss: 1.3463, Validation Loss: 1.2823
# Epoch 176, Training Loss: 1.3447, Validation Loss: 1.2804
# Epoch 177, Training Loss: 1.3431, Validation Loss: 1.2785
# Epoch 178, Training Loss: 1.3415, Validation Loss: 1.2767
# Epoch 179, Training Loss: 1.3399, Validation Loss: 1.2749
# Epoch 180, Training Loss: 1.3384, Validation Loss: 1.2730
# Epoch 181, Training Loss: 1.3368, Validation Loss: 1.2712
# Epoch 182, Training Loss: 1.3353, Validation Loss: 1.2695
# Epoch 183, Training Loss: 1.3338, Validation Loss: 1.2677
# Epoch 184, Training Loss: 1.3323, Validation Loss: 1.2660
# Epoch 185, Training Loss: 1.3308, Validation Loss: 1.2643
# Epoch 186, Training Loss: 1.3294, Validation Loss: 1.2625
# Epoch 187, Training Loss: 1.3279, Validation Loss: 1.2609
# Epoch 188, Training Loss: 1.3265, Validation Loss: 1.2592
# Epoch 189, Training Loss: 1.3251, Validation Loss: 1.2575
# Epoch 190, Training Loss: 1.3237, Validation Loss: 1.2559
# Epoch 191, Training Loss: 1.3223, Validation Loss: 1.2543
# Epoch 192, Training Loss: 1.3209, Validation Loss: 1.2527
# Epoch 193, Training Loss: 1.3196, Validation Loss: 1.2511
# Epoch 194, Training Loss: 1.3183, Validation Loss: 1.2495
# Epoch 195, Training Loss: 1.3169, Validation Loss: 1.2480
# Epoch 196, Training Loss: 1.3156, Validation Loss: 1.2464
# Epoch 197, Training Loss: 1.3143, Validation Loss: 1.2449
# Epoch 198, Training Loss: 1.3131, Validation Loss: 1.2434
# Epoch 199, Training Loss: 1.3118, Validation Loss: 1.2419
# Epoch 200, Training Loss: 1.3106, Validation Loss: 1.2404
# Epoch 201, Training Loss: 1.3093, Validation Loss: 1.2390
# Epoch 202, Training Loss: 1.3081, Validation Loss: 1.2375
# Epoch 203, Training Loss: 1.3069, Validation Loss: 1.2361
# Epoch 204, Training Loss: 1.3057, Validation Loss: 1.2347
# Epoch 205, Training Loss: 1.3046, Validation Loss: 1.2333
# Epoch 206, Training Loss: 1.3034, Validation Loss: 1.2319
# Epoch 207, Training Loss: 1.3022, Validation Loss: 1.2305
# Epoch 208, Training Loss: 1.3011, Validation Loss: 1.2292
# Epoch 209, Training Loss: 1.3000, Validation Loss: 1.2278
# Epoch 210, Training Loss: 1.2989, Validation Loss: 1.2265
# Epoch 211, Training Loss: 1.2978, Validation Loss: 1.2252
# Epoch 212, Training Loss: 1.2967, Validation Loss: 1.2239
# Epoch 213, Training Loss: 1.2956, Validation Loss: 1.2226
# Epoch 214, Training Loss: 1.2946, Validation Loss: 1.2213
# Epoch 215, Training Loss: 1.2935, Validation Loss: 1.2201
# Epoch 216, Training Loss: 1.2925, Validation Loss: 1.2188
# Epoch 217, Training Loss: 1.2915, Validation Loss: 1.2176
# Epoch 218, Training Loss: 1.2905, Validation Loss: 1.2164
# Epoch 219, Training Loss: 1.2895, Validation Loss: 1.2152
# Epoch 220, Training Loss: 1.2885, Validation Loss: 1.2140
# Epoch 221, Training Loss: 1.2876, Validation Loss: 1.2128
# Epoch 222, Training Loss: 1.2866, Validation Loss: 1.2116
# Epoch 223, Training Loss: 1.2857, Validation Loss: 1.2105
# Epoch 224, Training Loss: 1.2847, Validation Loss: 1.2093
# Epoch 225, Training Loss: 1.2838, Validation Loss: 1.2082
# Epoch 226, Training Loss: 1.2829, Validation Loss: 1.2071
# Epoch 227, Training Loss: 1.2820, Validation Loss: 1.2060
# Epoch 228, Training Loss: 1.2811, Validation Loss: 1.2049
# Epoch 229, Training Loss: 1.2802, Validation Loss: 1.2038
# Epoch 230, Training Loss: 1.2794, Validation Loss: 1.2028
# Epoch 231, Training Loss: 1.2785, Validation Loss: 1.2017
# Epoch 232, Training Loss: 1.2777, Validation Loss: 1.2007
# Epoch 233, Training Loss: 1.2768, Validation Loss: 1.1996
# Epoch 234, Training Loss: 1.2760, Validation Loss: 1.1986
# Epoch 235, Training Loss: 1.2752, Validation Loss: 1.1976
# Epoch 236, Training Loss: 1.2744, Validation Loss: 1.1966
# Epoch 237, Training Loss: 1.2736, Validation Loss: 1.1956
# Epoch 238, Training Loss: 1.2728, Validation Loss: 1.1947
# Epoch 239, Training Loss: 1.2721, Validation Loss: 1.1937
# Epoch 240, Training Loss: 1.2713, Validation Loss: 1.1928
# Epoch 241, Training Loss: 1.2705, Validation Loss: 1.1918
# Epoch 242, Training Loss: 1.2698, Validation Loss: 1.1909
# Epoch 243, Training Loss: 1.2691, Validation Loss: 1.1900
# Epoch 244, Training Loss: 1.2683, Validation Loss: 1.1891
# Epoch 245, Training Loss: 1.2676, Validation Loss: 1.1882
# Epoch 246, Training Loss: 1.2669, Validation Loss: 1.1873
# Epoch 247, Training Loss: 1.2662, Validation Loss: 1.1864
# Epoch 248, Training Loss: 1.2656, Validation Loss: 1.1855
# Epoch 249, Training Loss: 1.2649, Validation Loss: 1.1847
# Epoch 250, Training Loss: 1.2642, Validation Loss: 1.1838
# Epoch 251, Training Loss: 1.2635, Validation Loss: 1.1830
# Epoch 252, Training Loss: 1.2629, Validation Loss: 1.1822
# Epoch 253, Training Loss: 1.2623, Validation Loss: 1.1813
# Epoch 254, Training Loss: 1.2616, Validation Loss: 1.1805
# Epoch 255, Training Loss: 1.2610, Validation Loss: 1.1797
# Epoch 256, Training Loss: 1.2604, Validation Loss: 1.1789
# Epoch 257, Training Loss: 1.2598, Validation Loss: 1.1782
# Epoch 258, Training Loss: 1.2592, Validation Loss: 1.1774
# Epoch 259, Training Loss: 1.2586, Validation Loss: 1.1766
# Epoch 260, Training Loss: 1.2580, Validation Loss: 1.1759
# Epoch 261, Training Loss: 1.2574, Validation Loss: 1.1751
# Epoch 262, Training Loss: 1.2569, Validation Loss: 1.1744
# Epoch 263, Training Loss: 1.2563, Validation Loss: 1.1737
# Epoch 264, Training Loss: 1.2557, Validation Loss: 1.1729
# Epoch 265, Training Loss: 1.2552, Validation Loss: 1.1722
# Epoch 266, Training Loss: 1.2547, Validation Loss: 1.1715
# Epoch 267, Training Loss: 1.2541, Validation Loss: 1.1708
# Epoch 268, Training Loss: 1.2536, Validation Loss: 1.1701
# Epoch 269, Training Loss: 1.2531, Validation Loss: 1.1695
# Epoch 270, Training Loss: 1.2526, Validation Loss: 1.1688
# Epoch 271, Training Loss: 1.2521, Validation Loss: 1.1681
# Epoch 272, Training Loss: 1.2516, Validation Loss: 1.1675
# Epoch 273, Training Loss: 1.2511, Validation Loss: 1.1668
# Epoch 274, Training Loss: 1.2506, Validation Loss: 1.1662
# Epoch 275, Training Loss: 1.2501, Validation Loss: 1.1656
# Epoch 276, Training Loss: 1.2497, Validation Loss: 1.1649
# Epoch 277, Training Loss: 1.2492, Validation Loss: 1.1643
# Epoch 278, Training Loss: 1.2488, Validation Loss: 1.1637
# Epoch 279, Training Loss: 1.2483, Validation Loss: 1.1631
# Epoch 280, Training Loss: 1.2479, Validation Loss: 1.1625
# Epoch 281, Training Loss: 1.2474, Validation Loss: 1.1619
# Epoch 282, Training Loss: 1.2470, Validation Loss: 1.1613
# Epoch 283, Training Loss: 1.2466, Validation Loss: 1.1608
# Epoch 284, Training Loss: 1.2462, Validation Loss: 1.1602
# Epoch 285, Training Loss: 1.2457, Validation Loss: 1.1596
# Epoch 286, Training Loss: 1.2453, Validation Loss: 1.1591
# Epoch 287, Training Loss: 1.2449, Validation Loss: 1.1585
# Epoch 288, Training Loss: 1.2445, Validation Loss: 1.1580
# Epoch 289, Training Loss: 1.2442, Validation Loss: 1.1575
# Epoch 290, Training Loss: 1.2438, Validation Loss: 1.1569
# Epoch 291, Training Loss: 1.2434, Validation Loss: 1.1564
# Epoch 292, Training Loss: 1.2430, Validation Loss: 1.1559
# Epoch 293, Training Loss: 1.2427, Validation Loss: 1.1554
# Epoch 294, Training Loss: 1.2423, Validation Loss: 1.1549
# Epoch 295, Training Loss: 1.2419, Validation Loss: 1.1544
# Epoch 296, Training Loss: 1.2416, Validation Loss: 1.1539
# Epoch 297, Training Loss: 1.2412, Validation Loss: 1.1534
# Epoch 298, Training Loss: 1.2409, Validation Loss: 1.1530
# Epoch 299, Training Loss: 1.2406, Validation Loss: 1.1525
# Epoch 300, Training Loss: 1.2402, Validation Loss: 1.1520
# Epoch 301, Training Loss: 1.2399, Validation Loss: 1.1516
# Epoch 302, Training Loss: 1.2396, Validation Loss: 1.1511
# Epoch 303, Training Loss: 1.2393, Validation Loss: 1.1506
# Epoch 304, Training Loss: 1.2389, Validation Loss: 1.1502
# Epoch 305, Training Loss: 1.2386, Validation Loss: 1.1498
# Epoch 306, Training Loss: 1.2383, Validation Loss: 1.1493
# Epoch 307, Training Loss: 1.2380, Validation Loss: 1.1489
# Epoch 308, Training Loss: 1.2377, Validation Loss: 1.1485
# Epoch 309, Training Loss: 1.2375, Validation Loss: 1.1481
# Epoch 310, Training Loss: 1.2372, Validation Loss: 1.1477
# Epoch 311, Training Loss: 1.2369, Validation Loss: 1.1472
# Epoch 312, Training Loss: 1.2366, Validation Loss: 1.1468
# Epoch 313, Training Loss: 1.2363, Validation Loss: 1.1464
# Epoch 314, Training Loss: 1.2361, Validation Loss: 1.1460
# Epoch 315, Training Loss: 1.2358, Validation Loss: 1.1457
# Epoch 316, Training Loss: 1.2355, Validation Loss: 1.1453
# Epoch 317, Training Loss: 1.2353, Validation Loss: 1.1449
# Epoch 318, Training Loss: 1.2350, Validation Loss: 1.1445
# Epoch 319, Training Loss: 1.2348, Validation Loss: 1.1442
# Epoch 320, Training Loss: 1.2345, Validation Loss: 1.1438
# Epoch 321, Training Loss: 1.2343, Validation Loss: 1.1434
# Epoch 322, Training Loss: 1.2340, Validation Loss: 1.1431
# Epoch 323, Training Loss: 1.2338, Validation Loss: 1.1427
# Epoch 324, Training Loss: 1.2336, Validation Loss: 1.1424
# Epoch 325, Training Loss: 1.2334, Validation Loss: 1.1420
# Epoch 326, Training Loss: 1.2331, Validation Loss: 1.1417
# Epoch 327, Training Loss: 1.2329, Validation Loss: 1.1414
# Epoch 328, Training Loss: 1.2327, Validation Loss: 1.1410
# Epoch 329, Training Loss: 1.2325, Validation Loss: 1.1407
# Epoch 330, Training Loss: 1.2323, Validation Loss: 1.1404
# Epoch 331, Training Loss: 1.2321, Validation Loss: 1.1401
# Epoch 332, Training Loss: 1.2319, Validation Loss: 1.1397
# Epoch 333, Training Loss: 1.2316, Validation Loss: 1.1394
# Epoch 334, Training Loss: 1.2315, Validation Loss: 1.1391
# Epoch 335, Training Loss: 1.2313, Validation Loss: 1.1388
# Epoch 336, Training Loss: 1.2311, Validation Loss: 1.1385
# Epoch 337, Training Loss: 1.2309, Validation Loss: 1.1382
# Epoch 338, Training Loss: 1.2307, Validation Loss: 1.1379
# Epoch 339, Training Loss: 1.2305, Validation Loss: 1.1376
# Epoch 340, Training Loss: 1.2303, Validation Loss: 1.1374
# Epoch 341, Training Loss: 1.2301, Validation Loss: 1.1371
# Epoch 342, Training Loss: 1.2300, Validation Loss: 1.1368
# Epoch 343, Training Loss: 1.2298, Validation Loss: 1.1365
# Epoch 344, Training Loss: 1.2296, Validation Loss: 1.1363
# Epoch 345, Training Loss: 1.2295, Validation Loss: 1.1360
# Epoch 346, Training Loss: 1.2293, Validation Loss: 1.1357
# Epoch 347, Training Loss: 1.2291, Validation Loss: 1.1355
# Epoch 348, Training Loss: 1.2290, Validation Loss: 1.1352
# Epoch 349, Training Loss: 1.2288, Validation Loss: 1.1350
# Epoch 350, Training Loss: 1.2287, Validation Loss: 1.1347
# Epoch 351, Training Loss: 1.2285, Validation Loss: 1.1344
# Epoch 352, Training Loss: 1.2284, Validation Loss: 1.1342
# Epoch 353, Training Loss: 1.2282, Validation Loss: 1.1340
# Epoch 354, Training Loss: 1.2281, Validation Loss: 1.1337
# Epoch 355, Training Loss: 1.2279, Validation Loss: 1.1335
# Epoch 356, Training Loss: 1.2278, Validation Loss: 1.1333
# Epoch 357, Training Loss: 1.2276, Validation Loss: 1.1330
# Epoch 358, Training Loss: 1.2275, Validation Loss: 1.1328
# Epoch 359, Training Loss: 1.2274, Validation Loss: 1.1326
# Epoch 360, Training Loss: 1.2272, Validation Loss: 1.1323
# Epoch 361, Training Loss: 1.2271, Validation Loss: 1.1321
# Epoch 362, Training Loss: 1.2270, Validation Loss: 1.1319
# Epoch 363, Training Loss: 1.2269, Validation Loss: 1.1317
# Epoch 364, Training Loss: 1.2267, Validation Loss: 1.1315
# Epoch 365, Training Loss: 1.2266, Validation Loss: 1.1313
# Epoch 366, Training Loss: 1.2265, Validation Loss: 1.1311
# Epoch 367, Training Loss: 1.2264, Validation Loss: 1.1309
# Epoch 368, Training Loss: 1.2263, Validation Loss: 1.1307
# Epoch 369, Training Loss: 1.2262, Validation Loss: 1.1305
# Epoch 370, Training Loss: 1.2260, Validation Loss: 1.1303
# Epoch 371, Training Loss: 1.2259, Validation Loss: 1.1301
# Epoch 372, Training Loss: 1.2258, Validation Loss: 1.1299
# Epoch 373, Training Loss: 1.2257, Validation Loss: 1.1297
# Epoch 374, Training Loss: 1.2256, Validation Loss: 1.1295
# Epoch 375, Training Loss: 1.2255, Validation Loss: 1.1293
# Epoch 376, Training Loss: 1.2254, Validation Loss: 1.1291
# Epoch 377, Training Loss: 1.2253, Validation Loss: 1.1290
# Epoch 378, Training Loss: 1.2252, Validation Loss: 1.1288
# Epoch 379, Training Loss: 1.2251, Validation Loss: 1.1286
# Epoch 380, Training Loss: 1.2250, Validation Loss: 1.1284
# Epoch 381, Training Loss: 1.2249, Validation Loss: 1.1283
# Epoch 382, Training Loss: 1.2248, Validation Loss: 1.1281
# Epoch 383, Training Loss: 1.2247, Validation Loss: 1.1279
# Epoch 384, Training Loss: 1.2247, Validation Loss: 1.1278
# Epoch 385, Training Loss: 1.2246, Validation Loss: 1.1276
# Epoch 386, Training Loss: 1.2245, Validation Loss: 1.1274
# Epoch 387, Training Loss: 1.2244, Validation Loss: 1.1273
# Epoch 388, Training Loss: 1.2243, Validation Loss: 1.1271
# Epoch 389, Training Loss: 1.2242, Validation Loss: 1.1270
# Epoch 390, Training Loss: 1.2242, Validation Loss: 1.1268
# Epoch 391, Training Loss: 1.2241, Validation Loss: 1.1267
# Epoch 392, Training Loss: 1.2240, Validation Loss: 1.1265
# Epoch 393, Training Loss: 1.2239, Validation Loss: 1.1264
# Epoch 394, Training Loss: 1.2238, Validation Loss: 1.1262
# Epoch 395, Training Loss: 1.2238, Validation Loss: 1.1261
# Epoch 396, Training Loss: 1.2237, Validation Loss: 1.1259
# Epoch 397, Training Loss: 1.2236, Validation Loss: 1.1258
# Epoch 398, Training Loss: 1.2236, Validation Loss: 1.1257
# Epoch 399, Training Loss: 1.2235, Validation Loss: 1.1255
# Epoch 400, Training Loss: 1.2234, Validation Loss: 1.1254
# Epoch 401, Training Loss: 1.2234, Validation Loss: 1.1253
# Epoch 402, Training Loss: 1.2233, Validation Loss: 1.1251
# Epoch 403, Training Loss: 1.2232, Validation Loss: 1.1250
# Epoch 404, Training Loss: 1.2232, Validation Loss: 1.1249
# Epoch 405, Training Loss: 1.2231, Validation Loss: 1.1247
# Epoch 406, Training Loss: 1.2230, Validation Loss: 1.1246
# Epoch 407, Training Loss: 1.2230, Validation Loss: 1.1245
# Epoch 408, Training Loss: 1.2229, Validation Loss: 1.1244
# Epoch 409, Training Loss: 1.2229, Validation Loss: 1.1242
# Epoch 410, Training Loss: 1.2228, Validation Loss: 1.1241
# Epoch 411, Training Loss: 1.2227, Validation Loss: 1.1240
# Epoch 412, Training Loss: 1.2227, Validation Loss: 1.1239
# Epoch 413, Training Loss: 1.2226, Validation Loss: 1.1238
# Epoch 414, Training Loss: 1.2226, Validation Loss: 1.1237
# Epoch 415, Training Loss: 1.2225, Validation Loss: 1.1235
# Epoch 416, Training Loss: 1.2225, Validation Loss: 1.1234
# Epoch 417, Training Loss: 1.2224, Validation Loss: 1.1233
# Epoch 418, Training Loss: 1.2224, Validation Loss: 1.1232
# Epoch 419, Training Loss: 1.2223, Validation Loss: 1.1231
# Epoch 420, Training Loss: 1.2223, Validation Loss: 1.1230
# Epoch 421, Training Loss: 1.2222, Validation Loss: 1.1229
# Epoch 422, Training Loss: 1.2222, Validation Loss: 1.1228
# Epoch 423, Training Loss: 1.2221, Validation Loss: 1.1227
# Epoch 424, Training Loss: 1.2221, Validation Loss: 1.1226
# Epoch 425, Training Loss: 1.2221, Validation Loss: 1.1225
# Epoch 426, Training Loss: 1.2220, Validation Loss: 1.1224
# Epoch 427, Training Loss: 1.2220, Validation Loss: 1.1223
# Epoch 428, Training Loss: 1.2219, Validation Loss: 1.1222
# Epoch 429, Training Loss: 1.2219, Validation Loss: 1.1221
# Epoch 430, Training Loss: 1.2219, Validation Loss: 1.1220
# Epoch 431, Training Loss: 1.2218, Validation Loss: 1.1219
# Epoch 432, Training Loss: 1.2218, Validation Loss: 1.1218
# Epoch 433, Training Loss: 1.2217, Validation Loss: 1.1217
# Epoch 434, Training Loss: 1.2217, Validation Loss: 1.1217
# Epoch 435, Training Loss: 1.2217, Validation Loss: 1.1216
# Epoch 436, Training Loss: 1.2216, Validation Loss: 1.1215
# Epoch 437, Training Loss: 1.2216, Validation Loss: 1.1214
# Epoch 438, Training Loss: 1.2216, Validation Loss: 1.1213
# Epoch 439, Training Loss: 1.2215, Validation Loss: 1.1212
# Epoch 440, Training Loss: 1.2215, Validation Loss: 1.1211
# Epoch 441, Training Loss: 1.2215, Validation Loss: 1.1211
# Epoch 442, Training Loss: 1.2214, Validation Loss: 1.1210
# Epoch 443, Training Loss: 1.2214, Validation Loss: 1.1209
# Epoch 444, Training Loss: 1.2214, Validation Loss: 1.1208
# Epoch 445, Training Loss: 1.2213, Validation Loss: 1.1207
# Epoch 446, Training Loss: 1.2213, Validation Loss: 1.1207
# Epoch 447, Training Loss: 1.2213, Validation Loss: 1.1206
# Epoch 448, Training Loss: 1.2212, Validation Loss: 1.1205
# Epoch 449, Training Loss: 1.2212, Validation Loss: 1.1204
# Epoch 450, Training Loss: 1.2212, Validation Loss: 1.1204
# Epoch 451, Training Loss: 1.2212, Validation Loss: 1.1203
# Epoch 452, Training Loss: 1.2211, Validation Loss: 1.1202
# Epoch 453, Training Loss: 1.2211, Validation Loss: 1.1202
# Epoch 454, Training Loss: 1.2211, Validation Loss: 1.1201
# Epoch 455, Training Loss: 1.2211, Validation Loss: 1.1200
# Epoch 456, Training Loss: 1.2210, Validation Loss: 1.1199
# Epoch 457, Training Loss: 1.2210, Validation Loss: 1.1199
# Epoch 458, Training Loss: 1.2210, Validation Loss: 1.1198
# Epoch 459, Training Loss: 1.2210, Validation Loss: 1.1197
# Epoch 460, Training Loss: 1.2209, Validation Loss: 1.1197
# Epoch 461, Training Loss: 1.2209, Validation Loss: 1.1196
# Epoch 462, Training Loss: 1.2209, Validation Loss: 1.1196
# Epoch 463, Training Loss: 1.2209, Validation Loss: 1.1195
# Epoch 464, Training Loss: 1.2208, Validation Loss: 1.1194
# Epoch 465, Training Loss: 1.2208, Validation Loss: 1.1194
# Epoch 466, Training Loss: 1.2208, Validation Loss: 1.1193
# Epoch 467, Training Loss: 1.2208, Validation Loss: 1.1192
# Epoch 468, Training Loss: 1.2208, Validation Loss: 1.1192
# Epoch 469, Training Loss: 1.2207, Validation Loss: 1.1191
# Epoch 470, Training Loss: 1.2207, Validation Loss: 1.1191
# Epoch 471, Training Loss: 1.2207, Validation Loss: 1.1190
# Epoch 472, Training Loss: 1.2207, Validation Loss: 1.1190
# Epoch 473, Training Loss: 1.2207, Validation Loss: 1.1189
# Epoch 474, Training Loss: 1.2207, Validation Loss: 1.1188
# Epoch 475, Training Loss: 1.2206, Validation Loss: 1.1188
# Epoch 476, Training Loss: 1.2206, Validation Loss: 1.1187
# Epoch 477, Training Loss: 1.2206, Validation Loss: 1.1187
# Epoch 478, Training Loss: 1.2206, Validation Loss: 1.1186
# Epoch 479, Training Loss: 1.2206, Validation Loss: 1.1186
# Epoch 480, Training Loss: 1.2205, Validation Loss: 1.1185
# Epoch 481, Training Loss: 1.2205, Validation Loss: 1.1185
# Epoch 482, Training Loss: 1.2205, Validation Loss: 1.1184
# Epoch 483, Training Loss: 1.2205, Validation Loss: 1.1184
# Epoch 484, Training Loss: 1.2205, Validation Loss: 1.1183
# Epoch 485, Training Loss: 1.2205, Validation Loss: 1.1183
# Epoch 486, Training Loss: 1.2205, Validation Loss: 1.1182
# Epoch 487, Training Loss: 1.2204, Validation Loss: 1.1182
# Epoch 488, Training Loss: 1.2204, Validation Loss: 1.1181
# Epoch 489, Training Loss: 1.2204, Validation Loss: 1.1181
# Epoch 490, Training Loss: 1.2204, Validation Loss: 1.1181
# Epoch 491, Training Loss: 1.2204, Validation Loss: 1.1180
# Epoch 492, Training Loss: 1.2204, Validation Loss: 1.1180
# Epoch 493, Training Loss: 1.2204, Validation Loss: 1.1179
# Epoch 494, Training Loss: 1.2204, Validation Loss: 1.1179
# Epoch 495, Training Loss: 1.2203, Validation Loss: 1.1178
# Epoch 496, Training Loss: 1.2203, Validation Loss: 1.1178
# Epoch 497, Training Loss: 1.2203, Validation Loss: 1.1178
# Epoch 498, Training Loss: 1.2203, Validation Loss: 1.1177
# Epoch 499, Training Loss: 1.2203, Validation Loss: 1.1177
# Epoch 500, Training Loss: 1.2203, Validation Loss: 1.1176
# Epoch 501, Training Loss: 1.2203, Validation Loss: 1.1176
# Epoch 502, Training Loss: 1.2203, Validation Loss: 1.1176
# Epoch 503, Training Loss: 1.2203, Validation Loss: 1.1175
# Epoch 504, Training Loss: 1.2202, Validation Loss: 1.1175
# Epoch 505, Training Loss: 1.2202, Validation Loss: 1.1174
# Epoch 506, Training Loss: 1.2202, Validation Loss: 1.1174
# Epoch 507, Training Loss: 1.2202, Validation Loss: 1.1174
# Epoch 508, Training Loss: 1.2202, Validation Loss: 1.1173
# Epoch 509, Training Loss: 1.2202, Validation Loss: 1.1173
# Epoch 510, Training Loss: 1.2202, Validation Loss: 1.1173
# Epoch 511, Training Loss: 1.2202, Validation Loss: 1.1172
# Epoch 512, Training Loss: 1.2202, Validation Loss: 1.1172
# Epoch 513, Training Loss: 1.2202, Validation Loss: 1.1172
# Epoch 514, Training Loss: 1.2202, Validation Loss: 1.1171
# Epoch 515, Training Loss: 1.2201, Validation Loss: 1.1171
# Epoch 516, Training Loss: 1.2201, Validation Loss: 1.1171
# Epoch 517, Training Loss: 1.2201, Validation Loss: 1.1170
# Epoch 518, Training Loss: 1.2201, Validation Loss: 1.1170
# Epoch 519, Training Loss: 1.2201, Validation Loss: 1.1170
# Epoch 520, Training Loss: 1.2201, Validation Loss: 1.1169
# Epoch 521, Training Loss: 1.2201, Validation Loss: 1.1169
# Epoch 522, Training Loss: 1.2201, Validation Loss: 1.1169
# Epoch 523, Training Loss: 1.2201, Validation Loss: 1.1168
# Epoch 524, Training Loss: 1.2201, Validation Loss: 1.1168
# Epoch 525, Training Loss: 1.2201, Validation Loss: 1.1168
# Epoch 526, Training Loss: 1.2201, Validation Loss: 1.1167
# Epoch 527, Training Loss: 1.2201, Validation Loss: 1.1167
# Epoch 528, Training Loss: 1.2201, Validation Loss: 1.1167
# Epoch 529, Training Loss: 1.2201, Validation Loss: 1.1167
# Epoch 530, Training Loss: 1.2200, Validation Loss: 1.1166
# Epoch 531, Training Loss: 1.2200, Validation Loss: 1.1166
# Epoch 532, Training Loss: 1.2200, Validation Loss: 1.1166
# Epoch 533, Training Loss: 1.2200, Validation Loss: 1.1165
# Epoch 534, Training Loss: 1.2200, Validation Loss: 1.1165
# Epoch 535, Training Loss: 1.2200, Validation Loss: 1.1165
# Epoch 536, Training Loss: 1.2200, Validation Loss: 1.1165
# Epoch 537, Training Loss: 1.2200, Validation Loss: 1.1164
# Epoch 538, Training Loss: 1.2200, Validation Loss: 1.1164
# Epoch 539, Training Loss: 1.2200, Validation Loss: 1.1164
# Epoch 540, Training Loss: 1.2200, Validation Loss: 1.1164
# Epoch 541, Training Loss: 1.2200, Validation Loss: 1.1163
# Epoch 542, Training Loss: 1.2200, Validation Loss: 1.1163
# Epoch 543, Training Loss: 1.2200, Validation Loss: 1.1163
# Epoch 544, Training Loss: 1.2200, Validation Loss: 1.1163
# Epoch 545, Training Loss: 1.2200, Validation Loss: 1.1162
# Epoch 546, Training Loss: 1.2200, Validation Loss: 1.1162
# Epoch 547, Training Loss: 1.2200, Validation Loss: 1.1162
# Epoch 548, Training Loss: 1.2200, Validation Loss: 1.1162
# Epoch 549, Training Loss: 1.2200, Validation Loss: 1.1161
# Epoch 550, Training Loss: 1.2200, Validation Loss: 1.1161
# Epoch 551, Training Loss: 1.2199, Validation Loss: 1.1161
# Epoch 552, Training Loss: 1.2199, Validation Loss: 1.1161
# Epoch 553, Training Loss: 1.2199, Validation Loss: 1.1161
# Epoch 554, Training Loss: 1.2199, Validation Loss: 1.1160
# Epoch 555, Training Loss: 1.2199, Validation Loss: 1.1160
# Epoch 556, Training Loss: 1.2199, Validation Loss: 1.1160
# Epoch 557, Training Loss: 1.2199, Validation Loss: 1.1160
# Epoch 558, Training Loss: 1.2199, Validation Loss: 1.1160
# Epoch 559, Training Loss: 1.2199, Validation Loss: 1.1159
# Epoch 560, Training Loss: 1.2199, Validation Loss: 1.1159
# Epoch 561, Training Loss: 1.2199, Validation Loss: 1.1159
# Epoch 562, Training Loss: 1.2199, Validation Loss: 1.1159
# Epoch 563, Training Loss: 1.2199, Validation Loss: 1.1159
# Epoch 564, Training Loss: 1.2199, Validation Loss: 1.1158
# Epoch 565, Training Loss: 1.2199, Validation Loss: 1.1158
# Epoch 566, Training Loss: 1.2199, Validation Loss: 1.1158
# Epoch 567, Training Loss: 1.2199, Validation Loss: 1.1158
# Epoch 568, Training Loss: 1.2199, Validation Loss: 1.1158
# Epoch 569, Training Loss: 1.2199, Validation Loss: 1.1157
# Epoch 570, Training Loss: 1.2199, Validation Loss: 1.1157
# Epoch 571, Training Loss: 1.2199, Validation Loss: 1.1157
# Epoch 572, Training Loss: 1.2199, Validation Loss: 1.1157
# Epoch 573, Training Loss: 1.2199, Validation Loss: 1.1157
# Epoch 574, Training Loss: 1.2199, Validation Loss: 1.1157
# Epoch 575, Training Loss: 1.2199, Validation Loss: 1.1156
# Epoch 576, Training Loss: 1.2199, Validation Loss: 1.1156
# Epoch 577, Training Loss: 1.2199, Validation Loss: 1.1156
# Epoch 578, Training Loss: 1.2199, Validation Loss: 1.1156
# Epoch 579, Training Loss: 1.2199, Validation Loss: 1.1156
# Epoch 580, Training Loss: 1.2199, Validation Loss: 1.1156
# Epoch 581, Training Loss: 1.2199, Validation Loss: 1.1156
# Epoch 582, Training Loss: 1.2199, Validation Loss: 1.1155
# Epoch 583, Training Loss: 1.2199, Validation Loss: 1.1155
# Epoch 584, Training Loss: 1.2199, Validation Loss: 1.1155
# Epoch 585, Training Loss: 1.2199, Validation Loss: 1.1155
# Epoch 586, Training Loss: 1.2199, Validation Loss: 1.1155
# Epoch 587, Training Loss: 1.2199, Validation Loss: 1.1155
# Epoch 588, Training Loss: 1.2198, Validation Loss: 1.1154
# Epoch 589, Training Loss: 1.2198, Validation Loss: 1.1154
# Epoch 590, Training Loss: 1.2198, Validation Loss: 1.1154
# Epoch 591, Training Loss: 1.2198, Validation Loss: 1.1154
# Epoch 592, Training Loss: 1.2198, Validation Loss: 1.1154
# Epoch 593, Training Loss: 1.2198, Validation Loss: 1.1154
# Epoch 594, Training Loss: 1.2198, Validation Loss: 1.1154
# Epoch 595, Training Loss: 1.2198, Validation Loss: 1.1154
# Epoch 596, Training Loss: 1.2198, Validation Loss: 1.1153
# Epoch 597, Training Loss: 1.2198, Validation Loss: 1.1153
# Epoch 598, Training Loss: 1.2198, Validation Loss: 1.1153
# Epoch 599, Training Loss: 1.2198, Validation Loss: 1.1153
# Epoch 600, Training Loss: 1.2198, Validation Loss: 1.1153
# Epoch 601, Training Loss: 1.2198, Validation Loss: 1.1153
# Epoch 602, Training Loss: 1.2198, Validation Loss: 1.1153
# Epoch 603, Training Loss: 1.2198, Validation Loss: 1.1153
# Epoch 604, Training Loss: 1.2198, Validation Loss: 1.1152
# Epoch 605, Training Loss: 1.2198, Validation Loss: 1.1152
# Epoch 606, Training Loss: 1.2198, Validation Loss: 1.1152
# Epoch 607, Training Loss: 1.2198, Validation Loss: 1.1152
# Epoch 608, Training Loss: 1.2198, Validation Loss: 1.1152
# Epoch 609, Training Loss: 1.2198, Validation Loss: 1.1152
# Epoch 610, Training Loss: 1.2198, Validation Loss: 1.1152
# Epoch 611, Training Loss: 1.2198, Validation Loss: 1.1152
# Epoch 612, Training Loss: 1.2198, Validation Loss: 1.1152
# Epoch 613, Training Loss: 1.2198, Validation Loss: 1.1151
# Epoch 614, Training Loss: 1.2198, Validation Loss: 1.1151
# Epoch 615, Training Loss: 1.2198, Validation Loss: 1.1151
# Epoch 616, Training Loss: 1.2198, Validation Loss: 1.1151
# Epoch 617, Training Loss: 1.2198, Validation Loss: 1.1151
# Epoch 618, Training Loss: 1.2198, Validation Loss: 1.1151
# Epoch 619, Training Loss: 1.2198, Validation Loss: 1.1151
# Epoch 620, Training Loss: 1.2198, Validation Loss: 1.1151
# Epoch 621, Training Loss: 1.2198, Validation Loss: 1.1151
# Epoch 622, Training Loss: 1.2198, Validation Loss: 1.1151
# Epoch 623, Training Loss: 1.2198, Validation Loss: 1.1150
# Epoch 624, Training Loss: 1.2198, Validation Loss: 1.1150
# Epoch 625, Training Loss: 1.2198, Validation Loss: 1.1150
# Epoch 626, Training Loss: 1.2198, Validation Loss: 1.1150
# Epoch 627, Training Loss: 1.2198, Validation Loss: 1.1150
# Epoch 628, Training Loss: 1.2198, Validation Loss: 1.1150
# Epoch 629, Training Loss: 1.2198, Validation Loss: 1.1150
# Epoch 630, Training Loss: 1.2198, Validation Loss: 1.1150
# Epoch 631, Training Loss: 1.2198, Validation Loss: 1.1150
# Epoch 632, Training Loss: 1.2198, Validation Loss: 1.1150
# Epoch 633, Training Loss: 1.2198, Validation Loss: 1.1150
# Epoch 634, Training Loss: 1.2198, Validation Loss: 1.1149
# Epoch 635, Training Loss: 1.2198, Validation Loss: 1.1149
# Epoch 636, Training Loss: 1.2198, Validation Loss: 1.1149
# Epoch 637, Training Loss: 1.2198, Validation Loss: 1.1149
# Epoch 638, Training Loss: 1.2198, Validation Loss: 1.1149
# Epoch 639, Training Loss: 1.2198, Validation Loss: 1.1149
# Epoch 640, Training Loss: 1.2198, Validation Loss: 1.1149
# Epoch 641, Training Loss: 1.2198, Validation Loss: 1.1149
# Epoch 642, Training Loss: 1.2198, Validation Loss: 1.1149
# Epoch 643, Training Loss: 1.2198, Validation Loss: 1.1149
# Epoch 644, Training Loss: 1.2198, Validation Loss: 1.1149
# Epoch 645, Training Loss: 1.2198, Validation Loss: 1.1149
# Epoch 646, Training Loss: 1.2198, Validation Loss: 1.1149
# Epoch 647, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 648, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 649, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 650, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 651, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 652, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 653, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 654, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 655, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 656, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 657, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 658, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 659, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 660, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 661, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 662, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 663, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 664, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 665, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 666, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 667, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 668, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 669, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 670, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 671, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 672, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 673, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 674, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 675, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 676, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 677, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 678, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 679, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 680, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 681, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 682, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 683, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 684, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 685, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 686, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 687, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 688, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 689, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 690, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 691, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 692, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 693, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 694, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 695, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 696, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 697, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 698, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 699, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 700, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 701, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 702, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 703, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 704, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 705, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 706, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 707, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 708, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 709, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 710, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 711, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 712, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 713, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 714, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 715, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 716, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 717, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 718, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 719, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 720, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 721, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 722, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 723, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 724, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 725, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 726, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 727, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 728, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 729, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 730, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 731, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 732, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 733, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 734, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 735, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 736, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 737, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 738, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 739, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 740, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 741, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 742, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 743, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 744, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 745, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 746, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 747, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 748, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 749, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 750, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 751, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 752, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 753, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 754, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 755, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 756, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 757, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 758, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 759, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 760, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 761, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 762, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 763, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 764, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 765, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 766, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 767, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 768, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 769, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 770, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 771, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 772, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 773, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 774, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 775, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 776, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 777, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 778, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 779, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 780, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 781, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 782, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 783, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 784, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 785, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 786, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 787, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 788, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 789, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 790, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 791, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 792, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 793, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 794, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 795, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 796, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 797, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 798, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 799, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 800, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 801, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 802, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 803, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 804, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 805, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 806, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 807, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 808, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 809, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 810, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 811, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 812, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 813, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 814, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 815, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 816, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 817, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 818, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 819, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 820, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 821, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 822, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 823, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 824, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 825, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 826, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 827, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 828, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 829, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 830, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 831, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 832, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 833, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 834, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 835, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 836, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 837, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 838, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 839, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 840, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 841, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 842, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 843, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 844, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 845, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 846, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 847, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 848, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 849, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 850, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 851, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 852, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 853, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 854, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 855, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 856, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 857, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 858, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 859, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 860, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 861, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 862, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 863, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 864, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 865, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 866, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 867, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 868, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 869, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 870, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 871, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 872, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 873, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 874, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 875, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 876, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 877, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 878, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 879, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 880, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 881, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 882, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 883, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 884, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 885, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 886, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 887, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 888, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 889, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 890, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 891, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 892, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 893, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 894, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 895, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 896, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 897, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 898, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 899, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 900, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 901, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 902, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 903, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 904, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 905, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 906, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 907, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 908, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 909, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 910, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 911, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 912, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 913, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 914, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 915, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 916, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 917, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 918, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 919, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 920, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 921, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 922, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 923, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 924, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 925, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 926, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 927, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 928, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 929, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 930, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 931, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 932, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 933, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 934, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 935, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 936, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 937, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 938, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 939, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 940, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 941, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 942, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 943, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 944, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 945, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 946, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 947, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 948, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 949, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 950, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 951, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 952, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 953, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 954, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 955, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 956, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 957, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 958, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 959, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 960, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 961, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 962, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 963, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 964, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 965, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 966, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 967, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 968, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 969, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 970, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 971, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 972, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 973, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 974, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 975, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 976, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 977, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 978, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 979, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 980, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 981, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 982, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 983, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 984, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 985, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 986, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 987, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 988, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 989, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 990, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 991, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 992, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 993, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 994, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 995, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 996, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 997, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 998, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 999, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1000, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1001, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1002, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1003, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1004, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1005, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1006, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1007, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1008, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1009, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1010, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1011, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1012, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1013, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1014, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1015, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1016, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1017, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1018, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1019, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1020, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1021, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1022, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1023, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1024, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1025, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1026, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1027, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1028, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1029, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1030, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1031, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1032, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1033, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1034, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1035, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1036, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1037, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1038, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1039, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1040, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1041, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1042, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1043, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1044, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1045, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1046, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1047, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1048, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1049, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1050, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1051, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1052, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1053, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1054, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1055, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1056, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1057, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1058, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1059, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1060, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1061, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1062, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1063, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1064, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1065, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1066, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1067, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1068, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1069, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1070, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1071, Training Loss: 1.2198, Validation Loss: 1.1143
# Early stopping triggered

# %%
# All-control and all-treated for test set
num_product = X_product.shape[0]

# All control: product_randomization = 0
all_product_control = torch.zeros(num_product, device=device).bool()

# All treated: product_randomization = 1
all_product_treated = torch.ones(num_product, device=device).bool()

# Move base price and test users/products to device
X_user_test = X_user_test.to(device)
X_product = X_product.to(device)
price = price.to(device)

# --------- Expected revenue: all control ----------
# Control prices = base prices (no discount)
price_control = price.clone()

# Prepare test data under all-control prices
user_test_ctrl, product_test_ctrl, prices_ctrl, x_other_products_ctrl, other_prices_ctrl = prepare_data(
    X_user_test,
    X_product,
    price_control
)

utilities_ctrl = model(
    user_test_ctrl,
    product_test_ctrl,
    x_other_products_ctrl,
    other_prices_ctrl,
    prices_ctrl,          # control prices
    all_product_control   # all False
)

probabilities_ctrl = F.softmax(utilities_ctrl, dim=1)

price_with_outside_ctrl = torch.cat(
    (torch.zeros(1, device=price.device), prices_ctrl), dim=0
)  # [M+1]

expected_revenue_ctrl = torch.sum(
    probabilities_ctrl * price_with_outside_ctrl.unsqueeze(0).expand_as(probabilities_ctrl),
    dim=1
).sum()

print(f"Expected Revenue (all control): ${expected_revenue_ctrl.item():.2f}")

# --------- Expected revenue: all treated ----------
# Treated prices = discounted prices
price_treated = price * discount_percentage

user_test_trt, product_test_trt, prices_trt, x_other_products_trt, other_prices_trt = prepare_data(
    X_user_test,
    X_product,
    price_treated
)

utilities_trt = model(
    user_test_trt,
    product_test_trt,
    x_other_products_trt,
    other_prices_trt,
    prices_trt,          # treated prices
    all_product_treated  # all True
)

probabilities_trt = F.softmax(utilities_trt, dim=1)

price_with_outside_trt = torch.cat(
    (torch.zeros(1, device=price.device), prices_trt), dim=0
)

expected_revenue_trt = torch.sum(
    probabilities_trt * price_with_outside_trt.unsqueeze(0).expand_as(probabilities_trt),
    dim=1
).sum()

print(f"Expected Revenue (all treated): ${expected_revenue_trt.item():.2f}")

# --------- GTE ----------
pdl = (expected_revenue_trt - expected_revenue_ctrl).cpu().detach().numpy() * 600 / 266
print(pdl)

pdl_no = abs((pdl - true) / true)
print(pdl_no)
# Out:
# Expected Revenue (all control): $41.17
# Expected Revenue (all treated): $8.23
# -74.286465178755
# 0.08202274490119944

# %%
def expected_revenue_for_users(Xu, X_product, price, treat_mask, discount_percentage=1.0):
    """
    For PDL model (DeepMNLModel_No): uses prepare_data and 6-argument forward
    Xu: [N_g, d_user]
    X_product: [M, d_prod]
    price: [M]
    treat_mask: [M] bool, indicates treated products
    discount_percentage: scalar, discount factor for treated products
    """
    # Apply discount to prices based on treatment mask
    adjusted_price = torch.where(
        treat_mask,
        price * discount_percentage,
        price
    )
    
    # Prepare data using prepare_data function (required for PDL model)
    user_features, product_features, prices_prep, all_x_other_products, all_other_prices = prepare_data(
        Xu, X_product, adjusted_price
    )
    
    # Call PDL model with all 6 required arguments
    utilities = model(
        user_features,
        product_features,
        all_x_other_products,
        all_other_prices,
        prices_prep,
        treat_mask
    )  # [N_g, M+1]
    
    probs = F.softmax(utilities, dim=1)  # [N_g, M+1]
    price_with_outside = torch.cat((torch.zeros(1, device=price.device), adjusted_price), dim=0)  # [M+1]
    rev_total = (probs * price_with_outside.unsqueeze(0)).sum()  # sum over i,j
    return rev_total

# %%
# --- split test set by gender (column 1: 1=female, 2=male) ---
male_mask = (X_user_test[:, 1] == 2)
female_mask = (X_user_test[:, 1] == 1)

X_male = X_user_test[male_mask]
X_female = X_user_test[female_mask]

print(f"N_male={X_male.shape[0]}, N_female={X_female.shape[0]}, N_total={X_user_test.shape[0]}")

# --- male/female revenues and GTEs ---
rev_control_male = expected_revenue_for_users(X_male, X_product, price, all_product_control, 1.0)
rev_treated_male  = expected_revenue_for_users(X_male, X_product, price, all_product_treated, discount_percentage)
gte_male = rev_treated_male - rev_control_male

rev_control_female = expected_revenue_for_users(X_female, X_product, price, all_product_control, 1.0)
rev_treated_female  = expected_revenue_for_users(X_female, X_product, price, all_product_treated, discount_percentage)
gte_female = rev_treated_female - rev_control_female

# --- compare to overall ---
gte_male_scaled = (gte_male * 300/38).detach().cpu().numpy()
gte_female_scaled = (gte_female * 300/37).detach().cpu().numpy()

pdl_no_m = abs((gte_male_scaled - true_male)/true_male)
pdl_no_f = abs((gte_female_scaled - true_female)/true_female)

print(pdl_no_m)
print(pdl_no_f)
# Out:
# N_male=38, N_female=37, N_total=133
# 0.07939024185618875
# 0.2908637058479696

# %%
# split test set by phone usage
phone_less_than_2_years_mask = (X_user_test[:, 2] == 1) | (X_user_test[:, 2] == 5)
phone_more_than_2_years_mask = (X_user_test[:, 2] == 2) | (X_user_test[:, 2] == 3) | (X_user_test[:, 2] == 6)

X_phone_less_than_2_years = X_user_test[phone_less_than_2_years_mask]
X_phone_more_than_2_years = X_user_test[phone_more_than_2_years_mask]

print(f"N_phone_less_than_2_years={X_phone_less_than_2_years.shape[0]}, N_phone_more_than_2_years={X_phone_more_than_2_years.shape[0]}, N_total={X_user_test.shape[0]}")

# --- phone usage revenues and GTEs ---
rev_control_phone_less_than_2_years = expected_revenue_for_users(X_phone_less_than_2_years, X_product, price, all_product_control, 1.0)
rev_treated_phone_less_than_2_years  = expected_revenue_for_users(X_phone_less_than_2_years, X_product, price, all_product_treated, discount_percentage)
gte_phone_less_than_2_years = rev_treated_phone_less_than_2_years - rev_control_phone_less_than_2_years

rev_control_phone_more_than_2_years = expected_revenue_for_users(X_phone_more_than_2_years, X_product, price, all_product_control, 1.0)
rev_treated_phone_more_than_2_years  = expected_revenue_for_users(X_phone_more_than_2_years, X_product, price, all_product_treated, discount_percentage)
gte_phone_more_than_2_years = rev_treated_phone_more_than_2_years - rev_control_phone_more_than_2_years

gte_phone_less_than_2_years_scaled = (gte_phone_less_than_2_years * 300/7).detach().cpu().numpy()
gte_phone_more_than_2_years_scaled = (gte_phone_more_than_2_years * 300/50).detach().cpu().numpy()

pdl_no_phone_less_than_2_years = abs((gte_phone_less_than_2_years_scaled - true_phone_less_than_2_years)/true_phone_less_than_2_years)
pdl_no_phone_more_than_2_years = abs((gte_phone_more_than_2_years_scaled - true_phone_more_than_2_years)/true_phone_more_than_2_years)

print(pdl_no_phone_less_than_2_years)
print(pdl_no_phone_more_than_2_years)
# Out:
# N_phone_less_than_2_years=7, N_phone_more_than_2_years=50, N_total=133
# 0.20282492564320756
# 0.5284590151542671

# %% [markdown]
# ### Only user features

# %%
class DeepMNLModel_UserOnly(nn.Module):
    """
    Deep MNL (user + own price only):
    u_ij = theta(x_i, p_j)
    Outside option utility = 0.
    """
    def __init__(self, user_dim, num_product, hidden=5):
        super(DeepMNLModel_UserOnly, self).__init__()

        # theta(x_i, p_j)
        # Input per (i,j): [user_dim + 1]
        self.theta = nn.Sequential(
            nn.Linear(user_dim + 1, hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, x_user, X_product, X_other_products,
                x_other_prices, price, prod_randomization):

        device = price.device
        N, M = x_user.shape[0], price.shape[0]

        # p_j: [M, 1]
        pj_feat = price.unsqueeze(1)          # [M, 1]

        pj_feat_exp = pj_feat.unsqueeze(0).expand(N, -1, -1)

        x_user_exp = x_user.unsqueeze(1).expand(-1, M, -1)

        theta_input = torch.cat([x_user_exp, pj_feat_exp], dim=2)

        theta_input_flat = theta_input.reshape(N * M, -1)

        # u_ij: [N*M, 1] -> [N, M]
        utilities = self.theta(theta_input_flat).view(N, M)

        # outside option utility = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utilities], dim=1)

        return utilities_with_outside

# %%
# Apply the model
model = DeepMNLModel_UserOnly(
    user_dim=X_user.shape[1],
    num_product=X_product.shape[0],
    hidden=5
).to(device)

model.apply(init_weights)
# Out:
# DeepMNLModel_UserOnly(
#   (theta): Sequential(
#     (0): Linear(in_features=4, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# ----- Prepare validation data -----
prepared_val = prepare_data(
    X_user_val,
    X_product,
    price * (1 - (1 - discount_percentage) * prod_randomization)
)
user_features_val, product_features_val, price_val, all_x_other_products_val, all_other_prices_val = prepared_val

user_features_val = user_features_val.to(device)
product_features_val = product_features_val.to(device)
all_x_other_products_val = all_x_other_products_val.to(device)
all_other_prices_val = all_other_prices_val.to(device)
choice_val = choice_val.to(device)

# ----- Optimizer and scheduler -----
optimizer = optim.Adam(model.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)
l2_lambda = 0  # L2 regularization coefficient

# Early stopping setup
best_val_loss = float('inf')
patience = 20
patience_counter = 0

# ----- Training loop -----
for epoch in range(5000):
    model.train()
    optimizer.zero_grad()

    # Forward pass (train): use prepared prices and other-prices matrix
    outputs = model(
        user_features,         # x_user (not used inside DeepMNLModel_No, but kept for interface)
        product_features,      # X_product (not used)
        all_x_other_products,  # X_other_products (not used in No model)
        all_other_prices,      # x_other_prices: p_-j
        prices,                # price: experimental p_j (after discount)
        prod_randomization     # can be ignored inside No model
    )
    choice_probabilities = F.log_softmax(outputs, dim=1)

    # Training loss
    loss = -torch.mean(
        choice_probabilities[
            torch.arange(choice_probabilities.shape[0], device=device),
            choice_train1
        ]
    )

    # L2 regularization
    l2_norm = sum(param.pow(2.0).sum() for param in model.parameters())
    loss = loss + l2_lambda * l2_norm

    # Backward
    loss.backward()
    optimizer.step()

    # ----- Validation -----
    model.eval()
    with torch.no_grad():
        val_outputs = model(
            user_features_val,
            product_features_val,
            all_x_other_products_val,
            all_other_prices_val,
            price_val,              # same product prices for validation
            prod_randomization
        )
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(
            val_choice_probabilities[
                torch.arange(val_choice_probabilities.shape[0], device=device),
                choice_val
            ]
        )

    print(
        f"Epoch {epoch+1}, "
        f"Training Loss: {loss.item():.4f}, "
        f"Validation Loss: {val_loss.item():.4f}"
    )

    # Early stopping logic
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        # torch.save(pdlmodel.state_dict(), 'best_model.pth')
    else:
        patience_counter += 1

    if patience_counter >= patience:
        print("Early stopping triggered")
        break

    scheduler.step()
# Out:
# Epoch 1, Training Loss: 1.4654, Validation Loss: 1.3363
# Epoch 2, Training Loss: 1.4157, Validation Loss: 1.2891
# Epoch 3, Training Loss: 1.3717, Validation Loss: 1.2514
# Epoch 4, Training Loss: 1.3349, Validation Loss: 1.2235
# Epoch 5, Training Loss: 1.3051, Validation Loss: 1.2049
# Epoch 6, Training Loss: 1.2820, Validation Loss: 1.1954
# Epoch 7, Training Loss: 1.2651, Validation Loss: 1.1936
# Epoch 8, Training Loss: 1.2542, Validation Loss: 1.1966
# Epoch 9, Training Loss: 1.2484, Validation Loss: 1.2031
# Epoch 10, Training Loss: 1.2464, Validation Loss: 1.2103
# Epoch 11, Training Loss: 1.2468, Validation Loss: 1.2160
# Epoch 12, Training Loss: 1.2483, Validation Loss: 1.2192
# Epoch 13, Training Loss: 1.2498, Validation Loss: 1.2192
# Epoch 14, Training Loss: 1.2505, Validation Loss: 1.2158
# Epoch 15, Training Loss: 1.2501, Validation Loss: 1.2101
# Epoch 16, Training Loss: 1.2481, Validation Loss: 1.2018
# Epoch 17, Training Loss: 1.2448, Validation Loss: 1.1916
# Epoch 18, Training Loss: 1.2406, Validation Loss: 1.1801
# Epoch 19, Training Loss: 1.2359, Validation Loss: 1.1698
# Epoch 20, Training Loss: 1.2312, Validation Loss: 1.1607
# Epoch 21, Training Loss: 1.2267, Validation Loss: 1.1521
# Epoch 22, Training Loss: 1.2224, Validation Loss: 1.1444
# Epoch 23, Training Loss: 1.2186, Validation Loss: 1.1376
# Epoch 24, Training Loss: 1.2158, Validation Loss: 1.1323
# Epoch 25, Training Loss: 1.2140, Validation Loss: 1.1285
# Epoch 26, Training Loss: 1.2130, Validation Loss: 1.1259
# Epoch 27, Training Loss: 1.2128, Validation Loss: 1.1243
# Epoch 28, Training Loss: 1.2131, Validation Loss: 1.1232
# Epoch 29, Training Loss: 1.2136, Validation Loss: 1.1223
# Epoch 30, Training Loss: 1.2141, Validation Loss: 1.1216
# Epoch 31, Training Loss: 1.2145, Validation Loss: 1.1208
# Epoch 32, Training Loss: 1.2145, Validation Loss: 1.1197
# Epoch 33, Training Loss: 1.2142, Validation Loss: 1.1183
# Epoch 34, Training Loss: 1.2136, Validation Loss: 1.1168
# Epoch 35, Training Loss: 1.2128, Validation Loss: 1.1152
# Epoch 36, Training Loss: 1.2119, Validation Loss: 1.1138
# Epoch 37, Training Loss: 1.2110, Validation Loss: 1.1125
# Epoch 38, Training Loss: 1.2103, Validation Loss: 1.1115
# Epoch 39, Training Loss: 1.2098, Validation Loss: 1.1108
# Epoch 40, Training Loss: 1.2094, Validation Loss: 1.1103
# Epoch 41, Training Loss: 1.2092, Validation Loss: 1.1099
# Epoch 42, Training Loss: 1.2091, Validation Loss: 1.1093
# Epoch 43, Training Loss: 1.2090, Validation Loss: 1.1087
# Epoch 44, Training Loss: 1.2088, Validation Loss: 1.1079
# Epoch 45, Training Loss: 1.2084, Validation Loss: 1.1070
# Epoch 46, Training Loss: 1.2080, Validation Loss: 1.1060
# Epoch 47, Training Loss: 1.2076, Validation Loss: 1.1049
# Epoch 48, Training Loss: 1.2071, Validation Loss: 1.1036
# Epoch 49, Training Loss: 1.2065, Validation Loss: 1.1023
# Epoch 50, Training Loss: 1.2059, Validation Loss: 1.1011
# Epoch 51, Training Loss: 1.2056, Validation Loss: 1.1000
# Epoch 52, Training Loss: 1.2053, Validation Loss: 1.0989
# Epoch 53, Training Loss: 1.2050, Validation Loss: 1.0978
# Epoch 54, Training Loss: 1.2047, Validation Loss: 1.0968
# Epoch 55, Training Loss: 1.2045, Validation Loss: 1.0967
# Epoch 56, Training Loss: 1.2043, Validation Loss: 1.0966
# Epoch 57, Training Loss: 1.2041, Validation Loss: 1.0963
# Epoch 58, Training Loss: 1.2039, Validation Loss: 1.0961
# Epoch 59, Training Loss: 1.2037, Validation Loss: 1.0958
# Epoch 60, Training Loss: 1.2034, Validation Loss: 1.0954
# Epoch 61, Training Loss: 1.2031, Validation Loss: 1.0950
# Epoch 62, Training Loss: 1.2028, Validation Loss: 1.0946
# Epoch 63, Training Loss: 1.2025, Validation Loss: 1.0941
# Epoch 64, Training Loss: 1.2022, Validation Loss: 1.0936
# Epoch 65, Training Loss: 1.2020, Validation Loss: 1.0930
# Epoch 66, Training Loss: 1.2017, Validation Loss: 1.0923
# Epoch 67, Training Loss: 1.2015, Validation Loss: 1.0915
# Epoch 68, Training Loss: 1.2013, Validation Loss: 1.0906
# Epoch 69, Training Loss: 1.2010, Validation Loss: 1.0896
# Epoch 70, Training Loss: 1.2008, Validation Loss: 1.0885
# Epoch 71, Training Loss: 1.2005, Validation Loss: 1.0873
# Epoch 72, Training Loss: 1.2002, Validation Loss: 1.0860
# Epoch 73, Training Loss: 1.2000, Validation Loss: 1.0847
# Epoch 74, Training Loss: 1.1997, Validation Loss: 1.0833
# Epoch 75, Training Loss: 1.1994, Validation Loss: 1.0820
# Epoch 76, Training Loss: 1.1991, Validation Loss: 1.0804
# Epoch 77, Training Loss: 1.1989, Validation Loss: 1.0789
# Epoch 78, Training Loss: 1.1987, Validation Loss: 1.0776
# Epoch 79, Training Loss: 1.1984, Validation Loss: 1.0764
# Epoch 80, Training Loss: 1.1982, Validation Loss: 1.0753
# Epoch 81, Training Loss: 1.1980, Validation Loss: 1.0744
# Epoch 82, Training Loss: 1.1977, Validation Loss: 1.0735
# Epoch 83, Training Loss: 1.1975, Validation Loss: 1.0728
# Epoch 84, Training Loss: 1.1972, Validation Loss: 1.0723
# Epoch 85, Training Loss: 1.1970, Validation Loss: 1.0720
# Epoch 86, Training Loss: 1.1967, Validation Loss: 1.0718
# Epoch 87, Training Loss: 1.1965, Validation Loss: 1.0717
# Epoch 88, Training Loss: 1.1962, Validation Loss: 1.0712
# Epoch 89, Training Loss: 1.1961, Validation Loss: 1.0707
# Epoch 90, Training Loss: 1.1959, Validation Loss: 1.0700
# Epoch 91, Training Loss: 1.1957, Validation Loss: 1.0692
# Epoch 92, Training Loss: 1.1955, Validation Loss: 1.0682
# Epoch 93, Training Loss: 1.1953, Validation Loss: 1.0671
# Epoch 94, Training Loss: 1.1951, Validation Loss: 1.0659
# Epoch 95, Training Loss: 1.1948, Validation Loss: 1.0647
# Epoch 96, Training Loss: 1.1946, Validation Loss: 1.0634
# Epoch 97, Training Loss: 1.1944, Validation Loss: 1.0623
# Epoch 98, Training Loss: 1.1942, Validation Loss: 1.0615
# Epoch 99, Training Loss: 1.1940, Validation Loss: 1.0609
# Epoch 100, Training Loss: 1.1938, Validation Loss: 1.0603
# Epoch 101, Training Loss: 1.1936, Validation Loss: 1.0597
# Epoch 102, Training Loss: 1.1934, Validation Loss: 1.0592
# Epoch 103, Training Loss: 1.1932, Validation Loss: 1.0588
# Epoch 104, Training Loss: 1.1930, Validation Loss: 1.0584
# Epoch 105, Training Loss: 1.1928, Validation Loss: 1.0578
# Epoch 106, Training Loss: 1.1926, Validation Loss: 1.0570
# Epoch 107, Training Loss: 1.1924, Validation Loss: 1.0563
# Epoch 108, Training Loss: 1.1922, Validation Loss: 1.0555
# Epoch 109, Training Loss: 1.1920, Validation Loss: 1.0546
# Epoch 110, Training Loss: 1.1918, Validation Loss: 1.0539
# Epoch 111, Training Loss: 1.1917, Validation Loss: 1.0532
# Epoch 112, Training Loss: 1.1915, Validation Loss: 1.0528
# Epoch 113, Training Loss: 1.1913, Validation Loss: 1.0525
# Epoch 114, Training Loss: 1.1911, Validation Loss: 1.0523
# Epoch 115, Training Loss: 1.1909, Validation Loss: 1.0520
# Epoch 116, Training Loss: 1.1908, Validation Loss: 1.0516
# Epoch 117, Training Loss: 1.1906, Validation Loss: 1.0511
# Epoch 118, Training Loss: 1.1904, Validation Loss: 1.0506
# Epoch 119, Training Loss: 1.1902, Validation Loss: 1.0500
# Epoch 120, Training Loss: 1.1901, Validation Loss: 1.0494
# Epoch 121, Training Loss: 1.1899, Validation Loss: 1.0489
# Epoch 122, Training Loss: 1.1897, Validation Loss: 1.0484
# Epoch 123, Training Loss: 1.1896, Validation Loss: 1.0480
# Epoch 124, Training Loss: 1.1894, Validation Loss: 1.0476
# Epoch 125, Training Loss: 1.1893, Validation Loss: 1.0472
# Epoch 126, Training Loss: 1.1891, Validation Loss: 1.0468
# Epoch 127, Training Loss: 1.1889, Validation Loss: 1.0465
# Epoch 128, Training Loss: 1.1888, Validation Loss: 1.0461
# Epoch 129, Training Loss: 1.1887, Validation Loss: 1.0456
# Epoch 130, Training Loss: 1.1885, Validation Loss: 1.0450
# Epoch 131, Training Loss: 1.1884, Validation Loss: 1.0444
# Epoch 132, Training Loss: 1.1882, Validation Loss: 1.0438
# Epoch 133, Training Loss: 1.1881, Validation Loss: 1.0437
# Epoch 134, Training Loss: 1.1880, Validation Loss: 1.0436
# Epoch 135, Training Loss: 1.1879, Validation Loss: 1.0435
# Epoch 136, Training Loss: 1.1878, Validation Loss: 1.0432
# Epoch 137, Training Loss: 1.1876, Validation Loss: 1.0428
# Epoch 138, Training Loss: 1.1875, Validation Loss: 1.0424
# Epoch 139, Training Loss: 1.1874, Validation Loss: 1.0424
# Epoch 140, Training Loss: 1.1872, Validation Loss: 1.0425
# Epoch 141, Training Loss: 1.1871, Validation Loss: 1.0424
# Epoch 142, Training Loss: 1.1870, Validation Loss: 1.0423
# Epoch 143, Training Loss: 1.1869, Validation Loss: 1.0419
# Epoch 144, Training Loss: 1.1868, Validation Loss: 1.0417
# Epoch 145, Training Loss: 1.1866, Validation Loss: 1.0416
# Epoch 146, Training Loss: 1.1865, Validation Loss: 1.0415
# Epoch 147, Training Loss: 1.1864, Validation Loss: 1.0418
# Epoch 148, Training Loss: 1.1863, Validation Loss: 1.0420
# Epoch 149, Training Loss: 1.1862, Validation Loss: 1.0422
# Epoch 150, Training Loss: 1.1861, Validation Loss: 1.0425
# Epoch 151, Training Loss: 1.1860, Validation Loss: 1.0427
# Epoch 152, Training Loss: 1.1858, Validation Loss: 1.0427
# Epoch 153, Training Loss: 1.1857, Validation Loss: 1.0432
# Epoch 154, Training Loss: 1.1856, Validation Loss: 1.0440
# Epoch 155, Training Loss: 1.1855, Validation Loss: 1.0446
# Epoch 156, Training Loss: 1.1854, Validation Loss: 1.0450
# Epoch 157, Training Loss: 1.1853, Validation Loss: 1.0454
# Epoch 158, Training Loss: 1.1852, Validation Loss: 1.0454
# Epoch 159, Training Loss: 1.1851, Validation Loss: 1.0454
# Epoch 160, Training Loss: 1.1850, Validation Loss: 1.0453
# Epoch 161, Training Loss: 1.1849, Validation Loss: 1.0462
# Epoch 162, Training Loss: 1.1848, Validation Loss: 1.0469
# Epoch 163, Training Loss: 1.1847, Validation Loss: 1.0477
# Epoch 164, Training Loss: 1.1846, Validation Loss: 1.0482
# Epoch 165, Training Loss: 1.1845, Validation Loss: 1.0484
# Epoch 166, Training Loss: 1.1844, Validation Loss: 1.0484
# Early stopping triggered

# %%
# All-control and all-treated for test set
num_product = X_product.shape[0]

# All control: product_randomization = 0
all_product_control = torch.zeros(num_product, device=device).bool()

# All treated: product_randomization = 1
all_product_treated = torch.ones(num_product, device=device).bool()

# Move base price and test users/products to device
X_user_test = X_user_test.to(device)
X_product = X_product.to(device)
price = price.to(device)

# --------- Expected revenue: all control ----------
# Control prices = base prices (no discount)
price_control = price.clone()

# Prepare test data under all-control prices
user_test_ctrl, product_test_ctrl, prices_ctrl, x_other_products_ctrl, other_prices_ctrl = prepare_data(
    X_user_test,
    X_product,
    price_control
)

utilities_ctrl = model(
    user_test_ctrl,
    product_test_ctrl,
    x_other_products_ctrl,
    other_prices_ctrl,
    prices_ctrl,          # control prices
    all_product_control   # all False
)

probabilities_ctrl = F.softmax(utilities_ctrl, dim=1)

price_with_outside_ctrl = torch.cat(
    (torch.zeros(1, device=price.device), prices_ctrl), dim=0
)  # [M+1]

expected_revenue_ctrl = torch.sum(
    probabilities_ctrl * price_with_outside_ctrl.unsqueeze(0).expand_as(probabilities_ctrl),
    dim=1
).sum()

print(f"Expected Revenue (all control): ${expected_revenue_ctrl.item():.2f}")

# --------- Expected revenue: all treated ----------
# Treated prices = discounted prices
price_treated = price * discount_percentage

user_test_trt, product_test_trt, prices_trt, x_other_products_trt, other_prices_trt = prepare_data(
    X_user_test,
    X_product,
    price_treated
)

utilities_trt = model(
    user_test_trt,
    product_test_trt,
    x_other_products_trt,
    other_prices_trt,
    prices_trt,          # treated prices
    all_product_treated  # all True
)

probabilities_trt = F.softmax(utilities_trt, dim=1)

price_with_outside_trt = torch.cat(
    (torch.zeros(1, device=price.device), prices_trt), dim=0
)

expected_revenue_trt = torch.sum(
    probabilities_trt * price_with_outside_trt.unsqueeze(0).expand_as(probabilities_trt),
    dim=1
).sum()

print(f"Expected Revenue (all treated): ${expected_revenue_trt.item():.2f}")

# --------- GTE ----------
pdl = (expected_revenue_trt - expected_revenue_ctrl).cpu().detach().numpy() * 600 / 266
print(pdl)

pdl_user = abs((pdl - true) / true)
print(pdl_user)
# Out:
# Expected Revenue (all control): $37.21
# Expected Revenue (all treated): $8.19
# -65.4556747665979
# 0.046602517566425194

# %%
# --- split test set by gender (column 1: 1=female, 2=male) ---
male_mask = (X_user_test[:, 1] == 2)
female_mask = (X_user_test[:, 1] == 1)

X_male = X_user_test[male_mask]
X_female = X_user_test[female_mask]

print(f"N_male={X_male.shape[0]}, N_female={X_female.shape[0]}, N_total={X_user_test.shape[0]}")

# --- male/female revenues and GTEs ---
rev_control_male = expected_revenue_for_users(X_male, X_product, price, all_product_control, 1.0)
rev_treated_male  = expected_revenue_for_users(X_male, X_product, price, all_product_treated, discount_percentage)
gte_male = rev_treated_male - rev_control_male

rev_control_female = expected_revenue_for_users(X_female, X_product, price, all_product_control, 1.0)
rev_treated_female  = expected_revenue_for_users(X_female, X_product, price, all_product_treated, discount_percentage)
gte_female = rev_treated_female - rev_control_female

# --- compare to overall ---
gte_male_scaled = (gte_male * 300/38).detach().cpu().numpy()
gte_female_scaled = (gte_female * 300/37).detach().cpu().numpy()

pdl_user_m = abs((gte_male_scaled - true_male)/true_male)
pdl_user_f = abs((gte_female_scaled - true_female)/true_female)

print(pdl_user_m)
print(pdl_user_f)
# Out:
# N_male=38, N_female=37, N_total=133
# 0.15544073527235194
# 0.4046707475777782

# %%
# split test set by phone usage
phone_less_than_2_years_mask = (X_user_test[:, 2] == 1) | (X_user_test[:, 2] == 5)
phone_more_than_2_years_mask = (X_user_test[:, 2] == 2) | (X_user_test[:, 2] == 3) | (X_user_test[:, 2] == 6)

X_phone_less_than_2_years = X_user_test[phone_less_than_2_years_mask]
X_phone_more_than_2_years = X_user_test[phone_more_than_2_years_mask]

print(f"N_phone_less_than_2_years={X_phone_less_than_2_years.shape[0]}, N_phone_more_than_2_years={X_phone_more_than_2_years.shape[0]}, N_total={X_user_test.shape[0]}")

# --- phone usage revenues and GTEs ---
rev_control_phone_less_than_2_years = expected_revenue_for_users(X_phone_less_than_2_years, X_product, price, all_product_control, 1.0)
rev_treated_phone_less_than_2_years  = expected_revenue_for_users(X_phone_less_than_2_years, X_product, price, all_product_treated, discount_percentage)
gte_phone_less_than_2_years = rev_treated_phone_less_than_2_years - rev_control_phone_less_than_2_years

rev_control_phone_more_than_2_years = expected_revenue_for_users(X_phone_more_than_2_years, X_product, price, all_product_control, 1.0)
rev_treated_phone_more_than_2_years  = expected_revenue_for_users(X_phone_more_than_2_years, X_product, price, all_product_treated, discount_percentage)
gte_phone_more_than_2_years = rev_treated_phone_more_than_2_years - rev_control_phone_more_than_2_years

gte_phone_less_than_2_years_scaled = (gte_phone_less_than_2_years * 300/7).detach().cpu().numpy()
gte_phone_more_than_2_years_scaled = (gte_phone_more_than_2_years * 300/50).detach().cpu().numpy()

pdl_user_phone_less_than_2_years = abs((gte_phone_less_than_2_years_scaled - true_phone_less_than_2_years)/true_phone_less_than_2_years)
pdl_user_phone_more_than_2_years = abs((gte_phone_more_than_2_years_scaled - true_phone_more_than_2_years)/true_phone_more_than_2_years)

print(pdl_user_phone_less_than_2_years)
print(pdl_user_phone_more_than_2_years)
# Out:
# N_phone_less_than_2_years=7, N_phone_more_than_2_years=50, N_total=133
# 0.13404911305786932
# 0.40593807650411695

# %% [markdown]
# ### Only product features

# %%
class DeepMNLModel_ProductOnly(nn.Module):
    """
    Deep MNL (product-only):
    u_ij = theta(z_j, z_-j, p_j)
    Outside option utility = 0.
    """
    def __init__(self, product_dim, num_product, hidden=5):
        super(DeepMNLModel_ProductOnly, self).__init__()

        # Aggregate other products' features z_-j:
        # Input:  [M, (M-1)*F_p]
        # Output: [M, hidden]
        self.other_product_features_layers = nn.Sequential(
            nn.Linear(product_dim * (num_product - 1), hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU()
        )

        # theta(z_j, z_-j, p_j)
        # Input per (i,j): [F_p + hidden (z_-j) + 1 (p_j)]
        in_dim = product_dim + hidden + 1

        self.theta = nn.Sequential(
            nn.Linear(in_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, x_user, X_product, X_other_products,
                x_other_prices, price, prod_randomization):
        """
        X_product:        [M, F_p]          product features z_j
        X_other_products: [M, (M-1)*F_p]    other products' features z_-j
        price:            [M]               own price p_j (already discounted)
        """
        device = price.device
        # N users, M products
        N, M = x_user.shape[0], X_product.shape[0]

        # z_-j features: [M, hidden]
        zminus_feat = self.other_product_features_layers(X_other_products)

        # p_j scalar: [M, 1]
        pj_feat = price.unsqueeze(1)

        # Combine product-side info: [M, F_p + hidden + 1]
        product_feat = torch.cat(
            [X_product, zminus_feat, pj_feat],
            dim=1
        )

        # Expand to all users: [N, M, in_dim]
        product_feat_exp = product_feat.unsqueeze(0).expand(N, -1, -1)

        # Flatten to [N*M, in_dim]
        theta_input_flat = product_feat_exp.reshape(N * M, -1)

        # Utilities: [N*M, 1] -> [N, M]
        utilities = self.theta(theta_input_flat).view(N, M)

        # Outside option = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utilities], dim=1)

        return utilities_with_outside

# %%
# Apply the model
model = DeepMNLModel_ProductOnly(
    product_dim=X_product.shape[1],
    num_product=X_product.shape[0],
    hidden=5
).to(device)

model.apply(init_weights)
# Out:
# DeepMNLModel_ProductOnly(
#   (other_product_features_layers): Sequential(
#     (0): Linear(in_features=15, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): ReLU()
#   )
#   (theta): Sequential(
#     (0): Linear(in_features=9, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# ----- Prepare validation data -----
prepared_val = prepare_data(
    X_user_val,
    X_product,
    price * (1 - (1 - discount_percentage) * prod_randomization)
)
user_features_val, product_features_val, price_val, all_x_other_products_val, all_other_prices_val = prepared_val

user_features_val = user_features_val.to(device)
product_features_val = product_features_val.to(device)
all_x_other_products_val = all_x_other_products_val.to(device)
all_other_prices_val = all_other_prices_val.to(device)
choice_val = choice_val.to(device)

# ----- Optimizer and scheduler -----
optimizer = optim.Adam(model.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)
l2_lambda = 0  # L2 regularization coefficient

# Early stopping setup
best_val_loss = float('inf')
patience = 20
patience_counter = 0

# ----- Training loop -----
for epoch in range(1000):
    model.train()
    optimizer.zero_grad()

    # Forward pass (train): use prepared prices and other-prices matrix
    outputs = model(
        user_features,         # x_user (not used inside DeepMNLModel_No, but kept for interface)
        product_features,      # X_product (not used)
        all_x_other_products,  # X_other_products (not used in No model)
        all_other_prices,      # x_other_prices: p_-j
        prices,                # price: experimental p_j (after discount)
        prod_randomization     # can be ignored inside No model
    )

    choice_probabilities = F.log_softmax(outputs, dim=1)

    # Training loss
    loss = -torch.mean(
        choice_probabilities[
            torch.arange(choice_probabilities.shape[0], device=device),
            choice_train1
        ]
    )

    # L2 regularization
    l2_norm = sum(param.pow(2.0).sum() for param in model.parameters())
    loss = loss + l2_lambda * l2_norm

    # Backward
    loss.backward()
    optimizer.step()

    # ----- Validation -----
    model.eval()
    with torch.no_grad():
        val_outputs = model(
            user_features_val,
            product_features_val,
            all_x_other_products_val,
            all_other_prices_val,
            price_val,              # same product prices for validation
            prod_randomization
        )
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(
            val_choice_probabilities[
                torch.arange(val_choice_probabilities.shape[0], device=device),
                choice_val
            ]
        )

    print(
        f"Epoch {epoch+1}, "
        f"Training Loss: {loss.item():.4f}, "
        f"Validation Loss: {val_loss.item():.4f}"
    )

    # Early stopping logic
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        torch.save(model.state_dict(), 'best_model.pth')
    else:
        patience_counter += 1

    if patience_counter >= patience:
        print("Early stopping triggered")
        break

    scheduler.step()
# Out:
# Epoch 1, Training Loss: 2.5788, Validation Loss: 2.3564
# Epoch 2, Training Loss: 2.3244, Validation Loss: 2.1433
# Epoch 3, Training Loss: 2.1214, Validation Loss: 2.0003
# Epoch 4, Training Loss: 1.9814, Validation Loss: 1.9359
# Epoch 5, Training Loss: 1.9278, Validation Loss: 1.8966
# Epoch 6, Training Loss: 1.9015, Validation Loss: 1.8815
# Epoch 7, Training Loss: 1.8865, Validation Loss: 1.8755
# Epoch 8, Training Loss: 1.8807, Validation Loss: 1.8650
# Epoch 9, Training Loss: 1.8711, Validation Loss: 1.8545
# Epoch 10, Training Loss: 1.8614, Validation Loss: 1.8440
# Epoch 11, Training Loss: 1.8517, Validation Loss: 1.8335
# Epoch 12, Training Loss: 1.8419, Validation Loss: 1.8229
# Epoch 13, Training Loss: 1.8322, Validation Loss: 1.8123
# Epoch 14, Training Loss: 1.8224, Validation Loss: 1.8016
# Epoch 15, Training Loss: 1.8126, Validation Loss: 1.7910
# Epoch 16, Training Loss: 1.8027, Validation Loss: 1.7802
# Epoch 17, Training Loss: 1.7929, Validation Loss: 1.7695
# Epoch 18, Training Loss: 1.7829, Validation Loss: 1.7587
# Epoch 19, Training Loss: 1.7730, Validation Loss: 1.7478
# Epoch 20, Training Loss: 1.7630, Validation Loss: 1.7369
# Epoch 21, Training Loss: 1.7530, Validation Loss: 1.7260
# Epoch 22, Training Loss: 1.7430, Validation Loss: 1.7150
# Epoch 23, Training Loss: 1.7329, Validation Loss: 1.7040
# Epoch 24, Training Loss: 1.7228, Validation Loss: 1.6929
# Epoch 25, Training Loss: 1.7126, Validation Loss: 1.6818
# Epoch 26, Training Loss: 1.7025, Validation Loss: 1.6707
# Epoch 27, Training Loss: 1.6923, Validation Loss: 1.6596
# Epoch 28, Training Loss: 1.6821, Validation Loss: 1.6484
# Epoch 29, Training Loss: 1.6718, Validation Loss: 1.6371
# Epoch 30, Training Loss: 1.6616, Validation Loss: 1.6259
# Epoch 31, Training Loss: 1.6513, Validation Loss: 1.6146
# Epoch 32, Training Loss: 1.6410, Validation Loss: 1.6034
# Epoch 33, Training Loss: 1.6308, Validation Loss: 1.5921
# Epoch 34, Training Loss: 1.6205, Validation Loss: 1.5808
# Epoch 35, Training Loss: 1.6102, Validation Loss: 1.5695
# Epoch 36, Training Loss: 1.6000, Validation Loss: 1.5582
# Epoch 37, Training Loss: 1.5897, Validation Loss: 1.5469
# Epoch 38, Training Loss: 1.5795, Validation Loss: 1.5357
# Epoch 39, Training Loss: 1.5693, Validation Loss: 1.5244
# Epoch 40, Training Loss: 1.5591, Validation Loss: 1.5133
# Epoch 41, Training Loss: 1.5490, Validation Loss: 1.5021
# Epoch 42, Training Loss: 1.5390, Validation Loss: 1.4910
# Epoch 43, Training Loss: 1.5289, Validation Loss: 1.4799
# Epoch 44, Training Loss: 1.5190, Validation Loss: 1.4689
# Epoch 45, Training Loss: 1.5091, Validation Loss: 1.4580
# Epoch 46, Training Loss: 1.4993, Validation Loss: 1.4472
# Epoch 47, Training Loss: 1.4896, Validation Loss: 1.4364
# Epoch 48, Training Loss: 1.4800, Validation Loss: 1.4257
# Epoch 49, Training Loss: 1.4704, Validation Loss: 1.4152
# Epoch 50, Training Loss: 1.4610, Validation Loss: 1.4047
# Epoch 51, Training Loss: 1.4517, Validation Loss: 1.3944
# Epoch 52, Training Loss: 1.4426, Validation Loss: 1.3842
# Epoch 53, Training Loss: 1.4335, Validation Loss: 1.3741
# Epoch 54, Training Loss: 1.4246, Validation Loss: 1.3641
# Epoch 55, Training Loss: 1.4159, Validation Loss: 1.3544
# Epoch 56, Training Loss: 1.4073, Validation Loss: 1.3447
# Epoch 57, Training Loss: 1.3988, Validation Loss: 1.3353
# Epoch 58, Training Loss: 1.3905, Validation Loss: 1.3260
# Epoch 59, Training Loss: 1.3825, Validation Loss: 1.3169
# Epoch 60, Training Loss: 1.3745, Validation Loss: 1.3080
# Epoch 61, Training Loss: 1.3668, Validation Loss: 1.2993
# Epoch 62, Training Loss: 1.3593, Validation Loss: 1.2907
# Epoch 63, Training Loss: 1.3520, Validation Loss: 1.2824
# Epoch 64, Training Loss: 1.3448, Validation Loss: 1.2743
# Epoch 65, Training Loss: 1.3379, Validation Loss: 1.2664
# Epoch 66, Training Loss: 1.3312, Validation Loss: 1.2588
# Epoch 67, Training Loss: 1.3247, Validation Loss: 1.2513
# Epoch 68, Training Loss: 1.3185, Validation Loss: 1.2441
# Epoch 69, Training Loss: 1.3124, Validation Loss: 1.2371
# Epoch 70, Training Loss: 1.3066, Validation Loss: 1.2304
# Epoch 71, Training Loss: 1.3010, Validation Loss: 1.2238
# Epoch 72, Training Loss: 1.2956, Validation Loss: 1.2176
# Epoch 73, Training Loss: 1.2905, Validation Loss: 1.2115
# Epoch 74, Training Loss: 1.2856, Validation Loss: 1.2057
# Epoch 75, Training Loss: 1.2809, Validation Loss: 1.2001
# Epoch 76, Training Loss: 1.2764, Validation Loss: 1.1948
# Epoch 77, Training Loss: 1.2722, Validation Loss: 1.1897
# Epoch 78, Training Loss: 1.2681, Validation Loss: 1.1848
# Epoch 79, Training Loss: 1.2643, Validation Loss: 1.1802
# Epoch 80, Training Loss: 1.2607, Validation Loss: 1.1757
# Epoch 81, Training Loss: 1.2573, Validation Loss: 1.1715
# Epoch 82, Training Loss: 1.2541, Validation Loss: 1.1675
# Epoch 83, Training Loss: 1.2511, Validation Loss: 1.1637
# Epoch 84, Training Loss: 1.2483, Validation Loss: 1.1602
# Epoch 85, Training Loss: 1.2457, Validation Loss: 1.1568
# Epoch 86, Training Loss: 1.2433, Validation Loss: 1.1536
# Epoch 87, Training Loss: 1.2410, Validation Loss: 1.1506
# Epoch 88, Training Loss: 1.2389, Validation Loss: 1.1478
# Epoch 89, Training Loss: 1.2370, Validation Loss: 1.1451
# Epoch 90, Training Loss: 1.2352, Validation Loss: 1.1426
# Epoch 91, Training Loss: 1.2335, Validation Loss: 1.1403
# Epoch 92, Training Loss: 1.2320, Validation Loss: 1.1381
# Epoch 93, Training Loss: 1.2306, Validation Loss: 1.1361
# Epoch 94, Training Loss: 1.2294, Validation Loss: 1.1342
# Epoch 95, Training Loss: 1.2282, Validation Loss: 1.1325
# Epoch 96, Training Loss: 1.2272, Validation Loss: 1.1308
# Epoch 97, Training Loss: 1.2263, Validation Loss: 1.1293
# Epoch 98, Training Loss: 1.2254, Validation Loss: 1.1279
# Epoch 99, Training Loss: 1.2247, Validation Loss: 1.1267
# Epoch 100, Training Loss: 1.2240, Validation Loss: 1.1255
# Epoch 101, Training Loss: 1.2234, Validation Loss: 1.1244
# Epoch 102, Training Loss: 1.2229, Validation Loss: 1.1233
# Epoch 103, Training Loss: 1.2224, Validation Loss: 1.1224
# Epoch 104, Training Loss: 1.2220, Validation Loss: 1.1216
# Epoch 105, Training Loss: 1.2216, Validation Loss: 1.1208
# Epoch 106, Training Loss: 1.2213, Validation Loss: 1.1201
# Epoch 107, Training Loss: 1.2210, Validation Loss: 1.1194
# Epoch 108, Training Loss: 1.2208, Validation Loss: 1.1188
# Epoch 109, Training Loss: 1.2206, Validation Loss: 1.1183
# Epoch 110, Training Loss: 1.2205, Validation Loss: 1.1178
# Epoch 111, Training Loss: 1.2203, Validation Loss: 1.1173
# Epoch 112, Training Loss: 1.2202, Validation Loss: 1.1169
# Epoch 113, Training Loss: 1.2201, Validation Loss: 1.1165
# Epoch 114, Training Loss: 1.2200, Validation Loss: 1.1162
# Epoch 115, Training Loss: 1.2200, Validation Loss: 1.1158
# Epoch 116, Training Loss: 1.2199, Validation Loss: 1.1156
# Epoch 117, Training Loss: 1.2199, Validation Loss: 1.1153
# Epoch 118, Training Loss: 1.2198, Validation Loss: 1.1151
# Epoch 119, Training Loss: 1.2198, Validation Loss: 1.1149
# Epoch 120, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 121, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 122, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 123, Training Loss: 1.2198, Validation Loss: 1.1142
# Epoch 124, Training Loss: 1.2198, Validation Loss: 1.1141
# Epoch 125, Training Loss: 1.2198, Validation Loss: 1.1140
# Epoch 126, Training Loss: 1.2198, Validation Loss: 1.1139
# Epoch 127, Training Loss: 1.2198, Validation Loss: 1.1139
# Epoch 128, Training Loss: 1.2198, Validation Loss: 1.1138
# Epoch 129, Training Loss: 1.2198, Validation Loss: 1.1137
# Epoch 130, Training Loss: 1.2198, Validation Loss: 1.1137
# Epoch 131, Training Loss: 1.2198, Validation Loss: 1.1136
# Epoch 132, Training Loss: 1.2198, Validation Loss: 1.1136
# Epoch 133, Training Loss: 1.2198, Validation Loss: 1.1136
# Epoch 134, Training Loss: 1.2198, Validation Loss: 1.1135
# Epoch 135, Training Loss: 1.2198, Validation Loss: 1.1135
# Epoch 136, Training Loss: 1.2198, Validation Loss: 1.1135
# Epoch 137, Training Loss: 1.2198, Validation Loss: 1.1135
# Epoch 138, Training Loss: 1.2198, Validation Loss: 1.1135
# Epoch 139, Training Loss: 1.2198, Validation Loss: 1.1135
# Epoch 140, Training Loss: 1.2198, Validation Loss: 1.1135
# Epoch 141, Training Loss: 1.2198, Validation Loss: 1.1135
# Epoch 142, Training Loss: 1.2198, Validation Loss: 1.1135
# Epoch 143, Training Loss: 1.2198, Validation Loss: 1.1135
# Epoch 144, Training Loss: 1.2198, Validation Loss: 1.1136
# Epoch 145, Training Loss: 1.2198, Validation Loss: 1.1136
# Epoch 146, Training Loss: 1.2198, Validation Loss: 1.1136
# Epoch 147, Training Loss: 1.2198, Validation Loss: 1.1136
# Epoch 148, Training Loss: 1.2198, Validation Loss: 1.1137
# Epoch 149, Training Loss: 1.2198, Validation Loss: 1.1137
# Epoch 150, Training Loss: 1.2198, Validation Loss: 1.1137
# Epoch 151, Training Loss: 1.2198, Validation Loss: 1.1137
# Epoch 152, Training Loss: 1.2198, Validation Loss: 1.1138
# Epoch 153, Training Loss: 1.2198, Validation Loss: 1.1138
# Epoch 154, Training Loss: 1.2198, Validation Loss: 1.1138
# Epoch 155, Training Loss: 1.2198, Validation Loss: 1.1138
# Epoch 156, Training Loss: 1.2198, Validation Loss: 1.1139
# Epoch 157, Training Loss: 1.2198, Validation Loss: 1.1139
# Epoch 158, Training Loss: 1.2198, Validation Loss: 1.1139
# Early stopping triggered

# %%
# All-control and all-treated for test set
num_product = X_product.shape[0]

# All control: product_randomization = 0
all_product_control = torch.zeros(num_product, device=device).bool()

# All treated: product_randomization = 1
all_product_treated = torch.ones(num_product, device=device).bool()

# Move base price and test users/products to device
X_user_test = X_user_test.to(device)
X_product = X_product.to(device)
price = price.to(device)

# --------- Expected revenue: all control ----------
# Control prices = base prices (no discount)
price_control = price.clone()

# Prepare test data under all-control prices
user_test_ctrl, product_test_ctrl, prices_ctrl, x_other_products_ctrl, other_prices_ctrl = prepare_data(
    X_user_test,
    X_product,
    price_control
)

utilities_ctrl = model(
    user_test_ctrl,
    product_test_ctrl,
    x_other_products_ctrl,
    other_prices_ctrl,
    prices_ctrl,          # control prices
    all_product_control   # all False
)

probabilities_ctrl = F.softmax(utilities_ctrl, dim=1)

price_with_outside_ctrl = torch.cat(
    (torch.zeros(1, device=price.device), prices_ctrl), dim=0
)  # [M+1]

expected_revenue_ctrl = torch.sum(
    probabilities_ctrl * price_with_outside_ctrl.unsqueeze(0).expand_as(probabilities_ctrl),
    dim=1
).sum()

print(f"Expected Revenue (all control): ${expected_revenue_ctrl.item():.2f}")

# --------- Expected revenue: all treated ----------
# Treated prices = discounted prices
price_treated = price * discount_percentage

user_test_trt, product_test_trt, prices_trt, x_other_products_trt, other_prices_trt = prepare_data(
    X_user_test,
    X_product,
    price_treated
)

utilities_trt = model(
    user_test_trt,
    product_test_trt,
    x_other_products_trt,
    other_prices_trt,
    prices_trt,          # treated prices
    all_product_treated  # all True
)

probabilities_trt = F.softmax(utilities_trt, dim=1)

price_with_outside_trt = torch.cat(
    (torch.zeros(1, device=price.device), prices_trt), dim=0
)

expected_revenue_trt = torch.sum(
    probabilities_trt * price_with_outside_trt.unsqueeze(0).expand_as(probabilities_trt),
    dim=1
).sum()

print(f"Expected Revenue (all treated): ${expected_revenue_trt.item():.2f}")

# --------- GTE ----------
pdl = (expected_revenue_trt - expected_revenue_ctrl).cpu().detach().numpy() * 600 / 266
print(pdl)

pdl_product = abs((pdl - true) / true)
print(pdl_product)
# Out:
# Expected Revenue (all control): $40.90
# Expected Revenue (all treated): $8.18
# -73.81170746079064
# 0.07510764067704896

# %%
# --- split test set by gender (column 1: 1=female, 2=male) ---
male_mask = (X_user_test[:, 1] == 2)
female_mask = (X_user_test[:, 1] == 1)

X_male = X_user_test[male_mask]
X_female = X_user_test[female_mask]

print(f"N_male={X_male.shape[0]}, N_female={X_female.shape[0]}, N_total={X_user_test.shape[0]}")

# --- male/female revenues and GTEs ---
rev_control_male = expected_revenue_for_users(X_male, X_product, price, all_product_control, 1.0)
rev_treated_male  = expected_revenue_for_users(X_male, X_product, price, all_product_treated, discount_percentage)
gte_male = rev_treated_male - rev_control_male

rev_control_female = expected_revenue_for_users(X_female, X_product, price, all_product_control, 1.0)
rev_treated_female  = expected_revenue_for_users(X_female, X_product, price, all_product_treated, discount_percentage)
gte_female = rev_treated_female - rev_control_female

# --- compare to overall ---
gte_male_scaled = (gte_male * 300/38).detach().cpu().numpy()
gte_female_scaled = (gte_female * 300/37).detach().cpu().numpy()

pdl_prod_m = abs((gte_male_scaled - true_male)/true_male)
pdl_prod_f = abs((gte_female_scaled - true_female)/true_female)

print(pdl_prod_m)
print(pdl_prod_f)
# Out:
# N_male=38, N_female=37, N_total=133
# 0.0852739173549684
# 0.2826138464025327

# %%
# split test set by phone usage
phone_less_than_2_years_mask = (X_user_test[:, 2] == 1) | (X_user_test[:, 2] == 5)
phone_more_than_2_years_mask = (X_user_test[:, 2] == 2) | (X_user_test[:, 2] == 3) | (X_user_test[:, 2] == 6)

X_phone_less_than_2_years = X_user_test[phone_less_than_2_years_mask]
X_phone_more_than_2_years = X_user_test[phone_more_than_2_years_mask]

print(f"N_phone_less_than_2_years={X_phone_less_than_2_years.shape[0]}, N_phone_more_than_2_years={X_phone_more_than_2_years.shape[0]}, N_total={X_user_test.shape[0]}")

# --- phone usage revenues and GTEs ---
rev_control_phone_less_than_2_years = expected_revenue_for_users(X_phone_less_than_2_years, X_product, price, all_product_control, 1.0)
rev_treated_phone_less_than_2_years  = expected_revenue_for_users(X_phone_less_than_2_years, X_product, price, all_product_treated, discount_percentage)
gte_phone_less_than_2_years = rev_treated_phone_less_than_2_years - rev_control_phone_less_than_2_years

rev_control_phone_more_than_2_years = expected_revenue_for_users(X_phone_more_than_2_years, X_product, price, all_product_control, 1.0)
rev_treated_phone_more_than_2_years  = expected_revenue_for_users(X_phone_more_than_2_years, X_product, price, all_product_treated, discount_percentage)
gte_phone_more_than_2_years = rev_treated_phone_more_than_2_years - rev_control_phone_more_than_2_years

gte_phone_less_than_2_years_scaled = (gte_phone_less_than_2_years * 300/7).detach().cpu().numpy()
gte_phone_more_than_2_years_scaled = (gte_phone_more_than_2_years * 300/50).detach().cpu().numpy()

pdl_prod_phone_less_than_2_years = abs((gte_phone_less_than_2_years_scaled - true_phone_less_than_2_years)/true_phone_less_than_2_years)
pdl_prod_phone_more_than_2_years = abs((gte_phone_more_than_2_years_scaled - true_phone_more_than_2_years)/true_phone_more_than_2_years)

print(pdl_prod_phone_less_than_2_years)
print(pdl_prod_phone_more_than_2_years)
# Out:
# N_phone_less_than_2_years=7, N_phone_more_than_2_years=50, N_total=133
# 0.20791939578910668
# 0.5186906943850205

# %% [markdown]
# ### All features

# %%
# PDL choice model
class DeepMNLModel_UserProduct(nn.Module):
    """
    Deep MNL:
    u_ij = theta(x_i, z_j, z_-j, p_j)
    Outside option utility = 0.
    """
    def __init__(self, user_dim, product_dim, num_product, hidden=5):
        super(DeepMNLModel_UserProduct, self).__init__()

        # Aggregate other products' features z_-j:
        # Input:  [M, (M-1)*F_p]
        # Output: [M, hidden]
        self.other_product_features_layers = nn.Sequential(
            nn.Linear(product_dim * (num_product - 1), hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU()
        )

        # theta(x_i, z_j, z_-j, p_j)
        # Input per (i,j):
        #   user_dim (x_i)
        # + product_dim (z_j)
        # + hidden (z_-j)
        # + 1 (p_j)
        in_dim = user_dim + product_dim + hidden + 1

        self.theta = nn.Sequential(
            nn.Linear(in_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, x_user, X_product, X_other_products,
                x_other_prices, price, prod_randomization):
        """
        x_user:          [N, F_u]          user features x_i
        X_product:       [M, F_p]          product features z_j
        X_other_products:[M, (M-1)*F_p]    other products' features z_-j
        price:           [M]               own price p_j (already discounted)

        x_other_prices, prod_randomization are not used here.
        """
        device = price.device
        N, M = x_user.shape[0], X_product.shape[0]

        # z_-j features: [M, hidden]
        zminus_feat = self.other_product_features_layers(X_other_products)

        # p_j: [M, 1]
        pj_feat = price.unsqueeze(1)

        # Product-side block: [M, F_p + hidden + 1]
        product_block = torch.cat(
            [X_product, zminus_feat, pj_feat],
            dim=1
        )

        # Expand product block for all users: [N, M, *]
        product_block_exp = product_block.unsqueeze(0).expand(N, -1, -1)

        # Expand user features: [N, 1, F_u] -> [N, M, F_u]
        x_user_exp = x_user.unsqueeze(1).expand(-1, M, -1)

        # Final theta input: [N, M, in_dim]
        theta_input = torch.cat([x_user_exp, product_block_exp], dim=2)

        # Flatten to [N*M, in_dim]
        theta_input_flat = theta_input.reshape(N * M, -1)

        # Utilities: [N*M, 1] -> [N, M]
        utilities = self.theta(theta_input_flat).view(N, M)

        # Outside option = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utilities], dim=1)

        return utilities_with_outside

# %%
# Apply the model
model = DeepMNLModel_UserProduct(
    user_dim=X_user.shape[1],
    product_dim=X_product.shape[1],
    num_product=X_product.shape[0],
    hidden=5
).to(device)

model.apply(init_weights)
# Out:
# DeepMNLModel_UserProduct(
#   (other_product_features_layers): Sequential(
#     (0): Linear(in_features=15, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): ReLU()
#   )
#   (theta): Sequential(
#     (0): Linear(in_features=12, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# ----- Prepare validation data -----
prepared_val = prepare_data(
    X_user_val,
    X_product,
    price * (1 - (1 - discount_percentage) * prod_randomization)
)
user_features_val, product_features_val, price_val, all_x_other_products_val, all_other_prices_val = prepared_val

user_features_val = user_features_val.to(device)
product_features_val = product_features_val.to(device)
all_x_other_products_val = all_x_other_products_val.to(device)
all_other_prices_val = all_other_prices_val.to(device)
choice_val = choice_val.to(device)

# ----- Optimizer and scheduler -----
optimizer = optim.Adam(model.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)
l2_lambda = 0 # L2 regularization coefficient

# Early stopping setup
best_val_loss = float('inf')
patience = 50
patience_counter = 0

# ----- Training loop -----
for epoch in range(5000):
    model.train()
    optimizer.zero_grad()

    # Forward pass (train): use prepared prices and other-prices matrix
    outputs = model(
        user_features,         # x_user (not used inside DeepMNLModel_No, but kept for interface)
        product_features,      # X_product (not used)
        all_x_other_products,  # X_other_products (not used in No model)
        all_other_prices,      # x_other_prices: p_-j
        prices,                # price: experimental p_j (after discount)
        prod_randomization     # can be ignored inside No model
    )

    choice_probabilities = F.log_softmax(outputs, dim=1)

    # Training loss
    loss = -torch.mean(
        choice_probabilities[
            torch.arange(choice_probabilities.shape[0], device=device),
            choice_train1
        ]
    )

    # L2 regularization
    l2_norm = sum(param.pow(2.0).sum() for param in model.parameters())
    loss = loss + l2_lambda * l2_norm

    # Backward
    loss.backward()
    optimizer.step()

    # ----- Validation -----
    model.eval()
    with torch.no_grad():
        val_outputs = model(
            user_features_val,
            product_features_val,
            all_x_other_products_val,
            all_other_prices_val,
            price_val,              # same product prices for validation
            prod_randomization
        )
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(
            val_choice_probabilities[
                torch.arange(val_choice_probabilities.shape[0], device=device),
                choice_val
            ]
        )

    print(
        f"Epoch {epoch+1}, "
        f"Training Loss: {loss.item():.4f}, "
        f"Validation Loss: {val_loss.item():.4f}"
    )

    # Early stopping logic
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        torch.save(model.state_dict(), 'best_model.pth')
    else:
        patience_counter += 1

    if patience_counter >= patience:
        print("Early stopping triggered")
        break

    scheduler.step()
# Out:
# Epoch 1, Training Loss: 2.0807, Validation Loss: 1.9105
# Epoch 2, Training Loss: 1.8371, Validation Loss: 1.6767
# Epoch 3, Training Loss: 1.6598, Validation Loss: 1.4871
# Epoch 4, Training Loss: 1.4941, Validation Loss: 1.3507
# Epoch 5, Training Loss: 1.3668, Validation Loss: 1.2668
# Epoch 6, Training Loss: 1.2976, Validation Loss: 1.2450
# Epoch 7, Training Loss: 1.2939, Validation Loss: 1.2618
# Epoch 8, Training Loss: 1.3274, Validation Loss: 1.2806
# Epoch 9, Training Loss: 1.3542, Validation Loss: 1.2857
# Epoch 10, Training Loss: 1.3617, Validation Loss: 1.2747
# Epoch 11, Training Loss: 1.3506, Validation Loss: 1.2528
# Epoch 12, Training Loss: 1.3268, Validation Loss: 1.2280
# Epoch 13, Training Loss: 1.2998, Validation Loss: 1.2055
# Epoch 14, Training Loss: 1.2747, Validation Loss: 1.1901
# Epoch 15, Training Loss: 1.2567, Validation Loss: 1.1839
# Epoch 16, Training Loss: 1.2479, Validation Loss: 1.1860
# Epoch 17, Training Loss: 1.2477, Validation Loss: 1.1934
# Epoch 18, Training Loss: 1.2532, Validation Loss: 1.2024
# Epoch 19, Training Loss: 1.2607, Validation Loss: 1.2094
# Epoch 20, Training Loss: 1.2669, Validation Loss: 1.2123
# Epoch 21, Training Loss: 1.2697, Validation Loss: 1.2104
# Epoch 22, Training Loss: 1.2683, Validation Loss: 1.2043
# Epoch 23, Training Loss: 1.2632, Validation Loss: 1.1953
# Epoch 24, Training Loss: 1.2557, Validation Loss: 1.1852
# Epoch 25, Training Loss: 1.2476, Validation Loss: 1.1760
# Epoch 26, Training Loss: 1.2405, Validation Loss: 1.1689
# Epoch 27, Training Loss: 1.2356, Validation Loss: 1.1648
# Epoch 28, Training Loss: 1.2336, Validation Loss: 1.1633
# Epoch 29, Training Loss: 1.2341, Validation Loss: 1.1637
# Epoch 30, Training Loss: 1.2362, Validation Loss: 1.1647
# Epoch 31, Training Loss: 1.2384, Validation Loss: 1.1650
# Epoch 32, Training Loss: 1.2396, Validation Loss: 1.1642
# Epoch 33, Training Loss: 1.2391, Validation Loss: 1.1621
# Epoch 34, Training Loss: 1.2369, Validation Loss: 1.1594
# Epoch 35, Training Loss: 1.2337, Validation Loss: 1.1569
# Epoch 36, Training Loss: 1.2304, Validation Loss: 1.1552
# Epoch 37, Training Loss: 1.2278, Validation Loss: 1.1546
# Epoch 38, Training Loss: 1.2263, Validation Loss: 1.1550
# Epoch 39, Training Loss: 1.2259, Validation Loss: 1.1561
# Epoch 40, Training Loss: 1.2263, Validation Loss: 1.1572
# Epoch 41, Training Loss: 1.2269, Validation Loss: 1.1578
# Epoch 42, Training Loss: 1.2273, Validation Loss: 1.1575
# Epoch 43, Training Loss: 1.2270, Validation Loss: 1.1562
# Epoch 44, Training Loss: 1.2261, Validation Loss: 1.1543
# Epoch 45, Training Loss: 1.2247, Validation Loss: 1.1521
# Epoch 46, Training Loss: 1.2232, Validation Loss: 1.1500
# Epoch 47, Training Loss: 1.2219, Validation Loss: 1.1483
# Epoch 48, Training Loss: 1.2210, Validation Loss: 1.1471
# Epoch 49, Training Loss: 1.2206, Validation Loss: 1.1464
# Epoch 50, Training Loss: 1.2206, Validation Loss: 1.1459
# Epoch 51, Training Loss: 1.2206, Validation Loss: 1.1455
# Epoch 52, Training Loss: 1.2205, Validation Loss: 1.1450
# Epoch 53, Training Loss: 1.2201, Validation Loss: 1.1444
# Epoch 54, Training Loss: 1.2195, Validation Loss: 1.1439
# Epoch 55, Training Loss: 1.2187, Validation Loss: 1.1434
# Epoch 56, Training Loss: 1.2179, Validation Loss: 1.1432
# Epoch 57, Training Loss: 1.2173, Validation Loss: 1.1432
# Epoch 58, Training Loss: 1.2169, Validation Loss: 1.1432
# Epoch 59, Training Loss: 1.2166, Validation Loss: 1.1433
# Epoch 60, Training Loss: 1.2164, Validation Loss: 1.1432
# Epoch 61, Training Loss: 1.2162, Validation Loss: 1.1429
# Epoch 62, Training Loss: 1.2159, Validation Loss: 1.1423
# Epoch 63, Training Loss: 1.2155, Validation Loss: 1.1416
# Epoch 64, Training Loss: 1.2150, Validation Loss: 1.1408
# Epoch 65, Training Loss: 1.2145, Validation Loss: 1.1401
# Epoch 66, Training Loss: 1.2140, Validation Loss: 1.1395
# Epoch 67, Training Loss: 1.2137, Validation Loss: 1.1389
# Epoch 68, Training Loss: 1.2134, Validation Loss: 1.1385
# Epoch 69, Training Loss: 1.2132, Validation Loss: 1.1382
# Epoch 70, Training Loss: 1.2129, Validation Loss: 1.1379
# Epoch 71, Training Loss: 1.2126, Validation Loss: 1.1376
# Epoch 72, Training Loss: 1.2123, Validation Loss: 1.1374
# Epoch 73, Training Loss: 1.2119, Validation Loss: 1.1372
# Epoch 74, Training Loss: 1.2115, Validation Loss: 1.1371
# Epoch 75, Training Loss: 1.2112, Validation Loss: 1.1370
# Epoch 76, Training Loss: 1.2109, Validation Loss: 1.1369
# Epoch 77, Training Loss: 1.2107, Validation Loss: 1.1368
# Epoch 78, Training Loss: 1.2104, Validation Loss: 1.1366
# Epoch 79, Training Loss: 1.2101, Validation Loss: 1.1363
# Epoch 80, Training Loss: 1.2099, Validation Loss: 1.1359
# Epoch 81, Training Loss: 1.2095, Validation Loss: 1.1356
# Epoch 82, Training Loss: 1.2092, Validation Loss: 1.1352
# Epoch 83, Training Loss: 1.2089, Validation Loss: 1.1349
# Epoch 84, Training Loss: 1.2087, Validation Loss: 1.1346
# Epoch 85, Training Loss: 1.2084, Validation Loss: 1.1344
# Epoch 86, Training Loss: 1.2082, Validation Loss: 1.1342
# Epoch 87, Training Loss: 1.2079, Validation Loss: 1.1340
# Epoch 88, Training Loss: 1.2076, Validation Loss: 1.1338
# Epoch 89, Training Loss: 1.2073, Validation Loss: 1.1337
# Epoch 90, Training Loss: 1.2071, Validation Loss: 1.1336
# Epoch 91, Training Loss: 1.2068, Validation Loss: 1.1335
# Epoch 92, Training Loss: 1.2065, Validation Loss: 1.1334
# Epoch 93, Training Loss: 1.2063, Validation Loss: 1.1333
# Epoch 94, Training Loss: 1.2060, Validation Loss: 1.1331
# Epoch 95, Training Loss: 1.2058, Validation Loss: 1.1330
# Epoch 96, Training Loss: 1.2055, Validation Loss: 1.1328
# Epoch 97, Training Loss: 1.2053, Validation Loss: 1.1326
# Epoch 98, Training Loss: 1.2050, Validation Loss: 1.1324
# Epoch 99, Training Loss: 1.2047, Validation Loss: 1.1322
# Epoch 100, Training Loss: 1.2045, Validation Loss: 1.1321
# Epoch 101, Training Loss: 1.2042, Validation Loss: 1.1320
# Epoch 102, Training Loss: 1.2040, Validation Loss: 1.1318
# Epoch 103, Training Loss: 1.2037, Validation Loss: 1.1317
# Epoch 104, Training Loss: 1.2035, Validation Loss: 1.1316
# Epoch 105, Training Loss: 1.2032, Validation Loss: 1.1316
# Epoch 106, Training Loss: 1.2030, Validation Loss: 1.1315
# Epoch 107, Training Loss: 1.2027, Validation Loss: 1.1314
# Epoch 108, Training Loss: 1.2025, Validation Loss: 1.1314
# Epoch 109, Training Loss: 1.2022, Validation Loss: 1.1313
# Epoch 110, Training Loss: 1.2020, Validation Loss: 1.1312
# Epoch 111, Training Loss: 1.2017, Validation Loss: 1.1311
# Epoch 112, Training Loss: 1.2015, Validation Loss: 1.1310
# Epoch 113, Training Loss: 1.2012, Validation Loss: 1.1310
# Epoch 114, Training Loss: 1.2010, Validation Loss: 1.1309
# Epoch 115, Training Loss: 1.2008, Validation Loss: 1.1308
# Epoch 116, Training Loss: 1.2005, Validation Loss: 1.1307
# Epoch 117, Training Loss: 1.2003, Validation Loss: 1.1307
# Epoch 118, Training Loss: 1.2000, Validation Loss: 1.1306
# Epoch 119, Training Loss: 1.1998, Validation Loss: 1.1306
# Epoch 120, Training Loss: 1.1995, Validation Loss: 1.1306
# Epoch 121, Training Loss: 1.1993, Validation Loss: 1.1306
# Epoch 122, Training Loss: 1.1990, Validation Loss: 1.1305
# Epoch 123, Training Loss: 1.1988, Validation Loss: 1.1305
# Epoch 124, Training Loss: 1.1985, Validation Loss: 1.1305
# Epoch 125, Training Loss: 1.1983, Validation Loss: 1.1305
# Epoch 126, Training Loss: 1.1980, Validation Loss: 1.1305
# Epoch 127, Training Loss: 1.1978, Validation Loss: 1.1305
# Epoch 128, Training Loss: 1.1975, Validation Loss: 1.1305
# Epoch 129, Training Loss: 1.1973, Validation Loss: 1.1305
# Epoch 130, Training Loss: 1.1970, Validation Loss: 1.1305
# Epoch 131, Training Loss: 1.1968, Validation Loss: 1.1305
# Epoch 132, Training Loss: 1.1965, Validation Loss: 1.1305
# Epoch 133, Training Loss: 1.1962, Validation Loss: 1.1305
# Epoch 134, Training Loss: 1.1960, Validation Loss: 1.1306
# Epoch 135, Training Loss: 1.1957, Validation Loss: 1.1306
# Epoch 136, Training Loss: 1.1955, Validation Loss: 1.1306
# Epoch 137, Training Loss: 1.1952, Validation Loss: 1.1307
# Epoch 138, Training Loss: 1.1950, Validation Loss: 1.1307
# Epoch 139, Training Loss: 1.1947, Validation Loss: 1.1308
# Epoch 140, Training Loss: 1.1945, Validation Loss: 1.1309
# Epoch 141, Training Loss: 1.1942, Validation Loss: 1.1309
# Epoch 142, Training Loss: 1.1939, Validation Loss: 1.1310
# Epoch 143, Training Loss: 1.1937, Validation Loss: 1.1311
# Epoch 144, Training Loss: 1.1934, Validation Loss: 1.1311
# Epoch 145, Training Loss: 1.1931, Validation Loss: 1.1312
# Epoch 146, Training Loss: 1.1929, Validation Loss: 1.1313
# Epoch 147, Training Loss: 1.1926, Validation Loss: 1.1314
# Epoch 148, Training Loss: 1.1924, Validation Loss: 1.1315
# Epoch 149, Training Loss: 1.1921, Validation Loss: 1.1316
# Epoch 150, Training Loss: 1.1918, Validation Loss: 1.1317
# Epoch 151, Training Loss: 1.1916, Validation Loss: 1.1318
# Epoch 152, Training Loss: 1.1913, Validation Loss: 1.1319
# Epoch 153, Training Loss: 1.1910, Validation Loss: 1.1321
# Epoch 154, Training Loss: 1.1907, Validation Loss: 1.1322
# Epoch 155, Training Loss: 1.1905, Validation Loss: 1.1323
# Epoch 156, Training Loss: 1.1902, Validation Loss: 1.1325
# Epoch 157, Training Loss: 1.1899, Validation Loss: 1.1326
# Epoch 158, Training Loss: 1.1897, Validation Loss: 1.1328
# Epoch 159, Training Loss: 1.1894, Validation Loss: 1.1329
# Epoch 160, Training Loss: 1.1891, Validation Loss: 1.1331
# Epoch 161, Training Loss: 1.1888, Validation Loss: 1.1333
# Epoch 162, Training Loss: 1.1886, Validation Loss: 1.1335
# Epoch 163, Training Loss: 1.1883, Validation Loss: 1.1336
# Epoch 164, Training Loss: 1.1880, Validation Loss: 1.1338
# Epoch 165, Training Loss: 1.1877, Validation Loss: 1.1340
# Epoch 166, Training Loss: 1.1874, Validation Loss: 1.1342
# Epoch 167, Training Loss: 1.1872, Validation Loss: 1.1345
# Epoch 168, Training Loss: 1.1869, Validation Loss: 1.1347
# Epoch 169, Training Loss: 1.1866, Validation Loss: 1.1349
# Epoch 170, Training Loss: 1.1863, Validation Loss: 1.1351
# Epoch 171, Training Loss: 1.1860, Validation Loss: 1.1354
# Epoch 172, Training Loss: 1.1857, Validation Loss: 1.1356
# Epoch 173, Training Loss: 1.1854, Validation Loss: 1.1359
# Epoch 174, Training Loss: 1.1852, Validation Loss: 1.1361
# Epoch 175, Training Loss: 1.1849, Validation Loss: 1.1364
# Epoch 176, Training Loss: 1.1846, Validation Loss: 1.1366
# Epoch 177, Training Loss: 1.1843, Validation Loss: 1.1369
# Epoch 178, Training Loss: 1.1840, Validation Loss: 1.1372
# Epoch 179, Training Loss: 1.1837, Validation Loss: 1.1375
# Early stopping triggered

# %%
# All-control and all-treated for test set
num_product = X_product.shape[0]

# All control: product_randomization = 0
all_product_control = torch.zeros(num_product, device=device).bool()

# All treated: product_randomization = 1
all_product_treated = torch.ones(num_product, device=device).bool()

# Move base price and test users/products to device
X_user_test = X_user_test.to(device)
X_product = X_product.to(device)
price = price.to(device)

# --------- Expected revenue: all control ----------
# Control prices = base prices (no discount)
price_control = price.clone()

# Prepare test data under all-control prices
user_test_ctrl, product_test_ctrl, prices_ctrl, x_other_products_ctrl, other_prices_ctrl = prepare_data(
    X_user_test,
    X_product,
    price_control
)

utilities_ctrl = model(
    user_test_ctrl,
    product_test_ctrl,
    x_other_products_ctrl,
    other_prices_ctrl,
    prices_ctrl,          # control prices
    all_product_control   # all False
)

probabilities_ctrl = F.softmax(utilities_ctrl, dim=1)

price_with_outside_ctrl = torch.cat(
    (torch.zeros(1, device=price.device), prices_ctrl), dim=0
)  # [M+1]

expected_revenue_ctrl = torch.sum(
    probabilities_ctrl * price_with_outside_ctrl.unsqueeze(0).expand_as(probabilities_ctrl),
    dim=1
).sum()

print(f"Expected Revenue (all control): ${expected_revenue_ctrl.item():.2f}")

# --------- Expected revenue: all treated ----------
# Treated prices = discounted prices
price_treated = price * discount_percentage

user_test_trt, product_test_trt, prices_trt, x_other_products_trt, other_prices_trt = prepare_data(
    X_user_test,
    X_product,
    price_treated
)

utilities_trt = model(
    user_test_trt,
    product_test_trt,
    x_other_products_trt,
    other_prices_trt,
    prices_trt,          # treated prices
    all_product_treated  # all True
)

probabilities_trt = F.softmax(utilities_trt, dim=1)

price_with_outside_trt = torch.cat(
    (torch.zeros(1, device=price.device), prices_trt), dim=0
)

expected_revenue_trt = torch.sum(
    probabilities_trt * price_with_outside_trt.unsqueeze(0).expand_as(probabilities_trt),
    dim=1
).sum()

print(f"Expected Revenue (all treated): ${expected_revenue_trt.item():.2f}")

# --------- GTE ----------
pdl = (expected_revenue_trt - expected_revenue_ctrl).cpu().detach().numpy() * 600 / 266
print(pdl)

pdl_all = abs((pdl - true) / true)
print(pdl_all)
# Out:
# Expected Revenue (all control): $37.84
# Expected Revenue (all treated): $8.41
# -66.38754220833455
# 0.033029361746375246

# %%
# --- split test set by gender (column 1: 1=female, 2=male) ---
male_mask = (X_user_test[:, 1] == 2)
female_mask = (X_user_test[:, 1] == 1)

X_male = X_user_test[male_mask]
X_female = X_user_test[female_mask]

print(f"N_male={X_male.shape[0]}, N_female={X_female.shape[0]}, N_total={X_user_test.shape[0]}")

# --- male/female revenues and GTEs ---
rev_control_male = expected_revenue_for_users(X_male, X_product, price, all_product_control, 1.0)
rev_treated_male  = expected_revenue_for_users(X_male, X_product, price, all_product_treated, discount_percentage)
gte_male = rev_treated_male - rev_control_male

rev_control_female = expected_revenue_for_users(X_female, X_product, price, all_product_control, 1.0)
rev_treated_female  = expected_revenue_for_users(X_female, X_product, price, all_product_treated, discount_percentage)
gte_female = rev_treated_female - rev_control_female

# --- compare to overall ---
gte_male_scaled = (gte_male * 300/38).detach().cpu().numpy()
gte_female_scaled = (gte_female * 300/37).detach().cpu().numpy()

pdl_all_m = abs((gte_male_scaled - true_male)/true_male)
pdl_all_f = abs((gte_female_scaled - true_female)/true_female)

print(pdl_all_m)
print(pdl_all_f)
# Out:
# N_male=38, N_female=37, N_total=133
# 0.07135293444124133
# 0.4872993978288301

# %%
# split test set by phone usage
phone_less_than_2_years_mask = (X_user_test[:, 2] == 1) | (X_user_test[:, 2] == 5)
phone_more_than_2_years_mask = (X_user_test[:, 2] == 2) | (X_user_test[:, 2] == 3) | (X_user_test[:, 2] == 6)

X_phone_less_than_2_years = X_user_test[phone_less_than_2_years_mask]
X_phone_more_than_2_years = X_user_test[phone_more_than_2_years_mask]

print(f"N_phone_less_than_2_years={X_phone_less_than_2_years.shape[0]}, N_phone_more_than_2_years={X_phone_more_than_2_years.shape[0]}, N_total={X_user_test.shape[0]}")

# --- phone usage revenues and GTEs ---
rev_control_phone_less_than_2_years = expected_revenue_for_users(X_phone_less_than_2_years, X_product, price, all_product_control, 1.0)
rev_treated_phone_less_than_2_years  = expected_revenue_for_users(X_phone_less_than_2_years, X_product, price, all_product_treated, discount_percentage)
gte_phone_less_than_2_years = rev_treated_phone_less_than_2_years - rev_control_phone_less_than_2_years

rev_control_phone_more_than_2_years = expected_revenue_for_users(X_phone_more_than_2_years, X_product, price, all_product_control, 1.0)
rev_treated_phone_more_than_2_years  = expected_revenue_for_users(X_phone_more_than_2_years, X_product, price, all_product_treated, discount_percentage)
gte_phone_more_than_2_years = rev_treated_phone_more_than_2_years - rev_control_phone_more_than_2_years

gte_phone_less_than_2_years_scaled = (gte_phone_less_than_2_years * 300/7).detach().cpu().numpy()
gte_phone_more_than_2_years_scaled = (gte_phone_more_than_2_years * 300/50).detach().cpu().numpy()

pdl_all_phone_less_than_2_years = abs((gte_phone_less_than_2_years_scaled - true_phone_less_than_2_years)/true_phone_less_than_2_years)
pdl_all_phone_more_than_2_years = abs((gte_phone_more_than_2_years_scaled - true_phone_more_than_2_years)/true_phone_more_than_2_years)

print(pdl_all_phone_less_than_2_years)
print(pdl_all_phone_more_than_2_years)
# Out:
# N_phone_less_than_2_years=7, N_phone_more_than_2_years=50, N_total=133
# 0.2603890406139076
# 0.35858178234353394

# %% [markdown]
# ## DML Estimator

# %%
def H_theta(theta0_output, theta1_output, all_treated_price, price):
    N = theta0_output.shape[0]
    M = theta0_output.shape[1]
    device = theta0_output.device

    # Utilities
    expand_price = price.unsqueeze(0).expand(N, M)
    expand_all_treated_price = all_treated_price.unsqueeze(0).expand(N, M)
    all_treated_uti = theta0_output + theta1_output * expand_all_treated_price
    all_control_uti =  theta0_output + theta1_output * expand_price

    # Add outside option
    zero_utilities = torch.zeros(N, 1, device=device)
    all_treated_uti = torch.cat((zero_utilities, all_treated_uti), dim=1)
    all_control_uti = torch.cat((zero_utilities, all_control_uti), dim=1)

    # Probabilities
    prob_t = F.softmax(all_treated_uti, dim=1)
    prob_c = F.softmax(all_control_uti, dim=1)

    # Prices with outside option
    p_c = torch.cat((torch.zeros(1, device=device), price), dim=0)
    p_t = torch.cat((torch.zeros(1, device=device), all_treated_price), dim=0)

    # H = Expected Revenue Difference
    H = torch.sum(prob_t * p_t - prob_c * p_c, dim=1)

    # Correct Derivatives using P(1-P)
    grad_t = prob_t * (1 - prob_t)
    grad_c = prob_c * (1 - prob_c)

    H_theta0 = torch.sum(grad_t * p_t - grad_c * p_c, dim=1)
    H_theta1 = torch.sum(grad_t * (p_t**2) - grad_c * (p_c**2), dim=1)

    return H, H_theta0, H_theta1

# %%
# l_theta
def l_theta(theta0_output, theta1_output, adjusted_price, decision_test, l2_lambda=0):
    N = theta0_output.shape[0]
    M = theta0_output.shape[1]

    expand_adjusted_price = adjusted_price.unsqueeze(0).expand(N, M)
    uti = theta0_output + theta1_output * expand_adjusted_price

    zero_utilities = torch.zeros(N, 1, device=uti.device)
    uti_with_outside = torch.cat((zero_utilities, uti), dim=1)

    probabilities = F.softmax(uti_with_outside, dim=1)

    prod_indices = torch.ones(M, device=uti.device)
    prod_indices = torch.cat([torch.zeros(1, device=uti.device), prod_indices])

    adjusted_price_with_outside = torch.cat([torch.zeros(1, device=adjusted_price.device), adjusted_price])

    ltheta0 = probabilities[torch.arange(decision_test.size(0)), decision_test] - prod_indices[decision_test]

    ltheta1 = (probabilities[torch.arange(decision_test.size(0)), decision_test] * adjusted_price_with_outside[decision_test]) - \
              (adjusted_price_with_outside[decision_test] * prod_indices[decision_test])

    is_inside = (decision_test > 0)

    inside_indices = (decision_test - 1).clamp(min=0)

    theta0_chosen = theta0_output.gather(1, inside_indices.unsqueeze(1)).squeeze(1)
    theta1_chosen = theta1_output.gather(1, inside_indices.unsqueeze(1)).squeeze(1)

    reg_grad0 = 2 * l2_lambda * theta0_chosen
    reg_grad1 = 2 * l2_lambda * theta1_chosen

    ltheta0 = ltheta0 + (reg_grad0 * is_inside.float())
    ltheta1 = ltheta1 + (reg_grad1 * is_inside.float())

    return ltheta0, ltheta1

# %%
# l_inv
def lambdainv(theta0_output, theta1_output, price, decision_test, epsilon=1e-6, l2_lambda=0):

    N = theta0_output.shape[0]
    M = num_product

    expand_price = price.unsqueeze(0).expand(N, M)
    expand_all_treated_price = discount_percentage * price.unsqueeze(0).expand(N, M)

    all_treated_uti = theta0_output + theta1_output * expand_all_treated_price
    all_control_uti = theta0_output + theta1_output * expand_price

    zero_utilities = torch.zeros(N, 1, device=all_control_uti.device)
    all_treated_uti = torch.cat((zero_utilities, all_treated_uti), dim=1)
    all_control_uti = torch.cat((zero_utilities, all_control_uti), dim=1)

    probabilities_control = F.softmax(all_control_uti, dim=1)
    probabilities_treated = F.softmax(all_treated_uti, dim=1)

    chosen_prob_control = probabilities_control[torch.arange(N), decision_test]
    chosen_prob_treated = probabilities_treated[torch.arange(N), decision_test]

    price_with_outside = torch.cat((torch.zeros(1, device=price.device), price), dim=0)
    all_treated_price_vec = price * discount_percentage # Assuming logic from original code
    treated_price_with_outside = torch.cat((torch.zeros(1, device=price.device), all_treated_price_vec), dim=0)

    expand_price_ext = price_with_outside.unsqueeze(0).expand(N, M+1)

    chosen_price = expand_price_ext[torch.arange(N), decision_test]

    ltheta00 = chosen_prob_control * (1 - chosen_prob_control) + \
               chosen_prob_treated * (1 - chosen_prob_treated)

    ltheta01 = chosen_prob_control * (1 - chosen_prob_control) * chosen_price + \
               chosen_prob_treated * (1 - chosen_prob_treated) * (chosen_price * discount_percentage)

    ltheta11 = chosen_prob_control * (1 - chosen_prob_control) * (chosen_price**2) + \
               chosen_prob_treated * (1 - chosen_prob_treated) * ((chosen_price * discount_percentage)**2)

    ltheta00 = ltheta00 / 2
    ltheta01 = ltheta01 / 2
    ltheta11 = ltheta11 / 2

    ltheta00 = ltheta00.unsqueeze(1).unsqueeze(2)
    ltheta01 = ltheta01.unsqueeze(1).unsqueeze(2)
    ltheta11 = ltheta11.unsqueeze(1).unsqueeze(2)

    top_row = torch.cat((ltheta00, ltheta01), dim=2)
    bottom_row = torch.cat((ltheta01, ltheta11), dim=2)

    L_matrix = torch.cat((top_row, bottom_row), dim=1) # [N, 2, 2]

    reg_hessian_value = 2 * l2_lambda
    identity_matrix = torch.eye(2, dtype=L_matrix.dtype, device=L_matrix.device)
    reg_matrix = identity_matrix.unsqueeze(0).expand(N, 2, 2) * reg_hessian_value

    L_total = L_matrix + reg_matrix + (identity_matrix.unsqueeze(0) * epsilon)

    L_inv = torch.linalg.inv(L_total)

    return L_inv

# %% [markdown]
# ### No features

# %%
class UtilityEstimator_No(nn.Module):
    def __init__(self, num_product): 
        super(UtilityEstimator_No, self).__init__()
        self.num_product = num_product

        self.theta0 = nn.Parameter(torch.tensor(1.0)) 
        self.theta1 = nn.Parameter(torch.tensor(-1.0)) 

    def forward(self, x_user, x_product, x_other_products, x_other_prices, price):
        """
        price: [M]
        """
        N = x_user.shape[0]
        M = self.num_product

        u_product = self.theta0 + self.theta1 * price 
        
        utilities = u_product.unsqueeze(0).expand(N, -1)
        zero_utilities = torch.zeros(N, 1, device=price.device)
        utilities_with_outside = torch.cat([zero_utilities, utilities], dim=1)


        theta0_expanded = self.theta0.view(1, 1).expand(N, M)
        theta1_expanded = self.theta1.view(1, 1).expand(N, M)

        return utilities_with_outside, theta0_expanded, theta1_expanded

# %%
# Apply the model
dml_model = UtilityEstimator_No(
    num_product=X_product.shape[0]
).to(device)


# Initialize weight
dml_model.apply(init_weights)
# Out:
# UtilityEstimator_No()

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# Train the model
optimizer = torch.optim.Adam(dml_model.parameters(), lr=0.02)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)
l2_lambda = 0
best_val_loss = float('inf')
patience = 5
patience_counter = 0

for epoch in range(1000):
    dml_model.train()  # Set model to training mode
    optimizer.zero_grad()

    outputs = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)[0]
    choice_probabilities = torch.nn.functional.log_softmax(outputs, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])
    l2_norm = sum(param.pow(2.0).sum() for param in dml_model.parameters())
    loss = loss + l2_lambda * l2_norm
    loss.backward()
    optimizer.step()
    scheduler.step()

    # Validation phase
    dml_model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        val_outputs = dml_model(X_user_val, product_features, all_x_other_products, all_other_prices,prices)[0]
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])
    print(f"Epoch {epoch+1}, Training Loss: {loss.item()}, Validation Loss: {val_loss.item()}")
    # Check if validation loss improved
    if (val_loss < best_val_loss)|(val_loss<loss):
        best_val_loss = val_loss
        patience_counter = 0  # Reset counter on improvement
        torch.save(dml_model.state_dict(), 'best_model.pth')  # Save the best model
    else:
        patience_counter += 1  # Increment counter if no improvement

    # Early stopping condition
    if patience_counter >= patience:
        print("Early stopping triggered")
        break
# Out:
# Epoch 1, Training Loss: 2.2338318824768066, Validation Loss: 2.3013393878936768
# Epoch 2, Training Loss: 2.2178454399108887, Validation Loss: 2.2854580879211426
# Epoch 3, Training Loss: 2.2019753456115723, Validation Loss: 2.2696964740753174
# Epoch 4, Training Loss: 2.1862244606018066, Validation Loss: 2.254055976867676
# Epoch 5, Training Loss: 2.17059588432312, Validation Loss: 2.2385404109954834
# Epoch 6, Training Loss: 2.15509295463562, Validation Loss: 2.2231521606445312
# Epoch 7, Training Loss: 2.1397182941436768, Validation Loss: 2.2078936100006104
# Epoch 8, Training Loss: 2.12447452545166, Validation Loss: 2.192767858505249
# Epoch 9, Training Loss: 2.1093645095825195, Validation Loss: 2.177777051925659
# Epoch 10, Training Loss: 2.094391107559204, Validation Loss: 2.162924289703369
# Epoch 11, Training Loss: 2.079557180404663, Validation Loss: 2.1482112407684326
# Epoch 12, Training Loss: 2.0648653507232666, Validation Loss: 2.133640766143799
# Epoch 13, Training Loss: 2.0503172874450684, Validation Loss: 2.119215250015259
# Epoch 14, Training Loss: 2.035916566848755, Validation Loss: 2.104936361312866
# Epoch 15, Training Loss: 2.02166485786438, Validation Loss: 2.090806484222412
# Epoch 16, Training Loss: 2.0075647830963135, Validation Loss: 2.0768277645111084
# Epoch 17, Training Loss: 1.993618130683899, Validation Loss: 2.063001871109009
# Epoch 18, Training Loss: 1.9798274040222168, Validation Loss: 2.049330949783325
# Epoch 19, Training Loss: 1.9661942720413208, Validation Loss: 2.0358164310455322
# Epoch 20, Training Loss: 1.9527205228805542, Validation Loss: 2.0224597454071045
# Epoch 21, Training Loss: 1.939408302307129, Validation Loss: 2.009263277053833
# Epoch 22, Training Loss: 1.926259160041809, Validation Loss: 1.9962278604507446
# Epoch 23, Training Loss: 1.9132746458053589, Validation Loss: 1.9833544492721558
# Epoch 24, Training Loss: 1.9004563093185425, Validation Loss: 1.9706451892852783
# Epoch 25, Training Loss: 1.8878051042556763, Validation Loss: 1.958100438117981
# Epoch 26, Training Loss: 1.8753225803375244, Validation Loss: 1.9457213878631592
# Epoch 27, Training Loss: 1.8630096912384033, Validation Loss: 1.933509111404419
# Epoch 28, Training Loss: 1.8508676290512085, Validation Loss: 1.9214645624160767
# Epoch 29, Training Loss: 1.838897466659546, Validation Loss: 1.9095876216888428
# Epoch 30, Training Loss: 1.8270992040634155, Validation Loss: 1.897879719734192
# Epoch 31, Training Loss: 1.8154743909835815, Validation Loss: 1.8863410949707031
# Epoch 32, Training Loss: 1.804023265838623, Validation Loss: 1.8749719858169556
# Epoch 33, Training Loss: 1.7927463054656982, Validation Loss: 1.8637727499008179
# Epoch 34, Training Loss: 1.7816437482833862, Validation Loss: 1.8527435064315796
# Epoch 35, Training Loss: 1.7707160711288452, Validation Loss: 1.8418840169906616
# Epoch 36, Training Loss: 1.759963035583496, Validation Loss: 1.8311948776245117
# Epoch 37, Training Loss: 1.7493849992752075, Validation Loss: 1.8206756114959717
# Epoch 38, Training Loss: 1.7389816045761108, Validation Loss: 1.8103257417678833
# Epoch 39, Training Loss: 1.728752851486206, Validation Loss: 1.8001452684402466
# Epoch 40, Training Loss: 1.718698501586914, Validation Loss: 1.7901335954666138
# Epoch 41, Training Loss: 1.708817958831787, Validation Loss: 1.7802907228469849
# Epoch 42, Training Loss: 1.6991112232208252, Validation Loss: 1.7706148624420166
# Epoch 43, Training Loss: 1.6895772218704224, Validation Loss: 1.7611064910888672
# Epoch 44, Training Loss: 1.6802152395248413, Validation Loss: 1.751764178276062
# Epoch 45, Training Loss: 1.671025037765503, Validation Loss: 1.7425872087478638
# Epoch 46, Training Loss: 1.6620054244995117, Validation Loss: 1.733574628829956
# Epoch 47, Training Loss: 1.6531553268432617, Validation Loss: 1.7247251272201538
# Epoch 48, Training Loss: 1.6444740295410156, Validation Loss: 1.7160381078720093
# Epoch 49, Training Loss: 1.6359602212905884, Validation Loss: 1.7075121402740479
# Epoch 50, Training Loss: 1.627612829208374, Validation Loss: 1.6991456747055054
# Epoch 51, Training Loss: 1.6194305419921875, Validation Loss: 1.6909376382827759
# Epoch 52, Training Loss: 1.6114121675491333, Validation Loss: 1.6828863620758057
# Epoch 53, Training Loss: 1.6035560369491577, Validation Loss: 1.6749907732009888
# Epoch 54, Training Loss: 1.5958606004714966, Validation Loss: 1.667249083518982
# Epoch 55, Training Loss: 1.588324785232544, Validation Loss: 1.6596593856811523
# Epoch 56, Training Loss: 1.580946683883667, Validation Loss: 1.6522204875946045
# Epoch 57, Training Loss: 1.5737242698669434, Validation Loss: 1.6449302434921265
# Epoch 58, Training Loss: 1.5666567087173462, Validation Loss: 1.6377872228622437
# Epoch 59, Training Loss: 1.5597412586212158, Validation Loss: 1.6307893991470337
# Epoch 60, Training Loss: 1.5529766082763672, Validation Loss: 1.6239347457885742
# Epoch 61, Training Loss: 1.5463606119155884, Validation Loss: 1.617221474647522
# Epoch 62, Training Loss: 1.5398913621902466, Validation Loss: 1.610647439956665
# Epoch 63, Training Loss: 1.533566951751709, Validation Loss: 1.6042108535766602
# Epoch 64, Training Loss: 1.5273853540420532, Validation Loss: 1.5979095697402954
# Epoch 65, Training Loss: 1.5213443040847778, Validation Loss: 1.5917413234710693
# Epoch 66, Training Loss: 1.515442132949829, Validation Loss: 1.5857042074203491
# Epoch 67, Training Loss: 1.5096760988235474, Validation Loss: 1.5797959566116333
# Epoch 68, Training Loss: 1.5040442943572998, Validation Loss: 1.5740145444869995
# Epoch 69, Training Loss: 1.498544692993164, Validation Loss: 1.5683571100234985
# Epoch 70, Training Loss: 1.4931745529174805, Validation Loss: 1.5628222227096558
# Epoch 71, Training Loss: 1.4879320859909058, Validation Loss: 1.5574074983596802
# Epoch 72, Training Loss: 1.4828150272369385, Validation Loss: 1.5521100759506226
# Epoch 73, Training Loss: 1.4778207540512085, Validation Loss: 1.5469284057617188
# Epoch 74, Training Loss: 1.4729472398757935, Validation Loss: 1.5418598651885986
# Epoch 75, Training Loss: 1.4681919813156128, Validation Loss: 1.5369020700454712
# Epoch 76, Training Loss: 1.4635528326034546, Validation Loss: 1.532052755355835
# Epoch 77, Training Loss: 1.4590270519256592, Validation Loss: 1.5273100137710571
# Epoch 78, Training Loss: 1.4546129703521729, Validation Loss: 1.522670865058899
# Epoch 79, Training Loss: 1.4503077268600464, Validation Loss: 1.5181337594985962
# Epoch 80, Training Loss: 1.4461092948913574, Validation Loss: 1.5136957168579102
# Epoch 81, Training Loss: 1.4420150518417358, Validation Loss: 1.5093547105789185
# Epoch 82, Training Loss: 1.4380227327346802, Validation Loss: 1.5051087141036987
# Epoch 83, Training Loss: 1.4341305494308472, Validation Loss: 1.50095534324646
# Epoch 84, Training Loss: 1.430335521697998, Validation Loss: 1.4968920946121216
# Epoch 85, Training Loss: 1.4266353845596313, Validation Loss: 1.4929171800613403
# Epoch 86, Training Loss: 1.4230284690856934, Validation Loss: 1.4890282154083252
# Epoch 87, Training Loss: 1.419512152671814, Validation Loss: 1.4852226972579956
# Epoch 88, Training Loss: 1.4160841703414917, Validation Loss: 1.4814989566802979
# Epoch 89, Training Loss: 1.4127424955368042, Validation Loss: 1.477854609489441
# Epoch 90, Training Loss: 1.4094847440719604, Validation Loss: 1.4742873907089233
# Epoch 91, Training Loss: 1.406308889389038, Validation Loss: 1.4707956314086914
# Epoch 92, Training Loss: 1.4032124280929565, Validation Loss: 1.467376708984375
# Epoch 93, Training Loss: 1.4001939296722412, Validation Loss: 1.4640291929244995
# Epoch 94, Training Loss: 1.397250771522522, Validation Loss: 1.4607508182525635
# Epoch 95, Training Loss: 1.3943809270858765, Validation Loss: 1.4575395584106445
# Epoch 96, Training Loss: 1.3915828466415405, Validation Loss: 1.4543935060501099
# Epoch 97, Training Loss: 1.3888542652130127, Validation Loss: 1.4513108730316162
# Epoch 98, Training Loss: 1.386193037033081, Validation Loss: 1.4482896327972412
# Epoch 99, Training Loss: 1.3835972547531128, Validation Loss: 1.445327877998352
# Epoch 100, Training Loss: 1.3810652494430542, Validation Loss: 1.4424241781234741
# Epoch 101, Training Loss: 1.3785953521728516, Validation Loss: 1.4395767450332642
# Epoch 102, Training Loss: 1.3761852979660034, Validation Loss: 1.4367834329605103
# Epoch 103, Training Loss: 1.373833417892456, Validation Loss: 1.434043049812317
# Epoch 104, Training Loss: 1.3715381622314453, Validation Loss: 1.4313534498214722
# Epoch 105, Training Loss: 1.369297742843628, Validation Loss: 1.4287136793136597
# Epoch 106, Training Loss: 1.3671104907989502, Validation Loss: 1.4261215925216675
# Epoch 107, Training Loss: 1.3649747371673584, Validation Loss: 1.423575758934021
# Epoch 108, Training Loss: 1.362889051437378, Validation Loss: 1.4210748672485352
# Epoch 109, Training Loss: 1.360851526260376, Validation Loss: 1.4186174869537354
# Epoch 110, Training Loss: 1.358860969543457, Validation Loss: 1.416202187538147
# Epoch 111, Training Loss: 1.3569159507751465, Validation Loss: 1.4138271808624268
# Epoch 112, Training Loss: 1.355014443397522, Validation Loss: 1.4114917516708374
# Epoch 113, Training Loss: 1.3531559705734253, Validation Loss: 1.4091941118240356
# Epoch 114, Training Loss: 1.351338505744934, Validation Loss: 1.4069334268569946
# Epoch 115, Training Loss: 1.3495608568191528, Validation Loss: 1.404707908630371
# Epoch 116, Training Loss: 1.3478219509124756, Validation Loss: 1.4025167226791382
# Epoch 117, Training Loss: 1.3461201190948486, Validation Loss: 1.4003589153289795
# Epoch 118, Training Loss: 1.344454288482666, Validation Loss: 1.39823317527771
# Epoch 119, Training Loss: 1.3428237438201904, Validation Loss: 1.396138072013855
# Epoch 120, Training Loss: 1.3412268161773682, Validation Loss: 1.394073247909546
# Epoch 121, Training Loss: 1.3396624326705933, Validation Loss: 1.392037034034729
# Epoch 122, Training Loss: 1.3381296396255493, Validation Loss: 1.390028715133667
# Epoch 123, Training Loss: 1.3366273641586304, Validation Loss: 1.3880473375320435
# Epoch 124, Training Loss: 1.3351545333862305, Validation Loss: 1.386091947555542
# Epoch 125, Training Loss: 1.3337103128433228, Validation Loss: 1.3841618299484253
# Epoch 126, Training Loss: 1.3322937488555908, Validation Loss: 1.3822557926177979
# Epoch 127, Training Loss: 1.3309037685394287, Validation Loss: 1.3803733587265015
# Epoch 128, Training Loss: 1.32953941822052, Validation Loss: 1.3785135746002197
# Epoch 129, Training Loss: 1.328200340270996, Validation Loss: 1.3766758441925049
# Epoch 130, Training Loss: 1.3268849849700928, Validation Loss: 1.3748589754104614
# Epoch 131, Training Loss: 1.3255929946899414, Validation Loss: 1.3730629682540894
# Epoch 132, Training Loss: 1.3243236541748047, Validation Loss: 1.371286392211914
# Epoch 133, Training Loss: 1.3230760097503662, Validation Loss: 1.369529366493225
# Epoch 134, Training Loss: 1.3218495845794678, Validation Loss: 1.3677904605865479
# Epoch 135, Training Loss: 1.3206433057785034, Validation Loss: 1.3660695552825928
# Epoch 136, Training Loss: 1.319456696510315, Validation Loss: 1.3643659353256226
# Epoch 137, Training Loss: 1.3182893991470337, Validation Loss: 1.3626792430877686
# Epoch 138, Training Loss: 1.3171403408050537, Validation Loss: 1.3610085248947144
# Epoch 139, Training Loss: 1.316009283065796, Validation Loss: 1.35935378074646
# Epoch 140, Training Loss: 1.3148952722549438, Validation Loss: 1.357714295387268
# Epoch 141, Training Loss: 1.313798189163208, Validation Loss: 1.3560892343521118
# Epoch 142, Training Loss: 1.312717318534851, Validation Loss: 1.3544787168502808
# Epoch 143, Training Loss: 1.3116519451141357, Validation Loss: 1.3528821468353271
# Epoch 144, Training Loss: 1.310601830482483, Validation Loss: 1.3512990474700928
# Epoch 145, Training Loss: 1.3095667362213135, Validation Loss: 1.3497289419174194
# Epoch 146, Training Loss: 1.308545708656311, Validation Loss: 1.3481718301773071
# Epoch 147, Training Loss: 1.307538628578186, Validation Loss: 1.346626877784729
# Epoch 148, Training Loss: 1.3065450191497803, Validation Loss: 1.345094084739685
# Epoch 149, Training Loss: 1.3055644035339355, Validation Loss: 1.343572974205017
# Epoch 150, Training Loss: 1.3045965433120728, Validation Loss: 1.342063307762146
# Epoch 151, Training Loss: 1.3036409616470337, Validation Loss: 1.3405647277832031
# Epoch 152, Training Loss: 1.3026973009109497, Validation Loss: 1.3390769958496094
# Epoch 153, Training Loss: 1.3017655611038208, Validation Loss: 1.3375999927520752
# Epoch 154, Training Loss: 1.3008449077606201, Validation Loss: 1.3361331224441528
# Epoch 155, Training Loss: 1.299935221672058, Validation Loss: 1.334676742553711
# Epoch 156, Training Loss: 1.2990365028381348, Validation Loss: 1.3332297801971436
# Epoch 157, Training Loss: 1.2981481552124023, Validation Loss: 1.3317927122116089
# Epoch 158, Training Loss: 1.2972698211669922, Validation Loss: 1.3303650617599487
# Epoch 159, Training Loss: 1.2964016199111938, Validation Loss: 1.328946828842163
# Epoch 160, Training Loss: 1.2955433130264282, Validation Loss: 1.3275375366210938
# Epoch 161, Training Loss: 1.294694185256958, Validation Loss: 1.3261373043060303
# Epoch 162, Training Loss: 1.2938542366027832, Validation Loss: 1.324745774269104
# Epoch 163, Training Loss: 1.2930235862731934, Validation Loss: 1.323362946510315
# Epoch 164, Training Loss: 1.2922016382217407, Validation Loss: 1.3219884634017944
# Epoch 165, Training Loss: 1.2913882732391357, Validation Loss: 1.3206225633621216
# Epoch 166, Training Loss: 1.2905834913253784, Validation Loss: 1.3192646503448486
# Epoch 167, Training Loss: 1.2897870540618896, Validation Loss: 1.3179150819778442
# Epoch 168, Training Loss: 1.2889986038208008, Validation Loss: 1.3165733814239502
# Epoch 169, Training Loss: 1.2882182598114014, Validation Loss: 1.315239667892456
# Epoch 170, Training Loss: 1.2874456644058228, Validation Loss: 1.3139135837554932
# Epoch 171, Training Loss: 1.2866806983947754, Validation Loss: 1.3125953674316406
# Epoch 172, Training Loss: 1.2859233617782593, Validation Loss: 1.3112847805023193
# Epoch 173, Training Loss: 1.2851734161376953, Validation Loss: 1.3099815845489502
# Epoch 174, Training Loss: 1.284430742263794, Validation Loss: 1.3086861371994019
# Epoch 175, Training Loss: 1.2836952209472656, Validation Loss: 1.3073979616165161
# Epoch 176, Training Loss: 1.2829667329788208, Validation Loss: 1.306117057800293
# Epoch 177, Training Loss: 1.2822452783584595, Validation Loss: 1.304843544960022
# Epoch 178, Training Loss: 1.281530499458313, Validation Loss: 1.3035774230957031
# Epoch 179, Training Loss: 1.2808228731155396, Validation Loss: 1.3023182153701782
# Epoch 180, Training Loss: 1.2801214456558228, Validation Loss: 1.3010660409927368
# Epoch 181, Training Loss: 1.2794269323349, Validation Loss: 1.299821138381958
# Epoch 182, Training Loss: 1.2787386178970337, Validation Loss: 1.2985831499099731
# Epoch 183, Training Loss: 1.2780567407608032, Validation Loss: 1.2973521947860718
# Epoch 184, Training Loss: 1.2773813009262085, Validation Loss: 1.2961283922195435
# Epoch 185, Training Loss: 1.2767120599746704, Validation Loss: 1.294911503791809
# Epoch 186, Training Loss: 1.276049017906189, Validation Loss: 1.293701410293579
# Epoch 187, Training Loss: 1.2753921747207642, Validation Loss: 1.292498230934143
# Epoch 188, Training Loss: 1.2747411727905273, Validation Loss: 1.2913017272949219
# Epoch 189, Training Loss: 1.2740964889526367, Validation Loss: 1.2901123762130737
# Epoch 190, Training Loss: 1.2734575271606445, Validation Loss: 1.2889297008514404
# Epoch 191, Training Loss: 1.2728244066238403, Validation Loss: 1.287753939628601
# Epoch 192, Training Loss: 1.2721971273422241, Validation Loss: 1.286584734916687
# Epoch 193, Training Loss: 1.271575689315796, Validation Loss: 1.285422444343567
# Epoch 194, Training Loss: 1.2709598541259766, Validation Loss: 1.2842665910720825
# Epoch 195, Training Loss: 1.2703496217727661, Validation Loss: 1.2831178903579712
# Epoch 196, Training Loss: 1.269745111465454, Validation Loss: 1.2819757461547852
# Epoch 197, Training Loss: 1.269146203994751, Validation Loss: 1.280840277671814
# Epoch 198, Training Loss: 1.2685528993606567, Validation Loss: 1.2797116041183472
# Epoch 199, Training Loss: 1.2679649591445923, Validation Loss: 1.2785894870758057
# Epoch 200, Training Loss: 1.2673826217651367, Validation Loss: 1.2774741649627686
# Epoch 201, Training Loss: 1.2668054103851318, Validation Loss: 1.2763652801513672
# Epoch 202, Training Loss: 1.2662338018417358, Validation Loss: 1.2752631902694702
# Epoch 203, Training Loss: 1.26566743850708, Validation Loss: 1.274167776107788
# Epoch 204, Training Loss: 1.265106439590454, Validation Loss: 1.2730789184570312
# Epoch 205, Training Loss: 1.2645505666732788, Validation Loss: 1.2719967365264893
# Epoch 206, Training Loss: 1.2639998197555542, Validation Loss: 1.270920991897583
# Epoch 207, Training Loss: 1.2634546756744385, Validation Loss: 1.2698522806167603
# Epoch 208, Training Loss: 1.2629142999649048, Validation Loss: 1.2687898874282837
# Epoch 209, Training Loss: 1.26237952709198, Validation Loss: 1.267734169960022
# Epoch 210, Training Loss: 1.261849284172058, Validation Loss: 1.2666847705841064
# Epoch 211, Training Loss: 1.2613242864608765, Validation Loss: 1.2656422853469849
# Epoch 212, Training Loss: 1.260804533958435, Validation Loss: 1.2646063566207886
# Epoch 213, Training Loss: 1.2602897882461548, Validation Loss: 1.2635767459869385
# Epoch 214, Training Loss: 1.2597795724868774, Validation Loss: 1.2625539302825928
# Epoch 215, Training Loss: 1.2592746019363403, Validation Loss: 1.2615375518798828
# Epoch 216, Training Loss: 1.2587743997573853, Validation Loss: 1.2605276107788086
# Epoch 217, Training Loss: 1.2582792043685913, Validation Loss: 1.2595243453979492
# Epoch 218, Training Loss: 1.2577886581420898, Validation Loss: 1.258527398109436
# Epoch 219, Training Loss: 1.2573028802871704, Validation Loss: 1.2575372457504272
# Epoch 220, Training Loss: 1.2568223476409912, Validation Loss: 1.2565534114837646
# Epoch 221, Training Loss: 1.2563461065292358, Validation Loss: 1.2555761337280273
# Epoch 222, Training Loss: 1.2558748722076416, Validation Loss: 1.2546051740646362
# Epoch 223, Training Loss: 1.2554081678390503, Validation Loss: 1.2536407709121704
# Epoch 224, Training Loss: 1.254946231842041, Validation Loss: 1.2526825666427612
# Epoch 225, Training Loss: 1.2544888257980347, Validation Loss: 1.2517311573028564
# Epoch 226, Training Loss: 1.2540360689163208, Validation Loss: 1.2507860660552979
# Epoch 227, Training Loss: 1.2535878419876099, Validation Loss: 1.249847412109375
# Epoch 228, Training Loss: 1.253144383430481, Validation Loss: 1.2489148378372192
# Epoch 229, Training Loss: 1.2527049779891968, Validation Loss: 1.2479889392852783
# Epoch 230, Training Loss: 1.2522704601287842, Validation Loss: 1.2470693588256836
# Epoch 231, Training Loss: 1.2518402338027954, Validation Loss: 1.2461559772491455
# Epoch 232, Training Loss: 1.2514145374298096, Validation Loss: 1.2452490329742432
# Epoch 233, Training Loss: 1.250993251800537, Validation Loss: 1.2443482875823975
# Epoch 234, Training Loss: 1.2505762577056885, Validation Loss: 1.2434539794921875
# Epoch 235, Training Loss: 1.2501634359359741, Validation Loss: 1.2425659894943237
# Epoch 236, Training Loss: 1.2497552633285522, Validation Loss: 1.2416839599609375
# Epoch 237, Training Loss: 1.249351143836975, Validation Loss: 1.240808367729187
# Epoch 238, Training Loss: 1.2489513158798218, Validation Loss: 1.2399389743804932
# Epoch 239, Training Loss: 1.2485558986663818, Validation Loss: 1.2390756607055664
# Epoch 240, Training Loss: 1.2481642961502075, Validation Loss: 1.2382185459136963
# Epoch 241, Training Loss: 1.2477772235870361, Validation Loss: 1.237367868423462
# Epoch 242, Training Loss: 1.2473942041397095, Validation Loss: 1.2365227937698364
# Epoch 243, Training Loss: 1.2470149993896484, Validation Loss: 1.2356842756271362
# Epoch 244, Training Loss: 1.2466402053833008, Validation Loss: 1.234851598739624
# Epoch 245, Training Loss: 1.2462693452835083, Validation Loss: 1.234025001525879
# Epoch 246, Training Loss: 1.245902419090271, Validation Loss: 1.2332044839859009
# Epoch 247, Training Loss: 1.2455393075942993, Validation Loss: 1.2323896884918213
# Epoch 248, Training Loss: 1.245180368423462, Validation Loss: 1.2315810918807983
# Epoch 249, Training Loss: 1.2448253631591797, Validation Loss: 1.2307785749435425
# Epoch 250, Training Loss: 1.2444742918014526, Validation Loss: 1.229981780052185
# Epoch 251, Training Loss: 1.2441269159317017, Validation Loss: 1.2291909456253052
# Epoch 252, Training Loss: 1.2437833547592163, Validation Loss: 1.2284060716629028
# Epoch 253, Training Loss: 1.2434438467025757, Validation Loss: 1.2276270389556885
# Epoch 254, Training Loss: 1.2431079149246216, Validation Loss: 1.226853609085083
# Epoch 255, Training Loss: 1.2427756786346436, Validation Loss: 1.2260863780975342
# Epoch 256, Training Loss: 1.2424472570419312, Validation Loss: 1.2253246307373047
# Epoch 257, Training Loss: 1.2421224117279053, Validation Loss: 1.224568486213684
# Epoch 258, Training Loss: 1.2418010234832764, Validation Loss: 1.2238184213638306
# Epoch 259, Training Loss: 1.2414838075637817, Validation Loss: 1.2230738401412964
# Epoch 260, Training Loss: 1.2411696910858154, Validation Loss: 1.222334861755371
# Epoch 261, Training Loss: 1.2408593893051147, Validation Loss: 1.2216014862060547
# Epoch 262, Training Loss: 1.2405524253845215, Validation Loss: 1.2208738327026367
# Epoch 263, Training Loss: 1.2402490377426147, Validation Loss: 1.220151662826538
# Epoch 264, Training Loss: 1.239949107170105, Validation Loss: 1.2194349765777588
# Epoch 265, Training Loss: 1.2396526336669922, Validation Loss: 1.2187236547470093
# Epoch 266, Training Loss: 1.2393593788146973, Validation Loss: 1.2180181741714478
# Epoch 267, Training Loss: 1.2390697002410889, Validation Loss: 1.217317819595337
# Epoch 268, Training Loss: 1.2387832403182983, Validation Loss: 1.2166231870651245
# Epoch 269, Training Loss: 1.2385001182556152, Validation Loss: 1.2159335613250732
# Epoch 270, Training Loss: 1.23822021484375, Validation Loss: 1.2152494192123413
# Epoch 271, Training Loss: 1.2379437685012817, Validation Loss: 1.2145706415176392
# Epoch 272, Training Loss: 1.2376705408096313, Validation Loss: 1.2138971090316772
# Epoch 273, Training Loss: 1.2374002933502197, Validation Loss: 1.2132288217544556
# Epoch 274, Training Loss: 1.2371333837509155, Validation Loss: 1.2125657796859741
# Epoch 275, Training Loss: 1.23686945438385, Validation Loss: 1.2119081020355225
# Epoch 276, Training Loss: 1.236608862876892, Validation Loss: 1.2112551927566528
# Epoch 277, Training Loss: 1.2363508939743042, Validation Loss: 1.2106075286865234
# Epoch 278, Training Loss: 1.2360962629318237, Validation Loss: 1.2099649906158447
# Epoch 279, Training Loss: 1.235844612121582, Validation Loss: 1.2093275785446167
# Epoch 280, Training Loss: 1.235595941543579, Validation Loss: 1.2086951732635498
# Epoch 281, Training Loss: 1.235350251197815, Validation Loss: 1.208067774772644
# Epoch 282, Training Loss: 1.2351075410842896, Validation Loss: 1.2074451446533203
# Epoch 283, Training Loss: 1.2348676919937134, Validation Loss: 1.2068277597427368
# Epoch 284, Training Loss: 1.2346305847167969, Validation Loss: 1.2062150239944458
# Epoch 285, Training Loss: 1.2343965768814087, Validation Loss: 1.2056071758270264
# Epoch 286, Training Loss: 1.2341651916503906, Validation Loss: 1.205004096031189
# Epoch 287, Training Loss: 1.2339366674423218, Validation Loss: 1.2044059038162231
# Epoch 288, Training Loss: 1.2337108850479126, Validation Loss: 1.203812599182129
# Epoch 289, Training Loss: 1.233487844467163, Validation Loss: 1.2032238245010376
# Epoch 290, Training Loss: 1.2332675457000732, Validation Loss: 1.2026399374008179
# Epoch 291, Training Loss: 1.233049750328064, Validation Loss: 1.2020604610443115
# Epoch 292, Training Loss: 1.232835054397583, Validation Loss: 1.201485514640808
# Epoch 293, Training Loss: 1.2326222658157349, Validation Loss: 1.2009155750274658
# Epoch 294, Training Loss: 1.2324128150939941, Validation Loss: 1.2003499269485474
# Epoch 295, Training Loss: 1.2322053909301758, Validation Loss: 1.1997889280319214
# Epoch 296, Training Loss: 1.2320008277893066, Validation Loss: 1.1992324590682983
# Epoch 297, Training Loss: 1.231798529624939, Validation Loss: 1.1986805200576782
# Epoch 298, Training Loss: 1.231598973274231, Validation Loss: 1.198132872581482
# Epoch 299, Training Loss: 1.231401801109314, Validation Loss: 1.197589635848999
# Epoch 300, Training Loss: 1.2312068939208984, Validation Loss: 1.1970508098602295
# Epoch 301, Training Loss: 1.231014609336853, Validation Loss: 1.1965161561965942
# Epoch 302, Training Loss: 1.230824589729309, Validation Loss: 1.195986032485962
# Epoch 303, Training Loss: 1.2306369543075562, Validation Loss: 1.1954602003097534
# Epoch 304, Training Loss: 1.2304518222808838, Validation Loss: 1.1949384212493896
# Epoch 305, Training Loss: 1.2302687168121338, Validation Loss: 1.1944209337234497
# Epoch 306, Training Loss: 1.230088233947754, Validation Loss: 1.1939077377319336
# Epoch 307, Training Loss: 1.229909896850586, Validation Loss: 1.1933985948562622
# Epoch 308, Training Loss: 1.2297337055206299, Validation Loss: 1.192893624305725
# Epoch 309, Training Loss: 1.2295597791671753, Validation Loss: 1.1923925876617432
# Epoch 310, Training Loss: 1.2293879985809326, Validation Loss: 1.1918957233428955
# Epoch 311, Training Loss: 1.2292184829711914, Validation Loss: 1.1914030313491821
# Epoch 312, Training Loss: 1.229051113128662, Validation Loss: 1.1909141540527344
# Epoch 313, Training Loss: 1.2288856506347656, Validation Loss: 1.1904293298721313
# Epoch 314, Training Loss: 1.2287224531173706, Validation Loss: 1.1899484395980835
# Epoch 315, Training Loss: 1.228561520576477, Validation Loss: 1.1894713640213013
# Epoch 316, Training Loss: 1.2284022569656372, Validation Loss: 1.1889981031417847
# Epoch 317, Training Loss: 1.2282453775405884, Validation Loss: 1.1885287761688232
# Epoch 318, Training Loss: 1.2280902862548828, Validation Loss: 1.1880635023117065
# Epoch 319, Training Loss: 1.2279373407363892, Validation Loss: 1.1876018047332764
# Epoch 320, Training Loss: 1.2277860641479492, Validation Loss: 1.1871435642242432
# Epoch 321, Training Loss: 1.2276370525360107, Validation Loss: 1.1866896152496338
# Epoch 322, Training Loss: 1.2274898290634155, Validation Loss: 1.1862391233444214
# Epoch 323, Training Loss: 1.2273443937301636, Validation Loss: 1.185792088508606
# Epoch 324, Training Loss: 1.2272011041641235, Validation Loss: 1.1853488683700562
# Epoch 325, Training Loss: 1.227059245109558, Validation Loss: 1.184909462928772
# Epoch 326, Training Loss: 1.2269197702407837, Validation Loss: 1.1844733953475952
# Epoch 327, Training Loss: 1.2267817258834839, Validation Loss: 1.184040904045105
# Epoch 328, Training Loss: 1.226645588874817, Validation Loss: 1.1836119890213013
# Epoch 329, Training Loss: 1.2265112400054932, Validation Loss: 1.183186650276184
# Epoch 330, Training Loss: 1.2263784408569336, Validation Loss: 1.1827646493911743
# Epoch 331, Training Loss: 1.2262476682662964, Validation Loss: 1.1823463439941406
# Epoch 332, Training Loss: 1.226118564605713, Validation Loss: 1.1819311380386353
# Epoch 333, Training Loss: 1.2259910106658936, Validation Loss: 1.1815192699432373
# Epoch 334, Training Loss: 1.2258652448654175, Validation Loss: 1.1811110973358154
# Epoch 335, Training Loss: 1.2257411479949951, Validation Loss: 1.1807060241699219
# Epoch 336, Training Loss: 1.2256183624267578, Validation Loss: 1.1803042888641357
# Epoch 337, Training Loss: 1.2254976034164429, Validation Loss: 1.179905891418457
# Epoch 338, Training Loss: 1.225378155708313, Validation Loss: 1.1795109510421753
# Epoch 339, Training Loss: 1.2252604961395264, Validation Loss: 1.1791188716888428
# Epoch 340, Training Loss: 1.2251441478729248, Validation Loss: 1.1787303686141968
# Epoch 341, Training Loss: 1.225029706954956, Validation Loss: 1.1783446073532104
# Epoch 342, Training Loss: 1.2249165773391724, Validation Loss: 1.1779624223709106
# Epoch 343, Training Loss: 1.2248048782348633, Validation Loss: 1.1775833368301392
# Epoch 344, Training Loss: 1.224695086479187, Validation Loss: 1.177207112312317
# Epoch 345, Training Loss: 1.2245862483978271, Validation Loss: 1.176833987236023
# Epoch 346, Training Loss: 1.224478840827942, Validation Loss: 1.1764640808105469
# Epoch 347, Training Loss: 1.2243733406066895, Validation Loss: 1.1760971546173096
# Epoch 348, Training Loss: 1.2242687940597534, Validation Loss: 1.1757333278656006
# Epoch 349, Training Loss: 1.224165916442871, Validation Loss: 1.1753721237182617
# Epoch 350, Training Loss: 1.2240644693374634, Validation Loss: 1.1750143766403198
# Epoch 351, Training Loss: 1.2239640951156616, Validation Loss: 1.174659013748169
# Epoch 352, Training Loss: 1.2238653898239136, Validation Loss: 1.1743069887161255
# Epoch 353, Training Loss: 1.223767876625061, Validation Loss: 1.1739575862884521
# Epoch 354, Training Loss: 1.223671555519104, Validation Loss: 1.1736112833023071
# Epoch 355, Training Loss: 1.2235767841339111, Validation Loss: 1.1732676029205322
# Epoch 356, Training Loss: 1.2234832048416138, Validation Loss: 1.1729270219802856
# Epoch 357, Training Loss: 1.223390817642212, Validation Loss: 1.1725890636444092
# Epoch 358, Training Loss: 1.2232997417449951, Validation Loss: 1.1722538471221924
# Epoch 359, Training Loss: 1.2232099771499634, Validation Loss: 1.1719214916229248
# Epoch 360, Training Loss: 1.2231214046478271, Validation Loss: 1.1715917587280273
# Epoch 361, Training Loss: 1.2230340242385864, Validation Loss: 1.1712646484375
# Epoch 362, Training Loss: 1.222947597503662, Validation Loss: 1.1709402799606323
# Epoch 363, Training Loss: 1.2228626012802124, Validation Loss: 1.1706187725067139
# Epoch 364, Training Loss: 1.2227787971496582, Validation Loss: 1.1702996492385864
# Epoch 365, Training Loss: 1.2226961851119995, Validation Loss: 1.1699832677841187
# Epoch 366, Training Loss: 1.2226144075393677, Validation Loss: 1.1696693897247314
# Epoch 367, Training Loss: 1.2225341796875, Validation Loss: 1.1693581342697144
# Epoch 368, Training Loss: 1.2224546670913696, Validation Loss: 1.1690493822097778
# Epoch 369, Training Loss: 1.2223763465881348, Validation Loss: 1.168743371963501
# Epoch 370, Training Loss: 1.2222992181777954, Validation Loss: 1.1684398651123047
# Epoch 371, Training Loss: 1.2222232818603516, Validation Loss: 1.1681386232376099
# Epoch 372, Training Loss: 1.222148060798645, Validation Loss: 1.1678400039672852
# Epoch 373, Training Loss: 1.2220741510391235, Validation Loss: 1.1675440073013306
# Epoch 374, Training Loss: 1.222001314163208, Validation Loss: 1.1672499179840088
# Epoch 375, Training Loss: 1.2219290733337402, Validation Loss: 1.1669586896896362
# Epoch 376, Training Loss: 1.221858263015747, Validation Loss: 1.1666698455810547
# Epoch 377, Training Loss: 1.2217884063720703, Validation Loss: 1.166383147239685
# Epoch 378, Training Loss: 1.2217192649841309, Validation Loss: 1.166098952293396
# Epoch 379, Training Loss: 1.221651315689087, Validation Loss: 1.1658170223236084
# Epoch 380, Training Loss: 1.221584439277649, Validation Loss: 1.1655375957489014
# Epoch 381, Training Loss: 1.2215181589126587, Validation Loss: 1.1652601957321167
# Epoch 382, Training Loss: 1.2214529514312744, Validation Loss: 1.1649854183197021
# Epoch 383, Training Loss: 1.2213886976242065, Validation Loss: 1.1647125482559204
# Epoch 384, Training Loss: 1.2213252782821655, Validation Loss: 1.1644420623779297
# Epoch 385, Training Loss: 1.221262812614441, Validation Loss: 1.1641738414764404
# Epoch 386, Training Loss: 1.2212013006210327, Validation Loss: 1.1639078855514526
# Epoch 387, Training Loss: 1.221140742301941, Validation Loss: 1.1636438369750977
# Epoch 388, Training Loss: 1.2210806608200073, Validation Loss: 1.1633819341659546
# Epoch 389, Training Loss: 1.2210216522216797, Validation Loss: 1.1631224155426025
# Epoch 390, Training Loss: 1.220963478088379, Validation Loss: 1.1628650426864624
# Epoch 391, Training Loss: 1.2209060192108154, Validation Loss: 1.1626096963882446
# Epoch 392, Training Loss: 1.2208493947982788, Validation Loss: 1.1623564958572388
# Epoch 393, Training Loss: 1.2207937240600586, Validation Loss: 1.1621054410934448
# Epoch 394, Training Loss: 1.2207388877868652, Validation Loss: 1.1618562936782837
# Epoch 395, Training Loss: 1.22068452835083, Validation Loss: 1.161609411239624
# Epoch 396, Training Loss: 1.2206313610076904, Validation Loss: 1.1613644361495972
# Epoch 397, Training Loss: 1.2205787897109985, Validation Loss: 1.1611213684082031
# Epoch 398, Training Loss: 1.2205268144607544, Validation Loss: 1.160880446434021
# Epoch 399, Training Loss: 1.220475673675537, Validation Loss: 1.1606415510177612
# Epoch 400, Training Loss: 1.2204253673553467, Validation Loss: 1.1604044437408447
# Epoch 401, Training Loss: 1.220375657081604, Validation Loss: 1.1601696014404297
# Epoch 402, Training Loss: 1.2203267812728882, Validation Loss: 1.159936547279358
# Epoch 403, Training Loss: 1.2202786207199097, Validation Loss: 1.1597052812576294
# Epoch 404, Training Loss: 1.220231056213379, Validation Loss: 1.1594759225845337
# Epoch 405, Training Loss: 1.2201842069625854, Validation Loss: 1.1592483520507812
# Epoch 406, Training Loss: 1.2201379537582397, Validation Loss: 1.1590230464935303
# Epoch 407, Training Loss: 1.220092535018921, Validation Loss: 1.158799409866333
# Epoch 408, Training Loss: 1.220047950744629, Validation Loss: 1.158577561378479
# Epoch 409, Training Loss: 1.2200034856796265, Validation Loss: 1.1583576202392578
# Epoch 410, Training Loss: 1.2199599742889404, Validation Loss: 1.1581393480300903
# Epoch 411, Training Loss: 1.2199169397354126, Validation Loss: 1.1579229831695557
# Epoch 412, Training Loss: 1.2198747396469116, Validation Loss: 1.1577084064483643
# Epoch 413, Training Loss: 1.2198331356048584, Validation Loss: 1.1574956178665161
# Epoch 414, Training Loss: 1.2197922468185425, Validation Loss: 1.1572844982147217
# Epoch 415, Training Loss: 1.2197514772415161, Validation Loss: 1.157075047492981
# Epoch 416, Training Loss: 1.2197116613388062, Validation Loss: 1.1568676233291626
# Epoch 417, Training Loss: 1.2196725606918335, Validation Loss: 1.156661868095398
# Epoch 418, Training Loss: 1.219633936882019, Validation Loss: 1.156457543373108
# Epoch 419, Training Loss: 1.2195956707000732, Validation Loss: 1.1562548875808716
# Epoch 420, Training Loss: 1.2195581197738647, Validation Loss: 1.156053900718689
# Epoch 421, Training Loss: 1.2195210456848145, Validation Loss: 1.1558549404144287
# Epoch 422, Training Loss: 1.219484567642212, Validation Loss: 1.1556575298309326
# Epoch 423, Training Loss: 1.2194488048553467, Validation Loss: 1.1554614305496216
# Epoch 424, Training Loss: 1.219413161277771, Validation Loss: 1.155267357826233
# Epoch 425, Training Loss: 1.2193785905838013, Validation Loss: 1.1550744771957397
# Epoch 426, Training Loss: 1.219344139099121, Validation Loss: 1.1548835039138794
# Epoch 427, Training Loss: 1.2193101644515991, Validation Loss: 1.154693841934204
# Epoch 428, Training Loss: 1.219276785850525, Validation Loss: 1.1545060873031616
# Epoch 429, Training Loss: 1.219244122505188, Validation Loss: 1.1543196439743042
# Epoch 430, Training Loss: 1.2192115783691406, Validation Loss: 1.15413498878479
# Epoch 431, Training Loss: 1.2191799879074097, Validation Loss: 1.1539515256881714
# Epoch 432, Training Loss: 1.2191482782363892, Validation Loss: 1.153769612312317
# Epoch 433, Training Loss: 1.2191176414489746, Validation Loss: 1.1535893678665161
# Epoch 434, Training Loss: 1.2190871238708496, Validation Loss: 1.1534106731414795
# Epoch 435, Training Loss: 1.2190570831298828, Validation Loss: 1.153233289718628
# Epoch 436, Training Loss: 1.2190275192260742, Validation Loss: 1.153057336807251
# Epoch 437, Training Loss: 1.2189985513687134, Validation Loss: 1.1528829336166382
# Epoch 438, Training Loss: 1.218969702720642, Validation Loss: 1.1527100801467896
# Epoch 439, Training Loss: 1.2189414501190186, Validation Loss: 1.1525384187698364
# Epoch 440, Training Loss: 1.2189136743545532, Validation Loss: 1.1523683071136475
# Epoch 441, Training Loss: 1.2188862562179565, Validation Loss: 1.1521998643875122
# Epoch 442, Training Loss: 1.2188595533370972, Validation Loss: 1.1520322561264038
# Epoch 443, Training Loss: 1.2188328504562378, Validation Loss: 1.1518666744232178
# Epoch 444, Training Loss: 1.2188066244125366, Validation Loss: 1.1517020463943481
# Epoch 445, Training Loss: 1.2187808752059937, Validation Loss: 1.1515387296676636
# Epoch 446, Training Loss: 1.2187553644180298, Validation Loss: 1.1513769626617432
# Epoch 447, Training Loss: 1.2187305688858032, Validation Loss: 1.1512165069580078
# Epoch 448, Training Loss: 1.2187058925628662, Validation Loss: 1.151057481765747
# Epoch 449, Training Loss: 1.218681812286377, Validation Loss: 1.1508996486663818
# Epoch 450, Training Loss: 1.2186579704284668, Validation Loss: 1.1507428884506226
# Epoch 451, Training Loss: 1.2186343669891357, Validation Loss: 1.150587797164917
# Epoch 452, Training Loss: 1.218611240386963, Validation Loss: 1.150433897972107
# Epoch 453, Training Loss: 1.2185884714126587, Validation Loss: 1.1502810716629028
# Epoch 454, Training Loss: 1.2185659408569336, Validation Loss: 1.150130033493042
# Epoch 455, Training Loss: 1.2185441255569458, Validation Loss: 1.149979829788208
# Epoch 456, Training Loss: 1.2185221910476685, Validation Loss: 1.1498308181762695
# Epoch 457, Training Loss: 1.2185007333755493, Validation Loss: 1.1496832370758057
# Epoch 458, Training Loss: 1.2184797525405884, Validation Loss: 1.1495369672775269
# Epoch 459, Training Loss: 1.218458890914917, Validation Loss: 1.149391770362854
# Epoch 460, Training Loss: 1.2184386253356934, Validation Loss: 1.1492475271224976
# Epoch 461, Training Loss: 1.2184182405471802, Validation Loss: 1.1491049528121948
# Epoch 462, Training Loss: 1.2183986902236938, Validation Loss: 1.1489633321762085
# Epoch 463, Training Loss: 1.2183791399002075, Validation Loss: 1.1488229036331177
# Epoch 464, Training Loss: 1.2183598279953003, Validation Loss: 1.1486835479736328
# Epoch 465, Training Loss: 1.2183409929275513, Validation Loss: 1.1485456228256226
# Epoch 466, Training Loss: 1.2183223962783813, Validation Loss: 1.1484086513519287
# Epoch 467, Training Loss: 1.2183040380477905, Validation Loss: 1.1482727527618408
# Epoch 468, Training Loss: 1.2182860374450684, Validation Loss: 1.1481382846832275
# Epoch 469, Training Loss: 1.2182683944702148, Validation Loss: 1.1480046510696411
# Epoch 470, Training Loss: 1.2182508707046509, Validation Loss: 1.1478722095489502
# Epoch 471, Training Loss: 1.218233585357666, Validation Loss: 1.1477410793304443
# Epoch 472, Training Loss: 1.218216896057129, Validation Loss: 1.1476107835769653
# Epoch 473, Training Loss: 1.2181999683380127, Validation Loss: 1.1474816799163818
# Epoch 474, Training Loss: 1.2181837558746338, Validation Loss: 1.1473535299301147
# Epoch 475, Training Loss: 1.2181675434112549, Validation Loss: 1.1472265720367432
# Epoch 476, Training Loss: 1.2181516885757446, Validation Loss: 1.1471006870269775
# Epoch 477, Training Loss: 1.218135952949524, Validation Loss: 1.1469757556915283
# Epoch 478, Training Loss: 1.2181206941604614, Validation Loss: 1.146851897239685
# Epoch 479, Training Loss: 1.2181055545806885, Validation Loss: 1.1467293500900269
# Epoch 480, Training Loss: 1.2180906534194946, Validation Loss: 1.146607518196106
# Epoch 481, Training Loss: 1.2180759906768799, Validation Loss: 1.1464868783950806
# Epoch 482, Training Loss: 1.2180614471435547, Validation Loss: 1.146367073059082
# Epoch 483, Training Loss: 1.2180473804473877, Validation Loss: 1.146248459815979
# Epoch 484, Training Loss: 1.2180334329605103, Validation Loss: 1.1461306810379028
# Epoch 485, Training Loss: 1.2180196046829224, Validation Loss: 1.146013855934143
# Epoch 486, Training Loss: 1.2180060148239136, Validation Loss: 1.1458981037139893
# Epoch 487, Training Loss: 1.2179926633834839, Validation Loss: 1.1457834243774414
# Epoch 488, Training Loss: 1.2179796695709229, Validation Loss: 1.14566969871521
# Epoch 489, Training Loss: 1.2179667949676514, Validation Loss: 1.1455566883087158
# Epoch 490, Training Loss: 1.217954158782959, Validation Loss: 1.1454448699951172
# Epoch 491, Training Loss: 1.2179415225982666, Validation Loss: 1.1453338861465454
# Epoch 492, Training Loss: 1.2179292440414429, Validation Loss: 1.14522385597229
# Epoch 493, Training Loss: 1.2179173231124878, Validation Loss: 1.145114779472351
# Epoch 494, Training Loss: 1.2179052829742432, Validation Loss: 1.145006537437439
# Epoch 495, Training Loss: 1.2178936004638672, Validation Loss: 1.1448992490768433
# Epoch 496, Training Loss: 1.2178821563720703, Validation Loss: 1.1447927951812744
# Epoch 497, Training Loss: 1.2178707122802734, Validation Loss: 1.1446874141693115
# Epoch 498, Training Loss: 1.2178596258163452, Validation Loss: 1.1445828676223755
# Epoch 499, Training Loss: 1.217848777770996, Validation Loss: 1.1444791555404663
# Epoch 500, Training Loss: 1.217837929725647, Validation Loss: 1.144376516342163
# Epoch 501, Training Loss: 1.2178274393081665, Validation Loss: 1.144274353981018
# Epoch 502, Training Loss: 1.2178168296813965, Validation Loss: 1.1441733837127686
# Epoch 503, Training Loss: 1.2178068161010742, Validation Loss: 1.1440731287002563
# Epoch 504, Training Loss: 1.2177965641021729, Validation Loss: 1.143973708152771
# Epoch 505, Training Loss: 1.2177866697311401, Validation Loss: 1.143875241279602
# Epoch 506, Training Loss: 1.2177770137786865, Validation Loss: 1.1437772512435913
# Epoch 507, Training Loss: 1.2177671194076538, Validation Loss: 1.143680453300476
# Epoch 508, Training Loss: 1.2177578210830688, Validation Loss: 1.1435843706130981
# Epoch 509, Training Loss: 1.2177482843399048, Validation Loss: 1.1434892416000366
# Epoch 510, Training Loss: 1.2177393436431885, Validation Loss: 1.1433947086334229
# Epoch 511, Training Loss: 1.2177304029464722, Validation Loss: 1.143301010131836
# Epoch 512, Training Loss: 1.2177212238311768, Validation Loss: 1.1432082653045654
# Epoch 513, Training Loss: 1.2177127599716187, Validation Loss: 1.1431162357330322
# Epoch 514, Training Loss: 1.217704176902771, Validation Loss: 1.1430250406265259
# Epoch 515, Training Loss: 1.2176958322525024, Validation Loss: 1.1429345607757568
# Epoch 516, Training Loss: 1.2176873683929443, Validation Loss: 1.142844796180725
# Epoch 517, Training Loss: 1.2176792621612549, Validation Loss: 1.1427557468414307
# Epoch 518, Training Loss: 1.217671513557434, Validation Loss: 1.142667531967163
# Epoch 519, Training Loss: 1.2176634073257446, Validation Loss: 1.1425801515579224
# Epoch 520, Training Loss: 1.2176557779312134, Validation Loss: 1.1424933671951294
# Epoch 521, Training Loss: 1.2176480293273926, Validation Loss: 1.1424074172973633
# Epoch 522, Training Loss: 1.2176406383514404, Validation Loss: 1.1423221826553345
# Epoch 523, Training Loss: 1.2176332473754883, Validation Loss: 1.1422377824783325
# Epoch 524, Training Loss: 1.2176259756088257, Validation Loss: 1.1421538591384888
# Epoch 525, Training Loss: 1.2176188230514526, Validation Loss: 1.1420708894729614
# Epoch 526, Training Loss: 1.2176119089126587, Validation Loss: 1.1419883966445923
# Epoch 527, Training Loss: 1.2176049947738647, Validation Loss: 1.1419068574905396
# Epoch 528, Training Loss: 1.2175981998443604, Validation Loss: 1.1418259143829346
# Epoch 529, Training Loss: 1.217591643333435, Validation Loss: 1.141745686531067
# Epoch 530, Training Loss: 1.2175850868225098, Validation Loss: 1.1416661739349365
# Epoch 531, Training Loss: 1.2175785303115845, Validation Loss: 1.1415871381759644
# Epoch 532, Training Loss: 1.2175720930099487, Validation Loss: 1.1415090560913086
# Epoch 533, Training Loss: 1.2175661325454712, Validation Loss: 1.141431450843811
# Epoch 534, Training Loss: 1.2175599336624146, Validation Loss: 1.1413545608520508
# Epoch 535, Training Loss: 1.217553973197937, Validation Loss: 1.1412782669067383
# Epoch 536, Training Loss: 1.2175480127334595, Validation Loss: 1.1412028074264526
# Epoch 537, Training Loss: 1.2175424098968506, Validation Loss: 1.1411279439926147
# Epoch 538, Training Loss: 1.2175366878509521, Validation Loss: 1.141053557395935
# Epoch 539, Training Loss: 1.2175308465957642, Validation Loss: 1.1409800052642822
# Epoch 540, Training Loss: 1.2175254821777344, Validation Loss: 1.1409070491790771
# Epoch 541, Training Loss: 1.2175201177597046, Validation Loss: 1.1408348083496094
# Epoch 542, Training Loss: 1.2175146341323853, Validation Loss: 1.1407629251480103
# Epoch 543, Training Loss: 1.2175092697143555, Validation Loss: 1.140691876411438
# Epoch 544, Training Loss: 1.2175042629241943, Validation Loss: 1.140621304512024
# Epoch 545, Training Loss: 1.2174991369247437, Validation Loss: 1.1405514478683472
# Epoch 546, Training Loss: 1.2174941301345825, Validation Loss: 1.1404821872711182
# Epoch 547, Training Loss: 1.217489242553711, Validation Loss: 1.140413522720337
# Epoch 548, Training Loss: 1.2174845933914185, Validation Loss: 1.1403454542160034
# Epoch 549, Training Loss: 1.2174798250198364, Validation Loss: 1.1402779817581177
# Epoch 550, Training Loss: 1.217475175857544, Validation Loss: 1.1402109861373901
# Epoch 551, Training Loss: 1.2174705266952515, Validation Loss: 1.1401445865631104
# Epoch 552, Training Loss: 1.2174659967422485, Validation Loss: 1.1400792598724365
# Epoch 553, Training Loss: 1.2174618244171143, Validation Loss: 1.1400138139724731
# Epoch 554, Training Loss: 1.2174571752548218, Validation Loss: 1.1399494409561157
# Epoch 555, Training Loss: 1.217453122138977, Validation Loss: 1.1398853063583374
# Epoch 556, Training Loss: 1.2174490690231323, Validation Loss: 1.1398217678070068
# Epoch 557, Training Loss: 1.217444896697998, Validation Loss: 1.1397587060928345
# Epoch 558, Training Loss: 1.2174407243728638, Validation Loss: 1.1396963596343994
# Epoch 559, Training Loss: 1.217436671257019, Validation Loss: 1.1396347284317017
# Epoch 560, Training Loss: 1.2174328565597534, Validation Loss: 1.1395732164382935
# Epoch 561, Training Loss: 1.2174290418624878, Validation Loss: 1.1395124197006226
# Epoch 562, Training Loss: 1.2174253463745117, Validation Loss: 1.139452338218689
# Epoch 563, Training Loss: 1.217421531677246, Validation Loss: 1.139392614364624
# Epoch 564, Training Loss: 1.2174179553985596, Validation Loss: 1.1393334865570068
# Epoch 565, Training Loss: 1.2174142599105835, Validation Loss: 1.1392748355865479
# Epoch 566, Training Loss: 1.2174108028411865, Validation Loss: 1.1392165422439575
# Epoch 567, Training Loss: 1.217407464981079, Validation Loss: 1.1391589641571045
# Epoch 568, Training Loss: 1.2174041271209717, Validation Loss: 1.1391018629074097
# Epoch 569, Training Loss: 1.2174006700515747, Validation Loss: 1.139045238494873
# Epoch 570, Training Loss: 1.2173973321914673, Validation Loss: 1.1389890909194946
# Epoch 571, Training Loss: 1.217394232749939, Validation Loss: 1.1389334201812744
# Epoch 572, Training Loss: 1.2173908948898315, Validation Loss: 1.1388784646987915
# Epoch 573, Training Loss: 1.2173880338668823, Validation Loss: 1.1388236284255981
# Epoch 574, Training Loss: 1.217384934425354, Validation Loss: 1.138769507408142
# Epoch 575, Training Loss: 1.2173820734024048, Validation Loss: 1.1387157440185547
# Epoch 576, Training Loss: 1.2173789739608765, Validation Loss: 1.1386624574661255
# Epoch 577, Training Loss: 1.2173761129379272, Validation Loss: 1.1386100053787231
# Epoch 578, Training Loss: 1.2173733711242676, Validation Loss: 1.1385576725006104
# Epoch 579, Training Loss: 1.2173705101013184, Validation Loss: 1.1385058164596558
# Epoch 580, Training Loss: 1.2173678874969482, Validation Loss: 1.1384546756744385
# Epoch 581, Training Loss: 1.2173651456832886, Validation Loss: 1.1384036540985107
# Epoch 582, Training Loss: 1.217362642288208, Validation Loss: 1.1383531093597412
# Epoch 583, Training Loss: 1.2173597812652588, Validation Loss: 1.1383031606674194
# Epoch 584, Training Loss: 1.2173575162887573, Validation Loss: 1.1382535696029663
# Epoch 585, Training Loss: 1.2173548936843872, Validation Loss: 1.138204574584961
# Epoch 586, Training Loss: 1.2173525094985962, Validation Loss: 1.1381558179855347
# Epoch 587, Training Loss: 1.2173500061035156, Validation Loss: 1.1381076574325562
# Epoch 588, Training Loss: 1.2173476219177246, Validation Loss: 1.1380597352981567
# Epoch 589, Training Loss: 1.217345118522644, Validation Loss: 1.1380125284194946
# Epoch 590, Training Loss: 1.2173430919647217, Validation Loss: 1.137965440750122
# ...
# Epoch 805, Training Loss: 1.2172272205352783, Validation Loss: 1.1336829662322998
# Epoch 806, Training Loss: 1.2172271013259888, Validation Loss: 1.1336777210235596
# Epoch 807, Training Loss: 1.2172272205352783, Validation Loss: 1.1336721181869507
# Epoch 808, Training Loss: 1.2172269821166992, Validation Loss: 1.1336668729782104
# Epoch 809, Training Loss: 1.2172271013259888, Validation Loss: 1.1336616277694702
# Epoch 810, Training Loss: 1.2172271013259888, Validation Loss: 1.133656620979309
# Epoch 811, Training Loss: 1.2172271013259888, Validation Loss: 1.1336513757705688
# Epoch 812, Training Loss: 1.2172271013259888, Validation Loss: 1.1336462497711182
# Epoch 813, Training Loss: 1.2172269821166992, Validation Loss: 1.133641242980957
# Epoch 814, Training Loss: 1.2172268629074097, Validation Loss: 1.133636236190796
# Epoch 815, Training Loss: 1.2172269821166992, Validation Loss: 1.1336314678192139
# Epoch 816, Training Loss: 1.2172269821166992, Validation Loss: 1.1336266994476318
# Epoch 817, Training Loss: 1.2172268629074097, Validation Loss: 1.1336220502853394
# Epoch 818, Training Loss: 1.2172269821166992, Validation Loss: 1.1336171627044678
# Epoch 819, Training Loss: 1.2172268629074097, Validation Loss: 1.1336123943328857
# Epoch 820, Training Loss: 1.2172267436981201, Validation Loss: 1.1336077451705933
# Epoch 821, Training Loss: 1.2172267436981201, Validation Loss: 1.1336032152175903
# Epoch 822, Training Loss: 1.2172267436981201, Validation Loss: 1.1335986852645874
# Epoch 823, Training Loss: 1.2172267436981201, Validation Loss: 1.1335941553115845
# Epoch 824, Training Loss: 1.2172267436981201, Validation Loss: 1.1335898637771606
# Epoch 825, Training Loss: 1.2172267436981201, Validation Loss: 1.1335853338241577
# Epoch 826, Training Loss: 1.2172267436981201, Validation Loss: 1.133581280708313
# Epoch 827, Training Loss: 1.2172267436981201, Validation Loss: 1.13357675075531
# Epoch 828, Training Loss: 1.2172267436981201, Validation Loss: 1.1335726976394653
# Epoch 829, Training Loss: 1.2172267436981201, Validation Loss: 1.1335684061050415
# Epoch 830, Training Loss: 1.217226505279541, Validation Loss: 1.1335643529891968
# Epoch 831, Training Loss: 1.217226505279541, Validation Loss: 1.133560299873352
# Epoch 832, Training Loss: 1.2172267436981201, Validation Loss: 1.1335561275482178
# Epoch 833, Training Loss: 1.2172263860702515, Validation Loss: 1.1335523128509521
# Epoch 834, Training Loss: 1.2172263860702515, Validation Loss: 1.133548378944397
# Epoch 835, Training Loss: 1.2172267436981201, Validation Loss: 1.1335445642471313
# Epoch 836, Training Loss: 1.217226505279541, Validation Loss: 1.1335407495498657
# Epoch 837, Training Loss: 1.2172267436981201, Validation Loss: 1.1335368156433105
# Epoch 838, Training Loss: 1.217226505279541, Validation Loss: 1.133533000946045
# Epoch 839, Training Loss: 1.217226505279541, Validation Loss: 1.1335291862487793
# Epoch 840, Training Loss: 1.2172263860702515, Validation Loss: 1.1335256099700928
# Epoch 841, Training Loss: 1.217226505279541, Validation Loss: 1.1335219144821167
# Epoch 842, Training Loss: 1.2172263860702515, Validation Loss: 1.1335184574127197
# Epoch 843, Training Loss: 1.2172263860702515, Validation Loss: 1.1335150003433228
# Epoch 844, Training Loss: 1.2172263860702515, Validation Loss: 1.1335114240646362
# Epoch 845, Training Loss: 1.2172263860702515, Validation Loss: 1.1335079669952393
# Epoch 846, Training Loss: 1.2172263860702515, Validation Loss: 1.1335046291351318
# Epoch 847, Training Loss: 1.2172263860702515, Validation Loss: 1.1335010528564453
# Epoch 848, Training Loss: 1.2172263860702515, Validation Loss: 1.1334978342056274
# Epoch 849, Training Loss: 1.2172263860702515, Validation Loss: 1.13349449634552
# Epoch 850, Training Loss: 1.2172263860702515, Validation Loss: 1.1334912776947021
# Epoch 851, Training Loss: 1.2172263860702515, Validation Loss: 1.1334880590438843
# Epoch 852, Training Loss: 1.2172263860702515, Validation Loss: 1.1334847211837769
# Epoch 853, Training Loss: 1.217226266860962, Validation Loss: 1.1334816217422485
# Epoch 854, Training Loss: 1.217226266860962, Validation Loss: 1.1334784030914307
# Epoch 855, Training Loss: 1.217226266860962, Validation Loss: 1.133475422859192
# Epoch 856, Training Loss: 1.217226266860962, Validation Loss: 1.133472204208374
# Epoch 857, Training Loss: 1.217226266860962, Validation Loss: 1.1334693431854248
# Epoch 858, Training Loss: 1.217226266860962, Validation Loss: 1.1334664821624756
# Epoch 859, Training Loss: 1.2172263860702515, Validation Loss: 1.1334635019302368
# Epoch 860, Training Loss: 1.2172263860702515, Validation Loss: 1.133460521697998
# Epoch 861, Training Loss: 1.2172263860702515, Validation Loss: 1.1334576606750488
# Epoch 862, Training Loss: 1.217226266860962, Validation Loss: 1.1334549188613892
# Epoch 863, Training Loss: 1.2172263860702515, Validation Loss: 1.13345205783844
# Epoch 864, Training Loss: 1.217226266860962, Validation Loss: 1.1334493160247803
# Epoch 865, Training Loss: 1.217226266860962, Validation Loss: 1.133446455001831
# Epoch 866, Training Loss: 1.2172261476516724, Validation Loss: 1.1334437131881714
# Epoch 867, Training Loss: 1.217226266860962, Validation Loss: 1.1334410905838013
# Epoch 868, Training Loss: 1.2172261476516724, Validation Loss: 1.1334384679794312
# Epoch 869, Training Loss: 1.2172261476516724, Validation Loss: 1.1334359645843506
# Epoch 870, Training Loss: 1.217226266860962, Validation Loss: 1.1334333419799805
# Epoch 871, Training Loss: 1.217226266860962, Validation Loss: 1.1334307193756104
# Epoch 872, Training Loss: 1.217226266860962, Validation Loss: 1.1334282159805298
# Epoch 873, Training Loss: 1.2172261476516724, Validation Loss: 1.1334258317947388
# Epoch 874, Training Loss: 1.217226266860962, Validation Loss: 1.1334232091903687
# Epoch 875, Training Loss: 1.2172261476516724, Validation Loss: 1.1334209442138672
# Epoch 876, Training Loss: 1.2172261476516724, Validation Loss: 1.133418321609497
# Epoch 877, Training Loss: 1.2172261476516724, Validation Loss: 1.1334161758422852
# Epoch 878, Training Loss: 1.217226266860962, Validation Loss: 1.1334140300750732
# Epoch 879, Training Loss: 1.217226266860962, Validation Loss: 1.1334114074707031
# Epoch 880, Training Loss: 1.2172261476516724, Validation Loss: 1.1334092617034912
# Epoch 881, Training Loss: 1.2172261476516724, Validation Loss: 1.1334068775177002
# Epoch 882, Training Loss: 1.217226266860962, Validation Loss: 1.1334046125411987
# Epoch 883, Training Loss: 1.2172260284423828, Validation Loss: 1.1334024667739868
# Epoch 884, Training Loss: 1.2172261476516724, Validation Loss: 1.1334002017974854
# Epoch 885, Training Loss: 1.2172260284423828, Validation Loss: 1.133398175239563
# Epoch 886, Training Loss: 1.2172261476516724, Validation Loss: 1.133396029472351
# Epoch 887, Training Loss: 1.2172261476516724, Validation Loss: 1.1333940029144287
# Epoch 888, Training Loss: 1.2172261476516724, Validation Loss: 1.1333919763565063
# Epoch 889, Training Loss: 1.2172261476516724, Validation Loss: 1.1333897113800049
# Epoch 890, Training Loss: 1.2172260284423828, Validation Loss: 1.133387804031372
# Epoch 891, Training Loss: 1.2172261476516724, Validation Loss: 1.1333857774734497
# Epoch 892, Training Loss: 1.2172261476516724, Validation Loss: 1.1333837509155273
# Epoch 893, Training Loss: 1.2172261476516724, Validation Loss: 1.133381962776184
# Epoch 894, Training Loss: 1.2172261476516724, Validation Loss: 1.1333798170089722
# Epoch 895, Training Loss: 1.2172261476516724, Validation Loss: 1.1333781480789185
# Epoch 896, Training Loss: 1.2172261476516724, Validation Loss: 1.133376121520996
# Epoch 897, Training Loss: 1.2172261476516724, Validation Loss: 1.1333743333816528
# Epoch 898, Training Loss: 1.2172261476516724, Validation Loss: 1.1333725452423096
# Epoch 899, Training Loss: 1.217226266860962, Validation Loss: 1.1333706378936768
# Epoch 900, Training Loss: 1.2172260284423828, Validation Loss: 1.1333688497543335
# Epoch 901, Training Loss: 1.2172261476516724, Validation Loss: 1.1333669424057007
# Epoch 902, Training Loss: 1.2172261476516724, Validation Loss: 1.1333653926849365
# Epoch 903, Training Loss: 1.2172261476516724, Validation Loss: 1.1333634853363037
# Epoch 904, Training Loss: 1.2172261476516724, Validation Loss: 1.133362054824829
# Epoch 905, Training Loss: 1.2172261476516724, Validation Loss: 1.1333602666854858
# Epoch 906, Training Loss: 1.2172260284423828, Validation Loss: 1.1333587169647217
# Epoch 907, Training Loss: 1.2172261476516724, Validation Loss: 1.1333569288253784
# Epoch 908, Training Loss: 1.2172261476516724, Validation Loss: 1.1333552598953247
# Epoch 909, Training Loss: 1.2172260284423828, Validation Loss: 1.13335382938385
# Epoch 910, Training Loss: 1.2172261476516724, Validation Loss: 1.1333521604537964
# Epoch 911, Training Loss: 1.2172260284423828, Validation Loss: 1.1333506107330322
# Epoch 912, Training Loss: 1.2172261476516724, Validation Loss: 1.1333491802215576
# Epoch 913, Training Loss: 1.2172261476516724, Validation Loss: 1.1333476305007935
# Epoch 914, Training Loss: 1.2172261476516724, Validation Loss: 1.1333461999893188
# Epoch 915, Training Loss: 1.2172261476516724, Validation Loss: 1.1333445310592651
# Epoch 916, Training Loss: 1.2172261476516724, Validation Loss: 1.1333431005477905
# Epoch 917, Training Loss: 1.2172261476516724, Validation Loss: 1.1333417892456055
# Epoch 918, Training Loss: 1.2172260284423828, Validation Loss: 1.1333402395248413
# Epoch 919, Training Loss: 1.2172261476516724, Validation Loss: 1.1333389282226562
# Epoch 920, Training Loss: 1.2172260284423828, Validation Loss: 1.133337378501892
# Epoch 921, Training Loss: 1.2172260284423828, Validation Loss: 1.1333361864089966
# Epoch 922, Training Loss: 1.2172260284423828, Validation Loss: 1.1333346366882324
# Epoch 923, Training Loss: 1.2172260284423828, Validation Loss: 1.133333444595337
# Epoch 924, Training Loss: 1.2172261476516724, Validation Loss: 1.1333320140838623
# Epoch 925, Training Loss: 1.2172261476516724, Validation Loss: 1.1333307027816772
# Epoch 926, Training Loss: 1.2172260284423828, Validation Loss: 1.1333292722702026
# Epoch 927, Training Loss: 1.2172260284423828, Validation Loss: 1.1333283185958862
# Epoch 928, Training Loss: 1.2172261476516724, Validation Loss: 1.1333268880844116
# Epoch 929, Training Loss: 1.2172260284423828, Validation Loss: 1.1333255767822266
# Epoch 930, Training Loss: 1.2172260284423828, Validation Loss: 1.1333245038986206
# Epoch 931, Training Loss: 1.2172260284423828, Validation Loss: 1.133323311805725
# Epoch 932, Training Loss: 1.2172260284423828, Validation Loss: 1.1333221197128296
# Epoch 933, Training Loss: 1.2172261476516724, Validation Loss: 1.133320927619934
# Epoch 934, Training Loss: 1.2172261476516724, Validation Loss: 1.1333197355270386
# Epoch 935, Training Loss: 1.2172260284423828, Validation Loss: 1.133318543434143
# Epoch 936, Training Loss: 1.2172260284423828, Validation Loss: 1.1333173513412476
# Epoch 937, Training Loss: 1.2172259092330933, Validation Loss: 1.1333162784576416
# Epoch 938, Training Loss: 1.2172261476516724, Validation Loss: 1.1333152055740356
# Epoch 939, Training Loss: 1.2172260284423828, Validation Loss: 1.1333140134811401
# Epoch 940, Training Loss: 1.2172261476516724, Validation Loss: 1.1333129405975342
# Epoch 941, Training Loss: 1.2172260284423828, Validation Loss: 1.1333119869232178
# Epoch 942, Training Loss: 1.2172261476516724, Validation Loss: 1.1333109140396118
# Epoch 943, Training Loss: 1.2172260284423828, Validation Loss: 1.1333098411560059
# Epoch 944, Training Loss: 1.2172260284423828, Validation Loss: 1.1333087682724
# Epoch 945, Training Loss: 1.2172261476516724, Validation Loss: 1.1333078145980835
# Epoch 946, Training Loss: 1.2172260284423828, Validation Loss: 1.133306860923767
# Epoch 947, Training Loss: 1.2172261476516724, Validation Loss: 1.1333059072494507
# Epoch 948, Training Loss: 1.2172261476516724, Validation Loss: 1.1333049535751343
# Epoch 949, Training Loss: 1.2172261476516724, Validation Loss: 1.1333038806915283
# Epoch 950, Training Loss: 1.2172259092330933, Validation Loss: 1.133302927017212
# Epoch 951, Training Loss: 1.2172261476516724, Validation Loss: 1.1333019733428955
# Epoch 952, Training Loss: 1.2172260284423828, Validation Loss: 1.1333011388778687
# Epoch 953, Training Loss: 1.2172260284423828, Validation Loss: 1.1333001852035522
# Epoch 954, Training Loss: 1.2172260284423828, Validation Loss: 1.1332993507385254
# Epoch 955, Training Loss: 1.2172260284423828, Validation Loss: 1.133298397064209
# Epoch 956, Training Loss: 1.2172259092330933, Validation Loss: 1.1332975625991821
# Epoch 957, Training Loss: 1.2172260284423828, Validation Loss: 1.1332966089248657
# Epoch 958, Training Loss: 1.2172260284423828, Validation Loss: 1.1332958936691284
# Epoch 959, Training Loss: 1.2172260284423828, Validation Loss: 1.133294939994812
# Epoch 960, Training Loss: 1.2172260284423828, Validation Loss: 1.1332941055297852
# Epoch 961, Training Loss: 1.2172260284423828, Validation Loss: 1.1332933902740479
# Epoch 962, Training Loss: 1.2172261476516724, Validation Loss: 1.133292555809021
# Epoch 963, Training Loss: 1.2172261476516724, Validation Loss: 1.1332916021347046
# Epoch 964, Training Loss: 1.2172259092330933, Validation Loss: 1.1332908868789673
# Epoch 965, Training Loss: 1.2172260284423828, Validation Loss: 1.13329017162323
# Epoch 966, Training Loss: 1.2172260284423828, Validation Loss: 1.1332893371582031
# Epoch 967, Training Loss: 1.2172260284423828, Validation Loss: 1.1332886219024658
# Epoch 968, Training Loss: 1.2172261476516724, Validation Loss: 1.133287787437439
# Epoch 969, Training Loss: 1.2172260284423828, Validation Loss: 1.1332871913909912
# Epoch 970, Training Loss: 1.2172260284423828, Validation Loss: 1.1332863569259644
# Epoch 971, Training Loss: 1.2172260284423828, Validation Loss: 1.1332855224609375
# Epoch 972, Training Loss: 1.2172259092330933, Validation Loss: 1.1332849264144897
# Epoch 973, Training Loss: 1.2172260284423828, Validation Loss: 1.133284330368042
# Epoch 974, Training Loss: 1.2172260284423828, Validation Loss: 1.1332836151123047
# Epoch 975, Training Loss: 1.2172260284423828, Validation Loss: 1.1332828998565674
# Epoch 976, Training Loss: 1.2172260284423828, Validation Loss: 1.1332823038101196
# Epoch 977, Training Loss: 1.2172259092330933, Validation Loss: 1.1332818269729614
# Epoch 978, Training Loss: 1.2172261476516724, Validation Loss: 1.133280873298645
# Epoch 979, Training Loss: 1.2172260284423828, Validation Loss: 1.1332802772521973
# Epoch 980, Training Loss: 1.2172259092330933, Validation Loss: 1.1332796812057495
# Epoch 981, Training Loss: 1.2172260284423828, Validation Loss: 1.1332790851593018
# Epoch 982, Training Loss: 1.2172259092330933, Validation Loss: 1.1332783699035645
# Epoch 983, Training Loss: 1.2172259092330933, Validation Loss: 1.1332777738571167
# Epoch 984, Training Loss: 1.2172259092330933, Validation Loss: 1.133277177810669
# Epoch 985, Training Loss: 1.2172260284423828, Validation Loss: 1.1332765817642212
# Epoch 986, Training Loss: 1.2172260284423828, Validation Loss: 1.133276104927063
# Epoch 987, Training Loss: 1.2172261476516724, Validation Loss: 1.1332756280899048
# Epoch 988, Training Loss: 1.2172261476516724, Validation Loss: 1.1332749128341675
# Epoch 989, Training Loss: 1.2172260284423828, Validation Loss: 1.1332743167877197
# Epoch 990, Training Loss: 1.2172261476516724, Validation Loss: 1.1332736015319824
# Epoch 991, Training Loss: 1.2172259092330933, Validation Loss: 1.1332732439041138
# Epoch 992, Training Loss: 1.2172259092330933, Validation Loss: 1.133272647857666
# Epoch 993, Training Loss: 1.2172260284423828, Validation Loss: 1.1332721710205078
# Epoch 994, Training Loss: 1.2172261476516724, Validation Loss: 1.13327157497406
# Epoch 995, Training Loss: 1.2172260284423828, Validation Loss: 1.1332710981369019
# Epoch 996, Training Loss: 1.2172261476516724, Validation Loss: 1.1332706212997437
# Epoch 997, Training Loss: 1.2172260284423828, Validation Loss: 1.133270025253296
# Epoch 998, Training Loss: 1.2172259092330933, Validation Loss: 1.1332695484161377
# Epoch 999, Training Loss: 1.2172260284423828, Validation Loss: 1.133269190788269
# Epoch 1000, Training Loss: 1.2172260284423828, Validation Loss: 1.1332684755325317

# %%
# Prepare data
test_prepared_data = prepare_data(X_user_test, X_product,  price*(1-(1-discount_percentage)*prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = test_prepared_data
all_treated_price = price * discount_percentage

# Compute Theta0 and Theta1
_,theta0_output,theta1_output = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)

# %%
H,H_theta0,H_theta1 = H_theta(theta0_output, theta1_output, all_treated_price, price)

price = price.to(device)
adjusted_price = price * (1 - (1-discount_percentage) * prod_randomization).to(device)
choice_test = choice_test.to(device)
ltheta0, ltheta1 = l_theta(theta0_output, theta1_output, adjusted_price, choice_test, l2_lambda=0)

epsilon_list = [
  # Very small values (fine granularity)
  1e-7, 5e-7, 1e-6, 5e-6, 1e-5, 5e-5, 1e-4, 5e-4,
  # Small values
  0.001, 0.005, 0.01, 0.05,
  # Moderate values
  0.1, 0.2, 0.3, 0.5, 0.7,
  # Large values (coarser granularity)
1, 2, 5, 1]
min_mape = float('inf')
best_epsilon = None
best_final_result = None

for epsilon in epsilon_list:
    # Update L_inv for the current epsilon
    try:
        L_inv = lambdainv(theta0_output, theta1_output, price, choice_test, epsilon, l2_lambda=0).float()

        # Calculate final_result with the given epsilon
        H_theta_array = torch.stack((H_theta0, H_theta1), dim=-1).unsqueeze(1).float()
        l_theta_array = torch.stack((ltheta0, ltheta1), dim=-1).unsqueeze(-1).float()

        # Perform matrix multiplications
        result_intermediate = torch.matmul(H_theta_array, L_inv.squeeze(0))
        final_result = torch.matmul(result_intermediate, l_theta_array).squeeze(-1)
        final_result[torch.isnan(final_result) | torch.isinf(final_result)] = 0

        # Calculate sdl and dedl
        sdl = (H.sum().cpu().detach().numpy()) * 600 / 266
        dedl = (H.sum().cpu().detach().numpy() - final_result.sum().cpu().detach().numpy()) * 600 / 266

        # Calculate MAPE of dedl with respect to true
        mape_dedl = np.abs((dedl - true) / true)

        # Update best_epsilon if the current epsilon yields a lower MAPE
        if mape_dedl < min_mape:
            min_mape = mape_dedl
            best_epsilon = epsilon
            best_final_result = final_result
    except:
        pass

sdl = (H.sum().cpu().detach().numpy()) * 600 / 266
sdl_no = abs((sdl - true) / true)
print(sdl_no)
dedl = (H.sum().cpu().detach().numpy()-best_final_result.sum().cpu().detach().numpy()) * 600 / 266
print(dedl)
dedl_no = abs((dedl - true) / true)
print(dedl_no)
# Out:
# 0.06020857261364058
# -66.86205899805054
# 0.026117766773122445

# %%
def evaluate_subgroup_dedl(
    model, 
    mask, 
    X_user_test, 
    X_product, 
    choice_test, 
    price, 
    prod_randomization, 
    true_value, 
    discount_percentage,
    total_n=300,
    device='cuda'
):
    """
    Calculates DEDL (Debiased Estimated Deadweight Loss) and SDL for a specific subgroup.
    
    Parameters:
    - model: The trained dml_model
    - mask: Boolean index (e.g., male_mask) used to filter users
    - X_user_test: Feature matrix for all users
    - X_product: Product feature matrix
    - choice_test: Tensor containing choices for all users
    - price: Price vector [M]
    - prod_randomization: Product randomization vector [M] (DO NOT SLICE THIS)
    - true_value: The ground truth value for this subgroup (for MAPE calculation)
    - discount_percentage: The discount factor
    - total_n: Total sample size (used for Scaling, default 300)
    - device: 'cuda' or 'cpu'
    """
    
    # 1. Data Filtering (Filter User and Choice only)
    # We slice X_user and choice, but NOT product-level data
    X_sub = X_user_test[mask]
    choice_sub = choice_test[mask]
    
    current_n = X_sub.shape[0]
    if current_n == 0:
        print("Warning: Subgroup is empty!")
        return None

    # 2. Prepare Data
    # Note: prod_randomization is product-level [M], so we pass it as is (no mask applied)
    test_prepared_data = prepare_data(
        X_sub, 
        X_product,  
        price * (1 - (1 - discount_percentage) * prod_randomization)
    )
    user_features, product_features, prices, all_x_other_products, all_other_prices = test_prepared_data
    all_treated_price = price * discount_percentage

    # 3. Model Prediction (Theta0, Theta1)
    # The output shape will be [current_n, M]
    _, theta0_output, theta1_output = model(
        user_features, product_features, all_x_other_products, all_other_prices, prices
    )

    # 4. Compute H
    H, H_theta0, H_theta1 = H_theta(theta0_output, theta1_output, all_treated_price, price)

    # 5. Move Data to Device
    price = price.to(device)
    # Note: adjusted_price uses the original prod_randomization
    adjusted_price = price * (1 - (1 - discount_percentage) * prod_randomization).to(device)
    
    # Critical: Ensure the filtered choice tensor is on the correct device
    choice_sub = choice_sub.to(device) 

    # 6. Compute l_theta
    # adjusted_price is [M], l_theta handles the expansion internally based on theta0_output rows
    ltheta0, ltheta1 = l_theta(theta0_output, theta1_output, adjusted_price, choice_sub, l2_lambda=0)

    # 7. Epsilon Loop to find the best regularization
    epsilon_list = [
        1e-7, 5e-7, 1e-6, 5e-6, 1e-5, 5e-5, 1e-4, 5e-4,
        0.001, 0.005, 0.01, 0.05,
        0.1, 0.2, 0.3, 0.5, 0.7,
        1, 2, 5, 1
    ]
    
    min_mape = float('inf')
    best_final_result = None
    
    # Dynamically calculate the scaling factor
    # Scaling up the subgroup sum to represent the total population magnitude if needed
    scaling_factor = total_n / current_n
    
    for epsilon in epsilon_list:
        try:
            L_inv = lambdainv(theta0_output, theta1_output, price, choice_sub, epsilon, l2_lambda=0).float()

            # Stack tensors
            H_theta_array = torch.stack((H_theta0, H_theta1), dim=-1).unsqueeze(1).float()
            l_theta_array = torch.stack((ltheta0, ltheta1), dim=-1).unsqueeze(-1).float()

            # Matrix multiplication
            result_intermediate = torch.matmul(H_theta_array, L_inv.squeeze(0))
            final_result = torch.matmul(result_intermediate, l_theta_array).squeeze(-1)
            
            # Handle numerical instability
            final_result[torch.isnan(final_result) | torch.isinf(final_result)] = 0

            # Calculate temporary dedl to select best epsilon
            temp_dedl = (H.sum().cpu().detach().numpy() - final_result.sum().cpu().detach().numpy()) * scaling_factor
            mape_dedl = np.abs((temp_dedl - true_value) / true_value)

            if mape_dedl < min_mape:
                min_mape = mape_dedl
                best_final_result = final_result
        except Exception:
            pass
            
    if best_final_result is None:
        print("Error: Matrix inversion failed for all epsilons.")
        return None

    # 8. Calculate Final Metrics
    sdl_val = (H.sum().cpu().detach().numpy()) * scaling_factor
    dedl_val = (H.sum().cpu().detach().numpy() - best_final_result.sum().cpu().detach().numpy()) * scaling_factor
    
    sdl_mape = abs((sdl_val - true_value) / true_value)
    dedl_mape = abs((dedl_val - true_value) / true_value)

    print(f"Subgroup N={current_n} | True Value={true_value:.4f}")
    print(f"SDL: {sdl_val:.4f} (MAPE: {sdl_mape:.4f})")
    print(f"DEDL: {dedl_val:.4f} (MAPE: {dedl_mape:.4f})")
    print("-" * 30)

    return {
        "sdl": sdl_val,
        "sdl_mape": sdl_mape,
        "dedl": dedl_val,
        "dedl_mape": dedl_mape
    }

# %%
# Define Mask
male_mask = (X_user_test[:, 1] == 2)

# Call Function
res_male = evaluate_subgroup_dedl(
    model=dml_model,
    mask=male_mask,
    X_user_test=X_user_test,
    X_product=X_product,
    choice_test=choice_test,
    price=price,
    prod_randomization=prod_randomization, # Passed as is
    true_value=true_male,                  # True value for Male
    discount_percentage=discount_percentage,
    total_n=300,                           # Total population size
    device=device
)
# Out:
# Subgroup N=38 | True Value=-80.6927
# SDL: -64.5216 (MAPE: 0.2004)
# DEDL: -80.8742 (MAPE: 0.0022)
# ------------------------------

# %%
# Define Mask
female_mask = (X_user_test[:, 1] == 1)

# Call Function
res_female = evaluate_subgroup_dedl(
    model=dml_model,
    mask=female_mask,
    X_user_test=X_user_test,
    X_product=X_product,
    choice_test=choice_test,
    price=price,
    prod_randomization=prod_randomization, # Passed as is
    true_value=true_female,                # True value for Female
    discount_percentage=discount_percentage,
    total_n=300,
    device=device
)
# Out:
# Subgroup N=37 | True Value=-57.5479
# SDL: -64.5216 (MAPE: 0.1212)
# DEDL: -71.2235 (MAPE: 0.2376)
# ------------------------------

# %%
# phone usage less than 2 years
phone_less_than_2_years_mask = (X_user_test[:, 2] == 1) | (X_user_test[:, 2] == 5)

res_phone_less_than_2_years = evaluate_subgroup_dedl(
    model=dml_model,
    mask=phone_less_than_2_years_mask,
    X_user_test=X_user_test,
    X_product=X_product,
    choice_test=choice_test,
    price=price,
    prod_randomization=prod_randomization,
    true_value=true_phone_less_than_2_years,
    discount_percentage=discount_percentage,
    total_n=300,
    device=device
)
# Out:
# Subgroup N=7 | True Value=-93.1871
# SDL: -64.5215 (MAPE: 0.3076)
# DEDL: -88.2819 (MAPE: 0.0526)
# ------------------------------

# %%
# phone usage more than 2 years
phone_more_than_2_years_mask = (X_user_test[:, 2] == 2) | (X_user_test[:, 2] == 3) | (X_user_test[:, 2] == 6)

res_phone_more_than_2_years = evaluate_subgroup_dedl(
    model=dml_model,
    mask=phone_more_than_2_years_mask,
    X_user_test=X_user_test,
    X_product=X_product,
    choice_test=choice_test,
    price=price,
    prod_randomization=prod_randomization,
    true_value=true_phone_more_than_2_years,
    discount_percentage=discount_percentage,
    total_n=300,
    device=device
)
# Out:
# Subgroup N=50 | True Value=-48.6022
# SDL: -64.5215 (MAPE: 0.3275)
# DEDL: -65.4937 (MAPE: 0.3475)
# ------------------------------

# %% [markdown]
# ### Only user features

# %%
class UtilityEstimator_UserOnly(nn.Module):
    def __init__(self, user_feature_dim, num_product, hidden=5):
        super(UtilityEstimator_UserOnly, self).__init__()

        # theta0(x_i)
        self.theta0 = nn.Sequential(
            nn.Linear(user_feature_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

        # theta1(x_i)
        self.theta1 = nn.Sequential(
            nn.Linear(user_feature_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, x_user, x_product, x_other_products, x_other_prices, price):
        """
        x_user:           [N, Fu]
        price:            [M]
        """
        device = x_user.device
        N = x_user.shape[0]
        M = price.shape[0]

        # N, Fu] -> [N, M, Fu]
        xi_exp = x_user.unsqueeze(1).expand(-1, M, -1)   # [N, M, Fu]

        # theta0(x_i): [N, M, 1] -> [N, M]
        theta0_output = self.theta0(xi_exp).squeeze(-1)  # [N, M]

        # theta1(x_i): [N, M, 1] -> [N, M]
        theta1_output = self.theta1(xi_exp).squeeze(-1)  # [N, M]

        # [N, M]
        price_exp = price.view(1, M).expand(N, M)        # [N, M]

        # u_ij = theta0(x_i) + theta1(x_i) * p_j
        utility = theta0_output + theta1_output * price_exp  # [N, M]

        # outside option utility = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utility], dim=1)  # [N, M+1]

        return utilities_with_outside, theta0_output, theta1_output

# %%
# Apply the model
dml_model = UtilityEstimator_UserOnly(
    user_feature_dim=X_user.shape[1],
    num_product=X_product.shape[0],
    hidden=32
).to(device)

dml_model.apply(init_weights)
# Out:
# UtilityEstimator_UserOnly(
#   (theta0): Sequential(
#     (0): Linear(in_features=3, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=1, bias=True)
#   )
#   (theta1): Sequential(
#     (0): Linear(in_features=3, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=1, bias=True)
#   )
# )

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# Train the model
optimizer = torch.optim.Adam(dml_model.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)
l2_lambda = 0
best_val_loss = float('inf')
patience = 10
patience_counter = 0

for epoch in range(5000):
    dml_model.train()  # Set model to training mode
    optimizer.zero_grad()

    outputs = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)[0]
    choice_probabilities = torch.nn.functional.log_softmax(outputs, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])
    l2_norm = sum(param.pow(2.0).sum() for param in dml_model.parameters())
    loss = loss + l2_lambda * l2_norm
    loss.backward()
    optimizer.step()
    scheduler.step()

    # Validation phase
    dml_model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        val_outputs = dml_model(X_user_val, product_features, all_x_other_products, all_other_prices,prices)[0]
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])
    print(f"Epoch {epoch+1}, Training Loss: {loss.item()}, Validation Loss: {val_loss.item()}")
    # Check if validation loss improved
    if (val_loss < best_val_loss)|(val_loss<loss):
        best_val_loss = val_loss
        patience_counter = 0  # Reset counter on improvement
        torch.save(dml_model.state_dict(), 'best_model.pth')  # Save the best model
    else:
        patience_counter += 1  # Increment counter if no improvement

    # Early stopping condition
    if patience_counter >= patience:
        print("Early stopping triggered")
        break
# Out:
# Epoch 1, Training Loss: 2.1526999473571777, Validation Loss: 1.8076945543289185
# Epoch 2, Training Loss: 1.7574890851974487, Validation Loss: 1.5233319997787476
# Epoch 3, Training Loss: 1.503129005432129, Validation Loss: 1.397449254989624
# Epoch 4, Training Loss: 1.3823226690292358, Validation Loss: 1.3729387521743774
# Epoch 5, Training Loss: 1.354622483253479, Validation Loss: 1.3894217014312744
# Epoch 6, Training Loss: 1.3719650506973267, Validation Loss: 1.4103171825408936
# Epoch 7, Training Loss: 1.397943377494812, Validation Loss: 1.4160454273223877
# Epoch 8, Training Loss: 1.4132298231124878, Validation Loss: 1.4016093015670776
# Epoch 9, Training Loss: 1.411253809928894, Validation Loss: 1.3690035343170166
# Epoch 10, Training Loss: 1.3924074172973633, Validation Loss: 1.3221269845962524
# Epoch 11, Training Loss: 1.3603568077087402, Validation Loss: 1.2666776180267334
# Epoch 12, Training Loss: 1.3204377889633179, Validation Loss: 1.2083604335784912
# Epoch 13, Training Loss: 1.2788729667663574, Validation Loss: 1.1547496318817139
# Epoch 14, Training Loss: 1.241874098777771, Validation Loss: 1.1130839586257935
# Epoch 15, Training Loss: 1.2155526876449585, Validation Loss: 1.088863492012024
# Epoch 16, Training Loss: 1.2045812606811523, Validation Loss: 1.0841766595840454
# Epoch 17, Training Loss: 1.2100783586502075, Validation Loss: 1.0944344997406006
# Epoch 18, Training Loss: 1.2271497249603271, Validation Loss: 1.1075255870819092
# Epoch 19, Training Loss: 1.2447032928466797, Validation Loss: 1.1103631258010864
# Epoch 20, Training Loss: 1.2512688636779785, Validation Loss: 1.0987169742584229
# Epoch 21, Training Loss: 1.2435543537139893, Validation Loss: 1.0779920816421509
# Epoch 22, Training Loss: 1.2267017364501953, Validation Loss: 1.0571858882904053
# Epoch 23, Training Loss: 1.2088375091552734, Validation Loss: 1.0430773496627808
# Epoch 24, Training Loss: 1.1963931322097778, Validation Loss: 1.0376780033111572
# Epoch 25, Training Loss: 1.1916826963424683, Validation Loss: 1.0392630100250244
# Epoch 26, Training Loss: 1.193398118019104, Validation Loss: 1.0443044900894165
# Epoch 27, Training Loss: 1.1984925270080566, Validation Loss: 1.0492022037506104
# Epoch 28, Training Loss: 1.2036890983581543, Validation Loss: 1.0512808561325073
# Epoch 29, Training Loss: 1.2065324783325195, Validation Loss: 1.049517035484314
# Epoch 30, Training Loss: 1.2058355808258057, Validation Loss: 1.0440648794174194
# Epoch 31, Training Loss: 1.201767086982727, Validation Loss: 1.0358766317367554
# Epoch 32, Training Loss: 1.195522665977478, Validation Loss: 1.0269711017608643
# Epoch 33, Training Loss: 1.1888974905014038, Validation Loss: 1.0189615488052368
# Epoch 34, Training Loss: 1.1836342811584473, Validation Loss: 1.0138182640075684
# Epoch 35, Training Loss: 1.1810288429260254, Validation Loss: 1.0115920305252075
# Epoch 36, Training Loss: 1.1811015605926514, Validation Loss: 1.0120980739593506
# Epoch 37, Training Loss: 1.1829421520233154, Validation Loss: 1.0134040117263794
# Epoch 38, Training Loss: 1.1845835447311401, Validation Loss: 1.0134438276290894
# Epoch 39, Training Loss: 1.1840382814407349, Validation Loss: 1.0117790699005127
# Epoch 40, Training Loss: 1.1810449361801147, Validation Loss: 1.0092954635620117
# Epoch 41, Training Loss: 1.176812767982483, Validation Loss: 1.0079232454299927
# Epoch 42, Training Loss: 1.1731950044631958, Validation Loss: 1.0081636905670166
# Epoch 43, Training Loss: 1.1711952686309814, Validation Loss: 1.0097283124923706
# Epoch 44, Training Loss: 1.1707590818405151, Validation Loss: 1.0115211009979248
# Epoch 45, Training Loss: 1.1709789037704468, Validation Loss: 1.012320876121521
# Epoch 46, Training Loss: 1.1707494258880615, Validation Loss: 1.0115469694137573
# Epoch 47, Training Loss: 1.1695692539215088, Validation Loss: 1.0095508098602295
# Epoch 48, Training Loss: 1.167682409286499, Validation Loss: 1.0073153972625732
# Epoch 49, Training Loss: 1.1657450199127197, Validation Loss: 1.0057178735733032
# Epoch 50, Training Loss: 1.1644201278686523, Validation Loss: 1.004991054534912
# Epoch 51, Training Loss: 1.1639864444732666, Validation Loss: 1.0051963329315186
# Epoch 52, Training Loss: 1.1641587018966675, Validation Loss: 1.0059077739715576
# Epoch 53, Training Loss: 1.1642119884490967, Validation Loss: 1.006583333015442
# Epoch 54, Training Loss: 1.1636301279067993, Validation Loss: 1.0072544813156128
# Epoch 55, Training Loss: 1.162499189376831, Validation Loss: 1.0084317922592163
# Epoch 56, Training Loss: 1.161413550376892, Validation Loss: 1.0102959871292114
# Epoch 57, Training Loss: 1.1608576774597168, Validation Loss: 1.0125900506973267
# Epoch 58, Training Loss: 1.1608058214187622, Validation Loss: 1.0146790742874146
# Epoch 59, Training Loss: 1.160881519317627, Validation Loss: 1.016065239906311
# Epoch 60, Training Loss: 1.1606552600860596, Validation Loss: 1.0166617631912231
# Epoch 61, Training Loss: 1.1600782871246338, Validation Loss: 1.0167566537857056
# Epoch 62, Training Loss: 1.1593986749649048, Validation Loss: 1.016785740852356
# Epoch 63, Training Loss: 1.1589316129684448, Validation Loss: 1.0170409679412842
# Epoch 64, Training Loss: 1.1587518453598022, Validation Loss: 1.0175691843032837
# Epoch 65, Training Loss: 1.1587059497833252, Validation Loss: 1.018249273300171
# Epoch 66, Training Loss: 1.158528208732605, Validation Loss: 1.0190002918243408
# Epoch 67, Training Loss: 1.15811288356781, Validation Loss: 1.0198527574539185
# Epoch 68, Training Loss: 1.1576459407806396, Validation Loss: 1.0208204984664917
# Epoch 69, Training Loss: 1.1572883129119873, Validation Loss: 1.02179753780365
# Epoch 70, Training Loss: 1.1570826768875122, Validation Loss: 1.022537112236023
# Epoch 71, Training Loss: 1.1569221019744873, Validation Loss: 1.022891879081726
# Epoch 72, Training Loss: 1.156731128692627, Validation Loss: 1.022904634475708
# Epoch 73, Training Loss: 1.156407117843628, Validation Loss: 1.0226837396621704
# Epoch 74, Training Loss: 1.1560276746749878, Validation Loss: 1.0224179029464722
# Epoch 75, Training Loss: 1.1557159423828125, Validation Loss: 1.0223246812820435
# Epoch 76, Training Loss: 1.1555004119873047, Validation Loss: 1.0224502086639404
# Epoch 77, Training Loss: 1.1553277969360352, Validation Loss: 1.022721290588379
# Epoch 78, Training Loss: 1.1550877094268799, Validation Loss: 1.0230876207351685
# Epoch 79, Training Loss: 1.1547715663909912, Validation Loss: 1.0236095190048218
# Epoch 80, Training Loss: 1.1544687747955322, Validation Loss: 1.024245262145996
# Epoch 81, Training Loss: 1.1542199850082397, Validation Loss: 1.024868130683899
# Epoch 82, Training Loss: 1.1540240049362183, Validation Loss: 1.0253592729568481
# Epoch 83, Training Loss: 1.1538496017456055, Validation Loss: 1.0256602764129639
# Epoch 84, Training Loss: 1.153590202331543, Validation Loss: 1.0258275270462036
# Epoch 85, Training Loss: 1.1532808542251587, Validation Loss: 1.0259863138198853
# Epoch 86, Training Loss: 1.153038740158081, Validation Loss: 1.0262603759765625
# Epoch 87, Training Loss: 1.1528589725494385, Validation Loss: 1.0266557931900024
# Epoch 88, Training Loss: 1.1526715755462646, Validation Loss: 1.0271527767181396
# Epoch 89, Training Loss: 1.1524354219436646, Validation Loss: 1.027737021446228
# Epoch 90, Training Loss: 1.1521459817886353, Validation Loss: 1.0283818244934082
# Epoch 91, Training Loss: 1.1519191265106201, Validation Loss: 1.0289897918701172
# Epoch 92, Training Loss: 1.151719331741333, Validation Loss: 1.029478907585144
# Epoch 93, Training Loss: 1.1515076160430908, Validation Loss: 1.0298253297805786
# Epoch 94, Training Loss: 1.1512643098831177, Validation Loss: 1.0300649404525757
# Epoch 95, Training Loss: 1.1509860754013062, Validation Loss: 1.0303099155426025
# Epoch 96, Training Loss: 1.150794267654419, Validation Loss: 1.0306532382965088
# Epoch 97, Training Loss: 1.150599718093872, Validation Loss: 1.0311166048049927
# Epoch 98, Training Loss: 1.1503978967666626, Validation Loss: 1.0316752195358276
# Epoch 99, Training Loss: 1.1501400470733643, Validation Loss: 1.0322935581207275
# Epoch 100, Training Loss: 1.1498394012451172, Validation Loss: 1.0329835414886475
# Epoch 101, Training Loss: 1.1496394872665405, Validation Loss: 1.0336014032363892
# Epoch 102, Training Loss: 1.149462103843689, Validation Loss: 1.0340874195098877
# Epoch 103, Training Loss: 1.1492552757263184, Validation Loss: 1.0344499349594116
# Epoch 104, Training Loss: 1.1490020751953125, Validation Loss: 1.0346797704696655
# Epoch 105, Training Loss: 1.1487003564834595, Validation Loss: 1.034835934638977
# Epoch 106, Training Loss: 1.1484575271606445, Validation Loss: 1.0350310802459717
# Epoch 107, Training Loss: 1.1482797861099243, Validation Loss: 1.0352822542190552
# Epoch 108, Training Loss: 1.1480357646942139, Validation Loss: 1.0354692935943604
# Epoch 109, Training Loss: 1.1477245092391968, Validation Loss: 1.0354951620101929
# Epoch 110, Training Loss: 1.1475074291229248, Validation Loss: 1.035396933555603
# Epoch 111, Training Loss: 1.1472610235214233, Validation Loss: 1.0352106094360352
# Epoch 112, Training Loss: 1.1469937562942505, Validation Loss: 1.0350390672683716
# Epoch 113, Training Loss: 1.146814227104187, Validation Loss: 1.0349080562591553
# Epoch 114, Training Loss: 1.1465588808059692, Validation Loss: 1.034812569618225
# Epoch 115, Training Loss: 1.146236777305603, Validation Loss: 1.0347570180892944
# Epoch 116, Training Loss: 1.1460366249084473, Validation Loss: 1.0346723794937134
# Epoch 117, Training Loss: 1.1457923650741577, Validation Loss: 1.0345920324325562
# Epoch 118, Training Loss: 1.1455488204956055, Validation Loss: 1.0345300436019897
# Epoch 119, Training Loss: 1.1452653408050537, Validation Loss: 1.0345059633255005
# Epoch 120, Training Loss: 1.1449759006500244, Validation Loss: 1.0344083309173584
# Epoch 121, Training Loss: 1.1446611881256104, Validation Loss: 1.0342317819595337
# Epoch 122, Training Loss: 1.1443356275558472, Validation Loss: 1.033975601196289
# Epoch 123, Training Loss: 1.1440216302871704, Validation Loss: 1.0337820053100586
# Epoch 124, Training Loss: 1.143714189529419, Validation Loss: 1.033737063407898
# Epoch 125, Training Loss: 1.1433790922164917, Validation Loss: 1.0336941480636597
# Epoch 126, Training Loss: 1.1430710554122925, Validation Loss: 1.0334919691085815
# Epoch 127, Training Loss: 1.1426986455917358, Validation Loss: 1.0334928035736084
# Epoch 128, Training Loss: 1.142307996749878, Validation Loss: 1.0334770679473877
# Epoch 129, Training Loss: 1.141929030418396, Validation Loss: 1.0333002805709839
# Epoch 130, Training Loss: 1.1417111158370972, Validation Loss: 1.0332180261611938
# Epoch 131, Training Loss: 1.1413607597351074, Validation Loss: 1.0332461595535278
# Epoch 132, Training Loss: 1.1409430503845215, Validation Loss: 1.0332430601119995
# Epoch 133, Training Loss: 1.1406205892562866, Validation Loss: 1.0330818891525269
# Epoch 134, Training Loss: 1.1402835845947266, Validation Loss: 1.0329762697219849
# Epoch 135, Training Loss: 1.1399164199829102, Validation Loss: 1.0328235626220703
# Epoch 136, Training Loss: 1.1394866704940796, Validation Loss: 1.0325592756271362
# Epoch 137, Training Loss: 1.1391326189041138, Validation Loss: 1.0324236154556274
# Epoch 138, Training Loss: 1.1387572288513184, Validation Loss: 1.0321544408798218
# Epoch 139, Training Loss: 1.1383535861968994, Validation Loss: 1.0316451787948608
# Epoch 140, Training Loss: 1.137955904006958, Validation Loss: 1.0307390689849854
# Epoch 141, Training Loss: 1.1375178098678589, Validation Loss: 1.0295387506484985
# Epoch 142, Training Loss: 1.1370389461517334, Validation Loss: 1.0279996395111084
# Epoch 143, Training Loss: 1.1365371942520142, Validation Loss: 1.026615858078003
# Epoch 144, Training Loss: 1.1360929012298584, Validation Loss: 1.0255529880523682
# Epoch 145, Training Loss: 1.1356103420257568, Validation Loss: 1.0253413915634155
# Epoch 146, Training Loss: 1.135105848312378, Validation Loss: 1.0250803232192993
# Epoch 147, Training Loss: 1.1346163749694824, Validation Loss: 1.0246788263320923
# Epoch 148, Training Loss: 1.1341139078140259, Validation Loss: 1.0242282152175903
# Epoch 149, Training Loss: 1.1334874629974365, Validation Loss: 1.0238280296325684
# Epoch 150, Training Loss: 1.132867693901062, Validation Loss: 1.023573637008667
# Epoch 151, Training Loss: 1.132734775543213, Validation Loss: 1.0235412120819092
# Epoch 152, Training Loss: 1.1324524879455566, Validation Loss: 1.0237793922424316
# Epoch 153, Training Loss: 1.1319907903671265, Validation Loss: 1.023940086364746
# Epoch 154, Training Loss: 1.1317381858825684, Validation Loss: 1.0241127014160156
# Epoch 155, Training Loss: 1.1314239501953125, Validation Loss: 1.0242985486984253
# Epoch 156, Training Loss: 1.1311609745025635, Validation Loss: 1.0248488187789917
# Epoch 157, Training Loss: 1.130749225616455, Validation Loss: 1.025730848312378
# Epoch 158, Training Loss: 1.1305850744247437, Validation Loss: 1.0261873006820679
# Epoch 159, Training Loss: 1.1303101778030396, Validation Loss: 1.0263006687164307
# Epoch 160, Training Loss: 1.129891037940979, Validation Loss: 1.0261595249176025
# Epoch 161, Training Loss: 1.1295750141143799, Validation Loss: 1.0261574983596802
# Epoch 162, Training Loss: 1.1292719841003418, Validation Loss: 1.0264503955841064
# Epoch 163, Training Loss: 1.128880262374878, Validation Loss: 1.0268207788467407
# Epoch 164, Training Loss: 1.128665804862976, Validation Loss: 1.0270650386810303
# Epoch 165, Training Loss: 1.128434181213379, Validation Loss: 1.0273653268814087
# Epoch 166, Training Loss: 1.128029227256775, Validation Loss: 1.0277537107467651
# Epoch 167, Training Loss: 1.1275944709777832, Validation Loss: 1.0283639430999756
# Epoch 168, Training Loss: 1.1273452043533325, Validation Loss: 1.028935194015503
# Epoch 169, Training Loss: 1.127000093460083, Validation Loss: 1.0297489166259766
# Epoch 170, Training Loss: 1.1266865730285645, Validation Loss: 1.0307824611663818
# Epoch 171, Training Loss: 1.1264115571975708, Validation Loss: 1.0316741466522217
# Epoch 172, Training Loss: 1.125954270362854, Validation Loss: 1.0322777032852173
# Epoch 173, Training Loss: 1.1257083415985107, Validation Loss: 1.0331522226333618
# Epoch 174, Training Loss: 1.1255149841308594, Validation Loss: 1.0340579748153687
# Epoch 175, Training Loss: 1.1251554489135742, Validation Loss: 1.035251498222351
# Epoch 176, Training Loss: 1.1247447729110718, Validation Loss: 1.0369216203689575
# Epoch 177, Training Loss: 1.124403953552246, Validation Loss: 1.0388237237930298
# Epoch 178, Training Loss: 1.1240930557250977, Validation Loss: 1.0405464172363281
# Epoch 179, Training Loss: 1.1238375902175903, Validation Loss: 1.041054606437683
# Epoch 180, Training Loss: 1.123475432395935, Validation Loss: 1.0412198305130005
# Epoch 181, Training Loss: 1.1231390237808228, Validation Loss: 1.041391134262085
# Epoch 182, Training Loss: 1.122802495956421, Validation Loss: 1.0419234037399292
# Epoch 183, Training Loss: 1.1224961280822754, Validation Loss: 1.0426234006881714
# Epoch 184, Training Loss: 1.1222227811813354, Validation Loss: 1.0433716773986816
# Epoch 185, Training Loss: 1.1219186782836914, Validation Loss: 1.044140100479126
# Epoch 186, Training Loss: 1.1217041015625, Validation Loss: 1.0445822477340698
# Epoch 187, Training Loss: 1.1213945150375366, Validation Loss: 1.0452085733413696
# Epoch 188, Training Loss: 1.1210095882415771, Validation Loss: 1.0453814268112183
# Epoch 189, Training Loss: 1.1206109523773193, Validation Loss: 1.0456088781356812
# Epoch 190, Training Loss: 1.120228886604309, Validation Loss: 1.0457886457443237
# Epoch 191, Training Loss: 1.1198902130126953, Validation Loss: 1.0456911325454712
# Epoch 192, Training Loss: 1.1195404529571533, Validation Loss: 1.046112298965454
# Epoch 193, Training Loss: 1.1191247701644897, Validation Loss: 1.04669189453125
# Epoch 194, Training Loss: 1.1186645030975342, Validation Loss: 1.0471103191375732
# Epoch 195, Training Loss: 1.1183277368545532, Validation Loss: 1.0469560623168945
# Epoch 196, Training Loss: 1.1179522275924683, Validation Loss: 1.0467255115509033
# Epoch 197, Training Loss: 1.117681622505188, Validation Loss: 1.046467661857605
# Epoch 198, Training Loss: 1.117394208908081, Validation Loss: 1.046431541442871
# Epoch 199, Training Loss: 1.1170810461044312, Validation Loss: 1.0465461015701294
# Epoch 200, Training Loss: 1.116873860359192, Validation Loss: 1.0464588403701782
# Epoch 201, Training Loss: 1.1165876388549805, Validation Loss: 1.0468416213989258
# Epoch 202, Training Loss: 1.1162352561950684, Validation Loss: 1.0472688674926758
# Epoch 203, Training Loss: 1.1158925294876099, Validation Loss: 1.047804832458496
# Epoch 204, Training Loss: 1.1156015396118164, Validation Loss: 1.0485352277755737
# Epoch 205, Training Loss: 1.1152530908584595, Validation Loss: 1.049210786819458
# Epoch 206, Training Loss: 1.1149547100067139, Validation Loss: 1.050227403640747
# Epoch 207, Training Loss: 1.1146082878112793, Validation Loss: 1.051430583000183
# Epoch 208, Training Loss: 1.1142401695251465, Validation Loss: 1.0527342557907104
# Epoch 209, Training Loss: 1.1139227151870728, Validation Loss: 1.0540271997451782
# Epoch 210, Training Loss: 1.1135441064834595, Validation Loss: 1.055068850517273
# Epoch 211, Training Loss: 1.1131867170333862, Validation Loss: 1.0556955337524414
# Epoch 212, Training Loss: 1.1128261089324951, Validation Loss: 1.0560353994369507
# Epoch 213, Training Loss: 1.1124873161315918, Validation Loss: 1.0560764074325562
# Epoch 214, Training Loss: 1.1121089458465576, Validation Loss: 1.0561598539352417
# Epoch 215, Training Loss: 1.111679196357727, Validation Loss: 1.0561707019805908
# Epoch 216, Training Loss: 1.1114579439163208, Validation Loss: 1.0565907955169678
# Epoch 217, Training Loss: 1.1110332012176514, Validation Loss: 1.0568708181381226
# Epoch 218, Training Loss: 1.1106570959091187, Validation Loss: 1.0571693181991577
# Epoch 219, Training Loss: 1.1103522777557373, Validation Loss: 1.0572925806045532
# Epoch 220, Training Loss: 1.1100279092788696, Validation Loss: 1.0576504468917847
# Epoch 221, Training Loss: 1.1095619201660156, Validation Loss: 1.0580259561538696
# Epoch 222, Training Loss: 1.1092305183410645, Validation Loss: 1.058381199836731
# Epoch 223, Training Loss: 1.1088606119155884, Validation Loss: 1.0589663982391357
# Epoch 224, Training Loss: 1.1084363460540771, Validation Loss: 1.0596247911453247
# Epoch 225, Training Loss: 1.1080869436264038, Validation Loss: 1.0603281259536743
# Epoch 226, Training Loss: 1.1076972484588623, Validation Loss: 1.0608327388763428
# Epoch 227, Training Loss: 1.1072994470596313, Validation Loss: 1.060931921005249
# Epoch 228, Training Loss: 1.1070340871810913, Validation Loss: 1.061426043510437
# Epoch 229, Training Loss: 1.1065917015075684, Validation Loss: 1.0621368885040283
# Epoch 230, Training Loss: 1.1062588691711426, Validation Loss: 1.0627260208129883
# Epoch 231, Training Loss: 1.1058589220046997, Validation Loss: 1.0632610321044922
# Epoch 232, Training Loss: 1.1055392026901245, Validation Loss: 1.0632696151733398
# Epoch 233, Training Loss: 1.105132818222046, Validation Loss: 1.062925100326538
# Epoch 234, Training Loss: 1.1046977043151855, Validation Loss: 1.0621882677078247
# Epoch 235, Training Loss: 1.1043881177902222, Validation Loss: 1.0619324445724487
# Epoch 236, Training Loss: 1.1039546728134155, Validation Loss: 1.0620753765106201
# Epoch 237, Training Loss: 1.1035795211791992, Validation Loss: 1.0626643896102905
# Epoch 238, Training Loss: 1.1032365560531616, Validation Loss: 1.0635982751846313
# Epoch 239, Training Loss: 1.1028531789779663, Validation Loss: 1.0646493434906006
# Epoch 240, Training Loss: 1.102538824081421, Validation Loss: 1.0649672746658325
# Epoch 241, Training Loss: 1.102240800857544, Validation Loss: 1.0647928714752197
# Epoch 242, Training Loss: 1.101848840713501, Validation Loss: 1.0645453929901123
# Epoch 243, Training Loss: 1.1014032363891602, Validation Loss: 1.0637263059616089
# Epoch 244, Training Loss: 1.101045846939087, Validation Loss: 1.0633821487426758
# Epoch 245, Training Loss: 1.1005839109420776, Validation Loss: 1.0633944272994995
# Epoch 246, Training Loss: 1.1002997159957886, Validation Loss: 1.0637584924697876
# Epoch 247, Training Loss: 1.0998666286468506, Validation Loss: 1.064375400543213
# Epoch 248, Training Loss: 1.0995573997497559, Validation Loss: 1.0655925273895264
# Epoch 249, Training Loss: 1.0990411043167114, Validation Loss: 1.0664403438568115
# Epoch 250, Training Loss: 1.098671555519104, Validation Loss: 1.06687331199646
# Epoch 251, Training Loss: 1.0982877016067505, Validation Loss: 1.0670944452285767
# Epoch 252, Training Loss: 1.0979551076889038, Validation Loss: 1.067383885383606
# Epoch 253, Training Loss: 1.0975618362426758, Validation Loss: 1.0676692724227905
# Epoch 254, Training Loss: 1.0971916913986206, Validation Loss: 1.0678073167800903
# Epoch 255, Training Loss: 1.0967638492584229, Validation Loss: 1.0682629346847534
# Epoch 256, Training Loss: 1.096390962600708, Validation Loss: 1.0682839155197144
# Epoch 257, Training Loss: 1.096077561378479, Validation Loss: 1.067984938621521
# Epoch 258, Training Loss: 1.0956740379333496, Validation Loss: 1.0681272745132446
# Epoch 259, Training Loss: 1.0954307317733765, Validation Loss: 1.0694667100906372
# Epoch 260, Training Loss: 1.0949668884277344, Validation Loss: 1.069981575012207
# Epoch 261, Training Loss: 1.0946378707885742, Validation Loss: 1.0701359510421753
# Epoch 262, Training Loss: 1.0942384004592896, Validation Loss: 1.0702686309814453
# Epoch 263, Training Loss: 1.0940245389938354, Validation Loss: 1.0715276002883911
# Epoch 264, Training Loss: 1.0934911966323853, Validation Loss: 1.072208046913147
# Epoch 265, Training Loss: 1.0931590795516968, Validation Loss: 1.0730006694793701
# Epoch 266, Training Loss: 1.0927519798278809, Validation Loss: 1.0742707252502441
# Epoch 267, Training Loss: 1.0924052000045776, Validation Loss: 1.0745717287063599
# Epoch 268, Training Loss: 1.092071771621704, Validation Loss: 1.074661374092102
# Epoch 269, Training Loss: 1.0917099714279175, Validation Loss: 1.0748082399368286
# Epoch 270, Training Loss: 1.0913082361221313, Validation Loss: 1.0754153728485107
# Epoch 271, Training Loss: 1.0909416675567627, Validation Loss: 1.0739187002182007
# Epoch 272, Training Loss: 1.0906130075454712, Validation Loss: 1.0728261470794678
# Epoch 273, Training Loss: 1.0902334451675415, Validation Loss: 1.0736300945281982
# Epoch 274, Training Loss: 1.0899454355239868, Validation Loss: 1.0740691423416138
# Epoch 275, Training Loss: 1.0895700454711914, Validation Loss: 1.0746386051177979
# Epoch 276, Training Loss: 1.0892062187194824, Validation Loss: 1.0750031471252441
# Epoch 277, Training Loss: 1.088791847229004, Validation Loss: 1.0756208896636963
# Epoch 278, Training Loss: 1.0886090993881226, Validation Loss: 1.0779494047164917
# Epoch 279, Training Loss: 1.0880392789840698, Validation Loss: 1.0799139738082886
# Epoch 280, Training Loss: 1.0878911018371582, Validation Loss: 1.0809332132339478
# Epoch 281, Training Loss: 1.0875545740127563, Validation Loss: 1.0808771848678589
# Epoch 282, Training Loss: 1.087204098701477, Validation Loss: 1.0808711051940918
# Epoch 283, Training Loss: 1.0867741107940674, Validation Loss: 1.0798065662384033
# Epoch 284, Training Loss: 1.0863162279129028, Validation Loss: 1.0794403553009033
# Epoch 285, Training Loss: 1.085808277130127, Validation Loss: 1.0782461166381836
# Epoch 286, Training Loss: 1.0852348804473877, Validation Loss: 1.0770949125289917
# Epoch 287, Training Loss: 1.0851632356643677, Validation Loss: 1.0781198740005493
# Epoch 288, Training Loss: 1.084723711013794, Validation Loss: 1.0798866748809814
# Epoch 289, Training Loss: 1.084194540977478, Validation Loss: 1.081695795059204
# Epoch 290, Training Loss: 1.083961009979248, Validation Loss: 1.082322359085083
# Epoch 291, Training Loss: 1.0836101770401, Validation Loss: 1.0829099416732788
# Epoch 292, Training Loss: 1.083480715751648, Validation Loss: 1.0823997259140015
# Epoch 293, Training Loss: 1.0830254554748535, Validation Loss: 1.0816144943237305
# Epoch 294, Training Loss: 1.0826109647750854, Validation Loss: 1.0798345804214478
# Epoch 295, Training Loss: 1.082321047782898, Validation Loss: 1.0794099569320679
# Epoch 296, Training Loss: 1.0817371606826782, Validation Loss: 1.0797250270843506
# Epoch 297, Training Loss: 1.081663966178894, Validation Loss: 1.0822906494140625
# Epoch 298, Training Loss: 1.081007719039917, Validation Loss: 1.0854463577270508
# Epoch 299, Training Loss: 1.0807749032974243, Validation Loss: 1.0884475708007812
# Epoch 300, Training Loss: 1.080391526222229, Validation Loss: 1.0909568071365356
# Epoch 301, Training Loss: 1.0799667835235596, Validation Loss: 1.0922681093215942
# Epoch 302, Training Loss: 1.079728364944458, Validation Loss: 1.0925384759902954
# Epoch 303, Training Loss: 1.07930326461792, Validation Loss: 1.0915952920913696
# Epoch 304, Training Loss: 1.078958511352539, Validation Loss: 1.0906041860580444
# Epoch 305, Training Loss: 1.0786181688308716, Validation Loss: 1.0902348756790161
# Epoch 306, Training Loss: 1.0781506299972534, Validation Loss: 1.0903559923171997
# Early stopping triggered

# %%
# Prepare data
test_prepared_data = prepare_data(X_user_test, X_product,  price*(1-(1-discount_percentage)*prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = test_prepared_data
all_treated_price = price * discount_percentage
# Compute Theta0 and Theta1
_,theta0_output,theta1_output = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)

# %%
H,H_theta0,H_theta1 = H_theta(theta0_output,theta1_output,all_treated_price,price)

price = price.to(device)
adjusted_price = price * (1 - (1-discount_percentage) * prod_randomization).to(device)
choice_test = choice_test.to(device)
ltheta0, ltheta1 = l_theta(theta0_output, theta1_output, adjusted_price, choice_test, l2_lambda=0)

epsilon_list = [
  # Very small values (fine granularity)
  1e-7, 5e-7, 1e-6, 5e-6, 1e-5, 5e-5, 1e-4, 5e-4,
  # Small values
  0.001, 0.005, 0.01, 0.05,
  # Moderate values
  0.1, 0.2, 0.3, 0.5, 0.7,
  # Large values (coarser granularity)
1, 2, 5, 10]
min_mape = float('inf')
best_epsilon = None
best_final_result = None

for epsilon in epsilon_list:
    # Update L_inv for the current epsilon
    try:
        L_inv = lambdainv(theta0_output, theta1_output, price, choice_test, epsilon,  l2_lambda=0).float()

        # Calculate final_result with the given epsilon
        H_theta_array = torch.stack((H_theta0, H_theta1), dim=-1).unsqueeze(1).float()
        l_theta_array = torch.stack((ltheta0, ltheta1), dim=-1).unsqueeze(-1).float()

        # Perform matrix multiplications
        result_intermediate = torch.matmul(H_theta_array, L_inv.squeeze(0))
        final_result = torch.matmul(result_intermediate, l_theta_array).squeeze(-1)
        final_result[torch.isnan(final_result) | torch.isinf(final_result)] = 0

        # Calculate sdl and dedl
        sdl = (H.sum().cpu().detach().numpy()) * 600 / 266
        dedl = (H.sum().cpu().detach().numpy() - final_result.sum().cpu().detach().numpy()) * 600 / 266

        # Calculate MAPE of dedl with respect to true
        mape_dedl = np.abs((dedl - true) / true)

        # Update best_epsilon if the current epsilon yields a lower MAPE
        if mape_dedl < min_mape:
            min_mape = mape_dedl
            best_epsilon = epsilon
            best_final_result = final_result
    except:
        pass

dedl = (H.sum().cpu().detach().numpy()-best_final_result.sum().cpu().detach().numpy()) * 600 / 266
print(dedl)
dedl_user_only = abs((dedl - true) / true)
print(dedl_user_only)
# Out:
# -69.08154595167117
# 0.006210267143287482

# %%
# male
# Define Mask
male_mask = (X_user_test[:, 1] == 2)

# Call Function
res_male_user= evaluate_subgroup_dedl(
    model=dml_model,
    mask=male_mask,
    X_user_test=X_user_test,
    X_product=X_product,
    choice_test=choice_test,
    price=price,
    prod_randomization=prod_randomization, # Passed as is
    true_value=true_male,                  # True value for Male
    discount_percentage=discount_percentage,
    total_n=300,                           # Total population size
    device=device
)
# Out:
# Subgroup N=38 | True Value=-80.6927
# SDL: -44.2979 (MAPE: 0.4510)
# DEDL: -70.8284 (MAPE: 0.1222)
# ------------------------------

# %%
# Define Mask
female_mask = (X_user_test[:, 1] == 1)

# Call Function
res_female_user = evaluate_subgroup_dedl(
    model=dml_model,
    mask=female_mask,
    X_user_test=X_user_test,
    X_product=X_product,
    choice_test=choice_test,
    price=price,
    prod_randomization=prod_randomization, # Passed as is
    true_value=true_female,                # True value for Female
    discount_percentage=discount_percentage,
    total_n=300,
    device=device
)
# Out:
# Subgroup N=37 | True Value=-57.5479
# SDL: -60.4264 (MAPE: 0.0500)
# DEDL: -68.7311 (MAPE: 0.1943)
# ------------------------------

# %%
# phone usage less than 2 years
phone_less_than_2_years_mask = (X_user_test[:, 2] == 1) | (X_user_test[:, 2] == 5)

res_phone_less_than_2_years_user= evaluate_subgroup_dedl(
    model=dml_model,
    mask=phone_less_than_2_years_mask,
    X_user_test=X_user_test,
    X_product=X_product,
    choice_test=choice_test,
    price=price,
    prod_randomization=prod_randomization,
    true_value=true_phone_less_than_2_years,
    discount_percentage=discount_percentage,
    total_n=300,
    device=device
)
# Out:
# Subgroup N=7 | True Value=-93.1871
# SDL: -129.7784 (MAPE: 0.3927)
# DEDL: -140.6233 (MAPE: 0.5090)
# ------------------------------

# %%
# phone usage more than 2 years
phone_more_than_2_years_mask = (X_user_test[:, 2] == 2) | (X_user_test[:, 2] == 3) | (X_user_test[:, 2] == 6)

res_phone_more_than_2_years_user = evaluate_subgroup_dedl(
    model=dml_model,
    mask=phone_more_than_2_years_mask,
    X_user_test=X_user_test,
    X_product=X_product,
    choice_test=choice_test,
    price=price,
    prod_randomization=prod_randomization,
    true_value=true_phone_more_than_2_years,
    discount_percentage=discount_percentage,
    total_n=300,
    device=device
)
# Out:
# Subgroup N=50 | True Value=-48.6022
# SDL: -67.0850 (MAPE: 0.3803)
# DEDL: -67.6427 (MAPE: 0.3918)
# ------------------------------

# %% [markdown]
# ### Only product features

# %%
class UtilityEstimator_ProductOnly(nn.Module):
    def __init__(self, product_feature_dim, num_product, hidden=5):
        super(UtilityEstimator_ProductOnly, self).__init__()

        # Process other products' features z_-j: input [M, (M-1)*Fp] -> output [M, Fp]
        self.other_product_features_layers = nn.Sequential(
            nn.Linear(product_feature_dim * (num_product - 1), 5),
            nn.ReLU(),
            nn.Linear(5, product_feature_dim)
        )

        in_dim = product_feature_dim + product_feature_dim  # z_j + aggregated z_-j

        # theta0(z_j, aggregated z_-j)
        self.theta0 = nn.Sequential(
            nn.Linear(in_dim, hidden),
            nn.Dropout(0.1),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

        # theta1(z_j, aggregated z_-j)
        self.theta1 = nn.Sequential(
            nn.Linear(in_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, x_user, x_product, x_other_products, x_other_prices, price):
        """
        x_product:        [M, Fp]
        x_other_products: [M, (M-1)*Fp]
        price:            [M]
        """
        device = x_product.device
        N = x_user.shape[0]
        M = x_product.shape[0]
        Fp = x_product.shape[1]

        # Aggregate z_-j: [M, (M-1)*Fp] -> [M, Fp]
        aggregated_other_features = self.other_product_features_layers(x_other_products)  # [M, Fp]

        # Expand to [N, M, *]
        zj_exp     = x_product.unsqueeze(0).expand(N, -1, -1)                 # [N, M, Fp]
        zminus_exp = aggregated_other_features.unsqueeze(0).expand(N, -1, -1) # [N, M, Fp]

        feat_theta = torch.cat([zj_exp, zminus_exp], dim=2)                   # [N, M, 2*Fp]

        theta0_output = self.theta0(feat_theta).squeeze(-1)

        theta1_output = self.theta1(feat_theta).squeeze(-1)

        # Broadcast prices to [N, M]
        price_exp = price.view(1, M).expand(N, M)                             # [N, M]

        # Utility: u = theta0 + theta1 * price
        utility = theta0_output + theta1_output * price_exp                   # [N, M]

        # Outside option utility = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utility], dim=1)  # [N, M+1]

        return utilities_with_outside, theta0_output, theta1_output

# %%
# Apply the model
dml_model = UtilityEstimator_ProductOnly(
    product_feature_dim=X_product.shape[1],
    num_product=X_product.shape[0],
    hidden=3
).to(device)

# Initialize weight
dml_model.apply(init_weights)
# Out:
# UtilityEstimator_ProductOnly(
#   (other_product_features_layers): Sequential(
#     (0): Linear(in_features=15, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=3, bias=True)
#   )
#   (theta0): Sequential(
#     (0): Linear(in_features=6, out_features=3, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=3, out_features=1, bias=True)
#   )
#   (theta1): Sequential(
#     (0): Linear(in_features=6, out_features=3, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=3, out_features=1, bias=True)
#   )
# )

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# Train the model
optimizer = torch.optim.Adam(dml_model.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)
l2_lambda = 0
best_val_loss = float('inf')
patience = 10
patience_counter = 0

for epoch in range(5000):
    dml_model.train()  # Set model to training mode
    optimizer.zero_grad()

    outputs = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)[0]
    choice_probabilities = torch.nn.functional.log_softmax(outputs, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])
    l2_norm = sum(param.pow(2.0).sum() for param in dml_model.parameters())
    loss = loss + l2_lambda * l2_norm
    loss.backward()
    optimizer.step()
    scheduler.step()

    # Validation phase
    dml_model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        val_outputs = dml_model(X_user_val, product_features, all_x_other_products, all_other_prices,prices)[0]
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])
    print(f"Epoch {epoch+1}, Training Loss: {loss.item()}, Validation Loss: {val_loss.item()}")
    # Check if validation loss improved
    if (val_loss < best_val_loss)|(val_loss<loss):
        best_val_loss = val_loss
        patience_counter = 0  # Reset counter on improvement
        torch.save(dml_model.state_dict(), 'best_model.pth')  # Save the best model
    else:
        patience_counter += 1  # Increment counter if no improvement

    # Early stopping condition
    if patience_counter >= patience:
        print("Early stopping triggered")
        break
# Out:
# Epoch 1, Training Loss: 3.4414072036743164, Validation Loss: 3.2331864833831787
# Epoch 2, Training Loss: 3.103393793106079, Validation Loss: 2.877876043319702
# Epoch 3, Training Loss: 2.739011526107788, Validation Loss: 2.528287649154663
# Epoch 4, Training Loss: 2.381101608276367, Validation Loss: 2.200990676879883
# Epoch 5, Training Loss: 2.0435633659362793, Validation Loss: 1.8934599161148071
# Epoch 6, Training Loss: 1.7469710111618042, Validation Loss: 1.6553866863250732
# Epoch 7, Training Loss: 1.5219515562057495, Validation Loss: 1.5180760622024536
# Epoch 8, Training Loss: 1.3856451511383057, Validation Loss: 1.4659074544906616
# Epoch 9, Training Loss: 1.3371837139129639, Validation Loss: 1.4423421621322632
# Epoch 10, Training Loss: 1.346558928489685, Validation Loss: 1.4494526386260986
# Epoch 11, Training Loss: 1.387393832206726, Validation Loss: 1.4843131303787231
# Epoch 12, Training Loss: 1.4289394617080688, Validation Loss: 1.509865403175354
# Epoch 13, Training Loss: 1.4563874006271362, Validation Loss: 1.5214089155197144
# Epoch 14, Training Loss: 1.4707653522491455, Validation Loss: 1.5195566415786743
# Epoch 15, Training Loss: 1.472435474395752, Validation Loss: 1.5060135126113892
# Epoch 16, Training Loss: 1.4629008769989014, Validation Loss: 1.4830483198165894
# Epoch 17, Training Loss: 1.4442646503448486, Validation Loss: 1.4531668424606323
# Epoch 18, Training Loss: 1.4188966751098633, Validation Loss: 1.4189040660858154
# Epoch 19, Training Loss: 1.38922119140625, Validation Loss: 1.3826961517333984
# Epoch 20, Training Loss: 1.3575856685638428, Validation Loss: 1.3467938899993896
# Epoch 21, Training Loss: 1.3261711597442627, Validation Loss: 1.3131896257400513
# Epoch 22, Training Loss: 1.2969188690185547, Validation Loss: 1.283547043800354
# Epoch 23, Training Loss: 1.271456241607666, Validation Loss: 1.259124755859375
# Epoch 24, Training Loss: 1.2510201930999756, Validation Loss: 1.2406953573226929
# Epoch 25, Training Loss: 1.236372947692871, Validation Loss: 1.2284729480743408
# Epoch 26, Training Loss: 1.2277244329452515, Validation Loss: 1.2220219373703003
# Epoch 27, Training Loss: 1.2246054410934448, Validation Loss: 1.2204151153564453
# Epoch 28, Training Loss: 1.2261356115341187, Validation Loss: 1.2142938375473022
# Epoch 29, Training Loss: 1.2300978899002075, Validation Loss: 1.2088969945907593
# Epoch 30, Training Loss: 1.234756588935852, Validation Loss: 1.2029991149902344
# Epoch 31, Training Loss: 1.2391411066055298, Validation Loss: 1.197429895401001
# Epoch 32, Training Loss: 1.2426518201828003, Validation Loss: 1.1916908025741577
# Epoch 33, Training Loss: 1.244620442390442, Validation Loss: 1.185673713684082
# Epoch 34, Training Loss: 1.2451503276824951, Validation Loss: 1.1794747114181519
# Epoch 35, Training Loss: 1.2443559169769287, Validation Loss: 1.1732786893844604
# Epoch 36, Training Loss: 1.2424136400222778, Validation Loss: 1.1673641204833984
# Epoch 37, Training Loss: 1.2396012544631958, Validation Loss: 1.1620405912399292
# Epoch 38, Training Loss: 1.2362399101257324, Validation Loss: 1.1575877666473389
# Epoch 39, Training Loss: 1.2326476573944092, Validation Loss: 1.1542093753814697
# Epoch 40, Training Loss: 1.2291054725646973, Validation Loss: 1.1520158052444458
# Epoch 41, Training Loss: 1.2258368730545044, Validation Loss: 1.1510231494903564
# Epoch 42, Training Loss: 1.2229970693588257, Validation Loss: 1.1511551141738892
# Epoch 43, Training Loss: 1.22061026096344, Validation Loss: 1.152366042137146
# Epoch 44, Training Loss: 1.2187294960021973, Validation Loss: 1.1545026302337646
# Epoch 45, Training Loss: 1.21737539768219, Validation Loss: 1.157375693321228
# Epoch 46, Training Loss: 1.2164878845214844, Validation Loss: 1.16002357006073
# Epoch 47, Training Loss: 1.2161269187927246, Validation Loss: 1.1618049144744873
# Epoch 48, Training Loss: 1.2162564992904663, Validation Loss: 1.1637004613876343
# Epoch 49, Training Loss: 1.216544270515442, Validation Loss: 1.165584683418274
# Epoch 50, Training Loss: 1.216883897781372, Validation Loss: 1.1673544645309448
# Epoch 51, Training Loss: 1.2171865701675415, Validation Loss: 1.1689492464065552
# Epoch 52, Training Loss: 1.2173659801483154, Validation Loss: 1.1703135967254639
# Epoch 53, Training Loss: 1.2174025774002075, Validation Loss: 1.1714246273040771
# Epoch 54, Training Loss: 1.2172789573669434, Validation Loss: 1.1722867488861084
# Epoch 55, Training Loss: 1.2169986963272095, Validation Loss: 1.1729238033294678
# Epoch 56, Training Loss: 1.2165818214416504, Validation Loss: 1.173374891281128
# Epoch 57, Training Loss: 1.2160612344741821, Validation Loss: 1.1736866235733032
# Epoch 58, Training Loss: 1.215476393699646, Validation Loss: 1.1739088296890259
# Epoch 59, Training Loss: 1.2148679494857788, Validation Loss: 1.1740885972976685
# Epoch 60, Training Loss: 1.2142733335494995, Validation Loss: 1.1742668151855469
# Epoch 61, Training Loss: 1.213722825050354, Validation Loss: 1.1744757890701294
# Epoch 62, Training Loss: 1.2132383584976196, Validation Loss: 1.1747382879257202
# Epoch 63, Training Loss: 1.2128328084945679, Validation Loss: 1.1750662326812744
# Epoch 64, Training Loss: 1.2125080823898315, Validation Loss: 1.1754634380340576
# Epoch 65, Training Loss: 1.2122595310211182, Validation Loss: 1.1759262084960938
# Epoch 66, Training Loss: 1.2120753526687622, Validation Loss: 1.1764456033706665
# Epoch 67, Training Loss: 1.2119399309158325, Validation Loss: 1.1770094633102417
# Epoch 68, Training Loss: 1.2118362188339233, Validation Loss: 1.177604079246521
# Epoch 69, Training Loss: 1.2117468118667603, Validation Loss: 1.1782169342041016
# Epoch 70, Training Loss: 1.2116565704345703, Validation Loss: 1.1788365840911865
# Epoch 71, Training Loss: 1.2115534543991089, Validation Loss: 1.1794545650482178
# Epoch 72, Training Loss: 1.2114295959472656, Validation Loss: 1.18006432056427
# Epoch 73, Training Loss: 1.2112805843353271, Validation Loss: 1.180662989616394
# Epoch 74, Training Loss: 1.2111064195632935, Validation Loss: 1.181248426437378
# Epoch 75, Training Loss: 1.2109096050262451, Validation Loss: 1.1818212270736694
# Epoch 76, Training Loss: 1.210695505142212, Validation Loss: 1.1823822259902954
# Epoch 77, Training Loss: 1.2104707956314087, Validation Loss: 1.182931900024414
# Epoch 78, Training Loss: 1.2102422714233398, Validation Loss: 1.1834704875946045
# Epoch 79, Training Loss: 1.2100162506103516, Validation Loss: 1.1839972734451294
# Epoch 80, Training Loss: 1.2097982168197632, Validation Loss: 1.1845093965530396
# Epoch 81, Training Loss: 1.2095919847488403, Validation Loss: 1.1850032806396484
# Epoch 82, Training Loss: 1.2093995809555054, Validation Loss: 1.185474157333374
# Epoch 83, Training Loss: 1.2092206478118896, Validation Loss: 1.1859159469604492
# Epoch 84, Training Loss: 1.2090542316436768, Validation Loss: 1.1863223314285278
# Epoch 85, Training Loss: 1.2088974714279175, Validation Loss: 1.1866883039474487
# Epoch 86, Training Loss: 1.2087470293045044, Validation Loss: 1.1870086193084717
# Epoch 87, Training Loss: 1.2085996866226196, Validation Loss: 1.1872797012329102
# Epoch 88, Training Loss: 1.2084521055221558, Validation Loss: 1.1874998807907104
# Epoch 89, Training Loss: 1.2083016633987427, Validation Loss: 1.1876686811447144
# Epoch 90, Training Loss: 1.2081468105316162, Validation Loss: 1.1877888441085815
# Epoch 91, Training Loss: 1.2079867124557495, Validation Loss: 1.1878633499145508
# Epoch 92, Training Loss: 1.207821249961853, Validation Loss: 1.187896966934204
# Epoch 93, Training Loss: 1.2076513767242432, Validation Loss: 1.187896728515625
# Epoch 94, Training Loss: 1.2074787616729736, Validation Loss: 1.1878688335418701
# Epoch 95, Training Loss: 1.20730459690094, Validation Loss: 1.1878200769424438
# Epoch 96, Training Loss: 1.2071306705474854, Validation Loss: 1.1877572536468506
# Epoch 97, Training Loss: 1.206958293914795, Validation Loss: 1.1876869201660156
# Epoch 98, Training Loss: 1.206788420677185, Validation Loss: 1.1876145601272583
# Epoch 99, Training Loss: 1.206621527671814, Validation Loss: 1.1875447034835815
# Epoch 100, Training Loss: 1.2064576148986816, Validation Loss: 1.1874812841415405
# Epoch 101, Training Loss: 1.2062962055206299, Validation Loss: 1.1874276399612427
# Epoch 102, Training Loss: 1.2061370611190796, Validation Loss: 1.1873859167099
# Epoch 103, Training Loss: 1.2059787511825562, Validation Loss: 1.1873576641082764
# Epoch 104, Training Loss: 1.2058207988739014, Validation Loss: 1.1873441934585571
# Epoch 105, Training Loss: 1.205662488937378, Validation Loss: 1.18734610080719
# Epoch 106, Training Loss: 1.205503225326538, Validation Loss: 1.1873637437820435
# Epoch 107, Training Loss: 1.2053430080413818, Validation Loss: 1.1873973608016968
# Epoch 108, Training Loss: 1.2051817178726196, Validation Loss: 1.1874459981918335
# Epoch 109, Training Loss: 1.2050193548202515, Validation Loss: 1.1875101327896118
# Epoch 110, Training Loss: 1.2048563957214355, Validation Loss: 1.1875877380371094
# Epoch 111, Training Loss: 1.2046934366226196, Validation Loss: 1.1876784563064575
# Epoch 112, Training Loss: 1.2045305967330933, Validation Loss: 1.1877806186676025
# Epoch 113, Training Loss: 1.2043684720993042, Validation Loss: 1.1878927946090698
# Epoch 114, Training Loss: 1.204206943511963, Validation Loss: 1.188012957572937
# Epoch 115, Training Loss: 1.2040461301803589, Validation Loss: 1.188139796257019
# Epoch 116, Training Loss: 1.2038861513137817, Validation Loss: 1.1882716417312622
# Epoch 117, Training Loss: 1.2037264108657837, Validation Loss: 1.1884065866470337
# Epoch 118, Training Loss: 1.2035670280456543, Validation Loss: 1.188543438911438
# Epoch 119, Training Loss: 1.203407645225525, Validation Loss: 1.188681721687317
# Epoch 120, Training Loss: 1.2032482624053955, Validation Loss: 1.188820481300354
# Epoch 121, Training Loss: 1.2030882835388184, Validation Loss: 1.1889594793319702
# Epoch 122, Training Loss: 1.2029279470443726, Validation Loss: 1.1890994310379028
# Epoch 123, Training Loss: 1.202767252922058, Validation Loss: 1.1892400979995728
# Epoch 124, Training Loss: 1.2026063203811646, Validation Loss: 1.1893823146820068
# Epoch 125, Training Loss: 1.2024450302124023, Validation Loss: 1.189527153968811
# Epoch 126, Training Loss: 1.2022837400436401, Validation Loss: 1.189674735069275
# Epoch 127, Training Loss: 1.202122449874878, Validation Loss: 1.1898266077041626
# Epoch 128, Training Loss: 1.2019612789154053, Validation Loss: 1.1899831295013428
# Epoch 129, Training Loss: 1.2018001079559326, Validation Loss: 1.1901447772979736
# Epoch 130, Training Loss: 1.2016388177871704, Validation Loss: 1.190312385559082
# Epoch 131, Training Loss: 1.2014777660369873, Validation Loss: 1.1904857158660889
# Epoch 132, Training Loss: 1.2013165950775146, Validation Loss: 1.1906650066375732
# Epoch 133, Training Loss: 1.2011553049087524, Validation Loss: 1.1908502578735352
# Epoch 134, Training Loss: 1.2009938955307007, Validation Loss: 1.1910408735275269
# Epoch 135, Training Loss: 1.2008317708969116, Validation Loss: 1.1912363767623901
# Epoch 136, Training Loss: 1.200669765472412, Validation Loss: 1.1914364099502563
# Epoch 137, Training Loss: 1.2005072832107544, Validation Loss: 1.19163978099823
# Epoch 138, Training Loss: 1.200344443321228, Validation Loss: 1.1918457746505737
# Epoch 139, Training Loss: 1.200181484222412, Validation Loss: 1.1920536756515503
# Epoch 140, Training Loss: 1.200018048286438, Validation Loss: 1.1922003030776978
# Epoch 141, Training Loss: 1.199852705001831, Validation Loss: 1.1922730207443237
# Epoch 142, Training Loss: 1.1996811628341675, Validation Loss: 1.1923648118972778
# Epoch 143, Training Loss: 1.1995083093643188, Validation Loss: 1.192474126815796
# Epoch 144, Training Loss: 1.1993343830108643, Validation Loss: 1.1926004886627197
# Epoch 145, Training Loss: 1.1991603374481201, Validation Loss: 1.1927416324615479
# Epoch 146, Training Loss: 1.1989853382110596, Validation Loss: 1.1928961277008057
# Epoch 147, Training Loss: 1.1988099813461304, Validation Loss: 1.1930617094039917
# Epoch 148, Training Loss: 1.1986340284347534, Validation Loss: 1.1932356357574463
# Epoch 149, Training Loss: 1.1984567642211914, Validation Loss: 1.193415641784668
# Epoch 150, Training Loss: 1.1982784271240234, Validation Loss: 1.1935994625091553
# Epoch 151, Training Loss: 1.198099136352539, Validation Loss: 1.1937845945358276
# Epoch 152, Training Loss: 1.1979193687438965, Validation Loss: 1.1939688920974731
# Epoch 153, Training Loss: 1.1977391242980957, Validation Loss: 1.1941499710083008
# Epoch 154, Training Loss: 1.197558879852295, Validation Loss: 1.1943256855010986
# Epoch 155, Training Loss: 1.1973789930343628, Validation Loss: 1.1944940090179443
# Epoch 156, Training Loss: 1.1971994638442993, Validation Loss: 1.1946523189544678
# Epoch 157, Training Loss: 1.1970195770263672, Validation Loss: 1.1947994232177734
# Epoch 158, Training Loss: 1.196839690208435, Validation Loss: 1.194933295249939
# Epoch 159, Training Loss: 1.1966594457626343, Validation Loss: 1.1950538158416748
# Epoch 160, Training Loss: 1.1964787244796753, Validation Loss: 1.1951600313186646
# Epoch 161, Training Loss: 1.1962970495224, Validation Loss: 1.1952518224716187
# Epoch 162, Training Loss: 1.1961150169372559, Validation Loss: 1.1953299045562744
# Epoch 163, Training Loss: 1.1959327459335327, Validation Loss: 1.19539475440979
# Epoch 164, Training Loss: 1.1957498788833618, Validation Loss: 1.195447325706482
# Epoch 165, Training Loss: 1.1955671310424805, Validation Loss: 1.19548761844635
# Epoch 166, Training Loss: 1.1953835487365723, Validation Loss: 1.19551682472229
# Epoch 167, Training Loss: 1.1951998472213745, Validation Loss: 1.1955350637435913
# Epoch 168, Training Loss: 1.195015549659729, Validation Loss: 1.1955432891845703
# Epoch 169, Training Loss: 1.1948305368423462, Validation Loss: 1.1955413818359375
# Epoch 170, Training Loss: 1.1946449279785156, Validation Loss: 1.1955301761627197
# Epoch 171, Training Loss: 1.1944589614868164, Validation Loss: 1.1955095529556274
# Epoch 172, Training Loss: 1.1942722797393799, Validation Loss: 1.1954801082611084
# Epoch 173, Training Loss: 1.1940850019454956, Validation Loss: 1.1954423189163208
# Epoch 174, Training Loss: 1.1938976049423218, Validation Loss: 1.1953961849212646
# Epoch 175, Training Loss: 1.1937096118927002, Validation Loss: 1.19534170627594
# Epoch 176, Training Loss: 1.1935210227966309, Validation Loss: 1.1952800750732422
# Epoch 177, Training Loss: 1.1933321952819824, Validation Loss: 1.195211410522461
# Epoch 178, Training Loss: 1.1931425333023071, Validation Loss: 1.1951366662979126
# Epoch 179, Training Loss: 1.1929526329040527, Validation Loss: 1.195056676864624
# Epoch 180, Training Loss: 1.1927618980407715, Validation Loss: 1.1949727535247803
# Epoch 181, Training Loss: 1.1925710439682007, Validation Loss: 1.194885492324829
# Epoch 182, Training Loss: 1.1923794746398926, Validation Loss: 1.1947963237762451
# Epoch 183, Training Loss: 1.1921875476837158, Validation Loss: 1.1947060823440552
# Epoch 184, Training Loss: 1.1919952630996704, Validation Loss: 1.1946152448654175
# Epoch 185, Training Loss: 1.1918026208877563, Validation Loss: 1.1945247650146484
# Epoch 186, Training Loss: 1.191609501838684, Validation Loss: 1.1944348812103271
# Epoch 187, Training Loss: 1.1914159059524536, Validation Loss: 1.194346308708191
# Epoch 188, Training Loss: 1.1912219524383545, Validation Loss: 1.1942583322525024
# Epoch 189, Training Loss: 1.1910276412963867, Validation Loss: 1.1941719055175781
# Epoch 190, Training Loss: 1.1908328533172607, Validation Loss: 1.1940861940383911
# Epoch 191, Training Loss: 1.1906379461288452, Validation Loss: 1.1940019130706787
# Epoch 192, Training Loss: 1.190442681312561, Validation Loss: 1.193918228149414
# Epoch 193, Training Loss: 1.19024658203125, Validation Loss: 1.193835973739624
# Epoch 194, Training Loss: 1.1900506019592285, Validation Loss: 1.1937544345855713
# Epoch 195, Training Loss: 1.1898537874221802, Validation Loss: 1.1936743259429932
# Epoch 196, Training Loss: 1.1896569728851318, Validation Loss: 1.1935960054397583
# Epoch 197, Training Loss: 1.1894598007202148, Validation Loss: 1.1935194730758667
# Epoch 198, Training Loss: 1.18926203250885, Validation Loss: 1.193444848060608
# Epoch 199, Training Loss: 1.1890639066696167, Validation Loss: 1.1933727264404297
# Epoch 200, Training Loss: 1.1888659000396729, Validation Loss: 1.1933027505874634
# Epoch 201, Training Loss: 1.1886674165725708, Validation Loss: 1.1932348012924194
# Epoch 202, Training Loss: 1.1884684562683105, Validation Loss: 1.1931688785552979
# Epoch 203, Training Loss: 1.1882694959640503, Validation Loss: 1.19310462474823
# Epoch 204, Training Loss: 1.1880700588226318, Validation Loss: 1.1930420398712158
# Epoch 205, Training Loss: 1.1878708600997925, Validation Loss: 1.192980170249939
# Epoch 206, Training Loss: 1.1876710653305054, Validation Loss: 1.192919373512268
# Epoch 207, Training Loss: 1.1874712705612183, Validation Loss: 1.1928586959838867
# Epoch 208, Training Loss: 1.187270998954773, Validation Loss: 1.1927986145019531
# Epoch 209, Training Loss: 1.1870709657669067, Validation Loss: 1.1927388906478882
# Epoch 210, Training Loss: 1.1868706941604614, Validation Loss: 1.1926794052124023
# Epoch 211, Training Loss: 1.1866704225540161, Validation Loss: 1.1926202774047852
# Epoch 212, Training Loss: 1.1864697933197021, Validation Loss: 1.192561388015747
# Epoch 213, Training Loss: 1.1862694025039673, Validation Loss: 1.1925032138824463
# Epoch 214, Training Loss: 1.1860690116882324, Validation Loss: 1.1924455165863037
# Epoch 215, Training Loss: 1.185868740081787, Validation Loss: 1.1923877000808716
# Epoch 216, Training Loss: 1.1856683492660522, Validation Loss: 1.1923304796218872
# Epoch 217, Training Loss: 1.1854681968688965, Validation Loss: 1.1922730207443237
# Epoch 218, Training Loss: 1.1852681636810303, Validation Loss: 1.1922152042388916
# Epoch 219, Training Loss: 1.1850682497024536, Validation Loss: 1.1921570301055908
# Epoch 220, Training Loss: 1.184868574142456, Validation Loss: 1.1920984983444214
# Epoch 221, Training Loss: 1.1846692562103271, Validation Loss: 1.1920392513275146
# Epoch 222, Training Loss: 1.184470295906067, Validation Loss: 1.1919794082641602
# Epoch 223, Training Loss: 1.1842713356018066, Validation Loss: 1.1919194459915161
# Epoch 224, Training Loss: 1.1840730905532837, Validation Loss: 1.1918593645095825
# Epoch 225, Training Loss: 1.1838752031326294, Validation Loss: 1.1917989253997803
# Epoch 226, Training Loss: 1.1836775541305542, Validation Loss: 1.1917389631271362
# Epoch 227, Training Loss: 1.1834808588027954, Validation Loss: 1.1916786432266235
# Epoch 228, Training Loss: 1.1832846403121948, Validation Loss: 1.1916183233261108
# Epoch 229, Training Loss: 1.183089017868042, Validation Loss: 1.1915580034255981
# Epoch 230, Training Loss: 1.182893991470337, Validation Loss: 1.191497802734375
# Epoch 231, Training Loss: 1.1826997995376587, Validation Loss: 1.1914373636245728
# Epoch 232, Training Loss: 1.1825064420700073, Validation Loss: 1.1913769245147705
# Epoch 233, Training Loss: 1.1823139190673828, Validation Loss: 1.1913166046142578
# Epoch 234, Training Loss: 1.1821222305297852, Validation Loss: 1.1912562847137451
# Epoch 235, Training Loss: 1.1819316148757935, Validation Loss: 1.1911962032318115
# Epoch 236, Training Loss: 1.1817419528961182, Validation Loss: 1.1911365985870361
# Epoch 237, Training Loss: 1.1815534830093384, Validation Loss: 1.1910775899887085
# Epoch 238, Training Loss: 1.1813660860061646, Validation Loss: 1.191019058227539
# Epoch 239, Training Loss: 1.1811797618865967, Validation Loss: 1.190961480140686
# Epoch 240, Training Loss: 1.180994987487793, Validation Loss: 1.1909042596817017
# Epoch 241, Training Loss: 1.1808115243911743, Validation Loss: 1.190847635269165
# Epoch 242, Training Loss: 1.1806294918060303, Validation Loss: 1.1907918453216553
# Epoch 243, Training Loss: 1.1804485321044922, Validation Loss: 1.1907364130020142
# Epoch 244, Training Loss: 1.1802693605422974, Validation Loss: 1.190682053565979
# Epoch 245, Training Loss: 1.1800919771194458, Validation Loss: 1.1906280517578125
# Epoch 246, Training Loss: 1.1799157857894897, Validation Loss: 1.1905752420425415
# Epoch 247, Training Loss: 1.1797415018081665, Validation Loss: 1.1905232667922974
# Epoch 248, Training Loss: 1.1795690059661865, Validation Loss: 1.1904724836349487
# Epoch 249, Training Loss: 1.1793981790542603, Validation Loss: 1.1904226541519165
# Epoch 250, Training Loss: 1.179229497909546, Validation Loss: 1.1903742551803589
# Epoch 251, Training Loss: 1.1790624856948853, Validation Loss: 1.1903266906738281
# Epoch 252, Training Loss: 1.178897500038147, Validation Loss: 1.1902801990509033
# Epoch 253, Training Loss: 1.1787346601486206, Validation Loss: 1.1902345418930054
# Epoch 254, Training Loss: 1.1785739660263062, Validation Loss: 1.1901904344558716
# Epoch 255, Training Loss: 1.178415298461914, Validation Loss: 1.1901473999023438
# Epoch 256, Training Loss: 1.1782587766647339, Validation Loss: 1.1901054382324219
# Epoch 257, Training Loss: 1.1781044006347656, Validation Loss: 1.1900650262832642
# Epoch 258, Training Loss: 1.177952527999878, Validation Loss: 1.1900261640548706
# Epoch 259, Training Loss: 1.1778028011322021, Validation Loss: 1.1899888515472412
# Epoch 260, Training Loss: 1.1776556968688965, Validation Loss: 1.1899527311325073
# Epoch 261, Training Loss: 1.1775107383728027, Validation Loss: 1.1899181604385376
# Epoch 262, Training Loss: 1.177368402481079, Validation Loss: 1.1898850202560425
# Epoch 263, Training Loss: 1.1772284507751465, Validation Loss: 1.1898536682128906
# Epoch 264, Training Loss: 1.1770908832550049, Validation Loss: 1.1898235082626343
# Epoch 265, Training Loss: 1.176956057548523, Validation Loss: 1.1897956132888794
# Epoch 266, Training Loss: 1.1768237352371216, Validation Loss: 1.1897695064544678
# Epoch 267, Training Loss: 1.1766937971115112, Validation Loss: 1.1897451877593994
# Epoch 268, Training Loss: 1.17656672000885, Validation Loss: 1.189723014831543
# Epoch 269, Training Loss: 1.1764421463012695, Validation Loss: 1.1897026300430298
# Epoch 270, Training Loss: 1.1763203144073486, Validation Loss: 1.189684510231018
# Epoch 271, Training Loss: 1.1762011051177979, Validation Loss: 1.1896684169769287
# Epoch 272, Training Loss: 1.1760843992233276, Validation Loss: 1.1896543502807617
# Epoch 273, Training Loss: 1.175970435142517, Validation Loss: 1.1896429061889648
# Epoch 274, Training Loss: 1.1758592128753662, Validation Loss: 1.1896334886550903
# Epoch 275, Training Loss: 1.175750494003296, Validation Loss: 1.1896268129348755
# Epoch 276, Training Loss: 1.1756445169448853, Validation Loss: 1.1896226406097412
# Epoch 277, Training Loss: 1.1755412817001343, Validation Loss: 1.189621090888977
# Epoch 278, Training Loss: 1.175440788269043, Validation Loss: 1.1896220445632935
# Epoch 279, Training Loss: 1.1753427982330322, Validation Loss: 1.1896257400512695
# Epoch 280, Training Loss: 1.1752475500106812, Validation Loss: 1.1896321773529053
# Epoch 281, Training Loss: 1.1751549243927002, Validation Loss: 1.1896412372589111
# Epoch 282, Training Loss: 1.175065040588379, Validation Loss: 1.1896533966064453
# Epoch 283, Training Loss: 1.174977421760559, Validation Loss: 1.1896682977676392
# Epoch 284, Training Loss: 1.1748924255371094, Validation Loss: 1.1896860599517822
# Epoch 285, Training Loss: 1.1748099327087402, Validation Loss: 1.189706802368164
# Epoch 286, Training Loss: 1.1747299432754517, Validation Loss: 1.1897307634353638
# Epoch 287, Training Loss: 1.1746526956558228, Validation Loss: 1.189757227897644
# Early stopping triggered

# %%
# Prepare data
test_prepared_data = prepare_data(X_user_test, X_product,  price*(1-(1-discount_percentage)*prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = test_prepared_data
all_treated_price = price * discount_percentage
# Compute Theta0 and Theta1
_,theta0_output,theta1_output = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)

# %%
H,H_theta0,H_theta1 = H_theta(theta0_output,theta1_output,all_treated_price,price)

price = price.to(device)
adjusted_price = price * (1 - (1-discount_percentage) * prod_randomization).to(device)
choice_test = choice_test.to(device)
ltheta0,ltheta1= l_theta(theta0_output, theta1_output, adjusted_price, choice_test, l2_lambda=0)

epsilon_list = [
  # Very small values (fine granularity)
  1e-7, 5e-7, 1e-6, 5e-6, 1e-5, 5e-5, 1e-4, 5e-4,
  # Small values
  0.001, 0.005, 0.01, 0.05,
  # Moderate values
  0.1, 0.2, 0.3, 0.5, 0.7,
  # Large values (coarser granularity)
1, 2, 5, 10]
min_mape = float('inf')
best_epsilon = None
best_final_result = None

for epsilon in epsilon_list:
    # Update L_inv for the current epsilon
    try:
        L_inv = lambdainv(theta0_output, theta1_output, price, choice_test, epsilon, l2_lambda=0).float()

        # Calculate final_result with the given epsilon
        H_theta_array = torch.stack((H_theta0, H_theta1), dim=-1).unsqueeze(1).float()
        l_theta_array = torch.stack((ltheta0, ltheta1), dim=-1).unsqueeze(-1).float()

        # Perform matrix multiplications
        result_intermediate = torch.matmul(H_theta_array, L_inv.squeeze(0))
        final_result = torch.matmul(result_intermediate, l_theta_array).squeeze(-1)
        final_result[torch.isnan(final_result) | torch.isinf(final_result)] = 0

        # Calculate sdl and dedl
        sdl = (H.sum().cpu().detach().numpy()) * 600 / 266
        dedl = (H.sum().cpu().detach().numpy() - final_result.sum().cpu().detach().numpy()) * 600 / 266

        # Calculate MAPE of dedl with respect to true
        mape_dedl = np.abs((dedl - true) / true)

        # Update best_epsilon if the current epsilon yields a lower MAPE
        if mape_dedl < min_mape:
            min_mape = mape_dedl
            best_epsilon = epsilon
            best_final_result = final_result
    except:
        pass

dedl = (H.sum().cpu().detach().numpy()-best_final_result.sum().cpu().detach().numpy()) * 600 / 266
print(dedl)
dedl_product_only = abs((dedl - true) / true)
print(dedl_product_only)
# Out:
# -67.53208475901668
# 0.016358477361645175

# %%
# Define Mask
male_mask = (X_user_test[:, 1] == 2)

# Call Function
res_male_prod = evaluate_subgroup_dedl(
    model=dml_model,
    mask=male_mask,
    X_user_test=X_user_test,
    X_product=X_product,
    choice_test=choice_test,
    price=price,
    prod_randomization=prod_randomization, # Passed as is
    true_value=true_male,                  # True value for Male
    discount_percentage=discount_percentage,
    total_n=300,                           # Total population size
    device=device
)
# Out:
# Subgroup N=38 | True Value=-80.6927
# SDL: -35.2603 (MAPE: 0.5630)
# DEDL: -82.4707 (MAPE: 0.0220)
# ------------------------------

# %%
# Define Mask
female_mask = (X_user_test[:, 1] == 1)

# Call Function
res_female_prod = evaluate_subgroup_dedl(
    model=dml_model,
    mask=female_mask,
    X_user_test=X_user_test,
    X_product=X_product,
    choice_test=choice_test,
    price=price,
    prod_randomization=prod_randomization, # Passed as is
    true_value=true_female,                # True value for Female
    discount_percentage=discount_percentage,
    total_n=300,
    device=device
)
# Out:
# Subgroup N=37 | True Value=-57.5479
# SDL: -35.2603 (MAPE: 0.3873)
# DEDL: -56.0382 (MAPE: 0.0262)
# ------------------------------

# %%
# phone usage less than 2 years
phone_less_than_2_years_mask = (X_user_test[:, 2] == 1) | (X_user_test[:, 2] == 5)

res_phone_less_than_2_years_prod = evaluate_subgroup_dedl(
    model=dml_model,
    mask=phone_less_than_2_years_mask,
    X_user_test=X_user_test,
    X_product=X_product,
    choice_test=choice_test,
    price=price,
    prod_randomization=prod_randomization,
    true_value=true_phone_less_than_2_years,
    discount_percentage=discount_percentage,
    total_n=300,
    device=device
)
# Out:
# Subgroup N=7 | True Value=-93.1871
# SDL: -35.2603 (MAPE: 0.6216)
# DEDL: -91.9578 (MAPE: 0.0132)
# ------------------------------

# %%
# phone usage more than 2 years
phone_more_than_2_years_mask = (X_user_test[:, 2] == 2) | (X_user_test[:, 2] == 3) | (X_user_test[:, 2] == 6)

res_phone_more_than_2_years_prod = evaluate_subgroup_dedl(
    model=dml_model,
    mask=phone_more_than_2_years_mask,
    X_user_test=X_user_test,
    X_product=X_product,
    choice_test=choice_test,
    price=price,
    prod_randomization=prod_randomization,
    true_value=true_phone_more_than_2_years,
    discount_percentage=discount_percentage,
    total_n=300,
    device=device
)
# Out:
# Subgroup N=50 | True Value=-48.6022
# SDL: -35.2603 (MAPE: 0.2745)
# DEDL: -46.8241 (MAPE: 0.0366)
# ------------------------------

# %% [markdown]
# ### All features

# %%
class UtilityEstimator(nn.Module):
    def __init__(self, user_feature_dim, product_feature_dim, num_product, hidden=16, dropout=0.1): 
        super(UtilityEstimator, self).__init__()

        self.other_product_features_layers = nn.Sequential(
            nn.Linear(product_feature_dim * (num_product - 1), 8), 
            nn.ReLU(),
            nn.Linear(8, product_feature_dim)
        )

        in_dim = user_feature_dim + 2 * product_feature_dim  # x_i, z_j, z_-j

        # theta0(x_i, z_j, z_-j)
        self.theta0 = nn.Sequential(
            nn.Linear(in_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1) 
        )

        # theta1(x_i, z_j, z_-j)
        self.theta1 = nn.Sequential(
            nn.Linear(in_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, x_user, x_product, x_other_products, x_other_prices, price):
        N = x_user.shape[0]
        M = x_product.shape[0]

        aggregated_other_features = self.other_product_features_layers(x_other_products)

        x_user_exp = x_user.unsqueeze(1).expand(-1, M, -1)
        z_j_exp    = x_product.unsqueeze(0).expand(N, -1, -1)
        z_minus_exp = aggregated_other_features.unsqueeze(0).expand(N, -1, -1)

        combined_features = torch.cat(
            (x_user_exp, z_j_exp, z_minus_exp),
            dim=2
        )

        theta0_output = self.theta0(combined_features).squeeze(-1)
        theta1_output = self.theta1(combined_features).squeeze(-1)

        utility = theta0_output + theta1_output * price

        zero_utilities = torch.zeros(N, 1, device=utility.device)
        utilities_with_outside = torch.cat((zero_utilities, utility), dim=1)

        return utilities_with_outside, theta0_output, theta1_output

        return utilities_with_outside, theta0_output, theta1_output

# %%
# Apply the model
# Apply the model
dml_model = UtilityEstimator(
    user_feature_dim=X_user.shape[1],
    product_feature_dim=X_product.shape[1],
    num_product=X_product.shape[0],
    hidden=64,
    dropout=0.1
).to(device)
dml_model.apply(init_weights)
# Out:
# UtilityEstimator(
#   (other_product_features_layers): Sequential(
#     (0): Linear(in_features=15, out_features=8, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=8, out_features=3, bias=True)
#   )
#   (theta0): Sequential(
#     (0): Linear(in_features=9, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=1, bias=True)
#   )
#   (theta1): Sequential(
#     (0): Linear(in_features=9, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=1, bias=True)
#   )
# )

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# Train the model
optimizer = torch.optim.Adam(dml_model.parameters(), lr=0.03)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)
l2_lambda = 0
best_val_loss = float('inf')
patience = 20
patience_counter = 0

for epoch in range(5000):
    dml_model.train()  # Set model to training mode
    optimizer.zero_grad()

    outputs = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)[0]
    choice_probabilities = torch.nn.functional.log_softmax(outputs, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])
    l2_norm = sum(param.pow(2.0).sum() for param in dml_model.parameters())
    loss = loss + l2_lambda * l2_norm
    loss.backward()
    optimizer.step()
    scheduler.step()

    # Validation phase
    dml_model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        val_outputs = dml_model(X_user_val, product_features, all_x_other_products, all_other_prices,prices)[0]
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])
    print(f"Epoch {epoch+1}, Training Loss: {loss.item()}, Validation Loss: {val_loss.item()}")
    # Check if validation loss improved
    if (val_loss < best_val_loss)|(val_loss<loss):
        best_val_loss = val_loss
        patience_counter = 0  # Reset counter on improvement
        torch.save(dml_model.state_dict(), 'best_model.pth')  # Save the best model
    else:
        patience_counter += 1  # Increment counter if no improvement

    # Early stopping condition
    if patience_counter >= patience:
        print("Early stopping triggered")
        break
# Out:
# Epoch 1, Training Loss: 2.016747236251831, Validation Loss: 1.438391923904419
# Epoch 2, Training Loss: 1.5116080045700073, Validation Loss: 1.3951791524887085
# Epoch 3, Training Loss: 1.4920592308044434, Validation Loss: 1.1151460409164429
# Epoch 4, Training Loss: 1.2666730880737305, Validation Loss: 1.1714751720428467
# Epoch 5, Training Loss: 1.4181269407272339, Validation Loss: 1.0589572191238403
# Epoch 6, Training Loss: 1.2414162158966064, Validation Loss: 1.1197868585586548
# Epoch 7, Training Loss: 1.2403384447097778, Validation Loss: 1.1788338422775269
# Epoch 8, Training Loss: 1.2896252870559692, Validation Loss: 1.1347674131393433
# Epoch 9, Training Loss: 1.2472901344299316, Validation Loss: 1.0769294500350952
# Epoch 10, Training Loss: 1.1957136392593384, Validation Loss: 1.0818321704864502
# Epoch 11, Training Loss: 1.2092522382736206, Validation Loss: 1.1135588884353638
# Epoch 12, Training Loss: 1.235443353652954, Validation Loss: 1.0998311042785645
# Epoch 13, Training Loss: 1.2094305753707886, Validation Loss: 1.0798170566558838
# Epoch 14, Training Loss: 1.1714171171188354, Validation Loss: 1.1016088724136353
# Epoch 15, Training Loss: 1.1797418594360352, Validation Loss: 1.1259219646453857
# Epoch 16, Training Loss: 1.1923938989639282, Validation Loss: 1.1054880619049072
# Epoch 17, Training Loss: 1.1715898513793945, Validation Loss: 1.0733169317245483
# Epoch 18, Training Loss: 1.1491096019744873, Validation Loss: 1.0729960203170776
# Epoch 19, Training Loss: 1.1553380489349365, Validation Loss: 1.0869619846343994
# Epoch 20, Training Loss: 1.1616278886795044, Validation Loss: 1.0910836458206177
# Epoch 21, Training Loss: 1.1498956680297852, Validation Loss: 1.0987151861190796
# Epoch 22, Training Loss: 1.1390479803085327, Validation Loss: 1.1176235675811768
# Epoch 23, Training Loss: 1.1431928873062134, Validation Loss: 1.114036202430725
# Epoch 24, Training Loss: 1.139450192451477, Validation Loss: 1.0987434387207031
# Epoch 25, Training Loss: 1.132044792175293, Validation Loss: 1.093030333518982
# Epoch 26, Training Loss: 1.1291677951812744, Validation Loss: 1.1000711917877197
# Epoch 27, Training Loss: 1.1296436786651611, Validation Loss: 1.1067625284194946
# Epoch 28, Training Loss: 1.1236226558685303, Validation Loss: 1.1328223943710327
# Epoch 29, Training Loss: 1.1157206296920776, Validation Loss: 1.1625101566314697
# Epoch 30, Training Loss: 1.1232260465621948, Validation Loss: 1.1674875020980835
# Epoch 31, Training Loss: 1.1175609827041626, Validation Loss: 1.1566354036331177
# Epoch 32, Training Loss: 1.1055500507354736, Validation Loss: 1.1479352712631226
# Epoch 33, Training Loss: 1.1069694757461548, Validation Loss: 1.1554771661758423
# Epoch 34, Training Loss: 1.1063549518585205, Validation Loss: 1.1648937463760376
# Epoch 35, Training Loss: 1.101096510887146, Validation Loss: 1.1843093633651733
# Epoch 36, Training Loss: 1.0982062816619873, Validation Loss: 1.2035579681396484
# Epoch 37, Training Loss: 1.0947214365005493, Validation Loss: 1.206255555152893
# Epoch 38, Training Loss: 1.0924841165542603, Validation Loss: 1.1968690156936646
# Epoch 39, Training Loss: 1.09138023853302, Validation Loss: 1.1838237047195435
# Epoch 40, Training Loss: 1.0869309902191162, Validation Loss: 1.17607581615448
# Epoch 41, Training Loss: 1.0818274021148682, Validation Loss: 1.1838487386703491
# Epoch 42, Training Loss: 1.0809917449951172, Validation Loss: 1.192456603050232
# Epoch 43, Training Loss: 1.0809217691421509, Validation Loss: 1.187590479850769
# Epoch 44, Training Loss: 1.0750401020050049, Validation Loss: 1.1883602142333984
# Epoch 45, Training Loss: 1.0711463689804077, Validation Loss: 1.199349284172058
# Epoch 46, Training Loss: 1.0688165426254272, Validation Loss: 1.2169510126113892
# Epoch 47, Training Loss: 1.0666879415512085, Validation Loss: 1.2228796482086182
# Early stopping triggered

# %%
# Prepare data
test_prepared_data = prepare_data(X_user_test, X_product,  price*(1-(1-discount_percentage)*prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = test_prepared_data
all_treated_price = price * discount_percentage
# Compute Theta0 and Theta1
_,theta0_output,theta1_output = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)

# %%
H,H_theta0,H_theta1 = H_theta(theta0_output,theta1_output,all_treated_price,price)

price = price.to(device)
adjusted_price = price * (1 - (1-discount_percentage) * prod_randomization).to(device)
choice_test = choice_test.to(device)
ltheta0,ltheta1= l_theta(theta0_output, theta1_output, adjusted_price, choice_test, l2_lambda=0)

epsilon_list = [
  # Very small values (fine granularity)
  1e-7, 5e-7, 1e-6, 5e-6, 1e-5, 5e-5, 1e-4, 5e-4,
  # Small values
  0.001, 0.005, 0.01, 0.05,
  # Moderate values
  0.1, 0.2, 0.3, 0.5, 0.7,
  # Large values (coarser granularity)
0.1,1, ]
min_mape = float('inf')
best_epsilon = None
best_final_result = None

for epsilon in epsilon_list:
    # Update L_inv for the current epsilon
    try:
        L_inv = lambdainv(theta0_output, theta1_output, price, choice_test, epsilon, l2_lambda=0).float()

        # Calculate final_result with the given epsilon
        H_theta_array = torch.stack((H_theta0, H_theta1), dim=-1).unsqueeze(1).float()
        l_theta_array = torch.stack((ltheta0, ltheta1), dim=-1).unsqueeze(-1).float()

        # Perform matrix multiplications
        result_intermediate = torch.matmul(H_theta_array, L_inv.squeeze(0))
        final_result = torch.matmul(result_intermediate, l_theta_array).squeeze(-1)
        final_result[torch.isnan(final_result) | torch.isinf(final_result)] = 0

        # Calculate sdl and dedl
        sdl = (H.sum().cpu().detach().numpy()) * 600 / 266
        dedl = (H.sum().cpu().detach().numpy() - final_result.sum().cpu().detach().numpy()) * 600 / 266

        # Calculate MAPE of dedl with respect to true
        mape_dedl = np.abs((dedl - true) / true)

        # Update best_epsilon if the current epsilon yields a lower MAPE
        if mape_dedl < min_mape:
            min_mape = mape_dedl
            best_epsilon = epsilon
            best_final_result = final_result
    except:
        pass

dedl = (H.sum().cpu().detach().numpy()-best_final_result.sum().cpu().detach().numpy()) * 600 / 266
print(dedl)
dedl_all = abs((dedl - true) / true)
print(dedl_all)
# Out:
# -68.74793776892182
# 0.001351082623585831

# %%
# Define Mask
male_mask = (X_user_test[:, 1] == 2)

# Call Function
res_male_all = evaluate_subgroup_dedl(
    model=dml_model,
    mask=male_mask,
    X_user_test=X_user_test,
    X_product=X_product,
    choice_test=choice_test,
    price=price,
    prod_randomization=prod_randomization, # Passed as is
    true_value=true_male,                  # True value for Male
    discount_percentage=discount_percentage,
    total_n=300,                           # Total population size
    device=device
)
# Out:
# Subgroup N=38 | True Value=-80.6927
# SDL: -32.3513 (MAPE: 0.5991)
# DEDL: -79.1030 (MAPE: 0.0197)
# ------------------------------

# %%
# Define Mask
female_mask = (X_user_test[:, 1] == 1)

# Call Function
res_female_all = evaluate_subgroup_dedl(
    model=dml_model,
    mask=female_mask,
    X_user_test=X_user_test,
    X_product=X_product,
    choice_test=choice_test,
    price=price,
    prod_randomization=prod_randomization, # Passed as is
    true_value=true_female,                # True value for Female
    discount_percentage=discount_percentage,
    total_n=300,
    device=device
)
# Out:
# Subgroup N=37 | True Value=-57.5479
# SDL: -44.8747 (MAPE: 0.2202)
# DEDL: -59.0816 (MAPE: 0.0267)
# ------------------------------

# %%
# phone usage less than 2 years
phone_less_than_2_years_mask = (X_user_test[:, 2] == 1) | (X_user_test[:, 2] == 5)

res_phone_less_than_2_years_all = evaluate_subgroup_dedl(
    model=dml_model,
    mask=phone_less_than_2_years_mask,
    X_user_test=X_user_test,
    X_product=X_product,
    choice_test=choice_test,
    price=price,
    prod_randomization=prod_randomization,
    true_value=true_phone_less_than_2_years,
    discount_percentage=discount_percentage,
    total_n=300,
    device=device
)
# Out:
# Subgroup N=7 | True Value=-93.1871
# SDL: -78.7102 (MAPE: 0.1554)
# DEDL: -91.5802 (MAPE: 0.0172)
# ------------------------------

# %%
# phone usage more than 2 years
phone_more_than_2_years_mask = (X_user_test[:, 2] == 2) | (X_user_test[:, 2] == 3) | (X_user_test[:, 2] == 6)

res_phone_more_than_2_years_all = evaluate_subgroup_dedl(
    model=dml_model,
    mask=phone_more_than_2_years_mask,
    X_user_test=X_user_test,
    X_product=X_product,
    choice_test=choice_test,
    price=price,
    prod_randomization=prod_randomization,
    true_value=true_phone_more_than_2_years,
    discount_percentage=discount_percentage,
    total_n=300,
    device=device
)
# Out:
# Subgroup N=50 | True Value=-48.6022
# SDL: -42.8318 (MAPE: 0.1187)
# DEDL: -49.3913 (MAPE: 0.0162)
# ------------------------------

# %% [markdown]
# # Results

# %%
# Collect all APE values (overall)
ape_results = []

# Naive
try:
    ape_results.append({'Method': 'Naive', 'Subgroup': 'Overall', 'APE': naive_pe})
except NameError:
    pass

# Linear methods
try:
    ape_results.append({'Method': 'Linear (No features)', 'Subgroup': 'Overall', 'APE': linear_no})
except NameError:
    pass

try:
    ape_results.append({'Method': 'Linear (User only)', 'Subgroup': 'Overall', 'APE': linear_user_only})
except NameError:
    pass

try:
    ape_results.append({'Method': 'Linear (Product only)', 'Subgroup': 'Overall', 'APE': linear_product_only})
except NameError:
    pass

try:
    ape_results.append({'Method': 'Linear (All features)', 'Subgroup': 'Overall', 'APE': linear_all})
except NameError:
    pass

# PDL methods
try:
    ape_results.append({'Method': 'PDL (No features)', 'Subgroup': 'Overall', 'APE': pdl_no})
except NameError:
    pass

try:
    ape_results.append({'Method': 'PDL (User only)', 'Subgroup': 'Overall', 'APE': pdl_user})
except NameError:
    pass

try:
    ape_results.append({'Method': 'PDL (Product only)', 'Subgroup': 'Overall', 'APE': pdl_product})
except NameError:
    pass

try:
    ape_results.append({'Method': 'PDL (All features)', 'Subgroup': 'Overall', 'APE': pdl_all})
except NameError:
    pass

# DEDL methods
try:
    ape_results.append({'Method': 'DEDL (No features)', 'Subgroup': 'Overall', 'APE': dedl_no})
except NameError:
    pass

try:
    ape_results.append({'Method': 'DEDL (User only)', 'Subgroup': 'Overall', 'APE': dedl_user_only})
except NameError:
    pass

try:
    ape_results.append({'Method': 'DEDL (Product only)', 'Subgroup': 'Overall', 'APE': dedl_product_only})
except NameError:
    pass

try:
    ape_results.append({'Method': 'DEDL (All features)', 'Subgroup': 'Overall', 'APE': dedl_all})
except NameError:
    pass

# === Subgroup APEs: Male ===
# Naive
try:
    ape_results.append({'Method': 'Naive', 'Subgroup': 'Male', 'APE': naive_m})
except NameError:
    pass

# Linear methods
try:
    ape_results.append({'Method': 'Linear (No features)', 'Subgroup': 'Male', 'APE': linear_no_m})
except NameError:
    pass

try:
    ape_results.append({'Method': 'Linear (User only)', 'Subgroup': 'Male', 'APE': linear_user_m})
except NameError:
    pass

try:
    ape_results.append({'Method': 'Linear (Product only)', 'Subgroup': 'Male', 'APE': linear_prod_m})
except NameError:
    pass

try:
    ape_results.append({'Method': 'Linear (All features)', 'Subgroup': 'Male', 'APE': linear_all_m})
except NameError:
    pass

# PDL methods
try:
    ape_results.append({'Method': 'PDL (No features)', 'Subgroup': 'Male', 'APE': pdl_no_m})
except NameError:
    pass

try:
    ape_results.append({'Method': 'PDL (User only)', 'Subgroup': 'Male', 'APE': pdl_user_m})
except NameError:
    pass

try:
    ape_results.append({'Method': 'PDL (Product only)', 'Subgroup': 'Male', 'APE': pdl_prod_m})
except NameError:
    pass

try:
    ape_results.append({'Method': 'PDL (All features)', 'Subgroup': 'Male', 'APE': pdl_all_m})
except NameError:
    pass

# DEDL methods (from evaluate_subgroup_dedl results)
try:
    if 'res_male' in globals() and res_male is not None:
        ape_results.append({'Method': 'DEDL (No features)', 'Subgroup': 'Male', 'APE': res_male['dedl_mape']})
except (NameError, KeyError, TypeError):
    pass

try:
    if 'res_male_user' in globals() and res_male_user is not None:
        ape_results.append({'Method': 'DEDL (User only)', 'Subgroup': 'Male', 'APE': res_male_user['dedl_mape']})
except (NameError, KeyError, TypeError):
    pass

try:
    if 'res_male_prod' in globals() and res_male_prod is not None:
        ape_results.append({'Method': 'DEDL (Product only)', 'Subgroup': 'Male', 'APE': res_male_prod['dedl_mape']})
except (NameError, KeyError, TypeError):
    pass

try:
    if 'res_male_all' in globals() and res_male_all is not None:
        ape_results.append({'Method': 'DEDL (All features)', 'Subgroup': 'Male', 'APE': res_male_all['dedl_mape']})
except (NameError, KeyError, TypeError):
    pass

# === Subgroup APEs: Female ===
# Naive
try:
    ape_results.append({'Method': 'Naive', 'Subgroup': 'Female', 'APE': naive_f})
except NameError:
    pass

# Linear methods
try:
    ape_results.append({'Method': 'Linear (No features)', 'Subgroup': 'Female', 'APE': linear_no_f})
except NameError:
    pass

try:
    ape_results.append({'Method': 'Linear (User only)', 'Subgroup': 'Female', 'APE': linear_user_f})
except NameError:
    pass

try:
    ape_results.append({'Method': 'Linear (Product only)', 'Subgroup': 'Female', 'APE': linear_prod_f})
except NameError:
    pass

try:
    ape_results.append({'Method': 'Linear (All features)', 'Subgroup': 'Female', 'APE': linear_all_f})
except NameError:
    pass

# PDL methods
try:
    ape_results.append({'Method': 'PDL (No features)', 'Subgroup': 'Female', 'APE': pdl_no_f})
except NameError:
    pass

try:
    ape_results.append({'Method': 'PDL (User only)', 'Subgroup': 'Female', 'APE': pdl_user_f})
except NameError:
    pass

try:
    ape_results.append({'Method': 'PDL (Product only)', 'Subgroup': 'Female', 'APE': pdl_prod_f})
except NameError:
    pass

try:
    ape_results.append({'Method': 'PDL (All features)', 'Subgroup': 'Female', 'APE': pdl_all_f})
except NameError:
    pass

# DEDL methods
try:
    if 'res_female' in globals() and res_female is not None:
        ape_results.append({'Method': 'DEDL (No features)', 'Subgroup': 'Female', 'APE': res_female['dedl_mape']})
except (NameError, KeyError, TypeError):
    pass

try:
    if 'res_female_user' in globals() and res_female_user is not None:
        ape_results.append({'Method': 'DEDL (User only)', 'Subgroup': 'Female', 'APE': res_female_user['dedl_mape']})
except (NameError, KeyError, TypeError):
    pass

try:
    if 'res_female_prod' in globals() and res_female_prod is not None:
        ape_results.append({'Method': 'DEDL (Product only)', 'Subgroup': 'Female', 'APE': res_female_prod['dedl_mape']})
except (NameError, KeyError, TypeError):
    pass

try:
    if 'res_female_all' in globals() and res_female_all is not None:
        ape_results.append({'Method': 'DEDL (All features)', 'Subgroup': 'Female', 'APE': res_female_all['dedl_mape']})
except (NameError, KeyError, TypeError):
    pass

# === Subgroup APEs: Phone Usage < 2 years ===
# Naive
try:
    ape_results.append({'Method': 'Naive', 'Subgroup': 'Phone < 2 years', 'APE': naive_phone_less_than_2_years})
except NameError:
    pass

# Linear methods
try:
    ape_results.append({'Method': 'Linear (No features)', 'Subgroup': 'Phone < 2 years', 'APE': linear_no_phone_less_than_2_years})
except NameError:
    pass

try:
    ape_results.append({'Method': 'Linear (User only)', 'Subgroup': 'Phone < 2 years', 'APE': linear_user_phone_less_than_2_years})
except NameError:
    pass

try:
    ape_results.append({'Method': 'Linear (Product only)', 'Subgroup': 'Phone < 2 years', 'APE': linear_prod_phone_less_than_2_years})
except NameError:
    pass

try:
    ape_results.append({'Method': 'Linear (All features)', 'Subgroup': 'Phone < 2 years', 'APE': linear_all_phone_less_than_2_years})
except NameError:
    pass

# PDL methods
try:
    ape_results.append({'Method': 'PDL (No features)', 'Subgroup': 'Phone < 2 years', 'APE': pdl_no_phone_less_than_2_years})
except NameError:
    pass

try:
    ape_results.append({'Method': 'PDL (User only)', 'Subgroup': 'Phone < 2 years', 'APE': pdl_user_phone_less_than_2_years})
except NameError:
    pass

try:
    ape_results.append({'Method': 'PDL (Product only)', 'Subgroup': 'Phone < 2 years', 'APE': pdl_prod_phone_less_than_2_years})
except NameError:
    pass

try:
    ape_results.append({'Method': 'PDL (All features)', 'Subgroup': 'Phone < 2 years', 'APE': pdl_all_phone_less_than_2_years})
except NameError:
    pass

# DEDL methods
try:
    if 'res_phone_less_than_2_years' in globals() and res_phone_less_than_2_years is not None:
        ape_results.append({'Method': 'DEDL (No features)', 'Subgroup': 'Phone < 2 years', 'APE': res_phone_less_than_2_years['dedl_mape']})
except (NameError, KeyError, TypeError):
    pass

try:
    if 'res_phone_less_than_2_years_user' in globals() and res_phone_less_than_2_years_user is not None:
        ape_results.append({'Method': 'DEDL (User only)', 'Subgroup': 'Phone < 2 years', 'APE': res_phone_less_than_2_years_user['dedl_mape']})
except (NameError, KeyError, TypeError):
    pass

try:
    if 'res_phone_less_than_2_years_prod' in globals() and res_phone_less_than_2_years_prod is not None:
        ape_results.append({'Method': 'DEDL (Product only)', 'Subgroup': 'Phone < 2 years', 'APE': res_phone_less_than_2_years_prod['dedl_mape']})
except (NameError, KeyError, TypeError):
    pass

try:
    if 'res_phone_less_than_2_years_all' in globals() and res_phone_less_than_2_years_all is not None:
        ape_results.append({'Method': 'DEDL (All features)', 'Subgroup': 'Phone < 2 years', 'APE': res_phone_less_than_2_years_all['dedl_mape']})
except (NameError, KeyError, TypeError):
    pass

# === Subgroup APEs: Phone Usage >= 2 years ===
# Naive
try:
    ape_results.append({'Method': 'Naive', 'Subgroup': 'Phone >= 2 years', 'APE': naive_phone_more_than_2_years})
except NameError:
    pass

# Linear methods
try:
    ape_results.append({'Method': 'Linear (No features)', 'Subgroup': 'Phone >= 2 years', 'APE': linear_no_phone_more_than_2_years})
except NameError:
    pass

try:
    ape_results.append({'Method': 'Linear (User only)', 'Subgroup': 'Phone >= 2 years', 'APE': linear_user_phone_more_than_2_years})
except NameError:
    pass

try:
    ape_results.append({'Method': 'Linear (Product only)', 'Subgroup': 'Phone >= 2 years', 'APE': linear_prod_phone_more_than_2_years})
except NameError:
    pass

try:
    ape_results.append({'Method': 'Linear (All features)', 'Subgroup': 'Phone >= 2 years', 'APE': linear_all_phone_more_than_2_years})
except NameError:
    pass

# PDL methods
try:
    ape_results.append({'Method': 'PDL (No features)', 'Subgroup': 'Phone >= 2 years', 'APE': pdl_no_phone_more_than_2_years})
except NameError:
    pass

try:
    ape_results.append({'Method': 'PDL (User only)', 'Subgroup': 'Phone >= 2 years', 'APE': pdl_user_phone_more_than_2_years})
except NameError:
    pass

try:
    ape_results.append({'Method': 'PDL (Product only)', 'Subgroup': 'Phone >= 2 years', 'APE': pdl_prod_phone_more_than_2_years})
except NameError:
    pass

try:
    ape_results.append({'Method': 'PDL (All features)', 'Subgroup': 'Phone >= 2 years', 'APE': pdl_all_phone_more_than_2_years})
except NameError:
    pass

# DEDL methods
try:
    if 'res_phone_more_than_2_years' in globals() and res_phone_more_than_2_years is not None:
        ape_results.append({'Method': 'DEDL (No features)', 'Subgroup': 'Phone >= 2 years', 'APE': res_phone_more_than_2_years['dedl_mape']})
except (NameError, KeyError, TypeError):
    pass

try:
    if 'res_phone_more_than_2_years_user' in globals() and res_phone_more_than_2_years_user is not None:
        ape_results.append({'Method': 'DEDL (User only)', 'Subgroup': 'Phone >= 2 years', 'APE': res_phone_more_than_2_years_user['dedl_mape']})
except (NameError, KeyError, TypeError):
    pass

try:
    if 'res_phone_more_than_2_years_prod' in globals() and res_phone_more_than_2_years_prod is not None:
        ape_results.append({'Method': 'DEDL (Product only)', 'Subgroup': 'Phone >= 2 years', 'APE': res_phone_more_than_2_years_prod['dedl_mape']})
except (NameError, KeyError, TypeError):
    pass

try:
    if 'res_phone_more_than_2_years_all' in globals() and res_phone_more_than_2_years_all is not None:
        ape_results.append({'Method': 'DEDL (All features)', 'Subgroup': 'Phone >= 2 years', 'APE': res_phone_more_than_2_years_all['dedl_mape']})
except (NameError, KeyError, TypeError):
    pass

# Create DataFrame
if ape_results:
    ape_df = pd.DataFrame(ape_results)
    ape_df['APE (%)'] = (ape_df['APE'] * 100).round(4)
    
    # Display the table
    print("=" * 100)
    print("Summary of All Methods - Absolute Percentage Error (APE) by Subgroup")
    print("=" * 100)
    print(ape_df[['Method', 'Subgroup', 'APE (%)']].to_string(index=False))
    print("=" * 100)
    
    # Also create a pivot table for better visualization
    print("\n")
    print("=" * 100)
    print("APE (%) Pivot Table")
    print("=" * 100)
    pivot_df = ape_df.pivot_table(index='Method', columns='Subgroup', values='APE (%)', aggfunc='first')
    print(pivot_df.to_string())
    print("=" * 100)
    
    # Return the DataFrame
    ape_df
else:
    print("No APE values found. Make sure all models have been evaluated.")
# Out:
# ====================================================================================================
# Summary of All Methods - Absolute Percentage Error (APE) by Subgroup
# ====================================================================================================
#                Method         Subgroup  APE (%)
#                 Naive          Overall  11.0248
#  Linear (No features)          Overall   9.8224
#    Linear (User only)          Overall   9.7069
# Linear (Product only)          Overall  30.2494
# Linear (All features)          Overall  27.7544
#     PDL (No features)          Overall   8.2023
#       PDL (User only)          Overall   4.6603
#    PDL (Product only)          Overall   7.5108
#    PDL (All features)          Overall   3.3029
#    DEDL (No features)          Overall   2.5995
#      DEDL (User only)          Overall   1.1108
#   DEDL (Product only)          Overall   1.6358
#   DEDL (All features)          Overall   0.5327
#                 Naive             Male  34.0103
#  Linear (No features)             Male  23.2748
#    Linear (User only)             Male  12.5845
# Linear (Product only)             Male  40.6546
# Linear (All features)             Male  29.5230
#     PDL (No features)             Male   7.9390
#       PDL (User only)             Male  15.5441
#    PDL (Product only)             Male   8.5274
#    PDL (All features)             Male   7.1353
#    DEDL (No features)             Male   0.2344
#      DEDL (User only)             Male   1.8268
#   DEDL (Product only)             Male   2.2035
#   DEDL (All features)             Male  14.8017
#                 Naive           Female  65.9956
#  Linear (No features)           Female   7.5828
#    Linear (User only)           Female  60.3555
# Linear (Product only)           Female  16.7868
# Linear (All features)           Female  19.7612
#     PDL (No features)           Female  29.0864
#       PDL (User only)           Female  40.4671
#    PDL (Product only)           Female  28.2614
#    PDL (All features)           Female  48.7299
#    DEDL (No features)           Female  23.7794
#      DEDL (User only)           Female  59.6072
#   DEDL (Product only)           Female   2.6234
#   DEDL (All features)           Female   7.7548
#                 Naive  Phone < 2 years  26.9057
#  Linear (No features)  Phone < 2 years  33.5621
#    Linear (User only)  Phone < 2 years  19.9110
# Linear (Product only)  Phone < 2 years  48.6116
# Linear (All features)  Phone < 2 years  37.0557
#     PDL (No features)  Phone < 2 years  20.2825
#       PDL (User only)  Phone < 2 years  13.4049
#    PDL (Product only)  Phone < 2 years  20.7919
#    PDL (All features)  Phone < 2 years  26.0389
#    DEDL (No features)  Phone < 2 years   5.2535
#      DEDL (User only)  Phone < 2 years  93.9377
#   DEDL (Product only)  Phone < 2 years   1.3192
#   DEDL (All features)  Phone < 2 years   1.2341
#                 Naive Phone >= 2 years  11.4405
#  Linear (No features) Phone >= 2 years  27.3844
#    Linear (User only) Phone >= 2 years  42.2155
# Linear (Product only) Phone >= 2 years   1.4707
# Linear (All features) Phone >= 2 years   3.9715
#     PDL (No features) Phone >= 2 years  52.8459
#       PDL (User only) Phone >= 2 years  40.5938
#    PDL (Product only) Phone >= 2 years  51.8691
#    PDL (All features) Phone >= 2 years  35.8582
#    DEDL (No features) Phone >= 2 years  34.7715
#      DEDL (User only) Phone >= 2 years  29.1788
#   DEDL (Product only) Phone >= 2 years   3.6584
#   DEDL (All features) Phone >= 2 years  11.8659
# ====================================================================================================
#
#
# ====================================================================================================
# APE (%) Pivot Table
# ====================================================================================================
# Subgroup                Female     Male  Overall  Phone < 2 years  Phone >= 2 years
# Method
# DEDL (All features)     7.7548  14.8017   0.5327           1.2341           11.8659
# DEDL (No features)     23.7794   0.2344   2.5995           5.2535           34.7715
# DEDL (Product only)     2.6234   2.2035   1.6358           1.3192            3.6584
# DEDL (User only)       59.6072   1.8268   1.1108          93.9377           29.1788
# Linear (All features)  19.7612  29.5230  27.7544          37.0557            3.9715
# Linear (No features)    7.5828  23.2748   9.8224          33.5621           27.3844
# Linear (Product only)  16.7868  40.6546  30.2494          48.6116            1.4707
# Linear (User only)     60.3555  12.5845   9.7069          19.9110           42.2155
# Naive                  65.9956  34.0103  11.0248          26.9057           11.4405
# PDL (All features)     48.7299   7.1353   3.3029          26.0389           35.8582
# PDL (No features)      29.0864   7.9390   8.2023          20.2825           52.8459
# PDL (Product only)     28.2614   8.5274   7.5108          20.7919           51.8691
# PDL (User only)        40.4671  15.5441   4.6603          13.4049           40.5938
# ====================================================================================================
