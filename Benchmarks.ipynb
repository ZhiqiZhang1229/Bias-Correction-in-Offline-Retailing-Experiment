# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import torch
from sklearn.model_selection import train_test_split
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %% [markdown]
# # Pre-processing Stage

# %%
no = pd.read_csv('no_discount.csv')
all = pd.read_csv('all_discount.csv')
half = pd.read_csv('half_discount.csv')
prod = pd.read_excel('product.xlsx')

# %% [markdown]
# ## Data Preparation

# %%
# Map user features to number
dataframes = {'all': all, 'half': half, 'no': no}
feature_cols = ['user_feature_1', 'user_feature_2', 'user_feature_3']
category_maps = {}

# 1. Build mapping for each feature across all dataframes
for col in feature_cols:
    # Collect unique values from all dataframes for this column
    unique_vals = pd.concat([df[col] for df in dataframes.values()]).unique()
    cat_map = {cat: i+1 for i, cat in enumerate(sorted(unique_vals))}
    category_maps[col] = cat_map

# 2. Apply the mapping to each dataframe
for df in dataframes.values():
    for col in feature_cols:
        df[col + '_num'] = df[col].map(category_maps[col])

# 3. Show mapping for each feature
for col in feature_cols:
    print(f"\nMapping for {col}:")
    for cat, idx in category_maps[col].items():
        print(f"{idx}: {cat}")
# Out:
# Mapping for user_feature_1:
# 1: Female
# 2: Male
# 3: Non-binary / third gender
# 4: Prefer not to say
#
# Mapping for user_feature_2:
# 1: 1-2 years ago
# 2: 2-3 years ago
# 3: 3-4 yeas ago
# 4: Currently, I don't have a phone
# 5: Less than 1 year ago
# 6: More than 4 years ago
#
# Mapping for user_feature_3:
# 1: Brand reputation
# 2: Design and appearance
# 3: Good price
# 4: Product quality

# %%
# Map choice to number (no discount)
# Define the mapping for 'choice'
choice_map = {
    "Do not purchase; save the $30 or use it for other expenses ($30 is roughly enough to cover two meals at a fast-food restaurant in the U.S.)": 0,
    "Color: Black; Style: Solid color; Weight: 2.66 pounds; Price: $24 (MSRP: $24)": 1,
    "Color: Black; Style: Gradient color; Weight: 2.66 pounds; Price: $26 (MSRP: $26)": 2,
    "Color: Dark blue; Style: Solid color; Weight: 2.61 pounds; Price: $25 (MSRP: $25)": 3,
    "Color: Dark blue; Style: Gradient color; Weight: 2.64 pounds; Price: $25 (MSRP: $25)": 4,
    "Color: Light blue; Style: Gradient color; Weight: 2.68 pounds; Price: $26 (MSRP: $26)": 5,
    "Color: White; Style: Solid color; Weight: 2.68 pounds; Price: $27 (MSRP: $27)": 6
}

# Apply the mapping
no['choice_num'] = no['choice'].map(choice_map)

# %%
# Map choice to number (all discount)
# Define the mapping for 'choice'
choice_map = {
    "Do not purchase; save the $30 or use it for other expenses ($30 is roughly enough to cover two meals at a fast-food restaurant in the U.S.)": 0,
    "Color: Black; Style: Solid color; Weight: 2.66 pounds; Price: $4.8 (MSRP: $24)": 1,
    "Color: Black; Style: Gradient color; Weight: 2.66 pounds; Price: $5.2 (MSRP: $26)": 2,
    "Color: Dark blue; Style: Solid color; Weight: 2.61 pounds; Price: $5 (MSRP: $25)": 3,
    "Color: Dark blue; Style: Gradient color; Weight: 2.64 pounds; Price: $5 (MSRP: $25)": 4,
    "Color: Light blue; Style: Gradient color; Weight: 2.68 pounds; Price: $5.2 (MSRP: $26)": 5,
    "Color: White; Style: Solid color; Weight: 2.68 pounds; Price: $5.4 (MSRP: $27)": 6
}

# Apply the mapping
all['choice_num'] = all['choice'].map(choice_map)

# %%
# Map choice to number (half discount)
# Define the mapping for 'choice'
choice_map = {
    "Do not purchase; save the $30 or use it for other expenses ($30 is roughly enough to cover two meals at a fast-food restaurant in the U.S.)": 0,
    "Color: Black; Style: Solid color; Weight: 2.66 pounds; Price: $4.8 (MSRP: $24)": 1,
    "Color: Black; Style: Gradient color; Weight: 2.66 pounds; Price: $26 (MSRP: $26)": 2,
    "Color: Dark blue; Style: Solid color; Weight: 2.61 pounds; Price: $25 (MSRP: $25)": 3,
    "Color: Dark blue; Style: Gradient color; Weight: 2.64 pounds; Price: $25 (MSRP: $25)": 4,
    "Color: Light blue; Style: Gradient color; Weight: 2.68 pounds; Price: $5.2 (MSRP: $26)": 5,
    "Color: White; Style: Solid color; Weight: 2.68 pounds; Price: $5.4 (MSRP: $27)": 6
}

# Apply the mapping
half['choice_num'] = half['choice'].map(choice_map)

# %%
# Normalization: user features
# Define the columns to scale
columns_to_scale = ['user_feature_1_num', 'user_feature_2_num', 'user_feature_3_num']

# Initialize the scaler
scaler = MinMaxScaler()

# Fit and transform the selected columns
half[columns_to_scale] = scaler.fit_transform(half[columns_to_scale])

# %%
# Normalization: product features and price
# Define the columns to scale
columns_to_scale = [
    'product_feature_1', 'product_feature_2', 'product_feature_3', 'price'
]

# Initialize the scaler
scaler = MinMaxScaler()

# Fit and transform the selected columns
prod[columns_to_scale] = scaler.fit_transform(prod[columns_to_scale])

# %%
# Set parameters
discount_percentage = 0.2
num_product = 6

# %%
# Check the number of valid data
num_row_no = len(no)
num_row_all = len(all)
num_row_half = len(half)
print(num_row_no)
print(num_row_all)
print(num_row_half)
# Out:
# 291
# 278
# 266

# %% [markdown]
# # Analysis Stage

# %% [markdown]
# ## True GTE

# %%
# All products are control (no discount)
# Merge the purchasing data with the product data
merged_no = no.merge(prod, left_on='choice_num', right_on='product_id', how='left')

# Calculate the total revenue
revenue_control = 0
revenue_control = merged_no['price'].sum() * 300/291

# All products are treated (all discount)
# Merge the purchasing data with the product data
merged_all = all.merge(prod, left_on='choice_num', right_on='product_id', how='left')

# Calculate the total revenue
revenue_treated = 0
revenue_treated = merged_all['price'].sum() * discount_percentage * 300/278

# Calculate the GTE
true = revenue_treated - revenue_control
print(true)
# Out:
# -68.6551789496238

# %% [markdown]
# ## DIM Estimator

# %%
# Define the function to calculate the revenue
def calculate_total_revenue(df):
    revenue_treated = 0.0
    revenue_control = 0.0
    df['adjusted_price'] = df.apply(
        lambda row: row['price'] * discount_percentage if row['if_treated'] == 1 else row['price'], axis=1
    )
    for _, row in df.iterrows():
        if row['if_treated'] == 0:
            revenue_control += row['adjusted_price']
        elif row['if_treated'] == 1:
            revenue_treated += row['adjusted_price']
    return revenue_control, revenue_treated

# Merge the purchasing data with the product data
merged_half = half.merge(prod, left_on='choice_num', right_on='product_id', how='left')

# Calculate the revenue difference
revenue_control, revenue_treated = calculate_total_revenue(merged_half)

# Calculate the GTE
naive = (revenue_treated - revenue_control) * 600/266
naive
naive_pe = abs((naive - true)/true)
print(naive_pe)
# Out:
# 0.11024849998145407

# %% [markdown]
# ## MNL Estimator

# %%
# Product features (skip the first row)
feature_cols = ['product_feature_1', 'product_feature_2', 'product_feature_3']
X_product = torch.tensor(prod[feature_cols].iloc[1:].to_numpy(), dtype=torch.float)

# Price (skip first row)
price = torch.tensor(prod['price'].iloc[1:].to_numpy(), dtype=torch.float)

# Product randomization (skip first row)
prod_randomization = torch.tensor(prod['if_treated'].iloc[1:].to_numpy(), dtype=torch.bool)

# User features
user_num_cols = ['user_feature_1_num', 'user_feature_2_num', 'user_feature_3_num']
X_user = torch.tensor(merged_half[user_num_cols].to_numpy(),dtype=torch.float)

# User choice
choice = torch.tensor(
    merged_half['choice_num'].to_numpy(),
    dtype=torch.long
)

# %%
# Split the training and test set
X_user_train, X_user_test, choice_train, choice_test = train_test_split(
    X_user, choice, test_size=0.5, random_state=42
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

X_user_train = X_user_train.to(device)
X_user_test  = X_user_test.to(device)
X_product    = X_product.to(device)
price        = price.to(device)
prod_randomization = prod_randomization.to(device)

choice_train = choice_train.to(device)
choice_test  = choice_test.to(device)

# %% [markdown]
# ### No features

# %%
class LinearMNLModel_No(nn.Module):
    def __init__(self):
        super(LinearMNLModel_No, self).__init__()
        # v is the same constant value for all products.
        self.v = nn.Parameter(torch.tensor(1.0))
        # gamma is the price sensitivity parameter.
        self.gamma = nn.Parameter(torch.tensor(1.0))

    def forward(self, x_user, X_product, price, prod_randomization):
        N = x_user.shape[0]
        # Adjust prices for treated products (discounted)
        adjusted_price = torch.where(
            prod_randomization,
            price * discount_percentage,
            price
        )
        # Compute utilities: shape [M]
        utility = self.v + self.gamma * adjusted_price
        # Expand to shape [N, M]
        utility = utility.expand(N, -1)
        # Add outside option (utility = 0)
        zero_utilities = torch.zeros(N, 1, device=utility.device)
        utilities_with_outside = torch.cat((zero_utilities, utility), dim=1)
        return utilities_with_outside

# %%
# Model training
model = LinearMNLModel_No().to(device)

optimizer = optim.Adam(model.parameters(), lr=0.001)
num_epochs = 10000
l2_lambda = 1e-4  # Coefficient for L2 regularization
for epoch in range(num_epochs):
    optimizer.zero_grad()
    utilities = model(X_user_train, X_product, price, prod_randomization)
    utilities = utilities - utilities.max(dim=1, keepdim=True).values
    choice_probabilities = nn.functional.log_softmax(utilities, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train])

    # Compute L2 regularization penalty over all model parameters
    l2_norm = sum(param.pow(2.0).sum() for param in model.parameters())
    loss = loss + l2_lambda * l2_norm

    loss.backward()
    optimizer.step()
    if epoch % 1000 == 0:
        print(f'Epoch {epoch}, Loss: {loss.item()}')
# Out:
# Epoch 0, Loss: 2.9594156742095947
# Epoch 1000, Loss: 1.991666316986084
# Epoch 2000, Loss: 1.457595944404602
# Epoch 3000, Loss: 1.2737023830413818
# Epoch 4000, Loss: 1.2315912246704102
# Epoch 5000, Loss: 1.2191221714019775
# Epoch 6000, Loss: 1.2120882272720337
# Epoch 7000, Loss: 1.2091130018234253
# Epoch 8000, Loss: 1.2084826231002808
# Epoch 9000, Loss: 1.2084379196166992

# %%
# All control and all treated in test set
all_product_control = np.random.choice([0,1], num_product, p=[1, 0])
all_product_treated = np.random.choice([0,1], num_product, p=[0, 1])
all_product_control = torch.from_numpy(all_product_control).to(X_user_train.device).bool()
all_product_treated = torch.from_numpy(all_product_treated).to(X_user_train.device).bool()
X_user_test, X_product, price = X_user_test.to(device), X_product.to(device), price.to(device)

# Calculate expected revenue if all control
utilities = model(X_user_test, X_product, price, all_product_control)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum()
print(f"Expected Revenue: ${expected_revenue.item():.2f}")

# Calculate expected revenue if all treated
utilities = model(X_user_test, X_product, price, all_product_treated)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue_treated = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum() * discount_percentage
print(f"Expected Revenue: ${expected_revenue_treated.item():.2f}")

# Calculate GTE
linear = (expected_revenue_treated-expected_revenue).cpu().detach().numpy()
linear = linear * 600 / 266 # For comparison purpose
print(linear)
linear_no = abs((linear - true)/true)
print(linear_no)
# Out:
# Expected Revenue: $38.62
# Expected Revenue: $8.52
# -67.89952615149936
# 0.011006493751606264

# %% [markdown]
# ### Only user features

# %%
class LinearMNLModel_UserOnly(nn.Module):
    def __init__(self, user_feature_dim):
        super(LinearMNLModel_UserOnly, self).__init__()
        self.beta_user = nn.Parameter(torch.randn(user_feature_dim))
        self.beta_price = nn.Parameter(torch.tensor(-1.0))

    def forward(self, x_user, X_product, price, prod_randomization):
        N, M = x_user.shape[0], X_product.shape[0]

        # Expand user features
        x_user_expanded = x_user.unsqueeze(1).expand(-1, M, -1).detach()
        utility_user = torch.sum(x_user_expanded * self.beta_user, dim=2)

        # Price adjustment
        adjusted_price = torch.where(
            prod_randomization.unsqueeze(0),
            price * discount_percentage,
            price
        )
        utility_price = adjusted_price * self.beta_price
        utility_price = utility_price.expand(N, M)

        total_utility = utility_user + utility_price

        # Outside option
        zero_utilities = torch.zeros(N, 1, device=total_utility.device)
        utilities_with_outside = torch.cat((zero_utilities,total_utility), dim=1)
        return utilities_with_outside

# %%
# Model training
model = LinearMNLModel_UserOnly(user_feature_dim=X_user.shape[1]).to(device)

optimizer = optim.Adam(model.parameters(), lr=0.001)
num_epochs = 10000
l2_lambda = 1e-4  # Coefficient for L2 regularization
for epoch in range(num_epochs):
    optimizer.zero_grad()
    utilities = model(X_user_train, X_product, price, prod_randomization)
    utilities = utilities - utilities.max(dim=1, keepdim=True).values
    choice_probabilities = nn.functional.log_softmax(utilities, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train])

    # Compute L2 regularization penalty over all model parameters
    l2_norm = sum(param.pow(2.0).sum() for param in model.parameters())
    loss = loss + l2_lambda * l2_norm

    loss.backward()
    optimizer.step()
    if epoch % 1000 == 0:
        print(f'Epoch {epoch}, Loss: {loss.item()}')
# Out:
# Epoch 0, Loss: 2.138808488845825
# Epoch 1000, Loss: 1.4613381624221802
# Epoch 2000, Loss: 1.2889728546142578
# Epoch 3000, Loss: 1.2356287240982056
# Epoch 4000, Loss: 1.2093948125839233
# Epoch 5000, Loss: 1.1977343559265137
# Epoch 6000, Loss: 1.1932528018951416
# Epoch 7000, Loss: 1.1921210289001465
# Epoch 8000, Loss: 1.1920028924942017
# Epoch 9000, Loss: 1.192000150680542

# %%
# All control and all treated in test set
all_product_control = np.random.choice([0,1], num_product, p=[1, 0])
all_product_treated = np.random.choice([0,1], num_product, p=[0, 1])
all_product_control = torch.from_numpy(all_product_control).to(X_user_train.device).bool()
all_product_treated = torch.from_numpy(all_product_treated).to(X_user_train.device).bool()
X_user_test, X_product, price = X_user_test.to(device), X_product.to(device), price.to(device)

# Calculate expected revenue if all control
utilities = model(X_user_test, X_product, price, all_product_control)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum()
print(f"Expected Revenue: ${expected_revenue.item():.2f}")

# Calculate expected revenue if all treated
utilities = model(X_user_test, X_product, price, all_product_treated)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue_treated = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum() * discount_percentage
print(f"Expected Revenue: ${expected_revenue_treated.item():.2f}")

# Calculate GTE
linear = (expected_revenue_treated-expected_revenue).cpu().detach().numpy()
linear = linear * 600 / 266
print(linear)
linear_user_only = abs((linear - true)/true)
print(linear_user_only)
# Out:
# Expected Revenue: $37.74
# Expected Revenue: $8.91
# -65.0199560294474
# 0.05294899781477188

# %% [markdown]
# ### Only product features

# %%
class LinearMNLModel_ProductOnly(nn.Module):
    def __init__(self, product_feature_dim):
        super(LinearMNLModel_ProductOnly, self).__init__()
        self.beta_product = nn.Parameter(torch.randn(product_feature_dim))
        self.beta_price = nn.Parameter(torch.tensor(-1.0))

    def forward(self, x_user, X_product, price, prod_randomization):
        N, M = x_user.shape[0], X_product.shape[0]

        # Expand product features
        X_product_expanded = X_product.unsqueeze(0).expand(N, -1, -1).detach()
        utility_product = torch.sum(X_product_expanded * self.beta_product, dim=2)

        # Price adjustment
        adjusted_price = torch.where(
            prod_randomization.unsqueeze(0),
            price * discount_percentage,
            price
        )
        utility_price = adjusted_price * self.beta_price
        utility_price = utility_price.expand(N, M)

        total_utility = utility_product + utility_price

        # Outside option
        zero_utilities = torch.zeros(N, 1, device=total_utility.device)
        utilities_with_outside = torch.cat((zero_utilities,total_utility), dim=1)
        return utilities_with_outside

# %%
# Model training
model = LinearMNLModel_ProductOnly(product_feature_dim=X_product.shape[1]).to(device)

optimizer = optim.Adam(model.parameters(), lr=0.001)
num_epochs = 10000
l2_lambda = 1e-4  # Coefficient for L2 regularization
for epoch in range(num_epochs):
    optimizer.zero_grad()
    utilities = model(X_user_train, X_product, price, prod_randomization)
    utilities = utilities - utilities.max(dim=1, keepdim=True).values
    choice_probabilities = nn.functional.log_softmax(utilities, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train])

    # Compute L2 regularization penalty over all model parameters
    l2_norm = sum(param.pow(2.0).sum() for param in model.parameters())
    loss = loss + l2_lambda * l2_norm

    loss.backward()
    optimizer.step()
    if epoch % 1000 == 0:
        print(f'Epoch {epoch}, Loss: {loss.item()}')
# Out:
# Epoch 0, Loss: 2.1990792751312256
# Epoch 1000, Loss: 1.495612382888794
# Epoch 2000, Loss: 1.278860092163086
# Epoch 3000, Loss: 1.2116801738739014
# Epoch 4000, Loss: 1.190086007118225
# Epoch 5000, Loss: 1.184604287147522
# Epoch 6000, Loss: 1.1838302612304688
# Epoch 7000, Loss: 1.183793544769287
# Epoch 8000, Loss: 1.183793306350708
# Epoch 9000, Loss: 1.1837931871414185

# %%
# All control and all treated in test set
all_product_control = np.random.choice([0,1], num_product, p=[1, 0])
all_product_treated = np.random.choice([0,1], num_product, p=[0, 1])
all_product_control = torch.from_numpy(all_product_control).to(X_user_train.device).bool()
all_product_treated = torch.from_numpy(all_product_treated).to(X_user_train.device).bool()
X_user_test, X_product, price = X_user_test.to(device), X_product.to(device), price.to(device)

# Calculate expected revenue if all control
utilities = model(X_user_test, X_product, price, all_product_control)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum()
print(f"Expected Revenue: ${expected_revenue.item():.2f}")

# Calculate expected revenue if all treated
utilities = model(X_user_test, X_product, price, all_product_treated)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue_treated = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum() * discount_percentage
print(f"Expected Revenue: ${expected_revenue_treated.item():.2f}")

# Calculate GTE
linear = (expected_revenue_treated-expected_revenue).cpu().detach().numpy()
linear = linear * 600 / 266
print(linear)
linear_product_only = abs((linear - true)/true)
print(linear_product_only)
# Out:
# Expected Revenue: $25.70
# Expected Revenue: $16.56
# -20.61003061165487
# 0.6998037012360332

# %% [markdown]
# ### All features

# %%
# MNL choice model
class LinearMNLModel(nn.Module):
    def __init__(self, user_feature_dim, product_feature_dim):
        super(LinearMNLModel, self).__init__()
        # Initialize parameters for user and product features
        self.beta_user = nn.Parameter(torch.randn(user_feature_dim))
        self.beta_product = nn.Parameter(torch.randn(product_feature_dim))
        self.beta_price = nn.Parameter(torch.tensor(-1.0))
    def forward(self, x_user, X_product, price, prod_randomization):
        N, M = x_user.shape[0], X_product.shape[0]

        # Expand user and product features to create a [N, M, F] shaped tensor for each
        x_user_expanded = x_user.unsqueeze(1).expand(-1, M, -1).detach()
        X_product_expanded = X_product.unsqueeze(0).expand(N, -1, -1).detach()

        # Calculate linear utility from features
        utility_user = torch.sum(x_user_expanded * self.beta_user, dim=2)
        utility_product = torch.sum(X_product_expanded * self.beta_product, dim=2)

        # Adjust prices based on randomization
        adjusted_price = torch.where(
            prod_randomization.unsqueeze(0),
            price * discount_percentage,
            price
        )

        # Calculate utility from price, properly expanding its dimension
        utility_price = adjusted_price * self.beta_price  # [M]
        utility_price = utility_price.expand(N, M)  # [N, M]

        # Total utility including features and price
        total_utility = utility_user + utility_product + utility_price

        # Incorporate the outside option with utility 0
        zero_utilities = torch.zeros(N, 1, device=total_utility.device)
        utilities_with_outside = torch.cat((zero_utilities,total_utility), dim=1)

        return utilities_with_outside

# %%
# Model training
model = LinearMNLModel(
    user_feature_dim=X_user.shape[1],
    product_feature_dim=X_product.shape[1]
).to(device)

optimizer = optim.Adam(model.parameters(), lr=0.001)
num_epochs = 10000
l2_lambda = 1e-4  # Coefficient for L2 regularization
for epoch in range(num_epochs):
    optimizer.zero_grad()
    utilities = model(X_user_train, X_product, price, prod_randomization)
    utilities = utilities - utilities.max(dim=1, keepdim=True).values
    choice_probabilities = nn.functional.log_softmax(utilities, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train])

    # Compute L2 regularization penalty over all model parameters
    l2_norm = sum(param.pow(2.0).sum() for param in model.parameters())
    loss = loss + l2_lambda * l2_norm

    loss.backward()
    optimizer.step()
    if epoch % 1000 == 0:
        print(f'Epoch {epoch}, Loss: {loss.item()}')
# Out:
# Epoch 0, Loss: 2.50156831741333
# Epoch 1000, Loss: 1.3553760051727295
# Epoch 2000, Loss: 1.1897709369659424
# Epoch 3000, Loss: 1.160108208656311
# Epoch 4000, Loss: 1.1557260751724243
# Epoch 5000, Loss: 1.1551049947738647
# Epoch 6000, Loss: 1.154944658279419
# Epoch 7000, Loss: 1.154920220375061
# Epoch 8000, Loss: 1.1549186706542969
# Epoch 9000, Loss: 1.1549185514450073

# %%
# All control and all treated in test set
all_product_control = np.random.choice([0,1], num_product, p=[1, 0])
all_product_treated = np.random.choice([0,1], num_product, p=[0, 1])
all_product_control = torch.from_numpy(all_product_control).to(X_user_train.device).bool()
all_product_treated = torch.from_numpy(all_product_treated).to(X_user_train.device).bool()
X_user_test, X_product, price = X_user_test.to(device), X_product.to(device), price.to(device)

# Calculate expected revenue if all control
utilities = model(X_user_test, X_product, price, all_product_control)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum()
print(f"Expected Revenue: ${expected_revenue.item():.2f}")

# Calculate expected revenue if all treated
utilities = model(X_user_test, X_product, price, all_product_treated)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue_treated = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum() * discount_percentage
print(f"Expected Revenue: ${expected_revenue_treated.item():.2f}")

# Calculate GTE
linear = (expected_revenue_treated-expected_revenue).cpu().detach().numpy()
linear = linear * 600 / 266
print(linear)
linear_all = abs((linear - true)/true)
print(linear_all)
# Out:
# Expected Revenue: $28.17
# Expected Revenue: $12.08
# -36.291435069607616
# 0.47139552143274294

# %% [markdown]
# ## PDL Estimator

# %%
# Validation set
X_user_train1, X_user_val, choice_train1, choice_val = train_test_split(X_user_train, choice_train,test_size=0.1,random_state=34)

# %%
# Prepare data
def prepare_data(user_features, product_features, prices):
    num_products = product_features.shape[0]
    all_x_other_products = []
    all_other_prices = []
    for i in range(num_products):
        indices = [j for j in range(num_products) if j != i]
        other_products = product_features[indices].reshape(-1)
        other_product_prices = prices[indices]
        all_x_other_products.append(other_products)
        all_other_prices.append(other_product_prices)
    # Convert lists to tensor
    all_x_other_products = torch.stack(all_x_other_products, dim=0)
    all_other_prices = torch.stack(all_other_prices, dim=0)
    return user_features, product_features, prices, all_x_other_products, all_other_prices

# %% [markdown]
# ### No features

# %%
class DeepMNLModel_No(nn.Module):
    """
    Price-only Deep MNL:
    u_ij = theta(p_j)
    Outside option utility = 0.
    """
    def __init__(self, num_product, hidden=5):
        super(DeepMNLModel_No, self).__init__()

        # theta(p_j):
        # Input:  [1]
        # Output: scalar utility
        self.theta = nn.Sequential(
            nn.Linear(1, hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, x_user, X_product, X_other_products, x_other_prices, price, prod_randomization):
        """
        Inputs used:
        - price: [M]  own price p_j
        - prod_randomization: [M]  treatment indicator
        """
        device = price.device
        N, M = x_user.shape[0], price.shape[0]

        # Apply treatment discount to own prices
        adjusted_price = torch.where(
            prod_randomization.to(device).bool(),
            price * discount_percentage,
            price
        )  # [M]

        # Prepare input for theta: [M, 1]
        pj_input = adjusted_price.unsqueeze(1)

        # Expand to all users: [N, M, 1]
        theta_input_exp = pj_input.unsqueeze(0).expand(N, -1, -1)

        # u_ij = theta(p_j): [N, M]
        utilities = self.theta(theta_input_exp).squeeze(-1)

        # Outside option utility = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utilities], dim=1)

        return utilities_with_outside

# %%
# Apply the model
pdlmodel = DeepMNLModel_No(
    num_product=X_product.shape[0],
    hidden=5
).to(device)

# Weight initialization
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)

pdlmodel.apply(init_weights)
# Out:
# DeepMNLModel_No(
#   (theta): Sequential(
#     (0): Linear(in_features=1, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# ----- Prepare validation data -----
prepared_val = prepare_data(
    X_user_val,
    X_product,
    price * (1 - (1 - discount_percentage) * prod_randomization)
)
user_features_val, product_features_val, _, all_x_other_products_val, all_other_prices_val = prepared_val

user_features_val = user_features_val.to(device)
product_features_val = product_features_val.to(device)
all_x_other_products_val = all_x_other_products_val.to(device)
all_other_prices_val = all_other_prices_val.to(device)
choice_val = choice_val.to(device)

# ----- Optimizer and scheduler -----
optimizer = optim.Adam(pdlmodel.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1000, gamma=0.5)
l2_lambda = 1e-4  # L2 regularization coefficient

# Early stopping setup
best_val_loss = float('inf')
patience = 15
patience_counter = 0

# ----- Training loop -----
for epoch in range(2000):
    pdlmodel.train()
    optimizer.zero_grad()

    # Forward pass (train): use prepared prices and other-prices matrix
    outputs = pdlmodel(
        user_features,         # x_user (not used inside DeepMNLModel_No, but kept for interface)
        product_features,      # X_product (not used)
        all_x_other_products,  # X_other_products (not used in No model)
        all_other_prices,      # x_other_prices: p_-j
        prices,                # price: experimental p_j (after discount)
        prod_randomization     # can be ignored inside No model
    )
    choice_probabilities = F.log_softmax(outputs, dim=1)

    # Training loss
    loss = -torch.mean(
        choice_probabilities[
            torch.arange(choice_probabilities.shape[0], device=device),
            choice_train1
        ]
    )

    # L2 regularization
    l2_norm = sum(param.pow(2.0).sum() for param in pdlmodel.parameters())
    loss = loss + l2_lambda * l2_norm

    # Backward
    loss.backward()
    optimizer.step()

    # ----- Validation -----
    pdlmodel.eval()
    with torch.no_grad():
        val_outputs = pdlmodel(
            user_features_val,
            product_features_val,
            all_x_other_products_val,
            all_other_prices_val,
            prices,              # same product prices for validation
            prod_randomization
        )
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(
            val_choice_probabilities[
                torch.arange(val_choice_probabilities.shape[0], device=device),
                choice_val
            ]
        )

    print(
        f"Epoch {epoch+1}, "
        f"Training Loss: {loss.item():.4f}, "
        f"Validation Loss: {val_loss.item():.4f}"
    )

    # Early stopping logic
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        torch.save(pdlmodel.state_dict(), 'best_model.pth')
    else:
        patience_counter += 1

    if patience_counter >= patience:
        print("Early stopping triggered")
        break

    scheduler.step()
# Out:
# Epoch 1, Training Loss: 1.9899, Validation Loss: 1.9602
# Epoch 2, Training Loss: 1.9660, Validation Loss: 1.9387
# Epoch 3, Training Loss: 1.9432, Validation Loss: 1.9212
# Epoch 4, Training Loss: 1.9235, Validation Loss: 1.9042
# Epoch 5, Training Loss: 1.9043, Validation Loss: 1.8872
# Epoch 6, Training Loss: 1.8854, Validation Loss: 1.8704
# Epoch 7, Training Loss: 1.8668, Validation Loss: 1.8534
# Epoch 8, Training Loss: 1.8481, Validation Loss: 1.8362
# Epoch 9, Training Loss: 1.8293, Validation Loss: 1.8187
# Epoch 10, Training Loss: 1.8105, Validation Loss: 1.8011
# Epoch 11, Training Loss: 1.7915, Validation Loss: 1.7832
# Epoch 12, Training Loss: 1.7724, Validation Loss: 1.7652
# Epoch 13, Training Loss: 1.7533, Validation Loss: 1.7471
# Epoch 14, Training Loss: 1.7341, Validation Loss: 1.7294
# Epoch 15, Training Loss: 1.7164, Validation Loss: 1.7121
# Epoch 16, Training Loss: 1.6991, Validation Loss: 1.6939
# Epoch 17, Training Loss: 1.6805, Validation Loss: 1.6748
# Epoch 18, Training Loss: 1.6606, Validation Loss: 1.6552
# Epoch 19, Training Loss: 1.6402, Validation Loss: 1.6354
# Epoch 20, Training Loss: 1.6195, Validation Loss: 1.6154
# Epoch 21, Training Loss: 1.5986, Validation Loss: 1.5952
# Epoch 22, Training Loss: 1.5775, Validation Loss: 1.5750
# Epoch 23, Training Loss: 1.5563, Validation Loss: 1.5548
# Epoch 24, Training Loss: 1.5351, Validation Loss: 1.5349
# Epoch 25, Training Loss: 1.5141, Validation Loss: 1.5152
# Epoch 26, Training Loss: 1.4933, Validation Loss: 1.4960
# Epoch 27, Training Loss: 1.4730, Validation Loss: 1.4774
# Epoch 28, Training Loss: 1.4532, Validation Loss: 1.4594
# Epoch 29, Training Loss: 1.4341, Validation Loss: 1.4423
# Epoch 30, Training Loss: 1.4158, Validation Loss: 1.4261
# Epoch 31, Training Loss: 1.3985, Validation Loss: 1.4110
# Epoch 32, Training Loss: 1.3823, Validation Loss: 1.3971
# Epoch 33, Training Loss: 1.3673, Validation Loss: 1.3844
# Epoch 34, Training Loss: 1.3536, Validation Loss: 1.3729
# Epoch 35, Training Loss: 1.3412, Validation Loss: 1.3628
# Epoch 36, Training Loss: 1.3303, Validation Loss: 1.3540
# Epoch 37, Training Loss: 1.3209, Validation Loss: 1.3464
# Epoch 38, Training Loss: 1.3128, Validation Loss: 1.3399
# Epoch 39, Training Loss: 1.3061, Validation Loss: 1.3345
# Epoch 40, Training Loss: 1.3006, Validation Loss: 1.3299
# Epoch 41, Training Loss: 1.2962, Validation Loss: 1.3261
# Epoch 42, Training Loss: 1.2928, Validation Loss: 1.3227
# Epoch 43, Training Loss: 1.2901, Validation Loss: 1.3196
# Epoch 44, Training Loss: 1.2880, Validation Loss: 1.3166
# Epoch 45, Training Loss: 1.2863, Validation Loss: 1.3135
# Epoch 46, Training Loss: 1.2848, Validation Loss: 1.3102
# Epoch 47, Training Loss: 1.2834, Validation Loss: 1.3065
# Epoch 48, Training Loss: 1.2818, Validation Loss: 1.3024
# Epoch 49, Training Loss: 1.2801, Validation Loss: 1.2979
# Epoch 50, Training Loss: 1.2781, Validation Loss: 1.2928
# Epoch 51, Training Loss: 1.2758, Validation Loss: 1.2873
# Epoch 52, Training Loss: 1.2732, Validation Loss: 1.2814
# Epoch 53, Training Loss: 1.2703, Validation Loss: 1.2752
# Epoch 54, Training Loss: 1.2673, Validation Loss: 1.2687
# Epoch 55, Training Loss: 1.2640, Validation Loss: 1.2620
# Epoch 56, Training Loss: 1.2606, Validation Loss: 1.2552
# Epoch 57, Training Loss: 1.2572, Validation Loss: 1.2484
# Epoch 58, Training Loss: 1.2538, Validation Loss: 1.2417
# Epoch 59, Training Loss: 1.2504, Validation Loss: 1.2350
# Epoch 60, Training Loss: 1.2472, Validation Loss: 1.2285
# Epoch 61, Training Loss: 1.2441, Validation Loss: 1.2221
# Epoch 62, Training Loss: 1.2412, Validation Loss: 1.2159
# Epoch 63, Training Loss: 1.2386, Validation Loss: 1.2100
# Epoch 64, Training Loss: 1.2361, Validation Loss: 1.2043
# Epoch 65, Training Loss: 1.2339, Validation Loss: 1.1988
# Epoch 66, Training Loss: 1.2318, Validation Loss: 1.1934
# Epoch 67, Training Loss: 1.2300, Validation Loss: 1.1882
# Epoch 68, Training Loss: 1.2283, Validation Loss: 1.1833
# Epoch 69, Training Loss: 1.2268, Validation Loss: 1.1783
# Epoch 70, Training Loss: 1.2254, Validation Loss: 1.1734
# Epoch 71, Training Loss: 1.2241, Validation Loss: 1.1687
# Epoch 72, Training Loss: 1.2229, Validation Loss: 1.1641
# Epoch 73, Training Loss: 1.2219, Validation Loss: 1.1594
# Epoch 74, Training Loss: 1.2209, Validation Loss: 1.1549
# Epoch 75, Training Loss: 1.2201, Validation Loss: 1.1505
# Epoch 76, Training Loss: 1.2194, Validation Loss: 1.1462
# Epoch 77, Training Loss: 1.2188, Validation Loss: 1.1421
# Epoch 78, Training Loss: 1.2185, Validation Loss: 1.1383
# Epoch 79, Training Loss: 1.2182, Validation Loss: 1.1347
# Epoch 80, Training Loss: 1.2182, Validation Loss: 1.1314
# Epoch 81, Training Loss: 1.2182, Validation Loss: 1.1286
# Epoch 82, Training Loss: 1.2183, Validation Loss: 1.1263
# Epoch 83, Training Loss: 1.2185, Validation Loss: 1.1245
# Epoch 84, Training Loss: 1.2186, Validation Loss: 1.1232
# Epoch 85, Training Loss: 1.2187, Validation Loss: 1.1223
# Epoch 86, Training Loss: 1.2188, Validation Loss: 1.1219
# Epoch 87, Training Loss: 1.2189, Validation Loss: 1.1218
# Epoch 88, Training Loss: 1.2190, Validation Loss: 1.1220
# Epoch 89, Training Loss: 1.2190, Validation Loss: 1.1223
# Epoch 90, Training Loss: 1.2189, Validation Loss: 1.1229
# Epoch 91, Training Loss: 1.2188, Validation Loss: 1.1235
# Epoch 92, Training Loss: 1.2188, Validation Loss: 1.1242
# Epoch 93, Training Loss: 1.2187, Validation Loss: 1.1250
# Epoch 94, Training Loss: 1.2186, Validation Loss: 1.1259
# Epoch 95, Training Loss: 1.2185, Validation Loss: 1.1267
# Epoch 96, Training Loss: 1.2184, Validation Loss: 1.1276
# Epoch 97, Training Loss: 1.2183, Validation Loss: 1.1285
# Epoch 98, Training Loss: 1.2183, Validation Loss: 1.1293
# Epoch 99, Training Loss: 1.2182, Validation Loss: 1.1301
# Epoch 100, Training Loss: 1.2182, Validation Loss: 1.1309
# Epoch 101, Training Loss: 1.2181, Validation Loss: 1.1317
# Epoch 102, Training Loss: 1.2181, Validation Loss: 1.1324
# Early stopping triggered

# %%
# All-control and all-treated for test set
num_product = X_product.shape[0]

# All control: product_randomization = 0
all_product_control = torch.zeros(num_product, device=device).bool()

# All treated: product_randomization = 1
all_product_treated = torch.ones(num_product, device=device).bool()

# Move base price and test users/products to device
X_user_test = X_user_test.to(device)
X_product = X_product.to(device)
price = price.to(device)

# --------- Expected revenue: all control ----------
# Control prices = base prices (no discount)
price_control = price.clone()

# Prepare test data under all-control prices
user_test_ctrl, product_test_ctrl, prices_ctrl, x_other_products_ctrl, other_prices_ctrl = prepare_data(
    X_user_test,
    X_product,
    price_control
)

utilities_ctrl = pdlmodel(
    user_test_ctrl,
    product_test_ctrl,
    x_other_products_ctrl,
    other_prices_ctrl,
    prices_ctrl,          # control prices
    all_product_control   # all False
)

probabilities_ctrl = F.softmax(utilities_ctrl, dim=1)

price_with_outside_ctrl = torch.cat(
    (torch.zeros(1, device=price.device), prices_ctrl), dim=0
)  # [M+1]

expected_revenue_ctrl = torch.sum(
    probabilities_ctrl * price_with_outside_ctrl.unsqueeze(0).expand_as(probabilities_ctrl),
    dim=1
).sum()

print(f"Expected Revenue (all control): ${expected_revenue_ctrl.item():.2f}")

# --------- Expected revenue: all treated ----------
# Treated prices = discounted prices
price_treated = price * discount_percentage

user_test_trt, product_test_trt, prices_trt, x_other_products_trt, other_prices_trt = prepare_data(
    X_user_test,
    X_product,
    price_treated
)

utilities_trt = pdlmodel(
    user_test_trt,
    product_test_trt,
    x_other_products_trt,
    other_prices_trt,
    prices_trt,          # treated prices
    all_product_treated  # all True
)

probabilities_trt = F.softmax(utilities_trt, dim=1)

price_with_outside_trt = torch.cat(
    (torch.zeros(1, device=price.device), prices_trt), dim=0
)

expected_revenue_trt = torch.sum(
    probabilities_trt * price_with_outside_trt.unsqueeze(0).expand_as(probabilities_trt),
    dim=1
).sum()

print(f"Expected Revenue (all treated): ${expected_revenue_trt.item():.2f}")

# --------- GTE ----------
pdl = (expected_revenue_trt - expected_revenue_ctrl).cpu().detach().numpy() * 600 / 266
print(pdl)

pdl_no = abs((pdl - true) / true)
print(pdl_no)
# Out:
# Expected Revenue (all control): $37.61
# Expected Revenue (all treated): $8.84
# -64.90133758774377
# 0.05467673989509868

# %% [markdown]
# ### Only user features

# %%
class DeepMNLModel_UserOnly(nn.Module):
    """
    Deep MNL (user + own price only):
    u_ij = theta(x_i, p_j)
    Outside option utility = 0.
    """
    def __init__(self, user_dim, num_product, hidden=5):
        super(DeepMNLModel_UserOnly, self).__init__()

        # theta(x_i, p_j)
        # Input per (i,j): [user_dim + 1]
        self.theta = nn.Sequential(
            nn.Linear(user_dim + 1, hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, x_user, X_product, X_other_products,
                x_other_prices, price, prod_randomization):
        """
        x_user: [N, F]   user features x_i
        price:  [M]      own price p_j (已经在外面处理好折扣的话，这里直接用)
        其它输入在该模型中不使用：
        - X_product, X_other_products, x_other_prices, prod_randomization
        """
        device = price.device
        N, M = x_user.shape[0], price.shape[0]

        # p_j: [M, 1]
        pj_feat = price.unsqueeze(1)          # [M, 1]

        # 扩展到所有用户： [N, M, 1]
        pj_feat_exp = pj_feat.unsqueeze(0).expand(N, -1, -1)

        # 用户特征扩展： [N, 1, F] -> [N, M, F]
        x_user_exp = x_user.unsqueeze(1).expand(-1, M, -1)

        # theta 输入: [N, M, F + 1]
        theta_input = torch.cat([x_user_exp, pj_feat_exp], dim=2)

        # reshape 成 [N*M, D]
        theta_input_flat = theta_input.reshape(N * M, -1)

        # u_ij: [N*M, 1] -> [N, M]
        utilities = self.theta(theta_input_flat).view(N, M)

        # outside option utility = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utilities], dim=1)

        return utilities_with_outside

# %%
# Apply the model
pdlmodel = DeepMNLModel_UserOnly(
    user_dim=X_user.shape[1],
    num_product=X_product.shape[0],
    hidden=5
).to(device)

# Weight initialization
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)

pdlmodel.apply(init_weights)
# Out:
# DeepMNLModel_UserOnly(
#   (theta): Sequential(
#     (0): Linear(in_features=4, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# ----- Prepare validation data -----
prepared_val = prepare_data(
    X_user_val,
    X_product,
    price * (1 - (1 - discount_percentage) * prod_randomization)
)
user_features_val, product_features_val, _, all_x_other_products_val, all_other_prices_val = prepared_val

user_features_val = user_features_val.to(device)
product_features_val = product_features_val.to(device)
all_x_other_products_val = all_x_other_products_val.to(device)
all_other_prices_val = all_other_prices_val.to(device)
choice_val = choice_val.to(device)

# ----- Optimizer and scheduler -----
optimizer = optim.Adam(pdlmodel.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1000, gamma=0.5)
l2_lambda = 1e-4  # L2 regularization coefficient

# Early stopping setup
best_val_loss = float('inf')
patience = 15
patience_counter = 0

# ----- Training loop -----
for epoch in range(2000):
    pdlmodel.train()
    optimizer.zero_grad()

    # Forward pass (train): use prepared prices and other-prices matrix
    outputs = pdlmodel(
        user_features,         # x_user (not used inside DeepMNLModel_No, but kept for interface)
        product_features,      # X_product (not used)
        all_x_other_products,  # X_other_products (not used in No model)
        all_other_prices,      # x_other_prices: p_-j
        prices,                # price: experimental p_j (after discount)
        prod_randomization     # can be ignored inside No model
    )
    choice_probabilities = F.log_softmax(outputs, dim=1)

    # Training loss
    loss = -torch.mean(
        choice_probabilities[
            torch.arange(choice_probabilities.shape[0], device=device),
            choice_train1
        ]
    )

    # L2 regularization
    l2_norm = sum(param.pow(2.0).sum() for param in pdlmodel.parameters())
    loss = loss + l2_lambda * l2_norm

    # Backward
    loss.backward()
    optimizer.step()

    # ----- Validation -----
    pdlmodel.eval()
    with torch.no_grad():
        val_outputs = pdlmodel(
            user_features_val,
            product_features_val,
            all_x_other_products_val,
            all_other_prices_val,
            prices,              # same product prices for validation
            prod_randomization
        )
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(
            val_choice_probabilities[
                torch.arange(val_choice_probabilities.shape[0], device=device),
                choice_val
            ]
        )

    print(
        f"Epoch {epoch+1}, "
        f"Training Loss: {loss.item():.4f}, "
        f"Validation Loss: {val_loss.item():.4f}"
    )

    # Early stopping logic
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        torch.save(pdlmodel.state_dict(), 'best_model.pth')
    else:
        patience_counter += 1

    if patience_counter >= patience:
        print("Early stopping triggered")
        break

    scheduler.step()
# Out:
# Epoch 1, Training Loss: 1.9901, Validation Loss: 1.9655
# Epoch 2, Training Loss: 1.9723, Validation Loss: 1.9547
# Epoch 3, Training Loss: 1.9611, Validation Loss: 1.9457
# Epoch 4, Training Loss: 1.9508, Validation Loss: 1.9377
# Epoch 5, Training Loss: 1.9418, Validation Loss: 1.9301
# Epoch 6, Training Loss: 1.9335, Validation Loss: 1.9224
# Epoch 7, Training Loss: 1.9257, Validation Loss: 1.9152
# Epoch 8, Training Loss: 1.9189, Validation Loss: 1.9083
# Epoch 9, Training Loss: 1.9124, Validation Loss: 1.9016
# Epoch 10, Training Loss: 1.9062, Validation Loss: 1.8953
# Epoch 11, Training Loss: 1.9002, Validation Loss: 1.8895
# Epoch 12, Training Loss: 1.8946, Validation Loss: 1.8839
# Epoch 13, Training Loss: 1.8895, Validation Loss: 1.8784
# Epoch 14, Training Loss: 1.8843, Validation Loss: 1.8729
# Epoch 15, Training Loss: 1.8792, Validation Loss: 1.8674
# Epoch 16, Training Loss: 1.8741, Validation Loss: 1.8619
# Epoch 17, Training Loss: 1.8690, Validation Loss: 1.8564
# Epoch 18, Training Loss: 1.8640, Validation Loss: 1.8510
# Epoch 19, Training Loss: 1.8589, Validation Loss: 1.8455
# Epoch 20, Training Loss: 1.8539, Validation Loss: 1.8401
# Epoch 21, Training Loss: 1.8489, Validation Loss: 1.8347
# Epoch 22, Training Loss: 1.8439, Validation Loss: 1.8293
# Epoch 23, Training Loss: 1.8389, Validation Loss: 1.8239
# Epoch 24, Training Loss: 1.8339, Validation Loss: 1.8186
# Epoch 25, Training Loss: 1.8290, Validation Loss: 1.8133
# Epoch 26, Training Loss: 1.8241, Validation Loss: 1.8080
# Epoch 27, Training Loss: 1.8192, Validation Loss: 1.8027
# Epoch 28, Training Loss: 1.8143, Validation Loss: 1.7974
# Epoch 29, Training Loss: 1.8094, Validation Loss: 1.7922
# Epoch 30, Training Loss: 1.8046, Validation Loss: 1.7869
# Epoch 31, Training Loss: 1.7998, Validation Loss: 1.7817
# Epoch 32, Training Loss: 1.7950, Validation Loss: 1.7765
# Epoch 33, Training Loss: 1.7902, Validation Loss: 1.7714
# Epoch 34, Training Loss: 1.7854, Validation Loss: 1.7662
# Epoch 35, Training Loss: 1.7807, Validation Loss: 1.7611
# Epoch 36, Training Loss: 1.7760, Validation Loss: 1.7560
# Epoch 37, Training Loss: 1.7713, Validation Loss: 1.7509
# Epoch 38, Training Loss: 1.7666, Validation Loss: 1.7459
# Epoch 39, Training Loss: 1.7619, Validation Loss: 1.7408
# Epoch 40, Training Loss: 1.7573, Validation Loss: 1.7358
# Epoch 41, Training Loss: 1.7527, Validation Loss: 1.7308
# Epoch 42, Training Loss: 1.7481, Validation Loss: 1.7258
# Epoch 43, Training Loss: 1.7435, Validation Loss: 1.7209
# Epoch 44, Training Loss: 1.7390, Validation Loss: 1.7160
# Epoch 45, Training Loss: 1.7344, Validation Loss: 1.7111
# Epoch 46, Training Loss: 1.7299, Validation Loss: 1.7062
# Epoch 47, Training Loss: 1.7254, Validation Loss: 1.7013
# Epoch 48, Training Loss: 1.7210, Validation Loss: 1.6965
# Epoch 49, Training Loss: 1.7165, Validation Loss: 1.6917
# Epoch 50, Training Loss: 1.7121, Validation Loss: 1.6869
# Epoch 51, Training Loss: 1.7077, Validation Loss: 1.6821
# Epoch 52, Training Loss: 1.7034, Validation Loss: 1.6774
# Epoch 53, Training Loss: 1.6990, Validation Loss: 1.6726
# Epoch 54, Training Loss: 1.6947, Validation Loss: 1.6679
# Epoch 55, Training Loss: 1.6904, Validation Loss: 1.6633
# Epoch 56, Training Loss: 1.6861, Validation Loss: 1.6586
# Epoch 57, Training Loss: 1.6818, Validation Loss: 1.6540
# Epoch 58, Training Loss: 1.6776, Validation Loss: 1.6494
# Epoch 59, Training Loss: 1.6734, Validation Loss: 1.6448
# Epoch 60, Training Loss: 1.6692, Validation Loss: 1.6403
# Epoch 61, Training Loss: 1.6650, Validation Loss: 1.6357
# Epoch 62, Training Loss: 1.6609, Validation Loss: 1.6312
# Epoch 63, Training Loss: 1.6568, Validation Loss: 1.6267
# Epoch 64, Training Loss: 1.6527, Validation Loss: 1.6223
# Epoch 65, Training Loss: 1.6486, Validation Loss: 1.6179
# Epoch 66, Training Loss: 1.6446, Validation Loss: 1.6134
# Epoch 67, Training Loss: 1.6406, Validation Loss: 1.6091
# Epoch 68, Training Loss: 1.6366, Validation Loss: 1.6047
# Epoch 69, Training Loss: 1.6326, Validation Loss: 1.6004
# Epoch 70, Training Loss: 1.6286, Validation Loss: 1.5961
# Epoch 71, Training Loss: 1.6247, Validation Loss: 1.5918
# Epoch 72, Training Loss: 1.6208, Validation Loss: 1.5875
# Epoch 73, Training Loss: 1.6169, Validation Loss: 1.5833
# Epoch 74, Training Loss: 1.6131, Validation Loss: 1.5791
# Epoch 75, Training Loss: 1.6092, Validation Loss: 1.5749
# Epoch 76, Training Loss: 1.6054, Validation Loss: 1.5707
# Epoch 77, Training Loss: 1.6016, Validation Loss: 1.5666
# Epoch 78, Training Loss: 1.5979, Validation Loss: 1.5625
# Epoch 79, Training Loss: 1.5941, Validation Loss: 1.5584
# Epoch 80, Training Loss: 1.5904, Validation Loss: 1.5543
# Epoch 81, Training Loss: 1.5867, Validation Loss: 1.5503
# Epoch 82, Training Loss: 1.5831, Validation Loss: 1.5463
# Epoch 83, Training Loss: 1.5794, Validation Loss: 1.5423
# Epoch 84, Training Loss: 1.5758, Validation Loss: 1.5383
# Epoch 85, Training Loss: 1.5722, Validation Loss: 1.5344
# Epoch 86, Training Loss: 1.5687, Validation Loss: 1.5305
# Epoch 87, Training Loss: 1.5651, Validation Loss: 1.5266
# Epoch 88, Training Loss: 1.5616, Validation Loss: 1.5227
# Epoch 89, Training Loss: 1.5581, Validation Loss: 1.5189
# Epoch 90, Training Loss: 1.5546, Validation Loss: 1.5151
# Epoch 91, Training Loss: 1.5512, Validation Loss: 1.5113
# Epoch 92, Training Loss: 1.5478, Validation Loss: 1.5075
# Epoch 93, Training Loss: 1.5444, Validation Loss: 1.5038
# Epoch 94, Training Loss: 1.5410, Validation Loss: 1.5001
# Epoch 95, Training Loss: 1.5377, Validation Loss: 1.4964
# Epoch 96, Training Loss: 1.5343, Validation Loss: 1.4927
# Epoch 97, Training Loss: 1.5310, Validation Loss: 1.4891
# Epoch 98, Training Loss: 1.5277, Validation Loss: 1.4855
# Epoch 99, Training Loss: 1.5245, Validation Loss: 1.4819
# Epoch 100, Training Loss: 1.5213, Validation Loss: 1.4783
# Epoch 101, Training Loss: 1.5181, Validation Loss: 1.4748
# Epoch 102, Training Loss: 1.5149, Validation Loss: 1.4713
# Epoch 103, Training Loss: 1.5117, Validation Loss: 1.4678
# Epoch 104, Training Loss: 1.5086, Validation Loss: 1.4643
# Epoch 105, Training Loss: 1.5055, Validation Loss: 1.4609
# Epoch 106, Training Loss: 1.5024, Validation Loss: 1.4575
# Epoch 107, Training Loss: 1.4993, Validation Loss: 1.4541
# Epoch 108, Training Loss: 1.4963, Validation Loss: 1.4507
# Epoch 109, Training Loss: 1.4933, Validation Loss: 1.4474
# Epoch 110, Training Loss: 1.4903, Validation Loss: 1.4441
# Epoch 111, Training Loss: 1.4873, Validation Loss: 1.4408
# Epoch 112, Training Loss: 1.4844, Validation Loss: 1.4375
# Epoch 113, Training Loss: 1.4815, Validation Loss: 1.4343
# Epoch 114, Training Loss: 1.4786, Validation Loss: 1.4311
# Epoch 115, Training Loss: 1.4757, Validation Loss: 1.4279
# Epoch 116, Training Loss: 1.4729, Validation Loss: 1.4247
# Epoch 117, Training Loss: 1.4700, Validation Loss: 1.4216
# Epoch 118, Training Loss: 1.4672, Validation Loss: 1.4184
# Epoch 119, Training Loss: 1.4644, Validation Loss: 1.4153
# Epoch 120, Training Loss: 1.4617, Validation Loss: 1.4123
# Epoch 121, Training Loss: 1.4590, Validation Loss: 1.4092
# Epoch 122, Training Loss: 1.4563, Validation Loss: 1.4062
# Epoch 123, Training Loss: 1.4536, Validation Loss: 1.4032
# Epoch 124, Training Loss: 1.4509, Validation Loss: 1.4002
# Epoch 125, Training Loss: 1.4483, Validation Loss: 1.3973
# Epoch 126, Training Loss: 1.4456, Validation Loss: 1.3944
# Epoch 127, Training Loss: 1.4430, Validation Loss: 1.3915
# Epoch 128, Training Loss: 1.4405, Validation Loss: 1.3886
# Epoch 129, Training Loss: 1.4379, Validation Loss: 1.3857
# Epoch 130, Training Loss: 1.4354, Validation Loss: 1.3829
# Epoch 131, Training Loss: 1.4329, Validation Loss: 1.3801
# Epoch 132, Training Loss: 1.4304, Validation Loss: 1.3773
# Epoch 133, Training Loss: 1.4279, Validation Loss: 1.3745
# Epoch 134, Training Loss: 1.4255, Validation Loss: 1.3718
# Epoch 135, Training Loss: 1.4231, Validation Loss: 1.3691
# Epoch 136, Training Loss: 1.4207, Validation Loss: 1.3664
# Epoch 137, Training Loss: 1.4183, Validation Loss: 1.3637
# Epoch 138, Training Loss: 1.4160, Validation Loss: 1.3611
# Epoch 139, Training Loss: 1.4136, Validation Loss: 1.3584
# Epoch 140, Training Loss: 1.4113, Validation Loss: 1.3558
# Epoch 141, Training Loss: 1.4090, Validation Loss: 1.3533
# Epoch 142, Training Loss: 1.4068, Validation Loss: 1.3507
# Epoch 143, Training Loss: 1.4045, Validation Loss: 1.3482
# Epoch 144, Training Loss: 1.4023, Validation Loss: 1.3457
# Epoch 145, Training Loss: 1.4001, Validation Loss: 1.3432
# Epoch 146, Training Loss: 1.3979, Validation Loss: 1.3407
# Epoch 147, Training Loss: 1.3958, Validation Loss: 1.3383
# Epoch 148, Training Loss: 1.3936, Validation Loss: 1.3358
# Epoch 149, Training Loss: 1.3915, Validation Loss: 1.3334
# Epoch 150, Training Loss: 1.3894, Validation Loss: 1.3310
# Epoch 151, Training Loss: 1.3873, Validation Loss: 1.3287
# Epoch 152, Training Loss: 1.3853, Validation Loss: 1.3263
# Epoch 153, Training Loss: 1.3832, Validation Loss: 1.3240
# Epoch 154, Training Loss: 1.3812, Validation Loss: 1.3217
# Epoch 155, Training Loss: 1.3792, Validation Loss: 1.3195
# Epoch 156, Training Loss: 1.3773, Validation Loss: 1.3172
# Epoch 157, Training Loss: 1.3753, Validation Loss: 1.3150
# Epoch 158, Training Loss: 1.3734, Validation Loss: 1.3128
# Epoch 159, Training Loss: 1.3714, Validation Loss: 1.3106
# Epoch 160, Training Loss: 1.3695, Validation Loss: 1.3084
# Epoch 161, Training Loss: 1.3677, Validation Loss: 1.3062
# Epoch 162, Training Loss: 1.3658, Validation Loss: 1.3041
# Epoch 163, Training Loss: 1.3640, Validation Loss: 1.3020
# Epoch 164, Training Loss: 1.3621, Validation Loss: 1.2999
# Epoch 165, Training Loss: 1.3603, Validation Loss: 1.2978
# Epoch 166, Training Loss: 1.3586, Validation Loss: 1.2958
# Epoch 167, Training Loss: 1.3568, Validation Loss: 1.2938
# Epoch 168, Training Loss: 1.3550, Validation Loss: 1.2917
# Epoch 169, Training Loss: 1.3533, Validation Loss: 1.2898
# Epoch 170, Training Loss: 1.3516, Validation Loss: 1.2878
# Epoch 171, Training Loss: 1.3499, Validation Loss: 1.2858
# Epoch 172, Training Loss: 1.3482, Validation Loss: 1.2839
# Epoch 173, Training Loss: 1.3466, Validation Loss: 1.2820
# Epoch 174, Training Loss: 1.3449, Validation Loss: 1.2801
# Epoch 175, Training Loss: 1.3433, Validation Loss: 1.2782
# Epoch 176, Training Loss: 1.3417, Validation Loss: 1.2763
# Epoch 177, Training Loss: 1.3401, Validation Loss: 1.2745
# Epoch 178, Training Loss: 1.3386, Validation Loss: 1.2727
# Epoch 179, Training Loss: 1.3370, Validation Loss: 1.2709
# Epoch 180, Training Loss: 1.3355, Validation Loss: 1.2691
# Epoch 181, Training Loss: 1.3340, Validation Loss: 1.2673
# Epoch 182, Training Loss: 1.3325, Validation Loss: 1.2656
# Epoch 183, Training Loss: 1.3310, Validation Loss: 1.2638
# Epoch 184, Training Loss: 1.3295, Validation Loss: 1.2621
# Epoch 185, Training Loss: 1.3281, Validation Loss: 1.2604
# Epoch 186, Training Loss: 1.3266, Validation Loss: 1.2587
# Epoch 187, Training Loss: 1.3252, Validation Loss: 1.2571
# Epoch 188, Training Loss: 1.3238, Validation Loss: 1.2554
# Epoch 189, Training Loss: 1.3224, Validation Loss: 1.2538
# Epoch 190, Training Loss: 1.3210, Validation Loss: 1.2522
# Epoch 191, Training Loss: 1.3197, Validation Loss: 1.2506
# Epoch 192, Training Loss: 1.3184, Validation Loss: 1.2490
# Epoch 193, Training Loss: 1.3170, Validation Loss: 1.2475
# Epoch 194, Training Loss: 1.3157, Validation Loss: 1.2459
# Epoch 195, Training Loss: 1.3144, Validation Loss: 1.2444
# Epoch 196, Training Loss: 1.3131, Validation Loss: 1.2429
# Epoch 197, Training Loss: 1.3119, Validation Loss: 1.2414
# Epoch 198, Training Loss: 1.3106, Validation Loss: 1.2399
# Epoch 199, Training Loss: 1.3094, Validation Loss: 1.2384
# Epoch 200, Training Loss: 1.3082, Validation Loss: 1.2370
# Epoch 201, Training Loss: 1.3070, Validation Loss: 1.2355
# Epoch 202, Training Loss: 1.3058, Validation Loss: 1.2341
# Epoch 203, Training Loss: 1.3046, Validation Loss: 1.2327
# Epoch 204, Training Loss: 1.3034, Validation Loss: 1.2313
# Epoch 205, Training Loss: 1.3023, Validation Loss: 1.2299
# Epoch 206, Training Loss: 1.3011, Validation Loss: 1.2286
# Epoch 207, Training Loss: 1.3000, Validation Loss: 1.2272
# Epoch 208, Training Loss: 1.2989, Validation Loss: 1.2259
# Epoch 209, Training Loss: 1.2978, Validation Loss: 1.2246
# Epoch 210, Training Loss: 1.2967, Validation Loss: 1.2233
# Epoch 211, Training Loss: 1.2957, Validation Loss: 1.2220
# Epoch 212, Training Loss: 1.2946, Validation Loss: 1.2207
# Epoch 213, Training Loss: 1.2936, Validation Loss: 1.2195
# Epoch 214, Training Loss: 1.2925, Validation Loss: 1.2182
# Epoch 215, Training Loss: 1.2915, Validation Loss: 1.2170
# Epoch 216, Training Loss: 1.2905, Validation Loss: 1.2158
# Epoch 217, Training Loss: 1.2895, Validation Loss: 1.2146
# Epoch 218, Training Loss: 1.2885, Validation Loss: 1.2134
# Epoch 219, Training Loss: 1.2876, Validation Loss: 1.2122
# Epoch 220, Training Loss: 1.2866, Validation Loss: 1.2110
# Epoch 221, Training Loss: 1.2857, Validation Loss: 1.2099
# Epoch 222, Training Loss: 1.2847, Validation Loss: 1.2087
# Epoch 223, Training Loss: 1.2838, Validation Loss: 1.2076
# Epoch 224, Training Loss: 1.2829, Validation Loss: 1.2065
# Epoch 225, Training Loss: 1.2820, Validation Loss: 1.2054
# Epoch 226, Training Loss: 1.2811, Validation Loss: 1.2043
# Epoch 227, Training Loss: 1.2802, Validation Loss: 1.2032
# Epoch 228, Training Loss: 1.2794, Validation Loss: 1.2021
# Epoch 229, Training Loss: 1.2785, Validation Loss: 1.2011
# Epoch 230, Training Loss: 1.2777, Validation Loss: 1.2000
# Epoch 231, Training Loss: 1.2769, Validation Loss: 1.1990
# Epoch 232, Training Loss: 1.2760, Validation Loss: 1.1980
# Epoch 233, Training Loss: 1.2752, Validation Loss: 1.1970
# Epoch 234, Training Loss: 1.2744, Validation Loss: 1.1960
# Epoch 235, Training Loss: 1.2736, Validation Loss: 1.1950
# Epoch 236, Training Loss: 1.2729, Validation Loss: 1.1940
# Epoch 237, Training Loss: 1.2721, Validation Loss: 1.1931
# Epoch 238, Training Loss: 1.2713, Validation Loss: 1.1921
# Epoch 239, Training Loss: 1.2706, Validation Loss: 1.1912
# Epoch 240, Training Loss: 1.2698, Validation Loss: 1.1903
# Epoch 241, Training Loss: 1.2691, Validation Loss: 1.1893
# Epoch 242, Training Loss: 1.2684, Validation Loss: 1.1884
# Epoch 243, Training Loss: 1.2677, Validation Loss: 1.1875
# Epoch 244, Training Loss: 1.2670, Validation Loss: 1.1866
# Epoch 245, Training Loss: 1.2663, Validation Loss: 1.1858
# Epoch 246, Training Loss: 1.2656, Validation Loss: 1.1849
# Epoch 247, Training Loss: 1.2649, Validation Loss: 1.1840
# Epoch 248, Training Loss: 1.2643, Validation Loss: 1.1832
# Epoch 249, Training Loss: 1.2636, Validation Loss: 1.1824
# Epoch 250, Training Loss: 1.2630, Validation Loss: 1.1815
# Epoch 251, Training Loss: 1.2623, Validation Loss: 1.1807
# Epoch 252, Training Loss: 1.2617, Validation Loss: 1.1799
# Epoch 253, Training Loss: 1.2611, Validation Loss: 1.1791
# Epoch 254, Training Loss: 1.2605, Validation Loss: 1.1783
# Epoch 255, Training Loss: 1.2598, Validation Loss: 1.1775
# Epoch 256, Training Loss: 1.2593, Validation Loss: 1.1768
# Epoch 257, Training Loss: 1.2587, Validation Loss: 1.1760
# Epoch 258, Training Loss: 1.2581, Validation Loss: 1.1753
# Epoch 259, Training Loss: 1.2575, Validation Loss: 1.1745
# Epoch 260, Training Loss: 1.2569, Validation Loss: 1.1738
# Epoch 261, Training Loss: 1.2564, Validation Loss: 1.1731
# Epoch 262, Training Loss: 1.2558, Validation Loss: 1.1723
# Epoch 263, Training Loss: 1.2553, Validation Loss: 1.1716
# Epoch 264, Training Loss: 1.2548, Validation Loss: 1.1709
# Epoch 265, Training Loss: 1.2542, Validation Loss: 1.1702
# Epoch 266, Training Loss: 1.2537, Validation Loss: 1.1696
# Epoch 267, Training Loss: 1.2532, Validation Loss: 1.1689
# Epoch 268, Training Loss: 1.2527, Validation Loss: 1.1682
# Epoch 269, Training Loss: 1.2522, Validation Loss: 1.1676
# Epoch 270, Training Loss: 1.2517, Validation Loss: 1.1669
# Epoch 271, Training Loss: 1.2512, Validation Loss: 1.1663
# Epoch 272, Training Loss: 1.2507, Validation Loss: 1.1656
# Epoch 273, Training Loss: 1.2503, Validation Loss: 1.1650
# Epoch 274, Training Loss: 1.2498, Validation Loss: 1.1644
# Epoch 275, Training Loss: 1.2494, Validation Loss: 1.1638
# Epoch 276, Training Loss: 1.2489, Validation Loss: 1.1632
# Epoch 277, Training Loss: 1.2485, Validation Loss: 1.1626
# Epoch 278, Training Loss: 1.2480, Validation Loss: 1.1620
# Epoch 279, Training Loss: 1.2476, Validation Loss: 1.1614
# Epoch 280, Training Loss: 1.2472, Validation Loss: 1.1608
# Epoch 281, Training Loss: 1.2467, Validation Loss: 1.1602
# Epoch 282, Training Loss: 1.2463, Validation Loss: 1.1597
# Epoch 283, Training Loss: 1.2459, Validation Loss: 1.1591
# Epoch 284, Training Loss: 1.2455, Validation Loss: 1.1586
# Epoch 285, Training Loss: 1.2451, Validation Loss: 1.1580
# Epoch 286, Training Loss: 1.2447, Validation Loss: 1.1575
# Epoch 287, Training Loss: 1.2443, Validation Loss: 1.1569
# Epoch 288, Training Loss: 1.2440, Validation Loss: 1.1564
# Epoch 289, Training Loss: 1.2436, Validation Loss: 1.1559
# Epoch 290, Training Loss: 1.2432, Validation Loss: 1.1554
# Epoch 291, Training Loss: 1.2429, Validation Loss: 1.1549
# Epoch 292, Training Loss: 1.2425, Validation Loss: 1.1544
# Epoch 293, Training Loss: 1.2421, Validation Loss: 1.1539
# Epoch 294, Training Loss: 1.2418, Validation Loss: 1.1534
# Epoch 295, Training Loss: 1.2415, Validation Loss: 1.1529
# Epoch 296, Training Loss: 1.2411, Validation Loss: 1.1525
# Epoch 297, Training Loss: 1.2408, Validation Loss: 1.1520
# Epoch 298, Training Loss: 1.2405, Validation Loss: 1.1515
# Epoch 299, Training Loss: 1.2401, Validation Loss: 1.1511
# Epoch 300, Training Loss: 1.2398, Validation Loss: 1.1506
# Epoch 301, Training Loss: 1.2395, Validation Loss: 1.1502
# Epoch 302, Training Loss: 1.2392, Validation Loss: 1.1497
# Epoch 303, Training Loss: 1.2389, Validation Loss: 1.1493
# Epoch 304, Training Loss: 1.2386, Validation Loss: 1.1489
# Epoch 305, Training Loss: 1.2383, Validation Loss: 1.1484
# Epoch 306, Training Loss: 1.2380, Validation Loss: 1.1480
# Epoch 307, Training Loss: 1.2377, Validation Loss: 1.1476
# Epoch 308, Training Loss: 1.2374, Validation Loss: 1.1472
# Epoch 309, Training Loss: 1.2372, Validation Loss: 1.1468
# Epoch 310, Training Loss: 1.2369, Validation Loss: 1.1464
# Epoch 311, Training Loss: 1.2366, Validation Loss: 1.1460
# Epoch 312, Training Loss: 1.2364, Validation Loss: 1.1456
# Epoch 313, Training Loss: 1.2361, Validation Loss: 1.1452
# Epoch 314, Training Loss: 1.2358, Validation Loss: 1.1448
# Epoch 315, Training Loss: 1.2356, Validation Loss: 1.1445
# Epoch 316, Training Loss: 1.2353, Validation Loss: 1.1441
# Epoch 317, Training Loss: 1.2351, Validation Loss: 1.1437
# Epoch 318, Training Loss: 1.2348, Validation Loss: 1.1434
# Epoch 319, Training Loss: 1.2346, Validation Loss: 1.1430
# Epoch 320, Training Loss: 1.2344, Validation Loss: 1.1427
# Epoch 321, Training Loss: 1.2341, Validation Loss: 1.1423
# Epoch 322, Training Loss: 1.2339, Validation Loss: 1.1420
# Epoch 323, Training Loss: 1.2337, Validation Loss: 1.1416
# Epoch 324, Training Loss: 1.2335, Validation Loss: 1.1413
# Epoch 325, Training Loss: 1.2332, Validation Loss: 1.1410
# Epoch 326, Training Loss: 1.2330, Validation Loss: 1.1406
# Epoch 327, Training Loss: 1.2328, Validation Loss: 1.1403
# Epoch 328, Training Loss: 1.2326, Validation Loss: 1.1400
# Epoch 329, Training Loss: 1.2324, Validation Loss: 1.1397
# Epoch 330, Training Loss: 1.2322, Validation Loss: 1.1394
# Epoch 331, Training Loss: 1.2320, Validation Loss: 1.1391
# Epoch 332, Training Loss: 1.2318, Validation Loss: 1.1388
# Epoch 333, Training Loss: 1.2316, Validation Loss: 1.1385
# Epoch 334, Training Loss: 1.2314, Validation Loss: 1.1382
# Epoch 335, Training Loss: 1.2312, Validation Loss: 1.1379
# Epoch 336, Training Loss: 1.2311, Validation Loss: 1.1376
# Epoch 337, Training Loss: 1.2309, Validation Loss: 1.1373
# Epoch 338, Training Loss: 1.2307, Validation Loss: 1.1370
# Epoch 339, Training Loss: 1.2305, Validation Loss: 1.1367
# Epoch 340, Training Loss: 1.2304, Validation Loss: 1.1365
# Epoch 341, Training Loss: 1.2302, Validation Loss: 1.1362
# Epoch 342, Training Loss: 1.2300, Validation Loss: 1.1359
# Epoch 343, Training Loss: 1.2299, Validation Loss: 1.1357
# Epoch 344, Training Loss: 1.2297, Validation Loss: 1.1354
# Epoch 345, Training Loss: 1.2295, Validation Loss: 1.1351
# Epoch 346, Training Loss: 1.2294, Validation Loss: 1.1349
# Epoch 347, Training Loss: 1.2292, Validation Loss: 1.1346
# Epoch 348, Training Loss: 1.2291, Validation Loss: 1.1344
# Epoch 349, Training Loss: 1.2289, Validation Loss: 1.1341
# Epoch 350, Training Loss: 1.2288, Validation Loss: 1.1339
# Epoch 351, Training Loss: 1.2286, Validation Loss: 1.1337
# Epoch 352, Training Loss: 1.2285, Validation Loss: 1.1334
# Epoch 353, Training Loss: 1.2284, Validation Loss: 1.1332
# Epoch 354, Training Loss: 1.2282, Validation Loss: 1.1330
# Epoch 355, Training Loss: 1.2281, Validation Loss: 1.1327
# Epoch 356, Training Loss: 1.2280, Validation Loss: 1.1325
# Epoch 357, Training Loss: 1.2278, Validation Loss: 1.1323
# Epoch 358, Training Loss: 1.2277, Validation Loss: 1.1321
# Epoch 359, Training Loss: 1.2276, Validation Loss: 1.1318
# Epoch 360, Training Loss: 1.2274, Validation Loss: 1.1316
# Epoch 361, Training Loss: 1.2273, Validation Loss: 1.1314
# Epoch 362, Training Loss: 1.2272, Validation Loss: 1.1312
# Epoch 363, Training Loss: 1.2271, Validation Loss: 1.1310
# Epoch 364, Training Loss: 1.2270, Validation Loss: 1.1308
# Epoch 365, Training Loss: 1.2269, Validation Loss: 1.1306
# Epoch 366, Training Loss: 1.2267, Validation Loss: 1.1304
# Epoch 367, Training Loss: 1.2266, Validation Loss: 1.1302
# Epoch 368, Training Loss: 1.2265, Validation Loss: 1.1300
# Epoch 369, Training Loss: 1.2264, Validation Loss: 1.1298
# Epoch 370, Training Loss: 1.2263, Validation Loss: 1.1296
# Epoch 371, Training Loss: 1.2262, Validation Loss: 1.1294
# Epoch 372, Training Loss: 1.2261, Validation Loss: 1.1293
# Epoch 373, Training Loss: 1.2260, Validation Loss: 1.1291
# Epoch 374, Training Loss: 1.2259, Validation Loss: 1.1289
# Epoch 375, Training Loss: 1.2258, Validation Loss: 1.1287
# Epoch 376, Training Loss: 1.2257, Validation Loss: 1.1286
# Epoch 377, Training Loss: 1.2256, Validation Loss: 1.1284
# Epoch 378, Training Loss: 1.2255, Validation Loss: 1.1282
# Epoch 379, Training Loss: 1.2254, Validation Loss: 1.1280
# Epoch 380, Training Loss: 1.2253, Validation Loss: 1.1279
# Epoch 381, Training Loss: 1.2253, Validation Loss: 1.1277
# Epoch 382, Training Loss: 1.2252, Validation Loss: 1.1275
# Epoch 383, Training Loss: 1.2251, Validation Loss: 1.1274
# Epoch 384, Training Loss: 1.2250, Validation Loss: 1.1272
# Epoch 385, Training Loss: 1.2249, Validation Loss: 1.1271
# Epoch 386, Training Loss: 1.2248, Validation Loss: 1.1269
# Epoch 387, Training Loss: 1.2248, Validation Loss: 1.1268
# Epoch 388, Training Loss: 1.2247, Validation Loss: 1.1266
# Epoch 389, Training Loss: 1.2246, Validation Loss: 1.1265
# Epoch 390, Training Loss: 1.2245, Validation Loss: 1.1263
# Epoch 391, Training Loss: 1.2245, Validation Loss: 1.1262
# Epoch 392, Training Loss: 1.2244, Validation Loss: 1.1260
# Epoch 393, Training Loss: 1.2243, Validation Loss: 1.1259
# Epoch 394, Training Loss: 1.2242, Validation Loss: 1.1257
# Epoch 395, Training Loss: 1.2242, Validation Loss: 1.1256
# Epoch 396, Training Loss: 1.2241, Validation Loss: 1.1255
# Epoch 397, Training Loss: 1.2240, Validation Loss: 1.1253
# Epoch 398, Training Loss: 1.2240, Validation Loss: 1.1252
# Epoch 399, Training Loss: 1.2239, Validation Loss: 1.1251
# Epoch 400, Training Loss: 1.2238, Validation Loss: 1.1249
# Epoch 401, Training Loss: 1.2238, Validation Loss: 1.1248
# Epoch 402, Training Loss: 1.2237, Validation Loss: 1.1247
# Epoch 403, Training Loss: 1.2237, Validation Loss: 1.1246
# Epoch 404, Training Loss: 1.2236, Validation Loss: 1.1244
# Epoch 405, Training Loss: 1.2235, Validation Loss: 1.1243
# Epoch 406, Training Loss: 1.2235, Validation Loss: 1.1242
# Epoch 407, Training Loss: 1.2234, Validation Loss: 1.1241
# Epoch 408, Training Loss: 1.2234, Validation Loss: 1.1240
# Epoch 409, Training Loss: 1.2233, Validation Loss: 1.1238
# Epoch 410, Training Loss: 1.2233, Validation Loss: 1.1237
# Epoch 411, Training Loss: 1.2232, Validation Loss: 1.1236
# Epoch 412, Training Loss: 1.2232, Validation Loss: 1.1235
# Epoch 413, Training Loss: 1.2231, Validation Loss: 1.1234
# Epoch 414, Training Loss: 1.2231, Validation Loss: 1.1233
# Epoch 415, Training Loss: 1.2230, Validation Loss: 1.1232
# Epoch 416, Training Loss: 1.2230, Validation Loss: 1.1231
# Epoch 417, Training Loss: 1.2229, Validation Loss: 1.1230
# Epoch 418, Training Loss: 1.2229, Validation Loss: 1.1229
# Epoch 419, Training Loss: 1.2228, Validation Loss: 1.1228
# Epoch 420, Training Loss: 1.2228, Validation Loss: 1.1227
# Epoch 421, Training Loss: 1.2227, Validation Loss: 1.1226
# Epoch 422, Training Loss: 1.2227, Validation Loss: 1.1225
# Epoch 423, Training Loss: 1.2227, Validation Loss: 1.1224
# Epoch 424, Training Loss: 1.2226, Validation Loss: 1.1223
# Epoch 425, Training Loss: 1.2226, Validation Loss: 1.1222
# Epoch 426, Training Loss: 1.2225, Validation Loss: 1.1221
# Epoch 427, Training Loss: 1.2225, Validation Loss: 1.1220
# Epoch 428, Training Loss: 1.2225, Validation Loss: 1.1219
# Epoch 429, Training Loss: 1.2224, Validation Loss: 1.1218
# Epoch 430, Training Loss: 1.2224, Validation Loss: 1.1217
# Epoch 431, Training Loss: 1.2223, Validation Loss: 1.1216
# Epoch 432, Training Loss: 1.2223, Validation Loss: 1.1215
# Epoch 433, Training Loss: 1.2223, Validation Loss: 1.1215
# Epoch 434, Training Loss: 1.2222, Validation Loss: 1.1214
# Epoch 435, Training Loss: 1.2222, Validation Loss: 1.1213
# Epoch 436, Training Loss: 1.2222, Validation Loss: 1.1212
# Epoch 437, Training Loss: 1.2221, Validation Loss: 1.1211
# Epoch 438, Training Loss: 1.2221, Validation Loss: 1.1210
# Epoch 439, Training Loss: 1.2221, Validation Loss: 1.1210
# Epoch 440, Training Loss: 1.2220, Validation Loss: 1.1209
# Epoch 441, Training Loss: 1.2220, Validation Loss: 1.1208
# Epoch 442, Training Loss: 1.2220, Validation Loss: 1.1207
# Epoch 443, Training Loss: 1.2219, Validation Loss: 1.1207
# Epoch 444, Training Loss: 1.2219, Validation Loss: 1.1206
# Epoch 445, Training Loss: 1.2219, Validation Loss: 1.1205
# Epoch 446, Training Loss: 1.2219, Validation Loss: 1.1204
# Epoch 447, Training Loss: 1.2218, Validation Loss: 1.1204
# Epoch 448, Training Loss: 1.2218, Validation Loss: 1.1203
# Epoch 449, Training Loss: 1.2218, Validation Loss: 1.1202
# Epoch 450, Training Loss: 1.2218, Validation Loss: 1.1201
# Epoch 451, Training Loss: 1.2217, Validation Loss: 1.1201
# Epoch 452, Training Loss: 1.2217, Validation Loss: 1.1200
# Epoch 453, Training Loss: 1.2217, Validation Loss: 1.1199
# Epoch 454, Training Loss: 1.2217, Validation Loss: 1.1199
# Epoch 455, Training Loss: 1.2216, Validation Loss: 1.1198
# Epoch 456, Training Loss: 1.2216, Validation Loss: 1.1197
# Epoch 457, Training Loss: 1.2216, Validation Loss: 1.1197
# Epoch 458, Training Loss: 1.2216, Validation Loss: 1.1196
# Epoch 459, Training Loss: 1.2215, Validation Loss: 1.1195
# Epoch 460, Training Loss: 1.2215, Validation Loss: 1.1195
# Epoch 461, Training Loss: 1.2215, Validation Loss: 1.1194
# Epoch 462, Training Loss: 1.2215, Validation Loss: 1.1194
# Epoch 463, Training Loss: 1.2215, Validation Loss: 1.1193
# Epoch 464, Training Loss: 1.2214, Validation Loss: 1.1192
# Epoch 465, Training Loss: 1.2214, Validation Loss: 1.1192
# Epoch 466, Training Loss: 1.2214, Validation Loss: 1.1191
# Epoch 467, Training Loss: 1.2214, Validation Loss: 1.1191
# Epoch 468, Training Loss: 1.2214, Validation Loss: 1.1190
# Epoch 469, Training Loss: 1.2213, Validation Loss: 1.1190
# Epoch 470, Training Loss: 1.2213, Validation Loss: 1.1189
# Epoch 471, Training Loss: 1.2213, Validation Loss: 1.1189
# Epoch 472, Training Loss: 1.2213, Validation Loss: 1.1188
# Epoch 473, Training Loss: 1.2213, Validation Loss: 1.1187
# Epoch 474, Training Loss: 1.2213, Validation Loss: 1.1187
# Epoch 475, Training Loss: 1.2212, Validation Loss: 1.1186
# Epoch 476, Training Loss: 1.2212, Validation Loss: 1.1186
# Epoch 477, Training Loss: 1.2212, Validation Loss: 1.1185
# Epoch 478, Training Loss: 1.2212, Validation Loss: 1.1185
# Epoch 479, Training Loss: 1.2212, Validation Loss: 1.1184
# Epoch 480, Training Loss: 1.2212, Validation Loss: 1.1184
# Epoch 481, Training Loss: 1.2212, Validation Loss: 1.1183
# Epoch 482, Training Loss: 1.2211, Validation Loss: 1.1183
# Epoch 483, Training Loss: 1.2211, Validation Loss: 1.1183
# Epoch 484, Training Loss: 1.2211, Validation Loss: 1.1182
# Epoch 485, Training Loss: 1.2211, Validation Loss: 1.1182
# Epoch 486, Training Loss: 1.2211, Validation Loss: 1.1181
# Epoch 487, Training Loss: 1.2211, Validation Loss: 1.1181
# Epoch 488, Training Loss: 1.2211, Validation Loss: 1.1180
# Epoch 489, Training Loss: 1.2210, Validation Loss: 1.1180
# Epoch 490, Training Loss: 1.2210, Validation Loss: 1.1179
# Epoch 491, Training Loss: 1.2210, Validation Loss: 1.1179
# Epoch 492, Training Loss: 1.2210, Validation Loss: 1.1179
# Epoch 493, Training Loss: 1.2210, Validation Loss: 1.1178
# Epoch 494, Training Loss: 1.2210, Validation Loss: 1.1178
# Epoch 495, Training Loss: 1.2210, Validation Loss: 1.1177
# Epoch 496, Training Loss: 1.2210, Validation Loss: 1.1177
# Epoch 497, Training Loss: 1.2210, Validation Loss: 1.1177
# Epoch 498, Training Loss: 1.2209, Validation Loss: 1.1176
# Epoch 499, Training Loss: 1.2209, Validation Loss: 1.1176
# Epoch 500, Training Loss: 1.2209, Validation Loss: 1.1175
# Epoch 501, Training Loss: 1.2209, Validation Loss: 1.1175
# Epoch 502, Training Loss: 1.2209, Validation Loss: 1.1175
# Epoch 503, Training Loss: 1.2209, Validation Loss: 1.1174
# Epoch 504, Training Loss: 1.2209, Validation Loss: 1.1174
# Epoch 505, Training Loss: 1.2209, Validation Loss: 1.1174
# Epoch 506, Training Loss: 1.2209, Validation Loss: 1.1173
# Epoch 507, Training Loss: 1.2209, Validation Loss: 1.1173
# Epoch 508, Training Loss: 1.2209, Validation Loss: 1.1172
# Epoch 509, Training Loss: 1.2208, Validation Loss: 1.1172
# Epoch 510, Training Loss: 1.2208, Validation Loss: 1.1172
# Epoch 511, Training Loss: 1.2208, Validation Loss: 1.1171
# Epoch 512, Training Loss: 1.2208, Validation Loss: 1.1171
# Epoch 513, Training Loss: 1.2208, Validation Loss: 1.1171
# Epoch 514, Training Loss: 1.2208, Validation Loss: 1.1170
# Epoch 515, Training Loss: 1.2208, Validation Loss: 1.1170
# Epoch 516, Training Loss: 1.2208, Validation Loss: 1.1170
# Epoch 517, Training Loss: 1.2208, Validation Loss: 1.1170
# Epoch 518, Training Loss: 1.2208, Validation Loss: 1.1169
# Epoch 519, Training Loss: 1.2208, Validation Loss: 1.1169
# Epoch 520, Training Loss: 1.2208, Validation Loss: 1.1169
# Epoch 521, Training Loss: 1.2208, Validation Loss: 1.1168
# Epoch 522, Training Loss: 1.2208, Validation Loss: 1.1168
# Epoch 523, Training Loss: 1.2207, Validation Loss: 1.1168
# Epoch 524, Training Loss: 1.2207, Validation Loss: 1.1167
# Epoch 525, Training Loss: 1.2207, Validation Loss: 1.1167
# Epoch 526, Training Loss: 1.2207, Validation Loss: 1.1167
# Epoch 527, Training Loss: 1.2207, Validation Loss: 1.1167
# Epoch 528, Training Loss: 1.2207, Validation Loss: 1.1166
# Epoch 529, Training Loss: 1.2207, Validation Loss: 1.1166
# Epoch 530, Training Loss: 1.2207, Validation Loss: 1.1166
# Epoch 531, Training Loss: 1.2207, Validation Loss: 1.1166
# Epoch 532, Training Loss: 1.2207, Validation Loss: 1.1165
# Epoch 533, Training Loss: 1.2207, Validation Loss: 1.1165
# Epoch 534, Training Loss: 1.2207, Validation Loss: 1.1165
# Epoch 535, Training Loss: 1.2207, Validation Loss: 1.1164
# Epoch 536, Training Loss: 1.2207, Validation Loss: 1.1164
# Epoch 537, Training Loss: 1.2207, Validation Loss: 1.1164
# Epoch 538, Training Loss: 1.2207, Validation Loss: 1.1164
# Epoch 539, Training Loss: 1.2207, Validation Loss: 1.1164
# Epoch 540, Training Loss: 1.2207, Validation Loss: 1.1163
# Epoch 541, Training Loss: 1.2207, Validation Loss: 1.1163
# Epoch 542, Training Loss: 1.2206, Validation Loss: 1.1163
# Epoch 543, Training Loss: 1.2206, Validation Loss: 1.1163
# Epoch 544, Training Loss: 1.2206, Validation Loss: 1.1162
# Epoch 545, Training Loss: 1.2206, Validation Loss: 1.1162
# Epoch 546, Training Loss: 1.2206, Validation Loss: 1.1162
# Epoch 547, Training Loss: 1.2206, Validation Loss: 1.1162
# Epoch 548, Training Loss: 1.2206, Validation Loss: 1.1161
# Epoch 549, Training Loss: 1.2206, Validation Loss: 1.1161
# Epoch 550, Training Loss: 1.2206, Validation Loss: 1.1161
# Epoch 551, Training Loss: 1.2206, Validation Loss: 1.1161
# Epoch 552, Training Loss: 1.2206, Validation Loss: 1.1161
# Epoch 553, Training Loss: 1.2206, Validation Loss: 1.1160
# Epoch 554, Training Loss: 1.2206, Validation Loss: 1.1160
# Epoch 555, Training Loss: 1.2206, Validation Loss: 1.1160
# Epoch 556, Training Loss: 1.2206, Validation Loss: 1.1160
# Epoch 557, Training Loss: 1.2206, Validation Loss: 1.1160
# Epoch 558, Training Loss: 1.2206, Validation Loss: 1.1159
# Epoch 559, Training Loss: 1.2206, Validation Loss: 1.1159
# Epoch 560, Training Loss: 1.2206, Validation Loss: 1.1159
# Epoch 561, Training Loss: 1.2206, Validation Loss: 1.1159
# Epoch 562, Training Loss: 1.2206, Validation Loss: 1.1159
# Epoch 563, Training Loss: 1.2206, Validation Loss: 1.1159
# Epoch 564, Training Loss: 1.2206, Validation Loss: 1.1158
# Epoch 565, Training Loss: 1.2206, Validation Loss: 1.1158
# Epoch 566, Training Loss: 1.2206, Validation Loss: 1.1158
# Epoch 567, Training Loss: 1.2206, Validation Loss: 1.1158
# Epoch 568, Training Loss: 1.2206, Validation Loss: 1.1158
# Epoch 569, Training Loss: 1.2206, Validation Loss: 1.1157
# Epoch 570, Training Loss: 1.2206, Validation Loss: 1.1157
# Epoch 571, Training Loss: 1.2206, Validation Loss: 1.1157
# Epoch 572, Training Loss: 1.2206, Validation Loss: 1.1157
# Epoch 573, Training Loss: 1.2205, Validation Loss: 1.1157
# Epoch 574, Training Loss: 1.2205, Validation Loss: 1.1157
# Epoch 575, Training Loss: 1.2205, Validation Loss: 1.1157
# Epoch 576, Training Loss: 1.2205, Validation Loss: 1.1156
# Epoch 577, Training Loss: 1.2205, Validation Loss: 1.1156
# Epoch 578, Training Loss: 1.2205, Validation Loss: 1.1156
# Epoch 579, Training Loss: 1.2205, Validation Loss: 1.1156
# Epoch 580, Training Loss: 1.2205, Validation Loss: 1.1156
# Epoch 581, Training Loss: 1.2205, Validation Loss: 1.1156
# Epoch 582, Training Loss: 1.2205, Validation Loss: 1.1155
# Epoch 583, Training Loss: 1.2205, Validation Loss: 1.1155
# Epoch 584, Training Loss: 1.2205, Validation Loss: 1.1155
# Epoch 585, Training Loss: 1.2205, Validation Loss: 1.1155
# Epoch 586, Training Loss: 1.2205, Validation Loss: 1.1155
# Epoch 587, Training Loss: 1.2205, Validation Loss: 1.1155
# Epoch 588, Training Loss: 1.2205, Validation Loss: 1.1155
# Epoch 589, Training Loss: 1.2205, Validation Loss: 1.1155
# Epoch 590, Training Loss: 1.2205, Validation Loss: 1.1154
# Epoch 591, Training Loss: 1.2205, Validation Loss: 1.1154
# Epoch 592, Training Loss: 1.2205, Validation Loss: 1.1154
# Epoch 593, Training Loss: 1.2205, Validation Loss: 1.1154
# Epoch 594, Training Loss: 1.2205, Validation Loss: 1.1154
# Epoch 595, Training Loss: 1.2205, Validation Loss: 1.1154
# Epoch 596, Training Loss: 1.2205, Validation Loss: 1.1154
# Epoch 597, Training Loss: 1.2205, Validation Loss: 1.1154
# Epoch 598, Training Loss: 1.2205, Validation Loss: 1.1153
# Epoch 599, Training Loss: 1.2205, Validation Loss: 1.1153
# Epoch 600, Training Loss: 1.2205, Validation Loss: 1.1153
# Epoch 601, Training Loss: 1.2205, Validation Loss: 1.1153
# Epoch 602, Training Loss: 1.2205, Validation Loss: 1.1153
# Epoch 603, Training Loss: 1.2205, Validation Loss: 1.1153
# Epoch 604, Training Loss: 1.2205, Validation Loss: 1.1153
# Epoch 605, Training Loss: 1.2205, Validation Loss: 1.1153
# Epoch 606, Training Loss: 1.2205, Validation Loss: 1.1152
# Epoch 607, Training Loss: 1.2205, Validation Loss: 1.1152
# Epoch 608, Training Loss: 1.2205, Validation Loss: 1.1152
# Epoch 609, Training Loss: 1.2205, Validation Loss: 1.1152
# Epoch 610, Training Loss: 1.2205, Validation Loss: 1.1152
# Epoch 611, Training Loss: 1.2205, Validation Loss: 1.1152
# Epoch 612, Training Loss: 1.2205, Validation Loss: 1.1152
# Epoch 613, Training Loss: 1.2205, Validation Loss: 1.1152
# Epoch 614, Training Loss: 1.2205, Validation Loss: 1.1152
# Epoch 615, Training Loss: 1.2205, Validation Loss: 1.1152
# Epoch 616, Training Loss: 1.2205, Validation Loss: 1.1151
# Epoch 617, Training Loss: 1.2205, Validation Loss: 1.1151
# Epoch 618, Training Loss: 1.2205, Validation Loss: 1.1151
# Epoch 619, Training Loss: 1.2205, Validation Loss: 1.1151
# Epoch 620, Training Loss: 1.2205, Validation Loss: 1.1151
# Epoch 621, Training Loss: 1.2205, Validation Loss: 1.1151
# Epoch 622, Training Loss: 1.2205, Validation Loss: 1.1151
# Epoch 623, Training Loss: 1.2205, Validation Loss: 1.1151
# Epoch 624, Training Loss: 1.2205, Validation Loss: 1.1151
# Epoch 625, Training Loss: 1.2205, Validation Loss: 1.1151
# Epoch 626, Training Loss: 1.2205, Validation Loss: 1.1151
# Epoch 627, Training Loss: 1.2205, Validation Loss: 1.1150
# Epoch 628, Training Loss: 1.2205, Validation Loss: 1.1150
# Epoch 629, Training Loss: 1.2205, Validation Loss: 1.1150
# Epoch 630, Training Loss: 1.2205, Validation Loss: 1.1150
# Epoch 631, Training Loss: 1.2205, Validation Loss: 1.1150
# Epoch 632, Training Loss: 1.2205, Validation Loss: 1.1150
# Epoch 633, Training Loss: 1.2205, Validation Loss: 1.1150
# Epoch 634, Training Loss: 1.2205, Validation Loss: 1.1150
# Epoch 635, Training Loss: 1.2205, Validation Loss: 1.1150
# Epoch 636, Training Loss: 1.2205, Validation Loss: 1.1150
# Epoch 637, Training Loss: 1.2205, Validation Loss: 1.1150
# Epoch 638, Training Loss: 1.2205, Validation Loss: 1.1150
# Epoch 639, Training Loss: 1.2205, Validation Loss: 1.1150
# Epoch 640, Training Loss: 1.2205, Validation Loss: 1.1149
# Epoch 641, Training Loss: 1.2205, Validation Loss: 1.1149
# Epoch 642, Training Loss: 1.2205, Validation Loss: 1.1149
# Epoch 643, Training Loss: 1.2205, Validation Loss: 1.1149
# Epoch 644, Training Loss: 1.2205, Validation Loss: 1.1149
# Epoch 645, Training Loss: 1.2205, Validation Loss: 1.1149
# Epoch 646, Training Loss: 1.2205, Validation Loss: 1.1149
# Epoch 647, Training Loss: 1.2205, Validation Loss: 1.1149
# Epoch 648, Training Loss: 1.2205, Validation Loss: 1.1149
# Epoch 649, Training Loss: 1.2205, Validation Loss: 1.1149
# Epoch 650, Training Loss: 1.2205, Validation Loss: 1.1149
# Epoch 651, Training Loss: 1.2205, Validation Loss: 1.1149
# Epoch 652, Training Loss: 1.2205, Validation Loss: 1.1149
# Epoch 653, Training Loss: 1.2205, Validation Loss: 1.1149
# Epoch 654, Training Loss: 1.2205, Validation Loss: 1.1149
# Epoch 655, Training Loss: 1.2205, Validation Loss: 1.1149
# Epoch 656, Training Loss: 1.2205, Validation Loss: 1.1148
# Epoch 657, Training Loss: 1.2205, Validation Loss: 1.1148
# Epoch 658, Training Loss: 1.2205, Validation Loss: 1.1148
# Epoch 659, Training Loss: 1.2205, Validation Loss: 1.1148
# Epoch 660, Training Loss: 1.2205, Validation Loss: 1.1148
# Epoch 661, Training Loss: 1.2205, Validation Loss: 1.1148
# Epoch 662, Training Loss: 1.2205, Validation Loss: 1.1148
# Epoch 663, Training Loss: 1.2205, Validation Loss: 1.1148
# Epoch 664, Training Loss: 1.2205, Validation Loss: 1.1148
# Epoch 665, Training Loss: 1.2205, Validation Loss: 1.1148
# Epoch 666, Training Loss: 1.2205, Validation Loss: 1.1148
# Epoch 667, Training Loss: 1.2205, Validation Loss: 1.1148
# Epoch 668, Training Loss: 1.2205, Validation Loss: 1.1148
# Epoch 669, Training Loss: 1.2205, Validation Loss: 1.1148
# Epoch 670, Training Loss: 1.2205, Validation Loss: 1.1148
# Epoch 671, Training Loss: 1.2205, Validation Loss: 1.1148
# Epoch 672, Training Loss: 1.2205, Validation Loss: 1.1148
# Epoch 673, Training Loss: 1.2205, Validation Loss: 1.1148
# Epoch 674, Training Loss: 1.2205, Validation Loss: 1.1148
# Epoch 675, Training Loss: 1.2205, Validation Loss: 1.1147
# Epoch 676, Training Loss: 1.2205, Validation Loss: 1.1147
# Epoch 677, Training Loss: 1.2205, Validation Loss: 1.1147
# Epoch 678, Training Loss: 1.2205, Validation Loss: 1.1147
# Epoch 679, Training Loss: 1.2205, Validation Loss: 1.1147
# Epoch 680, Training Loss: 1.2205, Validation Loss: 1.1147
# Epoch 681, Training Loss: 1.2205, Validation Loss: 1.1147
# Epoch 682, Training Loss: 1.2205, Validation Loss: 1.1147
# Epoch 683, Training Loss: 1.2205, Validation Loss: 1.1147
# Epoch 684, Training Loss: 1.2205, Validation Loss: 1.1147
# Epoch 685, Training Loss: 1.2205, Validation Loss: 1.1147
# Epoch 686, Training Loss: 1.2204, Validation Loss: 1.1147
# Epoch 687, Training Loss: 1.2204, Validation Loss: 1.1147
# Epoch 688, Training Loss: 1.2204, Validation Loss: 1.1147
# Epoch 689, Training Loss: 1.2204, Validation Loss: 1.1147
# Epoch 690, Training Loss: 1.2204, Validation Loss: 1.1147
# Epoch 691, Training Loss: 1.2204, Validation Loss: 1.1147
# Epoch 692, Training Loss: 1.2204, Validation Loss: 1.1147
# Epoch 693, Training Loss: 1.2204, Validation Loss: 1.1147
# Epoch 694, Training Loss: 1.2204, Validation Loss: 1.1147
# Epoch 695, Training Loss: 1.2204, Validation Loss: 1.1147
# Epoch 696, Training Loss: 1.2204, Validation Loss: 1.1147
# Epoch 697, Training Loss: 1.2204, Validation Loss: 1.1147
# Epoch 698, Training Loss: 1.2204, Validation Loss: 1.1147
# Epoch 699, Training Loss: 1.2204, Validation Loss: 1.1147
# Epoch 700, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 701, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 702, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 703, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 704, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 705, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 706, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 707, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 708, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 709, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 710, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 711, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 712, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 713, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 714, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 715, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 716, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 717, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 718, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 719, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 720, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 721, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 722, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 723, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 724, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 725, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 726, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 727, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 728, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 729, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 730, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 731, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 732, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 733, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 734, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 735, Training Loss: 1.2204, Validation Loss: 1.1146
# Epoch 736, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 737, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 738, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 739, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 740, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 741, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 742, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 743, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 744, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 745, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 746, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 747, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 748, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 749, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 750, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 751, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 752, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 753, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 754, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 755, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 756, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 757, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 758, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 759, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 760, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 761, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 762, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 763, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 764, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 765, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 766, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 767, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 768, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 769, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 770, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 771, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 772, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 773, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 774, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 775, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 776, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 777, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 778, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 779, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 780, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 781, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 782, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 783, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 784, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 785, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 786, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 787, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 788, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 789, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 790, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 791, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 792, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 793, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 794, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 795, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 796, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 797, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 798, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 799, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 800, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 801, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 802, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 803, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 804, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 805, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 806, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 807, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 808, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 809, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 810, Training Loss: 1.2204, Validation Loss: 1.1145
# Epoch 811, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 812, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 813, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 814, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 815, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 816, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 817, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 818, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 819, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 820, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 821, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 822, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 823, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 824, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 825, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 826, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 827, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 828, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 829, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 830, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 831, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 832, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 833, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 834, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 835, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 836, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 837, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 838, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 839, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 840, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 841, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 842, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 843, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 844, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 845, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 846, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 847, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 848, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 849, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 850, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 851, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 852, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 853, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 854, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 855, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 856, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 857, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 858, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 859, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 860, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 861, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 862, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 863, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 864, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 865, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 866, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 867, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 868, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 869, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 870, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 871, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 872, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 873, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 874, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 875, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 876, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 877, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 878, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 879, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 880, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 881, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 882, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 883, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 884, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 885, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 886, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 887, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 888, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 889, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 890, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 891, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 892, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 893, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 894, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 895, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 896, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 897, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 898, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 899, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 900, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 901, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 902, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 903, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 904, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 905, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 906, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 907, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 908, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 909, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 910, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 911, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 912, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 913, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 914, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 915, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 916, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 917, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 918, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 919, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 920, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 921, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 922, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 923, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 924, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 925, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 926, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 927, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 928, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 929, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 930, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 931, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 932, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 933, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 934, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 935, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 936, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 937, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 938, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 939, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 940, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 941, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 942, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 943, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 944, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 945, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 946, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 947, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 948, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 949, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 950, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 951, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 952, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 953, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 954, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 955, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 956, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 957, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 958, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 959, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 960, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 961, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 962, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 963, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 964, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 965, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 966, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 967, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 968, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 969, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 970, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 971, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 972, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 973, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 974, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 975, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 976, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 977, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 978, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 979, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 980, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 981, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 982, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 983, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 984, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 985, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 986, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 987, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 988, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 989, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 990, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 991, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 992, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 993, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 994, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 995, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 996, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 997, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 998, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 999, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1000, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1001, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1002, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1003, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1004, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1005, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1006, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1007, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1008, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1009, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1010, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1011, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1012, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1013, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1014, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1015, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1016, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1017, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1018, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1019, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1020, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1021, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1022, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1023, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1024, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1025, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1026, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1027, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1028, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1029, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1030, Training Loss: 1.2204, Validation Loss: 1.1144
# Epoch 1031, Training Loss: 1.2204, Validation Loss: 1.1144
# Early stopping triggered

# %%
# All-control and all-treated for test set
num_product = X_product.shape[0]

# All control: product_randomization = 0
all_product_control = torch.zeros(num_product, device=device).bool()

# All treated: product_randomization = 1
all_product_treated = torch.ones(num_product, device=device).bool()

# Move base price and test users/products to device
X_user_test = X_user_test.to(device)
X_product = X_product.to(device)
price = price.to(device)

# --------- Expected revenue: all control ----------
# Control prices = base prices (no discount)
price_control = price.clone()

# Prepare test data under all-control prices
user_test_ctrl, product_test_ctrl, prices_ctrl, x_other_products_ctrl, other_prices_ctrl = prepare_data(
    X_user_test,
    X_product,
    price_control
)

utilities_ctrl = pdlmodel(
    user_test_ctrl,
    product_test_ctrl,
    x_other_products_ctrl,
    other_prices_ctrl,
    prices_ctrl,          # control prices
    all_product_control   # all False
)

probabilities_ctrl = F.softmax(utilities_ctrl, dim=1)

price_with_outside_ctrl = torch.cat(
    (torch.zeros(1, device=price.device), prices_ctrl), dim=0
)  # [M+1]

expected_revenue_ctrl = torch.sum(
    probabilities_ctrl * price_with_outside_ctrl.unsqueeze(0).expand_as(probabilities_ctrl),
    dim=1
).sum()

print(f"Expected Revenue (all control): ${expected_revenue_ctrl.item():.2f}")

# --------- Expected revenue: all treated ----------
# Treated prices = discounted prices
price_treated = price * discount_percentage

user_test_trt, product_test_trt, prices_trt, x_other_products_trt, other_prices_trt = prepare_data(
    X_user_test,
    X_product,
    price_treated
)

utilities_trt = pdlmodel(
    user_test_trt,
    product_test_trt,
    x_other_products_trt,
    other_prices_trt,
    prices_trt,          # treated prices
    all_product_treated  # all True
)

probabilities_trt = F.softmax(utilities_trt, dim=1)

price_with_outside_trt = torch.cat(
    (torch.zeros(1, device=price.device), prices_trt), dim=0
)

expected_revenue_trt = torch.sum(
    probabilities_trt * price_with_outside_trt.unsqueeze(0).expand_as(probabilities_trt),
    dim=1
).sum()

print(f"Expected Revenue (all treated): ${expected_revenue_trt.item():.2f}")

# --------- GTE ----------
pdl = (expected_revenue_trt - expected_revenue_ctrl).cpu().detach().numpy() * 600 / 266
print(pdl)

pdl_user = abs((pdl - true) / true)
print(pdl_user)
# Out:
# Expected Revenue (all control): $41.23
# Expected Revenue (all treated): $8.25
# -74.40124167535538
# 0.08369452696274797

# %% [markdown]
# ### Only product features

# %%
class DeepMNLModel_ProductOnly(nn.Module):
    """
    Deep MNL (product-only):
    u_ij = theta(z_j, z_-j, p_j)
    Outside option utility = 0.
    """
    def __init__(self, product_dim, num_product, hidden=5):
        super(DeepMNLModel_ProductOnly, self).__init__()

        # Aggregate other products' features z_-j:
        # Input:  [M, (M-1)*F_p]
        # Output: [M, hidden]
        self.other_product_features_layers = nn.Sequential(
            nn.Linear(product_dim * (num_product - 1), hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU()
        )

        # theta(z_j, z_-j, p_j)
        # Input per (i,j): [F_p + hidden (z_-j) + 1 (p_j)]
        in_dim = product_dim + hidden + 1

        self.theta = nn.Sequential(
            nn.Linear(in_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, x_user, X_product, X_other_products,
                x_other_prices, price, prod_randomization):
        """
        X_product:        [M, F_p]          product features z_j
        X_other_products: [M, (M-1)*F_p]    other products' features z_-j
        price:            [M]               own price p_j (already discounted)

        这里不再使用:
        - x_user, x_other_prices, prod_randomization
        """
        device = price.device
        # N users, M products
        N, M = x_user.shape[0], X_product.shape[0]

        # z_-j features: [M, hidden]
        zminus_feat = self.other_product_features_layers(X_other_products)

        # p_j scalar: [M, 1]
        pj_feat = price.unsqueeze(1)

        # Combine product-side info: [M, F_p + hidden + 1]
        product_feat = torch.cat(
            [X_product, zminus_feat, pj_feat],
            dim=1
        )

        # Expand to all users: [N, M, in_dim]
        product_feat_exp = product_feat.unsqueeze(0).expand(N, -1, -1)

        # Flatten to [N*M, in_dim]
        theta_input_flat = product_feat_exp.reshape(N * M, -1)

        # Utilities: [N*M, 1] -> [N, M]
        utilities = self.theta(theta_input_flat).view(N, M)

        # Outside option = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utilities], dim=1)

        return utilities_with_outside

# %%
# Apply the model
pdlmodel = DeepMNLModel_ProductOnly(
    product_dim=X_product.shape[1],
    num_product=X_product.shape[0],
    hidden=5
).to(device)

# Weight initialization
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)

pdlmodel.apply(init_weights)
# Out:
# DeepMNLModel_ProductOnly(
#   (other_product_features_layers): Sequential(
#     (0): Linear(in_features=15, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): ReLU()
#   )
#   (theta): Sequential(
#     (0): Linear(in_features=9, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# ----- Prepare validation data -----
prepared_val = prepare_data(
    X_user_val,
    X_product,
    price * (1 - (1 - discount_percentage) * prod_randomization)
)
user_features_val, product_features_val, _, all_x_other_products_val, all_other_prices_val = prepared_val

user_features_val = user_features_val.to(device)
product_features_val = product_features_val.to(device)
all_x_other_products_val = all_x_other_products_val.to(device)
all_other_prices_val = all_other_prices_val.to(device)
choice_val = choice_val.to(device)

# ----- Optimizer and scheduler -----
optimizer = optim.Adam(pdlmodel.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1000, gamma=0.5)
l2_lambda = 1e-4  # L2 regularization coefficient

# Early stopping setup
best_val_loss = float('inf')
patience = 15
patience_counter = 0

# ----- Training loop -----
for epoch in range(2000):
    pdlmodel.train()
    optimizer.zero_grad()

    # Forward pass (train): use prepared prices and other-prices matrix
    outputs = pdlmodel(
        user_features,         # x_user (not used inside DeepMNLModel_No, but kept for interface)
        product_features,      # X_product (not used)
        all_x_other_products,  # X_other_products (not used in No model)
        all_other_prices,      # x_other_prices: p_-j
        prices,                # price: experimental p_j (after discount)
        prod_randomization     # can be ignored inside No model
    )
    choice_probabilities = F.log_softmax(outputs, dim=1)

    # Training loss
    loss = -torch.mean(
        choice_probabilities[
            torch.arange(choice_probabilities.shape[0], device=device),
            choice_train1
        ]
    )

    # L2 regularization
    l2_norm = sum(param.pow(2.0).sum() for param in pdlmodel.parameters())
    loss = loss + l2_lambda * l2_norm

    # Backward
    loss.backward()
    optimizer.step()

    # ----- Validation -----
    pdlmodel.eval()
    with torch.no_grad():
        val_outputs = pdlmodel(
            user_features_val,
            product_features_val,
            all_x_other_products_val,
            all_other_prices_val,
            prices,              # same product prices for validation
            prod_randomization
        )
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(
            val_choice_probabilities[
                torch.arange(val_choice_probabilities.shape[0], device=device),
                choice_val
            ]
        )

    print(
        f"Epoch {epoch+1}, "
        f"Training Loss: {loss.item():.4f}, "
        f"Validation Loss: {val_loss.item():.4f}"
    )

    # Early stopping logic
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        torch.save(pdlmodel.state_dict(), 'best_model.pth')
    else:
        patience_counter += 1

    if patience_counter >= patience:
        print("Early stopping triggered")
        break

    scheduler.step()
# Out:
# Epoch 1, Training Loss: 1.8331, Validation Loss: 1.7368
# Epoch 2, Training Loss: 1.7777, Validation Loss: 1.6712
# Epoch 3, Training Loss: 1.7223, Validation Loss: 1.6078
# Epoch 4, Training Loss: 1.6705, Validation Loss: 1.5450
# Epoch 5, Training Loss: 1.6234, Validation Loss: 1.4814
# Epoch 6, Training Loss: 1.5767, Validation Loss: 1.4198
# Epoch 7, Training Loss: 1.5291, Validation Loss: 1.3595
# Epoch 8, Training Loss: 1.4815, Validation Loss: 1.2979
# Epoch 9, Training Loss: 1.4312, Validation Loss: 1.2412
# Epoch 10, Training Loss: 1.3832, Validation Loss: 1.1907
# Epoch 11, Training Loss: 1.3399, Validation Loss: 1.1477
# Epoch 12, Training Loss: 1.3037, Validation Loss: 1.1123
# Epoch 13, Training Loss: 1.2775, Validation Loss: 1.0923
# Epoch 14, Training Loss: 1.2676, Validation Loss: 1.0870
# Epoch 15, Training Loss: 1.2717, Validation Loss: 1.0923
# Epoch 16, Training Loss: 1.2834, Validation Loss: 1.1005
# Epoch 17, Training Loss: 1.2944, Validation Loss: 1.1057
# Epoch 18, Training Loss: 1.2989, Validation Loss: 1.1061
# Epoch 19, Training Loss: 1.2954, Validation Loss: 1.1024
# Epoch 20, Training Loss: 1.2854, Validation Loss: 1.0966
# Epoch 21, Training Loss: 1.2718, Validation Loss: 1.0912
# Epoch 22, Training Loss: 1.2573, Validation Loss: 1.0878
# Epoch 23, Training Loss: 1.2442, Validation Loss: 1.0874
# Epoch 24, Training Loss: 1.2340, Validation Loss: 1.0897
# Epoch 25, Training Loss: 1.2283, Validation Loss: 1.0944
# Epoch 26, Training Loss: 1.2255, Validation Loss: 1.1006
# Epoch 27, Training Loss: 1.2247, Validation Loss: 1.1075
# Epoch 28, Training Loss: 1.2249, Validation Loss: 1.1141
# Epoch 29, Training Loss: 1.2251, Validation Loss: 1.1198
# Early stopping triggered

# %%
# All-control and all-treated for test set
num_product = X_product.shape[0]

# All control: product_randomization = 0
all_product_control = torch.zeros(num_product, device=device).bool()

# All treated: product_randomization = 1
all_product_treated = torch.ones(num_product, device=device).bool()

# Move base price and test users/products to device
X_user_test = X_user_test.to(device)
X_product = X_product.to(device)
price = price.to(device)

# --------- Expected revenue: all control ----------
# Control prices = base prices (no discount)
price_control = price.clone()

# Prepare test data under all-control prices
user_test_ctrl, product_test_ctrl, prices_ctrl, x_other_products_ctrl, other_prices_ctrl = prepare_data(
    X_user_test,
    X_product,
    price_control
)

utilities_ctrl = pdlmodel(
    user_test_ctrl,
    product_test_ctrl,
    x_other_products_ctrl,
    other_prices_ctrl,
    prices_ctrl,          # control prices
    all_product_control   # all False
)

probabilities_ctrl = F.softmax(utilities_ctrl, dim=1)

price_with_outside_ctrl = torch.cat(
    (torch.zeros(1, device=price.device), prices_ctrl), dim=0
)  # [M+1]

expected_revenue_ctrl = torch.sum(
    probabilities_ctrl * price_with_outside_ctrl.unsqueeze(0).expand_as(probabilities_ctrl),
    dim=1
).sum()

print(f"Expected Revenue (all control): ${expected_revenue_ctrl.item():.2f}")

# --------- Expected revenue: all treated ----------
# Treated prices = discounted prices
price_treated = price * discount_percentage

user_test_trt, product_test_trt, prices_trt, x_other_products_trt, other_prices_trt = prepare_data(
    X_user_test,
    X_product,
    price_treated
)

utilities_trt = pdlmodel(
    user_test_trt,
    product_test_trt,
    x_other_products_trt,
    other_prices_trt,
    prices_trt,          # treated prices
    all_product_treated  # all True
)

probabilities_trt = F.softmax(utilities_trt, dim=1)

price_with_outside_trt = torch.cat(
    (torch.zeros(1, device=price.device), prices_trt), dim=0
)

expected_revenue_trt = torch.sum(
    probabilities_trt * price_with_outside_trt.unsqueeze(0).expand_as(probabilities_trt),
    dim=1
).sum()

print(f"Expected Revenue (all treated): ${expected_revenue_trt.item():.2f}")

# --------- GTE ----------
pdl = (expected_revenue_trt - expected_revenue_ctrl).cpu().detach().numpy() * 600 / 266
print(pdl)

pdl_product = abs((pdl - true) / true)
print(pdl_product)
# Out:
# Expected Revenue (all control): $43.73
# Expected Revenue (all treated): $11.41
# -72.88818646194343
# 0.06165605533452369

# %% [markdown]
# ### All features

# %%
# PDL choice model
class DeepMNLModel_UserProduct(nn.Module):
    """
    Deep MNL:
    u_ij = theta(x_i, z_j, z_-j, p_j)
    Outside option utility = 0.
    """
    def __init__(self, user_dim, product_dim, num_product, hidden=5):
        super(DeepMNLModel_UserProduct, self).__init__()

        # Aggregate other products' features z_-j:
        # Input:  [M, (M-1)*F_p]
        # Output: [M, hidden]
        self.other_product_features_layers = nn.Sequential(
            nn.Linear(product_dim * (num_product - 1), hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU()
        )

        # theta(x_i, z_j, z_-j, p_j)
        # Input per (i,j):
        #   user_dim (x_i)
        # + product_dim (z_j)
        # + hidden (z_-j)
        # + 1 (p_j)
        in_dim = user_dim + product_dim + hidden + 1

        self.theta = nn.Sequential(
            nn.Linear(in_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, x_user, X_product, X_other_products,
                x_other_prices, price, prod_randomization):
        """
        x_user:          [N, F_u]          user features x_i
        X_product:       [M, F_p]          product features z_j
        X_other_products:[M, (M-1)*F_p]    other products' features z_-j
        price:           [M]               own price p_j (already discounted)

        x_other_prices, prod_randomization are not used here.
        """
        device = price.device
        N, M = x_user.shape[0], X_product.shape[0]

        # z_-j features: [M, hidden]
        zminus_feat = self.other_product_features_layers(X_other_products)

        # p_j: [M, 1]
        pj_feat = price.unsqueeze(1)

        # Product-side block: [M, F_p + hidden + 1]
        product_block = torch.cat(
            [X_product, zminus_feat, pj_feat],
            dim=1
        )

        # Expand product block for all users: [N, M, *]
        product_block_exp = product_block.unsqueeze(0).expand(N, -1, -1)

        # Expand user features: [N, 1, F_u] -> [N, M, F_u]
        x_user_exp = x_user.unsqueeze(1).expand(-1, M, -1)

        # Final theta input: [N, M, in_dim]
        theta_input = torch.cat([x_user_exp, product_block_exp], dim=2)

        # Flatten to [N*M, in_dim]
        theta_input_flat = theta_input.reshape(N * M, -1)

        # Utilities: [N*M, 1] -> [N, M]
        utilities = self.theta(theta_input_flat).view(N, M)

        # Outside option = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utilities], dim=1)

        return utilities_with_outside

# %%
# Apply the model
pdlmodel = DeepMNLModel_UserProduct(
    user_dim=X_user.shape[1],
    product_dim=X_product.shape[1],
    num_product=X_product.shape[0],
    hidden=5
).to(device)

# Weight initialization
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)

pdlmodel.apply(init_weights)
# Out:
# DeepMNLModel_UserProduct(
#   (other_product_features_layers): Sequential(
#     (0): Linear(in_features=15, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): ReLU()
#   )
#   (theta): Sequential(
#     (0): Linear(in_features=12, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# ----- Prepare validation data -----
prepared_val = prepare_data(
    X_user_val,
    X_product,
    price * (1 - (1 - discount_percentage) * prod_randomization)
)
user_features_val, product_features_val, _, all_x_other_products_val, all_other_prices_val = prepared_val

user_features_val = user_features_val.to(device)
product_features_val = product_features_val.to(device)
all_x_other_products_val = all_x_other_products_val.to(device)
all_other_prices_val = all_other_prices_val.to(device)
choice_val = choice_val.to(device)

# ----- Optimizer and scheduler -----
optimizer = optim.Adam(pdlmodel.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1000, gamma=0.5)
l2_lambda = 1e-4  # L2 regularization coefficient

# Early stopping setup
best_val_loss = float('inf')
patience = 15
patience_counter = 0

# ----- Training loop -----
for epoch in range(2000):
    pdlmodel.train()
    optimizer.zero_grad()

    # Forward pass (train): use prepared prices and other-prices matrix
    outputs = pdlmodel(
        user_features,         # x_user (not used inside DeepMNLModel_No, but kept for interface)
        product_features,      # X_product (not used)
        all_x_other_products,  # X_other_products (not used in No model)
        all_other_prices,      # x_other_prices: p_-j
        prices,                # price: experimental p_j (after discount)
        prod_randomization     # can be ignored inside No model
    )
    choice_probabilities = F.log_softmax(outputs, dim=1)

    # Training loss
    loss = -torch.mean(
        choice_probabilities[
            torch.arange(choice_probabilities.shape[0], device=device),
            choice_train1
        ]
    )

    # L2 regularization
    l2_norm = sum(param.pow(2.0).sum() for param in pdlmodel.parameters())
    loss = loss + l2_lambda * l2_norm

    # Backward
    loss.backward()
    optimizer.step()

    # ----- Validation -----
    pdlmodel.eval()
    with torch.no_grad():
        val_outputs = pdlmodel(
            user_features_val,
            product_features_val,
            all_x_other_products_val,
            all_other_prices_val,
            prices,              # same product prices for validation
            prod_randomization
        )
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(
            val_choice_probabilities[
                torch.arange(val_choice_probabilities.shape[0], device=device),
                choice_val
            ]
        )

    print(
        f"Epoch {epoch+1}, "
        f"Training Loss: {loss.item():.4f}, "
        f"Validation Loss: {val_loss.item():.4f}"
    )

    # Early stopping logic
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        torch.save(pdlmodel.state_dict(), 'best_model.pth')
    else:
        patience_counter += 1

    if patience_counter >= patience:
        print("Early stopping triggered")
        break

    scheduler.step()
# Out:
# Epoch 1, Training Loss: 2.2074, Validation Loss: 2.2007
# Epoch 2, Training Loss: 2.1324, Validation Loss: 2.1293
# Epoch 3, Training Loss: 2.0762, Validation Loss: 2.0685
# Epoch 4, Training Loss: 2.0300, Validation Loss: 2.0168
# Epoch 5, Training Loss: 1.9931, Validation Loss: 1.9748
# Epoch 6, Training Loss: 1.9640, Validation Loss: 1.9424
# Epoch 7, Training Loss: 1.9404, Validation Loss: 1.9167
# Epoch 8, Training Loss: 1.9201, Validation Loss: 1.8926
# Epoch 9, Training Loss: 1.9011, Validation Loss: 1.8735
# Epoch 10, Training Loss: 1.8836, Validation Loss: 1.8556
# Epoch 11, Training Loss: 1.8661, Validation Loss: 1.8358
# Epoch 12, Training Loss: 1.8481, Validation Loss: 1.8156
# Epoch 13, Training Loss: 1.8305, Validation Loss: 1.7962
# Epoch 14, Training Loss: 1.8132, Validation Loss: 1.7768
# Epoch 15, Training Loss: 1.7960, Validation Loss: 1.7573
# Epoch 16, Training Loss: 1.7791, Validation Loss: 1.7378
# Epoch 17, Training Loss: 1.7622, Validation Loss: 1.7183
# Epoch 18, Training Loss: 1.7451, Validation Loss: 1.6987
# Epoch 19, Training Loss: 1.7280, Validation Loss: 1.6791
# Epoch 20, Training Loss: 1.7107, Validation Loss: 1.6592
# Epoch 21, Training Loss: 1.6932, Validation Loss: 1.6390
# Epoch 22, Training Loss: 1.6754, Validation Loss: 1.6185
# Epoch 23, Training Loss: 1.6572, Validation Loss: 1.5975
# Epoch 24, Training Loss: 1.6384, Validation Loss: 1.5759
# Epoch 25, Training Loss: 1.6191, Validation Loss: 1.5536
# Epoch 26, Training Loss: 1.5991, Validation Loss: 1.5304
# Epoch 27, Training Loss: 1.5785, Validation Loss: 1.5058
# Epoch 28, Training Loss: 1.5566, Validation Loss: 1.4799
# Epoch 29, Training Loss: 1.5341, Validation Loss: 1.4526
# Epoch 30, Training Loss: 1.5106, Validation Loss: 1.4236
# Epoch 31, Training Loss: 1.4863, Validation Loss: 1.3934
# Epoch 32, Training Loss: 1.4610, Validation Loss: 1.3617
# Epoch 33, Training Loss: 1.4345, Validation Loss: 1.3278
# Epoch 34, Training Loss: 1.4065, Validation Loss: 1.2919
# Epoch 35, Training Loss: 1.3774, Validation Loss: 1.2539
# Epoch 36, Training Loss: 1.3480, Validation Loss: 1.2152
# Epoch 37, Training Loss: 1.3190, Validation Loss: 1.1781
# Epoch 38, Training Loss: 1.2910, Validation Loss: 1.1480
# Epoch 39, Training Loss: 1.2645, Validation Loss: 1.1230
# Epoch 40, Training Loss: 1.2414, Validation Loss: 1.1043
# Epoch 41, Training Loss: 1.2210, Validation Loss: 1.0930
# Epoch 42, Training Loss: 1.2081, Validation Loss: 1.0892
# Epoch 43, Training Loss: 1.2053, Validation Loss: 1.0935
# Epoch 44, Training Loss: 1.2117, Validation Loss: 1.1026
# Epoch 45, Training Loss: 1.2221, Validation Loss: 1.1108
# Epoch 46, Training Loss: 1.2306, Validation Loss: 1.1153
# Epoch 47, Training Loss: 1.2340, Validation Loss: 1.1153
# Epoch 48, Training Loss: 1.2321, Validation Loss: 1.1113
# Epoch 49, Training Loss: 1.2267, Validation Loss: 1.1042
# Epoch 50, Training Loss: 1.2210, Validation Loss: 1.0962
# Epoch 51, Training Loss: 1.2155, Validation Loss: 1.0903
# Epoch 52, Training Loss: 1.2101, Validation Loss: 1.0855
# Epoch 53, Training Loss: 1.2053, Validation Loss: 1.0828
# Epoch 54, Training Loss: 1.2014, Validation Loss: 1.0812
# Epoch 55, Training Loss: 1.1986, Validation Loss: 1.0805
# Epoch 56, Training Loss: 1.1973, Validation Loss: 1.0807
# Epoch 57, Training Loss: 1.1968, Validation Loss: 1.0820
# Epoch 58, Training Loss: 1.1967, Validation Loss: 1.0837
# Epoch 59, Training Loss: 1.1969, Validation Loss: 1.0854
# Epoch 60, Training Loss: 1.1970, Validation Loss: 1.0873
# Epoch 61, Training Loss: 1.1970, Validation Loss: 1.0891
# Epoch 62, Training Loss: 1.1969, Validation Loss: 1.0906
# Epoch 63, Training Loss: 1.1965, Validation Loss: 1.0919
# Epoch 64, Training Loss: 1.1960, Validation Loss: 1.0928
# Epoch 65, Training Loss: 1.1953, Validation Loss: 1.0935
# Epoch 66, Training Loss: 1.1943, Validation Loss: 1.0941
# Epoch 67, Training Loss: 1.1933, Validation Loss: 1.0947
# Epoch 68, Training Loss: 1.1921, Validation Loss: 1.0952
# Epoch 69, Training Loss: 1.1909, Validation Loss: 1.0958
# Epoch 70, Training Loss: 1.1897, Validation Loss: 1.0967
# Early stopping triggered

# %%
# All-control and all-treated for test set
num_product = X_product.shape[0]

# All control: product_randomization = 0
all_product_control = torch.zeros(num_product, device=device).bool()

# All treated: product_randomization = 1
all_product_treated = torch.ones(num_product, device=device).bool()

# Move base price and test users/products to device
X_user_test = X_user_test.to(device)
X_product = X_product.to(device)
price = price.to(device)

# --------- Expected revenue: all control ----------
# Control prices = base prices (no discount)
price_control = price.clone()

# Prepare test data under all-control prices
user_test_ctrl, product_test_ctrl, prices_ctrl, x_other_products_ctrl, other_prices_ctrl = prepare_data(
    X_user_test,
    X_product,
    price_control
)

utilities_ctrl = pdlmodel(
    user_test_ctrl,
    product_test_ctrl,
    x_other_products_ctrl,
    other_prices_ctrl,
    prices_ctrl,          # control prices
    all_product_control   # all False
)

probabilities_ctrl = F.softmax(utilities_ctrl, dim=1)

price_with_outside_ctrl = torch.cat(
    (torch.zeros(1, device=price.device), prices_ctrl), dim=0
)  # [M+1]

expected_revenue_ctrl = torch.sum(
    probabilities_ctrl * price_with_outside_ctrl.unsqueeze(0).expand_as(probabilities_ctrl),
    dim=1
).sum()

print(f"Expected Revenue (all control): ${expected_revenue_ctrl.item():.2f}")

# --------- Expected revenue: all treated ----------
# Treated prices = discounted prices
price_treated = price * discount_percentage

user_test_trt, product_test_trt, prices_trt, x_other_products_trt, other_prices_trt = prepare_data(
    X_user_test,
    X_product,
    price_treated
)

utilities_trt = pdlmodel(
    user_test_trt,
    product_test_trt,
    x_other_products_trt,
    other_prices_trt,
    prices_trt,          # treated prices
    all_product_treated  # all True
)

probabilities_trt = F.softmax(utilities_trt, dim=1)

price_with_outside_trt = torch.cat(
    (torch.zeros(1, device=price.device), prices_trt), dim=0
)

expected_revenue_trt = torch.sum(
    probabilities_trt * price_with_outside_trt.unsqueeze(0).expand_as(probabilities_trt),
    dim=1
).sum()

print(f"Expected Revenue (all treated): ${expected_revenue_trt.item():.2f}")

# --------- GTE ----------
pdl = (expected_revenue_trt - expected_revenue_ctrl).cpu().detach().numpy() * 600 / 266
print(pdl)

pdl_all = abs((pdl - true) / true)
print(pdl_all)
# Out:
# Expected Revenue (all control): $40.68
# Expected Revenue (all treated): $8.46
# -72.67346776517711
# 0.058528560802408675

# %% [markdown]
# ## DML Estimator

# %%
def H_theta(theta0_output,theta1_output,all_treated_price,price):
    N = theta0_output.shape[0]
    M = num_product
    expand_price = price.unsqueeze(0).expand(N, M)
    expand_all_treated_price = all_treated_price.unsqueeze(0).expand(N, M)
    all_treated_uti = theta0_output + theta1_output * expand_all_treated_price
    all_control_uti =  theta0_output + theta1_output * expand_price

    zero_utilities = torch.zeros(N, 1, device=all_treated_uti.device)
    all_treated_uti = torch.cat((zero_utilities,all_treated_uti), dim=1)
    all_control_uti = torch.cat((zero_utilities,all_control_uti), dim=1)

    all_treated_probabilities = F.softmax(all_treated_uti, dim=1)
    all_control_probabilities = F.softmax(all_control_uti, dim=1)

    price_with_outside = torch.cat((torch.zeros(1, device=price.device), price), dim=0)
    treated_price_with_outside = torch.cat((torch.zeros(1, device=all_treated_price.device), all_treated_price), dim=0)

    H = torch.sum(all_treated_probabilities * treated_price_with_outside - all_control_probabilities * price_with_outside,dim=1)
    expsum_treated = torch.sum(torch.exp(all_treated_uti),dim=1)
    expsum_control = torch.sum(torch.exp(all_control_uti),dim=1)

    expsum_treated_expanded = expsum_treated.unsqueeze(1).expand(-1, all_treated_uti.shape[1])
    expsum_control_expanded = expsum_control.unsqueeze(1).expand(-1, all_control_uti.shape[1])

    H_theta0 = torch.sum((torch.exp(all_treated_uti)*(1-torch.exp(all_treated_uti))/expsum_treated_expanded/expsum_treated_expanded) * treated_price_with_outside-
                          (torch.exp(all_control_uti)*(1-torch.exp(all_control_uti))/expsum_control_expanded/expsum_control_expanded) * price_with_outside,dim=1)
    H_theta1 = torch.sum((torch.exp(all_treated_uti)*(1-torch.exp(all_treated_uti))/expsum_treated_expanded/expsum_treated_expanded) * treated_price_with_outside * treated_price_with_outside-
                          (torch.exp(all_control_uti)*(1-torch.exp(all_control_uti))/expsum_control_expanded/expsum_control_expanded) * price_with_outside * price_with_outside,dim=1)

    return H,H_theta0,H_theta1

# %%
# l_theta
def l_theta(theta0_output, theta1_output, adjusted_price, decision_test, l2_lambda=1e-4):
    N = theta0_output.shape[0]
    M = theta0_output.shape[1]

    expand_adjusted_price = adjusted_price.unsqueeze(0).expand(N, M)
    uti = theta0_output + theta1_output * expand_adjusted_price

    zero_utilities = torch.zeros(N, 1, device=uti.device)
    uti_with_outside = torch.cat((zero_utilities, uti), dim=1)

    probabilities = F.softmax(uti_with_outside, dim=1)

    prod_indices = torch.ones(M, device=uti.device)
    prod_indices = torch.cat([torch.zeros(1, device=uti.device), prod_indices])

    adjusted_price_with_outside = torch.cat([torch.zeros(1, device=adjusted_price.device), adjusted_price])

    ltheta0 = probabilities[torch.arange(decision_test.size(0)), decision_test] - prod_indices[decision_test]

    ltheta1 = (probabilities[torch.arange(decision_test.size(0)), decision_test] * adjusted_price_with_outside[decision_test]) - \
              (adjusted_price_with_outside[decision_test] * prod_indices[decision_test])

    is_inside = (decision_test > 0)

    inside_indices = (decision_test - 1).clamp(min=0)

    theta0_chosen = theta0_output.gather(1, inside_indices.unsqueeze(1)).squeeze(1)
    theta1_chosen = theta1_output.gather(1, inside_indices.unsqueeze(1)).squeeze(1)

    reg_grad0 = 2 * l2_lambda * theta0_chosen
    reg_grad1 = 2 * l2_lambda * theta1_chosen

    ltheta0 = ltheta0 + (reg_grad0 * is_inside.float())
    ltheta1 = ltheta1 + (reg_grad1 * is_inside.float())

    return ltheta0, ltheta1

# %%
# l_inv
def lambdainv(theta0_output, theta1_output, price, decision_test, epsilon=1e-6, l2_lambda=1e-4):

    N = theta0_output.shape[0]
    M = num_product

    expand_price = price.unsqueeze(0).expand(N, M)
    expand_all_treated_price = discount_percentage * price.unsqueeze(0).expand(N, M)

    all_treated_uti = theta0_output + theta1_output * expand_all_treated_price
    all_control_uti = theta0_output + theta1_output * expand_price

    zero_utilities = torch.zeros(N, 1, device=all_control_uti.device)
    all_treated_uti = torch.cat((zero_utilities, all_treated_uti), dim=1)
    all_control_uti = torch.cat((zero_utilities, all_control_uti), dim=1)

    probabilities_control = F.softmax(all_control_uti, dim=1)
    probabilities_treated = F.softmax(all_treated_uti, dim=1)

    chosen_prob_control = probabilities_control[torch.arange(N), decision_test]
    chosen_prob_treated = probabilities_treated[torch.arange(N), decision_test]

    price_with_outside = torch.cat((torch.zeros(1, device=price.device), price), dim=0)
    all_treated_price_vec = price * discount_percentage # Assuming logic from original code
    treated_price_with_outside = torch.cat((torch.zeros(1, device=price.device), all_treated_price_vec), dim=0)

    expand_price_ext = price_with_outside.unsqueeze(0).expand(N, M+1)

    chosen_price = expand_price_ext[torch.arange(N), decision_test]

    ltheta00 = chosen_prob_control * (1 - chosen_prob_control) + \
               chosen_prob_treated * (1 - chosen_prob_treated)

    ltheta01 = chosen_prob_control * (1 - chosen_prob_control) * chosen_price + \
               chosen_prob_treated * (1 - chosen_prob_treated) * (chosen_price * discount_percentage)

    ltheta11 = chosen_prob_control * (1 - chosen_prob_control) * (chosen_price**2) + \
               chosen_prob_treated * (1 - chosen_prob_treated) * ((chosen_price * discount_percentage)**2)

    ltheta00 = ltheta00 / 2
    ltheta01 = ltheta01 / 2
    ltheta11 = ltheta11 / 2

    ltheta00 = ltheta00.unsqueeze(1).unsqueeze(2)
    ltheta01 = ltheta01.unsqueeze(1).unsqueeze(2)
    ltheta11 = ltheta11.unsqueeze(1).unsqueeze(2)

    top_row = torch.cat((ltheta00, ltheta01), dim=2)
    bottom_row = torch.cat((ltheta01, ltheta11), dim=2)

    L_matrix = torch.cat((top_row, bottom_row), dim=1) # [N, 2, 2]

    reg_hessian_value = 2 * l2_lambda
    identity_matrix = torch.eye(2, dtype=L_matrix.dtype, device=L_matrix.device)
    reg_matrix = identity_matrix.unsqueeze(0).expand(N, 2, 2) * reg_hessian_value

    L_total = L_matrix + reg_matrix + (identity_matrix.unsqueeze(0) * epsilon)

    L_inv = torch.linalg.inv(L_total)

    return L_inv

# %% [markdown]
# ### No features

# %%
class UtilityEstimator_No(nn.Module):
    def __init__(self, num_product, hidden=5):
        super(UtilityEstimator_No, self).__init__()

        # θ0(j): a learnable scalar per product
        self.theta0 = nn.Parameter(torch.zeros(num_product))

        # θ1(j): a learnable scalar per product
        self.theta1 = nn.Parameter(torch.zeros(num_product))

    def forward(self, x_user, x_product, x_other_products, x_other_prices, price):
        """
        x_user, x_product, x_other_products, x_other_prices 不再使用。
        price: [M]
        """
        device = price.device
        N, M = x_user.shape[0], price.shape[0]

        # θ0(j) expand to [N, M]
        theta0_output = self.theta0.view(1, M).expand(N, M)

        # θ1(j) expand to [N, M]
        theta1_output = self.theta1.view(1, M).expand(N, M)

        # price expand to [N, M]
        pj_exp = price.view(1, M).expand(N, M)

        # u_ij = θ0_j + θ1_j * p_j
        utility = theta0_output + theta1_output * pj_exp

        # outside option utility = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utility], dim=1)

        return utilities_with_outside, theta0_output, theta1_output

# %%
# Apply the model
dml_model = UtilityEstimator_No(
    num_product=X_product.shape[0],
    hidden=5
).to(device)


# Initialize weight
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)
dml_model.apply(init_weights)
# Out:
# UtilityEstimator_No()

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# Train the model
optimizer = torch.optim.Adam(dml_model.parameters(), lr=0.03)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1000, gamma=0.5)
l2_lambda = 1e-4
best_val_loss = float('inf')
patience = 10
patience_counter = 0

for epoch in range(2000):
    dml_model.train()  # Set model to training mode
    optimizer.zero_grad()

    outputs = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)[0]
    choice_probabilities = torch.nn.functional.log_softmax(outputs, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])
    l2_norm = sum(param.pow(2.0).sum() for param in dml_model.parameters())
    loss = loss + l2_lambda * l2_norm
    loss.backward()
    optimizer.step()
    scheduler.step()

    # Validation phase
    dml_model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        val_outputs = dml_model(X_user_val, product_features, all_x_other_products, all_other_prices,prices)[0]
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])
    print(f"Epoch {epoch+1}, Training Loss: {loss.item()}, Validation Loss: {val_loss.item()}")
    # Check if validation loss improved
    if (val_loss < best_val_loss)|(val_loss<loss):
        best_val_loss = val_loss
        patience_counter = 0  # Reset counter on improvement
        torch.save(dml_model.state_dict(), 'best_model.pth')  # Save the best model
    else:
        patience_counter += 1  # Increment counter if no improvement

    # Early stopping condition
    if patience_counter >= patience:
        print("Early stopping triggered")
        break
# Out:
# Epoch 1, Training Loss: 1.9459103345870972, Validation Loss: 1.9207828044891357
# Epoch 2, Training Loss: 1.9207996129989624, Validation Loss: 1.8960483074188232
# Epoch 3, Training Loss: 1.8960871696472168, Validation Loss: 1.8717182874679565
# Epoch 4, Training Loss: 1.8717854022979736, Validation Loss: 1.8478050231933594
# Epoch 5, Training Loss: 1.8479084968566895, Validation Loss: 1.8243186473846436
# Epoch 6, Training Loss: 1.8244677782058716, Validation Loss: 1.8012704849243164
# Epoch 7, Training Loss: 1.8014755249023438, Validation Loss: 1.7786704301834106
# Epoch 8, Training Loss: 1.7789417505264282, Validation Loss: 1.7565280199050903
# Epoch 9, Training Loss: 1.756877064704895, Validation Loss: 1.7348521947860718
# Epoch 10, Training Loss: 1.7352899312973022, Validation Loss: 1.7136516571044922
# Epoch 11, Training Loss: 1.7141896486282349, Validation Loss: 1.692933440208435
# Epoch 12, Training Loss: 1.6935824155807495, Validation Loss: 1.6727049350738525
# Epoch 13, Training Loss: 1.6734758615493774, Validation Loss: 1.6529728174209595
# Epoch 14, Training Loss: 1.6538745164871216, Validation Loss: 1.6337424516677856
# Epoch 15, Training Loss: 1.634783387184143, Validation Loss: 1.6150188446044922
# Epoch 16, Training Loss: 1.6162056922912598, Validation Loss: 1.596806287765503
# Epoch 17, Training Loss: 1.5981446504592896, Validation Loss: 1.5791082382202148
# Epoch 18, Training Loss: 1.5806015729904175, Validation Loss: 1.5619279146194458
# Epoch 19, Training Loss: 1.5635777711868286, Validation Loss: 1.54526686668396
# Epoch 20, Training Loss: 1.547072410583496, Validation Loss: 1.5291268825531006
# Epoch 21, Training Loss: 1.5310848951339722, Validation Loss: 1.513508677482605
# Epoch 22, Training Loss: 1.5156128406524658, Validation Loss: 1.498411774635315
# Epoch 23, Training Loss: 1.5006542205810547, Validation Loss: 1.4838354587554932
# Epoch 24, Training Loss: 1.4862046241760254, Validation Loss: 1.4697788953781128
# Epoch 25, Training Loss: 1.4722601175308228, Validation Loss: 1.456239104270935
# Epoch 26, Training Loss: 1.458815336227417, Validation Loss: 1.4432132244110107
# Epoch 27, Training Loss: 1.445863962173462, Validation Loss: 1.4306976795196533
# Epoch 28, Training Loss: 1.4333996772766113, Validation Loss: 1.4186880588531494
# Epoch 29, Training Loss: 1.4214147329330444, Validation Loss: 1.4071792364120483
# Epoch 30, Training Loss: 1.4099010229110718, Validation Loss: 1.3961652517318726
# Epoch 31, Training Loss: 1.3988497257232666, Validation Loss: 1.3856399059295654
# Epoch 32, Training Loss: 1.3882516622543335, Validation Loss: 1.3755954504013062
# Epoch 33, Training Loss: 1.3780968189239502, Validation Loss: 1.366024374961853
# Epoch 34, Training Loss: 1.3683748245239258, Validation Loss: 1.3569179773330688
# Epoch 35, Training Loss: 1.3590749502182007, Validation Loss: 1.3482669591903687
# Epoch 36, Training Loss: 1.350185751914978, Validation Loss: 1.3400615453720093
# Epoch 37, Training Loss: 1.3416951894760132, Validation Loss: 1.3322913646697998
# Epoch 38, Training Loss: 1.333592176437378, Validation Loss: 1.324945330619812
# Epoch 39, Training Loss: 1.3258638381958008, Validation Loss: 1.318011999130249
# Epoch 40, Training Loss: 1.3184986114501953, Validation Loss: 1.3114789724349976
# Epoch 41, Training Loss: 1.3114830255508423, Validation Loss: 1.3053343296051025
# Epoch 42, Training Loss: 1.3048051595687866, Validation Loss: 1.2995649576187134
# Epoch 43, Training Loss: 1.298452377319336, Validation Loss: 1.294157862663269
# Epoch 44, Training Loss: 1.2924120426177979, Validation Loss: 1.289098858833313
# Epoch 45, Training Loss: 1.2866716384887695, Validation Loss: 1.2843745946884155
# Epoch 46, Training Loss: 1.2812191247940063, Validation Loss: 1.2799710035324097
# Epoch 47, Training Loss: 1.276042103767395, Validation Loss: 1.2758740186691284
# Epoch 48, Training Loss: 1.2711288928985596, Validation Loss: 1.2720688581466675
# Epoch 49, Training Loss: 1.2664674520492554, Validation Loss: 1.2685415744781494
# Epoch 50, Training Loss: 1.2620468139648438, Validation Loss: 1.2652778625488281
# Epoch 51, Training Loss: 1.2578556537628174, Validation Loss: 1.2622634172439575
# Epoch 52, Training Loss: 1.2538834810256958, Validation Loss: 1.2594836950302124
# Epoch 53, Training Loss: 1.2501194477081299, Validation Loss: 1.2569248676300049
# Epoch 54, Training Loss: 1.2465535402297974, Validation Loss: 1.2545732259750366
# Epoch 55, Training Loss: 1.2431761026382446, Validation Loss: 1.2524149417877197
# Epoch 56, Training Loss: 1.2399781942367554, Validation Loss: 1.2504366636276245
# Epoch 57, Training Loss: 1.2369500398635864, Validation Loss: 1.2486255168914795
# Epoch 58, Training Loss: 1.2340837717056274, Validation Loss: 1.2469685077667236
# Epoch 59, Training Loss: 1.2313703298568726, Validation Loss: 1.2454537153244019
# Epoch 60, Training Loss: 1.2288020849227905, Validation Loss: 1.2440690994262695
# Epoch 61, Training Loss: 1.2263712882995605, Validation Loss: 1.2428033351898193
# Epoch 62, Training Loss: 1.2240711450576782, Validation Loss: 1.2416452169418335
# Epoch 63, Training Loss: 1.2218940258026123, Validation Loss: 1.2405849695205688
# Epoch 64, Training Loss: 1.2198337316513062, Validation Loss: 1.2396119832992554
# Epoch 65, Training Loss: 1.2178837060928345, Validation Loss: 1.238716959953308
# Epoch 66, Training Loss: 1.2160375118255615, Validation Loss: 1.2378915548324585
# Epoch 67, Training Loss: 1.2142904996871948, Validation Loss: 1.2371271848678589
# Epoch 68, Training Loss: 1.21263587474823, Validation Loss: 1.2364158630371094
# Epoch 69, Training Loss: 1.211069107055664, Validation Loss: 1.2357510328292847
# Epoch 70, Training Loss: 1.2095849514007568, Validation Loss: 1.2351258993148804
# Epoch 71, Training Loss: 1.208179235458374, Validation Loss: 1.2345346212387085
# Epoch 72, Training Loss: 1.206846833229065, Validation Loss: 1.2339715957641602
# Epoch 73, Training Loss: 1.2055838108062744, Validation Loss: 1.2334318161010742
# Epoch 74, Training Loss: 1.2043859958648682, Validation Loss: 1.2329113483428955
# Epoch 75, Training Loss: 1.2032495737075806, Validation Loss: 1.2324060201644897
# Epoch 76, Training Loss: 1.2021713256835938, Validation Loss: 1.2319132089614868
# Epoch 77, Training Loss: 1.2011476755142212, Validation Loss: 1.2314289808273315
# Epoch 78, Training Loss: 1.200175404548645, Validation Loss: 1.2309516668319702
# Epoch 79, Training Loss: 1.1992515325546265, Validation Loss: 1.23047935962677
# Epoch 80, Training Loss: 1.1983733177185059, Validation Loss: 1.2300103902816772
# Epoch 81, Training Loss: 1.197538137435913, Validation Loss: 1.2295434474945068
# Epoch 82, Training Loss: 1.1967434883117676, Validation Loss: 1.2290775775909424
# Epoch 83, Training Loss: 1.1959869861602783, Validation Loss: 1.2286123037338257
# Epoch 84, Training Loss: 1.1952662467956543, Validation Loss: 1.2281475067138672
# Epoch 85, Training Loss: 1.1945797204971313, Validation Loss: 1.2276828289031982
# Epoch 86, Training Loss: 1.1939252614974976, Validation Loss: 1.2272182703018188
# Epoch 87, Training Loss: 1.1933008432388306, Validation Loss: 1.2267541885375977
# Epoch 88, Training Loss: 1.1927052736282349, Validation Loss: 1.226291298866272
# Epoch 89, Training Loss: 1.1921366453170776, Validation Loss: 1.2258297204971313
# Epoch 90, Training Loss: 1.1915932893753052, Validation Loss: 1.2253698110580444
# Epoch 91, Training Loss: 1.191074013710022, Validation Loss: 1.2249127626419067
# Epoch 92, Training Loss: 1.190577507019043, Validation Loss: 1.224458932876587
# Epoch 93, Training Loss: 1.1901028156280518, Validation Loss: 1.2240089178085327
# Epoch 94, Training Loss: 1.1896482706069946, Validation Loss: 1.2235634326934814
# Epoch 95, Training Loss: 1.1892132759094238, Validation Loss: 1.2231234312057495
# Epoch 96, Training Loss: 1.1887966394424438, Validation Loss: 1.2226890325546265
# Epoch 97, Training Loss: 1.1883972883224487, Validation Loss: 1.2222610712051392
# Epoch 98, Training Loss: 1.1880145072937012, Validation Loss: 1.2218397855758667
# Epoch 99, Training Loss: 1.1876472234725952, Validation Loss: 1.2214254140853882
# Epoch 100, Training Loss: 1.1872949600219727, Validation Loss: 1.22101891040802
# Epoch 101, Training Loss: 1.186956524848938, Validation Loss: 1.2206201553344727
# Epoch 102, Training Loss: 1.186631441116333, Validation Loss: 1.2202295064926147
# Epoch 103, Training Loss: 1.1863192319869995, Validation Loss: 1.2198469638824463
# Epoch 104, Training Loss: 1.1860191822052002, Validation Loss: 1.2194726467132568
# Epoch 105, Training Loss: 1.1857305765151978, Validation Loss: 1.2191064357757568
# Epoch 106, Training Loss: 1.1854530572891235, Validation Loss: 1.2187483310699463
# Epoch 107, Training Loss: 1.1851859092712402, Validation Loss: 1.2183983325958252
# Epoch 108, Training Loss: 1.1849287748336792, Validation Loss: 1.218056082725525
# Epoch 109, Training Loss: 1.1846810579299927, Validation Loss: 1.217721700668335
# Epoch 110, Training Loss: 1.1844425201416016, Validation Loss: 1.217394232749939
# Epoch 111, Training Loss: 1.184212565422058, Validation Loss: 1.2170741558074951
# Epoch 112, Training Loss: 1.183990716934204, Validation Loss: 1.2167607545852661
# Epoch 113, Training Loss: 1.183777093887329, Validation Loss: 1.2164536714553833
# Epoch 114, Training Loss: 1.1835706233978271, Validation Loss: 1.2161529064178467
# Epoch 115, Training Loss: 1.1833717823028564, Validation Loss: 1.2158576250076294
# Epoch 116, Training Loss: 1.1831798553466797, Validation Loss: 1.2155678272247314
# Epoch 117, Training Loss: 1.1829943656921387, Validation Loss: 1.2152832746505737
# Epoch 118, Training Loss: 1.1828151941299438, Validation Loss: 1.215003252029419
# Epoch 119, Training Loss: 1.1826423406600952, Validation Loss: 1.214727759361267
# Epoch 120, Training Loss: 1.182475209236145, Validation Loss: 1.2144564390182495
# Epoch 121, Training Loss: 1.1823137998580933, Validation Loss: 1.2141892910003662
# Epoch 122, Training Loss: 1.1821575164794922, Validation Loss: 1.2139254808425903
# Epoch 123, Training Loss: 1.182006597518921, Validation Loss: 1.213665246963501
# Epoch 124, Training Loss: 1.1818605661392212, Validation Loss: 1.213408350944519
# Epoch 125, Training Loss: 1.181719422340393, Validation Loss: 1.213154673576355
# Epoch 126, Training Loss: 1.1815826892852783, Validation Loss: 1.2129040956497192
# Epoch 127, Training Loss: 1.1814507246017456, Validation Loss: 1.2126562595367432
# Epoch 128, Training Loss: 1.1813228130340576, Validation Loss: 1.2124115228652954
# Epoch 129, Training Loss: 1.1811989545822144, Validation Loss: 1.2121694087982178
# Epoch 130, Training Loss: 1.1810787916183472, Validation Loss: 1.211930513381958
# Epoch 131, Training Loss: 1.1809629201889038, Validation Loss: 1.2116940021514893
# Epoch 132, Training Loss: 1.1808502674102783, Validation Loss: 1.2114609479904175
# Epoch 133, Training Loss: 1.180741310119629, Validation Loss: 1.2112303972244263
# Epoch 134, Training Loss: 1.180635690689087, Validation Loss: 1.2110029458999634
# Epoch 135, Training Loss: 1.180533528327942, Validation Loss: 1.2107782363891602
# Epoch 136, Training Loss: 1.1804343461990356, Validation Loss: 1.2105568647384644
# Epoch 137, Training Loss: 1.1803381443023682, Validation Loss: 1.2103384733200073
# Epoch 138, Training Loss: 1.180245041847229, Validation Loss: 1.2101233005523682
# Epoch 139, Training Loss: 1.18015456199646, Validation Loss: 1.2099113464355469
# Epoch 140, Training Loss: 1.1800670623779297, Validation Loss: 1.2097028493881226
# Epoch 141, Training Loss: 1.17998206615448, Validation Loss: 1.2094976902008057
# Epoch 142, Training Loss: 1.1798995733261108, Validation Loss: 1.2092961072921753
# Epoch 143, Training Loss: 1.1798198223114014, Validation Loss: 1.2090976238250732
# Epoch 144, Training Loss: 1.1797420978546143, Validation Loss: 1.2089029550552368
# Epoch 145, Training Loss: 1.1796668767929077, Validation Loss: 1.208711862564087
# Epoch 146, Training Loss: 1.179593801498413, Validation Loss: 1.2085239887237549
# Epoch 147, Training Loss: 1.1795228719711304, Validation Loss: 1.208340048789978
# Epoch 148, Training Loss: 1.1794543266296387, Validation Loss: 1.2081595659255981
# Epoch 149, Training Loss: 1.1793874502182007, Validation Loss: 1.2079826593399048
# Epoch 150, Training Loss: 1.1793224811553955, Validation Loss: 1.2078092098236084
# Epoch 151, Training Loss: 1.1792596578598022, Validation Loss: 1.2076390981674194
# Epoch 152, Training Loss: 1.1791985034942627, Validation Loss: 1.207472562789917
# Epoch 153, Training Loss: 1.1791390180587769, Validation Loss: 1.2073091268539429
# Epoch 154, Training Loss: 1.1790813207626343, Validation Loss: 1.2071495056152344
# Epoch 155, Training Loss: 1.179025411605835, Validation Loss: 1.2069928646087646
# Epoch 156, Training Loss: 1.1789710521697998, Validation Loss: 1.2068394422531128
# Epoch 157, Training Loss: 1.1789182424545288, Validation Loss: 1.2066888809204102
# Epoch 158, Training Loss: 1.1788667440414429, Validation Loss: 1.2065417766571045
# Epoch 159, Training Loss: 1.1788169145584106, Validation Loss: 1.206397294998169
# Epoch 160, Training Loss: 1.178768277168274, Validation Loss: 1.2062557935714722
# Epoch 161, Training Loss: 1.178721308708191, Validation Loss: 1.206117033958435
# Epoch 162, Training Loss: 1.1786754131317139, Validation Loss: 1.2059811353683472
# Epoch 163, Training Loss: 1.1786309480667114, Validation Loss: 1.2058477401733398
# Epoch 164, Training Loss: 1.178587555885315, Validation Loss: 1.2057169675827026
# Epoch 165, Training Loss: 1.1785454750061035, Validation Loss: 1.205588459968567
# Epoch 166, Training Loss: 1.1785047054290771, Validation Loss: 1.2054624557495117
# Epoch 167, Training Loss: 1.1784648895263672, Validation Loss: 1.2053388357162476
# Epoch 168, Training Loss: 1.1784261465072632, Validation Loss: 1.2052173614501953
# Epoch 169, Training Loss: 1.1783887147903442, Validation Loss: 1.2050981521606445
# Epoch 170, Training Loss: 1.1783519983291626, Validation Loss: 1.2049810886383057
# Epoch 171, Training Loss: 1.1783164739608765, Validation Loss: 1.2048660516738892
# Epoch 172, Training Loss: 1.1782817840576172, Validation Loss: 1.204753041267395
# Epoch 173, Training Loss: 1.1782480478286743, Validation Loss: 1.2046419382095337
# Epoch 174, Training Loss: 1.178215503692627, Validation Loss: 1.2045326232910156
# Epoch 175, Training Loss: 1.1781835556030273, Validation Loss: 1.2044252157211304
# Epoch 176, Training Loss: 1.1781526803970337, Validation Loss: 1.2043198347091675
# Epoch 177, Training Loss: 1.1781225204467773, Validation Loss: 1.2042161226272583
# Epoch 178, Training Loss: 1.1780931949615479, Validation Loss: 1.2041141986846924
# Epoch 179, Training Loss: 1.1780644655227661, Validation Loss: 1.2040138244628906
# Epoch 180, Training Loss: 1.1780368089675903, Validation Loss: 1.2039152383804321
# Epoch 181, Training Loss: 1.1780096292495728, Validation Loss: 1.203818440437317
# Epoch 182, Training Loss: 1.1779834032058716, Validation Loss: 1.2037228345870972
# Epoch 183, Training Loss: 1.1779576539993286, Validation Loss: 1.2036292552947998
# Epoch 184, Training Loss: 1.177932858467102, Validation Loss: 1.203536868095398
# Epoch 185, Training Loss: 1.1779085397720337, Validation Loss: 1.2034461498260498
# Epoch 186, Training Loss: 1.1778849363327026, Validation Loss: 1.2033568620681763
# Epoch 187, Training Loss: 1.1778619289398193, Validation Loss: 1.203269124031067
# Epoch 188, Training Loss: 1.1778395175933838, Validation Loss: 1.2031828165054321
# Epoch 189, Training Loss: 1.177817702293396, Validation Loss: 1.203097939491272
# Epoch 190, Training Loss: 1.177796483039856, Validation Loss: 1.2030143737792969
# Epoch 191, Training Loss: 1.1777757406234741, Validation Loss: 1.2029322385787964
# Epoch 192, Training Loss: 1.1777557134628296, Validation Loss: 1.202851414680481
# Epoch 193, Training Loss: 1.1777361631393433, Validation Loss: 1.2027719020843506
# Epoch 194, Training Loss: 1.1777169704437256, Validation Loss: 1.2026935815811157
# Epoch 195, Training Loss: 1.1776983737945557, Validation Loss: 1.2026164531707764
# Epoch 196, Training Loss: 1.1776801347732544, Validation Loss: 1.202540636062622
# Epoch 197, Training Loss: 1.1776624917984009, Validation Loss: 1.2024661302566528
# Epoch 198, Training Loss: 1.177645206451416, Validation Loss: 1.202392578125
# Epoch 199, Training Loss: 1.1776283979415894, Validation Loss: 1.2023204565048218
# Epoch 200, Training Loss: 1.1776121854782104, Validation Loss: 1.2022494077682495
# Epoch 201, Training Loss: 1.177596092224121, Validation Loss: 1.2021795511245728
# Epoch 202, Training Loss: 1.1775808334350586, Validation Loss: 1.2021102905273438
# Epoch 203, Training Loss: 1.1775654554367065, Validation Loss: 1.202042579650879
# Epoch 204, Training Loss: 1.1775507926940918, Validation Loss: 1.2019758224487305
# Epoch 205, Training Loss: 1.1775362491607666, Validation Loss: 1.2019100189208984
# Epoch 206, Training Loss: 1.1775224208831787, Validation Loss: 1.2018451690673828
# Epoch 207, Training Loss: 1.17750883102417, Validation Loss: 1.2017812728881836
# Epoch 208, Training Loss: 1.1774954795837402, Validation Loss: 1.2017185688018799
# Epoch 209, Training Loss: 1.1774824857711792, Validation Loss: 1.201656699180603
# Epoch 210, Training Loss: 1.1774699687957764, Validation Loss: 1.2015959024429321
# Epoch 211, Training Loss: 1.177457571029663, Validation Loss: 1.2015355825424194
# Epoch 212, Training Loss: 1.177445411682129, Validation Loss: 1.2014764547348022
# Epoch 213, Training Loss: 1.177433729171753, Validation Loss: 1.2014185190200806
# Epoch 214, Training Loss: 1.1774224042892456, Validation Loss: 1.201361060142517
# Epoch 215, Training Loss: 1.1774111986160278, Validation Loss: 1.201304316520691
# Epoch 216, Training Loss: 1.1774003505706787, Validation Loss: 1.2012487649917603
# Epoch 217, Training Loss: 1.1773898601531982, Validation Loss: 1.201193928718567
# Epoch 218, Training Loss: 1.1773794889450073, Validation Loss: 1.2011396884918213
# Epoch 219, Training Loss: 1.177369236946106, Validation Loss: 1.2010866403579712
# Epoch 220, Training Loss: 1.1773594617843628, Validation Loss: 1.2010339498519897
# Epoch 221, Training Loss: 1.1773496866226196, Validation Loss: 1.2009823322296143
# Epoch 222, Training Loss: 1.1773405075073242, Validation Loss: 1.2009315490722656
# Epoch 223, Training Loss: 1.1773313283920288, Validation Loss: 1.2008812427520752
# Epoch 224, Training Loss: 1.1773223876953125, Validation Loss: 1.2008317708969116
# Epoch 225, Training Loss: 1.1773135662078857, Validation Loss: 1.2007827758789062
# Epoch 226, Training Loss: 1.177304983139038, Validation Loss: 1.2007348537445068
# Epoch 227, Training Loss: 1.1772968769073486, Validation Loss: 1.2006875276565552
# Epoch 228, Training Loss: 1.1772887706756592, Validation Loss: 1.2006407976150513
# Epoch 229, Training Loss: 1.1772807836532593, Validation Loss: 1.2005947828292847
# Epoch 230, Training Loss: 1.1772730350494385, Validation Loss: 1.2005494832992554
# Epoch 231, Training Loss: 1.1772654056549072, Validation Loss: 1.2005046606063843
# Epoch 232, Training Loss: 1.177258014678955, Validation Loss: 1.20046067237854
# Epoch 233, Training Loss: 1.177250862121582, Validation Loss: 1.2004172801971436
# Epoch 234, Training Loss: 1.177243709564209, Validation Loss: 1.2003744840621948
# Epoch 235, Training Loss: 1.177236795425415, Validation Loss: 1.2003322839736938
# Epoch 236, Training Loss: 1.1772301197052002, Validation Loss: 1.2002907991409302
# Epoch 237, Training Loss: 1.177223801612854, Validation Loss: 1.2002497911453247
# Epoch 238, Training Loss: 1.1772171258926392, Validation Loss: 1.2002094984054565
# Epoch 239, Training Loss: 1.1772109270095825, Validation Loss: 1.200169563293457
# Epoch 240, Training Loss: 1.1772048473358154, Validation Loss: 1.2001302242279053
# Epoch 241, Training Loss: 1.1771987676620483, Validation Loss: 1.2000916004180908
# Epoch 242, Training Loss: 1.1771929264068604, Validation Loss: 1.2000534534454346
# Epoch 243, Training Loss: 1.1771873235702515, Validation Loss: 1.2000160217285156
# Epoch 244, Training Loss: 1.1771814823150635, Validation Loss: 1.1999787092208862
# Epoch 245, Training Loss: 1.1771762371063232, Validation Loss: 1.1999423503875732
# Epoch 246, Training Loss: 1.177170753479004, Validation Loss: 1.199906349182129
# Epoch 247, Training Loss: 1.1771655082702637, Validation Loss: 1.1998709440231323
# Epoch 248, Training Loss: 1.177160382270813, Validation Loss: 1.1998358964920044
# Epoch 249, Training Loss: 1.1771552562713623, Validation Loss: 1.1998014450073242
# Epoch 250, Training Loss: 1.1771504878997803, Validation Loss: 1.1997673511505127
# Epoch 251, Training Loss: 1.1771454811096191, Validation Loss: 1.1997339725494385
# Epoch 252, Training Loss: 1.1771409511566162, Validation Loss: 1.1997010707855225
# Epoch 253, Training Loss: 1.1771363019943237, Validation Loss: 1.199668526649475
# Epoch 254, Training Loss: 1.1771317720413208, Validation Loss: 1.1996363401412964
# Epoch 255, Training Loss: 1.1771273612976074, Validation Loss: 1.199604868888855
# Epoch 256, Training Loss: 1.1771230697631836, Validation Loss: 1.1995737552642822
# Epoch 257, Training Loss: 1.1771187782287598, Validation Loss: 1.1995428800582886
# Epoch 258, Training Loss: 1.177114486694336, Validation Loss: 1.1995126008987427
# Epoch 259, Training Loss: 1.1771104335784912, Validation Loss: 1.1994829177856445
# Epoch 260, Training Loss: 1.177106499671936, Validation Loss: 1.1994534730911255
# Epoch 261, Training Loss: 1.1771026849746704, Validation Loss: 1.199424386024475
# Epoch 262, Training Loss: 1.1770987510681152, Validation Loss: 1.1993961334228516
# Epoch 263, Training Loss: 1.1770950555801392, Validation Loss: 1.199367880821228
# Epoch 264, Training Loss: 1.177091360092163, Validation Loss: 1.1993401050567627
# Epoch 265, Training Loss: 1.177087664604187, Validation Loss: 1.1993129253387451
# Epoch 266, Training Loss: 1.17708420753479, Validation Loss: 1.199285864830017
# Epoch 267, Training Loss: 1.177080750465393, Validation Loss: 1.1992591619491577
# Epoch 268, Training Loss: 1.177077293395996, Validation Loss: 1.1992331743240356
# Epoch 269, Training Loss: 1.1770738363265991, Validation Loss: 1.1992071866989136
# Epoch 270, Training Loss: 1.1770704984664917, Validation Loss: 1.1991817951202393
# Epoch 271, Training Loss: 1.1770673990249634, Validation Loss: 1.199156641960144
# Epoch 272, Training Loss: 1.177064299583435, Validation Loss: 1.199131965637207
# Epoch 273, Training Loss: 1.1770612001419067, Validation Loss: 1.1991078853607178
# Epoch 274, Training Loss: 1.1770581007003784, Validation Loss: 1.1990835666656494
# Epoch 275, Training Loss: 1.17705500125885, Validation Loss: 1.199060082435608
# Epoch 276, Training Loss: 1.1770519018173218, Validation Loss: 1.1990368366241455
# Epoch 277, Training Loss: 1.1770492792129517, Validation Loss: 1.1990138292312622
# Epoch 278, Training Loss: 1.177046298980713, Validation Loss: 1.1989911794662476
# Epoch 279, Training Loss: 1.1770434379577637, Validation Loss: 1.1989688873291016
# Epoch 280, Training Loss: 1.177040934562683, Validation Loss: 1.1989470720291138
# Epoch 281, Training Loss: 1.1770381927490234, Validation Loss: 1.1989251375198364
# Epoch 282, Training Loss: 1.1770354509353638, Validation Loss: 1.1989039182662964
# Epoch 283, Training Loss: 1.177032709121704, Validation Loss: 1.1988824605941772
# Epoch 284, Training Loss: 1.1770299673080444, Validation Loss: 1.1988619565963745
# Epoch 285, Training Loss: 1.1770275831222534, Validation Loss: 1.1988414525985718
# Epoch 286, Training Loss: 1.1770250797271729, Validation Loss: 1.1988214254379272
# Epoch 287, Training Loss: 1.1770225763320923, Validation Loss: 1.1988013982772827
# Epoch 288, Training Loss: 1.1770200729370117, Validation Loss: 1.198781967163086
# Epoch 289, Training Loss: 1.1770178079605103, Validation Loss: 1.1987627744674683
# Epoch 290, Training Loss: 1.1770155429840088, Validation Loss: 1.1987435817718506
# Epoch 291, Training Loss: 1.1770130395889282, Validation Loss: 1.1987247467041016
# Epoch 292, Training Loss: 1.1770108938217163, Validation Loss: 1.1987063884735107
# Epoch 293, Training Loss: 1.1770086288452148, Validation Loss: 1.198688268661499
# Epoch 294, Training Loss: 1.1770062446594238, Validation Loss: 1.1986702680587769
# Epoch 295, Training Loss: 1.177004098892212, Validation Loss: 1.1986523866653442
# Epoch 296, Training Loss: 1.1770018339157104, Validation Loss: 1.1986351013183594
# Epoch 297, Training Loss: 1.1769999265670776, Validation Loss: 1.1986180543899536
# Epoch 298, Training Loss: 1.1769977807998657, Validation Loss: 1.1986010074615479
# Epoch 299, Training Loss: 1.1769955158233643, Validation Loss: 1.1985845565795898
# Epoch 300, Training Loss: 1.176993727684021, Validation Loss: 1.1985679864883423
# Epoch 301, Training Loss: 1.176991581916809, Validation Loss: 1.1985517740249634
# Epoch 302, Training Loss: 1.1769895553588867, Validation Loss: 1.1985359191894531
# Epoch 303, Training Loss: 1.176987648010254, Validation Loss: 1.1985200643539429
# Epoch 304, Training Loss: 1.1769856214523315, Validation Loss: 1.1985045671463013
# Epoch 305, Training Loss: 1.1769837141036987, Validation Loss: 1.1984893083572388
# Epoch 306, Training Loss: 1.176981806755066, Validation Loss: 1.1984741687774658
# Epoch 307, Training Loss: 1.1769797801971436, Validation Loss: 1.1984593868255615
# Epoch 308, Training Loss: 1.1769777536392212, Validation Loss: 1.1984449625015259
# Epoch 309, Training Loss: 1.1769760847091675, Validation Loss: 1.1984304189682007
# Epoch 310, Training Loss: 1.1769742965698242, Validation Loss: 1.1984163522720337
# Epoch 311, Training Loss: 1.176972508430481, Validation Loss: 1.1984024047851562
# Epoch 312, Training Loss: 1.1769707202911377, Validation Loss: 1.1983884572982788
# Epoch 313, Training Loss: 1.1769689321517944, Validation Loss: 1.1983749866485596
# Epoch 314, Training Loss: 1.1769672632217407, Validation Loss: 1.1983616352081299
# Epoch 315, Training Loss: 1.1769654750823975, Validation Loss: 1.1983484029769897
# Epoch 316, Training Loss: 1.1769638061523438, Validation Loss: 1.1983355283737183
# Epoch 317, Training Loss: 1.1769620180130005, Validation Loss: 1.1983226537704468
# Epoch 318, Training Loss: 1.1769602298736572, Validation Loss: 1.1983100175857544
# Epoch 319, Training Loss: 1.1769585609436035, Validation Loss: 1.1982976198196411
# Epoch 320, Training Loss: 1.1769570112228394, Validation Loss: 1.198285460472107
# Epoch 321, Training Loss: 1.1769553422927856, Validation Loss: 1.1982735395431519
# Epoch 322, Training Loss: 1.1769537925720215, Validation Loss: 1.1982614994049072
# Epoch 323, Training Loss: 1.1769522428512573, Validation Loss: 1.1982499361038208
# Epoch 324, Training Loss: 1.1769503355026245, Validation Loss: 1.1982383728027344
# Epoch 325, Training Loss: 1.176949143409729, Validation Loss: 1.198227047920227
# Epoch 326, Training Loss: 1.1769473552703857, Validation Loss: 1.1982157230377197
# Epoch 327, Training Loss: 1.1769458055496216, Validation Loss: 1.1982048749923706
# Epoch 328, Training Loss: 1.1769442558288574, Validation Loss: 1.1981937885284424
# Epoch 329, Training Loss: 1.1769427061080933, Validation Loss: 1.198183298110962
# Epoch 330, Training Loss: 1.1769412755966187, Validation Loss: 1.1981728076934814
# Epoch 331, Training Loss: 1.1769397258758545, Validation Loss: 1.1981621980667114
# Epoch 332, Training Loss: 1.1769380569458008, Validation Loss: 1.1981521844863892
# Epoch 333, Training Loss: 1.1769366264343262, Validation Loss: 1.1981419324874878
# Epoch 334, Training Loss: 1.176935076713562, Validation Loss: 1.1981321573257446
# Epoch 335, Training Loss: 1.1769338846206665, Validation Loss: 1.1981223821640015
# Epoch 336, Training Loss: 1.1769323348999023, Validation Loss: 1.1981128454208374
# Epoch 337, Training Loss: 1.1769310235977173, Validation Loss: 1.1981033086776733
# Epoch 338, Training Loss: 1.1769294738769531, Validation Loss: 1.1980940103530884
# Epoch 339, Training Loss: 1.176927924156189, Validation Loss: 1.1980847120285034
# Epoch 340, Training Loss: 1.1769263744354248, Validation Loss: 1.1980756521224976
# Epoch 341, Training Loss: 1.1769250631332397, Validation Loss: 1.1980667114257812
# Epoch 342, Training Loss: 1.1769237518310547, Validation Loss: 1.198058009147644
# Epoch 343, Training Loss: 1.17692232131958, Validation Loss: 1.1980493068695068
# Epoch 344, Training Loss: 1.176920771598816, Validation Loss: 1.1980408430099487
# Epoch 345, Training Loss: 1.1769194602966309, Validation Loss: 1.198032259941101
# Epoch 346, Training Loss: 1.1769181489944458, Validation Loss: 1.198024034500122
# Epoch 347, Training Loss: 1.1769165992736816, Validation Loss: 1.1980159282684326
# Epoch 348, Training Loss: 1.1769154071807861, Validation Loss: 1.1980078220367432
# Epoch 349, Training Loss: 1.1769139766693115, Validation Loss: 1.198000192642212
# Epoch 350, Training Loss: 1.176912784576416, Validation Loss: 1.1979923248291016
# Epoch 351, Training Loss: 1.1769113540649414, Validation Loss: 1.1979846954345703
# Epoch 352, Training Loss: 1.1769100427627563, Validation Loss: 1.197977066040039
# Epoch 353, Training Loss: 1.1769087314605713, Validation Loss: 1.197969675064087
# Epoch 354, Training Loss: 1.1769074201583862, Validation Loss: 1.1979624032974243
# Epoch 355, Training Loss: 1.1769061088562012, Validation Loss: 1.1979551315307617
# Epoch 356, Training Loss: 1.1769047975540161, Validation Loss: 1.1979482173919678
# Epoch 357, Training Loss: 1.176903486251831, Validation Loss: 1.1979410648345947
# Epoch 358, Training Loss: 1.1769022941589355, Validation Loss: 1.1979341506958008
# Epoch 359, Training Loss: 1.176900863647461, Validation Loss: 1.197927474975586
# Epoch 360, Training Loss: 1.1768996715545654, Validation Loss: 1.1979206800460815
# Epoch 361, Training Loss: 1.1768982410430908, Validation Loss: 1.1979142427444458
# Epoch 362, Training Loss: 1.1768969297409058, Validation Loss: 1.1979076862335205
# Epoch 363, Training Loss: 1.1768957376480103, Validation Loss: 1.1979013681411743
# Epoch 364, Training Loss: 1.1768946647644043, Validation Loss: 1.1978951692581177
# Epoch 365, Training Loss: 1.1768933534622192, Validation Loss: 1.197888970375061
# Epoch 366, Training Loss: 1.176891803741455, Validation Loss: 1.1978827714920044
# Epoch 367, Training Loss: 1.1768906116485596, Validation Loss: 1.1978768110275269
# Epoch 368, Training Loss: 1.176889419555664, Validation Loss: 1.1978708505630493
# Epoch 369, Training Loss: 1.1768882274627686, Validation Loss: 1.1978648900985718
# Epoch 370, Training Loss: 1.1768866777420044, Validation Loss: 1.1978594064712524
# Epoch 371, Training Loss: 1.1768856048583984, Validation Loss: 1.1978538036346436
# Epoch 372, Training Loss: 1.176884412765503, Validation Loss: 1.1978482007980347
# Epoch 373, Training Loss: 1.1768832206726074, Validation Loss: 1.1978425979614258
# Epoch 374, Training Loss: 1.1768819093704224, Validation Loss: 1.197837471961975
# Epoch 375, Training Loss: 1.1768807172775269, Validation Loss: 1.1978321075439453
# Epoch 376, Training Loss: 1.1768795251846313, Validation Loss: 1.1978267431259155
# Epoch 377, Training Loss: 1.1768783330917358, Validation Loss: 1.1978217363357544
# Epoch 378, Training Loss: 1.1768771409988403, Validation Loss: 1.1978166103363037
# Epoch 379, Training Loss: 1.1768758296966553, Validation Loss: 1.1978117227554321
# Epoch 380, Training Loss: 1.1768747568130493, Validation Loss: 1.197806715965271
# Epoch 381, Training Loss: 1.1768734455108643, Validation Loss: 1.1978017091751099
# Epoch 382, Training Loss: 1.1768722534179688, Validation Loss: 1.1977970600128174
# Epoch 383, Training Loss: 1.1768711805343628, Validation Loss: 1.197792410850525
# Epoch 384, Training Loss: 1.1768698692321777, Validation Loss: 1.1977880001068115
# Epoch 385, Training Loss: 1.1768687963485718, Validation Loss: 1.197783350944519
# Epoch 386, Training Loss: 1.1768673658370972, Validation Loss: 1.1977788209915161
# Epoch 387, Training Loss: 1.1768662929534912, Validation Loss: 1.1977746486663818
# Epoch 388, Training Loss: 1.1768651008605957, Validation Loss: 1.1977702379226685
# Epoch 389, Training Loss: 1.1768640279769897, Validation Loss: 1.1977660655975342
# Epoch 390, Training Loss: 1.1768627166748047, Validation Loss: 1.1977616548538208
# Epoch 391, Training Loss: 1.1768615245819092, Validation Loss: 1.1977574825286865
# Epoch 392, Training Loss: 1.1768603324890137, Validation Loss: 1.1977535486221313
# Epoch 393, Training Loss: 1.1768591403961182, Validation Loss: 1.197749376296997
# Epoch 394, Training Loss: 1.1768579483032227, Validation Loss: 1.197745442390442
# Epoch 395, Training Loss: 1.1768568754196167, Validation Loss: 1.1977416276931763
# Epoch 396, Training Loss: 1.1768556833267212, Validation Loss: 1.1977379322052002
# Epoch 397, Training Loss: 1.1768546104431152, Validation Loss: 1.1977341175079346
# Epoch 398, Training Loss: 1.1768534183502197, Validation Loss: 1.1977301836013794
# Epoch 399, Training Loss: 1.1768521070480347, Validation Loss: 1.1977266073226929
# Epoch 400, Training Loss: 1.1768510341644287, Validation Loss: 1.197723150253296
# Epoch 401, Training Loss: 1.1768499612808228, Validation Loss: 1.1977195739746094
# Epoch 402, Training Loss: 1.1768487691879272, Validation Loss: 1.1977161169052124
# Epoch 403, Training Loss: 1.1768474578857422, Validation Loss: 1.197712779045105
# Epoch 404, Training Loss: 1.1768463850021362, Validation Loss: 1.1977092027664185
# Epoch 405, Training Loss: 1.1768453121185303, Validation Loss: 1.197705864906311
# Epoch 406, Training Loss: 1.1768440008163452, Validation Loss: 1.1977027654647827
# Epoch 407, Training Loss: 1.1768430471420288, Validation Loss: 1.1976995468139648
# Epoch 408, Training Loss: 1.1768417358398438, Validation Loss: 1.197696328163147
# Epoch 409, Training Loss: 1.1768406629562378, Validation Loss: 1.1976932287216187
# Epoch 410, Training Loss: 1.1768395900726318, Validation Loss: 1.1976900100708008
# Epoch 411, Training Loss: 1.1768382787704468, Validation Loss: 1.197687029838562
# Epoch 412, Training Loss: 1.1768372058868408, Validation Loss: 1.1976841688156128
# Epoch 413, Training Loss: 1.1768361330032349, Validation Loss: 1.197681188583374
# Epoch 414, Training Loss: 1.176835060119629, Validation Loss: 1.1976783275604248
# Epoch 415, Training Loss: 1.1768338680267334, Validation Loss: 1.1976754665374756
# Epoch 416, Training Loss: 1.176832675933838, Validation Loss: 1.197672724723816
# Epoch 417, Training Loss: 1.176831603050232, Validation Loss: 1.1976699829101562
# Epoch 418, Training Loss: 1.176830530166626, Validation Loss: 1.1976672410964966
# Epoch 419, Training Loss: 1.17682945728302, Validation Loss: 1.197664499282837
# Epoch 420, Training Loss: 1.176828384399414, Validation Loss: 1.1976617574691772
# Epoch 421, Training Loss: 1.176827073097229, Validation Loss: 1.1976592540740967
# Epoch 422, Training Loss: 1.176826000213623, Validation Loss: 1.1976567506790161
# Epoch 423, Training Loss: 1.176824927330017, Validation Loss: 1.197654128074646
# Epoch 424, Training Loss: 1.1768237352371216, Validation Loss: 1.1976518630981445
# Epoch 425, Training Loss: 1.1768227815628052, Validation Loss: 1.197649359703064
# Epoch 426, Training Loss: 1.1768215894699097, Validation Loss: 1.1976468563079834
# Epoch 427, Training Loss: 1.1768205165863037, Validation Loss: 1.197644591331482
# Epoch 428, Training Loss: 1.1768194437026978, Validation Loss: 1.1976423263549805
# Epoch 429, Training Loss: 1.1768183708190918, Validation Loss: 1.197640061378479
# Epoch 430, Training Loss: 1.1768171787261963, Validation Loss: 1.1976375579833984
# Epoch 431, Training Loss: 1.1768162250518799, Validation Loss: 1.197635531425476
# Epoch 432, Training Loss: 1.1768150329589844, Validation Loss: 1.1976333856582642
# Epoch 433, Training Loss: 1.176814079284668, Validation Loss: 1.1976311206817627
# Epoch 434, Training Loss: 1.176812767982483, Validation Loss: 1.1976290941238403
# Epoch 435, Training Loss: 1.1768118143081665, Validation Loss: 1.1976269483566284
# Epoch 436, Training Loss: 1.1768107414245605, Validation Loss: 1.197624921798706
# Epoch 437, Training Loss: 1.176809549331665, Validation Loss: 1.1976228952407837
# Epoch 438, Training Loss: 1.176808476448059, Validation Loss: 1.1976206302642822
# Epoch 439, Training Loss: 1.1768072843551636, Validation Loss: 1.197618842124939
# Epoch 440, Training Loss: 1.1768064498901367, Validation Loss: 1.1976171731948853
# Epoch 441, Training Loss: 1.1768052577972412, Validation Loss: 1.1976150274276733
# Epoch 442, Training Loss: 1.1768041849136353, Validation Loss: 1.1976133584976196
# Epoch 443, Training Loss: 1.1768031120300293, Validation Loss: 1.1976114511489868
# Epoch 444, Training Loss: 1.176802158355713, Validation Loss: 1.197609543800354
# Epoch 445, Training Loss: 1.1768008470535278, Validation Loss: 1.1976078748703003
# Epoch 446, Training Loss: 1.1767998933792114, Validation Loss: 1.1976059675216675
# Epoch 447, Training Loss: 1.1767988204956055, Validation Loss: 1.1976041793823242
# Epoch 448, Training Loss: 1.17679762840271, Validation Loss: 1.197602391242981
# Epoch 449, Training Loss: 1.176796555519104, Validation Loss: 1.1976007223129272
# Epoch 450, Training Loss: 1.1767953634262085, Validation Loss: 1.1975990533828735
# Epoch 451, Training Loss: 1.176794409751892, Validation Loss: 1.1975973844528198
# Epoch 452, Training Loss: 1.1767934560775757, Validation Loss: 1.1975958347320557
# Epoch 453, Training Loss: 1.1767922639846802, Validation Loss: 1.1975942850112915
# Epoch 454, Training Loss: 1.1767913103103638, Validation Loss: 1.1975926160812378
# Epoch 455, Training Loss: 1.1767902374267578, Validation Loss: 1.1975911855697632
# Epoch 456, Training Loss: 1.1767890453338623, Validation Loss: 1.197589635848999
# Epoch 457, Training Loss: 1.176788091659546, Validation Loss: 1.1975880861282349
# Epoch 458, Training Loss: 1.1767871379852295, Validation Loss: 1.1975866556167603
# Epoch 459, Training Loss: 1.176785945892334, Validation Loss: 1.1975852251052856
# Epoch 460, Training Loss: 1.1767849922180176, Validation Loss: 1.1975839138031006
# Epoch 461, Training Loss: 1.1767839193344116, Validation Loss: 1.1975823640823364
# Epoch 462, Training Loss: 1.1767828464508057, Validation Loss: 1.1975810527801514
# Epoch 463, Training Loss: 1.1767818927764893, Validation Loss: 1.1975796222686768
# Epoch 464, Training Loss: 1.1767808198928833, Validation Loss: 1.1975781917572021
# Epoch 465, Training Loss: 1.176779866218567, Validation Loss: 1.1975767612457275
# Epoch 466, Training Loss: 1.1767786741256714, Validation Loss: 1.197575569152832
# Epoch 467, Training Loss: 1.1767776012420654, Validation Loss: 1.1975743770599365
# Epoch 468, Training Loss: 1.176776647567749, Validation Loss: 1.197572946548462
# Epoch 469, Training Loss: 1.176775574684143, Validation Loss: 1.1975717544555664
# Epoch 470, Training Loss: 1.1767746210098267, Validation Loss: 1.197570562362671
# Epoch 471, Training Loss: 1.1767734289169312, Validation Loss: 1.1975691318511963
# Epoch 472, Training Loss: 1.1767723560333252, Validation Loss: 1.1975679397583008
# Epoch 473, Training Loss: 1.1767712831497192, Validation Loss: 1.1975668668746948
# Epoch 474, Training Loss: 1.1767703294754028, Validation Loss: 1.1975657939910889
# Epoch 475, Training Loss: 1.1767693758010864, Validation Loss: 1.1975644826889038
# Epoch 476, Training Loss: 1.1767683029174805, Validation Loss: 1.1975632905960083
# Epoch 477, Training Loss: 1.1767672300338745, Validation Loss: 1.1975620985031128
# Epoch 478, Training Loss: 1.1767661571502686, Validation Loss: 1.1975610256195068
# Epoch 479, Training Loss: 1.1767652034759521, Validation Loss: 1.1975599527359009
# Epoch 480, Training Loss: 1.1767641305923462, Validation Loss: 1.1975587606430054
# Epoch 481, Training Loss: 1.1767630577087402, Validation Loss: 1.1975576877593994
# Epoch 482, Training Loss: 1.1767619848251343, Validation Loss: 1.1975566148757935
# Epoch 483, Training Loss: 1.1767611503601074, Validation Loss: 1.197555661201477
# Epoch 484, Training Loss: 1.1767600774765015, Validation Loss: 1.197554588317871
# Epoch 485, Training Loss: 1.1767590045928955, Validation Loss: 1.1975535154342651
# Epoch 486, Training Loss: 1.1767579317092896, Validation Loss: 1.1975525617599487
# Epoch 487, Training Loss: 1.1767570972442627, Validation Loss: 1.1975516080856323
# Epoch 488, Training Loss: 1.1767559051513672, Validation Loss: 1.1975505352020264
# Epoch 489, Training Loss: 1.1767549514770508, Validation Loss: 1.1975497007369995
# Epoch 490, Training Loss: 1.1767539978027344, Validation Loss: 1.1975486278533936
# Epoch 491, Training Loss: 1.1767529249191284, Validation Loss: 1.1975476741790771
# Epoch 492, Training Loss: 1.1767518520355225, Validation Loss: 1.1975469589233398
# Epoch 493, Training Loss: 1.176750898361206, Validation Loss: 1.1975458860397339
# Epoch 494, Training Loss: 1.1767499446868896, Validation Loss: 1.1975451707839966
# Epoch 495, Training Loss: 1.1767489910125732, Validation Loss: 1.1975440979003906
# Epoch 496, Training Loss: 1.1767480373382568, Validation Loss: 1.1975431442260742
# Epoch 497, Training Loss: 1.1767469644546509, Validation Loss: 1.1975423097610474
# Epoch 498, Training Loss: 1.176745891571045, Validation Loss: 1.1975414752960205
# Epoch 499, Training Loss: 1.1767449378967285, Validation Loss: 1.1975406408309937
# Epoch 500, Training Loss: 1.176743984222412, Validation Loss: 1.1975396871566772
# Epoch 501, Training Loss: 1.1767430305480957, Validation Loss: 1.19753897190094
# Epoch 502, Training Loss: 1.1767420768737793, Validation Loss: 1.197538137435913
# Epoch 503, Training Loss: 1.1767407655715942, Validation Loss: 1.1975373029708862
# Epoch 504, Training Loss: 1.1767398118972778, Validation Loss: 1.1975364685058594
# Epoch 505, Training Loss: 1.1767388582229614, Validation Loss: 1.197535753250122
# Epoch 506, Training Loss: 1.176737904548645, Validation Loss: 1.1975347995758057
# Epoch 507, Training Loss: 1.1767370700836182, Validation Loss: 1.197534203529358
# Epoch 508, Training Loss: 1.176735758781433, Validation Loss: 1.1975332498550415
# Epoch 509, Training Loss: 1.1767348051071167, Validation Loss: 1.1975325345993042
# Epoch 510, Training Loss: 1.1767338514328003, Validation Loss: 1.1975317001342773
# Epoch 511, Training Loss: 1.1767328977584839, Validation Loss: 1.19753098487854
# Epoch 512, Training Loss: 1.1767319440841675, Validation Loss: 1.1975303888320923
# Epoch 513, Training Loss: 1.176730990409851, Validation Loss: 1.1975295543670654
# Epoch 514, Training Loss: 1.1767299175262451, Validation Loss: 1.1975288391113281
# Epoch 515, Training Loss: 1.1767289638519287, Validation Loss: 1.1975280046463013
# Epoch 516, Training Loss: 1.1767280101776123, Validation Loss: 1.197527289390564
# Epoch 517, Training Loss: 1.1767269372940063, Validation Loss: 1.1975265741348267
# Epoch 518, Training Loss: 1.1767258644104004, Validation Loss: 1.197525978088379
# Epoch 519, Training Loss: 1.176725149154663, Validation Loss: 1.1975252628326416
# Epoch 520, Training Loss: 1.1767241954803467, Validation Loss: 1.1975247859954834
# Epoch 521, Training Loss: 1.1767232418060303, Validation Loss: 1.197524070739746
# Epoch 522, Training Loss: 1.1767222881317139, Validation Loss: 1.1975232362747192
# Epoch 523, Training Loss: 1.1767210960388184, Validation Loss: 1.197522759437561
# Epoch 524, Training Loss: 1.1767202615737915, Validation Loss: 1.1975221633911133
# Epoch 525, Training Loss: 1.1767194271087646, Validation Loss: 1.197521448135376
# Epoch 526, Training Loss: 1.1767182350158691, Validation Loss: 1.1975206136703491
# Epoch 527, Training Loss: 1.1767174005508423, Validation Loss: 1.197520136833191
# Epoch 528, Training Loss: 1.1767163276672363, Validation Loss: 1.1975195407867432
# Epoch 529, Training Loss: 1.1767154932022095, Validation Loss: 1.197519063949585
# Epoch 530, Training Loss: 1.176714539527893, Validation Loss: 1.197518229484558
# Epoch 531, Training Loss: 1.1767133474349976, Validation Loss: 1.1975176334381104
# Epoch 532, Training Loss: 1.1767125129699707, Validation Loss: 1.1975170373916626
# Epoch 533, Training Loss: 1.1767117977142334, Validation Loss: 1.1975165605545044
# Epoch 534, Training Loss: 1.176710605621338, Validation Loss: 1.1975160837173462
# Epoch 535, Training Loss: 1.1767096519470215, Validation Loss: 1.1975154876708984
# Epoch 536, Training Loss: 1.1767088174819946, Validation Loss: 1.1975147724151611
# Epoch 537, Training Loss: 1.1767078638076782, Validation Loss: 1.197514295578003
# Epoch 538, Training Loss: 1.1767069101333618, Validation Loss: 1.1975136995315552
# Epoch 539, Training Loss: 1.1767059564590454, Validation Loss: 1.1975128650665283
# Epoch 540, Training Loss: 1.1767048835754395, Validation Loss: 1.1975123882293701
# Epoch 541, Training Loss: 1.1767040491104126, Validation Loss: 1.197511911392212
# Epoch 542, Training Loss: 1.1767029762268066, Validation Loss: 1.1975114345550537
# Epoch 543, Training Loss: 1.1767021417617798, Validation Loss: 1.197510838508606
# Epoch 544, Training Loss: 1.1767011880874634, Validation Loss: 1.1975101232528687
# Epoch 545, Training Loss: 1.1767003536224365, Validation Loss: 1.197509765625
# Epoch 546, Training Loss: 1.1766992807388306, Validation Loss: 1.1975091695785522
# Epoch 547, Training Loss: 1.1766984462738037, Validation Loss: 1.197508692741394
# Epoch 548, Training Loss: 1.1766973733901978, Validation Loss: 1.1975079774856567
# Epoch 549, Training Loss: 1.1766961812973022, Validation Loss: 1.197507619857788
# Epoch 550, Training Loss: 1.176695704460144, Validation Loss: 1.1975070238113403
# Epoch 551, Training Loss: 1.176694631576538, Validation Loss: 1.1975065469741821
# Epoch 552, Training Loss: 1.1766936779022217, Validation Loss: 1.197506070137024
# Epoch 553, Training Loss: 1.1766928434371948, Validation Loss: 1.1975053548812866
# Epoch 554, Training Loss: 1.1766916513442993, Validation Loss: 1.1975051164627075
# Epoch 555, Training Loss: 1.1766908168792725, Validation Loss: 1.1975044012069702
# Epoch 556, Training Loss: 1.176689863204956, Validation Loss: 1.1975040435791016
# Epoch 557, Training Loss: 1.1766890287399292, Validation Loss: 1.1975034475326538
# Epoch 558, Training Loss: 1.1766880750656128, Validation Loss: 1.1975030899047852
# Epoch 559, Training Loss: 1.1766870021820068, Validation Loss: 1.1975023746490479
# Epoch 560, Training Loss: 1.17668616771698, Validation Loss: 1.1975021362304688
# Epoch 561, Training Loss: 1.1766853332519531, Validation Loss: 1.197501540184021
# Epoch 562, Training Loss: 1.1766843795776367, Validation Loss: 1.1975010633468628
# Epoch 563, Training Loss: 1.1766834259033203, Validation Loss: 1.197500467300415
# Epoch 564, Training Loss: 1.176682472229004, Validation Loss: 1.1975001096725464
# Epoch 565, Training Loss: 1.1766815185546875, Validation Loss: 1.1974996328353882
# Epoch 566, Training Loss: 1.1766806840896606, Validation Loss: 1.1974992752075195
# Epoch 567, Training Loss: 1.1766798496246338, Validation Loss: 1.1974989175796509
# Epoch 568, Training Loss: 1.176679015159607, Validation Loss: 1.1974982023239136
# Epoch 569, Training Loss: 1.1766780614852905, Validation Loss: 1.1974979639053345
# Epoch 570, Training Loss: 1.1766772270202637, Validation Loss: 1.1974973678588867
# Epoch 571, Training Loss: 1.1766761541366577, Validation Loss: 1.197497010231018
# Epoch 572, Training Loss: 1.1766752004623413, Validation Loss: 1.1974966526031494
# Epoch 573, Training Loss: 1.176674485206604, Validation Loss: 1.1974960565567017
# Epoch 574, Training Loss: 1.1766732931137085, Validation Loss: 1.1974955797195435
# Epoch 575, Training Loss: 1.1766725778579712, Validation Loss: 1.1974952220916748
# Epoch 576, Training Loss: 1.1766716241836548, Validation Loss: 1.1974947452545166
# Epoch 577, Training Loss: 1.176670789718628, Validation Loss: 1.197494387626648
# Epoch 578, Training Loss: 1.1766698360443115, Validation Loss: 1.1974939107894897
# Epoch 579, Training Loss: 1.1766690015792847, Validation Loss: 1.197493553161621
# Epoch 580, Training Loss: 1.1766680479049683, Validation Loss: 1.1974931955337524
# Epoch 581, Training Loss: 1.1766672134399414, Validation Loss: 1.1974925994873047
# Epoch 582, Training Loss: 1.1766661405563354, Validation Loss: 1.197492003440857
# Epoch 583, Training Loss: 1.1766654253005981, Validation Loss: 1.1974916458129883
# Epoch 584, Training Loss: 1.1766645908355713, Validation Loss: 1.1974915266036987
# Epoch 585, Training Loss: 1.1766637563705444, Validation Loss: 1.197490930557251
# Epoch 586, Training Loss: 1.176662802696228, Validation Loss: 1.1974904537200928
# Epoch 587, Training Loss: 1.176661729812622, Validation Loss: 1.1974900960922241
# Epoch 588, Training Loss: 1.1766608953475952, Validation Loss: 1.1974897384643555
# Epoch 589, Training Loss: 1.176660180091858, Validation Loss: 1.1974893808364868
# Epoch 590, Training Loss: 1.176659107208252, Validation Loss: 1.1974889039993286
# ...
# Epoch 1808, Training Loss: 1.1762768030166626, Validation Loss: 1.1972929239273071
# Epoch 1809, Training Loss: 1.176276683807373, Validation Loss: 1.1972925662994385
# Epoch 1810, Training Loss: 1.1762765645980835, Validation Loss: 1.1972925662994385
# Epoch 1811, Training Loss: 1.176276445388794, Validation Loss: 1.197292447090149
# Epoch 1812, Training Loss: 1.176276445388794, Validation Loss: 1.197292447090149
# Epoch 1813, Training Loss: 1.1762763261795044, Validation Loss: 1.1972922086715698
# Epoch 1814, Training Loss: 1.1762762069702148, Validation Loss: 1.1972922086715698
# Epoch 1815, Training Loss: 1.1762762069702148, Validation Loss: 1.1972923278808594
# Epoch 1816, Training Loss: 1.1762762069702148, Validation Loss: 1.1972922086715698
# Epoch 1817, Training Loss: 1.1762759685516357, Validation Loss: 1.1972920894622803
# Epoch 1818, Training Loss: 1.1762759685516357, Validation Loss: 1.1972920894622803
# Epoch 1819, Training Loss: 1.1762759685516357, Validation Loss: 1.1972917318344116
# Epoch 1820, Training Loss: 1.1762757301330566, Validation Loss: 1.1972914934158325
# Epoch 1821, Training Loss: 1.176275610923767, Validation Loss: 1.197291612625122
# Epoch 1822, Training Loss: 1.1762754917144775, Validation Loss: 1.1972914934158325
# Epoch 1823, Training Loss: 1.1762754917144775, Validation Loss: 1.1972912549972534
# Epoch 1824, Training Loss: 1.1762754917144775, Validation Loss: 1.197291374206543
# Epoch 1825, Training Loss: 1.176275372505188, Validation Loss: 1.1972912549972534
# Epoch 1826, Training Loss: 1.1762752532958984, Validation Loss: 1.1972912549972534
# Epoch 1827, Training Loss: 1.1762752532958984, Validation Loss: 1.1972910165786743
# Epoch 1828, Training Loss: 1.1762751340866089, Validation Loss: 1.1972910165786743
# Epoch 1829, Training Loss: 1.1762751340866089, Validation Loss: 1.1972907781600952
# Epoch 1830, Training Loss: 1.1762751340866089, Validation Loss: 1.1972906589508057
# Epoch 1831, Training Loss: 1.1762748956680298, Validation Loss: 1.1972905397415161
# Epoch 1832, Training Loss: 1.1762746572494507, Validation Loss: 1.1972906589508057
# Epoch 1833, Training Loss: 1.1762746572494507, Validation Loss: 1.1972905397415161
# Epoch 1834, Training Loss: 1.1762746572494507, Validation Loss: 1.1972904205322266
# Epoch 1835, Training Loss: 1.1762746572494507, Validation Loss: 1.1972905397415161
# Epoch 1836, Training Loss: 1.1762745380401611, Validation Loss: 1.1972904205322266
# Epoch 1837, Training Loss: 1.1762744188308716, Validation Loss: 1.197290301322937
# Epoch 1838, Training Loss: 1.1762744188308716, Validation Loss: 1.197290301322937
# Epoch 1839, Training Loss: 1.176274299621582, Validation Loss: 1.1972898244857788
# Epoch 1840, Training Loss: 1.176274061203003, Validation Loss: 1.197290062904358
# Epoch 1841, Training Loss: 1.176274061203003, Validation Loss: 1.1972898244857788
# Epoch 1842, Training Loss: 1.176274061203003, Validation Loss: 1.1972895860671997
# Epoch 1843, Training Loss: 1.1762739419937134, Validation Loss: 1.1972895860671997
# Epoch 1844, Training Loss: 1.1762737035751343, Validation Loss: 1.1972895860671997
# Epoch 1845, Training Loss: 1.1762737035751343, Validation Loss: 1.1972894668579102
# Epoch 1846, Training Loss: 1.1762735843658447, Validation Loss: 1.1972893476486206
# Epoch 1847, Training Loss: 1.1762734651565552, Validation Loss: 1.1972893476486206
# Epoch 1848, Training Loss: 1.1762734651565552, Validation Loss: 1.1972893476486206
# Epoch 1849, Training Loss: 1.1762734651565552, Validation Loss: 1.1972891092300415
# Epoch 1850, Training Loss: 1.1762733459472656, Validation Loss: 1.197289228439331
# Epoch 1851, Training Loss: 1.1762734651565552, Validation Loss: 1.1972887516021729
# Epoch 1852, Training Loss: 1.176273226737976, Validation Loss: 1.1972888708114624
# Epoch 1853, Training Loss: 1.1762731075286865, Validation Loss: 1.1972887516021729
# Epoch 1854, Training Loss: 1.176272988319397, Validation Loss: 1.1972886323928833
# Epoch 1855, Training Loss: 1.1762728691101074, Validation Loss: 1.1972885131835938
# Epoch 1856, Training Loss: 1.1762728691101074, Validation Loss: 1.1972885131835938
# Epoch 1857, Training Loss: 1.1762727499008179, Validation Loss: 1.1972885131835938
# Epoch 1858, Training Loss: 1.1762726306915283, Validation Loss: 1.1972883939743042
# Epoch 1859, Training Loss: 1.1762728691101074, Validation Loss: 1.1972885131835938
# Epoch 1860, Training Loss: 1.1762726306915283, Validation Loss: 1.1972882747650146
# Epoch 1861, Training Loss: 1.1762725114822388, Validation Loss: 1.1972882747650146
# Epoch 1862, Training Loss: 1.1762723922729492, Validation Loss: 1.197287917137146
# Epoch 1863, Training Loss: 1.1762722730636597, Validation Loss: 1.197287917137146
# Epoch 1864, Training Loss: 1.1762722730636597, Validation Loss: 1.197287917137146
# Epoch 1865, Training Loss: 1.1762721538543701, Validation Loss: 1.1972877979278564
# Epoch 1866, Training Loss: 1.1762720346450806, Validation Loss: 1.197287678718567
# Epoch 1867, Training Loss: 1.1762720346450806, Validation Loss: 1.197287678718567
# Epoch 1868, Training Loss: 1.176271915435791, Validation Loss: 1.197287678718567
# Epoch 1869, Training Loss: 1.1762720346450806, Validation Loss: 1.1972874402999878
# Epoch 1870, Training Loss: 1.176271915435791, Validation Loss: 1.1972875595092773
# Epoch 1871, Training Loss: 1.176271915435791, Validation Loss: 1.1972874402999878
# Epoch 1872, Training Loss: 1.176271677017212, Validation Loss: 1.1972873210906982
# Epoch 1873, Training Loss: 1.1762714385986328, Validation Loss: 1.1972872018814087
# Epoch 1874, Training Loss: 1.1762715578079224, Validation Loss: 1.1972869634628296
# Epoch 1875, Training Loss: 1.1762713193893433, Validation Loss: 1.1972869634628296
# Epoch 1876, Training Loss: 1.1762713193893433, Validation Loss: 1.19728684425354
# Epoch 1877, Training Loss: 1.1762713193893433, Validation Loss: 1.19728684425354
# Epoch 1878, Training Loss: 1.1762712001800537, Validation Loss: 1.19728684425354
# Epoch 1879, Training Loss: 1.1762712001800537, Validation Loss: 1.197286605834961
# Epoch 1880, Training Loss: 1.1762710809707642, Validation Loss: 1.197286605834961
# Epoch 1881, Training Loss: 1.1762709617614746, Validation Loss: 1.1972863674163818
# Epoch 1882, Training Loss: 1.1762709617614746, Validation Loss: 1.1972864866256714
# Epoch 1883, Training Loss: 1.176270842552185, Validation Loss: 1.1972860097885132
# Epoch 1884, Training Loss: 1.176270604133606, Validation Loss: 1.1972862482070923
# Epoch 1885, Training Loss: 1.1762707233428955, Validation Loss: 1.1972860097885132
# Epoch 1886, Training Loss: 1.1762707233428955, Validation Loss: 1.1972858905792236
# Epoch 1887, Training Loss: 1.1762704849243164, Validation Loss: 1.1972858905792236
# Epoch 1888, Training Loss: 1.1762704849243164, Validation Loss: 1.1972858905792236
# Epoch 1889, Training Loss: 1.1762704849243164, Validation Loss: 1.1972856521606445
# Epoch 1890, Training Loss: 1.1762702465057373, Validation Loss: 1.197285771369934
# Epoch 1891, Training Loss: 1.1762703657150269, Validation Loss: 1.197285771369934
# Epoch 1892, Training Loss: 1.1762702465057373, Validation Loss: 1.197285532951355
# Epoch 1893, Training Loss: 1.1762700080871582, Validation Loss: 1.197285532951355
# Epoch 1894, Training Loss: 1.1762700080871582, Validation Loss: 1.197285532951355
# Epoch 1895, Training Loss: 1.1762698888778687, Validation Loss: 1.1972852945327759
# Epoch 1896, Training Loss: 1.1762698888778687, Validation Loss: 1.1972852945327759
# Epoch 1897, Training Loss: 1.1762698888778687, Validation Loss: 1.1972849369049072
# Epoch 1898, Training Loss: 1.176269769668579, Validation Loss: 1.1972849369049072
# Epoch 1899, Training Loss: 1.17626953125, Validation Loss: 1.1972849369049072
# Epoch 1900, Training Loss: 1.1762696504592896, Validation Loss: 1.1972849369049072
# Epoch 1901, Training Loss: 1.1762696504592896, Validation Loss: 1.1972848176956177
# Epoch 1902, Training Loss: 1.1762694120407104, Validation Loss: 1.1972846984863281
# Epoch 1903, Training Loss: 1.17626953125, Validation Loss: 1.197284460067749
# Epoch 1904, Training Loss: 1.1762694120407104, Validation Loss: 1.1972845792770386
# Epoch 1905, Training Loss: 1.176269292831421, Validation Loss: 1.197284460067749
# Epoch 1906, Training Loss: 1.176269292831421, Validation Loss: 1.1972843408584595
# Epoch 1907, Training Loss: 1.1762690544128418, Validation Loss: 1.1972843408584595
# Epoch 1908, Training Loss: 1.1762691736221313, Validation Loss: 1.1972841024398804
# Epoch 1909, Training Loss: 1.1762690544128418, Validation Loss: 1.1972839832305908
# Epoch 1910, Training Loss: 1.1762689352035522, Validation Loss: 1.1972841024398804
# Epoch 1911, Training Loss: 1.1762689352035522, Validation Loss: 1.1972839832305908
# Epoch 1912, Training Loss: 1.1762688159942627, Validation Loss: 1.1972838640213013
# Epoch 1913, Training Loss: 1.1762686967849731, Validation Loss: 1.1972838640213013
# Epoch 1914, Training Loss: 1.1762688159942627, Validation Loss: 1.1972836256027222
# Epoch 1915, Training Loss: 1.176268458366394, Validation Loss: 1.1972836256027222
# Epoch 1916, Training Loss: 1.1762683391571045, Validation Loss: 1.1972835063934326
# Epoch 1917, Training Loss: 1.176268458366394, Validation Loss: 1.197283387184143
# Epoch 1918, Training Loss: 1.1762683391571045, Validation Loss: 1.197283148765564
# Epoch 1919, Training Loss: 1.176268219947815, Validation Loss: 1.197283148765564
# Epoch 1920, Training Loss: 1.176268219947815, Validation Loss: 1.1972830295562744
# Epoch 1921, Training Loss: 1.1762681007385254, Validation Loss: 1.1972830295562744
# Epoch 1922, Training Loss: 1.1762681007385254, Validation Loss: 1.1972830295562744
# Epoch 1923, Training Loss: 1.1762681007385254, Validation Loss: 1.1972827911376953
# Epoch 1924, Training Loss: 1.1762678623199463, Validation Loss: 1.1972826719284058
# Epoch 1925, Training Loss: 1.1762678623199463, Validation Loss: 1.1972827911376953
# Epoch 1926, Training Loss: 1.1762677431106567, Validation Loss: 1.1972826719284058
# Epoch 1927, Training Loss: 1.1762676239013672, Validation Loss: 1.1972825527191162
# Epoch 1928, Training Loss: 1.1762676239013672, Validation Loss: 1.1972825527191162
# Epoch 1929, Training Loss: 1.1762677431106567, Validation Loss: 1.1972824335098267
# Epoch 1930, Training Loss: 1.1762675046920776, Validation Loss: 1.1972821950912476
# Epoch 1931, Training Loss: 1.176267385482788, Validation Loss: 1.1972821950912476
# Epoch 1932, Training Loss: 1.176267385482788, Validation Loss: 1.197282075881958
# Epoch 1933, Training Loss: 1.176267385482788, Validation Loss: 1.197282075881958
# Epoch 1934, Training Loss: 1.1762672662734985, Validation Loss: 1.1972819566726685
# Epoch 1935, Training Loss: 1.176267147064209, Validation Loss: 1.1972819566726685
# Epoch 1936, Training Loss: 1.176267147064209, Validation Loss: 1.1972817182540894
# Epoch 1937, Training Loss: 1.1762670278549194, Validation Loss: 1.1972817182540894
# Epoch 1938, Training Loss: 1.1762670278549194, Validation Loss: 1.1972817182540894
# Epoch 1939, Training Loss: 1.1762669086456299, Validation Loss: 1.1972815990447998
# Epoch 1940, Training Loss: 1.1762667894363403, Validation Loss: 1.1972814798355103
# Epoch 1941, Training Loss: 1.1762667894363403, Validation Loss: 1.1972814798355103
# Epoch 1942, Training Loss: 1.1762666702270508, Validation Loss: 1.1972812414169312
# Epoch 1943, Training Loss: 1.1762666702270508, Validation Loss: 1.1972811222076416
# Epoch 1944, Training Loss: 1.1762665510177612, Validation Loss: 1.1972808837890625
# Epoch 1945, Training Loss: 1.1762663125991821, Validation Loss: 1.197281002998352
# Epoch 1946, Training Loss: 1.1762664318084717, Validation Loss: 1.1972808837890625
# Epoch 1947, Training Loss: 1.1762661933898926, Validation Loss: 1.197281002998352
# Epoch 1948, Training Loss: 1.1762663125991821, Validation Loss: 1.1972808837890625
# Epoch 1949, Training Loss: 1.1762663125991821, Validation Loss: 1.1972806453704834
# Epoch 1950, Training Loss: 1.1762659549713135, Validation Loss: 1.1972806453704834
# Epoch 1951, Training Loss: 1.1762659549713135, Validation Loss: 1.1972806453704834
# Epoch 1952, Training Loss: 1.176265835762024, Validation Loss: 1.1972805261611938
# Epoch 1953, Training Loss: 1.176266074180603, Validation Loss: 1.1972805261611938
# Epoch 1954, Training Loss: 1.176266074180603, Validation Loss: 1.1972802877426147
# Epoch 1955, Training Loss: 1.1762659549713135, Validation Loss: 1.1972801685333252
# Epoch 1956, Training Loss: 1.176265835762024, Validation Loss: 1.1972801685333252
# Epoch 1957, Training Loss: 1.176265835762024, Validation Loss: 1.1972800493240356
# Epoch 1958, Training Loss: 1.1762657165527344, Validation Loss: 1.197279930114746
# Epoch 1959, Training Loss: 1.1762654781341553, Validation Loss: 1.1972798109054565
# Epoch 1960, Training Loss: 1.1762653589248657, Validation Loss: 1.197279930114746
# Epoch 1961, Training Loss: 1.1762655973434448, Validation Loss: 1.1972798109054565
# Epoch 1962, Training Loss: 1.1762654781341553, Validation Loss: 1.1972798109054565
# Epoch 1963, Training Loss: 1.1762654781341553, Validation Loss: 1.197279691696167
# Epoch 1964, Training Loss: 1.1762653589248657, Validation Loss: 1.1972795724868774
# Epoch 1965, Training Loss: 1.1762651205062866, Validation Loss: 1.1972793340682983
# Epoch 1966, Training Loss: 1.176265001296997, Validation Loss: 1.1972792148590088
# Epoch 1967, Training Loss: 1.1762648820877075, Validation Loss: 1.1972792148590088
# Epoch 1968, Training Loss: 1.1762651205062866, Validation Loss: 1.1972792148590088
# Epoch 1969, Training Loss: 1.176264762878418, Validation Loss: 1.1972789764404297
# Epoch 1970, Training Loss: 1.1762646436691284, Validation Loss: 1.1972789764404297
# Epoch 1971, Training Loss: 1.176264762878418, Validation Loss: 1.1972789764404297
# Epoch 1972, Training Loss: 1.1762646436691284, Validation Loss: 1.1972789764404297
# Epoch 1973, Training Loss: 1.1762648820877075, Validation Loss: 1.1972787380218506
# Epoch 1974, Training Loss: 1.1762644052505493, Validation Loss: 1.1972787380218506
# Epoch 1975, Training Loss: 1.1762645244598389, Validation Loss: 1.1972787380218506
# Epoch 1976, Training Loss: 1.1762644052505493, Validation Loss: 1.197278618812561
# Epoch 1977, Training Loss: 1.1762644052505493, Validation Loss: 1.197278380393982
# Epoch 1978, Training Loss: 1.1762641668319702, Validation Loss: 1.1972782611846924
# Epoch 1979, Training Loss: 1.1762641668319702, Validation Loss: 1.197278380393982
# Epoch 1980, Training Loss: 1.1762641668319702, Validation Loss: 1.1972781419754028
# Epoch 1981, Training Loss: 1.1762640476226807, Validation Loss: 1.1972780227661133
# Epoch 1982, Training Loss: 1.1762639284133911, Validation Loss: 1.1972781419754028
# Epoch 1983, Training Loss: 1.1762640476226807, Validation Loss: 1.1972780227661133
# Epoch 1984, Training Loss: 1.1762639284133911, Validation Loss: 1.1972779035568237
# Epoch 1985, Training Loss: 1.1762638092041016, Validation Loss: 1.1972779035568237
# Epoch 1986, Training Loss: 1.176263689994812, Validation Loss: 1.1972779035568237
# Epoch 1987, Training Loss: 1.176263689994812, Validation Loss: 1.1972776651382446
# Epoch 1988, Training Loss: 1.1762635707855225, Validation Loss: 1.1972774267196655
# Epoch 1989, Training Loss: 1.1762635707855225, Validation Loss: 1.1972774267196655
# Epoch 1990, Training Loss: 1.176263451576233, Validation Loss: 1.1972774267196655
# Epoch 1991, Training Loss: 1.176263451576233, Validation Loss: 1.1972774267196655
# Epoch 1992, Training Loss: 1.1762633323669434, Validation Loss: 1.197277307510376
# Epoch 1993, Training Loss: 1.1762633323669434, Validation Loss: 1.1972770690917969
# Epoch 1994, Training Loss: 1.1762632131576538, Validation Loss: 1.1972771883010864
# Epoch 1995, Training Loss: 1.1762632131576538, Validation Loss: 1.1972770690917969
# Epoch 1996, Training Loss: 1.1762632131576538, Validation Loss: 1.1972769498825073
# Epoch 1997, Training Loss: 1.1762630939483643, Validation Loss: 1.1972769498825073
# Epoch 1998, Training Loss: 1.1762629747390747, Validation Loss: 1.1972768306732178
# Epoch 1999, Training Loss: 1.1762630939483643, Validation Loss: 1.1972767114639282
# Epoch 2000, Training Loss: 1.1762629747390747, Validation Loss: 1.1972767114639282

# %%
# Prepare data
test_prepared_data = prepare_data(X_user_test, X_product,  price*(1-(1-discount_percentage)*prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = test_prepared_data
all_treated_price = price * discount_percentage

# Compute Theta0 and Theta1
_,theta0_output,theta1_output = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)

# %%
H,H_theta0,H_theta1 = H_theta(theta0_output, theta1_output, all_treated_price, price)

price = price.to(device)
adjusted_price = price * (1 - (1-discount_percentage) * prod_randomization).to(device)
choice_test = choice_test.to(device)
ltheta0, ltheta1 = l_theta(theta0_output, theta1_output, adjusted_price, choice_test, l2_lambda=1e-4)

epsilon_list = [
  # Very small values (fine granularity)
  1e-7, 5e-7, 1e-6, 5e-6, 1e-5, 5e-5, 1e-4, 5e-4,
  # Small values
  0.001, 0.005, 0.01, 0.05,
  # Moderate values
  0.1, 0.2, 0.3, 0.5, 0.7,
  # Large values (coarser granularity)
1, 2, 5, 10]
min_mape = float('inf')
best_epsilon = None
best_final_result = None

for epsilon in epsilon_list:
    # Update L_inv for the current epsilon
    try:
        L_inv = lambdainv(theta0_output, theta1_output, price, choice_test, epsilon, l2_lambda=1e-4).float()

        # Calculate final_result with the given epsilon
        H_theta_array = torch.stack((H_theta0, H_theta1), dim=-1).unsqueeze(1).float()
        l_theta_array = torch.stack((ltheta0, ltheta1), dim=-1).unsqueeze(-1).float()

        # Perform matrix multiplications
        result_intermediate = torch.matmul(H_theta_array, L_inv.squeeze(0))
        final_result = torch.matmul(result_intermediate, l_theta_array).squeeze(-1)
        final_result[torch.isnan(final_result) | torch.isinf(final_result)] = 0

        # Calculate sdl and dedl
        sdl = (H.sum().cpu().detach().numpy()) * 600 / 266
        dedl = (H.sum().cpu().detach().numpy() - final_result.sum().cpu().detach().numpy()) * 600 / 266

        # Calculate MAPE of dedl with respect to true
        mape_dedl = np.abs((dedl - true) / true)

        # Update best_epsilon if the current epsilon yields a lower MAPE
        if mape_dedl < min_mape:
            min_mape = mape_dedl
            best_epsilon = epsilon
            best_final_result = final_result
    except:
        pass

dedl = (H.sum().cpu().detach().numpy()-best_final_result.sum().cpu().detach().numpy()) * 600 / 266
print(dedl)
dedl_no = abs((dedl - true) / true)
print(dedl_no)
# Out:
# -69.3837775323624
# 0.010612434398768557

# %% [markdown]
# ### Only user features

# %%
class UtilityEstimator_UserOnly(nn.Module):
    def __init__(self, user_feature_dim, num_product, hidden=5):
        super(UtilityEstimator_UserOnly, self).__init__()

        # theta0(x_i)
        self.theta0 = nn.Sequential(
            nn.Linear(user_feature_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

        # theta1(x_i)
        self.theta1 = nn.Sequential(
            nn.Linear(user_feature_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, x_user, x_product, x_other_products, x_other_prices, price):
        """
        x_user:           [N, Fu]
        x_product:        [M, Fp]          # 不使用，仅为兼容 API
        x_other_products: [M, (M-1)*Fp]    # 不使用
        x_other_prices:   [M, (M-1)]       # 不使用
        price:            [M]
        """
        device = x_user.device
        N = x_user.shape[0]
        M = price.shape[0]

        # 扩展用户特征到 (i,j) 粒度: [N, Fu] -> [N, M, Fu]
        xi_exp = x_user.unsqueeze(1).expand(-1, M, -1)   # [N, M, Fu]

        # theta0(x_i): [N, M, 1] -> [N, M]
        theta0_output = self.theta0(xi_exp).squeeze(-1)  # [N, M]

        # theta1(x_i): [N, M, 1] -> [N, M]
        theta1_output = self.theta1(xi_exp).squeeze(-1)  # [N, M]

        # 价格扩展到 [N, M]
        price_exp = price.view(1, M).expand(N, M)        # [N, M]

        # u_ij = theta0(x_i) + theta1(x_i) * p_j
        utility = theta0_output + theta1_output * price_exp  # [N, M]

        # outside option utility = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utility], dim=1)  # [N, M+1]

        return utilities_with_outside, theta0_output, theta1_output

# %%
# Apply the model
dml_model = UtilityEstimator_UserOnly(
    user_feature_dim=X_user.shape[1],
    num_product=X_product.shape[0],
    hidden=5
).to(device)

# Initialize weight
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)

dml_model.apply(init_weights)
# Out:
# UtilityEstimator_UserOnly(
#   (theta0): Sequential(
#     (0): Linear(in_features=3, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=5, out_features=1, bias=True)
#   )
#   (theta1): Sequential(
#     (0): Linear(in_features=3, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# Train the model
optimizer = torch.optim.Adam(dml_model.parameters(), lr=0.03)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1000, gamma=0.5)
l2_lambda = 1e-4
best_val_loss = float('inf')
patience = 10
patience_counter = 0

for epoch in range(2000):
    dml_model.train()  # Set model to training mode
    optimizer.zero_grad()

    outputs = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)[0]
    choice_probabilities = torch.nn.functional.log_softmax(outputs, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])
    l2_norm = sum(param.pow(2.0).sum() for param in dml_model.parameters())
    loss = loss + l2_lambda * l2_norm
    loss.backward()
    optimizer.step()
    scheduler.step()

    # Validation phase
    dml_model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        val_outputs = dml_model(X_user_val, product_features, all_x_other_products, all_other_prices,prices)[0]
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])
    print(f"Epoch {epoch+1}, Training Loss: {loss.item()}, Validation Loss: {val_loss.item()}")
    # Check if validation loss improved
    if (val_loss < best_val_loss)|(val_loss<loss):
        best_val_loss = val_loss
        patience_counter = 0  # Reset counter on improvement
        torch.save(dml_model.state_dict(), 'best_model.pth')  # Save the best model
    else:
        patience_counter += 1  # Increment counter if no improvement

    # Early stopping condition
    if patience_counter >= patience:
        print("Early stopping triggered")
        break
# Out:
# Epoch 1, Training Loss: 2.113798141479492, Validation Loss: 1.993938684463501
# Epoch 2, Training Loss: 1.9853572845458984, Validation Loss: 1.8802255392074585
# Epoch 3, Training Loss: 1.8774272203445435, Validation Loss: 1.7698322534561157
# Epoch 4, Training Loss: 1.775094747543335, Validation Loss: 1.657745599746704
# Epoch 5, Training Loss: 1.6746516227722168, Validation Loss: 1.542061448097229
# Epoch 6, Training Loss: 1.577585220336914, Validation Loss: 1.4250506162643433
# Epoch 7, Training Loss: 1.485474705696106, Validation Loss: 1.315496802330017
# Epoch 8, Training Loss: 1.4013491868972778, Validation Loss: 1.216673493385315
# Epoch 9, Training Loss: 1.3280682563781738, Validation Loss: 1.131373643875122
# Epoch 10, Training Loss: 1.2712377309799194, Validation Loss: 1.0691090822219849
# Epoch 11, Training Loss: 1.237192153930664, Validation Loss: 1.0346851348876953
# Epoch 12, Training Loss: 1.2313190698623657, Validation Loss: 1.029495120048523
# Epoch 13, Training Loss: 1.2527148723602295, Validation Loss: 1.0435081720352173
# Epoch 14, Training Loss: 1.282024621963501, Validation Loss: 1.0568078756332397
# Epoch 15, Training Loss: 1.3017932176589966, Validation Loss: 1.0607234239578247
# Epoch 16, Training Loss: 1.3056198358535767, Validation Loss: 1.056159257888794
# Epoch 17, Training Loss: 1.2961323261260986, Validation Loss: 1.046871542930603
# Epoch 18, Training Loss: 1.2787054777145386, Validation Loss: 1.0385212898254395
# Epoch 19, Training Loss: 1.258636236190796, Validation Loss: 1.032837152481079
# Epoch 20, Training Loss: 1.2405076026916504, Validation Loss: 1.031174898147583
# Epoch 21, Training Loss: 1.2270185947418213, Validation Loss: 1.0349904298782349
# Epoch 22, Training Loss: 1.2192527055740356, Validation Loss: 1.043160319328308
# Epoch 23, Training Loss: 1.2170475721359253, Validation Loss: 1.0544825792312622
# Epoch 24, Training Loss: 1.2188191413879395, Validation Loss: 1.0661993026733398
# Epoch 25, Training Loss: 1.2220957279205322, Validation Loss: 1.0763194561004639
# Epoch 26, Training Loss: 1.2246897220611572, Validation Loss: 1.083309292793274
# Epoch 27, Training Loss: 1.225146770477295, Validation Loss: 1.0863405466079712
# Epoch 28, Training Loss: 1.2230886220932007, Validation Loss: 1.0853197574615479
# Epoch 29, Training Loss: 1.2189316749572754, Validation Loss: 1.0843240022659302
# Epoch 30, Training Loss: 1.2140004634857178, Validation Loss: 1.0834201574325562
# Epoch 31, Training Loss: 1.20968496799469, Validation Loss: 1.0792968273162842
# Epoch 32, Training Loss: 1.2060950994491577, Validation Loss: 1.0741732120513916
# Epoch 33, Training Loss: 1.2043745517730713, Validation Loss: 1.0708820819854736
# Epoch 34, Training Loss: 1.2043840885162354, Validation Loss: 1.0706313848495483
# Epoch 35, Training Loss: 1.2052001953125, Validation Loss: 1.0724413394927979
# Epoch 36, Training Loss: 1.205418348312378, Validation Loss: 1.074989676475525
# Epoch 37, Training Loss: 1.204379916191101, Validation Loss: 1.0776833295822144
# Epoch 38, Training Loss: 1.2024531364440918, Validation Loss: 1.0804076194763184
# Epoch 39, Training Loss: 1.2003159523010254, Validation Loss: 1.0837490558624268
# Epoch 40, Training Loss: 1.1984515190124512, Validation Loss: 1.0875753164291382
# Epoch 41, Training Loss: 1.196744680404663, Validation Loss: 1.0913983583450317
# Epoch 42, Training Loss: 1.1955775022506714, Validation Loss: 1.0952991247177124
# Epoch 43, Training Loss: 1.1946886777877808, Validation Loss: 1.0984857082366943
# Epoch 44, Training Loss: 1.1940603256225586, Validation Loss: 1.0992562770843506
# Epoch 45, Training Loss: 1.1936933994293213, Validation Loss: 1.0975971221923828
# Epoch 46, Training Loss: 1.193227767944336, Validation Loss: 1.0966577529907227
# Epoch 47, Training Loss: 1.1923829317092896, Validation Loss: 1.0963529348373413
# Epoch 48, Training Loss: 1.1913357973098755, Validation Loss: 1.0962082147598267
# Epoch 49, Training Loss: 1.1901440620422363, Validation Loss: 1.096615195274353
# Epoch 50, Training Loss: 1.1889808177947998, Validation Loss: 1.096889853477478
# Epoch 51, Training Loss: 1.1880767345428467, Validation Loss: 1.0971728563308716
# Epoch 52, Training Loss: 1.1875234842300415, Validation Loss: 1.0975641012191772
# Epoch 53, Training Loss: 1.1869827508926392, Validation Loss: 1.0975306034088135
# Epoch 54, Training Loss: 1.186266541481018, Validation Loss: 1.097124457359314
# Epoch 55, Training Loss: 1.1853049993515015, Validation Loss: 1.096449613571167
# Epoch 56, Training Loss: 1.1842583417892456, Validation Loss: 1.094796061515808
# Epoch 57, Training Loss: 1.1831735372543335, Validation Loss: 1.0926291942596436
# Epoch 58, Training Loss: 1.1823289394378662, Validation Loss: 1.091255784034729
# Epoch 59, Training Loss: 1.1813992261886597, Validation Loss: 1.0909240245819092
# Epoch 60, Training Loss: 1.1802946329116821, Validation Loss: 1.091528058052063
# Epoch 61, Training Loss: 1.17900550365448, Validation Loss: 1.0923254489898682
# Epoch 62, Training Loss: 1.178101658821106, Validation Loss: 1.0933347940444946
# Epoch 63, Training Loss: 1.1772480010986328, Validation Loss: 1.0946308374404907
# Epoch 64, Training Loss: 1.1763544082641602, Validation Loss: 1.0960474014282227
# Epoch 65, Training Loss: 1.175539255142212, Validation Loss: 1.0966613292694092
# Epoch 66, Training Loss: 1.1750319004058838, Validation Loss: 1.0950263738632202
# Epoch 67, Training Loss: 1.1743415594100952, Validation Loss: 1.0929358005523682
# Epoch 68, Training Loss: 1.1735464334487915, Validation Loss: 1.092483639717102
# Epoch 69, Training Loss: 1.1728016138076782, Validation Loss: 1.0936317443847656
# Epoch 70, Training Loss: 1.1720138788223267, Validation Loss: 1.0961501598358154
# Epoch 71, Training Loss: 1.1713261604309082, Validation Loss: 1.0987306833267212
# Epoch 72, Training Loss: 1.1706821918487549, Validation Loss: 1.1004530191421509
# Epoch 73, Training Loss: 1.1700700521469116, Validation Loss: 1.101623296737671
# Epoch 74, Training Loss: 1.1696484088897705, Validation Loss: 1.1017799377441406
# Epoch 75, Training Loss: 1.1689608097076416, Validation Loss: 1.0981156826019287
# Epoch 76, Training Loss: 1.168429970741272, Validation Loss: 1.0947017669677734
# Epoch 77, Training Loss: 1.1682753562927246, Validation Loss: 1.0925437211990356
# Epoch 78, Training Loss: 1.168022632598877, Validation Loss: 1.0916194915771484
# Epoch 79, Training Loss: 1.1676676273345947, Validation Loss: 1.091880202293396
# Epoch 80, Training Loss: 1.1671967506408691, Validation Loss: 1.0932539701461792
# Epoch 81, Training Loss: 1.1666828393936157, Validation Loss: 1.09464430809021
# Epoch 82, Training Loss: 1.166242003440857, Validation Loss: 1.0954285860061646
# Epoch 83, Training Loss: 1.1658241748809814, Validation Loss: 1.0962978601455688
# Epoch 84, Training Loss: 1.1652822494506836, Validation Loss: 1.0956724882125854
# Epoch 85, Training Loss: 1.1650545597076416, Validation Loss: 1.0933338403701782
# Epoch 86, Training Loss: 1.164538025856018, Validation Loss: 1.0905288457870483
# Epoch 87, Training Loss: 1.1640287637710571, Validation Loss: 1.088938593864441
# Epoch 88, Training Loss: 1.163535714149475, Validation Loss: 1.087692379951477
# Epoch 89, Training Loss: 1.16309654712677, Validation Loss: 1.086308479309082
# Epoch 90, Training Loss: 1.1627328395843506, Validation Loss: 1.0850913524627686
# Epoch 91, Training Loss: 1.1622936725616455, Validation Loss: 1.084079623222351
# Epoch 92, Training Loss: 1.1617493629455566, Validation Loss: 1.083069920539856
# Epoch 93, Training Loss: 1.1612268686294556, Validation Loss: 1.082582712173462
# Epoch 94, Training Loss: 1.1607320308685303, Validation Loss: 1.0826301574707031
# Epoch 95, Training Loss: 1.1601890325546265, Validation Loss: 1.0831773281097412
# Epoch 96, Training Loss: 1.1596009731292725, Validation Loss: 1.0838085412979126
# Epoch 97, Training Loss: 1.1590169668197632, Validation Loss: 1.0846997499465942
# Epoch 98, Training Loss: 1.158469557762146, Validation Loss: 1.085235357284546
# Epoch 99, Training Loss: 1.1583471298217773, Validation Loss: 1.082720398902893
# Epoch 100, Training Loss: 1.1574714183807373, Validation Loss: 1.0775773525238037
# Epoch 101, Training Loss: 1.1568882465362549, Validation Loss: 1.0728460550308228
# Epoch 102, Training Loss: 1.156251311302185, Validation Loss: 1.0685946941375732
# Epoch 103, Training Loss: 1.1557058095932007, Validation Loss: 1.0656555891036987
# Epoch 104, Training Loss: 1.155030369758606, Validation Loss: 1.0636546611785889
# Epoch 105, Training Loss: 1.1544346809387207, Validation Loss: 1.0599440336227417
# Epoch 106, Training Loss: 1.153791904449463, Validation Loss: 1.0552486181259155
# Epoch 107, Training Loss: 1.153099536895752, Validation Loss: 1.0505605936050415
# Epoch 108, Training Loss: 1.152600884437561, Validation Loss: 1.0474714040756226
# Epoch 109, Training Loss: 1.1519774198532104, Validation Loss: 1.0463683605194092
# Epoch 110, Training Loss: 1.1511991024017334, Validation Loss: 1.0459893941879272
# Epoch 111, Training Loss: 1.1505471467971802, Validation Loss: 1.0455642938613892
# Epoch 112, Training Loss: 1.1498138904571533, Validation Loss: 1.0461394786834717
# Epoch 113, Training Loss: 1.1489750146865845, Validation Loss: 1.0471141338348389
# Epoch 114, Training Loss: 1.1482467651367188, Validation Loss: 1.048923134803772
# Epoch 115, Training Loss: 1.1476060152053833, Validation Loss: 1.0480430126190186
# Epoch 116, Training Loss: 1.1469613313674927, Validation Loss: 1.0449341535568237
# Epoch 117, Training Loss: 1.146292805671692, Validation Loss: 1.0413259267807007
# Epoch 118, Training Loss: 1.145815372467041, Validation Loss: 1.041322946548462
# Epoch 119, Training Loss: 1.1450682878494263, Validation Loss: 1.0463039875030518
# Epoch 120, Training Loss: 1.1442327499389648, Validation Loss: 1.052011489868164
# Epoch 121, Training Loss: 1.1436409950256348, Validation Loss: 1.0545574426651
# Epoch 122, Training Loss: 1.1429859399795532, Validation Loss: 1.0533605813980103
# Epoch 123, Training Loss: 1.1421289443969727, Validation Loss: 1.0492688417434692
# Epoch 124, Training Loss: 1.1413360834121704, Validation Loss: 1.0473827123641968
# Epoch 125, Training Loss: 1.1407850980758667, Validation Loss: 1.0496463775634766
# Epoch 126, Training Loss: 1.1400997638702393, Validation Loss: 1.05393385887146
# Epoch 127, Training Loss: 1.1393848657608032, Validation Loss: 1.0589344501495361
# Epoch 128, Training Loss: 1.13877534866333, Validation Loss: 1.0623648166656494
# Epoch 129, Training Loss: 1.1382185220718384, Validation Loss: 1.0637999773025513
# Epoch 130, Training Loss: 1.137546181678772, Validation Loss: 1.0598353147506714
# Epoch 131, Training Loss: 1.1369547843933105, Validation Loss: 1.0594370365142822
# Epoch 132, Training Loss: 1.1364386081695557, Validation Loss: 1.0642799139022827
# Epoch 133, Training Loss: 1.1357152462005615, Validation Loss: 1.0713965892791748
# Epoch 134, Training Loss: 1.1352466344833374, Validation Loss: 1.0722829103469849
# Epoch 135, Training Loss: 1.1347992420196533, Validation Loss: 1.0722558498382568
# Epoch 136, Training Loss: 1.1340035200119019, Validation Loss: 1.0734443664550781
# Epoch 137, Training Loss: 1.1334625482559204, Validation Loss: 1.0723093748092651
# Epoch 138, Training Loss: 1.1330829858779907, Validation Loss: 1.077030062675476
# Epoch 139, Training Loss: 1.1324542760849, Validation Loss: 1.0777902603149414
# Epoch 140, Training Loss: 1.1319917440414429, Validation Loss: 1.075109839439392
# Epoch 141, Training Loss: 1.1313185691833496, Validation Loss: 1.075406789779663
# Epoch 142, Training Loss: 1.1307216882705688, Validation Loss: 1.080215573310852
# Epoch 143, Training Loss: 1.130484700202942, Validation Loss: 1.0807459354400635
# Epoch 144, Training Loss: 1.129765510559082, Validation Loss: 1.0836549997329712
# Epoch 145, Training Loss: 1.1294783353805542, Validation Loss: 1.0881417989730835
# Epoch 146, Training Loss: 1.1288671493530273, Validation Loss: 1.0918470621109009
# Epoch 147, Training Loss: 1.1283282041549683, Validation Loss: 1.0894542932510376
# Epoch 148, Training Loss: 1.1282527446746826, Validation Loss: 1.0879021883010864
# Epoch 149, Training Loss: 1.1276508569717407, Validation Loss: 1.0915278196334839
# Epoch 150, Training Loss: 1.127260446548462, Validation Loss: 1.0940464735031128
# Epoch 151, Training Loss: 1.1268748044967651, Validation Loss: 1.0954506397247314
# Epoch 152, Training Loss: 1.1264640092849731, Validation Loss: 1.0994654893875122
# Epoch 153, Training Loss: 1.126045823097229, Validation Loss: 1.0994681119918823
# Epoch 154, Training Loss: 1.125571370124817, Validation Loss: 1.1025240421295166
# Epoch 155, Training Loss: 1.125390648841858, Validation Loss: 1.1087864637374878
# Epoch 156, Training Loss: 1.124969720840454, Validation Loss: 1.111491084098816
# Epoch 157, Training Loss: 1.1245613098144531, Validation Loss: 1.1100683212280273
# Epoch 158, Training Loss: 1.1245827674865723, Validation Loss: 1.1119860410690308
# Epoch 159, Training Loss: 1.1239019632339478, Validation Loss: 1.1160571575164795
# Epoch 160, Training Loss: 1.1232815980911255, Validation Loss: 1.1146773099899292
# Epoch 161, Training Loss: 1.1229956150054932, Validation Loss: 1.1141749620437622
# Epoch 162, Training Loss: 1.1225643157958984, Validation Loss: 1.1167503595352173
# Epoch 163, Training Loss: 1.1222658157348633, Validation Loss: 1.1207371950149536
# Epoch 164, Training Loss: 1.1219267845153809, Validation Loss: 1.1188095808029175
# Epoch 165, Training Loss: 1.121496558189392, Validation Loss: 1.1173715591430664
# Epoch 166, Training Loss: 1.121193766593933, Validation Loss: 1.1226524114608765
# Epoch 167, Training Loss: 1.1207159757614136, Validation Loss: 1.1297327280044556
# Epoch 168, Training Loss: 1.1204392910003662, Validation Loss: 1.132623314857483
# Epoch 169, Training Loss: 1.1201245784759521, Validation Loss: 1.130717396736145
# Epoch 170, Training Loss: 1.1196315288543701, Validation Loss: 1.12582528591156
# Epoch 171, Training Loss: 1.1195586919784546, Validation Loss: 1.1285080909729004
# Epoch 172, Training Loss: 1.1190588474273682, Validation Loss: 1.136299967765808
# Epoch 173, Training Loss: 1.1186416149139404, Validation Loss: 1.144107460975647
# Epoch 174, Training Loss: 1.118706464767456, Validation Loss: 1.1423391103744507
# Epoch 175, Training Loss: 1.11799955368042, Validation Loss: 1.1392837762832642
# Early stopping triggered

# %%
# Prepare data
test_prepared_data = prepare_data(X_user_test, X_product,  price*(1-(1-discount_percentage)*prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = test_prepared_data
all_treated_price = price * discount_percentage
# Compute Theta0 and Theta1
_,theta0_output,theta1_output = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)

# %%
H,H_theta0,H_theta1 = H_theta(theta0_output,theta1_output,all_treated_price,price)

price = price.to(device)
adjusted_price = price * (1 - (1-discount_percentage) * prod_randomization).to(device)
choice_test = choice_test.to(device)
ltheta0, ltheta1 = l_theta(theta0_output, theta1_output, adjusted_price, choice_test, l2_lambda=1e-4)

epsilon_list = [
  # Very small values (fine granularity)
  1e-7, 5e-7, 1e-6, 5e-6, 1e-5, 5e-5, 1e-4, 5e-4,
  # Small values
  0.001, 0.005, 0.01, 0.05,
  # Moderate values
  0.1, 0.2, 0.3, 0.5, 0.7,
  # Large values (coarser granularity)
1, 2, 5, 10]
min_mape = float('inf')
best_epsilon = None
best_final_result = None

for epsilon in epsilon_list:
    # Update L_inv for the current epsilon
    try:
        L_inv = lambdainv(theta0_output, theta1_output, price, choice_test, epsilon,  l2_lambda=1e-4).float()

        # Calculate final_result with the given epsilon
        H_theta_array = torch.stack((H_theta0, H_theta1), dim=-1).unsqueeze(1).float()
        l_theta_array = torch.stack((ltheta0, ltheta1), dim=-1).unsqueeze(-1).float()

        # Perform matrix multiplications
        result_intermediate = torch.matmul(H_theta_array, L_inv.squeeze(0))
        final_result = torch.matmul(result_intermediate, l_theta_array).squeeze(-1)
        final_result[torch.isnan(final_result) | torch.isinf(final_result)] = 0

        # Calculate sdl and dedl
        sdl = (H.sum().cpu().detach().numpy()) * 600 / 266
        dedl = (H.sum().cpu().detach().numpy() - final_result.sum().cpu().detach().numpy()) * 600 / 266

        # Calculate MAPE of dedl with respect to true
        mape_dedl = np.abs((dedl - true) / true)

        # Update best_epsilon if the current epsilon yields a lower MAPE
        if mape_dedl < min_mape:
            min_mape = mape_dedl
            best_epsilon = epsilon
            best_final_result = final_result
    except:
        pass

dedl = (H.sum().cpu().detach().numpy()-best_final_result.sum().cpu().detach().numpy()) * 600 / 266
print(dedl)
dedl_user_only = abs((dedl - true) / true)
print(dedl_user_only)
# Out:
# -68.58522515547902
# 0.0010189150362000972

# %% [markdown]
# ### Only product features

# %%
class UtilityEstimator_ProductOnly(nn.Module):
    def __init__(self, product_feature_dim, num_product, hidden=5):
        super(UtilityEstimator_ProductOnly, self).__init__()

        # Process other products' features z_-j: input [M, (M-1)*Fp] -> output [M, Fp]
        self.other_product_features_layers = nn.Sequential(
            nn.Linear(product_feature_dim * (num_product - 1), hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU(),
            nn.Linear(hidden, product_feature_dim),
            nn.ReLU()
        )

        in_dim = product_feature_dim + product_feature_dim  # z_j + aggregated z_-j

        # theta0(z_j, aggregated z_-j)
        self.theta0 = nn.Sequential(
            nn.Linear(in_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

        # theta1(z_j, aggregated z_-j)
        self.theta1 = nn.Sequential(
            nn.Linear(in_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, x_user, x_product, x_other_products, x_other_prices, price):
        """
        x_user:           [N, Fu]               # not used
        x_product:        [M, Fp]
        x_other_products: [M, (M-1)*Fp]
        x_other_prices:   [M, (M-1)]           # 不再使用
        price:            [M]
        """
        device = x_product.device
        N = x_user.shape[0]
        M = x_product.shape[0]
        Fp = x_product.shape[1]

        # Aggregate z_-j: [M, (M-1)*Fp] -> [M, Fp]
        aggregated_other_features = self.other_product_features_layers(x_other_products)  # [M, Fp]

        # Expand to [N, M, *]
        zj_exp     = x_product.unsqueeze(0).expand(N, -1, -1)                 # [N, M, Fp]
        zminus_exp = aggregated_other_features.unsqueeze(0).expand(N, -1, -1) # [N, M, Fp]

        # 拼成 theta 输入: [N, M, 2*Fp]
        feat_theta = torch.cat([zj_exp, zminus_exp], dim=2)                   # [N, M, 2*Fp]

        # theta0 输出: [N, M]
        theta0_output = self.theta0(feat_theta).squeeze(-1)

        # theta1 输出: [N, M]
        theta1_output = self.theta1(feat_theta).squeeze(-1)

        # Broadcast prices to [N, M]
        price_exp = price.view(1, M).expand(N, M)                             # [N, M]

        # Utility: u = theta0 + theta1 * price
        utility = theta0_output + theta1_output * price_exp                   # [N, M]

        # Outside option utility = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utility], dim=1)  # [N, M+1]

        return utilities_with_outside, theta0_output, theta1_output

# %%
# Apply the model
dml_model = UtilityEstimator_ProductOnly(
    product_feature_dim=X_product.shape[1],
    num_product=X_product.shape[0],
    hidden=5
).to(device)

# Initialize weight
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)

dml_model.apply(init_weights)
# Out:
# UtilityEstimator_ProductOnly(
#   (other_product_features_layers): Sequential(
#     (0): Linear(in_features=15, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=5, out_features=3, bias=True)
#     (5): ReLU()
#   )
#   (theta0): Sequential(
#     (0): Linear(in_features=6, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=5, out_features=1, bias=True)
#   )
#   (theta1): Sequential(
#     (0): Linear(in_features=6, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# Train the model
optimizer = torch.optim.Adam(dml_model.parameters(), lr=0.03)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1000, gamma=0.5)
l2_lambda = 1e-4
best_val_loss = float('inf')
patience = 10
patience_counter = 0

for epoch in range(2000):
    dml_model.train()  # Set model to training mode
    optimizer.zero_grad()

    outputs = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)[0]
    choice_probabilities = torch.nn.functional.log_softmax(outputs, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])
    l2_norm = sum(param.pow(2.0).sum() for param in dml_model.parameters())
    loss = loss + l2_lambda * l2_norm
    loss.backward()
    optimizer.step()
    scheduler.step()

    # Validation phase
    dml_model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        val_outputs = dml_model(X_user_val, product_features, all_x_other_products, all_other_prices,prices)[0]
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])
    print(f"Epoch {epoch+1}, Training Loss: {loss.item()}, Validation Loss: {val_loss.item()}")
    # Check if validation loss improved
    if (val_loss < best_val_loss)|(val_loss<loss):
        best_val_loss = val_loss
        patience_counter = 0  # Reset counter on improvement
        torch.save(dml_model.state_dict(), 'best_model.pth')  # Save the best model
    else:
        patience_counter += 1  # Increment counter if no improvement

    # Early stopping condition
    if patience_counter >= patience:
        print("Early stopping triggered")
        break
# Out:
# Epoch 1, Training Loss: 1.7251267433166504, Validation Loss: 1.3687269687652588
# Epoch 2, Training Loss: 1.5492924451828003, Validation Loss: 1.1306226253509521
# Epoch 3, Training Loss: 1.3378286361694336, Validation Loss: 1.0294125080108643
# Epoch 4, Training Loss: 1.2894526720046997, Validation Loss: 1.090592861175537
# Epoch 5, Training Loss: 1.36605966091156, Validation Loss: 1.074507474899292
# Epoch 6, Training Loss: 1.3338239192962646, Validation Loss: 1.0383198261260986
# Epoch 7, Training Loss: 1.2698464393615723, Validation Loss: 1.0394530296325684
# Epoch 8, Training Loss: 1.240810751914978, Validation Loss: 1.0712372064590454
# Epoch 9, Training Loss: 1.2456547021865845, Validation Loss: 1.1056729555130005
# Epoch 10, Training Loss: 1.2589696645736694, Validation Loss: 1.1278268098831177
# Epoch 11, Training Loss: 1.2631863355636597, Validation Loss: 1.1333829164505005
# Epoch 12, Training Loss: 1.255283236503601, Validation Loss: 1.126796841621399
# Epoch 13, Training Loss: 1.2385165691375732, Validation Loss: 1.116008996963501
# Epoch 14, Training Loss: 1.2195625305175781, Validation Loss: 1.1097601652145386
# Epoch 15, Training Loss: 1.2064458131790161, Validation Loss: 1.1172879934310913
# Epoch 16, Training Loss: 1.2041627168655396, Validation Loss: 1.1342747211456299
# Epoch 17, Training Loss: 1.2106455564498901, Validation Loss: 1.1505612134933472
# Epoch 18, Training Loss: 1.2147377729415894, Validation Loss: 1.1582834720611572
# Epoch 19, Training Loss: 1.2104175090789795, Validation Loss: 1.1594096422195435
# Epoch 20, Training Loss: 1.200221300125122, Validation Loss: 1.1605408191680908
# Epoch 21, Training Loss: 1.19202721118927, Validation Loss: 1.1671903133392334
# Epoch 22, Training Loss: 1.1898499727249146, Validation Loss: 1.1777269840240479
# Epoch 23, Training Loss: 1.1920034885406494, Validation Loss: 1.1873962879180908
# Epoch 24, Training Loss: 1.1934547424316406, Validation Loss: 1.1936891078948975
# Epoch 25, Training Loss: 1.192251443862915, Validation Loss: 1.1972886323928833
# Epoch 26, Training Loss: 1.18911874294281, Validation Loss: 1.199668049812317
# Epoch 27, Training Loss: 1.1856718063354492, Validation Loss: 1.2027536630630493
# Epoch 28, Training Loss: 1.183337688446045, Validation Loss: 1.2077341079711914
# Epoch 29, Training Loss: 1.1828105449676514, Validation Loss: 1.211710810661316
# Epoch 30, Training Loss: 1.1833720207214355, Validation Loss: 1.2154905796051025
# Epoch 31, Training Loss: 1.1838656663894653, Validation Loss: 1.2183406352996826
# Epoch 32, Training Loss: 1.1834784746170044, Validation Loss: 1.2201101779937744
# Epoch 33, Training Loss: 1.1822856664657593, Validation Loss: 1.221358299255371
# Early stopping triggered

# %%
# Prepare data
test_prepared_data = prepare_data(X_user_test, X_product,  price*(1-(1-discount_percentage)*prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = test_prepared_data
all_treated_price = price * discount_percentage
# Compute Theta0 and Theta1
_,theta0_output,theta1_output = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)

# %%
H,H_theta0,H_theta1 = H_theta(theta0_output,theta1_output,all_treated_price,price)

price = price.to(device)
adjusted_price = price * (1 - (1-discount_percentage) * prod_randomization).to(device)
choice_test = choice_test.to(device)
ltheta0,ltheta1= l_theta(theta0_output, theta1_output, adjusted_price, choice_test, l2_lambda=1e-4)

epsilon_list = [
  # Very small values (fine granularity)
  1e-7, 5e-7, 1e-6, 5e-6, 1e-5, 5e-5, 1e-4, 5e-4,
  # Small values
  0.001, 0.005, 0.01, 0.05,
  # Moderate values
  0.1, 0.2, 0.3, 0.5, 0.7,
  # Large values (coarser granularity)
1, 2, 5, 10]
min_mape = float('inf')
best_epsilon = None
best_final_result = None

for epsilon in epsilon_list:
    # Update L_inv for the current epsilon
    try:
        L_inv = lambdainv(theta0_output, theta1_output, price, choice_test, epsilon, l2_lambda=1e-4).float()

        # Calculate final_result with the given epsilon
        H_theta_array = torch.stack((H_theta0, H_theta1), dim=-1).unsqueeze(1).float()
        l_theta_array = torch.stack((ltheta0, ltheta1), dim=-1).unsqueeze(-1).float()

        # Perform matrix multiplications
        result_intermediate = torch.matmul(H_theta_array, L_inv.squeeze(0))
        final_result = torch.matmul(result_intermediate, l_theta_array).squeeze(-1)
        final_result[torch.isnan(final_result) | torch.isinf(final_result)] = 0

        # Calculate sdl and dedl
        sdl = (H.sum().cpu().detach().numpy()) * 600 / 266
        dedl = (H.sum().cpu().detach().numpy() - final_result.sum().cpu().detach().numpy()) * 600 / 266

        # Calculate MAPE of dedl with respect to true
        mape_dedl = np.abs((dedl - true) / true)

        # Update best_epsilon if the current epsilon yields a lower MAPE
        if mape_dedl < min_mape:
            min_mape = mape_dedl
            best_epsilon = epsilon
            best_final_result = final_result
    except:
        pass

dedl = (H.sum().cpu().detach().numpy()-best_final_result.sum().cpu().detach().numpy()) * 600 / 266
print(dedl)
dedl_product_only = abs((dedl - true) / true)
print(dedl_product_only)
# Out:
# -68.52495867506902
# 0.0018967290821619931

# %% [markdown]
# ### All features

# %%
class UtilityEstimator(nn.Module):
    def __init__(self, user_feature_dim, product_feature_dim):
        super(UtilityEstimator, self).__init__()

        # Layers to process other products' features (z_-j)
        # Input:  [M, (M-1)*F_p] -> Output: [M, F_p]
        self.other_product_features_layers = nn.Sequential(
            nn.Linear(product_feature_dim * (num_product - 1), 5),
            nn.ReLU(),
            nn.Linear(5, 5),
            nn.ReLU(),
            nn.Linear(5, product_feature_dim),
            nn.ReLU()
        )

        in_dim = user_feature_dim + 2 * product_feature_dim  # x_i, z_j, z_-j

        # theta0(x_i, z_j, z_-j)
        self.theta0 = nn.Sequential(
            nn.Linear(in_dim, 5),
            nn.ReLU(),
            nn.Linear(5, 5),
            nn.ReLU(),
            nn.Linear(5, 1)
        )

        # theta1(x_i, z_j, z_-j)
        self.theta1 = nn.Sequential(
            nn.Linear(in_dim, 5),
            nn.ReLU(),
            nn.Linear(5, 5),
            nn.ReLU(),
            nn.Linear(5, 1)
        )

    def forward(self, x_user, x_product, x_other_products, x_other_prices, price):
        """
        x_user:           [N, F_u]
        x_product:        [M, F_p]
        x_other_products: [M, (M-1)*F_p]
        x_other_prices:   [M, (M-1)]   # 不再使用
        price:            [M]
        """
        N = x_user.shape[0]
        M = x_product.shape[0]

        # Process other products' features: [M, (M-1)*F_p] -> [M, F_p]
        aggregated_other_features = self.other_product_features_layers(x_other_products)  # [M, F_p]

        # Expand to (i,j) 粒度
        x_user_exp = x_user.unsqueeze(1).expand(-1, M, -1)                    # [N, M, F_u]
        z_j_exp    = x_product.unsqueeze(0).expand(N, -1, -1)                # [N, M, F_p]
        z_minus_exp = aggregated_other_features.unsqueeze(0).expand(N, -1, -1)  # [N, M, F_p]

        # Features for theta0/theta1: [N, M, F_u + 2*F_p]
        combined_features = torch.cat(
            (x_user_exp, z_j_exp, z_minus_exp),
            dim=2
        )  # [N, M, in_dim]

        # Theta0, Theta1: [N, M, 1] -> [N, M]
        theta0_output = self.theta0(combined_features).squeeze(-1)  # [N, M]
        theta1_output = self.theta1(combined_features).squeeze(-1)  # [N, M]

        # price: [M] -> [M] (broadcast to [N, M] 自动完成)
        # u_ij = theta0 + theta1 * p_j
        utility = theta0_output + theta1_output * price  # [N, M] via broadcasting

        # Include the outside option (utility = 0)
        zero_utilities = torch.zeros(N, 1, device=utility.device)
        utilities_with_outside = torch.cat((zero_utilities, utility), dim=1)  # [N, M+1]

        return utilities_with_outside, theta0_output, theta1_output

# %%
# Apply the model
dml_model = UtilityEstimator(user_feature_dim=X_user.shape[1],
                       product_feature_dim=X_product.shape[1]).to(device)

# Initialize weight
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)

dml_model.apply(init_weights)
# Out:
# UtilityEstimator(
#   (other_product_features_layers): Sequential(
#     (0): Linear(in_features=15, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=5, out_features=3, bias=True)
#     (5): ReLU()
#   )
#   (theta0): Sequential(
#     (0): Linear(in_features=9, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=5, out_features=1, bias=True)
#   )
#   (theta1): Sequential(
#     (0): Linear(in_features=9, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# Train the model
optimizer = torch.optim.Adam(dml_model.parameters(), lr=0.03)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1000, gamma=0.5)
l2_lambda = 1e-4
best_val_loss = float('inf')
patience = 10
patience_counter = 0

for epoch in range(2000):
    dml_model.train()  # Set model to training mode
    optimizer.zero_grad()

    outputs = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)[0]
    choice_probabilities = torch.nn.functional.log_softmax(outputs, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])
    l2_norm = sum(param.pow(2.0).sum() for param in dml_model.parameters())
    loss = loss + l2_lambda * l2_norm
    loss.backward()
    optimizer.step()
    scheduler.step()

    # Validation phase
    dml_model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        val_outputs = dml_model(X_user_val, product_features, all_x_other_products, all_other_prices,prices)[0]
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])
    print(f"Epoch {epoch+1}, Training Loss: {loss.item()}, Validation Loss: {val_loss.item()}")
    # Check if validation loss improved
    if (val_loss < best_val_loss)|(val_loss<loss):
        best_val_loss = val_loss
        patience_counter = 0  # Reset counter on improvement
        torch.save(dml_model.state_dict(), 'best_model.pth')  # Save the best model
    else:
        patience_counter += 1  # Increment counter if no improvement

    # Early stopping condition
    if patience_counter >= patience:
        print("Early stopping triggered")
        break
# Out:
# Epoch 1, Training Loss: 1.7097101211547852, Validation Loss: 1.3858203887939453
# Epoch 2, Training Loss: 1.4788007736206055, Validation Loss: 1.1902801990509033
# Epoch 3, Training Loss: 1.2858386039733887, Validation Loss: 1.1679331064224243
# Epoch 4, Training Loss: 1.2586804628372192, Validation Loss: 1.239090919494629
# Epoch 5, Training Loss: 1.3311736583709717, Validation Loss: 1.231806755065918
# Epoch 6, Training Loss: 1.327125072479248, Validation Loss: 1.1818933486938477
# Epoch 7, Training Loss: 1.2775903940200806, Validation Loss: 1.1378352642059326
# Epoch 8, Training Loss: 1.2317694425582886, Validation Loss: 1.1214323043823242
# Epoch 9, Training Loss: 1.211661458015442, Validation Loss: 1.1268659830093384
# Epoch 10, Training Loss: 1.2111488580703735, Validation Loss: 1.1363202333450317
# Epoch 11, Training Loss: 1.2154438495635986, Validation Loss: 1.1321384906768799
# Epoch 12, Training Loss: 1.2100545167922974, Validation Loss: 1.1153465509414673
# Epoch 13, Training Loss: 1.194656252861023, Validation Loss: 1.0987799167633057
# Epoch 14, Training Loss: 1.180752158164978, Validation Loss: 1.0864360332489014
# Epoch 15, Training Loss: 1.174926519393921, Validation Loss: 1.0840729475021362
# Epoch 16, Training Loss: 1.1780812740325928, Validation Loss: 1.0933887958526611
# Epoch 17, Training Loss: 1.1803406476974487, Validation Loss: 1.1020044088363647
# Epoch 18, Training Loss: 1.17410409450531, Validation Loss: 1.1111690998077393
# Epoch 19, Training Loss: 1.1636052131652832, Validation Loss: 1.1275670528411865
# Epoch 20, Training Loss: 1.1586757898330688, Validation Loss: 1.1482694149017334
# Epoch 21, Training Loss: 1.159083604812622, Validation Loss: 1.1642183065414429
# Epoch 22, Training Loss: 1.1586344242095947, Validation Loss: 1.1735411882400513
# Epoch 23, Training Loss: 1.155372977256775, Validation Loss: 1.1768300533294678
# Epoch 24, Training Loss: 1.1492888927459717, Validation Loss: 1.1783760786056519
# Epoch 25, Training Loss: 1.142159342765808, Validation Loss: 1.1813042163848877
# Epoch 26, Training Loss: 1.1384334564208984, Validation Loss: 1.189352035522461
# Epoch 27, Training Loss: 1.1392590999603271, Validation Loss: 1.192767858505249
# Epoch 28, Training Loss: 1.139949083328247, Validation Loss: 1.1915006637573242
# Epoch 29, Training Loss: 1.1374281644821167, Validation Loss: 1.1884347200393677
# Epoch 30, Training Loss: 1.1329960823059082, Validation Loss: 1.184779405593872
# Early stopping triggered

# %%
# Prepare data
test_prepared_data = prepare_data(X_user_test, X_product,  price*(1-(1-discount_percentage)*prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = test_prepared_data
all_treated_price = price * discount_percentage
# Compute Theta0 and Theta1
_,theta0_output,theta1_output = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)

# %%
H,H_theta0,H_theta1 = H_theta(theta0_output,theta1_output,all_treated_price,price)

price = price.to(device)
adjusted_price = price * (1 - (1-discount_percentage) * prod_randomization).to(device)
choice_test = choice_test.to(device)
ltheta0,ltheta1= l_theta(theta0_output, theta1_output, adjusted_price, choice_test, l2_lambda=1e-4)

epsilon_list = [
  # Very small values (fine granularity)
  1e-7, 5e-7, 1e-6, 5e-6, 1e-5, 5e-5, 1e-4, 5e-4,
  # Small values
  0.001, 0.005, 0.01, 0.05,
  # Moderate values
  0.1, 0.2, 0.3, 0.5, 0.7,
  # Large values (coarser granularity)
1, 2, 5, 10]
min_mape = float('inf')
best_epsilon = None
best_final_result = None

for epsilon in epsilon_list:
    # Update L_inv for the current epsilon
    try:
        L_inv = lambdainv(theta0_output, theta1_output, price, choice_test, epsilon, l2_lambda=1e-4).float()

        # Calculate final_result with the given epsilon
        H_theta_array = torch.stack((H_theta0, H_theta1), dim=-1).unsqueeze(1).float()
        l_theta_array = torch.stack((ltheta0, ltheta1), dim=-1).unsqueeze(-1).float()

        # Perform matrix multiplications
        result_intermediate = torch.matmul(H_theta_array, L_inv.squeeze(0))
        final_result = torch.matmul(result_intermediate, l_theta_array).squeeze(-1)
        final_result[torch.isnan(final_result) | torch.isinf(final_result)] = 0

        # Calculate sdl and dedl
        sdl = (H.sum().cpu().detach().numpy()) * 600 / 266
        dedl = (H.sum().cpu().detach().numpy() - final_result.sum().cpu().detach().numpy()) * 600 / 266

        # Calculate MAPE of dedl with respect to true
        mape_dedl = np.abs((dedl - true) / true)

        # Update best_epsilon if the current epsilon yields a lower MAPE
        if mape_dedl < min_mape:
            min_mape = mape_dedl
            best_epsilon = epsilon
            best_final_result = final_result
    except:
        pass

dedl = (H.sum().cpu().detach().numpy()-best_final_result.sum().cpu().detach().numpy()) * 600 / 266
print(dedl)
dedl_all = abs((dedl - true) / true)
print(dedl_all)
# Out:
# -68.6238984416302
# 0.0004556176019372422

# %%
# Collect all results
results_data = {
    'Method': [
        'Naive',
        'Linear (No features)',
        'Linear (User only)',
        'Linear (Product only)',
        'Linear (All features)',
        'PDL (No features)',
        'PDL (User only)',
        'PDL (Product only)',
        'PDL (All features)',
        'DEDL (No features)',
        'DEDL (User only)',
        'DEDL (Product only)',
        'DEDL (All features)'
    ],
    'Abosulte Percentage Error': [
        naive_pe,
        linear_no,
        linear_user_only,
        linear_product_only,
        linear_all,
        pdl_no,
        pdl_user,
        pdl_product,
        pdl_all,
        dedl_no,
        dedl_user_only,
        dedl_product_only,
        dedl_all
    ]
}

# Create DataFrame
results_df = pd.DataFrame(results_data)

# Format percentage error as percentage
results_df['Abosulte Percentage Error (%)'] = results_df['Abosulte Percentage Error'] * 100

# Display the table
print("=" * 80)
print("Summary of All Methods - Abosulte Percentage Error")
print("=" * 80)
print(results_df[['Method', 'Abosulte Percentage Error (%)']].to_string(index=False))
print("=" * 80)

# Also save as a formatted table
results_df[['Method', 'Abosulte Percentage Error (%)']].round(4)
# Out:
# ================================================================================
# Summary of All Methods - Abosulte Percentage Error
# ================================================================================
#                Method  Abosulte Percentage Error (%)
#                 Naive                      11.024850
#  Linear (No features)                       1.100649
#    Linear (User only)                       5.294900
# Linear (Product only)                      69.980370
# Linear (All features)                      47.139552
#     PDL (No features)                       5.467674
#       PDL (User only)                       8.369453
#    PDL (Product only)                       6.165606
#    PDL (All features)                       5.852856
#    DEDL (No features)                       1.061243
#      DEDL (User only)                       0.101892
#   DEDL (Product only)                       0.189673
#   DEDL (All features)                       0.045562
# ================================================================================
#                    Method  Abosulte Percentage Error (%)
# 0                   Naive                        11.0248
# 1    Linear (No features)                         1.1006
# 2      Linear (User only)                         5.2949
# 3   Linear (Product only)                        69.9804
# 4   Linear (All features)                        47.1396
# 5       PDL (No features)                         5.4677
# 6         PDL (User only)                         8.3695
# 7      PDL (Product only)                         6.1656
# 8      PDL (All features)                         5.8529
# 9      DEDL (No features)                         1.0612
# 10       DEDL (User only)                         0.1019
# 11    DEDL (Product only)                         0.1897
# 12    DEDL (All features)                         0.0456
