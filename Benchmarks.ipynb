# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import torch
from sklearn.model_selection import train_test_split
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %% [markdown]
# # Pre-processing Stage

# %%
no = pd.read_csv('no_discount.csv')
all = pd.read_csv('all_discount.csv')
half = pd.read_csv('half_discount.csv')
prod = pd.read_excel('product.xlsx')

# %% [markdown]
# ## Data Preparation

# %%
# Map user features to number
dataframes = {'all': all, 'half': half, 'no': no}
feature_cols = ['user_feature_1', 'user_feature_2', 'user_feature_3']
category_maps = {}

# 1. Build mapping for each feature across all dataframes
for col in feature_cols:
    # Collect unique values from all dataframes for this column
    unique_vals = pd.concat([df[col] for df in dataframes.values()]).unique()
    cat_map = {cat: i+1 for i, cat in enumerate(sorted(unique_vals))}
    category_maps[col] = cat_map

# 2. Apply the mapping to each dataframe
for df in dataframes.values():
    for col in feature_cols:
        df[col + '_num'] = df[col].map(category_maps[col])

# 3. Show mapping for each feature
for col in feature_cols:
    print(f"\nMapping for {col}:")
    for cat, idx in category_maps[col].items():
        print(f"{idx}: {cat}")
# Out:
# Mapping for user_feature_1:
# 1: Female
# 2: Male
# 3: Non-binary / third gender
# 4: Prefer not to say
#
# Mapping for user_feature_2:
# 1: 1-2 years ago
# 2: 2-3 years ago
# 3: 3-4 yeas ago
# 4: Currently, I don't have a phone
# 5: Less than 1 year ago
# 6: More than 4 years ago
#
# Mapping for user_feature_3:
# 1: Brand reputation
# 2: Design and appearance
# 3: Good price
# 4: Product quality

# %%
# Map choice to number (no discount)
# Define the mapping for 'choice'
choice_map = {
    "Do not purchase; save the $30 or use it for other expenses ($30 is roughly enough to cover two meals at a fast-food restaurant in the U.S.)": 0,
    "Color: Black; Style: Solid color; Weight: 2.66 pounds; Price: $24 (MSRP: $24)": 1,
    "Color: Black; Style: Gradient color; Weight: 2.66 pounds; Price: $26 (MSRP: $26)": 2,
    "Color: Dark blue; Style: Solid color; Weight: 2.61 pounds; Price: $25 (MSRP: $25)": 3,
    "Color: Dark blue; Style: Gradient color; Weight: 2.64 pounds; Price: $25 (MSRP: $25)": 4,
    "Color: Light blue; Style: Gradient color; Weight: 2.68 pounds; Price: $26 (MSRP: $26)": 5,
    "Color: White; Style: Solid color; Weight: 2.68 pounds; Price: $27 (MSRP: $27)": 6
}

# Apply the mapping
no['choice_num'] = no['choice'].map(choice_map)

# %%
# Map choice to number (all discount)
# Define the mapping for 'choice'
choice_map = {
    "Do not purchase; save the $30 or use it for other expenses ($30 is roughly enough to cover two meals at a fast-food restaurant in the U.S.)": 0,
    "Color: Black; Style: Solid color; Weight: 2.66 pounds; Price: $4.8 (MSRP: $24)": 1,
    "Color: Black; Style: Gradient color; Weight: 2.66 pounds; Price: $5.2 (MSRP: $26)": 2,
    "Color: Dark blue; Style: Solid color; Weight: 2.61 pounds; Price: $5 (MSRP: $25)": 3,
    "Color: Dark blue; Style: Gradient color; Weight: 2.64 pounds; Price: $5 (MSRP: $25)": 4,
    "Color: Light blue; Style: Gradient color; Weight: 2.68 pounds; Price: $5.2 (MSRP: $26)": 5,
    "Color: White; Style: Solid color; Weight: 2.68 pounds; Price: $5.4 (MSRP: $27)": 6
}

# Apply the mapping
all['choice_num'] = all['choice'].map(choice_map)

# %%
# Map choice to number (half discount)
# Define the mapping for 'choice'
choice_map = {
    "Do not purchase; save the $30 or use it for other expenses ($30 is roughly enough to cover two meals at a fast-food restaurant in the U.S.)": 0,
    "Color: Black; Style: Solid color; Weight: 2.66 pounds; Price: $4.8 (MSRP: $24)": 1,
    "Color: Black; Style: Gradient color; Weight: 2.66 pounds; Price: $26 (MSRP: $26)": 2,
    "Color: Dark blue; Style: Solid color; Weight: 2.61 pounds; Price: $25 (MSRP: $25)": 3,
    "Color: Dark blue; Style: Gradient color; Weight: 2.64 pounds; Price: $25 (MSRP: $25)": 4,
    "Color: Light blue; Style: Gradient color; Weight: 2.68 pounds; Price: $5.2 (MSRP: $26)": 5,
    "Color: White; Style: Solid color; Weight: 2.68 pounds; Price: $5.4 (MSRP: $27)": 6
}

# Apply the mapping
half['choice_num'] = half['choice'].map(choice_map)

# %%
# Normalization: user features
# Define the columns to scale
columns_to_scale = ['user_feature_1_num', 'user_feature_2_num', 'user_feature_3_num']

# Initialize the scaler
scaler = MinMaxScaler()

# Fit and transform the selected columns
half[columns_to_scale] = scaler.fit_transform(half[columns_to_scale])

# %%
# Normalization: product features and price
# Define the columns to scale
columns_to_scale = [
    'product_feature_1', 'product_feature_2', 'product_feature_3', 'price'
]

# Initialize the scaler
scaler = MinMaxScaler()

# Fit and transform the selected columns
prod[columns_to_scale] = scaler.fit_transform(prod[columns_to_scale])

# %%
# Set parameters
discount_percentage = 0.2
num_product = 6

# %%
# Check the number of valid data
num_row_no = len(no)
num_row_all = len(all)
num_row_half = len(half)
print(num_row_no)
print(num_row_all)
print(num_row_half)
# Out:
# 291
# 278
# 266

# %% [markdown]
# # Analysis Stage

# %% [markdown]
# ## True GTE

# %%
# All products are control (no discount)
# Merge the purchasing data with the product data
merged_no = no.merge(prod, left_on='choice_num', right_on='product_id', how='left')

# Calculate the total revenue
revenue_control = 0
revenue_control = merged_no['price'].sum() * 300/291

# All products are treated (all discount)
# Merge the purchasing data with the product data
merged_all = all.merge(prod, left_on='choice_num', right_on='product_id', how='left')

# Calculate the total revenue
revenue_treated = 0
revenue_treated = merged_all['price'].sum() * discount_percentage * 300/278

# Calculate the GTE
true = revenue_treated - revenue_control
print(true)
# Out:
# -68.6551789496238

# %% [markdown]
# ## DIM Estimator

# %%
# Define the function to calculate the revenue
def calculate_total_revenue(df):
    revenue_treated = 0.0
    revenue_control = 0.0
    df['adjusted_price'] = df.apply(
        lambda row: row['price'] * discount_percentage if row['if_treated'] == 1 else row['price'], axis=1
    )
    for _, row in df.iterrows():
        if row['if_treated'] == 0:
            revenue_control += row['adjusted_price']
        elif row['if_treated'] == 1:
            revenue_treated += row['adjusted_price']
    return revenue_control, revenue_treated

# Merge the purchasing data with the product data
merged_half = half.merge(prod, left_on='choice_num', right_on='product_id', how='left')

# Calculate the revenue difference
revenue_control, revenue_treated = calculate_total_revenue(merged_half)

# Calculate the GTE
naive = (revenue_treated - revenue_control) * 600/266
naive
naive_pe = abs((naive - true)/true)
print(naive_pe)
# Out:
# 0.11024849998145407

# %% [markdown]
# ## MNL Estimator

# %%
# Product features (skip the first row)
feature_cols = ['product_feature_1', 'product_feature_2', 'product_feature_3']
X_product = torch.tensor(prod[feature_cols].iloc[1:].to_numpy(), dtype=torch.float)

# Price (skip first row)
price = torch.tensor(prod['price'].iloc[1:].to_numpy(), dtype=torch.float)

# Product randomization (skip first row)
prod_randomization = torch.tensor(prod['if_treated'].iloc[1:].to_numpy(), dtype=torch.bool)

# User features
user_num_cols = ['user_feature_1_num', 'user_feature_2_num', 'user_feature_3_num']
X_user = torch.tensor(merged_half[user_num_cols].to_numpy(),dtype=torch.float)

# User choice
choice = torch.tensor(
    merged_half['choice_num'].to_numpy(),
    dtype=torch.long
)

# %%
# Split the training and test set
X_user_train, X_user_test, choice_train, choice_test = train_test_split(
    X_user, choice, test_size=0.5, random_state=42
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

X_user_train = X_user_train.to(device)
X_user_test  = X_user_test.to(device)
X_product    = X_product.to(device)
price        = price.to(device)
prod_randomization = prod_randomization.to(device)

choice_train = choice_train.to(device)
choice_test  = choice_test.to(device)

# Validation set
X_user_train1, X_user_val, choice_train1, choice_val = train_test_split(X_user_train, choice_train,test_size=0.1,random_state=34)

# %% [markdown]
# ### No features

# %%
class LinearMNLModel_No(nn.Module):
    def __init__(self):
        super(LinearMNLModel_No, self).__init__()
        # v is the same constant value for all products.
        self.v = nn.Parameter(torch.tensor(1.0))
        # gamma is the price sensitivity parameter.
        self.gamma = nn.Parameter(torch.tensor(1.0))

    def forward(self, x_user, X_product, price, prod_randomization):
        N = x_user.shape[0]
        # Adjust prices for treated products (discounted)
        adjusted_price = torch.where(
            prod_randomization,
            price * discount_percentage,
            price
        )
        # Compute utilities: shape [M]
        utility = self.v + self.gamma * adjusted_price
        # Expand to shape [N, M]
        utility = utility.expand(N, -1)
        # Add outside option (utility = 0)
        zero_utilities = torch.zeros(N, 1, device=utility.device)
        utilities_with_outside = torch.cat((zero_utilities, utility), dim=1)
        return utilities_with_outside

# %%
model = LinearMNLModel_No().to(device)
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)
model.apply(init_weights)
optimizer = optim.Adam(model.parameters(), lr=0.01) 
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)

num_epochs = 5000
l2_lambda = 0
best_val_loss = float('inf')
patience = 10
patience_counter = 0

for epoch in range(num_epochs):
    # Set model to training mode
    model.train()
    optimizer.zero_grad()

    # Forward pass (Training)
    utilities = model(X_user_train1, X_product, price, prod_randomization)
    
    choice_probabilities = F.log_softmax(utilities, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])

    # L2 Regularization
    l2_norm = sum(param.pow(2.0).sum() for param in model.parameters())
    loss = loss + l2_lambda * l2_norm

    # Backward pass
    loss.backward()
    optimizer.step()
    scheduler.step()

    # --- 4. Validation phase (验证阶段) ---
    model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        val_utilities = model(X_user_val, X_product, price, prod_randomization)
        
        val_utilities = val_utilities - val_utilities.max(dim=1, keepdim=True).values
        
        val_choice_probabilities = F.log_softmax(val_utilities, dim=1)
        val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])

    if epoch % 100 == 0: 
        print(f"Epoch {epoch+1}, Training Loss: {loss.item()}, Validation Loss: {val_loss.item()}")

    if (val_loss < best_val_loss) | (val_loss < loss):
        best_val_loss = val_loss
        patience_counter = 0  # Reset counter
        torch.save(model.state_dict(), 'best_model_linear_mnl.pth')  # Save best model
    else:
        patience_counter += 1  

    if patience_counter >= patience:
        print(f"Early stopping triggered at epoch {epoch}")
        break
# Out:
# Epoch 1, Training Loss: 2.959160089492798, Validation Loss: 2.948221445083618
# Epoch 101, Training Loss: 1.98223876953125, Validation Loss: 1.9728033542633057
# Epoch 201, Training Loss: 1.458035945892334, Validation Loss: 1.446217656135559
# Epoch 301, Training Loss: 1.2844624519348145, Validation Loss: 1.2660506963729858
# Epoch 401, Training Loss: 1.2421146631240845, Validation Loss: 1.2156528234481812
# Epoch 501, Training Loss: 1.2312737703323364, Validation Loss: 1.1968811750411987
# Epoch 601, Training Loss: 1.2267866134643555, Validation Loss: 1.1849260330200195
# Epoch 701, Training Loss: 1.223840594291687, Validation Loss: 1.1750608682632446
# Epoch 801, Training Loss: 1.2216732501983643, Validation Loss: 1.1666038036346436
# Epoch 901, Training Loss: 1.2201117277145386, Validation Loss: 1.1594539880752563
# Epoch 1001, Training Loss: 1.2190316915512085, Validation Loss: 1.153525471687317
# Epoch 1101, Training Loss: 1.2183150053024292, Validation Loss: 1.1486985683441162
# Epoch 1201, Training Loss: 1.2178585529327393, Validation Loss: 1.1448352336883545
# Epoch 1301, Training Loss: 1.2175792455673218, Validation Loss: 1.141793966293335
# Epoch 1401, Training Loss: 1.217415690422058, Validation Loss: 1.1394401788711548
# Epoch 1501, Training Loss: 1.217323660850525, Validation Loss: 1.1376498937606812
# Epoch 1601, Training Loss: 1.2172740697860718, Validation Loss: 1.1363136768341064
# Epoch 1701, Training Loss: 1.217248797416687, Validation Loss: 1.1353365182876587
# Epoch 1801, Training Loss: 1.2172361612319946, Validation Loss: 1.1346368789672852
# Epoch 1901, Training Loss: 1.2172303199768066, Validation Loss: 1.1341477632522583
# Epoch 2001, Training Loss: 1.217227816581726, Validation Loss: 1.1338139772415161
# Epoch 2101, Training Loss: 1.2172267436981201, Validation Loss: 1.1335924863815308
# Epoch 2201, Training Loss: 1.217226266860962, Validation Loss: 1.1334495544433594
# Epoch 2301, Training Loss: 1.2172260284423828, Validation Loss: 1.1333600282669067
# Epoch 2401, Training Loss: 1.2172259092330933, Validation Loss: 1.1333056688308716
# Epoch 2501, Training Loss: 1.2172261476516724, Validation Loss: 1.1332738399505615
# Epoch 2601, Training Loss: 1.2172259092330933, Validation Loss: 1.1332635879516602
# Epoch 2701, Training Loss: 1.2172260284423828, Validation Loss: 1.133255958557129
# Epoch 2801, Training Loss: 1.2172259092330933, Validation Loss: 1.1332499980926514
# Epoch 2901, Training Loss: 1.2172261476516724, Validation Loss: 1.1332457065582275
# Epoch 3001, Training Loss: 1.2172260284423828, Validation Loss: 1.1332429647445679
# Epoch 3101, Training Loss: 1.2172260284423828, Validation Loss: 1.1332406997680664
# Epoch 3201, Training Loss: 1.2172260284423828, Validation Loss: 1.1332390308380127
# Epoch 3301, Training Loss: 1.2172259092330933, Validation Loss: 1.1332380771636963
# Epoch 3401, Training Loss: 1.2172260284423828, Validation Loss: 1.1332374811172485
# Epoch 3501, Training Loss: 1.2172259092330933, Validation Loss: 1.1332371234893799
# Epoch 3601, Training Loss: 1.2172260284423828, Validation Loss: 1.1332371234893799
# Epoch 3701, Training Loss: 1.2172260284423828, Validation Loss: 1.1332370042800903
# Epoch 3801, Training Loss: 1.2172260284423828, Validation Loss: 1.1332367658615112
# Epoch 3901, Training Loss: 1.2172260284423828, Validation Loss: 1.1332367658615112
# Epoch 4001, Training Loss: 1.2172261476516724, Validation Loss: 1.1332367658615112
# Epoch 4101, Training Loss: 1.2172260284423828, Validation Loss: 1.1332367658615112
# Epoch 4201, Training Loss: 1.2172259092330933, Validation Loss: 1.1332367658615112
# Epoch 4301, Training Loss: 1.2172261476516724, Validation Loss: 1.1332367658615112
# Epoch 4401, Training Loss: 1.2172260284423828, Validation Loss: 1.1332366466522217
# Epoch 4501, Training Loss: 1.2172259092330933, Validation Loss: 1.1332366466522217
# Epoch 4601, Training Loss: 1.2172259092330933, Validation Loss: 1.1332366466522217
# Epoch 4701, Training Loss: 1.2172259092330933, Validation Loss: 1.1332366466522217
# Epoch 4801, Training Loss: 1.2172259092330933, Validation Loss: 1.133236289024353
# Epoch 4901, Training Loss: 1.2172260284423828, Validation Loss: 1.1332365274429321

# %%
# All control and all treated in test set
all_product_control = np.random.choice([0,1], num_product, p=[1, 0])
all_product_treated = np.random.choice([0,1], num_product, p=[0, 1])
all_product_control = torch.from_numpy(all_product_control).to(X_user_train.device).bool()
all_product_treated = torch.from_numpy(all_product_treated).to(X_user_train.device).bool()
X_user_test, X_product, price = X_user_test.to(device), X_product.to(device), price.to(device)

# Calculate expected revenue if all control
utilities = model(X_user_test, X_product, price, all_product_control)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum()
print(f"Expected Revenue: ${expected_revenue.item():.2f}")

# Calculate expected revenue if all treated
utilities = model(X_user_test, X_product, price, all_product_treated)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue_treated = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum() * discount_percentage
print(f"Expected Revenue: ${expected_revenue_treated.item():.2f}")

# Calculate GTE
linear = (expected_revenue_treated-expected_revenue).cpu().detach().numpy()
linear = linear * 600 / 266 # For comparison purpose
print(linear)
linear_no = abs((linear - true)/true)
print(linear_no)
# Out:
# Expected Revenue: $37.51
# Expected Revenue: $8.90
# -64.5298821585519
# 0.060087190131699574

# %% [markdown]
# ### Only user features

# %%
class LinearMNLModel_UserOnly(nn.Module):
    def __init__(self, user_feature_dim):
        super(LinearMNLModel_UserOnly, self).__init__()
        self.beta_user = nn.Parameter(torch.randn(user_feature_dim))
        self.beta_price = nn.Parameter(torch.tensor(-1.0))

    def forward(self, x_user, X_product, price, prod_randomization):
        N, M = x_user.shape[0], X_product.shape[0]

        # Expand user features
        x_user_expanded = x_user.unsqueeze(1).expand(-1, M, -1).detach()
        utility_user = torch.sum(x_user_expanded * self.beta_user, dim=2)

        # Price adjustment
        adjusted_price = torch.where(
            prod_randomization.unsqueeze(0),
            price * discount_percentage,
            price
        )
        utility_price = adjusted_price * self.beta_price
        utility_price = utility_price.expand(N, M)

        total_utility = utility_user + utility_price

        # Outside option
        zero_utilities = torch.zeros(N, 1, device=total_utility.device)
        utilities_with_outside = torch.cat((zero_utilities,total_utility), dim=1)
        return utilities_with_outside

# %%
# Model training
model = LinearMNLModel_UserOnly(user_feature_dim=X_user.shape[1]).to(device)
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)
model.apply(init_weights)
optimizer = optim.Adam(model.parameters(), lr=0.01) 
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)

num_epochs = 5000
l2_lambda = 0
best_val_loss = float('inf')
patience = 10
patience_counter = 0

for epoch in range(num_epochs):
    # Set model to training mode
    model.train()
    optimizer.zero_grad()

    # Forward pass (Training)
    utilities = model(X_user_train1, X_product, price, prod_randomization)
    
    choice_probabilities = F.log_softmax(utilities, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])

    # L2 Regularization
    l2_norm = sum(param.pow(2.0).sum() for param in model.parameters())
    loss = loss + l2_lambda * l2_norm

    # Backward pass
    loss.backward()
    optimizer.step()
    scheduler.step()

    # --- 4. Validation phase (验证阶段) ---
    model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        val_utilities = model(X_user_val, X_product, price, prod_randomization)
        
        val_utilities = val_utilities - val_utilities.max(dim=1, keepdim=True).values
        
        val_choice_probabilities = F.log_softmax(val_utilities, dim=1)
        val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])

    if epoch % 100 == 0: 
        print(f"Epoch {epoch+1}, Training Loss: {loss.item()}, Validation Loss: {val_loss.item()}")

    if (val_loss < best_val_loss) | (val_loss < loss):
        best_val_loss = val_loss
        patience_counter = 0  # Reset counter
        torch.save(model.state_dict(), 'best_model_linear_mnl.pth')  # Save best model
    else:
        patience_counter += 1  

    if patience_counter >= patience:
        print(f"Early stopping triggered at epoch {epoch}")
        break
# Out:
# Epoch 1, Training Loss: 1.4125741720199585, Validation Loss: 1.3267217874526978
# Epoch 101, Training Loss: 1.256240963935852, Validation Loss: 1.07330322265625
# Epoch 201, Training Loss: 1.2294076681137085, Validation Loss: 1.0203304290771484
# Epoch 301, Training Loss: 1.2185896635055542, Validation Loss: 1.0105253458023071
# Epoch 401, Training Loss: 1.2144628763198853, Validation Loss: 1.0156253576278687
# Epoch 501, Training Loss: 1.21306312084198, Validation Loss: 1.0224069356918335
# Epoch 601, Training Loss: 1.2126542329788208, Validation Loss: 1.027262568473816
# Epoch 701, Training Loss: 1.2125521898269653, Validation Loss: 1.0300724506378174
# Epoch 801, Training Loss: 1.2125308513641357, Validation Loss: 1.031492829322815
# Epoch 901, Training Loss: 1.2125270366668701, Validation Loss: 1.0321329832077026
# Epoch 1001, Training Loss: 1.2125264406204224, Validation Loss: 1.0323917865753174
# Epoch 1101, Training Loss: 1.2125263214111328, Validation Loss: 1.0324859619140625
# Epoch 1201, Training Loss: 1.2125263214111328, Validation Loss: 1.032516598701477
# Epoch 1301, Training Loss: 1.2125262022018433, Validation Loss: 1.032525658607483
# Epoch 1401, Training Loss: 1.2125263214111328, Validation Loss: 1.0325279235839844
# Epoch 1501, Training Loss: 1.2125263214111328, Validation Loss: 1.0325285196304321
# Epoch 1601, Training Loss: 1.2125264406204224, Validation Loss: 1.0325285196304321
# Epoch 1701, Training Loss: 1.2125263214111328, Validation Loss: 1.032528281211853
# Epoch 1801, Training Loss: 1.2125263214111328, Validation Loss: 1.032528281211853
# Epoch 1901, Training Loss: 1.2125263214111328, Validation Loss: 1.0325285196304321
# Epoch 2001, Training Loss: 1.2125263214111328, Validation Loss: 1.0325285196304321
# Epoch 2101, Training Loss: 1.2125263214111328, Validation Loss: 1.0325285196304321
# Epoch 2201, Training Loss: 1.2125263214111328, Validation Loss: 1.0325285196304321
# Epoch 2301, Training Loss: 1.2125263214111328, Validation Loss: 1.0325285196304321
# Epoch 2401, Training Loss: 1.2125263214111328, Validation Loss: 1.0325285196304321
# Epoch 2501, Training Loss: 1.2125263214111328, Validation Loss: 1.0325285196304321
# Epoch 2601, Training Loss: 1.2125263214111328, Validation Loss: 1.0325285196304321
# Epoch 2701, Training Loss: 1.2125263214111328, Validation Loss: 1.0325284004211426
# Epoch 2801, Training Loss: 1.2125263214111328, Validation Loss: 1.0325285196304321
# Epoch 2901, Training Loss: 1.2125263214111328, Validation Loss: 1.0325285196304321
# Epoch 3001, Training Loss: 1.2125263214111328, Validation Loss: 1.0325285196304321
# Epoch 3101, Training Loss: 1.2125263214111328, Validation Loss: 1.0325284004211426
# Epoch 3201, Training Loss: 1.2125263214111328, Validation Loss: 1.0325285196304321
# Epoch 3301, Training Loss: 1.2125263214111328, Validation Loss: 1.0325285196304321
# Epoch 3401, Training Loss: 1.2125263214111328, Validation Loss: 1.0325285196304321
# Epoch 3501, Training Loss: 1.2125263214111328, Validation Loss: 1.0325285196304321
# Epoch 3601, Training Loss: 1.2125263214111328, Validation Loss: 1.0325285196304321
# Epoch 3701, Training Loss: 1.2125263214111328, Validation Loss: 1.0325284004211426
# Epoch 3801, Training Loss: 1.2125263214111328, Validation Loss: 1.0325285196304321
# Epoch 3901, Training Loss: 1.2125263214111328, Validation Loss: 1.0325285196304321
# Epoch 4001, Training Loss: 1.2125263214111328, Validation Loss: 1.0325285196304321
# Epoch 4101, Training Loss: 1.2125263214111328, Validation Loss: 1.0325285196304321
# Epoch 4201, Training Loss: 1.2125263214111328, Validation Loss: 1.0325285196304321
# Epoch 4301, Training Loss: 1.2125263214111328, Validation Loss: 1.0325285196304321
# Epoch 4401, Training Loss: 1.2125263214111328, Validation Loss: 1.0325285196304321
# Epoch 4501, Training Loss: 1.2125263214111328, Validation Loss: 1.0325285196304321
# Epoch 4601, Training Loss: 1.2125263214111328, Validation Loss: 1.0325285196304321
# Epoch 4701, Training Loss: 1.2125263214111328, Validation Loss: 1.0325285196304321
# Epoch 4801, Training Loss: 1.2125263214111328, Validation Loss: 1.0325285196304321
# Epoch 4901, Training Loss: 1.2125263214111328, Validation Loss: 1.0325285196304321

# %%
# All control and all treated in test set
all_product_control = np.random.choice([0,1], num_product, p=[1, 0])
all_product_treated = np.random.choice([0,1], num_product, p=[0, 1])
all_product_control = torch.from_numpy(all_product_control).to(X_user_train.device).bool()
all_product_treated = torch.from_numpy(all_product_treated).to(X_user_train.device).bool()
X_user_test, X_product, price = X_user_test.to(device), X_product.to(device), price.to(device)

# Calculate expected revenue if all control
utilities = model(X_user_test, X_product, price, all_product_control)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum()
print(f"Expected Revenue: ${expected_revenue.item():.2f}")

# Calculate expected revenue if all treated
utilities = model(X_user_test, X_product, price, all_product_treated)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue_treated = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum() * discount_percentage
print(f"Expected Revenue: ${expected_revenue_treated.item():.2f}")

# Calculate GTE
linear = (expected_revenue_treated-expected_revenue).cpu().detach().numpy()
linear = linear * 600 / 266
print(linear)
linear_user_only = abs((linear - true)/true)
print(linear_user_only)
# Out:
# Expected Revenue: $36.18
# Expected Revenue: $9.32
# -60.58626963679952
# 0.11752805012342765

# %% [markdown]
# ### Only product features

# %%
class LinearMNLModel_ProductOnly(nn.Module):
    def __init__(self, product_feature_dim):
        super(LinearMNLModel_ProductOnly, self).__init__()
        self.beta_product = nn.Parameter(torch.randn(product_feature_dim))
        self.beta_price = nn.Parameter(torch.tensor(-1.0))

    def forward(self, x_user, X_product, price, prod_randomization):
        N, M = x_user.shape[0], X_product.shape[0]

        # Expand product features
        X_product_expanded = X_product.unsqueeze(0).expand(N, -1, -1).detach()
        utility_product = torch.sum(X_product_expanded * self.beta_product, dim=2)

        # Price adjustment
        adjusted_price = torch.where(
            prod_randomization.unsqueeze(0),
            price * discount_percentage,
            price
        )
        utility_price = adjusted_price * self.beta_price
        utility_price = utility_price.expand(N, M)

        total_utility = utility_product + utility_price

        # Outside option
        zero_utilities = torch.zeros(N, 1, device=total_utility.device)
        utilities_with_outside = torch.cat((zero_utilities,total_utility), dim=1)
        return utilities_with_outside

# %%
# Model training
model = LinearMNLModel_ProductOnly(product_feature_dim=X_product.shape[1]).to(device)
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)
model.apply(init_weights)
optimizer = optim.Adam(model.parameters(), lr=0.01) 
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)

num_epochs = 5000
l2_lambda = 0
best_val_loss = float('inf')
patience = 10
patience_counter = 0

for epoch in range(num_epochs):
    # Set model to training mode
    model.train()
    optimizer.zero_grad()

    # Forward pass (Training)
    utilities = model(X_user_train1, X_product, price, prod_randomization)
    
    choice_probabilities = F.log_softmax(utilities, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])

    # L2 Regularization
    l2_norm = sum(param.pow(2.0).sum() for param in model.parameters())
    loss = loss + l2_lambda * l2_norm

    # Backward pass
    loss.backward()
    optimizer.step()
    scheduler.step()

    # --- 4. Validation phase (验证阶段) ---
    model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        val_utilities = model(X_user_val, X_product, price, prod_randomization)
        
        val_utilities = val_utilities - val_utilities.max(dim=1, keepdim=True).values
        
        val_choice_probabilities = F.log_softmax(val_utilities, dim=1)
        val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])

    if epoch % 100 == 0: 
        print(f"Epoch {epoch+1}, Training Loss: {loss.item()}, Validation Loss: {val_loss.item()}")

    if (val_loss < best_val_loss) | (val_loss < loss):
        best_val_loss = val_loss
        patience_counter = 0  # Reset counter
        torch.save(model.state_dict(), 'best_model_linear_mnl.pth')  # Save best model
    else:
        patience_counter += 1  

    if patience_counter >= patience:
        print(f"Early stopping triggered at epoch {epoch}")
        break
# Out:
# Epoch 1, Training Loss: 1.8592193126678467, Validation Loss: 1.9835050106048584
# Epoch 101, Training Loss: 1.4283355474472046, Validation Loss: 1.403351902961731
# Epoch 201, Training Loss: 1.2947416305541992, Validation Loss: 1.2860618829727173
# Epoch 301, Training Loss: 1.2360093593597412, Validation Loss: 1.2426822185516357
# Epoch 401, Training Loss: 1.209613561630249, Validation Loss: 1.2220277786254883
# Epoch 501, Training Loss: 1.1973379850387573, Validation Loss: 1.2087411880493164
# Epoch 601, Training Loss: 1.1914604902267456, Validation Loss: 1.198697805404663
# Epoch 701, Training Loss: 1.1886146068572998, Validation Loss: 1.1908971071243286
# Epoch 801, Training Loss: 1.1872509717941284, Validation Loss: 1.184983491897583
# Epoch 901, Training Loss: 1.18661630153656, Validation Loss: 1.1806682348251343
# Epoch 1001, Training Loss: 1.1863341331481934, Validation Loss: 1.1776469945907593
# Epoch 1101, Training Loss: 1.1862154006958008, Validation Loss: 1.1756161451339722
# Epoch 1201, Training Loss: 1.1861687898635864, Validation Loss: 1.1743049621582031
# Epoch 1301, Training Loss: 1.1861517429351807, Validation Loss: 1.17349112033844
# Epoch 1401, Training Loss: 1.1861459016799927, Validation Loss: 1.173005223274231
# Epoch 1501, Training Loss: 1.186144232749939, Validation Loss: 1.1727269887924194
# Epoch 1601, Training Loss: 1.1861436367034912, Validation Loss: 1.1725742816925049
# Epoch 1701, Training Loss: 1.1861436367034912, Validation Loss: 1.1724940538406372
# Epoch 1801, Training Loss: 1.1861435174942017, Validation Loss: 1.1724538803100586
# Epoch 1901, Training Loss: 1.186143398284912, Validation Loss: 1.1724350452423096
# Epoch 2001, Training Loss: 1.1861436367034912, Validation Loss: 1.1724265813827515
# Epoch 2101, Training Loss: 1.186143398284912, Validation Loss: 1.1724226474761963
# Epoch 2201, Training Loss: 1.1861436367034912, Validation Loss: 1.1724212169647217
# Epoch 2301, Training Loss: 1.1861435174942017, Validation Loss: 1.1724212169647217
# Epoch 2401, Training Loss: 1.1861435174942017, Validation Loss: 1.1724212169647217
# Epoch 2501, Training Loss: 1.1861435174942017, Validation Loss: 1.1724212169647217
# Epoch 2601, Training Loss: 1.1861435174942017, Validation Loss: 1.1724212169647217
# Epoch 2701, Training Loss: 1.1861435174942017, Validation Loss: 1.1724212169647217
# Epoch 2801, Training Loss: 1.1861435174942017, Validation Loss: 1.1724212169647217
# Epoch 2901, Training Loss: 1.1861435174942017, Validation Loss: 1.1724212169647217
# Epoch 3001, Training Loss: 1.1861435174942017, Validation Loss: 1.1724212169647217
# Epoch 3101, Training Loss: 1.1861435174942017, Validation Loss: 1.1724212169647217
# Epoch 3201, Training Loss: 1.1861435174942017, Validation Loss: 1.1724212169647217
# Epoch 3301, Training Loss: 1.1861435174942017, Validation Loss: 1.1724212169647217
# Epoch 3401, Training Loss: 1.1861435174942017, Validation Loss: 1.1724212169647217
# Epoch 3501, Training Loss: 1.1861435174942017, Validation Loss: 1.1724212169647217
# Epoch 3601, Training Loss: 1.1861435174942017, Validation Loss: 1.1724212169647217
# Epoch 3701, Training Loss: 1.1861435174942017, Validation Loss: 1.1724212169647217
# Epoch 3801, Training Loss: 1.1861435174942017, Validation Loss: 1.1724212169647217
# Epoch 3901, Training Loss: 1.1861435174942017, Validation Loss: 1.1724210977554321
# Epoch 4001, Training Loss: 1.186143398284912, Validation Loss: 1.1724210977554321
# Epoch 4101, Training Loss: 1.186143398284912, Validation Loss: 1.1724210977554321
# Epoch 4201, Training Loss: 1.186143398284912, Validation Loss: 1.1724207401275635
# Epoch 4301, Training Loss: 1.1861435174942017, Validation Loss: 1.1724210977554321
# Epoch 4401, Training Loss: 1.1861435174942017, Validation Loss: 1.1724210977554321
# Epoch 4501, Training Loss: 1.1861435174942017, Validation Loss: 1.1724210977554321
# Epoch 4601, Training Loss: 1.186143398284912, Validation Loss: 1.1724207401275635
# Epoch 4701, Training Loss: 1.1861436367034912, Validation Loss: 1.1724210977554321
# Epoch 4801, Training Loss: 1.1861436367034912, Validation Loss: 1.1724210977554321
# Epoch 4901, Training Loss: 1.1861436367034912, Validation Loss: 1.1724210977554321

# %%
# All control and all treated in test set
all_product_control = np.random.choice([0,1], num_product, p=[1, 0])
all_product_treated = np.random.choice([0,1], num_product, p=[0, 1])
all_product_control = torch.from_numpy(all_product_control).to(X_user_train.device).bool()
all_product_treated = torch.from_numpy(all_product_treated).to(X_user_train.device).bool()
X_user_test, X_product, price = X_user_test.to(device), X_product.to(device), price.to(device)

# Calculate expected revenue if all control
utilities = model(X_user_test, X_product, price, all_product_control)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum()
print(f"Expected Revenue: ${expected_revenue.item():.2f}")

# Calculate expected revenue if all treated
utilities = model(X_user_test, X_product, price, all_product_treated)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue_treated = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum() * discount_percentage
print(f"Expected Revenue: ${expected_revenue_treated.item():.2f}")

# Calculate GTE
linear = (expected_revenue_treated-expected_revenue).cpu().detach().numpy()
linear = linear * 600 / 266
print(linear)
linear_product_only = abs((linear - true)/true)
print(linear_product_only)
# Out:
# Expected Revenue: $24.67
# Expected Revenue: $17.25
# -16.727557935212786
# 0.7563540261472955

# %% [markdown]
# ### All features

# %%
# MNL choice model
class LinearMNLModel(nn.Module):
    def __init__(self, user_feature_dim, product_feature_dim):
        super(LinearMNLModel, self).__init__()
        # Initialize parameters for user and product features
        self.beta_user = nn.Parameter(torch.randn(user_feature_dim))
        self.beta_product = nn.Parameter(torch.randn(product_feature_dim))
        self.beta_price = nn.Parameter(torch.tensor(-1.0))
    def forward(self, x_user, X_product, price, prod_randomization):
        N, M = x_user.shape[0], X_product.shape[0]

        # Expand user and product features to create a [N, M, F] shaped tensor for each
        x_user_expanded = x_user.unsqueeze(1).expand(-1, M, -1).detach()
        X_product_expanded = X_product.unsqueeze(0).expand(N, -1, -1).detach()

        # Calculate linear utility from features
        utility_user = torch.sum(x_user_expanded * self.beta_user, dim=2)
        utility_product = torch.sum(X_product_expanded * self.beta_product, dim=2)

        # Adjust prices based on randomization
        adjusted_price = torch.where(
            prod_randomization.unsqueeze(0),
            price * discount_percentage,
            price
        )

        # Calculate utility from price, properly expanding its dimension
        utility_price = adjusted_price * self.beta_price  # [M]
        utility_price = utility_price.expand(N, M)  # [N, M]

        # Total utility including features and price
        total_utility = utility_user + utility_product + utility_price

        # Incorporate the outside option with utility 0
        zero_utilities = torch.zeros(N, 1, device=total_utility.device)
        utilities_with_outside = torch.cat((zero_utilities,total_utility), dim=1)

        return utilities_with_outside

# %%
# Model training
model = LinearMNLModel(
    user_feature_dim=X_user.shape[1],
    product_feature_dim=X_product.shape[1]
).to(device)
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)
model.apply(init_weights)
optimizer = optim.Adam(model.parameters(), lr=0.01) 
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)

num_epochs = 5000
l2_lambda = 0
best_val_loss = float('inf')
patience = 10
patience_counter = 0

for epoch in range(num_epochs):
    # Set model to training mode
    model.train()
    optimizer.zero_grad()

    # Forward pass (Training)
    utilities = model(X_user_train1, X_product, price, prod_randomization)
    
    choice_probabilities = F.log_softmax(utilities, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])

    # L2 Regularization
    l2_norm = sum(param.pow(2.0).sum() for param in model.parameters())
    loss = loss + l2_lambda * l2_norm

    # Backward pass
    loss.backward()
    optimizer.step()
    scheduler.step()

    # --- 4. Validation phase (验证阶段) ---
    model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        val_utilities = model(X_user_val, X_product, price, prod_randomization)
        
        val_utilities = val_utilities - val_utilities.max(dim=1, keepdim=True).values
        
        val_choice_probabilities = F.log_softmax(val_utilities, dim=1)
        val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])

    if epoch % 100 == 0: 
        print(f"Epoch {epoch+1}, Training Loss: {loss.item()}, Validation Loss: {val_loss.item()}")

    if (val_loss < best_val_loss) | (val_loss < loss):
        best_val_loss = val_loss
        patience_counter = 0  # Reset counter
        torch.save(model.state_dict(), 'best_model_linear_mnl.pth')  # Save best model
    else:
        patience_counter += 1  

    if patience_counter >= patience:
        print(f"Early stopping triggered at epoch {epoch}")
        break
# Out:
# Epoch 1, Training Loss: 2.5558688640594482, Validation Loss: 2.8942508697509766
# Epoch 101, Training Loss: 1.3533287048339844, Validation Loss: 1.249069094657898
# Epoch 201, Training Loss: 1.2533549070358276, Validation Loss: 1.0864800214767456
# Epoch 301, Training Loss: 1.2135553359985352, Validation Loss: 1.065589189529419
# Epoch 401, Training Loss: 1.1913317441940308, Validation Loss: 1.0661247968673706
# Epoch 501, Training Loss: 1.1781517267227173, Validation Loss: 1.075846552848816
# Epoch 601, Training Loss: 1.170103669166565, Validation Loss: 1.0886338949203491
# Epoch 701, Training Loss: 1.1652265787124634, Validation Loss: 1.1014353036880493
# Epoch 801, Training Loss: 1.1623575687408447, Validation Loss: 1.1129199266433716
# Epoch 901, Training Loss: 1.1607362031936646, Validation Loss: 1.1226067543029785
# Epoch 1001, Training Loss: 1.159858226776123, Validation Loss: 1.1304233074188232
# Epoch 1101, Training Loss: 1.159401774406433, Validation Loss: 1.1365025043487549
# Epoch 1201, Training Loss: 1.1591718196868896, Validation Loss: 1.1410807371139526
# Epoch 1301, Training Loss: 1.159057855606079, Validation Loss: 1.1444346904754639
# Epoch 1401, Training Loss: 1.1590003967285156, Validation Loss: 1.1468397378921509
# Epoch 1501, Training Loss: 1.158969521522522, Validation Loss: 1.148540735244751
# Epoch 1601, Training Loss: 1.1589514017105103, Validation Loss: 1.1497395038604736
# Epoch 1701, Training Loss: 1.1589395999908447, Validation Loss: 1.150591492652893
# Epoch 1801, Training Loss: 1.1589314937591553, Validation Loss: 1.1512091159820557
# Epoch 1901, Training Loss: 1.1589254140853882, Validation Loss: 1.1516704559326172
# Epoch 2001, Training Loss: 1.1589210033416748, Validation Loss: 1.1520265340805054
# Epoch 2101, Training Loss: 1.1589179039001465, Validation Loss: 1.152309775352478
# Epoch 2201, Training Loss: 1.158915638923645, Validation Loss: 1.1525404453277588
# Epoch 2301, Training Loss: 1.1589140892028809, Validation Loss: 1.1527303457260132
# Epoch 2401, Training Loss: 1.1589131355285645, Validation Loss: 1.1528875827789307
# Epoch 2501, Training Loss: 1.1589123010635376, Validation Loss: 1.1530168056488037
# Epoch 2601, Training Loss: 1.1589120626449585, Validation Loss: 1.1530729532241821
# Epoch 2701, Training Loss: 1.158911943435669, Validation Loss: 1.1531246900558472
# Epoch 2801, Training Loss: 1.1589117050170898, Validation Loss: 1.153172254562378
# Epoch 2901, Training Loss: 1.1589117050170898, Validation Loss: 1.1532156467437744
# Epoch 3001, Training Loss: 1.1589114665985107, Validation Loss: 1.1532548666000366
# Epoch 3101, Training Loss: 1.1589115858078003, Validation Loss: 1.1532899141311646
# Epoch 3201, Training Loss: 1.1589114665985107, Validation Loss: 1.1533212661743164
# Epoch 3301, Training Loss: 1.1589113473892212, Validation Loss: 1.1533488035202026
# Epoch 3401, Training Loss: 1.1589113473892212, Validation Loss: 1.1533727645874023
# Epoch 3501, Training Loss: 1.1589113473892212, Validation Loss: 1.1533933877944946
# Epoch 3601, Training Loss: 1.1589112281799316, Validation Loss: 1.1534110307693481
# Epoch 3701, Training Loss: 1.1589112281799316, Validation Loss: 1.153425931930542
# Epoch 3801, Training Loss: 1.1589112281799316, Validation Loss: 1.1534383296966553
# Epoch 3901, Training Loss: 1.1589112281799316, Validation Loss: 1.1534483432769775
# Epoch 4001, Training Loss: 1.1589112281799316, Validation Loss: 1.1534568071365356
# Epoch 4101, Training Loss: 1.1589112281799316, Validation Loss: 1.1534634828567505
# Epoch 4201, Training Loss: 1.1589113473892212, Validation Loss: 1.1534688472747803
# Epoch 4301, Training Loss: 1.1589112281799316, Validation Loss: 1.153472661972046
# Epoch 4401, Training Loss: 1.1589112281799316, Validation Loss: 1.1534756422042847
# Epoch 4501, Training Loss: 1.1589113473892212, Validation Loss: 1.1534783840179443
# Epoch 4601, Training Loss: 1.1589112281799316, Validation Loss: 1.1534795761108398
# Epoch 4701, Training Loss: 1.1589113473892212, Validation Loss: 1.1534807682037354
# Epoch 4801, Training Loss: 1.1589112281799316, Validation Loss: 1.1534818410873413
# Epoch 4901, Training Loss: 1.1589112281799316, Validation Loss: 1.153482437133789

# %%
# All control and all treated in test set
all_product_control = np.random.choice([0,1], num_product, p=[1, 0])
all_product_treated = np.random.choice([0,1], num_product, p=[0, 1])
all_product_control = torch.from_numpy(all_product_control).to(X_user_train.device).bool()
all_product_treated = torch.from_numpy(all_product_treated).to(X_user_train.device).bool()
X_user_test, X_product, price = X_user_test.to(device), X_product.to(device), price.to(device)

# Calculate expected revenue if all control
utilities = model(X_user_test, X_product, price, all_product_control)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum()
print(f"Expected Revenue: ${expected_revenue.item():.2f}")

# Calculate expected revenue if all treated
utilities = model(X_user_test, X_product, price, all_product_treated)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue_treated = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum() * discount_percentage
print(f"Expected Revenue: ${expected_revenue_treated.item():.2f}")

# Calculate GTE
linear = (expected_revenue_treated-expected_revenue).cpu().detach().numpy()
linear = linear * 600 / 266
print(linear)
linear_all = abs((linear - true)/true)
print(linear_all)
# Out:
# Expected Revenue: $26.00
# Expected Revenue: $13.44
# -28.316716502483626
# 0.5875516321461894

# %% [markdown]
# ## PDL Estimator

# %%
# Prepare data
def prepare_data(user_features, product_features, prices):
    num_products = product_features.shape[0]
    all_x_other_products = []
    all_other_prices = []
    for i in range(num_products):
        indices = [j for j in range(num_products) if j != i]
        other_products = product_features[indices].reshape(-1)
        other_product_prices = prices[indices]
        all_x_other_products.append(other_products)
        all_other_prices.append(other_product_prices)
    # Convert lists to tensor
    all_x_other_products = torch.stack(all_x_other_products, dim=0)
    all_other_prices = torch.stack(all_other_prices, dim=0)
    return user_features, product_features, prices, all_x_other_products, all_other_prices

# %% [markdown]
# ### No features

# %%
class DeepMNLModel_No(nn.Module):
    """
    Price-only Deep MNL:
    u_ij = theta(p_j)
    Outside option utility = 0.
    """
    def __init__(self, num_product, hidden=5):
        super(DeepMNLModel_No, self).__init__()

        # theta(p_j):
        # Input:  [1]
        # Output: scalar utility
        self.theta = nn.Sequential(
        nn.Linear(1, hidden),
        nn.ReLU(),
        nn.Linear(hidden, 1)

)

    def forward(self, x_user, X_product, X_other_products, x_other_prices, price, prod_randomization):
        """
        Inputs used:
        - price: [M]  own price p_j
        - prod_randomization: [M]  treatment indicator
        """
        device = price.device
        N, M = x_user.shape[0], price.shape[0]

        # Apply treatment discount to own prices
        adjusted_price = torch.where(
            prod_randomization.to(device).bool(),
            price * discount_percentage,
            price
        )  # [M]

        # Prepare input for theta: [M, 1]
        pj_input = adjusted_price.unsqueeze(1)

        # Expand to all users: [N, M, 1]
        theta_input_exp = pj_input.unsqueeze(0).expand(N, -1, -1)

        # u_ij = theta(p_j): [N, M]
        utilities = self.theta(theta_input_exp).squeeze(-1)

        # Outside option utility = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utilities], dim=1)

        return utilities_with_outside

# %%
# Apply the model
pdlmodel = DeepMNLModel_No(
    num_product=X_product.shape[0],
    hidden=5
).to(device)

# Weight initialization
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)

pdlmodel.apply(init_weights)
# Out:
# DeepMNLModel_No(
#   (theta): Sequential(
#     (0): Linear(in_features=1, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# ----- Prepare validation data -----
prepared_val = prepare_data(
    X_user_val,
    X_product,
    price * (1 - (1 - discount_percentage) * prod_randomization)
)
user_features_val, product_features_val, _, all_x_other_products_val, all_other_prices_val = prepared_val

user_features_val = user_features_val.to(device)
product_features_val = product_features_val.to(device)
all_x_other_products_val = all_x_other_products_val.to(device)
all_other_prices_val = all_other_prices_val.to(device)
choice_val = choice_val.to(device)

# ----- Optimizer and scheduler -----
optimizer = optim.Adam(pdlmodel.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)
l2_lambda = 0  # L2 regularization coefficient

# Early stopping setup
best_val_loss = float('inf')
patience = 10
patience_counter = 0

# ----- Training loop -----
for epoch in range(5000):
    pdlmodel.train()
    optimizer.zero_grad()

    # Forward pass (train): use prepared prices and other-prices matrix
    outputs = pdlmodel(
        user_features,         # x_user (not used inside DeepMNLModel_No, but kept for interface)
        product_features,      # X_product (not used)
        all_x_other_products,  # X_other_products (not used in No model)
        all_other_prices,      # x_other_prices: p_-j
        prices,                # price: experimental p_j (after discount)
        prod_randomization     # can be ignored inside No model
    )
    choice_probabilities = F.log_softmax(outputs, dim=1)

    # Training loss
    loss = -torch.mean(
        choice_probabilities[
            torch.arange(choice_probabilities.shape[0], device=device),
            choice_train1
        ]
    )

    # L2 regularization
    l2_norm = sum(param.pow(2.0).sum() for param in pdlmodel.parameters())
    loss = loss + l2_lambda * l2_norm

    # Backward
    loss.backward()
    optimizer.step()

    # ----- Validation -----
    pdlmodel.eval()
    with torch.no_grad():
        val_outputs = pdlmodel(
            user_features_val,
            product_features_val,
            all_x_other_products_val,
            all_other_prices_val,
            prices,              # same product prices for validation
            prod_randomization
        )
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(
            val_choice_probabilities[
                torch.arange(val_choice_probabilities.shape[0], device=device),
                choice_val
            ]
        )

    print(
        f"Epoch {epoch+1}, "
        f"Training Loss: {loss.item():.4f}, "
        f"Validation Loss: {val_loss.item():.4f}"
    )

    # Early stopping logic
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        torch.save(pdlmodel.state_dict(), 'best_model.pth')
    else:
        patience_counter += 1

    if patience_counter >= patience:
        print("Early stopping triggered")
        break

    scheduler.step()
# Out:
# Epoch 1, Training Loss: 1.8457, Validation Loss: 1.8544
# Epoch 2, Training Loss: 1.8276, Validation Loss: 1.8375
# Epoch 3, Training Loss: 1.8097, Validation Loss: 1.8208
# Epoch 4, Training Loss: 1.7920, Validation Loss: 1.8045
# Epoch 5, Training Loss: 1.7746, Validation Loss: 1.7887
# Epoch 6, Training Loss: 1.7578, Validation Loss: 1.7739
# Epoch 7, Training Loss: 1.7417, Validation Loss: 1.7592
# Epoch 8, Training Loss: 1.7259, Validation Loss: 1.7448
# Epoch 9, Training Loss: 1.7103, Validation Loss: 1.7306
# Epoch 10, Training Loss: 1.6949, Validation Loss: 1.7166
# Epoch 11, Training Loss: 1.6798, Validation Loss: 1.7028
# Epoch 12, Training Loss: 1.6650, Validation Loss: 1.6892
# Epoch 13, Training Loss: 1.6503, Validation Loss: 1.6758
# Epoch 14, Training Loss: 1.6360, Validation Loss: 1.6627
# Epoch 15, Training Loss: 1.6218, Validation Loss: 1.6497
# Epoch 16, Training Loss: 1.6080, Validation Loss: 1.6370
# Epoch 17, Training Loss: 1.5944, Validation Loss: 1.6245
# Epoch 18, Training Loss: 1.5810, Validation Loss: 1.6123
# Epoch 19, Training Loss: 1.5680, Validation Loss: 1.6003
# Epoch 20, Training Loss: 1.5552, Validation Loss: 1.5885
# Epoch 21, Training Loss: 1.5427, Validation Loss: 1.5770
# Epoch 22, Training Loss: 1.5304, Validation Loss: 1.5658
# Epoch 23, Training Loss: 1.5185, Validation Loss: 1.5548
# Epoch 24, Training Loss: 1.5069, Validation Loss: 1.5441
# Epoch 25, Training Loss: 1.4956, Validation Loss: 1.5336
# Epoch 26, Training Loss: 1.4846, Validation Loss: 1.5234
# Epoch 27, Training Loss: 1.4739, Validation Loss: 1.5135
# Epoch 28, Training Loss: 1.4636, Validation Loss: 1.5039
# Epoch 29, Training Loss: 1.4536, Validation Loss: 1.4945
# Epoch 30, Training Loss: 1.4439, Validation Loss: 1.4854
# Epoch 31, Training Loss: 1.4345, Validation Loss: 1.4766
# Epoch 32, Training Loss: 1.4255, Validation Loss: 1.4681
# Epoch 33, Training Loss: 1.4168, Validation Loss: 1.4598
# Epoch 34, Training Loss: 1.4085, Validation Loss: 1.4518
# Epoch 35, Training Loss: 1.4005, Validation Loss: 1.4441
# Epoch 36, Training Loss: 1.3928, Validation Loss: 1.4365
# Epoch 37, Training Loss: 1.3854, Validation Loss: 1.4293
# Epoch 38, Training Loss: 1.3784, Validation Loss: 1.4222
# Epoch 39, Training Loss: 1.3716, Validation Loss: 1.4154
# Epoch 40, Training Loss: 1.3652, Validation Loss: 1.4088
# Epoch 41, Training Loss: 1.3590, Validation Loss: 1.4023
# Epoch 42, Training Loss: 1.3531, Validation Loss: 1.3961
# Epoch 43, Training Loss: 1.3475, Validation Loss: 1.3900
# Epoch 44, Training Loss: 1.3422, Validation Loss: 1.3841
# Epoch 45, Training Loss: 1.3371, Validation Loss: 1.3783
# Epoch 46, Training Loss: 1.3322, Validation Loss: 1.3727
# Epoch 47, Training Loss: 1.3276, Validation Loss: 1.3671
# Epoch 48, Training Loss: 1.3232, Validation Loss: 1.3618
# Epoch 49, Training Loss: 1.3189, Validation Loss: 1.3565
# Epoch 50, Training Loss: 1.3149, Validation Loss: 1.3513
# Epoch 51, Training Loss: 1.3110, Validation Loss: 1.3462
# Epoch 52, Training Loss: 1.3073, Validation Loss: 1.3412
# Epoch 53, Training Loss: 1.3038, Validation Loss: 1.3363
# Epoch 54, Training Loss: 1.3004, Validation Loss: 1.3315
# Epoch 55, Training Loss: 1.2971, Validation Loss: 1.3267
# Epoch 56, Training Loss: 1.2940, Validation Loss: 1.3220
# Epoch 57, Training Loss: 1.2910, Validation Loss: 1.3173
# Epoch 58, Training Loss: 1.2880, Validation Loss: 1.3127
# Epoch 59, Training Loss: 1.2852, Validation Loss: 1.3082
# Epoch 60, Training Loss: 1.2825, Validation Loss: 1.3037
# Epoch 61, Training Loss: 1.2799, Validation Loss: 1.2992
# Epoch 62, Training Loss: 1.2773, Validation Loss: 1.2948
# Epoch 63, Training Loss: 1.2749, Validation Loss: 1.2905
# Epoch 64, Training Loss: 1.2725, Validation Loss: 1.2862
# Epoch 65, Training Loss: 1.2702, Validation Loss: 1.2819
# Epoch 66, Training Loss: 1.2679, Validation Loss: 1.2777
# Epoch 67, Training Loss: 1.2657, Validation Loss: 1.2736
# Epoch 68, Training Loss: 1.2636, Validation Loss: 1.2695
# Epoch 69, Training Loss: 1.2615, Validation Loss: 1.2654
# Epoch 70, Training Loss: 1.2595, Validation Loss: 1.2614
# Epoch 71, Training Loss: 1.2575, Validation Loss: 1.2575
# Epoch 72, Training Loss: 1.2556, Validation Loss: 1.2536
# Epoch 73, Training Loss: 1.2538, Validation Loss: 1.2497
# Epoch 74, Training Loss: 1.2520, Validation Loss: 1.2459
# Epoch 75, Training Loss: 1.2503, Validation Loss: 1.2422
# Epoch 76, Training Loss: 1.2486, Validation Loss: 1.2386
# Epoch 77, Training Loss: 1.2469, Validation Loss: 1.2350
# Epoch 78, Training Loss: 1.2454, Validation Loss: 1.2314
# Epoch 79, Training Loss: 1.2438, Validation Loss: 1.2280
# Epoch 80, Training Loss: 1.2424, Validation Loss: 1.2246
# Epoch 81, Training Loss: 1.2410, Validation Loss: 1.2213
# Epoch 82, Training Loss: 1.2396, Validation Loss: 1.2180
# Epoch 83, Training Loss: 1.2383, Validation Loss: 1.2148
# Epoch 84, Training Loss: 1.2370, Validation Loss: 1.2117
# Epoch 85, Training Loss: 1.2359, Validation Loss: 1.2087
# Epoch 86, Training Loss: 1.2347, Validation Loss: 1.2057
# Epoch 87, Training Loss: 1.2336, Validation Loss: 1.2028
# Epoch 88, Training Loss: 1.2326, Validation Loss: 1.2000
# Epoch 89, Training Loss: 1.2316, Validation Loss: 1.1973
# Epoch 90, Training Loss: 1.2306, Validation Loss: 1.1946
# Epoch 91, Training Loss: 1.2298, Validation Loss: 1.1920
# Epoch 92, Training Loss: 1.2289, Validation Loss: 1.1895
# Epoch 93, Training Loss: 1.2281, Validation Loss: 1.1871
# Epoch 94, Training Loss: 1.2273, Validation Loss: 1.1847
# Epoch 95, Training Loss: 1.2266, Validation Loss: 1.1824
# Epoch 96, Training Loss: 1.2259, Validation Loss: 1.1802
# Epoch 97, Training Loss: 1.2253, Validation Loss: 1.1781
# Epoch 98, Training Loss: 1.2247, Validation Loss: 1.1760
# Epoch 99, Training Loss: 1.2241, Validation Loss: 1.1740
# Epoch 100, Training Loss: 1.2236, Validation Loss: 1.1720
# Epoch 101, Training Loss: 1.2231, Validation Loss: 1.1702
# Epoch 102, Training Loss: 1.2226, Validation Loss: 1.1683
# Epoch 103, Training Loss: 1.2222, Validation Loss: 1.1666
# Epoch 104, Training Loss: 1.2218, Validation Loss: 1.1649
# Epoch 105, Training Loss: 1.2214, Validation Loss: 1.1633
# Epoch 106, Training Loss: 1.2210, Validation Loss: 1.1617
# Epoch 107, Training Loss: 1.2207, Validation Loss: 1.1602
# Epoch 108, Training Loss: 1.2204, Validation Loss: 1.1588
# Epoch 109, Training Loss: 1.2201, Validation Loss: 1.1574
# Epoch 110, Training Loss: 1.2198, Validation Loss: 1.1561
# Epoch 111, Training Loss: 1.2196, Validation Loss: 1.1548
# Epoch 112, Training Loss: 1.2194, Validation Loss: 1.1536
# Epoch 113, Training Loss: 1.2191, Validation Loss: 1.1525
# Epoch 114, Training Loss: 1.2189, Validation Loss: 1.1513
# Epoch 115, Training Loss: 1.2188, Validation Loss: 1.1503
# Epoch 116, Training Loss: 1.2186, Validation Loss: 1.1493
# Epoch 117, Training Loss: 1.2184, Validation Loss: 1.1483
# Epoch 118, Training Loss: 1.2183, Validation Loss: 1.1474
# Epoch 119, Training Loss: 1.2182, Validation Loss: 1.1465
# Epoch 120, Training Loss: 1.2181, Validation Loss: 1.1457
# Epoch 121, Training Loss: 1.2180, Validation Loss: 1.1449
# Epoch 122, Training Loss: 1.2179, Validation Loss: 1.1441
# Epoch 123, Training Loss: 1.2178, Validation Loss: 1.1434
# Epoch 124, Training Loss: 1.2177, Validation Loss: 1.1427
# Epoch 125, Training Loss: 1.2177, Validation Loss: 1.1420
# Epoch 126, Training Loss: 1.2176, Validation Loss: 1.1414
# Epoch 127, Training Loss: 1.2176, Validation Loss: 1.1409
# Epoch 128, Training Loss: 1.2175, Validation Loss: 1.1403
# Epoch 129, Training Loss: 1.2175, Validation Loss: 1.1398
# Epoch 130, Training Loss: 1.2174, Validation Loss: 1.1394
# Epoch 131, Training Loss: 1.2174, Validation Loss: 1.1389
# Epoch 132, Training Loss: 1.2174, Validation Loss: 1.1385
# Epoch 133, Training Loss: 1.2174, Validation Loss: 1.1381
# Epoch 134, Training Loss: 1.2173, Validation Loss: 1.1377
# Epoch 135, Training Loss: 1.2173, Validation Loss: 1.1373
# Epoch 136, Training Loss: 1.2173, Validation Loss: 1.1370
# Epoch 137, Training Loss: 1.2173, Validation Loss: 1.1366
# Epoch 138, Training Loss: 1.2173, Validation Loss: 1.1363
# Epoch 139, Training Loss: 1.2173, Validation Loss: 1.1360
# Epoch 140, Training Loss: 1.2173, Validation Loss: 1.1357
# Epoch 141, Training Loss: 1.2173, Validation Loss: 1.1355
# Epoch 142, Training Loss: 1.2173, Validation Loss: 1.1352
# Epoch 143, Training Loss: 1.2173, Validation Loss: 1.1350
# Epoch 144, Training Loss: 1.2173, Validation Loss: 1.1347
# Epoch 145, Training Loss: 1.2172, Validation Loss: 1.1345
# Epoch 146, Training Loss: 1.2172, Validation Loss: 1.1343
# Epoch 147, Training Loss: 1.2172, Validation Loss: 1.1342
# Epoch 148, Training Loss: 1.2172, Validation Loss: 1.1340
# Epoch 149, Training Loss: 1.2172, Validation Loss: 1.1338
# Epoch 150, Training Loss: 1.2172, Validation Loss: 1.1337
# Epoch 151, Training Loss: 1.2172, Validation Loss: 1.1336
# Epoch 152, Training Loss: 1.2172, Validation Loss: 1.1335
# Epoch 153, Training Loss: 1.2172, Validation Loss: 1.1334
# Epoch 154, Training Loss: 1.2172, Validation Loss: 1.1333
# Epoch 155, Training Loss: 1.2172, Validation Loss: 1.1332
# Epoch 156, Training Loss: 1.2172, Validation Loss: 1.1331
# Epoch 157, Training Loss: 1.2172, Validation Loss: 1.1331
# Epoch 158, Training Loss: 1.2172, Validation Loss: 1.1330
# Epoch 159, Training Loss: 1.2172, Validation Loss: 1.1330
# Epoch 160, Training Loss: 1.2172, Validation Loss: 1.1329
# Epoch 161, Training Loss: 1.2172, Validation Loss: 1.1329
# Epoch 162, Training Loss: 1.2172, Validation Loss: 1.1329
# Epoch 163, Training Loss: 1.2172, Validation Loss: 1.1329
# Epoch 164, Training Loss: 1.2172, Validation Loss: 1.1328
# Epoch 165, Training Loss: 1.2172, Validation Loss: 1.1328
# Epoch 166, Training Loss: 1.2172, Validation Loss: 1.1328
# Epoch 167, Training Loss: 1.2172, Validation Loss: 1.1328
# Epoch 168, Training Loss: 1.2172, Validation Loss: 1.1328
# Epoch 169, Training Loss: 1.2172, Validation Loss: 1.1328
# Epoch 170, Training Loss: 1.2172, Validation Loss: 1.1328
# Epoch 171, Training Loss: 1.2172, Validation Loss: 1.1329
# Epoch 172, Training Loss: 1.2172, Validation Loss: 1.1329
# Epoch 173, Training Loss: 1.2172, Validation Loss: 1.1329
# Epoch 174, Training Loss: 1.2172, Validation Loss: 1.1329
# Epoch 175, Training Loss: 1.2172, Validation Loss: 1.1329
# Epoch 176, Training Loss: 1.2172, Validation Loss: 1.1329
# Epoch 177, Training Loss: 1.2172, Validation Loss: 1.1329
# Early stopping triggered

# %%
# All-control and all-treated for test set
num_product = X_product.shape[0]

# All control: product_randomization = 0
all_product_control = torch.zeros(num_product, device=device).bool()

# All treated: product_randomization = 1
all_product_treated = torch.ones(num_product, device=device).bool()

# Move base price and test users/products to device
X_user_test = X_user_test.to(device)
X_product = X_product.to(device)
price = price.to(device)

# --------- Expected revenue: all control ----------
# Control prices = base prices (no discount)
price_control = price.clone()

# Prepare test data under all-control prices
user_test_ctrl, product_test_ctrl, prices_ctrl, x_other_products_ctrl, other_prices_ctrl = prepare_data(
    X_user_test,
    X_product,
    price_control
)

utilities_ctrl = pdlmodel(
    user_test_ctrl,
    product_test_ctrl,
    x_other_products_ctrl,
    other_prices_ctrl,
    prices_ctrl,          # control prices
    all_product_control   # all False
)

probabilities_ctrl = F.softmax(utilities_ctrl, dim=1)

price_with_outside_ctrl = torch.cat(
    (torch.zeros(1, device=price.device), prices_ctrl), dim=0
)  # [M+1]

expected_revenue_ctrl = torch.sum(
    probabilities_ctrl * price_with_outside_ctrl.unsqueeze(0).expand_as(probabilities_ctrl),
    dim=1
).sum()

print(f"Expected Revenue (all control): ${expected_revenue_ctrl.item():.2f}")

# --------- Expected revenue: all treated ----------
# Treated prices = discounted prices
price_treated = price * discount_percentage

user_test_trt, product_test_trt, prices_trt, x_other_products_trt, other_prices_trt = prepare_data(
    X_user_test,
    X_product,
    price_treated
)

utilities_trt = pdlmodel(
    user_test_trt,
    product_test_trt,
    x_other_products_trt,
    other_prices_trt,
    prices_trt,          # treated prices
    all_product_treated  # all True
)

probabilities_trt = F.softmax(utilities_trt, dim=1)

price_with_outside_trt = torch.cat(
    (torch.zeros(1, device=price.device), prices_trt), dim=0
)

expected_revenue_trt = torch.sum(
    probabilities_trt * price_with_outside_trt.unsqueeze(0).expand_as(probabilities_trt),
    dim=1
).sum()

print(f"Expected Revenue (all treated): ${expected_revenue_trt.item():.2f}")

# --------- GTE ----------
pdl = (expected_revenue_trt - expected_revenue_ctrl).cpu().detach().numpy() * 600 / 266
print(pdl)

pdl_no = abs((pdl - true) / true)
print(pdl_no)
# Out:
# Expected Revenue (all control): $37.55
# Expected Revenue (all treated): $8.87
# -64.70293747751336
# 0.05756654534409455

# %% [markdown]
# ### Only user features

# %%
class DeepMNLModel_UserOnly(nn.Module):
    """
    Deep MNL (user + own price only):
    u_ij = theta(x_i, p_j)
    Outside option utility = 0.
    """
    def __init__(self, user_dim, num_product, hidden=5):
        super(DeepMNLModel_UserOnly, self).__init__()

        # theta(x_i, p_j)
        # Input per (i,j): [user_dim + 1]
        self.theta = nn.Sequential(
            nn.Linear(user_dim + 1, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, x_user, X_product, X_other_products,
                x_other_prices, price, prod_randomization):

        device = price.device
        N, M = x_user.shape[0], price.shape[0]

        # p_j: [M, 1]
        pj_feat = price.unsqueeze(1)          # [M, 1]

        pj_feat_exp = pj_feat.unsqueeze(0).expand(N, -1, -1)

        x_user_exp = x_user.unsqueeze(1).expand(-1, M, -1)

        theta_input = torch.cat([x_user_exp, pj_feat_exp], dim=2)

        theta_input_flat = theta_input.reshape(N * M, -1)

        # u_ij: [N*M, 1] -> [N, M]
        utilities = self.theta(theta_input_flat).view(N, M)

        # outside option utility = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utilities], dim=1)

        return utilities_with_outside

# %%
# Apply the model
pdlmodel = DeepMNLModel_UserOnly(
    user_dim=X_user.shape[1],
    num_product=X_product.shape[0],
    hidden=5
).to(device)

# Weight initialization
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)

pdlmodel.apply(init_weights)
# Out:
# DeepMNLModel_UserOnly(
#   (theta): Sequential(
#     (0): Linear(in_features=4, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# ----- Prepare validation data -----
prepared_val = prepare_data(
    X_user_val,
    X_product,
    price * (1 - (1 - discount_percentage) * prod_randomization)
)
user_features_val, product_features_val, _, all_x_other_products_val, all_other_prices_val = prepared_val

user_features_val = user_features_val.to(device)
product_features_val = product_features_val.to(device)
all_x_other_products_val = all_x_other_products_val.to(device)
all_other_prices_val = all_other_prices_val.to(device)
choice_val = choice_val.to(device)

# ----- Optimizer and scheduler -----
optimizer = optim.Adam(pdlmodel.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)
l2_lambda = 0  # L2 regularization coefficient

# Early stopping setup
best_val_loss = float('inf')
patience = 10
patience_counter = 0

# ----- Training loop -----
for epoch in range(5000):
    pdlmodel.train()
    optimizer.zero_grad()

    # Forward pass (train): use prepared prices and other-prices matrix
    outputs = pdlmodel(
        user_features,         # x_user (not used inside DeepMNLModel_No, but kept for interface)
        product_features,      # X_product (not used)
        all_x_other_products,  # X_other_products (not used in No model)
        all_other_prices,      # x_other_prices: p_-j
        prices,                # price: experimental p_j (after discount)
        prod_randomization     # can be ignored inside No model
    )
    choice_probabilities = F.log_softmax(outputs, dim=1)

    # Training loss
    loss = -torch.mean(
        choice_probabilities[
            torch.arange(choice_probabilities.shape[0], device=device),
            choice_train1
        ]
    )

    # L2 regularization
    l2_norm = sum(param.pow(2.0).sum() for param in pdlmodel.parameters())
    loss = loss + l2_lambda * l2_norm

    # Backward
    loss.backward()
    optimizer.step()

    # ----- Validation -----
    pdlmodel.eval()
    with torch.no_grad():
        val_outputs = pdlmodel(
            user_features_val,
            product_features_val,
            all_x_other_products_val,
            all_other_prices_val,
            prices,              # same product prices for validation
            prod_randomization
        )
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(
            val_choice_probabilities[
                torch.arange(val_choice_probabilities.shape[0], device=device),
                choice_val
            ]
        )

    print(
        f"Epoch {epoch+1}, "
        f"Training Loss: {loss.item():.4f}, "
        f"Validation Loss: {val_loss.item():.4f}"
    )

    # Early stopping logic
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        torch.save(pdlmodel.state_dict(), 'best_model.pth')
    else:
        patience_counter += 1

    if patience_counter >= patience:
        print("Early stopping triggered")
        break

    scheduler.step()
# Out:
# Epoch 1, Training Loss: 1.9507, Validation Loss: 1.9826
# Epoch 2, Training Loss: 1.9270, Validation Loss: 1.9560
# Epoch 3, Training Loss: 1.9032, Validation Loss: 1.9297
# Epoch 4, Training Loss: 1.8794, Validation Loss: 1.9033
# Epoch 5, Training Loss: 1.8558, Validation Loss: 1.8767
# Epoch 6, Training Loss: 1.8321, Validation Loss: 1.8495
# Epoch 7, Training Loss: 1.8084, Validation Loss: 1.8223
# Epoch 8, Training Loss: 1.7849, Validation Loss: 1.7955
# Epoch 9, Training Loss: 1.7615, Validation Loss: 1.7682
# Epoch 10, Training Loss: 1.7377, Validation Loss: 1.7411
# Epoch 11, Training Loss: 1.7145, Validation Loss: 1.7142
# Epoch 12, Training Loss: 1.6912, Validation Loss: 1.6871
# Epoch 13, Training Loss: 1.6676, Validation Loss: 1.6602
# Epoch 14, Training Loss: 1.6443, Validation Loss: 1.6325
# Epoch 15, Training Loss: 1.6207, Validation Loss: 1.6038
# Epoch 16, Training Loss: 1.5965, Validation Loss: 1.5740
# Epoch 17, Training Loss: 1.5720, Validation Loss: 1.5439
# Epoch 18, Training Loss: 1.5472, Validation Loss: 1.5141
# Epoch 19, Training Loss: 1.5226, Validation Loss: 1.4839
# Epoch 20, Training Loss: 1.4984, Validation Loss: 1.4542
# Epoch 21, Training Loss: 1.4745, Validation Loss: 1.4267
# Epoch 22, Training Loss: 1.4508, Validation Loss: 1.3999
# Epoch 23, Training Loss: 1.4275, Validation Loss: 1.3737
# Epoch 24, Training Loss: 1.4049, Validation Loss: 1.3485
# Epoch 25, Training Loss: 1.3828, Validation Loss: 1.3242
# Epoch 26, Training Loss: 1.3608, Validation Loss: 1.3018
# Epoch 27, Training Loss: 1.3399, Validation Loss: 1.2823
# Epoch 28, Training Loss: 1.3200, Validation Loss: 1.2643
# Epoch 29, Training Loss: 1.3010, Validation Loss: 1.2471
# Epoch 30, Training Loss: 1.2833, Validation Loss: 1.2320
# Epoch 31, Training Loss: 1.2669, Validation Loss: 1.2188
# Epoch 32, Training Loss: 1.2523, Validation Loss: 1.2080
# Epoch 33, Training Loss: 1.2395, Validation Loss: 1.1995
# Epoch 34, Training Loss: 1.2291, Validation Loss: 1.1919
# Epoch 35, Training Loss: 1.2212, Validation Loss: 1.1860
# Epoch 36, Training Loss: 1.2157, Validation Loss: 1.1821
# Epoch 37, Training Loss: 1.2122, Validation Loss: 1.1799
# Epoch 38, Training Loss: 1.2104, Validation Loss: 1.1791
# Epoch 39, Training Loss: 1.2101, Validation Loss: 1.1793
# Epoch 40, Training Loss: 1.2109, Validation Loss: 1.1801
# Epoch 41, Training Loss: 1.2124, Validation Loss: 1.1811
# Epoch 42, Training Loss: 1.2142, Validation Loss: 1.1821
# Epoch 43, Training Loss: 1.2162, Validation Loss: 1.1828
# Epoch 44, Training Loss: 1.2179, Validation Loss: 1.1831
# Epoch 45, Training Loss: 1.2192, Validation Loss: 1.1828
# Epoch 46, Training Loss: 1.2201, Validation Loss: 1.1819
# Epoch 47, Training Loss: 1.2204, Validation Loss: 1.1804
# Epoch 48, Training Loss: 1.2201, Validation Loss: 1.1785
# Epoch 49, Training Loss: 1.2193, Validation Loss: 1.1761
# Epoch 50, Training Loss: 1.2181, Validation Loss: 1.1733
# Epoch 51, Training Loss: 1.2166, Validation Loss: 1.1704
# Epoch 52, Training Loss: 1.2148, Validation Loss: 1.1673
# Epoch 53, Training Loss: 1.2130, Validation Loss: 1.1643
# Epoch 54, Training Loss: 1.2111, Validation Loss: 1.1613
# Epoch 55, Training Loss: 1.2092, Validation Loss: 1.1584
# Epoch 56, Training Loss: 1.2075, Validation Loss: 1.1558
# Epoch 57, Training Loss: 1.2060, Validation Loss: 1.1534
# Epoch 58, Training Loss: 1.2047, Validation Loss: 1.1512
# Epoch 59, Training Loss: 1.2036, Validation Loss: 1.1493
# Epoch 60, Training Loss: 1.2028, Validation Loss: 1.1476
# Epoch 61, Training Loss: 1.2022, Validation Loss: 1.1461
# Epoch 62, Training Loss: 1.2017, Validation Loss: 1.1448
# Epoch 63, Training Loss: 1.2015, Validation Loss: 1.1437
# Epoch 64, Training Loss: 1.2013, Validation Loss: 1.1426
# Epoch 65, Training Loss: 1.2012, Validation Loss: 1.1416
# Epoch 66, Training Loss: 1.2012, Validation Loss: 1.1407
# Epoch 67, Training Loss: 1.2012, Validation Loss: 1.1397
# Epoch 68, Training Loss: 1.2013, Validation Loss: 1.1387
# Epoch 69, Training Loss: 1.2013, Validation Loss: 1.1377
# Epoch 70, Training Loss: 1.2012, Validation Loss: 1.1367
# Epoch 71, Training Loss: 1.2011, Validation Loss: 1.1357
# Epoch 72, Training Loss: 1.2009, Validation Loss: 1.1347
# Epoch 73, Training Loss: 1.2007, Validation Loss: 1.1337
# Epoch 74, Training Loss: 1.2005, Validation Loss: 1.1327
# Epoch 75, Training Loss: 1.2002, Validation Loss: 1.1318
# Epoch 76, Training Loss: 1.1999, Validation Loss: 1.1309
# Epoch 77, Training Loss: 1.1996, Validation Loss: 1.1300
# Epoch 78, Training Loss: 1.1992, Validation Loss: 1.1291
# Epoch 79, Training Loss: 1.1989, Validation Loss: 1.1283
# Epoch 80, Training Loss: 1.1986, Validation Loss: 1.1275
# Epoch 81, Training Loss: 1.1984, Validation Loss: 1.1268
# Epoch 82, Training Loss: 1.1982, Validation Loss: 1.1261
# Epoch 83, Training Loss: 1.1981, Validation Loss: 1.1254
# Epoch 84, Training Loss: 1.1980, Validation Loss: 1.1248
# Epoch 85, Training Loss: 1.1979, Validation Loss: 1.1241
# Epoch 86, Training Loss: 1.1979, Validation Loss: 1.1235
# Epoch 87, Training Loss: 1.1978, Validation Loss: 1.1229
# Epoch 88, Training Loss: 1.1978, Validation Loss: 1.1223
# Epoch 89, Training Loss: 1.1977, Validation Loss: 1.1217
# Epoch 90, Training Loss: 1.1977, Validation Loss: 1.1211
# Epoch 91, Training Loss: 1.1976, Validation Loss: 1.1205
# Epoch 92, Training Loss: 1.1975, Validation Loss: 1.1199
# Epoch 93, Training Loss: 1.1974, Validation Loss: 1.1193
# Epoch 94, Training Loss: 1.1973, Validation Loss: 1.1187
# Epoch 95, Training Loss: 1.1972, Validation Loss: 1.1181
# Epoch 96, Training Loss: 1.1972, Validation Loss: 1.1175
# Epoch 97, Training Loss: 1.1971, Validation Loss: 1.1170
# Epoch 98, Training Loss: 1.1970, Validation Loss: 1.1165
# Epoch 99, Training Loss: 1.1970, Validation Loss: 1.1160
# Epoch 100, Training Loss: 1.1969, Validation Loss: 1.1155
# Epoch 101, Training Loss: 1.1969, Validation Loss: 1.1151
# Epoch 102, Training Loss: 1.1969, Validation Loss: 1.1146
# Epoch 103, Training Loss: 1.1968, Validation Loss: 1.1142
# Epoch 104, Training Loss: 1.1968, Validation Loss: 1.1138
# Epoch 105, Training Loss: 1.1968, Validation Loss: 1.1135
# Epoch 106, Training Loss: 1.1967, Validation Loss: 1.1131
# Epoch 107, Training Loss: 1.1967, Validation Loss: 1.1128
# Epoch 108, Training Loss: 1.1967, Validation Loss: 1.1124
# Epoch 109, Training Loss: 1.1966, Validation Loss: 1.1121
# Epoch 110, Training Loss: 1.1966, Validation Loss: 1.1118
# Epoch 111, Training Loss: 1.1966, Validation Loss: 1.1116
# Epoch 112, Training Loss: 1.1966, Validation Loss: 1.1113
# Epoch 113, Training Loss: 1.1965, Validation Loss: 1.1110
# Epoch 114, Training Loss: 1.1965, Validation Loss: 1.1108
# Epoch 115, Training Loss: 1.1965, Validation Loss: 1.1106
# Epoch 116, Training Loss: 1.1964, Validation Loss: 1.1104
# Epoch 117, Training Loss: 1.1964, Validation Loss: 1.1102
# Epoch 118, Training Loss: 1.1964, Validation Loss: 1.1100
# Epoch 119, Training Loss: 1.1963, Validation Loss: 1.1098
# Epoch 120, Training Loss: 1.1963, Validation Loss: 1.1096
# Epoch 121, Training Loss: 1.1963, Validation Loss: 1.1094
# Epoch 122, Training Loss: 1.1963, Validation Loss: 1.1092
# Epoch 123, Training Loss: 1.1963, Validation Loss: 1.1090
# Epoch 124, Training Loss: 1.1963, Validation Loss: 1.1088
# Epoch 125, Training Loss: 1.1963, Validation Loss: 1.1086
# Epoch 126, Training Loss: 1.1962, Validation Loss: 1.1084
# Epoch 127, Training Loss: 1.1962, Validation Loss: 1.1083
# Epoch 128, Training Loss: 1.1962, Validation Loss: 1.1081
# Epoch 129, Training Loss: 1.1962, Validation Loss: 1.1079
# Epoch 130, Training Loss: 1.1962, Validation Loss: 1.1078
# Epoch 131, Training Loss: 1.1962, Validation Loss: 1.1076
# Epoch 132, Training Loss: 1.1962, Validation Loss: 1.1075
# Epoch 133, Training Loss: 1.1961, Validation Loss: 1.1074
# Epoch 134, Training Loss: 1.1961, Validation Loss: 1.1073
# Epoch 135, Training Loss: 1.1961, Validation Loss: 1.1072
# Epoch 136, Training Loss: 1.1961, Validation Loss: 1.1071
# Epoch 137, Training Loss: 1.1961, Validation Loss: 1.1070
# Epoch 138, Training Loss: 1.1961, Validation Loss: 1.1069
# Epoch 139, Training Loss: 1.1961, Validation Loss: 1.1068
# Epoch 140, Training Loss: 1.1961, Validation Loss: 1.1067
# Epoch 141, Training Loss: 1.1961, Validation Loss: 1.1066
# Epoch 142, Training Loss: 1.1961, Validation Loss: 1.1065
# Epoch 143, Training Loss: 1.1961, Validation Loss: 1.1064
# Epoch 144, Training Loss: 1.1960, Validation Loss: 1.1063
# Epoch 145, Training Loss: 1.1960, Validation Loss: 1.1063
# Epoch 146, Training Loss: 1.1960, Validation Loss: 1.1062
# Epoch 147, Training Loss: 1.1960, Validation Loss: 1.1061
# Epoch 148, Training Loss: 1.1960, Validation Loss: 1.1061
# Epoch 149, Training Loss: 1.1960, Validation Loss: 1.1060
# Epoch 150, Training Loss: 1.1960, Validation Loss: 1.1060
# Epoch 151, Training Loss: 1.1960, Validation Loss: 1.1059
# Epoch 152, Training Loss: 1.1960, Validation Loss: 1.1059
# Epoch 153, Training Loss: 1.1960, Validation Loss: 1.1058
# Epoch 154, Training Loss: 1.1960, Validation Loss: 1.1058
# Epoch 155, Training Loss: 1.1960, Validation Loss: 1.1057
# Epoch 156, Training Loss: 1.1960, Validation Loss: 1.1057
# Epoch 157, Training Loss: 1.1960, Validation Loss: 1.1057
# Epoch 158, Training Loss: 1.1960, Validation Loss: 1.1056
# Epoch 159, Training Loss: 1.1960, Validation Loss: 1.1056
# Epoch 160, Training Loss: 1.1959, Validation Loss: 1.1056
# Epoch 161, Training Loss: 1.1959, Validation Loss: 1.1056
# Epoch 162, Training Loss: 1.1959, Validation Loss: 1.1056
# Epoch 163, Training Loss: 1.1959, Validation Loss: 1.1055
# Epoch 164, Training Loss: 1.1959, Validation Loss: 1.1055
# Epoch 165, Training Loss: 1.1959, Validation Loss: 1.1055
# Epoch 166, Training Loss: 1.1959, Validation Loss: 1.1055
# Epoch 167, Training Loss: 1.1959, Validation Loss: 1.1055
# Epoch 168, Training Loss: 1.1959, Validation Loss: 1.1055
# Epoch 169, Training Loss: 1.1959, Validation Loss: 1.1055
# Epoch 170, Training Loss: 1.1959, Validation Loss: 1.1055
# Epoch 171, Training Loss: 1.1959, Validation Loss: 1.1055
# Epoch 172, Training Loss: 1.1959, Validation Loss: 1.1055
# Epoch 173, Training Loss: 1.1959, Validation Loss: 1.1055
# Epoch 174, Training Loss: 1.1959, Validation Loss: 1.1055
# Epoch 175, Training Loss: 1.1959, Validation Loss: 1.1055
# Epoch 176, Training Loss: 1.1959, Validation Loss: 1.1055
# Epoch 177, Training Loss: 1.1959, Validation Loss: 1.1055
# Epoch 178, Training Loss: 1.1959, Validation Loss: 1.1055
# Epoch 179, Training Loss: 1.1959, Validation Loss: 1.1055
# Epoch 180, Training Loss: 1.1959, Validation Loss: 1.1055
# Early stopping triggered

# %%
# All-control and all-treated for test set
num_product = X_product.shape[0]

# All control: product_randomization = 0
all_product_control = torch.zeros(num_product, device=device).bool()

# All treated: product_randomization = 1
all_product_treated = torch.ones(num_product, device=device).bool()

# Move base price and test users/products to device
X_user_test = X_user_test.to(device)
X_product = X_product.to(device)
price = price.to(device)

# --------- Expected revenue: all control ----------
# Control prices = base prices (no discount)
price_control = price.clone()

# Prepare test data under all-control prices
user_test_ctrl, product_test_ctrl, prices_ctrl, x_other_products_ctrl, other_prices_ctrl = prepare_data(
    X_user_test,
    X_product,
    price_control
)

utilities_ctrl = pdlmodel(
    user_test_ctrl,
    product_test_ctrl,
    x_other_products_ctrl,
    other_prices_ctrl,
    prices_ctrl,          # control prices
    all_product_control   # all False
)

probabilities_ctrl = F.softmax(utilities_ctrl, dim=1)

price_with_outside_ctrl = torch.cat(
    (torch.zeros(1, device=price.device), prices_ctrl), dim=0
)  # [M+1]

expected_revenue_ctrl = torch.sum(
    probabilities_ctrl * price_with_outside_ctrl.unsqueeze(0).expand_as(probabilities_ctrl),
    dim=1
).sum()

print(f"Expected Revenue (all control): ${expected_revenue_ctrl.item():.2f}")

# --------- Expected revenue: all treated ----------
# Treated prices = discounted prices
price_treated = price * discount_percentage

user_test_trt, product_test_trt, prices_trt, x_other_products_trt, other_prices_trt = prepare_data(
    X_user_test,
    X_product,
    price_treated
)

utilities_trt = pdlmodel(
    user_test_trt,
    product_test_trt,
    x_other_products_trt,
    other_prices_trt,
    prices_trt,          # treated prices
    all_product_treated  # all True
)

probabilities_trt = F.softmax(utilities_trt, dim=1)

price_with_outside_trt = torch.cat(
    (torch.zeros(1, device=price.device), prices_trt), dim=0
)

expected_revenue_trt = torch.sum(
    probabilities_trt * price_with_outside_trt.unsqueeze(0).expand_as(probabilities_trt),
    dim=1
).sum()

print(f"Expected Revenue (all treated): ${expected_revenue_trt.item():.2f}")

# --------- GTE ----------
pdl = (expected_revenue_trt - expected_revenue_ctrl).cpu().detach().numpy() * 600 / 266
print(pdl)

pdl_user = abs((pdl - true) / true)
print(pdl_user)
# Out:
# Expected Revenue (all control): $36.02
# Expected Revenue (all treated): $8.55
# -61.969047202203505
# 0.09738714325289709

# %% [markdown]
# ### Only product features

# %%
class DeepMNLModel_ProductOnly(nn.Module):
    """
    Deep MNL (product-only):
    u_ij = theta(z_j, z_-j, p_j)
    Outside option utility = 0.
    """
    def __init__(self, product_dim, num_product, hidden=5):
        super(DeepMNLModel_ProductOnly, self).__init__()

        # Aggregate other products' features z_-j:
        # Input:  [M, (M-1)*F_p]
        # Output: [M, hidden]
        self.other_product_features_layers = nn.Sequential(
            nn.Linear(product_dim * (num_product - 1), hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU()
        )

        # theta(z_j, z_-j, p_j)
        # Input per (i,j): [F_p + hidden (z_-j) + 1 (p_j)]
        in_dim = product_dim + hidden + 1

        self.theta = nn.Sequential(
            nn.Linear(in_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, x_user, X_product, X_other_products,
                x_other_prices, price, prod_randomization):
        """
        X_product:        [M, F_p]          product features z_j
        X_other_products: [M, (M-1)*F_p]    other products' features z_-j
        price:            [M]               own price p_j (already discounted)
        """
        device = price.device
        # N users, M products
        N, M = x_user.shape[0], X_product.shape[0]

        # z_-j features: [M, hidden]
        zminus_feat = self.other_product_features_layers(X_other_products)

        # p_j scalar: [M, 1]
        pj_feat = price.unsqueeze(1)

        # Combine product-side info: [M, F_p + hidden + 1]
        product_feat = torch.cat(
            [X_product, zminus_feat, pj_feat],
            dim=1
        )

        # Expand to all users: [N, M, in_dim]
        product_feat_exp = product_feat.unsqueeze(0).expand(N, -1, -1)

        # Flatten to [N*M, in_dim]
        theta_input_flat = product_feat_exp.reshape(N * M, -1)

        # Utilities: [N*M, 1] -> [N, M]
        utilities = self.theta(theta_input_flat).view(N, M)

        # Outside option = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utilities], dim=1)

        return utilities_with_outside

# %%
# Apply the model
pdlmodel = DeepMNLModel_ProductOnly(
    product_dim=X_product.shape[1],
    num_product=X_product.shape[0],
    hidden=5
).to(device)

# Weight initialization
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)

pdlmodel.apply(init_weights)
# Out:
# DeepMNLModel_ProductOnly(
#   (other_product_features_layers): Sequential(
#     (0): Linear(in_features=15, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): ReLU()
#   )
#   (theta): Sequential(
#     (0): Linear(in_features=9, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# ----- Prepare validation data -----
prepared_val = prepare_data(
    X_user_val,
    X_product,
    price * (1 - (1 - discount_percentage) * prod_randomization)
)
user_features_val, product_features_val, _, all_x_other_products_val, all_other_prices_val = prepared_val

user_features_val = user_features_val.to(device)
product_features_val = product_features_val.to(device)
all_x_other_products_val = all_x_other_products_val.to(device)
all_other_prices_val = all_other_prices_val.to(device)
choice_val = choice_val.to(device)

# ----- Optimizer and scheduler -----
optimizer = optim.Adam(pdlmodel.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)
l2_lambda = 0  # L2 regularization coefficient

# Early stopping setup
best_val_loss = float('inf')
patience = 10
patience_counter = 0

# ----- Training loop -----
for epoch in range(5000):
    pdlmodel.train()
    optimizer.zero_grad()

    # Forward pass (train): use prepared prices and other-prices matrix
    outputs = pdlmodel(
        user_features,         # x_user (not used inside DeepMNLModel_No, but kept for interface)
        product_features,      # X_product (not used)
        all_x_other_products,  # X_other_products (not used in No model)
        all_other_prices,      # x_other_prices: p_-j
        prices,                # price: experimental p_j (after discount)
        prod_randomization     # can be ignored inside No model
    )

    choice_probabilities = F.log_softmax(outputs, dim=1)

    # Training loss
    loss = -torch.mean(
        choice_probabilities[
            torch.arange(choice_probabilities.shape[0], device=device),
            choice_train1
        ]
    )

    # L2 regularization
    l2_norm = sum(param.pow(2.0).sum() for param in pdlmodel.parameters())
    loss = loss + l2_lambda * l2_norm

    # Backward
    loss.backward()
    optimizer.step()

    # ----- Validation -----
    pdlmodel.eval()
    with torch.no_grad():
        val_outputs = pdlmodel(
            user_features_val,
            product_features_val,
            all_x_other_products_val,
            all_other_prices_val,
            prices,              # same product prices for validation
            prod_randomization
        )
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(
            val_choice_probabilities[
                torch.arange(val_choice_probabilities.shape[0], device=device),
                choice_val
            ]
        )

    print(
        f"Epoch {epoch+1}, "
        f"Training Loss: {loss.item():.4f}, "
        f"Validation Loss: {val_loss.item():.4f}"
    )

    # Early stopping logic
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        torch.save(pdlmodel.state_dict(), 'best_model.pth')
    else:
        patience_counter += 1

    if patience_counter >= patience:
        print("Early stopping triggered")
        break

    scheduler.step()
# Out:
# Epoch 1, Training Loss: 1.6353, Validation Loss: 1.4547
# Epoch 2, Training Loss: 1.5510, Validation Loss: 1.3451
# Epoch 3, Training Loss: 1.4792, Validation Loss: 1.2545
# Epoch 4, Training Loss: 1.4136, Validation Loss: 1.1768
# Epoch 5, Training Loss: 1.3504, Validation Loss: 1.1154
# Epoch 6, Training Loss: 1.3049, Validation Loss: 1.0782
# Epoch 7, Training Loss: 1.2843, Validation Loss: 1.0652
# Epoch 8, Training Loss: 1.2892, Validation Loss: 1.0689
# Epoch 9, Training Loss: 1.3046, Validation Loss: 1.0748
# Epoch 10, Training Loss: 1.3134, Validation Loss: 1.0756
# Epoch 11, Training Loss: 1.3098, Validation Loss: 1.0711
# Epoch 12, Training Loss: 1.2960, Validation Loss: 1.0646
# Epoch 13, Training Loss: 1.2767, Validation Loss: 1.0599
# Epoch 14, Training Loss: 1.2572, Validation Loss: 1.0587
# Epoch 15, Training Loss: 1.2422, Validation Loss: 1.0628
# Epoch 16, Training Loss: 1.2323, Validation Loss: 1.0718
# Epoch 17, Training Loss: 1.2276, Validation Loss: 1.0838
# Epoch 18, Training Loss: 1.2269, Validation Loss: 1.0946
# Epoch 19, Training Loss: 1.2287, Validation Loss: 1.1046
# Epoch 20, Training Loss: 1.2301, Validation Loss: 1.1111
# Epoch 21, Training Loss: 1.2290, Validation Loss: 1.1135
# Epoch 22, Training Loss: 1.2248, Validation Loss: 1.1127
# Epoch 23, Training Loss: 1.2185, Validation Loss: 1.1099
# Epoch 24, Training Loss: 1.2109, Validation Loss: 1.1059
# Early stopping triggered

# %%
# All-control and all-treated for test set
num_product = X_product.shape[0]

# All control: product_randomization = 0
all_product_control = torch.zeros(num_product, device=device).bool()

# All treated: product_randomization = 1
all_product_treated = torch.ones(num_product, device=device).bool()

# Move base price and test users/products to device
X_user_test = X_user_test.to(device)
X_product = X_product.to(device)
price = price.to(device)

# --------- Expected revenue: all control ----------
# Control prices = base prices (no discount)
price_control = price.clone()

# Prepare test data under all-control prices
user_test_ctrl, product_test_ctrl, prices_ctrl, x_other_products_ctrl, other_prices_ctrl = prepare_data(
    X_user_test,
    X_product,
    price_control
)

utilities_ctrl = pdlmodel(
    user_test_ctrl,
    product_test_ctrl,
    x_other_products_ctrl,
    other_prices_ctrl,
    prices_ctrl,          # control prices
    all_product_control   # all False
)

probabilities_ctrl = F.softmax(utilities_ctrl, dim=1)

price_with_outside_ctrl = torch.cat(
    (torch.zeros(1, device=price.device), prices_ctrl), dim=0
)  # [M+1]

expected_revenue_ctrl = torch.sum(
    probabilities_ctrl * price_with_outside_ctrl.unsqueeze(0).expand_as(probabilities_ctrl),
    dim=1
).sum()

print(f"Expected Revenue (all control): ${expected_revenue_ctrl.item():.2f}")

# --------- Expected revenue: all treated ----------
# Treated prices = discounted prices
price_treated = price * discount_percentage

user_test_trt, product_test_trt, prices_trt, x_other_products_trt, other_prices_trt = prepare_data(
    X_user_test,
    X_product,
    price_treated
)

utilities_trt = pdlmodel(
    user_test_trt,
    product_test_trt,
    x_other_products_trt,
    other_prices_trt,
    prices_trt,          # treated prices
    all_product_treated  # all True
)

probabilities_trt = F.softmax(utilities_trt, dim=1)

price_with_outside_trt = torch.cat(
    (torch.zeros(1, device=price.device), prices_trt), dim=0
)

expected_revenue_trt = torch.sum(
    probabilities_trt * price_with_outside_trt.unsqueeze(0).expand_as(probabilities_trt),
    dim=1
).sum()

print(f"Expected Revenue (all treated): ${expected_revenue_trt.item():.2f}")

# --------- GTE ----------
pdl = (expected_revenue_trt - expected_revenue_ctrl).cpu().detach().numpy() * 600 / 266
print(pdl)

pdl_product = abs((pdl - true) / true)
print(pdl_product)
# Out:
# Expected Revenue (all control): $39.86
# Expected Revenue (all treated): $10.71
# -65.75381917164738
# 0.04225988224581449

# %% [markdown]
# ### All features

# %%
# PDL choice model
class DeepMNLModel_UserProduct(nn.Module):
    """
    Deep MNL:
    u_ij = theta(x_i, z_j, z_-j, p_j)
    Outside option utility = 0.
    """
    def __init__(self, user_dim, product_dim, num_product, hidden=5):
        super(DeepMNLModel_UserProduct, self).__init__()

        # Aggregate other products' features z_-j:
        # Input:  [M, (M-1)*F_p]
        # Output: [M, hidden]
        self.other_product_features_layers = nn.Sequential(
            nn.Linear(product_dim * (num_product - 1), hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU()
        )

        # theta(x_i, z_j, z_-j, p_j)
        # Input per (i,j):
        #   user_dim (x_i)
        # + product_dim (z_j)
        # + hidden (z_-j)
        # + 1 (p_j)
        in_dim = user_dim + product_dim + hidden + 1

        self.theta = nn.Sequential(
            nn.Linear(in_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, x_user, X_product, X_other_products,
                x_other_prices, price, prod_randomization):
        """
        x_user:          [N, F_u]          user features x_i
        X_product:       [M, F_p]          product features z_j
        X_other_products:[M, (M-1)*F_p]    other products' features z_-j
        price:           [M]               own price p_j (already discounted)

        x_other_prices, prod_randomization are not used here.
        """
        device = price.device
        N, M = x_user.shape[0], X_product.shape[0]

        # z_-j features: [M, hidden]
        zminus_feat = self.other_product_features_layers(X_other_products)

        # p_j: [M, 1]
        pj_feat = price.unsqueeze(1)

        # Product-side block: [M, F_p + hidden + 1]
        product_block = torch.cat(
            [X_product, zminus_feat, pj_feat],
            dim=1
        )

        # Expand product block for all users: [N, M, *]
        product_block_exp = product_block.unsqueeze(0).expand(N, -1, -1)

        # Expand user features: [N, 1, F_u] -> [N, M, F_u]
        x_user_exp = x_user.unsqueeze(1).expand(-1, M, -1)

        # Final theta input: [N, M, in_dim]
        theta_input = torch.cat([x_user_exp, product_block_exp], dim=2)

        # Flatten to [N*M, in_dim]
        theta_input_flat = theta_input.reshape(N * M, -1)

        # Utilities: [N*M, 1] -> [N, M]
        utilities = self.theta(theta_input_flat).view(N, M)

        # Outside option = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utilities], dim=1)

        return utilities_with_outside

# %%
# Apply the model
pdlmodel = DeepMNLModel_UserProduct(
    user_dim=X_user.shape[1],
    product_dim=X_product.shape[1],
    num_product=X_product.shape[0],
    hidden=5
).to(device)

# Weight initialization
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)

pdlmodel.apply(init_weights)
# Out:
# DeepMNLModel_UserProduct(
#   (other_product_features_layers): Sequential(
#     (0): Linear(in_features=15, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): ReLU()
#   )
#   (theta): Sequential(
#     (0): Linear(in_features=12, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# ----- Prepare validation data -----
prepared_val = prepare_data(
    X_user_val,
    X_product,
    price * (1 - (1 - discount_percentage) * prod_randomization)
)
user_features_val, product_features_val, _, all_x_other_products_val, all_other_prices_val = prepared_val

user_features_val = user_features_val.to(device)
product_features_val = product_features_val.to(device)
all_x_other_products_val = all_x_other_products_val.to(device)
all_other_prices_val = all_other_prices_val.to(device)
choice_val = choice_val.to(device)

# ----- Optimizer and scheduler -----
optimizer = optim.Adam(pdlmodel.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)
l2_lambda = 0 # L2 regularization coefficient

# Early stopping setup
best_val_loss = float('inf')
patience = 10
patience_counter = 0

# ----- Training loop -----
for epoch in range(5000):
    pdlmodel.train()
    optimizer.zero_grad()

    # Forward pass (train): use prepared prices and other-prices matrix
    outputs = pdlmodel(
        user_features,         # x_user (not used inside DeepMNLModel_No, but kept for interface)
        product_features,      # X_product (not used)
        all_x_other_products,  # X_other_products (not used in No model)
        all_other_prices,      # x_other_prices: p_-j
        prices,                # price: experimental p_j (after discount)
        prod_randomization     # can be ignored inside No model
    )

    choice_probabilities = F.log_softmax(outputs, dim=1)

    # Training loss
    loss = -torch.mean(
        choice_probabilities[
            torch.arange(choice_probabilities.shape[0], device=device),
            choice_train1
        ]
    )

    # L2 regularization
    l2_norm = sum(param.pow(2.0).sum() for param in pdlmodel.parameters())
    loss = loss + l2_lambda * l2_norm

    # Backward
    loss.backward()
    optimizer.step()

    # ----- Validation -----
    pdlmodel.eval()
    with torch.no_grad():
        val_outputs = pdlmodel(
            user_features_val,
            product_features_val,
            all_x_other_products_val,
            all_other_prices_val,
            prices,              # same product prices for validation
            prod_randomization
        )
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(
            val_choice_probabilities[
                torch.arange(val_choice_probabilities.shape[0], device=device),
                choice_val
            ]
        )

    print(
        f"Epoch {epoch+1}, "
        f"Training Loss: {loss.item():.4f}, "
        f"Validation Loss: {val_loss.item():.4f}"
    )

    # Early stopping logic
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        torch.save(pdlmodel.state_dict(), 'best_model.pth')
    else:
        patience_counter += 1

    if patience_counter >= patience:
        print("Early stopping triggered")
        break

    scheduler.step()
# Out:
# Epoch 1, Training Loss: 2.1402, Validation Loss: 2.0631
# Epoch 2, Training Loss: 2.0515, Validation Loss: 2.0048
# Epoch 3, Training Loss: 1.9912, Validation Loss: 1.9618
# Epoch 4, Training Loss: 1.9509, Validation Loss: 1.9343
# Epoch 5, Training Loss: 1.9328, Validation Loss: 1.9232
# Epoch 6, Training Loss: 1.9249, Validation Loss: 1.9176
# Epoch 7, Training Loss: 1.9197, Validation Loss: 1.9120
# Epoch 8, Training Loss: 1.9145, Validation Loss: 1.9064
# Epoch 9, Training Loss: 1.9093, Validation Loss: 1.9008
# Epoch 10, Training Loss: 1.9041, Validation Loss: 1.8952
# Epoch 11, Training Loss: 1.8990, Validation Loss: 1.8896
# Epoch 12, Training Loss: 1.8938, Validation Loss: 1.8841
# Epoch 13, Training Loss: 1.8887, Validation Loss: 1.8786
# Epoch 14, Training Loss: 1.8836, Validation Loss: 1.8731
# Epoch 15, Training Loss: 1.8785, Validation Loss: 1.8676
# Epoch 16, Training Loss: 1.8734, Validation Loss: 1.8621
# Epoch 17, Training Loss: 1.8684, Validation Loss: 1.8567
# Epoch 18, Training Loss: 1.8633, Validation Loss: 1.8512
# Epoch 19, Training Loss: 1.8583, Validation Loss: 1.8458
# Epoch 20, Training Loss: 1.8533, Validation Loss: 1.8404
# Epoch 21, Training Loss: 1.8483, Validation Loss: 1.8350
# Epoch 22, Training Loss: 1.8433, Validation Loss: 1.8296
# Epoch 23, Training Loss: 1.8384, Validation Loss: 1.8243
# Epoch 24, Training Loss: 1.8334, Validation Loss: 1.8189
# Epoch 25, Training Loss: 1.8285, Validation Loss: 1.8136
# Epoch 26, Training Loss: 1.8236, Validation Loss: 1.8083
# Epoch 27, Training Loss: 1.8187, Validation Loss: 1.8031
# Epoch 28, Training Loss: 1.8139, Validation Loss: 1.7978
# Epoch 29, Training Loss: 1.8090, Validation Loss: 1.7926
# Epoch 30, Training Loss: 1.8042, Validation Loss: 1.7873
# Epoch 31, Training Loss: 1.7994, Validation Loss: 1.7821
# Epoch 32, Training Loss: 1.7946, Validation Loss: 1.7770
# Epoch 33, Training Loss: 1.7898, Validation Loss: 1.7718
# Epoch 34, Training Loss: 1.7851, Validation Loss: 1.7667
# Epoch 35, Training Loss: 1.7804, Validation Loss: 1.7616
# Epoch 36, Training Loss: 1.7757, Validation Loss: 1.7565
# Epoch 37, Training Loss: 1.7710, Validation Loss: 1.7514
# Epoch 38, Training Loss: 1.7663, Validation Loss: 1.7463
# Epoch 39, Training Loss: 1.7617, Validation Loss: 1.7413
# Epoch 40, Training Loss: 1.7570, Validation Loss: 1.7363
# Epoch 41, Training Loss: 1.7524, Validation Loss: 1.7313
# Epoch 42, Training Loss: 1.7479, Validation Loss: 1.7263
# Epoch 43, Training Loss: 1.7433, Validation Loss: 1.7214
# Epoch 44, Training Loss: 1.7388, Validation Loss: 1.7165
# Epoch 45, Training Loss: 1.7342, Validation Loss: 1.7116
# Epoch 46, Training Loss: 1.7297, Validation Loss: 1.7067
# Epoch 47, Training Loss: 1.7253, Validation Loss: 1.7018
# Epoch 48, Training Loss: 1.7208, Validation Loss: 1.6970
# Epoch 49, Training Loss: 1.7164, Validation Loss: 1.6922
# Epoch 50, Training Loss: 1.7120, Validation Loss: 1.6874
# Epoch 51, Training Loss: 1.7076, Validation Loss: 1.6827
# Epoch 52, Training Loss: 1.7032, Validation Loss: 1.6779
# Epoch 53, Training Loss: 1.6989, Validation Loss: 1.6732
# Epoch 54, Training Loss: 1.6946, Validation Loss: 1.6685
# Epoch 55, Training Loss: 1.6903, Validation Loss: 1.6638
# Epoch 56, Training Loss: 1.6860, Validation Loss: 1.6592
# Epoch 57, Training Loss: 1.6817, Validation Loss: 1.6546
# Epoch 58, Training Loss: 1.6775, Validation Loss: 1.6500
# Epoch 59, Training Loss: 1.6733, Validation Loss: 1.6454
# Epoch 60, Training Loss: 1.6691, Validation Loss: 1.6408
# Epoch 61, Training Loss: 1.6650, Validation Loss: 1.6363
# Epoch 62, Training Loss: 1.6608, Validation Loss: 1.6318
# Epoch 63, Training Loss: 1.6567, Validation Loss: 1.6273
# Epoch 64, Training Loss: 1.6526, Validation Loss: 1.6229
# Epoch 65, Training Loss: 1.6486, Validation Loss: 1.6184
# Epoch 66, Training Loss: 1.6445, Validation Loss: 1.6140
# Epoch 67, Training Loss: 1.6405, Validation Loss: 1.6097
# Epoch 68, Training Loss: 1.6365, Validation Loss: 1.6053
# Epoch 69, Training Loss: 1.6325, Validation Loss: 1.6010
# Epoch 70, Training Loss: 1.6286, Validation Loss: 1.5967
# Epoch 71, Training Loss: 1.6247, Validation Loss: 1.5924
# Epoch 72, Training Loss: 1.6208, Validation Loss: 1.5881
# Epoch 73, Training Loss: 1.6169, Validation Loss: 1.5839
# Epoch 74, Training Loss: 1.6130, Validation Loss: 1.5797
# Epoch 75, Training Loss: 1.6092, Validation Loss: 1.5755
# Epoch 76, Training Loss: 1.6054, Validation Loss: 1.5713
# Epoch 77, Training Loss: 1.6016, Validation Loss: 1.5672
# Epoch 78, Training Loss: 1.5979, Validation Loss: 1.5631
# Epoch 79, Training Loss: 1.5941, Validation Loss: 1.5590
# Epoch 80, Training Loss: 1.5904, Validation Loss: 1.5549
# Epoch 81, Training Loss: 1.5867, Validation Loss: 1.5509
# Epoch 82, Training Loss: 1.5831, Validation Loss: 1.5469
# Epoch 83, Training Loss: 1.5794, Validation Loss: 1.5429
# Epoch 84, Training Loss: 1.5758, Validation Loss: 1.5389
# Epoch 85, Training Loss: 1.5722, Validation Loss: 1.5350
# Epoch 86, Training Loss: 1.5687, Validation Loss: 1.5311
# Epoch 87, Training Loss: 1.5651, Validation Loss: 1.5272
# Epoch 88, Training Loss: 1.5616, Validation Loss: 1.5233
# Epoch 89, Training Loss: 1.5581, Validation Loss: 1.5195
# Epoch 90, Training Loss: 1.5547, Validation Loss: 1.5157
# Epoch 91, Training Loss: 1.5512, Validation Loss: 1.5119
# Epoch 92, Training Loss: 1.5478, Validation Loss: 1.5081
# Epoch 93, Training Loss: 1.5444, Validation Loss: 1.5044
# Epoch 94, Training Loss: 1.5410, Validation Loss: 1.5007
# Epoch 95, Training Loss: 1.5377, Validation Loss: 1.4970
# Epoch 96, Training Loss: 1.5343, Validation Loss: 1.4933
# Epoch 97, Training Loss: 1.5310, Validation Loss: 1.4897
# Epoch 98, Training Loss: 1.5278, Validation Loss: 1.4861
# Epoch 99, Training Loss: 1.5245, Validation Loss: 1.4825
# Epoch 100, Training Loss: 1.5213, Validation Loss: 1.4789
# Epoch 101, Training Loss: 1.5181, Validation Loss: 1.4754
# Epoch 102, Training Loss: 1.5149, Validation Loss: 1.4719
# Epoch 103, Training Loss: 1.5117, Validation Loss: 1.4684
# Epoch 104, Training Loss: 1.5086, Validation Loss: 1.4649
# Epoch 105, Training Loss: 1.5055, Validation Loss: 1.4615
# Epoch 106, Training Loss: 1.5024, Validation Loss: 1.4581
# Epoch 107, Training Loss: 1.4994, Validation Loss: 1.4547
# Epoch 108, Training Loss: 1.4963, Validation Loss: 1.4513
# Epoch 109, Training Loss: 1.4933, Validation Loss: 1.4480
# Epoch 110, Training Loss: 1.4903, Validation Loss: 1.4446
# Epoch 111, Training Loss: 1.4873, Validation Loss: 1.4414
# Epoch 112, Training Loss: 1.4844, Validation Loss: 1.4381
# Epoch 113, Training Loss: 1.4815, Validation Loss: 1.4348
# Epoch 114, Training Loss: 1.4786, Validation Loss: 1.4316
# Epoch 115, Training Loss: 1.4757, Validation Loss: 1.4284
# Epoch 116, Training Loss: 1.4729, Validation Loss: 1.4253
# Epoch 117, Training Loss: 1.4700, Validation Loss: 1.4221
# Epoch 118, Training Loss: 1.4672, Validation Loss: 1.4190
# Epoch 119, Training Loss: 1.4644, Validation Loss: 1.4159
# Epoch 120, Training Loss: 1.4617, Validation Loss: 1.4128
# Epoch 121, Training Loss: 1.4590, Validation Loss: 1.4098
# Epoch 122, Training Loss: 1.4562, Validation Loss: 1.4068
# Epoch 123, Training Loss: 1.4536, Validation Loss: 1.4038
# Epoch 124, Training Loss: 1.4509, Validation Loss: 1.4008
# Epoch 125, Training Loss: 1.4482, Validation Loss: 1.3978
# Epoch 126, Training Loss: 1.4456, Validation Loss: 1.3949
# Epoch 127, Training Loss: 1.4430, Validation Loss: 1.3920
# Epoch 128, Training Loss: 1.4405, Validation Loss: 1.3891
# Epoch 129, Training Loss: 1.4379, Validation Loss: 1.3863
# Epoch 130, Training Loss: 1.4354, Validation Loss: 1.3834
# Epoch 131, Training Loss: 1.4329, Validation Loss: 1.3806
# Epoch 132, Training Loss: 1.4304, Validation Loss: 1.3778
# Epoch 133, Training Loss: 1.4279, Validation Loss: 1.3751
# Epoch 134, Training Loss: 1.4255, Validation Loss: 1.3723
# Epoch 135, Training Loss: 1.4231, Validation Loss: 1.3696
# Epoch 136, Training Loss: 1.4207, Validation Loss: 1.3669
# Epoch 137, Training Loss: 1.4183, Validation Loss: 1.3642
# Epoch 138, Training Loss: 1.4159, Validation Loss: 1.3616
# Epoch 139, Training Loss: 1.4136, Validation Loss: 1.3589
# Epoch 140, Training Loss: 1.4113, Validation Loss: 1.3563
# Epoch 141, Training Loss: 1.4090, Validation Loss: 1.3538
# Epoch 142, Training Loss: 1.4067, Validation Loss: 1.3512
# Epoch 143, Training Loss: 1.4045, Validation Loss: 1.3487
# Epoch 144, Training Loss: 1.4023, Validation Loss: 1.3461
# Epoch 145, Training Loss: 1.4000, Validation Loss: 1.3437
# Epoch 146, Training Loss: 1.3979, Validation Loss: 1.3412
# Epoch 147, Training Loss: 1.3957, Validation Loss: 1.3387
# Epoch 148, Training Loss: 1.3936, Validation Loss: 1.3363
# Epoch 149, Training Loss: 1.3914, Validation Loss: 1.3339
# Epoch 150, Training Loss: 1.3893, Validation Loss: 1.3315
# Epoch 151, Training Loss: 1.3873, Validation Loss: 1.3291
# Epoch 152, Training Loss: 1.3852, Validation Loss: 1.3268
# Epoch 153, Training Loss: 1.3832, Validation Loss: 1.3245
# Epoch 154, Training Loss: 1.3811, Validation Loss: 1.3222
# Epoch 155, Training Loss: 1.3791, Validation Loss: 1.3199
# Epoch 156, Training Loss: 1.3772, Validation Loss: 1.3176
# Epoch 157, Training Loss: 1.3752, Validation Loss: 1.3154
# Epoch 158, Training Loss: 1.3733, Validation Loss: 1.3132
# Epoch 159, Training Loss: 1.3713, Validation Loss: 1.3110
# Epoch 160, Training Loss: 1.3694, Validation Loss: 1.3088
# Epoch 161, Training Loss: 1.3675, Validation Loss: 1.3067
# Epoch 162, Training Loss: 1.3657, Validation Loss: 1.3045
# Epoch 163, Training Loss: 1.3638, Validation Loss: 1.3024
# Epoch 164, Training Loss: 1.3620, Validation Loss: 1.3003
# Epoch 165, Training Loss: 1.3602, Validation Loss: 1.2983
# Epoch 166, Training Loss: 1.3584, Validation Loss: 1.2962
# Epoch 167, Training Loss: 1.3567, Validation Loss: 1.2942
# Epoch 168, Training Loss: 1.3549, Validation Loss: 1.2922
# Epoch 169, Training Loss: 1.3532, Validation Loss: 1.2902
# Epoch 170, Training Loss: 1.3515, Validation Loss: 1.2882
# Epoch 171, Training Loss: 1.3498, Validation Loss: 1.2862
# Epoch 172, Training Loss: 1.3481, Validation Loss: 1.2843
# Epoch 173, Training Loss: 1.3464, Validation Loss: 1.2824
# Epoch 174, Training Loss: 1.3448, Validation Loss: 1.2805
# Epoch 175, Training Loss: 1.3432, Validation Loss: 1.2786
# Epoch 176, Training Loss: 1.3416, Validation Loss: 1.2767
# Epoch 177, Training Loss: 1.3400, Validation Loss: 1.2749
# Epoch 178, Training Loss: 1.3384, Validation Loss: 1.2730
# Epoch 179, Training Loss: 1.3368, Validation Loss: 1.2712
# Epoch 180, Training Loss: 1.3353, Validation Loss: 1.2694
# Epoch 181, Training Loss: 1.3338, Validation Loss: 1.2677
# Epoch 182, Training Loss: 1.3323, Validation Loss: 1.2659
# Epoch 183, Training Loss: 1.3308, Validation Loss: 1.2642
# Epoch 184, Training Loss: 1.3293, Validation Loss: 1.2625
# Epoch 185, Training Loss: 1.3279, Validation Loss: 1.2608
# Epoch 186, Training Loss: 1.3264, Validation Loss: 1.2591
# Epoch 187, Training Loss: 1.3250, Validation Loss: 1.2574
# Epoch 188, Training Loss: 1.3236, Validation Loss: 1.2558
# Epoch 189, Training Loss: 1.3222, Validation Loss: 1.2541
# Epoch 190, Training Loss: 1.3208, Validation Loss: 1.2525
# Epoch 191, Training Loss: 1.3195, Validation Loss: 1.2509
# Epoch 192, Training Loss: 1.3181, Validation Loss: 1.2493
# Epoch 193, Training Loss: 1.3168, Validation Loss: 1.2478
# Epoch 194, Training Loss: 1.3155, Validation Loss: 1.2462
# Epoch 195, Training Loss: 1.3142, Validation Loss: 1.2447
# Epoch 196, Training Loss: 1.3129, Validation Loss: 1.2432
# Epoch 197, Training Loss: 1.3116, Validation Loss: 1.2417
# Epoch 198, Training Loss: 1.3104, Validation Loss: 1.2402
# Epoch 199, Training Loss: 1.3091, Validation Loss: 1.2387
# Epoch 200, Training Loss: 1.3079, Validation Loss: 1.2373
# Epoch 201, Training Loss: 1.3067, Validation Loss: 1.2358
# Epoch 202, Training Loss: 1.3055, Validation Loss: 1.2344
# Epoch 203, Training Loss: 1.3043, Validation Loss: 1.2330
# Epoch 204, Training Loss: 1.3032, Validation Loss: 1.2316
# Epoch 205, Training Loss: 1.3020, Validation Loss: 1.2302
# Epoch 206, Training Loss: 1.3009, Validation Loss: 1.2288
# Epoch 207, Training Loss: 1.2997, Validation Loss: 1.2275
# Epoch 208, Training Loss: 1.2986, Validation Loss: 1.2262
# Epoch 209, Training Loss: 1.2975, Validation Loss: 1.2248
# Epoch 210, Training Loss: 1.2964, Validation Loss: 1.2235
# Epoch 211, Training Loss: 1.2954, Validation Loss: 1.2222
# Epoch 212, Training Loss: 1.2943, Validation Loss: 1.2210
# Epoch 213, Training Loss: 1.2933, Validation Loss: 1.2197
# Epoch 214, Training Loss: 1.2922, Validation Loss: 1.2185
# Epoch 215, Training Loss: 1.2912, Validation Loss: 1.2172
# Epoch 216, Training Loss: 1.2902, Validation Loss: 1.2160
# Epoch 217, Training Loss: 1.2892, Validation Loss: 1.2148
# Epoch 218, Training Loss: 1.2882, Validation Loss: 1.2136
# Epoch 219, Training Loss: 1.2872, Validation Loss: 1.2124
# Epoch 220, Training Loss: 1.2863, Validation Loss: 1.2112
# Epoch 221, Training Loss: 1.2853, Validation Loss: 1.2101
# Epoch 222, Training Loss: 1.2844, Validation Loss: 1.2089
# Epoch 223, Training Loss: 1.2835, Validation Loss: 1.2078
# Epoch 224, Training Loss: 1.2826, Validation Loss: 1.2067
# Epoch 225, Training Loss: 1.2817, Validation Loss: 1.2056
# Epoch 226, Training Loss: 1.2808, Validation Loss: 1.2045
# Epoch 227, Training Loss: 1.2799, Validation Loss: 1.2034
# Epoch 228, Training Loss: 1.2790, Validation Loss: 1.2023
# Epoch 229, Training Loss: 1.2782, Validation Loss: 1.2013
# Epoch 230, Training Loss: 1.2773, Validation Loss: 1.2002
# Epoch 231, Training Loss: 1.2765, Validation Loss: 1.1992
# Epoch 232, Training Loss: 1.2757, Validation Loss: 1.1982
# Epoch 233, Training Loss: 1.2748, Validation Loss: 1.1972
# Epoch 234, Training Loss: 1.2740, Validation Loss: 1.1962
# Epoch 235, Training Loss: 1.2732, Validation Loss: 1.1952
# Epoch 236, Training Loss: 1.2725, Validation Loss: 1.1942
# Epoch 237, Training Loss: 1.2717, Validation Loss: 1.1932
# Epoch 238, Training Loss: 1.2709, Validation Loss: 1.1923
# Epoch 239, Training Loss: 1.2702, Validation Loss: 1.1913
# Epoch 240, Training Loss: 1.2694, Validation Loss: 1.1904
# Epoch 241, Training Loss: 1.2687, Validation Loss: 1.1895
# Epoch 242, Training Loss: 1.2680, Validation Loss: 1.1886
# Epoch 243, Training Loss: 1.2673, Validation Loss: 1.1877
# Epoch 244, Training Loss: 1.2666, Validation Loss: 1.1868
# Epoch 245, Training Loss: 1.2659, Validation Loss: 1.1859
# Epoch 246, Training Loss: 1.2652, Validation Loss: 1.1850
# Epoch 247, Training Loss: 1.2645, Validation Loss: 1.1842
# Epoch 248, Training Loss: 1.2638, Validation Loss: 1.1833
# Epoch 249, Training Loss: 1.2632, Validation Loss: 1.1825
# Epoch 250, Training Loss: 1.2625, Validation Loss: 1.1817
# Epoch 251, Training Loss: 1.2619, Validation Loss: 1.1809
# Epoch 252, Training Loss: 1.2612, Validation Loss: 1.1800
# Epoch 253, Training Loss: 1.2606, Validation Loss: 1.1792
# Epoch 254, Training Loss: 1.2600, Validation Loss: 1.1785
# Epoch 255, Training Loss: 1.2594, Validation Loss: 1.1777
# Epoch 256, Training Loss: 1.2588, Validation Loss: 1.1769
# Epoch 257, Training Loss: 1.2582, Validation Loss: 1.1761
# Epoch 258, Training Loss: 1.2576, Validation Loss: 1.1754
# Epoch 259, Training Loss: 1.2571, Validation Loss: 1.1746
# Epoch 260, Training Loss: 1.2565, Validation Loss: 1.1739
# Epoch 261, Training Loss: 1.2559, Validation Loss: 1.1732
# Epoch 262, Training Loss: 1.2554, Validation Loss: 1.1724
# Epoch 263, Training Loss: 1.2548, Validation Loss: 1.1717
# Epoch 264, Training Loss: 1.2543, Validation Loss: 1.1710
# Epoch 265, Training Loss: 1.2538, Validation Loss: 1.1703
# Epoch 266, Training Loss: 1.2532, Validation Loss: 1.1697
# Epoch 267, Training Loss: 1.2527, Validation Loss: 1.1690
# Epoch 268, Training Loss: 1.2522, Validation Loss: 1.1683
# Epoch 269, Training Loss: 1.2517, Validation Loss: 1.1676
# Epoch 270, Training Loss: 1.2512, Validation Loss: 1.1670
# Epoch 271, Training Loss: 1.2507, Validation Loss: 1.1663
# Epoch 272, Training Loss: 1.2503, Validation Loss: 1.1657
# Epoch 273, Training Loss: 1.2498, Validation Loss: 1.1651
# Epoch 274, Training Loss: 1.2493, Validation Loss: 1.1645
# Epoch 275, Training Loss: 1.2489, Validation Loss: 1.1638
# Epoch 276, Training Loss: 1.2484, Validation Loss: 1.1632
# Epoch 277, Training Loss: 1.2480, Validation Loss: 1.1626
# Epoch 278, Training Loss: 1.2475, Validation Loss: 1.1620
# Epoch 279, Training Loss: 1.2471, Validation Loss: 1.1615
# Epoch 280, Training Loss: 1.2467, Validation Loss: 1.1609
# Epoch 281, Training Loss: 1.2462, Validation Loss: 1.1603
# Epoch 282, Training Loss: 1.2458, Validation Loss: 1.1597
# Epoch 283, Training Loss: 1.2454, Validation Loss: 1.1592
# Epoch 284, Training Loss: 1.2450, Validation Loss: 1.1586
# Epoch 285, Training Loss: 1.2446, Validation Loss: 1.1581
# Epoch 286, Training Loss: 1.2442, Validation Loss: 1.1575
# Epoch 287, Training Loss: 1.2438, Validation Loss: 1.1570
# Epoch 288, Training Loss: 1.2434, Validation Loss: 1.1565
# Epoch 289, Training Loss: 1.2431, Validation Loss: 1.1560
# Epoch 290, Training Loss: 1.2427, Validation Loss: 1.1555
# Epoch 291, Training Loss: 1.2423, Validation Loss: 1.1549
# Epoch 292, Training Loss: 1.2420, Validation Loss: 1.1544
# Epoch 293, Training Loss: 1.2416, Validation Loss: 1.1539
# Epoch 294, Training Loss: 1.2413, Validation Loss: 1.1535
# Epoch 295, Training Loss: 1.2409, Validation Loss: 1.1530
# Epoch 296, Training Loss: 1.2406, Validation Loss: 1.1525
# Epoch 297, Training Loss: 1.2402, Validation Loss: 1.1520
# Epoch 298, Training Loss: 1.2399, Validation Loss: 1.1516
# Epoch 299, Training Loss: 1.2396, Validation Loss: 1.1511
# Epoch 300, Training Loss: 1.2393, Validation Loss: 1.1507
# Epoch 301, Training Loss: 1.2390, Validation Loss: 1.1502
# Epoch 302, Training Loss: 1.2386, Validation Loss: 1.1498
# Epoch 303, Training Loss: 1.2383, Validation Loss: 1.1493
# Epoch 304, Training Loss: 1.2380, Validation Loss: 1.1489
# Epoch 305, Training Loss: 1.2377, Validation Loss: 1.1485
# Epoch 306, Training Loss: 1.2374, Validation Loss: 1.1480
# Epoch 307, Training Loss: 1.2372, Validation Loss: 1.1476
# Epoch 308, Training Loss: 1.2369, Validation Loss: 1.1472
# Epoch 309, Training Loss: 1.2366, Validation Loss: 1.1468
# Epoch 310, Training Loss: 1.2363, Validation Loss: 1.1464
# Epoch 311, Training Loss: 1.2360, Validation Loss: 1.1460
# Epoch 312, Training Loss: 1.2358, Validation Loss: 1.1456
# Epoch 313, Training Loss: 1.2355, Validation Loss: 1.1452
# Epoch 314, Training Loss: 1.2353, Validation Loss: 1.1449
# Epoch 315, Training Loss: 1.2350, Validation Loss: 1.1445
# Epoch 316, Training Loss: 1.2347, Validation Loss: 1.1441
# Epoch 317, Training Loss: 1.2345, Validation Loss: 1.1437
# Epoch 318, Training Loss: 1.2343, Validation Loss: 1.1434
# Epoch 319, Training Loss: 1.2340, Validation Loss: 1.1430
# Epoch 320, Training Loss: 1.2338, Validation Loss: 1.1427
# Epoch 321, Training Loss: 1.2335, Validation Loss: 1.1423
# Epoch 322, Training Loss: 1.2333, Validation Loss: 1.1420
# Epoch 323, Training Loss: 1.2331, Validation Loss: 1.1416
# Epoch 324, Training Loss: 1.2329, Validation Loss: 1.1413
# Epoch 325, Training Loss: 1.2327, Validation Loss: 1.1410
# Epoch 326, Training Loss: 1.2324, Validation Loss: 1.1406
# Epoch 327, Training Loss: 1.2322, Validation Loss: 1.1403
# Epoch 328, Training Loss: 1.2320, Validation Loss: 1.1400
# Epoch 329, Training Loss: 1.2318, Validation Loss: 1.1397
# Epoch 330, Training Loss: 1.2316, Validation Loss: 1.1394
# Epoch 331, Training Loss: 1.2314, Validation Loss: 1.1391
# Epoch 332, Training Loss: 1.2312, Validation Loss: 1.1387
# Epoch 333, Training Loss: 1.2310, Validation Loss: 1.1384
# Epoch 334, Training Loss: 1.2308, Validation Loss: 1.1382
# Epoch 335, Training Loss: 1.2306, Validation Loss: 1.1379
# Epoch 336, Training Loss: 1.2305, Validation Loss: 1.1376
# Epoch 337, Training Loss: 1.2303, Validation Loss: 1.1373
# Epoch 338, Training Loss: 1.2301, Validation Loss: 1.1370
# Epoch 339, Training Loss: 1.2299, Validation Loss: 1.1367
# Epoch 340, Training Loss: 1.2297, Validation Loss: 1.1364
# Epoch 341, Training Loss: 1.2296, Validation Loss: 1.1362
# Epoch 342, Training Loss: 1.2294, Validation Loss: 1.1359
# Epoch 343, Training Loss: 1.2292, Validation Loss: 1.1356
# Epoch 344, Training Loss: 1.2291, Validation Loss: 1.1354
# Epoch 345, Training Loss: 1.2289, Validation Loss: 1.1351
# Epoch 346, Training Loss: 1.2288, Validation Loss: 1.1349
# Epoch 347, Training Loss: 1.2286, Validation Loss: 1.1346
# Epoch 348, Training Loss: 1.2285, Validation Loss: 1.1344
# Epoch 349, Training Loss: 1.2283, Validation Loss: 1.1341
# Epoch 350, Training Loss: 1.2282, Validation Loss: 1.1339
# Epoch 351, Training Loss: 1.2280, Validation Loss: 1.1336
# Epoch 352, Training Loss: 1.2279, Validation Loss: 1.1334
# Epoch 353, Training Loss: 1.2277, Validation Loss: 1.1332
# Epoch 354, Training Loss: 1.2276, Validation Loss: 1.1329
# Epoch 355, Training Loss: 1.2275, Validation Loss: 1.1327
# Epoch 356, Training Loss: 1.2273, Validation Loss: 1.1325
# Epoch 357, Training Loss: 1.2272, Validation Loss: 1.1322
# Epoch 358, Training Loss: 1.2271, Validation Loss: 1.1320
# Epoch 359, Training Loss: 1.2269, Validation Loss: 1.1318
# Epoch 360, Training Loss: 1.2268, Validation Loss: 1.1316
# Epoch 361, Training Loss: 1.2267, Validation Loss: 1.1314
# Epoch 362, Training Loss: 1.2266, Validation Loss: 1.1312
# Epoch 363, Training Loss: 1.2264, Validation Loss: 1.1310
# Epoch 364, Training Loss: 1.2263, Validation Loss: 1.1308
# Epoch 365, Training Loss: 1.2262, Validation Loss: 1.1306
# Epoch 366, Training Loss: 1.2261, Validation Loss: 1.1304
# Epoch 367, Training Loss: 1.2260, Validation Loss: 1.1302
# Epoch 368, Training Loss: 1.2259, Validation Loss: 1.1300
# Epoch 369, Training Loss: 1.2258, Validation Loss: 1.1298
# Epoch 370, Training Loss: 1.2257, Validation Loss: 1.1296
# Epoch 371, Training Loss: 1.2256, Validation Loss: 1.1294
# Epoch 372, Training Loss: 1.2255, Validation Loss: 1.1292
# Epoch 373, Training Loss: 1.2254, Validation Loss: 1.1290
# Epoch 374, Training Loss: 1.2253, Validation Loss: 1.1289
# Epoch 375, Training Loss: 1.2252, Validation Loss: 1.1287
# Epoch 376, Training Loss: 1.2251, Validation Loss: 1.1285
# Epoch 377, Training Loss: 1.2250, Validation Loss: 1.1283
# Epoch 378, Training Loss: 1.2249, Validation Loss: 1.1282
# Epoch 379, Training Loss: 1.2248, Validation Loss: 1.1280
# Epoch 380, Training Loss: 1.2247, Validation Loss: 1.1278
# Epoch 381, Training Loss: 1.2246, Validation Loss: 1.1277
# Epoch 382, Training Loss: 1.2245, Validation Loss: 1.1275
# Epoch 383, Training Loss: 1.2244, Validation Loss: 1.1273
# Epoch 384, Training Loss: 1.2243, Validation Loss: 1.1272
# Epoch 385, Training Loss: 1.2243, Validation Loss: 1.1270
# Epoch 386, Training Loss: 1.2242, Validation Loss: 1.1269
# Epoch 387, Training Loss: 1.2241, Validation Loss: 1.1267
# Epoch 388, Training Loss: 1.2240, Validation Loss: 1.1266
# Epoch 389, Training Loss: 1.2239, Validation Loss: 1.1264
# Epoch 390, Training Loss: 1.2239, Validation Loss: 1.1263
# Epoch 391, Training Loss: 1.2238, Validation Loss: 1.1261
# Epoch 392, Training Loss: 1.2237, Validation Loss: 1.1260
# Epoch 393, Training Loss: 1.2236, Validation Loss: 1.1258
# Epoch 394, Training Loss: 1.2236, Validation Loss: 1.1257
# Epoch 395, Training Loss: 1.2235, Validation Loss: 1.1256
# Epoch 396, Training Loss: 1.2234, Validation Loss: 1.1254
# Epoch 397, Training Loss: 1.2234, Validation Loss: 1.1253
# Epoch 398, Training Loss: 1.2233, Validation Loss: 1.1251
# Epoch 399, Training Loss: 1.2232, Validation Loss: 1.1250
# Epoch 400, Training Loss: 1.2232, Validation Loss: 1.1249
# Epoch 401, Training Loss: 1.2231, Validation Loss: 1.1248
# Epoch 402, Training Loss: 1.2231, Validation Loss: 1.1246
# Epoch 403, Training Loss: 1.2230, Validation Loss: 1.1245
# Epoch 404, Training Loss: 1.2229, Validation Loss: 1.1244
# Epoch 405, Training Loss: 1.2229, Validation Loss: 1.1243
# Epoch 406, Training Loss: 1.2228, Validation Loss: 1.1241
# Epoch 407, Training Loss: 1.2228, Validation Loss: 1.1240
# Epoch 408, Training Loss: 1.2227, Validation Loss: 1.1239
# Epoch 409, Training Loss: 1.2226, Validation Loss: 1.1238
# Epoch 410, Training Loss: 1.2226, Validation Loss: 1.1237
# Epoch 411, Training Loss: 1.2225, Validation Loss: 1.1236
# Epoch 412, Training Loss: 1.2225, Validation Loss: 1.1234
# Epoch 413, Training Loss: 1.2224, Validation Loss: 1.1233
# Epoch 414, Training Loss: 1.2224, Validation Loss: 1.1232
# Epoch 415, Training Loss: 1.2223, Validation Loss: 1.1231
# Epoch 416, Training Loss: 1.2223, Validation Loss: 1.1230
# Epoch 417, Training Loss: 1.2222, Validation Loss: 1.1229
# Epoch 418, Training Loss: 1.2222, Validation Loss: 1.1228
# Epoch 419, Training Loss: 1.2222, Validation Loss: 1.1227
# Epoch 420, Training Loss: 1.2221, Validation Loss: 1.1226
# Epoch 421, Training Loss: 1.2221, Validation Loss: 1.1225
# Epoch 422, Training Loss: 1.2220, Validation Loss: 1.1224
# Epoch 423, Training Loss: 1.2220, Validation Loss: 1.1223
# Epoch 424, Training Loss: 1.2219, Validation Loss: 1.1222
# Epoch 425, Training Loss: 1.2219, Validation Loss: 1.1221
# Epoch 426, Training Loss: 1.2219, Validation Loss: 1.1220
# Epoch 427, Training Loss: 1.2218, Validation Loss: 1.1219
# Epoch 428, Training Loss: 1.2218, Validation Loss: 1.1218
# Epoch 429, Training Loss: 1.2217, Validation Loss: 1.1217
# Epoch 430, Training Loss: 1.2217, Validation Loss: 1.1216
# Epoch 431, Training Loss: 1.2217, Validation Loss: 1.1216
# Epoch 432, Training Loss: 1.2216, Validation Loss: 1.1215
# Epoch 433, Training Loss: 1.2216, Validation Loss: 1.1214
# Epoch 434, Training Loss: 1.2216, Validation Loss: 1.1213
# Epoch 435, Training Loss: 1.2215, Validation Loss: 1.1212
# Epoch 436, Training Loss: 1.2215, Validation Loss: 1.1211
# Epoch 437, Training Loss: 1.2215, Validation Loss: 1.1211
# Epoch 438, Training Loss: 1.2214, Validation Loss: 1.1210
# Epoch 439, Training Loss: 1.2214, Validation Loss: 1.1209
# Epoch 440, Training Loss: 1.2214, Validation Loss: 1.1208
# Epoch 441, Training Loss: 1.2213, Validation Loss: 1.1207
# Epoch 442, Training Loss: 1.2213, Validation Loss: 1.1207
# Epoch 443, Training Loss: 1.2213, Validation Loss: 1.1206
# Epoch 444, Training Loss: 1.2212, Validation Loss: 1.1205
# Epoch 445, Training Loss: 1.2212, Validation Loss: 1.1204
# Epoch 446, Training Loss: 1.2212, Validation Loss: 1.1204
# Epoch 447, Training Loss: 1.2212, Validation Loss: 1.1203
# Epoch 448, Training Loss: 1.2211, Validation Loss: 1.1202
# Epoch 449, Training Loss: 1.2211, Validation Loss: 1.1201
# Epoch 450, Training Loss: 1.2211, Validation Loss: 1.1201
# Epoch 451, Training Loss: 1.2210, Validation Loss: 1.1200
# Epoch 452, Training Loss: 1.2210, Validation Loss: 1.1199
# Epoch 453, Training Loss: 1.2210, Validation Loss: 1.1199
# Epoch 454, Training Loss: 1.2210, Validation Loss: 1.1198
# Epoch 455, Training Loss: 1.2210, Validation Loss: 1.1197
# Epoch 456, Training Loss: 1.2209, Validation Loss: 1.1197
# Epoch 457, Training Loss: 1.2209, Validation Loss: 1.1196
# Epoch 458, Training Loss: 1.2209, Validation Loss: 1.1195
# Epoch 459, Training Loss: 1.2209, Validation Loss: 1.1195
# Epoch 460, Training Loss: 1.2208, Validation Loss: 1.1194
# Epoch 461, Training Loss: 1.2208, Validation Loss: 1.1194
# Epoch 462, Training Loss: 1.2208, Validation Loss: 1.1193
# Epoch 463, Training Loss: 1.2208, Validation Loss: 1.1192
# Epoch 464, Training Loss: 1.2208, Validation Loss: 1.1192
# Epoch 465, Training Loss: 1.2207, Validation Loss: 1.1191
# Epoch 466, Training Loss: 1.2207, Validation Loss: 1.1191
# Epoch 467, Training Loss: 1.2207, Validation Loss: 1.1190
# Epoch 468, Training Loss: 1.2207, Validation Loss: 1.1189
# Epoch 469, Training Loss: 1.2207, Validation Loss: 1.1189
# Epoch 470, Training Loss: 1.2206, Validation Loss: 1.1188
# Epoch 471, Training Loss: 1.2206, Validation Loss: 1.1188
# Epoch 472, Training Loss: 1.2206, Validation Loss: 1.1187
# Epoch 473, Training Loss: 1.2206, Validation Loss: 1.1187
# Epoch 474, Training Loss: 1.2206, Validation Loss: 1.1186
# Epoch 475, Training Loss: 1.2206, Validation Loss: 1.1186
# Epoch 476, Training Loss: 1.2205, Validation Loss: 1.1185
# Epoch 477, Training Loss: 1.2205, Validation Loss: 1.1185
# Epoch 478, Training Loss: 1.2205, Validation Loss: 1.1184
# Epoch 479, Training Loss: 1.2205, Validation Loss: 1.1184
# Epoch 480, Training Loss: 1.2205, Validation Loss: 1.1183
# Epoch 481, Training Loss: 1.2205, Validation Loss: 1.1183
# Epoch 482, Training Loss: 1.2205, Validation Loss: 1.1182
# Epoch 483, Training Loss: 1.2204, Validation Loss: 1.1182
# Epoch 484, Training Loss: 1.2204, Validation Loss: 1.1181
# Epoch 485, Training Loss: 1.2204, Validation Loss: 1.1181
# Epoch 486, Training Loss: 1.2204, Validation Loss: 1.1180
# Epoch 487, Training Loss: 1.2204, Validation Loss: 1.1180
# Epoch 488, Training Loss: 1.2204, Validation Loss: 1.1179
# Epoch 489, Training Loss: 1.2204, Validation Loss: 1.1179
# Epoch 490, Training Loss: 1.2204, Validation Loss: 1.1179
# Epoch 491, Training Loss: 1.2203, Validation Loss: 1.1178
# Epoch 492, Training Loss: 1.2203, Validation Loss: 1.1178
# Epoch 493, Training Loss: 1.2203, Validation Loss: 1.1177
# Epoch 494, Training Loss: 1.2203, Validation Loss: 1.1177
# Epoch 495, Training Loss: 1.2203, Validation Loss: 1.1177
# Epoch 496, Training Loss: 1.2203, Validation Loss: 1.1176
# Epoch 497, Training Loss: 1.2203, Validation Loss: 1.1176
# Epoch 498, Training Loss: 1.2203, Validation Loss: 1.1175
# Epoch 499, Training Loss: 1.2203, Validation Loss: 1.1175
# Epoch 500, Training Loss: 1.2202, Validation Loss: 1.1175
# Epoch 501, Training Loss: 1.2202, Validation Loss: 1.1174
# Epoch 502, Training Loss: 1.2202, Validation Loss: 1.1174
# Epoch 503, Training Loss: 1.2202, Validation Loss: 1.1173
# Epoch 504, Training Loss: 1.2202, Validation Loss: 1.1173
# Epoch 505, Training Loss: 1.2202, Validation Loss: 1.1173
# Epoch 506, Training Loss: 1.2202, Validation Loss: 1.1172
# Epoch 507, Training Loss: 1.2202, Validation Loss: 1.1172
# Epoch 508, Training Loss: 1.2202, Validation Loss: 1.1172
# Epoch 509, Training Loss: 1.2202, Validation Loss: 1.1171
# Epoch 510, Training Loss: 1.2202, Validation Loss: 1.1171
# Epoch 511, Training Loss: 1.2201, Validation Loss: 1.1171
# Epoch 512, Training Loss: 1.2201, Validation Loss: 1.1170
# Epoch 513, Training Loss: 1.2201, Validation Loss: 1.1170
# Epoch 514, Training Loss: 1.2201, Validation Loss: 1.1170
# Epoch 515, Training Loss: 1.2201, Validation Loss: 1.1169
# Epoch 516, Training Loss: 1.2201, Validation Loss: 1.1169
# Epoch 517, Training Loss: 1.2201, Validation Loss: 1.1169
# Epoch 518, Training Loss: 1.2201, Validation Loss: 1.1168
# Epoch 519, Training Loss: 1.2201, Validation Loss: 1.1168
# Epoch 520, Training Loss: 1.2201, Validation Loss: 1.1168
# Epoch 521, Training Loss: 1.2201, Validation Loss: 1.1167
# Epoch 522, Training Loss: 1.2201, Validation Loss: 1.1167
# Epoch 523, Training Loss: 1.2201, Validation Loss: 1.1167
# Epoch 524, Training Loss: 1.2201, Validation Loss: 1.1167
# Epoch 525, Training Loss: 1.2200, Validation Loss: 1.1166
# Epoch 526, Training Loss: 1.2200, Validation Loss: 1.1166
# Epoch 527, Training Loss: 1.2200, Validation Loss: 1.1166
# Epoch 528, Training Loss: 1.2200, Validation Loss: 1.1165
# Epoch 529, Training Loss: 1.2200, Validation Loss: 1.1165
# Epoch 530, Training Loss: 1.2200, Validation Loss: 1.1165
# Epoch 531, Training Loss: 1.2200, Validation Loss: 1.1165
# Epoch 532, Training Loss: 1.2200, Validation Loss: 1.1164
# Epoch 533, Training Loss: 1.2200, Validation Loss: 1.1164
# Epoch 534, Training Loss: 1.2200, Validation Loss: 1.1164
# Epoch 535, Training Loss: 1.2200, Validation Loss: 1.1164
# Epoch 536, Training Loss: 1.2200, Validation Loss: 1.1163
# Epoch 537, Training Loss: 1.2200, Validation Loss: 1.1163
# Epoch 538, Training Loss: 1.2200, Validation Loss: 1.1163
# Epoch 539, Training Loss: 1.2200, Validation Loss: 1.1163
# Epoch 540, Training Loss: 1.2200, Validation Loss: 1.1162
# Epoch 541, Training Loss: 1.2200, Validation Loss: 1.1162
# Epoch 542, Training Loss: 1.2200, Validation Loss: 1.1162
# Epoch 543, Training Loss: 1.2200, Validation Loss: 1.1162
# Epoch 544, Training Loss: 1.2200, Validation Loss: 1.1161
# Epoch 545, Training Loss: 1.2200, Validation Loss: 1.1161
# Epoch 546, Training Loss: 1.2199, Validation Loss: 1.1161
# Epoch 547, Training Loss: 1.2199, Validation Loss: 1.1161
# Epoch 548, Training Loss: 1.2199, Validation Loss: 1.1161
# Epoch 549, Training Loss: 1.2199, Validation Loss: 1.1160
# Epoch 550, Training Loss: 1.2199, Validation Loss: 1.1160
# Epoch 551, Training Loss: 1.2199, Validation Loss: 1.1160
# Epoch 552, Training Loss: 1.2199, Validation Loss: 1.1160
# Epoch 553, Training Loss: 1.2199, Validation Loss: 1.1160
# Epoch 554, Training Loss: 1.2199, Validation Loss: 1.1159
# Epoch 555, Training Loss: 1.2199, Validation Loss: 1.1159
# Epoch 556, Training Loss: 1.2199, Validation Loss: 1.1159
# Epoch 557, Training Loss: 1.2199, Validation Loss: 1.1159
# Epoch 558, Training Loss: 1.2199, Validation Loss: 1.1159
# Epoch 559, Training Loss: 1.2199, Validation Loss: 1.1158
# Epoch 560, Training Loss: 1.2199, Validation Loss: 1.1158
# Epoch 561, Training Loss: 1.2199, Validation Loss: 1.1158
# Epoch 562, Training Loss: 1.2199, Validation Loss: 1.1158
# Epoch 563, Training Loss: 1.2199, Validation Loss: 1.1158
# Epoch 564, Training Loss: 1.2199, Validation Loss: 1.1157
# Epoch 565, Training Loss: 1.2199, Validation Loss: 1.1157
# Epoch 566, Training Loss: 1.2199, Validation Loss: 1.1157
# Epoch 567, Training Loss: 1.2199, Validation Loss: 1.1157
# Epoch 568, Training Loss: 1.2199, Validation Loss: 1.1157
# Epoch 569, Training Loss: 1.2199, Validation Loss: 1.1157
# Epoch 570, Training Loss: 1.2199, Validation Loss: 1.1156
# Epoch 571, Training Loss: 1.2199, Validation Loss: 1.1156
# Epoch 572, Training Loss: 1.2199, Validation Loss: 1.1156
# Epoch 573, Training Loss: 1.2199, Validation Loss: 1.1156
# Epoch 574, Training Loss: 1.2199, Validation Loss: 1.1156
# Epoch 575, Training Loss: 1.2199, Validation Loss: 1.1156
# Epoch 576, Training Loss: 1.2199, Validation Loss: 1.1155
# Epoch 577, Training Loss: 1.2199, Validation Loss: 1.1155
# Epoch 578, Training Loss: 1.2199, Validation Loss: 1.1155
# Epoch 579, Training Loss: 1.2199, Validation Loss: 1.1155
# Epoch 580, Training Loss: 1.2199, Validation Loss: 1.1155
# Epoch 581, Training Loss: 1.2199, Validation Loss: 1.1155
# Epoch 582, Training Loss: 1.2199, Validation Loss: 1.1155
# Epoch 583, Training Loss: 1.2198, Validation Loss: 1.1154
# Epoch 584, Training Loss: 1.2198, Validation Loss: 1.1154
# Epoch 585, Training Loss: 1.2198, Validation Loss: 1.1154
# Epoch 586, Training Loss: 1.2198, Validation Loss: 1.1154
# Epoch 587, Training Loss: 1.2198, Validation Loss: 1.1154
# Epoch 588, Training Loss: 1.2198, Validation Loss: 1.1154
# Epoch 589, Training Loss: 1.2198, Validation Loss: 1.1154
# Epoch 590, Training Loss: 1.2198, Validation Loss: 1.1153
# Epoch 591, Training Loss: 1.2198, Validation Loss: 1.1153
# Epoch 592, Training Loss: 1.2198, Validation Loss: 1.1153
# Epoch 593, Training Loss: 1.2198, Validation Loss: 1.1153
# Epoch 594, Training Loss: 1.2198, Validation Loss: 1.1153
# Epoch 595, Training Loss: 1.2198, Validation Loss: 1.1153
# Epoch 596, Training Loss: 1.2198, Validation Loss: 1.1153
# Epoch 597, Training Loss: 1.2198, Validation Loss: 1.1153
# Epoch 598, Training Loss: 1.2198, Validation Loss: 1.1152
# Epoch 599, Training Loss: 1.2198, Validation Loss: 1.1152
# Epoch 600, Training Loss: 1.2198, Validation Loss: 1.1152
# Epoch 601, Training Loss: 1.2198, Validation Loss: 1.1152
# Epoch 602, Training Loss: 1.2198, Validation Loss: 1.1152
# Epoch 603, Training Loss: 1.2198, Validation Loss: 1.1152
# Epoch 604, Training Loss: 1.2198, Validation Loss: 1.1152
# Epoch 605, Training Loss: 1.2198, Validation Loss: 1.1152
# Epoch 606, Training Loss: 1.2198, Validation Loss: 1.1152
# Epoch 607, Training Loss: 1.2198, Validation Loss: 1.1151
# Epoch 608, Training Loss: 1.2198, Validation Loss: 1.1151
# Epoch 609, Training Loss: 1.2198, Validation Loss: 1.1151
# Epoch 610, Training Loss: 1.2198, Validation Loss: 1.1151
# Epoch 611, Training Loss: 1.2198, Validation Loss: 1.1151
# Epoch 612, Training Loss: 1.2198, Validation Loss: 1.1151
# Epoch 613, Training Loss: 1.2198, Validation Loss: 1.1151
# Epoch 614, Training Loss: 1.2198, Validation Loss: 1.1151
# Epoch 615, Training Loss: 1.2198, Validation Loss: 1.1151
# Epoch 616, Training Loss: 1.2198, Validation Loss: 1.1151
# Epoch 617, Training Loss: 1.2198, Validation Loss: 1.1150
# Epoch 618, Training Loss: 1.2198, Validation Loss: 1.1150
# Epoch 619, Training Loss: 1.2198, Validation Loss: 1.1150
# Epoch 620, Training Loss: 1.2198, Validation Loss: 1.1150
# Epoch 621, Training Loss: 1.2198, Validation Loss: 1.1150
# Epoch 622, Training Loss: 1.2198, Validation Loss: 1.1150
# Epoch 623, Training Loss: 1.2198, Validation Loss: 1.1150
# Epoch 624, Training Loss: 1.2198, Validation Loss: 1.1150
# Epoch 625, Training Loss: 1.2198, Validation Loss: 1.1150
# Epoch 626, Training Loss: 1.2198, Validation Loss: 1.1150
# Epoch 627, Training Loss: 1.2198, Validation Loss: 1.1150
# Epoch 628, Training Loss: 1.2198, Validation Loss: 1.1150
# Epoch 629, Training Loss: 1.2198, Validation Loss: 1.1149
# Epoch 630, Training Loss: 1.2198, Validation Loss: 1.1149
# Epoch 631, Training Loss: 1.2198, Validation Loss: 1.1149
# Epoch 632, Training Loss: 1.2198, Validation Loss: 1.1149
# Epoch 633, Training Loss: 1.2198, Validation Loss: 1.1149
# Epoch 634, Training Loss: 1.2198, Validation Loss: 1.1149
# Epoch 635, Training Loss: 1.2198, Validation Loss: 1.1149
# Epoch 636, Training Loss: 1.2198, Validation Loss: 1.1149
# Epoch 637, Training Loss: 1.2198, Validation Loss: 1.1149
# Epoch 638, Training Loss: 1.2198, Validation Loss: 1.1149
# Epoch 639, Training Loss: 1.2198, Validation Loss: 1.1149
# Epoch 640, Training Loss: 1.2198, Validation Loss: 1.1149
# Epoch 641, Training Loss: 1.2198, Validation Loss: 1.1149
# Epoch 642, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 643, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 644, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 645, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 646, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 647, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 648, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 649, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 650, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 651, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 652, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 653, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 654, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 655, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 656, Training Loss: 1.2198, Validation Loss: 1.1148
# Epoch 657, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 658, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 659, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 660, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 661, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 662, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 663, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 664, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 665, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 666, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 667, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 668, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 669, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 670, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 671, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 672, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 673, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 674, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 675, Training Loss: 1.2198, Validation Loss: 1.1147
# Epoch 676, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 677, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 678, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 679, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 680, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 681, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 682, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 683, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 684, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 685, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 686, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 687, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 688, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 689, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 690, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 691, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 692, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 693, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 694, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 695, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 696, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 697, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 698, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 699, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 700, Training Loss: 1.2198, Validation Loss: 1.1146
# Epoch 701, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 702, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 703, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 704, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 705, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 706, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 707, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 708, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 709, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 710, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 711, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 712, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 713, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 714, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 715, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 716, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 717, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 718, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 719, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 720, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 721, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 722, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 723, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 724, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 725, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 726, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 727, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 728, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 729, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 730, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 731, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 732, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 733, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 734, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 735, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 736, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 737, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 738, Training Loss: 1.2198, Validation Loss: 1.1145
# Epoch 739, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 740, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 741, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 742, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 743, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 744, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 745, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 746, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 747, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 748, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 749, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 750, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 751, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 752, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 753, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 754, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 755, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 756, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 757, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 758, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 759, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 760, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 761, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 762, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 763, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 764, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 765, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 766, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 767, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 768, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 769, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 770, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 771, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 772, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 773, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 774, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 775, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 776, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 777, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 778, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 779, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 780, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 781, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 782, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 783, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 784, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 785, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 786, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 787, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 788, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 789, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 790, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 791, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 792, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 793, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 794, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 795, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 796, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 797, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 798, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 799, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 800, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 801, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 802, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 803, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 804, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 805, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 806, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 807, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 808, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 809, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 810, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 811, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 812, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 813, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 814, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 815, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 816, Training Loss: 1.2198, Validation Loss: 1.1144
# Epoch 817, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 818, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 819, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 820, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 821, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 822, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 823, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 824, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 825, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 826, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 827, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 828, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 829, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 830, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 831, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 832, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 833, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 834, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 835, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 836, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 837, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 838, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 839, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 840, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 841, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 842, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 843, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 844, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 845, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 846, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 847, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 848, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 849, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 850, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 851, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 852, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 853, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 854, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 855, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 856, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 857, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 858, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 859, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 860, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 861, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 862, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 863, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 864, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 865, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 866, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 867, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 868, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 869, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 870, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 871, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 872, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 873, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 874, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 875, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 876, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 877, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 878, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 879, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 880, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 881, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 882, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 883, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 884, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 885, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 886, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 887, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 888, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 889, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 890, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 891, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 892, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 893, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 894, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 895, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 896, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 897, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 898, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 899, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 900, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 901, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 902, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 903, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 904, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 905, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 906, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 907, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 908, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 909, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 910, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 911, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 912, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 913, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 914, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 915, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 916, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 917, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 918, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 919, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 920, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 921, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 922, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 923, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 924, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 925, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 926, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 927, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 928, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 929, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 930, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 931, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 932, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 933, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 934, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 935, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 936, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 937, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 938, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 939, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 940, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 941, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 942, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 943, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 944, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 945, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 946, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 947, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 948, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 949, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 950, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 951, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 952, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 953, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 954, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 955, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 956, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 957, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 958, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 959, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 960, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 961, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 962, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 963, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 964, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 965, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 966, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 967, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 968, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 969, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 970, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 971, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 972, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 973, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 974, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 975, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 976, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 977, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 978, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 979, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 980, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 981, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 982, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 983, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 984, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 985, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 986, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 987, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 988, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 989, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 990, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 991, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 992, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 993, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 994, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 995, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 996, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 997, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 998, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 999, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1000, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1001, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1002, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1003, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1004, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1005, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1006, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1007, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1008, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1009, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1010, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1011, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1012, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1013, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1014, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1015, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1016, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1017, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1018, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1019, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1020, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1021, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1022, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1023, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1024, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1025, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1026, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1027, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1028, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1029, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1030, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1031, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1032, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1033, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1034, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1035, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1036, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1037, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1038, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1039, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1040, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1041, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1042, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1043, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1044, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1045, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1046, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1047, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1048, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1049, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1050, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1051, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1052, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1053, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1054, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1055, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1056, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1057, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1058, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1059, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1060, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1061, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1062, Training Loss: 1.2198, Validation Loss: 1.1143
# Epoch 1063, Training Loss: 1.2198, Validation Loss: 1.1143
# Early stopping triggered

# %%
# All-control and all-treated for test set
num_product = X_product.shape[0]

# All control: product_randomization = 0
all_product_control = torch.zeros(num_product, device=device).bool()

# All treated: product_randomization = 1
all_product_treated = torch.ones(num_product, device=device).bool()

# Move base price and test users/products to device
X_user_test = X_user_test.to(device)
X_product = X_product.to(device)
price = price.to(device)

# --------- Expected revenue: all control ----------
# Control prices = base prices (no discount)
price_control = price.clone()

# Prepare test data under all-control prices
user_test_ctrl, product_test_ctrl, prices_ctrl, x_other_products_ctrl, other_prices_ctrl = prepare_data(
    X_user_test,
    X_product,
    price_control
)

utilities_ctrl = pdlmodel(
    user_test_ctrl,
    product_test_ctrl,
    x_other_products_ctrl,
    other_prices_ctrl,
    prices_ctrl,          # control prices
    all_product_control   # all False
)

probabilities_ctrl = F.softmax(utilities_ctrl, dim=1)

price_with_outside_ctrl = torch.cat(
    (torch.zeros(1, device=price.device), prices_ctrl), dim=0
)  # [M+1]

expected_revenue_ctrl = torch.sum(
    probabilities_ctrl * price_with_outside_ctrl.unsqueeze(0).expand_as(probabilities_ctrl),
    dim=1
).sum()

print(f"Expected Revenue (all control): ${expected_revenue_ctrl.item():.2f}")

# --------- Expected revenue: all treated ----------
# Treated prices = discounted prices
price_treated = price * discount_percentage

user_test_trt, product_test_trt, prices_trt, x_other_products_trt, other_prices_trt = prepare_data(
    X_user_test,
    X_product,
    price_treated
)

utilities_trt = pdlmodel(
    user_test_trt,
    product_test_trt,
    x_other_products_trt,
    other_prices_trt,
    prices_trt,          # treated prices
    all_product_treated  # all True
)

probabilities_trt = F.softmax(utilities_trt, dim=1)

price_with_outside_trt = torch.cat(
    (torch.zeros(1, device=price.device), prices_trt), dim=0
)

expected_revenue_trt = torch.sum(
    probabilities_trt * price_with_outside_trt.unsqueeze(0).expand_as(probabilities_trt),
    dim=1
).sum()

print(f"Expected Revenue (all treated): ${expected_revenue_trt.item():.2f}")

# --------- GTE ----------
pdl = (expected_revenue_trt - expected_revenue_ctrl).cpu().detach().numpy() * 600 / 266
print(pdl)

pdl_all = abs((pdl - true) / true)
print(pdl_all)
# Out:
# Expected Revenue (all control): $41.17
# Expected Revenue (all treated): $8.23
# -74.286465178755
# 0.08202274490119944

# %% [markdown]
# ## DML Estimator

# %%
def H_theta(theta0_output,theta1_output,all_treated_price,price):
    N = theta0_output.shape[0]
    M = num_product
    expand_price = price.unsqueeze(0).expand(N, M)
    expand_all_treated_price = all_treated_price.unsqueeze(0).expand(N, M)
    all_treated_uti = theta0_output + theta1_output * expand_all_treated_price
    all_control_uti =  theta0_output + theta1_output * expand_price

    zero_utilities = torch.zeros(N, 1, device=all_treated_uti.device)
    all_treated_uti = torch.cat((zero_utilities,all_treated_uti), dim=1)
    all_control_uti = torch.cat((zero_utilities,all_control_uti), dim=1)

    all_treated_probabilities = F.softmax(all_treated_uti, dim=1)
    all_control_probabilities = F.softmax(all_control_uti, dim=1)

    price_with_outside = torch.cat((torch.zeros(1, device=price.device), price), dim=0)
    treated_price_with_outside = torch.cat((torch.zeros(1, device=all_treated_price.device), all_treated_price), dim=0)

    H = torch.sum(all_treated_probabilities * treated_price_with_outside - all_control_probabilities * price_with_outside,dim=1)
    expsum_treated = torch.sum(torch.exp(all_treated_uti),dim=1)
    expsum_control = torch.sum(torch.exp(all_control_uti),dim=1)

    expsum_treated_expanded = expsum_treated.unsqueeze(1).expand(-1, all_treated_uti.shape[1])
    expsum_control_expanded = expsum_control.unsqueeze(1).expand(-1, all_control_uti.shape[1])

    H_theta0 = torch.sum((torch.exp(all_treated_uti)*(1-torch.exp(all_treated_uti))/expsum_treated_expanded/expsum_treated_expanded) * treated_price_with_outside-
                          (torch.exp(all_control_uti)*(1-torch.exp(all_control_uti))/expsum_control_expanded/expsum_control_expanded) * price_with_outside,dim=1)
    H_theta1 = torch.sum((torch.exp(all_treated_uti)*(1-torch.exp(all_treated_uti))/expsum_treated_expanded/expsum_treated_expanded) * treated_price_with_outside * treated_price_with_outside-
                          (torch.exp(all_control_uti)*(1-torch.exp(all_control_uti))/expsum_control_expanded/expsum_control_expanded) * price_with_outside * price_with_outside,dim=1)

    return H,H_theta0,H_theta1

# %%
# l_theta
def l_theta(theta0_output, theta1_output, adjusted_price, decision_test, l2_lambda=1e-4):
    N = theta0_output.shape[0]
    M = theta0_output.shape[1]

    expand_adjusted_price = adjusted_price.unsqueeze(0).expand(N, M)
    uti = theta0_output + theta1_output * expand_adjusted_price

    zero_utilities = torch.zeros(N, 1, device=uti.device)
    uti_with_outside = torch.cat((zero_utilities, uti), dim=1)

    probabilities = F.softmax(uti_with_outside, dim=1)

    prod_indices = torch.ones(M, device=uti.device)
    prod_indices = torch.cat([torch.zeros(1, device=uti.device), prod_indices])

    adjusted_price_with_outside = torch.cat([torch.zeros(1, device=adjusted_price.device), adjusted_price])

    ltheta0 = probabilities[torch.arange(decision_test.size(0)), decision_test] - prod_indices[decision_test]

    ltheta1 = (probabilities[torch.arange(decision_test.size(0)), decision_test] * adjusted_price_with_outside[decision_test]) - \
              (adjusted_price_with_outside[decision_test] * prod_indices[decision_test])

    is_inside = (decision_test > 0)

    inside_indices = (decision_test - 1).clamp(min=0)

    theta0_chosen = theta0_output.gather(1, inside_indices.unsqueeze(1)).squeeze(1)
    theta1_chosen = theta1_output.gather(1, inside_indices.unsqueeze(1)).squeeze(1)

    reg_grad0 = 2 * l2_lambda * theta0_chosen
    reg_grad1 = 2 * l2_lambda * theta1_chosen

    ltheta0 = ltheta0 + (reg_grad0 * is_inside.float())
    ltheta1 = ltheta1 + (reg_grad1 * is_inside.float())

    return ltheta0, ltheta1

# %%
# l_inv
def lambdainv(theta0_output, theta1_output, price, decision_test, epsilon=1e-6, l2_lambda=1e-4):

    N = theta0_output.shape[0]
    M = num_product

    expand_price = price.unsqueeze(0).expand(N, M)
    expand_all_treated_price = discount_percentage * price.unsqueeze(0).expand(N, M)

    all_treated_uti = theta0_output + theta1_output * expand_all_treated_price
    all_control_uti = theta0_output + theta1_output * expand_price

    zero_utilities = torch.zeros(N, 1, device=all_control_uti.device)
    all_treated_uti = torch.cat((zero_utilities, all_treated_uti), dim=1)
    all_control_uti = torch.cat((zero_utilities, all_control_uti), dim=1)

    probabilities_control = F.softmax(all_control_uti, dim=1)
    probabilities_treated = F.softmax(all_treated_uti, dim=1)

    chosen_prob_control = probabilities_control[torch.arange(N), decision_test]
    chosen_prob_treated = probabilities_treated[torch.arange(N), decision_test]

    price_with_outside = torch.cat((torch.zeros(1, device=price.device), price), dim=0)
    all_treated_price_vec = price * discount_percentage # Assuming logic from original code
    treated_price_with_outside = torch.cat((torch.zeros(1, device=price.device), all_treated_price_vec), dim=0)

    expand_price_ext = price_with_outside.unsqueeze(0).expand(N, M+1)

    chosen_price = expand_price_ext[torch.arange(N), decision_test]

    ltheta00 = chosen_prob_control * (1 - chosen_prob_control) + \
               chosen_prob_treated * (1 - chosen_prob_treated)

    ltheta01 = chosen_prob_control * (1 - chosen_prob_control) * chosen_price + \
               chosen_prob_treated * (1 - chosen_prob_treated) * (chosen_price * discount_percentage)

    ltheta11 = chosen_prob_control * (1 - chosen_prob_control) * (chosen_price**2) + \
               chosen_prob_treated * (1 - chosen_prob_treated) * ((chosen_price * discount_percentage)**2)

    ltheta00 = ltheta00 / 2
    ltheta01 = ltheta01 / 2
    ltheta11 = ltheta11 / 2

    ltheta00 = ltheta00.unsqueeze(1).unsqueeze(2)
    ltheta01 = ltheta01.unsqueeze(1).unsqueeze(2)
    ltheta11 = ltheta11.unsqueeze(1).unsqueeze(2)

    top_row = torch.cat((ltheta00, ltheta01), dim=2)
    bottom_row = torch.cat((ltheta01, ltheta11), dim=2)

    L_matrix = torch.cat((top_row, bottom_row), dim=1) # [N, 2, 2]

    reg_hessian_value = 2 * l2_lambda
    identity_matrix = torch.eye(2, dtype=L_matrix.dtype, device=L_matrix.device)
    reg_matrix = identity_matrix.unsqueeze(0).expand(N, 2, 2) * reg_hessian_value

    L_total = L_matrix + reg_matrix + (identity_matrix.unsqueeze(0) * epsilon)

    L_inv = torch.linalg.inv(L_total)

    return L_inv

# %% [markdown]
# ### No features

# %%
class UtilityEstimator_No(nn.Module):
    def __init__(self, num_product): 
        super(UtilityEstimator_No, self).__init__()
        self.num_product = num_product

        self.theta0 = nn.Parameter(torch.tensor(1.0)) 
        self.theta1 = nn.Parameter(torch.tensor(-1.0)) 

    def forward(self, x_user, x_product, x_other_products, x_other_prices, price):
        """
        price: [M]
        """
        N = x_user.shape[0]
        M = self.num_product

        u_product = self.theta0 + self.theta1 * price 
        
        utilities = u_product.unsqueeze(0).expand(N, -1)
        zero_utilities = torch.zeros(N, 1, device=price.device)
        utilities_with_outside = torch.cat([zero_utilities, utilities], dim=1)


        theta0_expanded = self.theta0.view(1, 1).expand(N, M)
        theta1_expanded = self.theta1.view(1, 1).expand(N, M)

        return utilities_with_outside, theta0_expanded, theta1_expanded

# %%
# Apply the model
dml_model = UtilityEstimator_No(
    num_product=X_product.shape[0]
).to(device)


# Initialize weight
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)
dml_model.apply(init_weights)
# Out:
# UtilityEstimator_No()

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# Train the model
optimizer = torch.optim.Adam(dml_model.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)
l2_lambda = 0
best_val_loss = float('inf')
patience = 10
patience_counter = 0

for epoch in range(5000):
    dml_model.train()  # Set model to training mode
    optimizer.zero_grad()

    outputs = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)[0]
    choice_probabilities = torch.nn.functional.log_softmax(outputs, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])
    l2_norm = sum(param.pow(2.0).sum() for param in dml_model.parameters())
    loss = loss + l2_lambda * l2_norm
    loss.backward()
    optimizer.step()
    scheduler.step()

    # Validation phase
    dml_model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        val_outputs = dml_model(X_user_val, product_features, all_x_other_products, all_other_prices,prices)[0]
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])
    print(f"Epoch {epoch+1}, Training Loss: {loss.item()}, Validation Loss: {val_loss.item()}")
    # Check if validation loss improved
    if (val_loss < best_val_loss)|(val_loss<loss):
        best_val_loss = val_loss
        patience_counter = 0  # Reset counter on improvement
        torch.save(dml_model.state_dict(), 'best_model.pth')  # Save the best model
    else:
        patience_counter += 1  # Increment counter if no improvement

    # Early stopping condition
    if patience_counter >= patience:
        print("Early stopping triggered")
        break
# Out:
# Epoch 1, Training Loss: 2.2338318824768066, Validation Loss: 2.309324026107788
# Epoch 2, Training Loss: 2.2258245944976807, Validation Loss: 2.301340103149414
# Epoch 3, Training Loss: 2.217845916748047, Validation Loss: 2.2933857440948486
# Epoch 4, Training Loss: 2.20989727973938, Validation Loss: 2.28546142578125
# Epoch 5, Training Loss: 2.2019786834716797, Validation Loss: 2.2775676250457764
# Epoch 6, Training Loss: 2.1940908432006836, Validation Loss: 2.2697055339813232
# Epoch 7, Training Loss: 2.186234474182129, Validation Loss: 2.2618746757507324
# Epoch 8, Training Loss: 2.1784098148345947, Validation Loss: 2.2540760040283203
# Epoch 9, Training Loss: 2.1706178188323975, Validation Loss: 2.2463104724884033
# Epoch 10, Training Loss: 2.1628589630126953, Validation Loss: 2.2385780811309814
# Epoch 11, Training Loss: 2.1551339626312256, Validation Loss: 2.230879306793213
# Epoch 12, Training Loss: 2.1474428176879883, Validation Loss: 2.223215341567993
# Epoch 13, Training Loss: 2.139786958694458, Validation Loss: 2.215585947036743
# Epoch 14, Training Loss: 2.1321661472320557, Validation Loss: 2.2079918384552
# Epoch 15, Training Loss: 2.1245810985565186, Validation Loss: 2.2004334926605225
# Epoch 16, Training Loss: 2.117032527923584, Validation Loss: 2.192911386489868
# Epoch 17, Training Loss: 2.109520673751831, Validation Loss: 2.185425281524658
# Epoch 18, Training Loss: 2.1020455360412598, Validation Loss: 2.1779768466949463
# Epoch 19, Training Loss: 2.0946083068847656, Validation Loss: 2.170565128326416
# Epoch 20, Training Loss: 2.087209463119507, Validation Loss: 2.163191795349121
# Epoch 21, Training Loss: 2.0798487663269043, Validation Loss: 2.155856132507324
# Epoch 22, Training Loss: 2.0725269317626953, Validation Loss: 2.148559093475342
# Epoch 23, Training Loss: 2.065244674682617, Validation Loss: 2.141301155090332
# Epoch 24, Training Loss: 2.0580015182495117, Validation Loss: 2.1340818405151367
# Epoch 25, Training Loss: 2.0507984161376953, Validation Loss: 2.1269021034240723
# Epoch 26, Training Loss: 2.043635845184326, Validation Loss: 2.1197621822357178
# Epoch 27, Training Loss: 2.036513566970825, Validation Loss: 2.112661600112915
# Epoch 28, Training Loss: 2.0294322967529297, Validation Loss: 2.1056017875671387
# Epoch 29, Training Loss: 2.0223920345306396, Validation Loss: 2.0985825061798096
# Epoch 30, Training Loss: 2.015393018722534, Validation Loss: 2.0916035175323486
# Epoch 31, Training Loss: 2.0084354877471924, Validation Loss: 2.084665536880493
# Epoch 32, Training Loss: 2.0015199184417725, Validation Loss: 2.077768325805664
# Epoch 33, Training Loss: 1.9946467876434326, Validation Loss: 2.0709128379821777
# Epoch 34, Training Loss: 1.9878153800964355, Validation Loss: 2.0640981197357178
# Epoch 35, Training Loss: 1.981026530265808, Validation Loss: 2.057325601577759
# Epoch 36, Training Loss: 1.9742804765701294, Validation Loss: 2.0505943298339844
# Epoch 37, Training Loss: 1.9675769805908203, Validation Loss: 2.043905019760132
# Epoch 38, Training Loss: 1.9609166383743286, Validation Loss: 2.037257671356201
# Epoch 39, Training Loss: 1.954298973083496, Validation Loss: 2.0306522846221924
# Epoch 40, Training Loss: 1.9477245807647705, Validation Loss: 2.0240890979766846
# Epoch 41, Training Loss: 1.9411935806274414, Validation Loss: 2.017568349838257
# Epoch 42, Training Loss: 1.9347058534622192, Validation Loss: 2.01108980178833
# Epoch 43, Training Loss: 1.928261637687683, Validation Loss: 2.0046536922454834
# Epoch 44, Training Loss: 1.921860933303833, Validation Loss: 1.9982599020004272
# Epoch 45, Training Loss: 1.9155036211013794, Validation Loss: 1.9919089078903198
# Epoch 46, Training Loss: 1.90919029712677, Validation Loss: 1.9856005907058716
# Epoch 47, Training Loss: 1.9029207229614258, Validation Loss: 1.9793344736099243
# Epoch 48, Training Loss: 1.8966946601867676, Validation Loss: 1.9731111526489258
# Epoch 49, Training Loss: 1.8905125856399536, Validation Loss: 1.9669305086135864
# Epoch 50, Training Loss: 1.8843746185302734, Validation Loss: 1.9607927799224854
# Epoch 51, Training Loss: 1.8782801628112793, Validation Loss: 1.9546974897384644
# Epoch 52, Training Loss: 1.8722295761108398, Validation Loss: 1.948644995689392
# Epoch 53, Training Loss: 1.866222858428955, Validation Loss: 1.9426349401474
# Epoch 54, Training Loss: 1.8602601289749146, Validation Loss: 1.9366681575775146
# Epoch 55, Training Loss: 1.8543416261672974, Validation Loss: 1.9307435750961304
# Epoch 56, Training Loss: 1.8484666347503662, Validation Loss: 1.9248619079589844
# Epoch 57, Training Loss: 1.8426355123519897, Validation Loss: 1.919022798538208
# Epoch 58, Training Loss: 1.8368481397628784, Validation Loss: 1.9132264852523804
# Epoch 59, Training Loss: 1.8311048746109009, Validation Loss: 1.9074723720550537
# Epoch 60, Training Loss: 1.8254053592681885, Validation Loss: 1.9017610549926758
# Epoch 61, Training Loss: 1.8197492361068726, Validation Loss: 1.8960920572280884
# Epoch 62, Training Loss: 1.8141372203826904, Validation Loss: 1.8904656171798706
# Epoch 63, Training Loss: 1.8085685968399048, Validation Loss: 1.8848813772201538
# Epoch 64, Training Loss: 1.8030434846878052, Validation Loss: 1.8793398141860962
# Epoch 65, Training Loss: 1.7975623607635498, Validation Loss: 1.87384033203125
# Epoch 66, Training Loss: 1.7921242713928223, Validation Loss: 1.8683830499649048
# Epoch 67, Training Loss: 1.7867298126220703, Validation Loss: 1.862967848777771
# Epoch 68, Training Loss: 1.7813787460327148, Validation Loss: 1.857594609260559
# Epoch 69, Training Loss: 1.7760705947875977, Validation Loss: 1.8522635698318481
# Epoch 70, Training Loss: 1.7708061933517456, Validation Loss: 1.84697425365448
# Epoch 71, Training Loss: 1.7655842304229736, Validation Loss: 1.8417266607284546
# Epoch 72, Training Loss: 1.7604060173034668, Validation Loss: 1.836521029472351
# Epoch 73, Training Loss: 1.755270004272461, Validation Loss: 1.8313567638397217
# Epoch 74, Training Loss: 1.750177025794983, Validation Loss: 1.826233983039856
# Epoch 75, Training Loss: 1.7451272010803223, Validation Loss: 1.8211530447006226
# Epoch 76, Training Loss: 1.7401198148727417, Validation Loss: 1.816112756729126
# Epoch 77, Training Loss: 1.735154628753662, Validation Loss: 1.8111141920089722
# Epoch 78, Training Loss: 1.7302321195602417, Validation Loss: 1.8061563968658447
# Epoch 79, Training Loss: 1.7253519296646118, Validation Loss: 1.8012396097183228
# Epoch 80, Training Loss: 1.7205134630203247, Validation Loss: 1.7963637113571167
# Epoch 81, Training Loss: 1.7157174348831177, Validation Loss: 1.7915284633636475
# Epoch 82, Training Loss: 1.710963249206543, Validation Loss: 1.786733865737915
# Epoch 83, Training Loss: 1.7062510251998901, Validation Loss: 1.7819796800613403
# Epoch 84, Training Loss: 1.7015801668167114, Validation Loss: 1.7772657871246338
# Epoch 85, Training Loss: 1.696950912475586, Validation Loss: 1.7725921869277954
# Epoch 86, Training Loss: 1.6923633813858032, Validation Loss: 1.7679582834243774
# Epoch 87, Training Loss: 1.6878167390823364, Validation Loss: 1.763364553451538
# Epoch 88, Training Loss: 1.6833112239837646, Validation Loss: 1.7588104009628296
# Epoch 89, Training Loss: 1.6788465976715088, Validation Loss: 1.7542961835861206
# Epoch 90, Training Loss: 1.674423098564148, Validation Loss: 1.7498210668563843
# Epoch 91, Training Loss: 1.6700400114059448, Validation Loss: 1.7453851699829102
# Epoch 92, Training Loss: 1.6656975746154785, Validation Loss: 1.7409886121749878
# Epoch 93, Training Loss: 1.6613951921463013, Validation Loss: 1.736631155014038
# Epoch 94, Training Loss: 1.6571329832077026, Validation Loss: 1.7323122024536133
# Epoch 95, Training Loss: 1.6529110670089722, Validation Loss: 1.728031873703003
# Epoch 96, Training Loss: 1.648728609085083, Validation Loss: 1.7237900495529175
# Epoch 97, Training Loss: 1.6445858478546143, Validation Loss: 1.7195864915847778
# Epoch 98, Training Loss: 1.6404826641082764, Validation Loss: 1.7154209613800049
# Epoch 99, Training Loss: 1.6364189386367798, Validation Loss: 1.711293339729309
# Epoch 100, Training Loss: 1.6323939561843872, Validation Loss: 1.7072036266326904
# Epoch 101, Training Loss: 1.6284081935882568, Validation Loss: 1.7031511068344116
# Epoch 102, Training Loss: 1.6244609355926514, Validation Loss: 1.6991361379623413
# Epoch 103, Training Loss: 1.6205521821975708, Validation Loss: 1.69515860080719
# Epoch 104, Training Loss: 1.6166821718215942, Validation Loss: 1.6912174224853516
# Epoch 105, Training Loss: 1.6128499507904053, Validation Loss: 1.687313199043274
# Epoch 106, Training Loss: 1.609055519104004, Validation Loss: 1.683445692062378
# Epoch 107, Training Loss: 1.6052991151809692, Validation Loss: 1.6796141862869263
# Epoch 108, Training Loss: 1.6015799045562744, Validation Loss: 1.6758191585540771
# Epoch 109, Training Loss: 1.5978986024856567, Validation Loss: 1.6720600128173828
# Epoch 110, Training Loss: 1.5942538976669312, Validation Loss: 1.6683366298675537
# Epoch 111, Training Loss: 1.5906463861465454, Validation Loss: 1.6646486520767212
# Epoch 112, Training Loss: 1.5870753526687622, Validation Loss: 1.6609960794448853
# Epoch 113, Training Loss: 1.583540916442871, Validation Loss: 1.6573785543441772
# Epoch 114, Training Loss: 1.5800427198410034, Validation Loss: 1.653795838356018
# Epoch 115, Training Loss: 1.5765804052352905, Validation Loss: 1.6502474546432495
# Epoch 116, Training Loss: 1.5731539726257324, Validation Loss: 1.6467339992523193
# Epoch 117, Training Loss: 1.5697633028030396, Validation Loss: 1.6432543992996216
# Epoch 118, Training Loss: 1.5664077997207642, Validation Loss: 1.6398087739944458
# Epoch 119, Training Loss: 1.5630875825881958, Validation Loss: 1.6363970041275024
# Epoch 120, Training Loss: 1.5598021745681763, Validation Loss: 1.6330186128616333
# Epoch 121, Training Loss: 1.5565510988235474, Validation Loss: 1.6296733617782593
# Epoch 122, Training Loss: 1.5533348321914673, Validation Loss: 1.626361608505249
# Epoch 123, Training Loss: 1.5501526594161987, Validation Loss: 1.623082160949707
# Epoch 124, Training Loss: 1.5470044612884521, Validation Loss: 1.619835615158081
# Epoch 125, Training Loss: 1.5438898801803589, Validation Loss: 1.6166210174560547
# Epoch 126, Training Loss: 1.5408087968826294, Validation Loss: 1.6134388446807861
# Epoch 127, Training Loss: 1.5377609729766846, Validation Loss: 1.6102880239486694
# Epoch 128, Training Loss: 1.5347460508346558, Validation Loss: 1.6071691513061523
# Epoch 129, Training Loss: 1.5317637920379639, Validation Loss: 1.6040815114974976
# Epoch 130, Training Loss: 1.5288141965866089, Validation Loss: 1.601024866104126
# Epoch 131, Training Loss: 1.5258965492248535, Validation Loss: 1.5979993343353271
# Epoch 132, Training Loss: 1.5230112075805664, Validation Loss: 1.5950040817260742
# Epoch 133, Training Loss: 1.5201573371887207, Validation Loss: 1.5920393466949463
# Epoch 134, Training Loss: 1.5173349380493164, Validation Loss: 1.5891045331954956
# Epoch 135, Training Loss: 1.514543890953064, Validation Loss: 1.5861997604370117
# Epoch 136, Training Loss: 1.5117837190628052, Validation Loss: 1.5833244323730469
# Epoch 137, Training Loss: 1.5090545415878296, Validation Loss: 1.5804784297943115
# Epoch 138, Training Loss: 1.5063554048538208, Validation Loss: 1.5776615142822266
# Epoch 139, Training Loss: 1.5036863088607788, Validation Loss: 1.5748733282089233
# Epoch 140, Training Loss: 1.5010477304458618, Validation Loss: 1.5721137523651123
# Epoch 141, Training Loss: 1.4984383583068848, Validation Loss: 1.5693825483322144
# Epoch 142, Training Loss: 1.4958584308624268, Validation Loss: 1.5666793584823608
# Epoch 143, Training Loss: 1.4933079481124878, Validation Loss: 1.5640039443969727
# Epoch 144, Training Loss: 1.4907863140106201, Validation Loss: 1.5613559484481812
# Epoch 145, Training Loss: 1.4882930517196655, Validation Loss: 1.5587354898452759
# Epoch 146, Training Loss: 1.4858283996582031, Validation Loss: 1.55614173412323
# Epoch 147, Training Loss: 1.4833916425704956, Validation Loss: 1.5535746812820435
# Epoch 148, Training Loss: 1.4809828996658325, Validation Loss: 1.5510345697402954
# Epoch 149, Training Loss: 1.4786016941070557, Validation Loss: 1.5485203266143799
# Epoch 150, Training Loss: 1.4762481451034546, Validation Loss: 1.546032190322876
# Epoch 151, Training Loss: 1.4739211797714233, Validation Loss: 1.543569803237915
# Epoch 152, Training Loss: 1.471621036529541, Validation Loss: 1.5411328077316284
# Epoch 153, Training Loss: 1.4693478345870972, Validation Loss: 1.538720965385437
# Epoch 154, Training Loss: 1.4671005010604858, Validation Loss: 1.5363341569900513
# Epoch 155, Training Loss: 1.4648793935775757, Validation Loss: 1.533971905708313
# Epoch 156, Training Loss: 1.462683916091919, Validation Loss: 1.5316343307495117
# Epoch 157, Training Loss: 1.4605141878128052, Validation Loss: 1.5293205976486206
# Epoch 158, Training Loss: 1.4583693742752075, Validation Loss: 1.5270310640335083
# Epoch 159, Training Loss: 1.456249713897705, Validation Loss: 1.524765133857727
# Epoch 160, Training Loss: 1.4541547298431396, Validation Loss: 1.5225225687026978
# Epoch 161, Training Loss: 1.4520844221115112, Validation Loss: 1.5203030109405518
# Epoch 162, Training Loss: 1.4500380754470825, Validation Loss: 1.5181065797805786
# Epoch 163, Training Loss: 1.448015570640564, Validation Loss: 1.5159326791763306
# Epoch 164, Training Loss: 1.4460170269012451, Validation Loss: 1.5137813091278076
# Epoch 165, Training Loss: 1.4440418481826782, Validation Loss: 1.5116519927978516
# Epoch 166, Training Loss: 1.4420897960662842, Validation Loss: 1.5095442533493042
# Epoch 167, Training Loss: 1.4401605129241943, Validation Loss: 1.5074586868286133
# Epoch 168, Training Loss: 1.4382542371749878, Validation Loss: 1.5053941011428833
# Epoch 169, Training Loss: 1.4363701343536377, Validation Loss: 1.5033509731292725
# Epoch 170, Training Loss: 1.4345083236694336, Validation Loss: 1.5013283491134644
# Epoch 171, Training Loss: 1.4326683282852173, Validation Loss: 1.4993268251419067
# Epoch 172, Training Loss: 1.4308500289916992, Validation Loss: 1.4973455667495728
# Epoch 173, Training Loss: 1.4290533065795898, Validation Loss: 1.4953843355178833
# Epoch 174, Training Loss: 1.427277684211731, Validation Loss: 1.4934431314468384
# Epoch 175, Training Loss: 1.4255229234695435, Validation Loss: 1.4915212392807007
# Epoch 176, Training Loss: 1.4237886667251587, Validation Loss: 1.4896193742752075
# Epoch 177, Training Loss: 1.4220751523971558, Validation Loss: 1.4877361059188843
# Epoch 178, Training Loss: 1.4203814268112183, Validation Loss: 1.4858723878860474
# Epoch 179, Training Loss: 1.4187079668045044, Validation Loss: 1.4840270280838013
# Epoch 180, Training Loss: 1.4170541763305664, Validation Loss: 1.4822003841400146
# Epoch 181, Training Loss: 1.4154199361801147, Validation Loss: 1.4803918600082397
# Epoch 182, Training Loss: 1.4138048887252808, Validation Loss: 1.4786014556884766
# Epoch 183, Training Loss: 1.4122087955474854, Validation Loss: 1.4768288135528564
# Epoch 184, Training Loss: 1.4106312990188599, Validation Loss: 1.4750738143920898
# Epoch 185, Training Loss: 1.4090726375579834, Validation Loss: 1.4733359813690186
# Epoch 186, Training Loss: 1.4075322151184082, Validation Loss: 1.4716154336929321
# Epoch 187, Training Loss: 1.4060096740722656, Validation Loss: 1.469911813735962
# Epoch 188, Training Loss: 1.4045051336288452, Validation Loss: 1.4682248830795288
# Epoch 189, Training Loss: 1.4030182361602783, Validation Loss: 1.4665542840957642
# Epoch 190, Training Loss: 1.4015487432479858, Validation Loss: 1.4648998975753784
# Epoch 191, Training Loss: 1.4000962972640991, Validation Loss: 1.463261604309082
# Epoch 192, Training Loss: 1.3986608982086182, Validation Loss: 1.4616392850875854
# Epoch 193, Training Loss: 1.3972421884536743, Validation Loss: 1.460032343864441
# Epoch 194, Training Loss: 1.3958401679992676, Validation Loss: 1.4584410190582275
# Epoch 195, Training Loss: 1.3944542407989502, Validation Loss: 1.4568647146224976
# Epoch 196, Training Loss: 1.3930845260620117, Validation Loss: 1.4553033113479614
# Epoch 197, Training Loss: 1.3917304277420044, Validation Loss: 1.4537569284439087
# Epoch 198, Training Loss: 1.3903924226760864, Validation Loss: 1.452224850654602
# Epoch 199, Training Loss: 1.389069676399231, Validation Loss: 1.4507074356079102
# Epoch 200, Training Loss: 1.3877620697021484, Validation Loss: 1.4492040872573853
# Epoch 201, Training Loss: 1.3864697217941284, Validation Loss: 1.4477146863937378
# Epoch 202, Training Loss: 1.3851921558380127, Validation Loss: 1.4462387561798096
# Epoch 203, Training Loss: 1.3839291334152222, Validation Loss: 1.4447767734527588
# Epoch 204, Training Loss: 1.3826805353164673, Validation Loss: 1.4433280229568481
# Epoch 205, Training Loss: 1.381446123123169, Validation Loss: 1.4418926239013672
# Epoch 206, Training Loss: 1.3802260160446167, Validation Loss: 1.4404703378677368
# Epoch 207, Training Loss: 1.379019856452942, Validation Loss: 1.4390603303909302
# Epoch 208, Training Loss: 1.3778269290924072, Validation Loss: 1.4376634359359741
# Epoch 209, Training Loss: 1.376647710800171, Validation Loss: 1.4362787008285522
# Epoch 210, Training Loss: 1.3754818439483643, Validation Loss: 1.4349063634872437
# Epoch 211, Training Loss: 1.374328851699829, Validation Loss: 1.4335461854934692
# Epoch 212, Training Loss: 1.3731889724731445, Validation Loss: 1.43219792842865
# Epoch 213, Training Loss: 1.372061848640442, Validation Loss: 1.430861473083496
# Epoch 214, Training Loss: 1.370947241783142, Validation Loss: 1.4295364618301392
# Epoch 215, Training Loss: 1.369844913482666, Validation Loss: 1.4282232522964478
# Epoch 216, Training Loss: 1.3687551021575928, Validation Loss: 1.4269208908081055
# Epoch 217, Training Loss: 1.367677092552185, Validation Loss: 1.4256293773651123
# Epoch 218, Training Loss: 1.3666108846664429, Validation Loss: 1.4243491888046265
# Epoch 219, Training Loss: 1.3655563592910767, Validation Loss: 1.4230793714523315
# Epoch 220, Training Loss: 1.3645133972167969, Validation Loss: 1.4218206405639648
# Epoch 221, Training Loss: 1.363481879234314, Validation Loss: 1.42057204246521
# Epoch 222, Training Loss: 1.3624614477157593, Validation Loss: 1.4193336963653564
# Epoch 223, Training Loss: 1.3614519834518433, Validation Loss: 1.4181054830551147
# Epoch 224, Training Loss: 1.3604536056518555, Validation Loss: 1.4168872833251953
# Epoch 225, Training Loss: 1.3594658374786377, Validation Loss: 1.4156789779663086
# Epoch 226, Training Loss: 1.3584885597229004, Validation Loss: 1.414480209350586
# Epoch 227, Training Loss: 1.357521653175354, Validation Loss: 1.4132909774780273
# Epoch 228, Training Loss: 1.3565651178359985, Validation Loss: 1.4121111631393433
# Epoch 229, Training Loss: 1.3556184768676758, Validation Loss: 1.4109405279159546
# Epoch 230, Training Loss: 1.3546820878982544, Validation Loss: 1.4097788333892822
# Epoch 231, Training Loss: 1.3537551164627075, Validation Loss: 1.4086265563964844
# Epoch 232, Training Loss: 1.3528380393981934, Validation Loss: 1.4074828624725342
# Epoch 233, Training Loss: 1.3519306182861328, Validation Loss: 1.406347632408142
# Epoch 234, Training Loss: 1.3510322570800781, Validation Loss: 1.4052209854125977
# Epoch 235, Training Loss: 1.3501431941986084, Validation Loss: 1.4041029214859009
# Epoch 236, Training Loss: 1.3492634296417236, Validation Loss: 1.4029932022094727
# Epoch 237, Training Loss: 1.348392367362976, Validation Loss: 1.4018914699554443
# Epoch 238, Training Loss: 1.3475303649902344, Validation Loss: 1.400797963142395
# Epoch 239, Training Loss: 1.3466768264770508, Validation Loss: 1.3997122049331665
# Epoch 240, Training Loss: 1.3458318710327148, Validation Loss: 1.3986341953277588
# Epoch 241, Training Loss: 1.3449954986572266, Validation Loss: 1.3975639343261719
# Epoch 242, Training Loss: 1.3441673517227173, Validation Loss: 1.3965013027191162
# Epoch 243, Training Loss: 1.343347191810608, Validation Loss: 1.395445704460144
# Epoch 244, Training Loss: 1.342535138130188, Validation Loss: 1.3943979740142822
# Epoch 245, Training Loss: 1.341731309890747, Validation Loss: 1.3933571577072144
# Epoch 246, Training Loss: 1.340935230255127, Validation Loss: 1.39232337474823
# Epoch 247, Training Loss: 1.3401468992233276, Validation Loss: 1.3912967443466187
# Epoch 248, Training Loss: 1.3393657207489014, Validation Loss: 1.3902767896652222
# Epoch 249, Training Loss: 1.338592290878296, Validation Loss: 1.3892637491226196
# Epoch 250, Training Loss: 1.3378262519836426, Validation Loss: 1.3882572650909424
# Epoch 251, Training Loss: 1.3370673656463623, Validation Loss: 1.38725745677948
# Epoch 252, Training Loss: 1.3363155126571655, Validation Loss: 1.3862639665603638
# Epoch 253, Training Loss: 1.3355709314346313, Validation Loss: 1.3852767944335938
# Epoch 254, Training Loss: 1.3348332643508911, Validation Loss: 1.3842960596084595
# Epoch 255, Training Loss: 1.3341020345687866, Validation Loss: 1.3833215236663818
# Epoch 256, Training Loss: 1.3333778381347656, Validation Loss: 1.3823528289794922
# Epoch 257, Training Loss: 1.3326603174209595, Validation Loss: 1.3813903331756592
# Epoch 258, Training Loss: 1.3319488763809204, Validation Loss: 1.380433440208435
# Epoch 259, Training Loss: 1.3312442302703857, Validation Loss: 1.379482626914978
# Epoch 260, Training Loss: 1.3305459022521973, Validation Loss: 1.3785372972488403
# Epoch 261, Training Loss: 1.3298536539077759, Validation Loss: 1.3775978088378906
# Epoch 262, Training Loss: 1.3291674852371216, Validation Loss: 1.3766634464263916
# Epoch 263, Training Loss: 1.3284873962402344, Validation Loss: 1.3757349252700806
# Epoch 264, Training Loss: 1.3278130292892456, Validation Loss: 1.3748115301132202
# Epoch 265, Training Loss: 1.3271448612213135, Validation Loss: 1.3738936185836792
# Epoch 266, Training Loss: 1.3264822959899902, Validation Loss: 1.3729809522628784
# Epoch 267, Training Loss: 1.325825572013855, Validation Loss: 1.3720731735229492
# Epoch 268, Training Loss: 1.325174331665039, Validation Loss: 1.3711702823638916
# Epoch 269, Training Loss: 1.324528455734253, Validation Loss: 1.3702727556228638
# Epoch 270, Training Loss: 1.3238879442214966, Validation Loss: 1.3693798780441284
# Epoch 271, Training Loss: 1.3232530355453491, Validation Loss: 1.3684918880462646
# Epoch 272, Training Loss: 1.3226231336593628, Validation Loss: 1.367608666419983
# Epoch 273, Training Loss: 1.3219987154006958, Validation Loss: 1.3667300939559937
# Epoch 274, Training Loss: 1.3213791847229004, Validation Loss: 1.3658561706542969
# Epoch 275, Training Loss: 1.3207646608352661, Validation Loss: 1.3649866580963135
# Epoch 276, Training Loss: 1.3201552629470825, Validation Loss: 1.3641217947006226
# Epoch 277, Training Loss: 1.319550633430481, Validation Loss: 1.363261103630066
# Epoch 278, Training Loss: 1.3189507722854614, Validation Loss: 1.3624049425125122
# Epoch 279, Training Loss: 1.318355679512024, Validation Loss: 1.3615529537200928
# Epoch 280, Training Loss: 1.317765235900879, Validation Loss: 1.3607053756713867
# Epoch 281, Training Loss: 1.317179560661316, Validation Loss: 1.359861969947815
# Epoch 282, Training Loss: 1.3165981769561768, Validation Loss: 1.3590222597122192
# Epoch 283, Training Loss: 1.3160213232040405, Validation Loss: 1.3581868410110474
# Epoch 284, Training Loss: 1.3154488801956177, Validation Loss: 1.3573554754257202
# Epoch 285, Training Loss: 1.3148809671401978, Validation Loss: 1.3565280437469482
# Epoch 286, Training Loss: 1.314317226409912, Validation Loss: 1.3557041883468628
# Epoch 287, Training Loss: 1.3137574195861816, Validation Loss: 1.3548845052719116
# Epoch 288, Training Loss: 1.3132020235061646, Validation Loss: 1.354068398475647
# Epoch 289, Training Loss: 1.3126507997512817, Validation Loss: 1.353256106376648
# Epoch 290, Training Loss: 1.312103509902954, Validation Loss: 1.352447271347046
# Epoch 291, Training Loss: 1.3115601539611816, Validation Loss: 1.3516422510147095
# Epoch 292, Training Loss: 1.311020851135254, Validation Loss: 1.35084068775177
# Epoch 293, Training Loss: 1.3104852437973022, Validation Loss: 1.350042700767517
# Epoch 294, Training Loss: 1.3099534511566162, Validation Loss: 1.3492482900619507
# Epoch 295, Training Loss: 1.309425711631775, Validation Loss: 1.3484570980072021
# Epoch 296, Training Loss: 1.308901309967041, Validation Loss: 1.3476693630218506
# Epoch 297, Training Loss: 1.3083804845809937, Validation Loss: 1.3468849658966064
# Epoch 298, Training Loss: 1.307863712310791, Validation Loss: 1.3461039066314697
# Epoch 299, Training Loss: 1.3073502779006958, Validation Loss: 1.3453258275985718
# Epoch 300, Training Loss: 1.3068403005599976, Validation Loss: 1.3445512056350708
# Epoch 301, Training Loss: 1.3063338994979858, Validation Loss: 1.3437798023223877
# Epoch 302, Training Loss: 1.3058308362960815, Validation Loss: 1.3430112600326538
# Epoch 303, Training Loss: 1.3053311109542847, Validation Loss: 1.342246174812317
# Epoch 304, Training Loss: 1.3048347234725952, Validation Loss: 1.3414840698242188
# Epoch 305, Training Loss: 1.3043416738510132, Validation Loss: 1.3407248258590698
# Epoch 306, Training Loss: 1.3038517236709595, Validation Loss: 1.3399685621261597
# Epoch 307, Training Loss: 1.3033651113510132, Validation Loss: 1.3392152786254883
# Epoch 308, Training Loss: 1.3028815984725952, Validation Loss: 1.3384648561477661
# Epoch 309, Training Loss: 1.3024013042449951, Validation Loss: 1.3377174139022827
# Epoch 310, Training Loss: 1.3019239902496338, Validation Loss: 1.3369728326797485
# Epoch 311, Training Loss: 1.3014496564865112, Validation Loss: 1.3362306356430054
# Epoch 312, Training Loss: 1.300978183746338, Validation Loss: 1.3354917764663696
# Epoch 313, Training Loss: 1.300510048866272, Validation Loss: 1.334755539894104
# Epoch 314, Training Loss: 1.3000446557998657, Validation Loss: 1.3340219259262085
# Epoch 315, Training Loss: 1.2995821237564087, Validation Loss: 1.3332910537719727
# Epoch 316, Training Loss: 1.2991225719451904, Validation Loss: 1.332562804222107
# Epoch 317, Training Loss: 1.2986655235290527, Validation Loss: 1.3318370580673218
# Epoch 318, Training Loss: 1.2982115745544434, Validation Loss: 1.3311141729354858
# Epoch 319, Training Loss: 1.2977601289749146, Validation Loss: 1.3303937911987305
# Epoch 320, Training Loss: 1.2973116636276245, Validation Loss: 1.3296759128570557
# Epoch 321, Training Loss: 1.2968658208847046, Validation Loss: 1.3289605379104614
# Epoch 322, Training Loss: 1.2964223623275757, Validation Loss: 1.3282476663589478
# Epoch 323, Training Loss: 1.295981526374817, Validation Loss: 1.3275372982025146
# Epoch 324, Training Loss: 1.2955434322357178, Validation Loss: 1.3268293142318726
# Epoch 325, Training Loss: 1.2951080799102783, Validation Loss: 1.3261239528656006
# Epoch 326, Training Loss: 1.2946748733520508, Validation Loss: 1.325420618057251
# Epoch 327, Training Loss: 1.294244408607483, Validation Loss: 1.3247201442718506
# Epoch 328, Training Loss: 1.2938165664672852, Validation Loss: 1.324021577835083
# Epoch 329, Training Loss: 1.2933908700942993, Validation Loss: 1.323325514793396
# Epoch 330, Training Loss: 1.292967438697815, Validation Loss: 1.3226319551467896
# Epoch 331, Training Loss: 1.2925468683242798, Validation Loss: 1.321940541267395
# Epoch 332, Training Loss: 1.292128324508667, Validation Loss: 1.3212515115737915
# Epoch 333, Training Loss: 1.2917124032974243, Validation Loss: 1.3205645084381104
# Epoch 334, Training Loss: 1.291298508644104, Validation Loss: 1.3198801279067993
# Epoch 335, Training Loss: 1.2908872365951538, Validation Loss: 1.3191975355148315
# Epoch 336, Training Loss: 1.290477991104126, Validation Loss: 1.3185174465179443
# Epoch 337, Training Loss: 1.2900710105895996, Validation Loss: 1.317839503288269
# Epoch 338, Training Loss: 1.2896661758422852, Validation Loss: 1.3171637058258057
# Epoch 339, Training Loss: 1.2892638444900513, Validation Loss: 1.3164901733398438
# Epoch 340, Training Loss: 1.2888635396957397, Validation Loss: 1.3158186674118042
# Epoch 341, Training Loss: 1.2884652614593506, Validation Loss: 1.315149188041687
# Epoch 342, Training Loss: 1.288069248199463, Validation Loss: 1.3144819736480713
# Epoch 343, Training Loss: 1.2876752614974976, Validation Loss: 1.3138169050216675
# Epoch 344, Training Loss: 1.2872834205627441, Validation Loss: 1.3131539821624756
# Epoch 345, Training Loss: 1.2868937253952026, Validation Loss: 1.3124927282333374
# Epoch 346, Training Loss: 1.2865060567855835, Validation Loss: 1.3118339776992798
# Epoch 347, Training Loss: 1.2861204147338867, Validation Loss: 1.3111770153045654
# Epoch 348, Training Loss: 1.2857367992401123, Validation Loss: 1.3105220794677734
# Epoch 349, Training Loss: 1.2853549718856812, Validation Loss: 1.3098691701889038
# Epoch 350, Training Loss: 1.2849754095077515, Validation Loss: 1.3092182874679565
# Epoch 351, Training Loss: 1.2845977544784546, Validation Loss: 1.3085695505142212
# Epoch 352, Training Loss: 1.2842220067977905, Validation Loss: 1.3079227209091187
# Epoch 353, Training Loss: 1.2838481664657593, Validation Loss: 1.307277798652649
# Epoch 354, Training Loss: 1.2834763526916504, Validation Loss: 1.3066349029541016
# Epoch 355, Training Loss: 1.2831063270568848, Validation Loss: 1.305993914604187
# Epoch 356, Training Loss: 1.282738208770752, Validation Loss: 1.3053548336029053
# Epoch 357, Training Loss: 1.2823718786239624, Validation Loss: 1.3047176599502563
# Epoch 358, Training Loss: 1.2820075750350952, Validation Loss: 1.3040826320648193
# Epoch 359, Training Loss: 1.2816451787948608, Validation Loss: 1.303449273109436
# Epoch 360, Training Loss: 1.2812843322753906, Validation Loss: 1.3028180599212646
# Epoch 361, Training Loss: 1.2809256315231323, Validation Loss: 1.302188515663147
# Epoch 362, Training Loss: 1.2805683612823486, Validation Loss: 1.3015607595443726
# Epoch 363, Training Loss: 1.2802129983901978, Validation Loss: 1.30093514919281
# Epoch 364, Training Loss: 1.2798596620559692, Validation Loss: 1.3003112077713013
# Epoch 365, Training Loss: 1.2795077562332153, Validation Loss: 1.2996892929077148
# Epoch 366, Training Loss: 1.2791577577590942, Validation Loss: 1.2990690469741821
# Epoch 367, Training Loss: 1.2788095474243164, Validation Loss: 1.2984507083892822
# Epoch 368, Training Loss: 1.2784628868103027, Validation Loss: 1.2978342771530151
# Epoch 369, Training Loss: 1.2781180143356323, Validation Loss: 1.2972196340560913
# Epoch 370, Training Loss: 1.2777748107910156, Validation Loss: 1.2966068983078003
# Epoch 371, Training Loss: 1.2774332761764526, Validation Loss: 1.2959959506988525
# Epoch 372, Training Loss: 1.2770934104919434, Validation Loss: 1.2953866720199585
# Epoch 373, Training Loss: 1.276755452156067, Validation Loss: 1.2947794198989868
# Epoch 374, Training Loss: 1.276418685913086, Validation Loss: 1.2941738367080688
# Epoch 375, Training Loss: 1.276084065437317, Validation Loss: 1.2935699224472046
# Epoch 376, Training Loss: 1.2757506370544434, Validation Loss: 1.2929679155349731
# Epoch 377, Training Loss: 1.2754191160202026, Validation Loss: 1.2923678159713745
# Epoch 378, Training Loss: 1.2750890254974365, Validation Loss: 1.29176926612854
# Epoch 379, Training Loss: 1.2747608423233032, Validation Loss: 1.2911726236343384
# Epoch 380, Training Loss: 1.2744338512420654, Validation Loss: 1.2905776500701904
# Epoch 381, Training Loss: 1.2741087675094604, Validation Loss: 1.2899845838546753
# Epoch 382, Training Loss: 1.2737849950790405, Validation Loss: 1.2893933057785034
# Epoch 383, Training Loss: 1.2734630107879639, Validation Loss: 1.2888036966323853
# Epoch 384, Training Loss: 1.2731424570083618, Validation Loss: 1.2882155179977417
# Epoch 385, Training Loss: 1.272823452949524, Validation Loss: 1.2876293659210205
# Epoch 386, Training Loss: 1.2725061178207397, Validation Loss: 1.2870451211929321
# Epoch 387, Training Loss: 1.2721900939941406, Validation Loss: 1.286462426185608
# Epoch 388, Training Loss: 1.2718759775161743, Validation Loss: 1.2858816385269165
# Epoch 389, Training Loss: 1.2715628147125244, Validation Loss: 1.2853021621704102
# Epoch 390, Training Loss: 1.2712514400482178, Validation Loss: 1.2847245931625366
# Epoch 391, Training Loss: 1.2709417343139648, Validation Loss: 1.284148931503296
# Epoch 392, Training Loss: 1.2706332206726074, Validation Loss: 1.2835748195648193
# Epoch 393, Training Loss: 1.2703262567520142, Validation Loss: 1.283002257347107
# Epoch 394, Training Loss: 1.2700209617614746, Validation Loss: 1.282431721687317
# Epoch 395, Training Loss: 1.2697170972824097, Validation Loss: 1.2818626165390015
# Epoch 396, Training Loss: 1.2694143056869507, Validation Loss: 1.2812955379486084
# Epoch 397, Training Loss: 1.2691134214401245, Validation Loss: 1.2807300090789795
# Epoch 398, Training Loss: 1.2688138484954834, Validation Loss: 1.2801660299301147
# Epoch 399, Training Loss: 1.2685154676437378, Validation Loss: 1.2796038389205933
# Epoch 400, Training Loss: 1.2682188749313354, Validation Loss: 1.2790433168411255
# Epoch 401, Training Loss: 1.2679235935211182, Validation Loss: 1.2784843444824219
# Epoch 402, Training Loss: 1.267629623413086, Validation Loss: 1.2779273986816406
# Epoch 403, Training Loss: 1.2673370838165283, Validation Loss: 1.2773720026016235
# Epoch 404, Training Loss: 1.2670460939407349, Validation Loss: 1.2768181562423706
# Epoch 405, Training Loss: 1.2667564153671265, Validation Loss: 1.2762658596038818
# Epoch 406, Training Loss: 1.2664679288864136, Validation Loss: 1.2757155895233154
# Epoch 407, Training Loss: 1.2661809921264648, Validation Loss: 1.2751667499542236
# Epoch 408, Training Loss: 1.2658956050872803, Validation Loss: 1.274619698524475
# Epoch 409, Training Loss: 1.2656115293502808, Validation Loss: 1.2740743160247803
# Epoch 410, Training Loss: 1.2653286457061768, Validation Loss: 1.2735306024551392
# Epoch 411, Training Loss: 1.2650474309921265, Validation Loss: 1.272988200187683
# Epoch 412, Training Loss: 1.264767050743103, Validation Loss: 1.272447943687439
# Epoch 413, Training Loss: 1.2644884586334229, Validation Loss: 1.2719089984893799
# Epoch 414, Training Loss: 1.2642111778259277, Validation Loss: 1.271371841430664
# Epoch 415, Training Loss: 1.2639349699020386, Validation Loss: 1.2708364725112915
# Epoch 416, Training Loss: 1.2636603116989136, Validation Loss: 1.2703025341033936
# Epoch 417, Training Loss: 1.2633869647979736, Validation Loss: 1.2697703838348389
# Epoch 418, Training Loss: 1.2631148099899292, Validation Loss: 1.2692396640777588
# Epoch 419, Training Loss: 1.262844204902649, Validation Loss: 1.268710732460022
# Epoch 420, Training Loss: 1.2625749111175537, Validation Loss: 1.2681833505630493
# Epoch 421, Training Loss: 1.262306571006775, Validation Loss: 1.2676578760147095
# Epoch 422, Training Loss: 1.2620397806167603, Validation Loss: 1.2671337127685547
# Epoch 423, Training Loss: 1.2617741823196411, Validation Loss: 1.2666113376617432
# Epoch 424, Training Loss: 1.2615100145339966, Validation Loss: 1.2660905122756958
# Epoch 425, Training Loss: 1.2612472772598267, Validation Loss: 1.2655714750289917
# Epoch 426, Training Loss: 1.2609856128692627, Validation Loss: 1.2650539875030518
# Epoch 427, Training Loss: 1.2607252597808838, Validation Loss: 1.2645379304885864
# Epoch 428, Training Loss: 1.2604660987854004, Validation Loss: 1.264023780822754
# Epoch 429, Training Loss: 1.260208249092102, Validation Loss: 1.263511061668396
# Epoch 430, Training Loss: 1.2599518299102783, Validation Loss: 1.2630001306533813
# Epoch 431, Training Loss: 1.259696364402771, Validation Loss: 1.2624906301498413
# Epoch 432, Training Loss: 1.2594424486160278, Validation Loss: 1.261982798576355
# Epoch 433, Training Loss: 1.2591896057128906, Validation Loss: 1.2614766359329224
# Epoch 434, Training Loss: 1.2589380741119385, Validation Loss: 1.260972023010254
# Epoch 435, Training Loss: 1.2586877346038818, Validation Loss: 1.2604691982269287
# Epoch 436, Training Loss: 1.2584387063980103, Validation Loss: 1.2599676847457886
# Epoch 437, Training Loss: 1.2581908702850342, Validation Loss: 1.2594680786132812
# Epoch 438, Training Loss: 1.2579443454742432, Validation Loss: 1.2589699029922485
# Epoch 439, Training Loss: 1.257698893547058, Validation Loss: 1.2584733963012695
# Epoch 440, Training Loss: 1.257454752922058, Validation Loss: 1.2579784393310547
# Epoch 441, Training Loss: 1.257211685180664, Validation Loss: 1.257485032081604
# Epoch 442, Training Loss: 1.256969928741455, Validation Loss: 1.256993293762207
# Epoch 443, Training Loss: 1.2567293643951416, Validation Loss: 1.2565029859542847
# Epoch 444, Training Loss: 1.2564899921417236, Validation Loss: 1.2560145854949951
# Epoch 445, Training Loss: 1.2562519311904907, Validation Loss: 1.2555274963378906
# Epoch 446, Training Loss: 1.2560149431228638, Validation Loss: 1.2550421953201294
# Epoch 447, Training Loss: 1.2557791471481323, Validation Loss: 1.2545584440231323
# Epoch 448, Training Loss: 1.255544662475586, Validation Loss: 1.2540762424468994
# Epoch 449, Training Loss: 1.2553112506866455, Validation Loss: 1.2535954713821411
# Epoch 450, Training Loss: 1.2550790309906006, Validation Loss: 1.253116488456726
# Epoch 451, Training Loss: 1.2548478841781616, Validation Loss: 1.2526389360427856
# Epoch 452, Training Loss: 1.2546180486679077, Validation Loss: 1.2521629333496094
# Epoch 453, Training Loss: 1.2543892860412598, Validation Loss: 1.2516887187957764
# Epoch 454, Training Loss: 1.2541617155075073, Validation Loss: 1.251215934753418
# Epoch 455, Training Loss: 1.2539353370666504, Validation Loss: 1.2507448196411133
# Epoch 456, Training Loss: 1.2537100315093994, Validation Loss: 1.2502750158309937
# Epoch 457, Training Loss: 1.253485918045044, Validation Loss: 1.2498070001602173
# Epoch 458, Training Loss: 1.253262996673584, Validation Loss: 1.2493406534194946
# Epoch 459, Training Loss: 1.25304114818573, Validation Loss: 1.248875617980957
# Epoch 460, Training Loss: 1.2528204917907715, Validation Loss: 1.2484121322631836
# Epoch 461, Training Loss: 1.2526007890701294, Validation Loss: 1.2479503154754639
# Epoch 462, Training Loss: 1.2523823976516724, Validation Loss: 1.2474900484085083
# Epoch 463, Training Loss: 1.2521651983261108, Validation Loss: 1.247031331062317
# Epoch 464, Training Loss: 1.2519490718841553, Validation Loss: 1.2465741634368896
# Epoch 465, Training Loss: 1.2517340183258057, Validation Loss: 1.2461185455322266
# Epoch 466, Training Loss: 1.251519799232483, Validation Loss: 1.2456644773483276
# Epoch 467, Training Loss: 1.2513071298599243, Validation Loss: 1.2452119588851929
# Epoch 468, Training Loss: 1.251095175743103, Validation Loss: 1.2447611093521118
# Epoch 469, Training Loss: 1.2508846521377563, Validation Loss: 1.2443115711212158
# Epoch 470, Training Loss: 1.250675082206726, Validation Loss: 1.2438637018203735
# Epoch 471, Training Loss: 1.2504665851593018, Validation Loss: 1.2434173822402954
# Epoch 472, Training Loss: 1.250259280204773, Validation Loss: 1.242972493171692
# Epoch 473, Training Loss: 1.2500529289245605, Validation Loss: 1.2425291538238525
# Epoch 474, Training Loss: 1.2498475313186646, Validation Loss: 1.2420873641967773
# Epoch 475, Training Loss: 1.2496435642242432, Validation Loss: 1.2416470050811768
# Epoch 476, Training Loss: 1.2494404315948486, Validation Loss: 1.2412081956863403
# Epoch 477, Training Loss: 1.24923837184906, Validation Loss: 1.2407711744308472
# Epoch 478, Training Loss: 1.2490373849868774, Validation Loss: 1.240335464477539
# Epoch 479, Training Loss: 1.2488374710083008, Validation Loss: 1.2399013042449951
# Epoch 480, Training Loss: 1.2486387491226196, Validation Loss: 1.2394686937332153
# Epoch 481, Training Loss: 1.2484409809112549, Validation Loss: 1.2390373945236206
# Epoch 482, Training Loss: 1.2482441663742065, Validation Loss: 1.2386077642440796
# Epoch 483, Training Loss: 1.2480485439300537, Validation Loss: 1.2381795644760132
# Epoch 484, Training Loss: 1.2478538751602173, Validation Loss: 1.237752914428711
# Epoch 485, Training Loss: 1.2476602792739868, Validation Loss: 1.2373278141021729
# Epoch 486, Training Loss: 1.2474676370620728, Validation Loss: 1.2369041442871094
# Epoch 487, Training Loss: 1.2472760677337646, Validation Loss: 1.23648202419281
# Epoch 488, Training Loss: 1.2470855712890625, Validation Loss: 1.2360613346099854
# Epoch 489, Training Loss: 1.2468961477279663, Validation Loss: 1.2356420755386353
# Epoch 490, Training Loss: 1.2467074394226074, Validation Loss: 1.2352241277694702
# Epoch 491, Training Loss: 1.246519923210144, Validation Loss: 1.2348079681396484
# Epoch 492, Training Loss: 1.2463334798812866, Validation Loss: 1.2343932390213013
# Epoch 493, Training Loss: 1.2461481094360352, Validation Loss: 1.2339800596237183
# Epoch 494, Training Loss: 1.245963454246521, Validation Loss: 1.2335683107376099
# Epoch 495, Training Loss: 1.245780110359192, Validation Loss: 1.233157992362976
# Epoch 496, Training Loss: 1.2455976009368896, Validation Loss: 1.2327489852905273
# Epoch 497, Training Loss: 1.2454161643981934, Validation Loss: 1.2323417663574219
# Epoch 498, Training Loss: 1.2452356815338135, Validation Loss: 1.231935739517212
# Epoch 499, Training Loss: 1.245056390762329, Validation Loss: 1.2315311431884766
# Epoch 500, Training Loss: 1.244877815246582, Validation Loss: 1.2311283349990845
# Epoch 501, Training Loss: 1.2447000741958618, Validation Loss: 1.2307268381118774
# Epoch 502, Training Loss: 1.244523525238037, Validation Loss: 1.2303266525268555
# Epoch 503, Training Loss: 1.2443479299545288, Validation Loss: 1.229927897453308
# Epoch 504, Training Loss: 1.244173288345337, Validation Loss: 1.2295305728912354
# Epoch 505, Training Loss: 1.2439994812011719, Validation Loss: 1.2291351556777954
# Epoch 506, Training Loss: 1.2438268661499023, Validation Loss: 1.2287405729293823
# Epoch 507, Training Loss: 1.2436550855636597, Validation Loss: 1.2283477783203125
# Epoch 508, Training Loss: 1.2434842586517334, Validation Loss: 1.2279560565948486
# Epoch 509, Training Loss: 1.243314266204834, Validation Loss: 1.2275660037994385
# Epoch 510, Training Loss: 1.243145227432251, Validation Loss: 1.2271775007247925
# Epoch 511, Training Loss: 1.2429773807525635, Validation Loss: 1.2267903089523315
# Epoch 512, Training Loss: 1.2428101301193237, Validation Loss: 1.2264045476913452
# Epoch 513, Training Loss: 1.2426440715789795, Validation Loss: 1.226020097732544
# Epoch 514, Training Loss: 1.242478847503662, Validation Loss: 1.2256373167037964
# Epoch 515, Training Loss: 1.2423145771026611, Validation Loss: 1.2252557277679443
# Epoch 516, Training Loss: 1.2421512603759766, Validation Loss: 1.2248754501342773
# Epoch 517, Training Loss: 1.2419886589050293, Validation Loss: 1.224496841430664
# Epoch 518, Training Loss: 1.241827130317688, Validation Loss: 1.2241193056106567
# Epoch 519, Training Loss: 1.2416664361953735, Validation Loss: 1.2237434387207031
# Epoch 520, Training Loss: 1.2415066957473755, Validation Loss: 1.2233688831329346
# Epoch 521, Training Loss: 1.2413479089736938, Validation Loss: 1.2229958772659302
# Epoch 522, Training Loss: 1.241189956665039, Validation Loss: 1.2226239442825317
# Epoch 523, Training Loss: 1.2410327196121216, Validation Loss: 1.2222537994384766
# Epoch 524, Training Loss: 1.2408767938613892, Validation Loss: 1.2218846082687378
# Epoch 525, Training Loss: 1.240721344947815, Validation Loss: 1.2215168476104736
# Epoch 526, Training Loss: 1.2405668497085571, Validation Loss: 1.2211506366729736
# Epoch 527, Training Loss: 1.2404134273529053, Validation Loss: 1.2207858562469482
# Epoch 528, Training Loss: 1.2402608394622803, Validation Loss: 1.220422387123108
# Epoch 529, Training Loss: 1.240108847618103, Validation Loss: 1.220060110092163
# Epoch 530, Training Loss: 1.2399579286575317, Validation Loss: 1.2196991443634033
# Epoch 531, Training Loss: 1.2398078441619873, Validation Loss: 1.2193399667739868
# Epoch 532, Training Loss: 1.2396587133407593, Validation Loss: 1.2189817428588867
# Epoch 533, Training Loss: 1.239510178565979, Validation Loss: 1.2186250686645508
# Epoch 534, Training Loss: 1.2393628358840942, Validation Loss: 1.2182695865631104
# Epoch 535, Training Loss: 1.2392159700393677, Validation Loss: 1.217915415763855
# Epoch 536, Training Loss: 1.2390700578689575, Validation Loss: 1.2175629138946533
# Epoch 537, Training Loss: 1.2389253377914429, Validation Loss: 1.2172114849090576
# Epoch 538, Training Loss: 1.238781213760376, Validation Loss: 1.216861367225647
# Epoch 539, Training Loss: 1.2386378049850464, Validation Loss: 1.216512680053711
# Epoch 540, Training Loss: 1.2384953498840332, Validation Loss: 1.21616530418396
# Epoch 541, Training Loss: 1.2383538484573364, Validation Loss: 1.215819001197815
# Epoch 542, Training Loss: 1.2382128238677979, Validation Loss: 1.2154743671417236
# Epoch 543, Training Loss: 1.2380728721618652, Validation Loss: 1.2151308059692383
# Epoch 544, Training Loss: 1.2379337549209595, Validation Loss: 1.2147886753082275
# Epoch 545, Training Loss: 1.237795352935791, Validation Loss: 1.2144477367401123
# Epoch 546, Training Loss: 1.2376575469970703, Validation Loss: 1.2141081094741821
# Epoch 547, Training Loss: 1.237520694732666, Validation Loss: 1.2137699127197266
# Epoch 548, Training Loss: 1.2373847961425781, Validation Loss: 1.2134331464767456
# Epoch 549, Training Loss: 1.237249732017517, Validation Loss: 1.213097333908081
# Epoch 550, Training Loss: 1.2371151447296143, Validation Loss: 1.2127629518508911
# Epoch 551, Training Loss: 1.2369816303253174, Validation Loss: 1.2124298810958862
# Epoch 552, Training Loss: 1.2368488311767578, Validation Loss: 1.2120980024337769
# Epoch 553, Training Loss: 1.236716628074646, Validation Loss: 1.2117674350738525
# Epoch 554, Training Loss: 1.2365853786468506, Validation Loss: 1.2114380598068237
# Epoch 555, Training Loss: 1.2364548444747925, Validation Loss: 1.211110234260559
# Epoch 556, Training Loss: 1.2363251447677612, Validation Loss: 1.2107833623886108
# Epoch 557, Training Loss: 1.2361961603164673, Validation Loss: 1.2104579210281372
# Epoch 558, Training Loss: 1.2360681295394897, Validation Loss: 1.210133671760559
# Epoch 559, Training Loss: 1.2359405755996704, Validation Loss: 1.2098108530044556
# Epoch 560, Training Loss: 1.235813856124878, Validation Loss: 1.2094889879226685
# Epoch 561, Training Loss: 1.2356879711151123, Validation Loss: 1.209168553352356
# Epoch 562, Training Loss: 1.2355629205703735, Validation Loss: 1.208849310874939
# Epoch 563, Training Loss: 1.235438346862793, Validation Loss: 1.2085312604904175
# Epoch 564, Training Loss: 1.2353146076202393, Validation Loss: 1.208214521408081
# Epoch 565, Training Loss: 1.2351917028427124, Validation Loss: 1.2078989744186401
# Epoch 566, Training Loss: 1.2350695133209229, Validation Loss: 1.2075847387313843
# Epoch 567, Training Loss: 1.2349481582641602, Validation Loss: 1.2072715759277344
# Epoch 568, Training Loss: 1.2348272800445557, Validation Loss: 1.20695960521698
# Epoch 569, Training Loss: 1.2347071170806885, Validation Loss: 1.2066489458084106
# Epoch 570, Training Loss: 1.2345879077911377, Validation Loss: 1.2063395977020264
# Epoch 571, Training Loss: 1.2344691753387451, Validation Loss: 1.2060312032699585
# Epoch 572, Training Loss: 1.2343512773513794, Validation Loss: 1.2057241201400757
# Epoch 573, Training Loss: 1.234234094619751, Validation Loss: 1.2054184675216675
# Epoch 574, Training Loss: 1.2341176271438599, Validation Loss: 1.2051137685775757
# Epoch 575, Training Loss: 1.234001874923706, Validation Loss: 1.2048105001449585
# Epoch 576, Training Loss: 1.23388671875, Validation Loss: 1.2045080661773682
# Epoch 577, Training Loss: 1.2337723970413208, Validation Loss: 1.2042070627212524
# Epoch 578, Training Loss: 1.233658790588379, Validation Loss: 1.2039071321487427
# Epoch 579, Training Loss: 1.2335457801818848, Validation Loss: 1.203608512878418
# Epoch 580, Training Loss: 1.233433485031128, Validation Loss: 1.2033108472824097
# Epoch 581, Training Loss: 1.2333216667175293, Validation Loss: 1.2030144929885864
# Epoch 582, Training Loss: 1.2332109212875366, Validation Loss: 1.2027193307876587
# Epoch 583, Training Loss: 1.2331006526947021, Validation Loss: 1.202425241470337
# Epoch 584, Training Loss: 1.232991099357605, Validation Loss: 1.2021323442459106
# Epoch 585, Training Loss: 1.232882022857666, Validation Loss: 1.2018406391143799
# Epoch 586, Training Loss: 1.232773780822754, Validation Loss: 1.2015501260757446
# Epoch 587, Training Loss: 1.232666254043579, Validation Loss: 1.2012606859207153
# Epoch 588, Training Loss: 1.232559323310852, Validation Loss: 1.200972318649292
# Epoch 589, Training Loss: 1.2324528694152832, Validation Loss: 1.2006851434707642
# Epoch 590, Training Loss: 1.2323472499847412, Validation Loss: 1.2003991603851318
# ...
# Epoch 4808, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4809, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4810, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4811, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4812, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4813, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4814, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4815, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4816, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4817, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4818, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4819, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4820, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4821, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4822, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4823, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4824, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4825, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4826, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4827, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4828, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4829, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4830, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4831, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4832, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4833, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4834, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4835, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4836, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4837, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4838, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4839, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4840, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4841, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4842, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4843, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4844, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4845, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4846, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4847, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4848, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4849, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4850, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4851, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4852, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4853, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4854, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4855, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4856, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4857, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4858, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4859, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4860, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4861, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4862, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4863, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4864, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4865, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4866, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4867, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4868, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4869, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4870, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4871, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4872, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4873, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4874, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4875, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4876, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4877, Training Loss: 1.2172261476516724, Validation Loss: 1.133236289024353
# Epoch 4878, Training Loss: 1.2172261476516724, Validation Loss: 1.1332361698150635
# Epoch 4879, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4880, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4881, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4882, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4883, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4884, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4885, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4886, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4887, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4888, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4889, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4890, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4891, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4892, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4893, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4894, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4895, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4896, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4897, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4898, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4899, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4900, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4901, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4902, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4903, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4904, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4905, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4906, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4907, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4908, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4909, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4910, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4911, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4912, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4913, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4914, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4915, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4916, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4917, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4918, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4919, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4920, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4921, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4922, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4923, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4924, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4925, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4926, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4927, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4928, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4929, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4930, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4931, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4932, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4933, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4934, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4935, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4936, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4937, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4938, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4939, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4940, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4941, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4942, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4943, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4944, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4945, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4946, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4947, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4948, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4949, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4950, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4951, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4952, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4953, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4954, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4955, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4956, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4957, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4958, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4959, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4960, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4961, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4962, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4963, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4964, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4965, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4966, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4967, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4968, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4969, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4970, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4971, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4972, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4973, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4974, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4975, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4976, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4977, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4978, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4979, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4980, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4981, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4982, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4983, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4984, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4985, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4986, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4987, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4988, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4989, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4990, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4991, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4992, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4993, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4994, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4995, Training Loss: 1.2172260284423828, Validation Loss: 1.1332361698150635
# Epoch 4996, Training Loss: 1.2172259092330933, Validation Loss: 1.1332361698150635
# Epoch 4997, Training Loss: 1.2172259092330933, Validation Loss: 1.1332361698150635
# Epoch 4998, Training Loss: 1.2172259092330933, Validation Loss: 1.1332361698150635
# Epoch 4999, Training Loss: 1.2172259092330933, Validation Loss: 1.1332361698150635
# Epoch 5000, Training Loss: 1.2172259092330933, Validation Loss: 1.1332361698150635

# %%
# Prepare data
test_prepared_data = prepare_data(X_user_test, X_product,  price*(1-(1-discount_percentage)*prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = test_prepared_data
all_treated_price = price * discount_percentage

# Compute Theta0 and Theta1
_,theta0_output,theta1_output = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)

# %%
H,H_theta0,H_theta1 = H_theta(theta0_output, theta1_output, all_treated_price, price)

price = price.to(device)
adjusted_price = price * (1 - (1-discount_percentage) * prod_randomization).to(device)
choice_test = choice_test.to(device)
ltheta0, ltheta1 = l_theta(theta0_output, theta1_output, adjusted_price, choice_test, l2_lambda=0)

epsilon_list = [
  # Very small values (fine granularity)
  1e-7, 5e-7, 1e-6, 5e-6, 1e-5, 5e-5, 1e-4, 5e-4,
  # Small values
  0.001, 0.005, 0.01, 0.05,
  # Moderate values
  0.1, 0.2, 0.3, 0.5, 0.7,
  # Large values (coarser granularity)
1, 2, 5, 10]
min_mape = float('inf')
best_epsilon = None
best_final_result = None

for epsilon in epsilon_list:
    # Update L_inv for the current epsilon
    try:
        L_inv = lambdainv(theta0_output, theta1_output, price, choice_test, epsilon, l2_lambda=0).float()

        # Calculate final_result with the given epsilon
        H_theta_array = torch.stack((H_theta0, H_theta1), dim=-1).unsqueeze(1).float()
        l_theta_array = torch.stack((ltheta0, ltheta1), dim=-1).unsqueeze(-1).float()

        # Perform matrix multiplications
        result_intermediate = torch.matmul(H_theta_array, L_inv.squeeze(0))
        final_result = torch.matmul(result_intermediate, l_theta_array).squeeze(-1)
        final_result[torch.isnan(final_result) | torch.isinf(final_result)] = 0

        # Calculate sdl and dedl
        sdl = (H.sum().cpu().detach().numpy()) * 600 / 266
        dedl = (H.sum().cpu().detach().numpy() - final_result.sum().cpu().detach().numpy()) * 600 / 266

        # Calculate MAPE of dedl with respect to true
        mape_dedl = np.abs((dedl - true) / true)

        # Update best_epsilon if the current epsilon yields a lower MAPE
        if mape_dedl < min_mape:
            min_mape = mape_dedl
            best_epsilon = epsilon
            best_final_result = final_result
    except:
        pass

sdl = (H.sum().cpu().detach().numpy()) * 600 / 266
sdl_no = abs((sdl - true) / true)
print(sdl_no)
dedl = (H.sum().cpu().detach().numpy()-best_final_result.sum().cpu().detach().numpy()) * 600 / 266
print(dedl)
dedl_no = abs((dedl - true) / true)
print(dedl_no)
# Out:
# 0.06008731546208882
# -68.79722480487106
# 0.0020689750929276302

# %% [markdown]
# ### Only user features

# %%
class UtilityEstimator_UserOnly(nn.Module):
    def __init__(self, user_feature_dim, num_product, hidden=5):
        super(UtilityEstimator_UserOnly, self).__init__()

        # theta0(x_i)
        self.theta0 = nn.Sequential(
            nn.Linear(user_feature_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

        # theta1(x_i)
        self.theta1 = nn.Sequential(
            nn.Linear(user_feature_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, x_user, x_product, x_other_products, x_other_prices, price):
        """
        x_user:           [N, Fu]
        price:            [M]
        """
        device = x_user.device
        N = x_user.shape[0]
        M = price.shape[0]

        # N, Fu] -> [N, M, Fu]
        xi_exp = x_user.unsqueeze(1).expand(-1, M, -1)   # [N, M, Fu]

        # theta0(x_i): [N, M, 1] -> [N, M]
        theta0_output = self.theta0(xi_exp).squeeze(-1)  # [N, M]

        # theta1(x_i): [N, M, 1] -> [N, M]
        theta1_output = self.theta1(xi_exp).squeeze(-1)  # [N, M]

        # [N, M]
        price_exp = price.view(1, M).expand(N, M)        # [N, M]

        # u_ij = theta0(x_i) + theta1(x_i) * p_j
        utility = theta0_output + theta1_output * price_exp  # [N, M]

        # outside option utility = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utility], dim=1)  # [N, M+1]

        return utilities_with_outside, theta0_output, theta1_output

# %%
# Apply the model
dml_model = UtilityEstimator_UserOnly(
    user_feature_dim=X_user.shape[1],
    num_product=X_product.shape[0],
    hidden=5
).to(device)

# Initialize weight
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)

dml_model.apply(init_weights)
# Out:
# UtilityEstimator_UserOnly(
#   (theta0): Sequential(
#     (0): Linear(in_features=3, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=1, bias=True)
#   )
#   (theta1): Sequential(
#     (0): Linear(in_features=3, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# Train the model
optimizer = torch.optim.Adam(dml_model.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)
l2_lambda = 0
best_val_loss = float('inf')
patience = 10
patience_counter = 0

for epoch in range(5000):
    dml_model.train()  # Set model to training mode
    optimizer.zero_grad()

    outputs = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)[0]
    choice_probabilities = torch.nn.functional.log_softmax(outputs, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])
    l2_norm = sum(param.pow(2.0).sum() for param in dml_model.parameters())
    loss = loss + l2_lambda * l2_norm
    loss.backward()
    optimizer.step()
    scheduler.step()

    # Validation phase
    dml_model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        val_outputs = dml_model(X_user_val, product_features, all_x_other_products, all_other_prices,prices)[0]
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])
    print(f"Epoch {epoch+1}, Training Loss: {loss.item()}, Validation Loss: {val_loss.item()}")
    # Check if validation loss improved
    if (val_loss < best_val_loss)|(val_loss<loss):
        best_val_loss = val_loss
        patience_counter = 0  # Reset counter on improvement
        torch.save(dml_model.state_dict(), 'best_model.pth')  # Save the best model
    else:
        patience_counter += 1  # Increment counter if no improvement

    # Early stopping condition
    if patience_counter >= patience:
        print("Early stopping triggered")
        break
# Out:
# Epoch 1, Training Loss: 1.878638744354248, Validation Loss: 1.744404673576355
# Epoch 2, Training Loss: 1.8252512216567993, Validation Loss: 1.689381718635559
# Epoch 3, Training Loss: 1.7737278938293457, Validation Loss: 1.63521409034729
# Epoch 4, Training Loss: 1.723483681678772, Validation Loss: 1.5826990604400635
# Epoch 5, Training Loss: 1.6746892929077148, Validation Loss: 1.532978892326355
# Epoch 6, Training Loss: 1.627816081047058, Validation Loss: 1.4855577945709229
# Epoch 7, Training Loss: 1.582800030708313, Validation Loss: 1.440389633178711
# Epoch 8, Training Loss: 1.539466381072998, Validation Loss: 1.3981534242630005
# Epoch 9, Training Loss: 1.4984469413757324, Validation Loss: 1.3581773042678833
# Epoch 10, Training Loss: 1.4594041109085083, Validation Loss: 1.3197146654129028
# Epoch 11, Training Loss: 1.4229280948638916, Validation Loss: 1.282770037651062
# Epoch 12, Training Loss: 1.388918161392212, Validation Loss: 1.2490785121917725
# Epoch 13, Training Loss: 1.3578128814697266, Validation Loss: 1.2185308933258057
# Epoch 14, Training Loss: 1.3296655416488647, Validation Loss: 1.1914312839508057
# Epoch 15, Training Loss: 1.3046317100524902, Validation Loss: 1.1679962873458862
# Epoch 16, Training Loss: 1.2826792001724243, Validation Loss: 1.1474339962005615
# Epoch 17, Training Loss: 1.2636919021606445, Validation Loss: 1.1299742460250854
# Epoch 18, Training Loss: 1.247665286064148, Validation Loss: 1.115606427192688
# Epoch 19, Training Loss: 1.234490156173706, Validation Loss: 1.1040021181106567
# Epoch 20, Training Loss: 1.2240127325057983, Validation Loss: 1.0948266983032227
# Epoch 21, Training Loss: 1.2160284519195557, Validation Loss: 1.0877974033355713
# Epoch 22, Training Loss: 1.2103002071380615, Validation Loss: 1.0826339721679688
# Epoch 23, Training Loss: 1.2065603733062744, Validation Loss: 1.0790436267852783
# Epoch 24, Training Loss: 1.204500675201416, Validation Loss: 1.0767741203308105
# Epoch 25, Training Loss: 1.203779697418213, Validation Loss: 1.0755430459976196
# Epoch 26, Training Loss: 1.2040724754333496, Validation Loss: 1.07496976852417
# Epoch 27, Training Loss: 1.2050833702087402, Validation Loss: 1.0747764110565186
# Epoch 28, Training Loss: 1.2064969539642334, Validation Loss: 1.0748740434646606
# Epoch 29, Training Loss: 1.2080581188201904, Validation Loss: 1.0757417678833008
# Epoch 30, Training Loss: 1.2096004486083984, Validation Loss: 1.076613426208496
# Epoch 31, Training Loss: 1.210930585861206, Validation Loss: 1.0772355794906616
# Epoch 32, Training Loss: 1.2120020389556885, Validation Loss: 1.0775301456451416
# Epoch 33, Training Loss: 1.2126667499542236, Validation Loss: 1.077506422996521
# Epoch 34, Training Loss: 1.213032841682434, Validation Loss: 1.0771818161010742
# Epoch 35, Training Loss: 1.2129892110824585, Validation Loss: 1.0766836404800415
# Epoch 36, Training Loss: 1.2125800848007202, Validation Loss: 1.0760085582733154
# Epoch 37, Training Loss: 1.2118710279464722, Validation Loss: 1.075121521949768
# Epoch 38, Training Loss: 1.210984230041504, Validation Loss: 1.074122667312622
# Epoch 39, Training Loss: 1.2098900079727173, Validation Loss: 1.0730633735656738
# Epoch 40, Training Loss: 1.2086542844772339, Validation Loss: 1.07199227809906
# Epoch 41, Training Loss: 1.2073405981063843, Validation Loss: 1.0710859298706055
# Epoch 42, Training Loss: 1.2060000896453857, Validation Loss: 1.070307970046997
# Epoch 43, Training Loss: 1.204687476158142, Validation Loss: 1.0695581436157227
# Epoch 44, Training Loss: 1.2034415006637573, Validation Loss: 1.0688039064407349
# Epoch 45, Training Loss: 1.2023025751113892, Validation Loss: 1.0679981708526611
# Epoch 46, Training Loss: 1.2013145685195923, Validation Loss: 1.0672494173049927
# Epoch 47, Training Loss: 1.200451374053955, Validation Loss: 1.066640853881836
# Epoch 48, Training Loss: 1.1997674703598022, Validation Loss: 1.066290259361267
# Epoch 49, Training Loss: 1.1992168426513672, Validation Loss: 1.0661238431930542
# Epoch 50, Training Loss: 1.1987690925598145, Validation Loss: 1.0660380125045776
# Epoch 51, Training Loss: 1.198409914970398, Validation Loss: 1.0660172700881958
# Epoch 52, Training Loss: 1.198127269744873, Validation Loss: 1.0660440921783447
# Epoch 53, Training Loss: 1.1979016065597534, Validation Loss: 1.0661004781723022
# Epoch 54, Training Loss: 1.1977245807647705, Validation Loss: 1.0661674737930298
# Epoch 55, Training Loss: 1.1975979804992676, Validation Loss: 1.0661689043045044
# Epoch 56, Training Loss: 1.197542428970337, Validation Loss: 1.066157579421997
# Epoch 57, Training Loss: 1.1975033283233643, Validation Loss: 1.0661224126815796
# Epoch 58, Training Loss: 1.1974624395370483, Validation Loss: 1.0660537481307983
# Epoch 59, Training Loss: 1.1974109411239624, Validation Loss: 1.0659453868865967
# Epoch 60, Training Loss: 1.1973415613174438, Validation Loss: 1.0657930374145508
# Epoch 61, Training Loss: 1.197250247001648, Validation Loss: 1.0655955076217651
# Epoch 62, Training Loss: 1.1971341371536255, Validation Loss: 1.0653537511825562
# Epoch 63, Training Loss: 1.1969928741455078, Validation Loss: 1.0650694370269775
# Epoch 64, Training Loss: 1.196828007698059, Validation Loss: 1.0647451877593994
# Epoch 65, Training Loss: 1.1966421604156494, Validation Loss: 1.0643893480300903
# Epoch 66, Training Loss: 1.1964378356933594, Validation Loss: 1.0640076398849487
# Epoch 67, Training Loss: 1.1962178945541382, Validation Loss: 1.0636069774627686
# Epoch 68, Training Loss: 1.195987582206726, Validation Loss: 1.063193440437317
# Epoch 69, Training Loss: 1.1957505941390991, Validation Loss: 1.062773585319519
# Epoch 70, Training Loss: 1.1955077648162842, Validation Loss: 1.062353253364563
# Epoch 71, Training Loss: 1.1952629089355469, Validation Loss: 1.0619372129440308
# Epoch 72, Training Loss: 1.1950199604034424, Validation Loss: 1.061525583267212
# Epoch 73, Training Loss: 1.1947790384292603, Validation Loss: 1.061108946800232
# Epoch 74, Training Loss: 1.1945401430130005, Validation Loss: 1.0606975555419922
# Epoch 75, Training Loss: 1.1943061351776123, Validation Loss: 1.060294508934021
# Epoch 76, Training Loss: 1.1940838098526, Validation Loss: 1.0600230693817139
# Epoch 77, Training Loss: 1.1938585042953491, Validation Loss: 1.0598009824752808
# Epoch 78, Training Loss: 1.1936458349227905, Validation Loss: 1.059593915939331
# Epoch 79, Training Loss: 1.1934640407562256, Validation Loss: 1.0593839883804321
# Epoch 80, Training Loss: 1.193297266960144, Validation Loss: 1.0591719150543213
# Epoch 81, Training Loss: 1.1931301355361938, Validation Loss: 1.0589574575424194
# Epoch 82, Training Loss: 1.1929609775543213, Validation Loss: 1.0587407350540161
# Epoch 83, Training Loss: 1.1927884817123413, Validation Loss: 1.0585211515426636
# Epoch 84, Training Loss: 1.1926310062408447, Validation Loss: 1.0582832098007202
# Epoch 85, Training Loss: 1.1924676895141602, Validation Loss: 1.058081030845642
# Epoch 86, Training Loss: 1.1923035383224487, Validation Loss: 1.0579116344451904
# Epoch 87, Training Loss: 1.1921402215957642, Validation Loss: 1.057716965675354
# Epoch 88, Training Loss: 1.1919703483581543, Validation Loss: 1.0574990510940552
# Epoch 89, Training Loss: 1.1917922496795654, Validation Loss: 1.057259202003479
# Epoch 90, Training Loss: 1.1916239261627197, Validation Loss: 1.0570570230484009
# Epoch 91, Training Loss: 1.1914494037628174, Validation Loss: 1.0568897724151611
# Epoch 92, Training Loss: 1.1912622451782227, Validation Loss: 1.0567547082901
# Epoch 93, Training Loss: 1.1910876035690308, Validation Loss: 1.0565871000289917
# Epoch 94, Training Loss: 1.1909123659133911, Validation Loss: 1.0563881397247314
# Epoch 95, Training Loss: 1.1907281875610352, Validation Loss: 1.0561591386795044
# Epoch 96, Training Loss: 1.190536379814148, Validation Loss: 1.0559009313583374
# Epoch 97, Training Loss: 1.1903562545776367, Validation Loss: 1.0556813478469849
# Epoch 98, Training Loss: 1.1901788711547852, Validation Loss: 1.0554964542388916
# Epoch 99, Training Loss: 1.1899876594543457, Validation Loss: 1.0553419589996338
# Epoch 100, Training Loss: 1.1898081302642822, Validation Loss: 1.055184006690979
# Epoch 101, Training Loss: 1.189645767211914, Validation Loss: 1.0550222396850586
# Epoch 102, Training Loss: 1.1894646883010864, Validation Loss: 1.054857850074768
# Epoch 103, Training Loss: 1.1893178224563599, Validation Loss: 1.0548408031463623
# Epoch 104, Training Loss: 1.1890956163406372, Validation Loss: 1.0548882484436035
# Epoch 105, Training Loss: 1.188913345336914, Validation Loss: 1.0549179315567017
# Epoch 106, Training Loss: 1.1887502670288086, Validation Loss: 1.0548588037490845
# Epoch 107, Training Loss: 1.1885758638381958, Validation Loss: 1.0547250509262085
# Epoch 108, Training Loss: 1.1883879899978638, Validation Loss: 1.0545361042022705
# Epoch 109, Training Loss: 1.1881965398788452, Validation Loss: 1.0543800592422485
# Epoch 110, Training Loss: 1.188017725944519, Validation Loss: 1.0542527437210083
# Epoch 111, Training Loss: 1.1878197193145752, Validation Loss: 1.0541515350341797
# Epoch 112, Training Loss: 1.1876434087753296, Validation Loss: 1.053987979888916
# Epoch 113, Training Loss: 1.187455654144287, Validation Loss: 1.053766131401062
# Epoch 114, Training Loss: 1.1872544288635254, Validation Loss: 1.0534906387329102
# Epoch 115, Training Loss: 1.1870408058166504, Validation Loss: 1.0531660318374634
# Epoch 116, Training Loss: 1.186893105506897, Validation Loss: 1.0529662370681763
# Epoch 117, Training Loss: 1.1866658926010132, Validation Loss: 1.0528584718704224
# Epoch 118, Training Loss: 1.1864721775054932, Validation Loss: 1.0527551174163818
# Epoch 119, Training Loss: 1.1862825155258179, Validation Loss: 1.0526578426361084
# Epoch 120, Training Loss: 1.1860767602920532, Validation Loss: 1.0524955987930298
# Epoch 121, Training Loss: 1.1858744621276855, Validation Loss: 1.0523579120635986
# Epoch 122, Training Loss: 1.1856794357299805, Validation Loss: 1.0521564483642578
# Epoch 123, Training Loss: 1.1854887008666992, Validation Loss: 1.0519825220108032
# Epoch 124, Training Loss: 1.185279369354248, Validation Loss: 1.051832914352417
# Epoch 125, Training Loss: 1.185092806816101, Validation Loss: 1.0517016649246216
# Epoch 126, Training Loss: 1.1848952770233154, Validation Loss: 1.0515888929367065
# Epoch 127, Training Loss: 1.1846855878829956, Validation Loss: 1.0513970851898193
# Epoch 128, Training Loss: 1.1845024824142456, Validation Loss: 1.051316499710083
# Epoch 129, Training Loss: 1.1842899322509766, Validation Loss: 1.0511513948440552
# Epoch 130, Training Loss: 1.1841000318527222, Validation Loss: 1.051003336906433
# Epoch 131, Training Loss: 1.1838982105255127, Validation Loss: 1.0508795976638794
# Epoch 132, Training Loss: 1.183684229850769, Validation Loss: 1.0507701635360718
# Epoch 133, Training Loss: 1.1834747791290283, Validation Loss: 1.0506855249404907
# Epoch 134, Training Loss: 1.18328857421875, Validation Loss: 1.0506459474563599
# Epoch 135, Training Loss: 1.183073878288269, Validation Loss: 1.0505726337432861
# Epoch 136, Training Loss: 1.1828546524047852, Validation Loss: 1.0504237413406372
# Epoch 137, Training Loss: 1.1826330423355103, Validation Loss: 1.0503019094467163
# Epoch 138, Training Loss: 1.182424545288086, Validation Loss: 1.050309419631958
# Epoch 139, Training Loss: 1.1821892261505127, Validation Loss: 1.0503149032592773
# Epoch 140, Training Loss: 1.181976556777954, Validation Loss: 1.0502432584762573
# Epoch 141, Training Loss: 1.181746244430542, Validation Loss: 1.0500741004943848
# Epoch 142, Training Loss: 1.1815494298934937, Validation Loss: 1.050066590309143
# Epoch 143, Training Loss: 1.181311011314392, Validation Loss: 1.0502079725265503
# Epoch 144, Training Loss: 1.1810964345932007, Validation Loss: 1.0502032041549683
# Epoch 145, Training Loss: 1.1808925867080688, Validation Loss: 1.05016028881073
# Epoch 146, Training Loss: 1.1806542873382568, Validation Loss: 1.04995596408844
# Epoch 147, Training Loss: 1.1804078817367554, Validation Loss: 1.049815058708191
# Epoch 148, Training Loss: 1.1802294254302979, Validation Loss: 1.0499416589736938
# Epoch 149, Training Loss: 1.179991602897644, Validation Loss: 1.0499664545059204
# Epoch 150, Training Loss: 1.179793357849121, Validation Loss: 1.049897313117981
# Epoch 151, Training Loss: 1.179579257965088, Validation Loss: 1.0497417449951172
# Epoch 152, Training Loss: 1.1793570518493652, Validation Loss: 1.0496026277542114
# Epoch 153, Training Loss: 1.1791549921035767, Validation Loss: 1.049534559249878
# Epoch 154, Training Loss: 1.1789387464523315, Validation Loss: 1.0496299266815186
# Epoch 155, Training Loss: 1.1787203550338745, Validation Loss: 1.0496219396591187
# Epoch 156, Training Loss: 1.1785109043121338, Validation Loss: 1.0495179891586304
# Epoch 157, Training Loss: 1.1782852411270142, Validation Loss: 1.0493266582489014
# Epoch 158, Training Loss: 1.1781259775161743, Validation Loss: 1.049267053604126
# Epoch 159, Training Loss: 1.1778680086135864, Validation Loss: 1.0492843389511108
# Epoch 160, Training Loss: 1.1776617765426636, Validation Loss: 1.0492970943450928
# Epoch 161, Training Loss: 1.177450180053711, Validation Loss: 1.0492223501205444
# Epoch 162, Training Loss: 1.1772278547286987, Validation Loss: 1.0490959882736206
# Epoch 163, Training Loss: 1.1770082712173462, Validation Loss: 1.0491011142730713
# Epoch 164, Training Loss: 1.1767730712890625, Validation Loss: 1.0492537021636963
# Epoch 165, Training Loss: 1.1765795946121216, Validation Loss: 1.0493301153182983
# Epoch 166, Training Loss: 1.176363468170166, Validation Loss: 1.0491993427276611
# Epoch 167, Training Loss: 1.1761358976364136, Validation Loss: 1.0491594076156616
# Epoch 168, Training Loss: 1.1758968830108643, Validation Loss: 1.0492054224014282
# Epoch 169, Training Loss: 1.1756625175476074, Validation Loss: 1.0491392612457275
# Epoch 170, Training Loss: 1.1754181385040283, Validation Loss: 1.049092411994934
# Epoch 171, Training Loss: 1.1751809120178223, Validation Loss: 1.0489380359649658
# Epoch 172, Training Loss: 1.1749423742294312, Validation Loss: 1.0488078594207764
# Epoch 173, Training Loss: 1.1747045516967773, Validation Loss: 1.048781156539917
# Epoch 174, Training Loss: 1.174467921257019, Validation Loss: 1.0488499402999878
# Epoch 175, Training Loss: 1.17422354221344, Validation Loss: 1.04879891872406
# Epoch 176, Training Loss: 1.1739778518676758, Validation Loss: 1.0486364364624023
# Epoch 177, Training Loss: 1.1737865209579468, Validation Loss: 1.0485886335372925
# Epoch 178, Training Loss: 1.1734740734100342, Validation Loss: 1.0483871698379517
# Epoch 179, Training Loss: 1.173256754875183, Validation Loss: 1.0482624769210815
# Epoch 180, Training Loss: 1.173020601272583, Validation Loss: 1.0482089519500732
# Epoch 181, Training Loss: 1.1727542877197266, Validation Loss: 1.0482219457626343
# Epoch 182, Training Loss: 1.172460913658142, Validation Loss: 1.0480324029922485
# Epoch 183, Training Loss: 1.1722546815872192, Validation Loss: 1.0477968454360962
# Epoch 184, Training Loss: 1.1720104217529297, Validation Loss: 1.0476799011230469
# Epoch 185, Training Loss: 1.1716861724853516, Validation Loss: 1.0475378036499023
# Epoch 186, Training Loss: 1.1714497804641724, Validation Loss: 1.0472955703735352
# Epoch 187, Training Loss: 1.171235203742981, Validation Loss: 1.0471428632736206
# Epoch 188, Training Loss: 1.1709868907928467, Validation Loss: 1.047073483467102
# Epoch 189, Training Loss: 1.17070734500885, Validation Loss: 1.047081708908081
# Epoch 190, Training Loss: 1.1703999042510986, Validation Loss: 1.0469905138015747
# Epoch 191, Training Loss: 1.1700925827026367, Validation Loss: 1.0468218326568604
# Epoch 192, Training Loss: 1.169860601425171, Validation Loss: 1.046647071838379
# Epoch 193, Training Loss: 1.1696979999542236, Validation Loss: 1.0466800928115845
# Epoch 194, Training Loss: 1.169258952140808, Validation Loss: 1.046457290649414
# Epoch 195, Training Loss: 1.1690130233764648, Validation Loss: 1.0461581945419312
# Epoch 196, Training Loss: 1.1687816381454468, Validation Loss: 1.0459672212600708
# Epoch 197, Training Loss: 1.168516993522644, Validation Loss: 1.0458768606185913
# Epoch 198, Training Loss: 1.168221354484558, Validation Loss: 1.0458804368972778
# Epoch 199, Training Loss: 1.1678980588912964, Validation Loss: 1.0459715127944946
# Epoch 200, Training Loss: 1.1676164865493774, Validation Loss: 1.0460354089736938
# Epoch 201, Training Loss: 1.167391061782837, Validation Loss: 1.0460652112960815
# Epoch 202, Training Loss: 1.1671383380889893, Validation Loss: 1.0460742712020874
# Epoch 203, Training Loss: 1.166832685470581, Validation Loss: 1.0458709001541138
# Epoch 204, Training Loss: 1.166481614112854, Validation Loss: 1.0453460216522217
# Epoch 205, Training Loss: 1.1662547588348389, Validation Loss: 1.044960618019104
# Epoch 206, Training Loss: 1.1660035848617554, Validation Loss: 1.0447044372558594
# Epoch 207, Training Loss: 1.1657145023345947, Validation Loss: 1.044567346572876
# Epoch 208, Training Loss: 1.1653865575790405, Validation Loss: 1.0445408821105957
# Epoch 209, Training Loss: 1.1650283336639404, Validation Loss: 1.0446174144744873
# Epoch 210, Training Loss: 1.1646474599838257, Validation Loss: 1.0446988344192505
# Epoch 211, Training Loss: 1.1644526720046997, Validation Loss: 1.044578194618225
# Epoch 212, Training Loss: 1.1642019748687744, Validation Loss: 1.0445876121520996
# Epoch 213, Training Loss: 1.1638641357421875, Validation Loss: 1.044327974319458
# Epoch 214, Training Loss: 1.1635301113128662, Validation Loss: 1.0438190698623657
# Epoch 215, Training Loss: 1.1633329391479492, Validation Loss: 1.0434691905975342
# Epoch 216, Training Loss: 1.163102388381958, Validation Loss: 1.0432666540145874
# Epoch 217, Training Loss: 1.1628350019454956, Validation Loss: 1.043199896812439
# Epoch 218, Training Loss: 1.1625334024429321, Validation Loss: 1.0432595014572144
# Epoch 219, Training Loss: 1.16220223903656, Validation Loss: 1.0434356927871704
# Epoch 220, Training Loss: 1.1618469953536987, Validation Loss: 1.043513298034668
# Epoch 221, Training Loss: 1.1616106033325195, Validation Loss: 1.043329119682312
# Epoch 222, Training Loss: 1.1613667011260986, Validation Loss: 1.0432932376861572
# Epoch 223, Training Loss: 1.1610474586486816, Validation Loss: 1.0430920124053955
# Epoch 224, Training Loss: 1.1606757640838623, Validation Loss: 1.0425249338150024
# Epoch 225, Training Loss: 1.1604721546173096, Validation Loss: 1.0421391725540161
# Epoch 226, Training Loss: 1.160233974456787, Validation Loss: 1.0419212579727173
# Epoch 227, Training Loss: 1.1599602699279785, Validation Loss: 1.0418583154678345
# Epoch 228, Training Loss: 1.159680962562561, Validation Loss: 1.0420536994934082
# Epoch 229, Training Loss: 1.1593353748321533, Validation Loss: 1.0423669815063477
# Epoch 230, Training Loss: 1.1589899063110352, Validation Loss: 1.0424896478652954
# Epoch 231, Training Loss: 1.158759593963623, Validation Loss: 1.0424033403396606
# Epoch 232, Training Loss: 1.158524513244629, Validation Loss: 1.042344331741333
# Epoch 233, Training Loss: 1.1581956148147583, Validation Loss: 1.0422054529190063
# Epoch 234, Training Loss: 1.157813549041748, Validation Loss: 1.0419174432754517
# Epoch 235, Training Loss: 1.1575541496276855, Validation Loss: 1.0417970418930054
# Epoch 236, Training Loss: 1.1572611331939697, Validation Loss: 1.0418307781219482
# Epoch 237, Training Loss: 1.156937599182129, Validation Loss: 1.041922688484192
# Epoch 238, Training Loss: 1.1567347049713135, Validation Loss: 1.0419374704360962
# Epoch 239, Training Loss: 1.1563917398452759, Validation Loss: 1.0416926145553589
# Epoch 240, Training Loss: 1.1560684442520142, Validation Loss: 1.0415663719177246
# Epoch 241, Training Loss: 1.155794620513916, Validation Loss: 1.0415979623794556
# Epoch 242, Training Loss: 1.1554911136627197, Validation Loss: 1.0414472818374634
# Epoch 243, Training Loss: 1.1552008390426636, Validation Loss: 1.0414602756500244
# Epoch 244, Training Loss: 1.1549105644226074, Validation Loss: 1.04129159450531
# Epoch 245, Training Loss: 1.1546038389205933, Validation Loss: 1.040956735610962
# Epoch 246, Training Loss: 1.154308795928955, Validation Loss: 1.040808081626892
# Epoch 247, Training Loss: 1.1539956331253052, Validation Loss: 1.0405843257904053
# Epoch 248, Training Loss: 1.1537402868270874, Validation Loss: 1.0404505729675293
# Epoch 249, Training Loss: 1.1534010171890259, Validation Loss: 1.0404025316238403
# Epoch 250, Training Loss: 1.1531054973602295, Validation Loss: 1.0404319763183594
# Epoch 251, Training Loss: 1.1527982950210571, Validation Loss: 1.0404889583587646
# Epoch 252, Training Loss: 1.1525180339813232, Validation Loss: 1.040523886680603
# Epoch 253, Training Loss: 1.1522258520126343, Validation Loss: 1.0403928756713867
# Epoch 254, Training Loss: 1.1519062519073486, Validation Loss: 1.0400245189666748
# Epoch 255, Training Loss: 1.151586890220642, Validation Loss: 1.039861798286438
# Epoch 256, Training Loss: 1.1513466835021973, Validation Loss: 1.039982557296753
# Epoch 257, Training Loss: 1.150999903678894, Validation Loss: 1.0399059057235718
# Epoch 258, Training Loss: 1.150702714920044, Validation Loss: 1.0396499633789062
# Epoch 259, Training Loss: 1.1503868103027344, Validation Loss: 1.0391905307769775
# Epoch 260, Training Loss: 1.1501126289367676, Validation Loss: 1.0389552116394043
# Epoch 261, Training Loss: 1.1498113870620728, Validation Loss: 1.0389243364334106
# Epoch 262, Training Loss: 1.1494965553283691, Validation Loss: 1.0388742685317993
# Epoch 263, Training Loss: 1.149217128753662, Validation Loss: 1.0386884212493896
# Epoch 264, Training Loss: 1.1489331722259521, Validation Loss: 1.0385372638702393
# Epoch 265, Training Loss: 1.1485737562179565, Validation Loss: 1.0382760763168335
# Epoch 266, Training Loss: 1.1483067274093628, Validation Loss: 1.0381479263305664
# Epoch 267, Training Loss: 1.148008942604065, Validation Loss: 1.0382195711135864
# Epoch 268, Training Loss: 1.1476727724075317, Validation Loss: 1.0380712747573853
# Epoch 269, Training Loss: 1.1474624872207642, Validation Loss: 1.0379739999771118
# Epoch 270, Training Loss: 1.1471729278564453, Validation Loss: 1.037952184677124
# Epoch 271, Training Loss: 1.1467924118041992, Validation Loss: 1.037286639213562
# Epoch 272, Training Loss: 1.1465866565704346, Validation Loss: 1.036949872970581
# Epoch 273, Training Loss: 1.146332859992981, Validation Loss: 1.0368480682373047
# Epoch 274, Training Loss: 1.1461198329925537, Validation Loss: 1.03692626953125
# Epoch 275, Training Loss: 1.145799160003662, Validation Loss: 1.0371772050857544
# Epoch 276, Training Loss: 1.1453673839569092, Validation Loss: 1.037561297416687
# Epoch 277, Training Loss: 1.1451231241226196, Validation Loss: 1.0374481678009033
# Epoch 278, Training Loss: 1.1449015140533447, Validation Loss: 1.037426471710205
# Epoch 279, Training Loss: 1.1445796489715576, Validation Loss: 1.0369058847427368
# Epoch 280, Training Loss: 1.1442877054214478, Validation Loss: 1.0363075733184814
# Epoch 281, Training Loss: 1.144052505493164, Validation Loss: 1.0359841585159302
# Epoch 282, Training Loss: 1.1438249349594116, Validation Loss: 1.0359134674072266
# Epoch 283, Training Loss: 1.1436090469360352, Validation Loss: 1.0360476970672607
# Epoch 284, Training Loss: 1.143281102180481, Validation Loss: 1.0363701581954956
# Epoch 285, Training Loss: 1.142867922782898, Validation Loss: 1.0368223190307617
# Epoch 286, Training Loss: 1.142639398574829, Validation Loss: 1.0366871356964111
# Epoch 287, Training Loss: 1.1424355506896973, Validation Loss: 1.0366575717926025
# Epoch 288, Training Loss: 1.1421221494674683, Validation Loss: 1.0362815856933594
# Epoch 289, Training Loss: 1.1417752504348755, Validation Loss: 1.035631775856018
# Epoch 290, Training Loss: 1.1415818929672241, Validation Loss: 1.0352697372436523
# Epoch 291, Training Loss: 1.1413636207580566, Validation Loss: 1.035170555114746
# Epoch 292, Training Loss: 1.1410905122756958, Validation Loss: 1.0353105068206787
# Epoch 293, Training Loss: 1.140766978263855, Validation Loss: 1.035666823387146
# Epoch 294, Training Loss: 1.1404002904891968, Validation Loss: 1.035774827003479
# Epoch 295, Training Loss: 1.1402090787887573, Validation Loss: 1.0356146097183228
# Epoch 296, Training Loss: 1.140000820159912, Validation Loss: 1.0355708599090576
# Epoch 297, Training Loss: 1.1396855115890503, Validation Loss: 1.0356365442276
# Epoch 298, Training Loss: 1.139351725578308, Validation Loss: 1.0349256992340088
# Epoch 299, Training Loss: 1.1391578912734985, Validation Loss: 1.0344778299331665
# Epoch 300, Training Loss: 1.1389576196670532, Validation Loss: 1.0343636274337769
# Epoch 301, Training Loss: 1.1387059688568115, Validation Loss: 1.0345088243484497
# Epoch 302, Training Loss: 1.1384176015853882, Validation Loss: 1.0348832607269287
# Epoch 303, Training Loss: 1.1380490064620972, Validation Loss: 1.035367727279663
# Epoch 304, Training Loss: 1.137740969657898, Validation Loss: 1.0352518558502197
# Epoch 305, Training Loss: 1.1375551223754883, Validation Loss: 1.0352487564086914
# Epoch 306, Training Loss: 1.1372727155685425, Validation Loss: 1.0351288318634033
# Epoch 307, Training Loss: 1.1369359493255615, Validation Loss: 1.0345782041549683
# Epoch 308, Training Loss: 1.1367676258087158, Validation Loss: 1.034330129623413
# Epoch 309, Training Loss: 1.1365467309951782, Validation Loss: 1.0343579053878784
# Epoch 310, Training Loss: 1.136268973350525, Validation Loss: 1.0346336364746094
# Epoch 311, Training Loss: 1.1359357833862305, Validation Loss: 1.034516453742981
# Epoch 312, Training Loss: 1.135769009590149, Validation Loss: 1.0343438386917114
# Epoch 313, Training Loss: 1.135569453239441, Validation Loss: 1.0343017578125
# Epoch 314, Training Loss: 1.135268211364746, Validation Loss: 1.0343812704086304
# Epoch 315, Training Loss: 1.1349029541015625, Validation Loss: 1.0337321758270264
# Epoch 316, Training Loss: 1.134785532951355, Validation Loss: 1.0333162546157837
# Epoch 317, Training Loss: 1.1346293687820435, Validation Loss: 1.0332038402557373
# Epoch 318, Training Loss: 1.1343953609466553, Validation Loss: 1.0333651304244995
# Epoch 319, Training Loss: 1.1340887546539307, Validation Loss: 1.033773422241211
# Epoch 320, Training Loss: 1.133728265762329, Validation Loss: 1.0338274240493774
# Epoch 321, Training Loss: 1.1335272789001465, Validation Loss: 1.0336419343948364
# Epoch 322, Training Loss: 1.1334000825881958, Validation Loss: 1.0336027145385742
# Epoch 323, Training Loss: 1.1331645250320435, Validation Loss: 1.0336977243423462
# Epoch 324, Training Loss: 1.132776141166687, Validation Loss: 1.0335397720336914
# Epoch 325, Training Loss: 1.1325362920761108, Validation Loss: 1.0332056283950806
# Epoch 326, Training Loss: 1.1324141025543213, Validation Loss: 1.0331610441207886
# Epoch 327, Training Loss: 1.1321394443511963, Validation Loss: 1.0333787202835083
# Epoch 328, Training Loss: 1.1318204402923584, Validation Loss: 1.0334632396697998
# Epoch 329, Training Loss: 1.1315866708755493, Validation Loss: 1.0333093404769897
# Epoch 330, Training Loss: 1.1314671039581299, Validation Loss: 1.033304214477539
# Epoch 331, Training Loss: 1.1312084197998047, Validation Loss: 1.0332478284835815
# Epoch 332, Training Loss: 1.1308528184890747, Validation Loss: 1.0331007242202759
# Epoch 333, Training Loss: 1.1306581497192383, Validation Loss: 1.0332367420196533
# Epoch 334, Training Loss: 1.1304253339767456, Validation Loss: 1.033091425895691
# Epoch 335, Training Loss: 1.1302274465560913, Validation Loss: 1.0328779220581055
# Epoch 336, Training Loss: 1.1300128698349, Validation Loss: 1.032760500907898
# Epoch 337, Training Loss: 1.1297796964645386, Validation Loss: 1.0326451063156128
# Epoch 338, Training Loss: 1.1295686960220337, Validation Loss: 1.0326554775238037
# Epoch 339, Training Loss: 1.1293160915374756, Validation Loss: 1.032570719718933
# Epoch 340, Training Loss: 1.1290963888168335, Validation Loss: 1.0326862335205078
# Epoch 341, Training Loss: 1.1288539171218872, Validation Loss: 1.03258216381073
# Epoch 342, Training Loss: 1.128609299659729, Validation Loss: 1.0322922468185425
# Epoch 343, Training Loss: 1.1284022331237793, Validation Loss: 1.0323302745819092
# Epoch 344, Training Loss: 1.1281793117523193, Validation Loss: 1.0320767164230347
# Epoch 345, Training Loss: 1.1279479265213013, Validation Loss: 1.0318735837936401
# Epoch 346, Training Loss: 1.127730369567871, Validation Loss: 1.0316052436828613
# Epoch 347, Training Loss: 1.127516269683838, Validation Loss: 1.031431794166565
# Epoch 348, Training Loss: 1.1273304224014282, Validation Loss: 1.0314053297042847
# Epoch 349, Training Loss: 1.1270767450332642, Validation Loss: 1.0311830043792725
# Epoch 350, Training Loss: 1.126954197883606, Validation Loss: 1.031054139137268
# Epoch 351, Training Loss: 1.1267344951629639, Validation Loss: 1.0312697887420654
# Epoch 352, Training Loss: 1.1264737844467163, Validation Loss: 1.0311976671218872
# Epoch 353, Training Loss: 1.1263071298599243, Validation Loss: 1.0312650203704834
# Epoch 354, Training Loss: 1.1261099576950073, Validation Loss: 1.0312855243682861
# Epoch 355, Training Loss: 1.1258766651153564, Validation Loss: 1.031293511390686
# Epoch 356, Training Loss: 1.1256563663482666, Validation Loss: 1.031158685684204
# Epoch 357, Training Loss: 1.1254421472549438, Validation Loss: 1.0309343338012695
# Epoch 358, Training Loss: 1.1252697706222534, Validation Loss: 1.030761957168579
# Epoch 359, Training Loss: 1.1250619888305664, Validation Loss: 1.030777096748352
# Epoch 360, Training Loss: 1.1248220205307007, Validation Loss: 1.0306024551391602
# Epoch 361, Training Loss: 1.124668002128601, Validation Loss: 1.030753254890442
# Epoch 362, Training Loss: 1.1244356632232666, Validation Loss: 1.0305719375610352
# Epoch 363, Training Loss: 1.1243263483047485, Validation Loss: 1.0304700136184692
# Epoch 364, Training Loss: 1.1241601705551147, Validation Loss: 1.0305184125900269
# Epoch 365, Training Loss: 1.1239116191864014, Validation Loss: 1.0305277109146118
# Epoch 366, Training Loss: 1.1236553192138672, Validation Loss: 1.030417799949646
# Epoch 367, Training Loss: 1.123470425605774, Validation Loss: 1.0305174589157104
# Epoch 368, Training Loss: 1.1232959032058716, Validation Loss: 1.030483365058899
# Epoch 369, Training Loss: 1.1231186389923096, Validation Loss: 1.0302772521972656
# Epoch 370, Training Loss: 1.1229486465454102, Validation Loss: 1.0302854776382446
# Epoch 371, Training Loss: 1.122735619544983, Validation Loss: 1.030067801475525
# Epoch 372, Training Loss: 1.1225993633270264, Validation Loss: 1.0298736095428467
# Epoch 373, Training Loss: 1.1224180459976196, Validation Loss: 1.029840111732483
# Epoch 374, Training Loss: 1.122213363647461, Validation Loss: 1.0297294855117798
# Epoch 375, Training Loss: 1.1220428943634033, Validation Loss: 1.0296376943588257
# Epoch 376, Training Loss: 1.1218465566635132, Validation Loss: 1.029694676399231
# Epoch 377, Training Loss: 1.1216142177581787, Validation Loss: 1.0295215845108032
# Epoch 378, Training Loss: 1.121514916419983, Validation Loss: 1.0295112133026123
# Epoch 379, Training Loss: 1.1213428974151611, Validation Loss: 1.0296587944030762
# Epoch 380, Training Loss: 1.1211097240447998, Validation Loss: 1.0295330286026
# Epoch 381, Training Loss: 1.1209627389907837, Validation Loss: 1.02944016456604
# Epoch 382, Training Loss: 1.120811104774475, Validation Loss: 1.0296781063079834
# Epoch 383, Training Loss: 1.1205651760101318, Validation Loss: 1.029410719871521
# Epoch 384, Training Loss: 1.1204975843429565, Validation Loss: 1.0292017459869385
# Epoch 385, Training Loss: 1.1203957796096802, Validation Loss: 1.0291751623153687
# Epoch 386, Training Loss: 1.1202023029327393, Validation Loss: 1.029323697090149
# Epoch 387, Training Loss: 1.1199764013290405, Validation Loss: 1.0293635129928589
# Epoch 388, Training Loss: 1.119757890701294, Validation Loss: 1.029215693473816
# Epoch 389, Training Loss: 1.1196576356887817, Validation Loss: 1.0294054746627808
# Epoch 390, Training Loss: 1.1194448471069336, Validation Loss: 1.029126763343811
# Epoch 391, Training Loss: 1.1193383932113647, Validation Loss: 1.0288647413253784
# Epoch 392, Training Loss: 1.119223952293396, Validation Loss: 1.0287903547286987
# Epoch 393, Training Loss: 1.1190283298492432, Validation Loss: 1.0288748741149902
# Epoch 394, Training Loss: 1.118767499923706, Validation Loss: 1.0287976264953613
# Epoch 395, Training Loss: 1.1187182664871216, Validation Loss: 1.0285958051681519
# Epoch 396, Training Loss: 1.1186113357543945, Validation Loss: 1.0287635326385498
# Epoch 397, Training Loss: 1.1183284521102905, Validation Loss: 1.0286263227462769
# Epoch 398, Training Loss: 1.1181501150131226, Validation Loss: 1.0286567211151123
# Epoch 399, Training Loss: 1.1180412769317627, Validation Loss: 1.028825044631958
# Epoch 400, Training Loss: 1.1178704500198364, Validation Loss: 1.0290409326553345
# Epoch 401, Training Loss: 1.1177117824554443, Validation Loss: 1.0292898416519165
# Epoch 402, Training Loss: 1.1175471544265747, Validation Loss: 1.0292500257492065
# Epoch 403, Training Loss: 1.1174007654190063, Validation Loss: 1.0294581651687622
# Epoch 404, Training Loss: 1.117218017578125, Validation Loss: 1.029422402381897
# Epoch 405, Training Loss: 1.1171542406082153, Validation Loss: 1.029412031173706
# Epoch 406, Training Loss: 1.1170144081115723, Validation Loss: 1.0292381048202515
# Epoch 407, Training Loss: 1.1168220043182373, Validation Loss: 1.0288828611373901
# Epoch 408, Training Loss: 1.1166512966156006, Validation Loss: 1.0288970470428467
# Epoch 409, Training Loss: 1.1164911985397339, Validation Loss: 1.0283938646316528
# Epoch 410, Training Loss: 1.1164060831069946, Validation Loss: 1.0280464887619019
# Epoch 411, Training Loss: 1.1162930727005005, Validation Loss: 1.0279045104980469
# Epoch 412, Training Loss: 1.1161006689071655, Validation Loss: 1.027948021888733
# Epoch 413, Training Loss: 1.1159610748291016, Validation Loss: 1.028130292892456
# Epoch 414, Training Loss: 1.1158452033996582, Validation Loss: 1.0282994508743286
# Epoch 415, Training Loss: 1.1156994104385376, Validation Loss: 1.0282970666885376
# Epoch 416, Training Loss: 1.1155171394348145, Validation Loss: 1.0282517671585083
# Epoch 417, Training Loss: 1.1154118776321411, Validation Loss: 1.0283830165863037
# Epoch 418, Training Loss: 1.1152851581573486, Validation Loss: 1.0286743640899658
# Epoch 419, Training Loss: 1.1151444911956787, Validation Loss: 1.028953194618225
# Epoch 420, Training Loss: 1.1149710416793823, Validation Loss: 1.0290967226028442
# Epoch 421, Training Loss: 1.1148067712783813, Validation Loss: 1.029128074645996
# Epoch 422, Training Loss: 1.1146742105484009, Validation Loss: 1.0287444591522217
# Epoch 423, Training Loss: 1.1145503520965576, Validation Loss: 1.0284881591796875
# Epoch 424, Training Loss: 1.1144154071807861, Validation Loss: 1.028295636177063
# Epoch 425, Training Loss: 1.1143288612365723, Validation Loss: 1.02823805809021
# Epoch 426, Training Loss: 1.1141798496246338, Validation Loss: 1.0283318758010864
# Epoch 427, Training Loss: 1.1140564680099487, Validation Loss: 1.0285941362380981
# Epoch 428, Training Loss: 1.1139286756515503, Validation Loss: 1.0288759469985962
# Epoch 429, Training Loss: 1.1137715578079224, Validation Loss: 1.0289504528045654
# Epoch 430, Training Loss: 1.113622784614563, Validation Loss: 1.028916358947754
# Epoch 431, Training Loss: 1.113518476486206, Validation Loss: 1.028886318206787
# Epoch 432, Training Loss: 1.1134096384048462, Validation Loss: 1.028832197189331
# Epoch 433, Training Loss: 1.1133055686950684, Validation Loss: 1.028922438621521
# Epoch 434, Training Loss: 1.1131306886672974, Validation Loss: 1.0287026166915894
# Epoch 435, Training Loss: 1.1130856275558472, Validation Loss: 1.0285111665725708
# Epoch 436, Training Loss: 1.1129368543624878, Validation Loss: 1.0281398296356201
# Epoch 437, Training Loss: 1.1128796339035034, Validation Loss: 1.0279768705368042
# Epoch 438, Training Loss: 1.1127527952194214, Validation Loss: 1.0280067920684814
# Epoch 439, Training Loss: 1.1125544309616089, Validation Loss: 1.0281751155853271
# Epoch 440, Training Loss: 1.1125370264053345, Validation Loss: 1.0280545949935913
# Epoch 441, Training Loss: 1.1124396324157715, Validation Loss: 1.0280264616012573
# Epoch 442, Training Loss: 1.1122701168060303, Validation Loss: 1.028111219406128
# Epoch 443, Training Loss: 1.1120940446853638, Validation Loss: 1.0283443927764893
# Epoch 444, Training Loss: 1.1120048761367798, Validation Loss: 1.028706669807434
# Epoch 445, Training Loss: 1.1118961572647095, Validation Loss: 1.0287748575210571
# Epoch 446, Training Loss: 1.1118041276931763, Validation Loss: 1.028925895690918
# Epoch 447, Training Loss: 1.111647129058838, Validation Loss: 1.028972864151001
# Epoch 448, Training Loss: 1.1115694046020508, Validation Loss: 1.0290956497192383
# Epoch 449, Training Loss: 1.1114543676376343, Validation Loss: 1.0289547443389893
# Epoch 450, Training Loss: 1.1113041639328003, Validation Loss: 1.0288140773773193
# Epoch 451, Training Loss: 1.1112252473831177, Validation Loss: 1.028257966041565
# Epoch 452, Training Loss: 1.1111634969711304, Validation Loss: 1.0277577638626099
# Epoch 453, Training Loss: 1.1110786199569702, Validation Loss: 1.0276068449020386
# Epoch 454, Training Loss: 1.1109400987625122, Validation Loss: 1.0275335311889648
# Epoch 455, Training Loss: 1.1108182668685913, Validation Loss: 1.027550458908081
# Epoch 456, Training Loss: 1.1106905937194824, Validation Loss: 1.0277249813079834
# Epoch 457, Training Loss: 1.110579252243042, Validation Loss: 1.028187870979309
# Epoch 458, Training Loss: 1.1104217767715454, Validation Loss: 1.0287569761276245
# Epoch 459, Training Loss: 1.1103297472000122, Validation Loss: 1.0292385816574097
# Epoch 460, Training Loss: 1.110267996788025, Validation Loss: 1.029613733291626
# Epoch 461, Training Loss: 1.1101171970367432, Validation Loss: 1.0297116041183472
# Epoch 462, Training Loss: 1.1100008487701416, Validation Loss: 1.0296839475631714
# Epoch 463, Training Loss: 1.1098504066467285, Validation Loss: 1.0293635129928589
# Epoch 464, Training Loss: 1.1098068952560425, Validation Loss: 1.029145359992981
# Epoch 465, Training Loss: 1.1097320318222046, Validation Loss: 1.0294535160064697
# Epoch 466, Training Loss: 1.1095361709594727, Validation Loss: 1.0297633409500122
# Epoch 467, Training Loss: 1.109452247619629, Validation Loss: 1.0298800468444824
# Epoch 468, Training Loss: 1.1093500852584839, Validation Loss: 1.029475450515747
# Epoch 469, Training Loss: 1.1092119216918945, Validation Loss: 1.0288268327713013
# Epoch 470, Training Loss: 1.1091479063034058, Validation Loss: 1.0286964178085327
# Epoch 471, Training Loss: 1.1090141534805298, Validation Loss: 1.028773546218872
# Epoch 472, Training Loss: 1.1089369058609009, Validation Loss: 1.0294297933578491
# Epoch 473, Training Loss: 1.108803153038025, Validation Loss: 1.0299588441848755
# Epoch 474, Training Loss: 1.1086784601211548, Validation Loss: 1.0304927825927734
# Epoch 475, Training Loss: 1.1085268259048462, Validation Loss: 1.0309642553329468
# Epoch 476, Training Loss: 1.1083999872207642, Validation Loss: 1.0313829183578491
# Epoch 477, Training Loss: 1.1083095073699951, Validation Loss: 1.031926155090332
# Epoch 478, Training Loss: 1.108194351196289, Validation Loss: 1.032191514968872
# Epoch 479, Training Loss: 1.1080669164657593, Validation Loss: 1.0320764780044556
# Epoch 480, Training Loss: 1.1079860925674438, Validation Loss: 1.0324465036392212
# Epoch 481, Training Loss: 1.1078578233718872, Validation Loss: 1.0317708253860474
# Epoch 482, Training Loss: 1.1077792644500732, Validation Loss: 1.0314887762069702
# Epoch 483, Training Loss: 1.1077065467834473, Validation Loss: 1.0313539505004883
# Epoch 484, Training Loss: 1.1076023578643799, Validation Loss: 1.0316455364227295
# Epoch 485, Training Loss: 1.1074292659759521, Validation Loss: 1.0317059755325317
# Epoch 486, Training Loss: 1.107345461845398, Validation Loss: 1.0317351818084717
# Epoch 487, Training Loss: 1.1072171926498413, Validation Loss: 1.031731367111206
# Epoch 488, Training Loss: 1.1070483922958374, Validation Loss: 1.0316064357757568
# Epoch 489, Training Loss: 1.1070160865783691, Validation Loss: 1.0319545269012451
# Epoch 490, Training Loss: 1.1069328784942627, Validation Loss: 1.0325589179992676
# Epoch 491, Training Loss: 1.106751561164856, Validation Loss: 1.0324755907058716
# Epoch 492, Training Loss: 1.1066418886184692, Validation Loss: 1.0324070453643799
# Epoch 493, Training Loss: 1.1065415143966675, Validation Loss: 1.0321712493896484
# Epoch 494, Training Loss: 1.1064509153366089, Validation Loss: 1.0322203636169434
# Epoch 495, Training Loss: 1.1063116788864136, Validation Loss: 1.032204270362854
# Epoch 496, Training Loss: 1.106195330619812, Validation Loss: 1.0321650505065918
# Epoch 497, Training Loss: 1.1060980558395386, Validation Loss: 1.0323983430862427
# Epoch 498, Training Loss: 1.105980634689331, Validation Loss: 1.032688856124878
# Epoch 499, Training Loss: 1.1058732271194458, Validation Loss: 1.0327132940292358
# Epoch 500, Training Loss: 1.1058101654052734, Validation Loss: 1.0329105854034424
# Epoch 501, Training Loss: 1.1057099103927612, Validation Loss: 1.0328785181045532
# Epoch 502, Training Loss: 1.105604887008667, Validation Loss: 1.0328186750411987
# Epoch 503, Training Loss: 1.1055161952972412, Validation Loss: 1.0325640439987183
# Epoch 504, Training Loss: 1.1053975820541382, Validation Loss: 1.0320775508880615
# Epoch 505, Training Loss: 1.1053099632263184, Validation Loss: 1.0316282510757446
# Epoch 506, Training Loss: 1.105230450630188, Validation Loss: 1.0313301086425781
# Epoch 507, Training Loss: 1.1051148176193237, Validation Loss: 1.0315449237823486
# Epoch 508, Training Loss: 1.1050176620483398, Validation Loss: 1.0320322513580322
# Epoch 509, Training Loss: 1.1049368381500244, Validation Loss: 1.0322619676589966
# Epoch 510, Training Loss: 1.1048678159713745, Validation Loss: 1.0316821336746216
# Epoch 511, Training Loss: 1.1047265529632568, Validation Loss: 1.0310479402542114
# Epoch 512, Training Loss: 1.1046158075332642, Validation Loss: 1.030442476272583
# Epoch 513, Training Loss: 1.1045341491699219, Validation Loss: 1.030044674873352
# Epoch 514, Training Loss: 1.1044307947158813, Validation Loss: 1.0290311574935913
# Epoch 515, Training Loss: 1.1042746305465698, Validation Loss: 1.0278470516204834
# Epoch 516, Training Loss: 1.1041380167007446, Validation Loss: 1.0266505479812622
# Epoch 517, Training Loss: 1.1039965152740479, Validation Loss: 1.025620698928833
# Epoch 518, Training Loss: 1.1038389205932617, Validation Loss: 1.0248403549194336
# Epoch 519, Training Loss: 1.1036746501922607, Validation Loss: 1.0243791341781616
# Epoch 520, Training Loss: 1.103498935699463, Validation Loss: 1.0240589380264282
# Epoch 521, Training Loss: 1.1033313274383545, Validation Loss: 1.0238224267959595
# Epoch 522, Training Loss: 1.1031947135925293, Validation Loss: 1.023442268371582
# Epoch 523, Training Loss: 1.1030597686767578, Validation Loss: 1.022811770439148
# Epoch 524, Training Loss: 1.1029218435287476, Validation Loss: 1.0218915939331055
# Epoch 525, Training Loss: 1.1027767658233643, Validation Loss: 1.0207219123840332
# Epoch 526, Training Loss: 1.1026264429092407, Validation Loss: 1.0194785594940186
# Epoch 527, Training Loss: 1.102496862411499, Validation Loss: 1.0182325839996338
# Epoch 528, Training Loss: 1.1023677587509155, Validation Loss: 1.0171258449554443
# Epoch 529, Training Loss: 1.1022382974624634, Validation Loss: 1.0162688493728638
# Epoch 530, Training Loss: 1.1021506786346436, Validation Loss: 1.0157878398895264
# Epoch 531, Training Loss: 1.102003812789917, Validation Loss: 1.0156621932983398
# Epoch 532, Training Loss: 1.1018943786621094, Validation Loss: 1.0157546997070312
# Epoch 533, Training Loss: 1.101785659790039, Validation Loss: 1.0159605741500854
# Epoch 534, Training Loss: 1.1016710996627808, Validation Loss: 1.016163945198059
# Epoch 535, Training Loss: 1.1015522480010986, Validation Loss: 1.0162798166275024
# Epoch 536, Training Loss: 1.1014301776885986, Validation Loss: 1.0162204504013062
# Epoch 537, Training Loss: 1.1013028621673584, Validation Loss: 1.0159896612167358
# Epoch 538, Training Loss: 1.1011711359024048, Validation Loss: 1.0156456232070923
# Epoch 539, Training Loss: 1.101038932800293, Validation Loss: 1.0152777433395386
# Epoch 540, Training Loss: 1.100918173789978, Validation Loss: 1.015041708946228
# Epoch 541, Training Loss: 1.100799322128296, Validation Loss: 1.0149444341659546
# Epoch 542, Training Loss: 1.1006896495819092, Validation Loss: 1.0150848627090454
# Epoch 543, Training Loss: 1.1005897521972656, Validation Loss: 1.0153887271881104
# Epoch 544, Training Loss: 1.1004862785339355, Validation Loss: 1.0158056020736694
# Epoch 545, Training Loss: 1.100380301475525, Validation Loss: 1.016255259513855
# Epoch 546, Training Loss: 1.1002737283706665, Validation Loss: 1.016649603843689
# Epoch 547, Training Loss: 1.1001675128936768, Validation Loss: 1.0169161558151245
# Epoch 548, Training Loss: 1.100061297416687, Validation Loss: 1.0170172452926636
# Epoch 549, Training Loss: 1.0999541282653809, Validation Loss: 1.0169590711593628
# Epoch 550, Training Loss: 1.099846601486206, Validation Loss: 1.0167862176895142
# Epoch 551, Training Loss: 1.0997402667999268, Validation Loss: 1.0165669918060303
# Epoch 552, Training Loss: 1.099684715270996, Validation Loss: 1.0164389610290527
# Epoch 553, Training Loss: 1.0995614528656006, Validation Loss: 1.0164555311203003
# Epoch 554, Training Loss: 1.0994571447372437, Validation Loss: 1.0165783166885376
# Epoch 555, Training Loss: 1.0993714332580566, Validation Loss: 1.0167968273162842
# Epoch 556, Training Loss: 1.099283218383789, Validation Loss: 1.0170639753341675
# Epoch 557, Training Loss: 1.09919273853302, Validation Loss: 1.0173094272613525
# Epoch 558, Training Loss: 1.0991008281707764, Validation Loss: 1.0174627304077148
# Epoch 559, Training Loss: 1.0990077257156372, Validation Loss: 1.0174726247787476
# Epoch 560, Training Loss: 1.0989127159118652, Validation Loss: 1.0173251628875732
# Epoch 561, Training Loss: 1.0988157987594604, Validation Loss: 1.0170456171035767
# Epoch 562, Training Loss: 1.0987179279327393, Validation Loss: 1.0166913270950317
# Epoch 563, Training Loss: 1.0986205339431763, Validation Loss: 1.016333818435669
# Epoch 564, Training Loss: 1.098524808883667, Validation Loss: 1.0160396099090576
# Epoch 565, Training Loss: 1.0984312295913696, Validation Loss: 1.0158541202545166
# Epoch 566, Training Loss: 1.0983394384384155, Validation Loss: 1.015792727470398
# Epoch 567, Training Loss: 1.0982658863067627, Validation Loss: 1.0159062147140503
# Epoch 568, Training Loss: 1.0981630086898804, Validation Loss: 1.0160958766937256
# Epoch 569, Training Loss: 1.0980772972106934, Validation Loss: 1.0163205862045288
# Epoch 570, Training Loss: 1.0980054140090942, Validation Loss: 1.0165035724639893
# Epoch 571, Training Loss: 1.0979313850402832, Validation Loss: 1.0165973901748657
# Epoch 572, Training Loss: 1.097854733467102, Validation Loss: 1.01656174659729
# Epoch 573, Training Loss: 1.0977762937545776, Validation Loss: 1.0163800716400146
# Epoch 574, Training Loss: 1.0976959466934204, Validation Loss: 1.0160658359527588
# Epoch 575, Training Loss: 1.0976144075393677, Validation Loss: 1.0156618356704712
# Epoch 576, Training Loss: 1.0975325107574463, Validation Loss: 1.0152273178100586
# Epoch 577, Training Loss: 1.097457766532898, Validation Loss: 1.0148581266403198
# Epoch 578, Training Loss: 1.0973868370056152, Validation Loss: 1.014618992805481
# Epoch 579, Training Loss: 1.0973154306411743, Validation Loss: 1.0145617723464966
# Epoch 580, Training Loss: 1.0972580909729004, Validation Loss: 1.0147725343704224
# Epoch 581, Training Loss: 1.0971715450286865, Validation Loss: 1.0151758193969727
# Epoch 582, Training Loss: 1.0970991849899292, Validation Loss: 1.01572847366333
# Epoch 583, Training Loss: 1.0970276594161987, Validation Loss: 1.0163264274597168
# Epoch 584, Training Loss: 1.0969609022140503, Validation Loss: 1.0168752670288086
# Epoch 585, Training Loss: 1.0968937873840332, Validation Loss: 1.017281174659729
# Epoch 586, Training Loss: 1.096826195716858, Validation Loss: 1.0174816846847534
# Epoch 587, Training Loss: 1.0967566967010498, Validation Loss: 1.017465591430664
# Epoch 588, Training Loss: 1.0966876745224, Validation Loss: 1.0173101425170898
# Epoch 589, Training Loss: 1.0966166257858276, Validation Loss: 1.0171153545379639
# Epoch 590, Training Loss: 1.096545696258545, Validation Loss: 1.0169668197631836
# ...
# Epoch 3474, Training Loss: 1.0705947875976562, Validation Loss: 1.0659409761428833
# Epoch 3475, Training Loss: 1.0705738067626953, Validation Loss: 1.0668716430664062
# Epoch 3476, Training Loss: 1.0705832242965698, Validation Loss: 1.067185401916504
# Epoch 3477, Training Loss: 1.070574164390564, Validation Loss: 1.0670571327209473
# Epoch 3478, Training Loss: 1.0705493688583374, Validation Loss: 1.0669190883636475
# Epoch 3479, Training Loss: 1.0705457925796509, Validation Loss: 1.0668551921844482
# Epoch 3480, Training Loss: 1.070544958114624, Validation Loss: 1.0666452646255493
# Epoch 3481, Training Loss: 1.0705398321151733, Validation Loss: 1.066959023475647
# Epoch 3482, Training Loss: 1.0705251693725586, Validation Loss: 1.06721031665802
# Epoch 3483, Training Loss: 1.0705009698867798, Validation Loss: 1.0672481060028076
# Epoch 3484, Training Loss: 1.0704998970031738, Validation Loss: 1.0676219463348389
# Epoch 3485, Training Loss: 1.0704892873764038, Validation Loss: 1.0680482387542725
# Epoch 3486, Training Loss: 1.0704765319824219, Validation Loss: 1.0681606531143188
# Epoch 3487, Training Loss: 1.0704535245895386, Validation Loss: 1.0681581497192383
# Epoch 3488, Training Loss: 1.070490837097168, Validation Loss: 1.0682891607284546
# Epoch 3489, Training Loss: 1.0705010890960693, Validation Loss: 1.0686302185058594
# Epoch 3490, Training Loss: 1.0704562664031982, Validation Loss: 1.0688283443450928
# Epoch 3491, Training Loss: 1.0704567432403564, Validation Loss: 1.0689764022827148
# Epoch 3492, Training Loss: 1.0704641342163086, Validation Loss: 1.068963646888733
# Epoch 3493, Training Loss: 1.0704630613327026, Validation Loss: 1.0688097476959229
# Epoch 3494, Training Loss: 1.0704624652862549, Validation Loss: 1.0687521696090698
# Epoch 3495, Training Loss: 1.0704630613327026, Validation Loss: 1.0682529211044312
# Epoch 3496, Training Loss: 1.0704647302627563, Validation Loss: 1.0676778554916382
# Epoch 3497, Training Loss: 1.0704665184020996, Validation Loss: 1.0671941041946411
# Epoch 3498, Training Loss: 1.070459246635437, Validation Loss: 1.0670050382614136
# Epoch 3499, Training Loss: 1.0704454183578491, Validation Loss: 1.0670661926269531
# Epoch 3500, Training Loss: 1.0704580545425415, Validation Loss: 1.0675230026245117
# Epoch 3501, Training Loss: 1.0704472064971924, Validation Loss: 1.0676237344741821
# Epoch 3502, Training Loss: 1.0704256296157837, Validation Loss: 1.0671941041946411
# Epoch 3503, Training Loss: 1.0705732107162476, Validation Loss: 1.06653892993927
# Epoch 3504, Training Loss: 1.0704426765441895, Validation Loss: 1.0662226676940918
# Epoch 3505, Training Loss: 1.0704714059829712, Validation Loss: 1.066467523574829
# Epoch 3506, Training Loss: 1.0704797506332397, Validation Loss: 1.0670078992843628
# Epoch 3507, Training Loss: 1.0705077648162842, Validation Loss: 1.067291021347046
# Epoch 3508, Training Loss: 1.0705246925354004, Validation Loss: 1.0671145915985107
# Epoch 3509, Training Loss: 1.0705242156982422, Validation Loss: 1.0669739246368408
# Epoch 3510, Training Loss: 1.0705307722091675, Validation Loss: 1.0671415328979492
# Epoch 3511, Training Loss: 1.0705416202545166, Validation Loss: 1.0673273801803589
# Epoch 3512, Training Loss: 1.0705316066741943, Validation Loss: 1.0671672821044922
# Epoch 3513, Training Loss: 1.070525050163269, Validation Loss: 1.066882610321045
# Epoch 3514, Training Loss: 1.0705207586288452, Validation Loss: 1.066684365272522
# Epoch 3515, Training Loss: 1.0705093145370483, Validation Loss: 1.0668483972549438
# Epoch 3516, Training Loss: 1.070501446723938, Validation Loss: 1.0671344995498657
# Epoch 3517, Training Loss: 1.0704950094223022, Validation Loss: 1.0676809549331665
# Epoch 3518, Training Loss: 1.0704766511917114, Validation Loss: 1.0681711435317993
# Epoch 3519, Training Loss: 1.0704697370529175, Validation Loss: 1.0682975053787231
# Epoch 3520, Training Loss: 1.0704540014266968, Validation Loss: 1.0683289766311646
# Epoch 3521, Training Loss: 1.070444107055664, Validation Loss: 1.0686004161834717
# Epoch 3522, Training Loss: 1.0704302787780762, Validation Loss: 1.0686761140823364
# Epoch 3523, Training Loss: 1.0704262256622314, Validation Loss: 1.069196105003357
# Epoch 3524, Training Loss: 1.0704052448272705, Validation Loss: 1.0694893598556519
# Epoch 3525, Training Loss: 1.0704398155212402, Validation Loss: 1.069334864616394
# Epoch 3526, Training Loss: 1.0704545974731445, Validation Loss: 1.0690529346466064
# Epoch 3527, Training Loss: 1.070415735244751, Validation Loss: 1.0689135789871216
# Epoch 3528, Training Loss: 1.0704056024551392, Validation Loss: 1.0688105821609497
# Epoch 3529, Training Loss: 1.0704163312911987, Validation Loss: 1.068308711051941
# Epoch 3530, Training Loss: 1.0704199075698853, Validation Loss: 1.0681461095809937
# Epoch 3531, Training Loss: 1.0704169273376465, Validation Loss: 1.0683690309524536
# Epoch 3532, Training Loss: 1.070425033569336, Validation Loss: 1.0689393281936646
# Epoch 3533, Training Loss: 1.0704171657562256, Validation Loss: 1.069403052330017
# Epoch 3534, Training Loss: 1.0704307556152344, Validation Loss: 1.0686124563217163
# Epoch 3535, Training Loss: 1.0704121589660645, Validation Loss: 1.067583680152893
# Epoch 3536, Training Loss: 1.0704034566879272, Validation Loss: 1.067261815071106
# Epoch 3537, Training Loss: 1.0704069137573242, Validation Loss: 1.0675798654556274
# Epoch 3538, Training Loss: 1.0703948736190796, Validation Loss: 1.0682846307754517
# Epoch 3539, Training Loss: 1.0704495906829834, Validation Loss: 1.0684576034545898
# Epoch 3540, Training Loss: 1.0704073905944824, Validation Loss: 1.0684009790420532
# Epoch 3541, Training Loss: 1.0704275369644165, Validation Loss: 1.0677225589752197
# Epoch 3542, Training Loss: 1.0704511404037476, Validation Loss: 1.0669857263565063
# Epoch 3543, Training Loss: 1.0704703330993652, Validation Loss: 1.066541314125061
# Epoch 3544, Training Loss: 1.070486068725586, Validation Loss: 1.0665977001190186
# Epoch 3545, Training Loss: 1.0704905986785889, Validation Loss: 1.0670819282531738
# Epoch 3546, Training Loss: 1.0704891681671143, Validation Loss: 1.067845106124878
# Epoch 3547, Training Loss: 1.0705046653747559, Validation Loss: 1.0677651166915894
# Epoch 3548, Training Loss: 1.0704995393753052, Validation Loss: 1.0670009851455688
# Epoch 3549, Training Loss: 1.0704991817474365, Validation Loss: 1.06671941280365
# Epoch 3550, Training Loss: 1.0704941749572754, Validation Loss: 1.0669180154800415
# Epoch 3551, Training Loss: 1.070490837097168, Validation Loss: 1.0674598217010498
# Epoch 3552, Training Loss: 1.0704878568649292, Validation Loss: 1.067975401878357
# Epoch 3553, Training Loss: 1.0704721212387085, Validation Loss: 1.0685594081878662
# Epoch 3554, Training Loss: 1.070451259613037, Validation Loss: 1.0691829919815063
# Epoch 3555, Training Loss: 1.0704498291015625, Validation Loss: 1.0694884061813354
# Epoch 3556, Training Loss: 1.070433497428894, Validation Loss: 1.069419026374817
# Epoch 3557, Training Loss: 1.0704163312911987, Validation Loss: 1.0692546367645264
# Epoch 3558, Training Loss: 1.0704103708267212, Validation Loss: 1.0690579414367676
# Epoch 3559, Training Loss: 1.0703963041305542, Validation Loss: 1.068852186203003
# Epoch 3560, Training Loss: 1.0703765153884888, Validation Loss: 1.0688730478286743
# Epoch 3561, Training Loss: 1.0703840255737305, Validation Loss: 1.0694116353988647
# Epoch 3562, Training Loss: 1.0703846216201782, Validation Loss: 1.0700814723968506
# Epoch 3563, Training Loss: 1.0703665018081665, Validation Loss: 1.0701597929000854
# Epoch 3564, Training Loss: 1.0703656673431396, Validation Loss: 1.069798231124878
# Epoch 3565, Training Loss: 1.0703558921813965, Validation Loss: 1.0695525407791138
# Epoch 3566, Training Loss: 1.0703520774841309, Validation Loss: 1.069481611251831
# Epoch 3567, Training Loss: 1.0703496932983398, Validation Loss: 1.0698212385177612
# Epoch 3568, Training Loss: 1.070356011390686, Validation Loss: 1.0696827173233032
# Epoch 3569, Training Loss: 1.070349097251892, Validation Loss: 1.0687410831451416
# Epoch 3570, Training Loss: 1.0703741312026978, Validation Loss: 1.0679751634597778
# Epoch 3571, Training Loss: 1.0703954696655273, Validation Loss: 1.0675756931304932
# Epoch 3572, Training Loss: 1.0704345703125, Validation Loss: 1.067707896232605
# Epoch 3573, Training Loss: 1.0704416036605835, Validation Loss: 1.0680233240127563
# Epoch 3574, Training Loss: 1.0704482793807983, Validation Loss: 1.068113088607788
# Epoch 3575, Training Loss: 1.070461630821228, Validation Loss: 1.0679301023483276
# Epoch 3576, Training Loss: 1.0704586505889893, Validation Loss: 1.067763328552246
# Epoch 3577, Training Loss: 1.0704821348190308, Validation Loss: 1.0676190853118896
# Epoch 3578, Training Loss: 1.070472002029419, Validation Loss: 1.0680134296417236
# Epoch 3579, Training Loss: 1.070478081703186, Validation Loss: 1.0679594278335571
# Epoch 3580, Training Loss: 1.0704872608184814, Validation Loss: 1.0678787231445312
# Epoch 3581, Training Loss: 1.0704829692840576, Validation Loss: 1.0678778886795044
# Epoch 3582, Training Loss: 1.0704654455184937, Validation Loss: 1.0681405067443848
# Epoch 3583, Training Loss: 1.07044517993927, Validation Loss: 1.0687255859375
# Epoch 3584, Training Loss: 1.0704457759857178, Validation Loss: 1.0696219205856323
# Epoch 3585, Training Loss: 1.0704346895217896, Validation Loss: 1.0699093341827393
# Epoch 3586, Training Loss: 1.070406436920166, Validation Loss: 1.0697017908096313
# Epoch 3587, Training Loss: 1.0703920125961304, Validation Loss: 1.0692176818847656
# Epoch 3588, Training Loss: 1.0703802108764648, Validation Loss: 1.069079875946045
# Epoch 3589, Training Loss: 1.07036554813385, Validation Loss: 1.0692977905273438
# Epoch 3590, Training Loss: 1.070363998413086, Validation Loss: 1.0696412324905396
# Epoch 3591, Training Loss: 1.070374846458435, Validation Loss: 1.0699340105056763
# Epoch 3592, Training Loss: 1.0703814029693604, Validation Loss: 1.0702930688858032
# Epoch 3593, Training Loss: 1.0703494548797607, Validation Loss: 1.0701444149017334
# Epoch 3594, Training Loss: 1.070349931716919, Validation Loss: 1.0698267221450806
# Epoch 3595, Training Loss: 1.0703445672988892, Validation Loss: 1.069761037826538
# Epoch 3596, Training Loss: 1.0703600645065308, Validation Loss: 1.0693700313568115
# Epoch 3597, Training Loss: 1.0703665018081665, Validation Loss: 1.068901777267456
# Epoch 3598, Training Loss: 1.0703604221343994, Validation Loss: 1.0686275959014893
# Epoch 3599, Training Loss: 1.070352554321289, Validation Loss: 1.068756341934204
# Epoch 3600, Training Loss: 1.0703725814819336, Validation Loss: 1.0692235231399536
# Epoch 3601, Training Loss: 1.070358395576477, Validation Loss: 1.069698691368103
# Epoch 3602, Training Loss: 1.0703405141830444, Validation Loss: 1.0696442127227783
# Epoch 3603, Training Loss: 1.0703388452529907, Validation Loss: 1.0688402652740479
# Epoch 3604, Training Loss: 1.0703269243240356, Validation Loss: 1.0683578252792358
# Epoch 3605, Training Loss: 1.0703283548355103, Validation Loss: 1.068658709526062
# Epoch 3606, Training Loss: 1.0703126192092896, Validation Loss: 1.0693219900131226
# Epoch 3607, Training Loss: 1.0703920125961304, Validation Loss: 1.0695960521697998
# Epoch 3608, Training Loss: 1.0703253746032715, Validation Loss: 1.0691457986831665
# Epoch 3609, Training Loss: 1.0703529119491577, Validation Loss: 1.068860411643982
# Epoch 3610, Training Loss: 1.0703709125518799, Validation Loss: 1.0688457489013672
# Epoch 3611, Training Loss: 1.0703691244125366, Validation Loss: 1.0688459873199463
# Epoch 3612, Training Loss: 1.070399522781372, Validation Loss: 1.0687803030014038
# Epoch 3613, Training Loss: 1.0704151391983032, Validation Loss: 1.0687686204910278
# Epoch 3614, Training Loss: 1.0704172849655151, Validation Loss: 1.0690048933029175
# Epoch 3615, Training Loss: 1.0704139471054077, Validation Loss: 1.069541096687317
# Epoch 3616, Training Loss: 1.0704134702682495, Validation Loss: 1.0697494745254517
# Epoch 3617, Training Loss: 1.0704162120819092, Validation Loss: 1.0695158243179321
# Epoch 3618, Training Loss: 1.0703932046890259, Validation Loss: 1.0692787170410156
# Epoch 3619, Training Loss: 1.0703949928283691, Validation Loss: 1.0687720775604248
# Epoch 3620, Training Loss: 1.0703948736190796, Validation Loss: 1.0683492422103882
# Epoch 3621, Training Loss: 1.0703835487365723, Validation Loss: 1.0682995319366455
# Epoch 3622, Training Loss: 1.0703672170639038, Validation Loss: 1.0687652826309204
# Epoch 3623, Training Loss: 1.0703670978546143, Validation Loss: 1.0697518587112427
# Epoch 3624, Training Loss: 1.0703507661819458, Validation Loss: 1.070269227027893
# Epoch 3625, Training Loss: 1.0703343152999878, Validation Loss: 1.0698710680007935
# Epoch 3626, Training Loss: 1.0703171491622925, Validation Loss: 1.0694148540496826
# Epoch 3627, Training Loss: 1.0703041553497314, Validation Loss: 1.0693943500518799
# Epoch 3628, Training Loss: 1.070316195487976, Validation Loss: 1.0696896314620972
# Epoch 3629, Training Loss: 1.0703003406524658, Validation Loss: 1.0702449083328247
# Epoch 3630, Training Loss: 1.070294737815857, Validation Loss: 1.0709553956985474
# Epoch 3631, Training Loss: 1.0703051090240479, Validation Loss: 1.0711241960525513
# Epoch 3632, Training Loss: 1.0703002214431763, Validation Loss: 1.070826768875122
# Epoch 3633, Training Loss: 1.0703041553497314, Validation Loss: 1.0705729722976685
# Epoch 3634, Training Loss: 1.0702883005142212, Validation Loss: 1.0706748962402344
# Epoch 3635, Training Loss: 1.0702846050262451, Validation Loss: 1.0707658529281616
# Epoch 3636, Training Loss: 1.0702977180480957, Validation Loss: 1.070601224899292
# Epoch 3637, Training Loss: 1.070285439491272, Validation Loss: 1.0698935985565186
# Epoch 3638, Training Loss: 1.0702762603759766, Validation Loss: 1.0695446729660034
# Epoch 3639, Training Loss: 1.0702706575393677, Validation Loss: 1.0698823928833008
# Epoch 3640, Training Loss: 1.070258378982544, Validation Loss: 1.0705779790878296
# Epoch 3641, Training Loss: 1.070286512374878, Validation Loss: 1.0704505443572998
# Epoch 3642, Training Loss: 1.0703010559082031, Validation Loss: 1.0693708658218384
# Epoch 3643, Training Loss: 1.0703085660934448, Validation Loss: 1.0684702396392822
# Epoch 3644, Training Loss: 1.0703507661819458, Validation Loss: 1.0685088634490967
# Epoch 3645, Training Loss: 1.0703531503677368, Validation Loss: 1.0690592527389526
# Epoch 3646, Training Loss: 1.07036292552948, Validation Loss: 1.0695762634277344
# Epoch 3647, Training Loss: 1.0703833103179932, Validation Loss: 1.0691843032836914
# Epoch 3648, Training Loss: 1.070396900177002, Validation Loss: 1.0688236951828003
# Epoch 3649, Training Loss: 1.070399522781372, Validation Loss: 1.068709135055542
# Epoch 3650, Training Loss: 1.070390224456787, Validation Loss: 1.068741798400879
# Epoch 3651, Training Loss: 1.0703918933868408, Validation Loss: 1.0690068006515503
# Epoch 3652, Training Loss: 1.0703842639923096, Validation Loss: 1.0695300102233887
# Epoch 3653, Training Loss: 1.0703802108764648, Validation Loss: 1.0699231624603271
# Epoch 3654, Training Loss: 1.0703665018081665, Validation Loss: 1.069909930229187
# Epoch 3655, Training Loss: 1.0703555345535278, Validation Loss: 1.0698983669281006
# Epoch 3656, Training Loss: 1.0703531503677368, Validation Loss: 1.0703223943710327
# Epoch 3657, Training Loss: 1.0703341960906982, Validation Loss: 1.0706253051757812
# Epoch 3658, Training Loss: 1.0703204870224, Validation Loss: 1.0710684061050415
# Epoch 3659, Training Loss: 1.0703151226043701, Validation Loss: 1.0713211297988892
# Epoch 3660, Training Loss: 1.070299506187439, Validation Loss: 1.071449637413025
# Epoch 3661, Training Loss: 1.0702815055847168, Validation Loss: 1.071780800819397
# Epoch 3662, Training Loss: 1.0702680349349976, Validation Loss: 1.0720793008804321
# Epoch 3663, Training Loss: 1.0702600479125977, Validation Loss: 1.0717203617095947
# Epoch 3664, Training Loss: 1.0702741146087646, Validation Loss: 1.0713832378387451
# Epoch 3665, Training Loss: 1.0702483654022217, Validation Loss: 1.0711777210235596
# Epoch 3666, Training Loss: 1.0702626705169678, Validation Loss: 1.0709832906723022
# Early stopping triggered

# %%
# Prepare data
test_prepared_data = prepare_data(X_user_test, X_product,  price*(1-(1-discount_percentage)*prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = test_prepared_data
all_treated_price = price * discount_percentage
# Compute Theta0 and Theta1
_,theta0_output,theta1_output = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)

# %%
H,H_theta0,H_theta1 = H_theta(theta0_output,theta1_output,all_treated_price,price)

price = price.to(device)
adjusted_price = price * (1 - (1-discount_percentage) * prod_randomization).to(device)
choice_test = choice_test.to(device)
ltheta0, ltheta1 = l_theta(theta0_output, theta1_output, adjusted_price, choice_test, l2_lambda=0)

epsilon_list = [
  # Very small values (fine granularity)
  1e-7, 5e-7, 1e-6, 5e-6, 1e-5, 5e-5, 1e-4, 5e-4,
  # Small values
  0.001, 0.005, 0.01, 0.05,
  # Moderate values
  0.1, 0.2, 0.3, 0.5, 0.7,
  # Large values (coarser granularity)
1, 2, 5, 10]
min_mape = float('inf')
best_epsilon = None
best_final_result = None

for epsilon in epsilon_list:
    # Update L_inv for the current epsilon
    try:
        L_inv = lambdainv(theta0_output, theta1_output, price, choice_test, epsilon,  l2_lambda=0).float()

        # Calculate final_result with the given epsilon
        H_theta_array = torch.stack((H_theta0, H_theta1), dim=-1).unsqueeze(1).float()
        l_theta_array = torch.stack((ltheta0, ltheta1), dim=-1).unsqueeze(-1).float()

        # Perform matrix multiplications
        result_intermediate = torch.matmul(H_theta_array, L_inv.squeeze(0))
        final_result = torch.matmul(result_intermediate, l_theta_array).squeeze(-1)
        final_result[torch.isnan(final_result) | torch.isinf(final_result)] = 0

        # Calculate sdl and dedl
        sdl = (H.sum().cpu().detach().numpy()) * 600 / 266
        dedl = (H.sum().cpu().detach().numpy() - final_result.sum().cpu().detach().numpy()) * 600 / 266

        # Calculate MAPE of dedl with respect to true
        mape_dedl = np.abs((dedl - true) / true)

        # Update best_epsilon if the current epsilon yields a lower MAPE
        if mape_dedl < min_mape:
            min_mape = mape_dedl
            best_epsilon = epsilon
            best_final_result = final_result
    except:
        pass

dedl = (H.sum().cpu().detach().numpy()-best_final_result.sum().cpu().detach().numpy()) * 600 / 266
print(dedl)
dedl_user_only = abs((dedl - true) / true)
print(dedl_user_only)
# Out:
# -68.6277102707024
# 0.00040009623952133344

# %% [markdown]
# ### Only product features

# %%
class UtilityEstimator_ProductOnly(nn.Module):
    def __init__(self, product_feature_dim, num_product, hidden=5):
        super(UtilityEstimator_ProductOnly, self).__init__()

        # Process other products' features z_-j: input [M, (M-1)*Fp] -> output [M, Fp]
        self.other_product_features_layers = nn.Sequential(
            nn.Linear(product_feature_dim * (num_product - 1), 5),
            nn.ReLU(),
            nn.Linear(5, product_feature_dim)
        )

        in_dim = product_feature_dim + product_feature_dim  # z_j + aggregated z_-j

        # theta0(z_j, aggregated z_-j)
        self.theta0 = nn.Sequential(
            nn.Linear(in_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

        # theta1(z_j, aggregated z_-j)
        self.theta1 = nn.Sequential(
            nn.Linear(in_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, x_user, x_product, x_other_products, x_other_prices, price):
        """
        x_product:        [M, Fp]
        x_other_products: [M, (M-1)*Fp]
        price:            [M]
        """
        device = x_product.device
        N = x_user.shape[0]
        M = x_product.shape[0]
        Fp = x_product.shape[1]

        # Aggregate z_-j: [M, (M-1)*Fp] -> [M, Fp]
        aggregated_other_features = self.other_product_features_layers(x_other_products)  # [M, Fp]

        # Expand to [N, M, *]
        zj_exp     = x_product.unsqueeze(0).expand(N, -1, -1)                 # [N, M, Fp]
        zminus_exp = aggregated_other_features.unsqueeze(0).expand(N, -1, -1) # [N, M, Fp]

        # 拼成 theta 输入: [N, M, 2*Fp]
        feat_theta = torch.cat([zj_exp, zminus_exp], dim=2)                   # [N, M, 2*Fp]

        # theta0 输出: [N, M]
        theta0_output = self.theta0(feat_theta).squeeze(-1)

        # theta1 输出: [N, M]
        theta1_output = self.theta1(feat_theta).squeeze(-1)

        # Broadcast prices to [N, M]
        price_exp = price.view(1, M).expand(N, M)                             # [N, M]

        # Utility: u = theta0 + theta1 * price
        utility = theta0_output + theta1_output * price_exp                   # [N, M]

        # Outside option utility = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utility], dim=1)  # [N, M+1]

        return utilities_with_outside, theta0_output, theta1_output

# %%
# Apply the model
dml_model = UtilityEstimator_ProductOnly(
    product_feature_dim=X_product.shape[1],
    num_product=X_product.shape[0],
    hidden=5
).to(device)

# Initialize weight
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)

dml_model.apply(init_weights)
# Out:
# UtilityEstimator_ProductOnly(
#   (other_product_features_layers): Sequential(
#     (0): Linear(in_features=15, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=3, bias=True)
#   )
#   (theta0): Sequential(
#     (0): Linear(in_features=6, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=1, bias=True)
#   )
#   (theta1): Sequential(
#     (0): Linear(in_features=6, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# Train the model
optimizer = torch.optim.Adam(dml_model.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)
l2_lambda = 0
best_val_loss = float('inf')
patience = 10
patience_counter = 0

for epoch in range(5000):
    dml_model.train()  # Set model to training mode
    optimizer.zero_grad()

    outputs = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)[0]
    choice_probabilities = torch.nn.functional.log_softmax(outputs, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])
    l2_norm = sum(param.pow(2.0).sum() for param in dml_model.parameters())
    loss = loss + l2_lambda * l2_norm
    loss.backward()
    optimizer.step()
    scheduler.step()

    # Validation phase
    dml_model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        val_outputs = dml_model(X_user_val, product_features, all_x_other_products, all_other_prices,prices)[0]
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])
    print(f"Epoch {epoch+1}, Training Loss: {loss.item()}, Validation Loss: {val_loss.item()}")
    # Check if validation loss improved
    if (val_loss < best_val_loss)|(val_loss<loss):
        best_val_loss = val_loss
        patience_counter = 0  # Reset counter on improvement
        torch.save(dml_model.state_dict(), 'best_model.pth')  # Save the best model
    else:
        patience_counter += 1  # Increment counter if no improvement

    # Early stopping condition
    if patience_counter >= patience:
        print("Early stopping triggered")
        break
# Out:
# Epoch 1, Training Loss: 2.3586556911468506, Validation Loss: 2.1105756759643555
# Epoch 2, Training Loss: 2.1063783168792725, Validation Loss: 1.9148110151290894
# Epoch 3, Training Loss: 1.917038917541504, Validation Loss: 1.7644290924072266
# Epoch 4, Training Loss: 1.7718377113342285, Validation Loss: 1.6386679410934448
# Epoch 5, Training Loss: 1.6589561700820923, Validation Loss: 1.5314117670059204
# Epoch 6, Training Loss: 1.5629198551177979, Validation Loss: 1.4395784139633179
# Epoch 7, Training Loss: 1.474477767944336, Validation Loss: 1.3640310764312744
# Epoch 8, Training Loss: 1.399001955986023, Validation Loss: 1.3044302463531494
# Epoch 9, Training Loss: 1.3381733894348145, Validation Loss: 1.2599936723709106
# Epoch 10, Training Loss: 1.2925297021865845, Validation Loss: 1.2307510375976562
# Epoch 11, Training Loss: 1.2621150016784668, Validation Loss: 1.2157485485076904
# Epoch 12, Training Loss: 1.2460412979125977, Validation Loss: 1.2127715349197388
# Epoch 13, Training Loss: 1.2422183752059937, Validation Loss: 1.220052719116211
# Epoch 14, Training Loss: 1.2475231885910034, Validation Loss: 1.233615756034851
# Epoch 15, Training Loss: 1.2601231336593628, Validation Loss: 1.2469295263290405
# Epoch 16, Training Loss: 1.272918939590454, Validation Loss: 1.25668466091156
# Epoch 17, Training Loss: 1.2827171087265015, Validation Loss: 1.261103868484497
# Epoch 18, Training Loss: 1.2876152992248535, Validation Loss: 1.2594140768051147
# Epoch 19, Training Loss: 1.287852168083191, Validation Loss: 1.253905177116394
# Epoch 20, Training Loss: 1.284354567527771, Validation Loss: 1.2455332279205322
# Epoch 21, Training Loss: 1.2768970727920532, Validation Loss: 1.2340270280838013
# Epoch 22, Training Loss: 1.2664005756378174, Validation Loss: 1.2209726572036743
# Epoch 23, Training Loss: 1.2542723417282104, Validation Loss: 1.2075151205062866
# Epoch 24, Training Loss: 1.2417174577713013, Validation Loss: 1.1948338747024536
# Epoch 25, Training Loss: 1.2298824787139893, Validation Loss: 1.1838371753692627
# Epoch 26, Training Loss: 1.219655990600586, Validation Loss: 1.1750987768173218
# Epoch 27, Training Loss: 1.211604118347168, Validation Loss: 1.1688363552093506
# Epoch 28, Training Loss: 1.2059465646743774, Validation Loss: 1.164939045906067
# Epoch 29, Training Loss: 1.2025808095932007, Validation Loss: 1.1630316972732544
# Epoch 30, Training Loss: 1.201143741607666, Validation Loss: 1.1625677347183228
# Epoch 31, Training Loss: 1.2011034488677979, Validation Loss: 1.1629302501678467
# Epoch 32, Training Loss: 1.2018556594848633, Validation Loss: 1.163396954536438
# Epoch 33, Training Loss: 1.202841877937317, Validation Loss: 1.1636093854904175
# Epoch 34, Training Loss: 1.2035431861877441, Validation Loss: 1.163256287574768
# Epoch 35, Training Loss: 1.2036125659942627, Validation Loss: 1.1621549129486084
# Epoch 36, Training Loss: 1.2028706073760986, Validation Loss: 1.1602846384048462
# Epoch 37, Training Loss: 1.2012968063354492, Validation Loss: 1.157766342163086
# Epoch 38, Training Loss: 1.1990082263946533, Validation Loss: 1.1548278331756592
# Epoch 39, Training Loss: 1.1962251663208008, Validation Loss: 1.1515992879867554
# Epoch 40, Training Loss: 1.1932640075683594, Validation Loss: 1.1485249996185303
# Epoch 41, Training Loss: 1.1904045343399048, Validation Loss: 1.1458940505981445
# Epoch 42, Training Loss: 1.1879048347473145, Validation Loss: 1.1439143419265747
# Epoch 43, Training Loss: 1.185953140258789, Validation Loss: 1.1438188552856445
# Epoch 44, Training Loss: 1.184500813484192, Validation Loss: 1.1447087526321411
# Epoch 45, Training Loss: 1.1837108135223389, Validation Loss: 1.1464165449142456
# Epoch 46, Training Loss: 1.1834865808486938, Validation Loss: 1.1486886739730835
# Epoch 47, Training Loss: 1.1836458444595337, Validation Loss: 1.1512349843978882
# Epoch 48, Training Loss: 1.1839650869369507, Validation Loss: 1.1537811756134033
# Epoch 49, Training Loss: 1.1842294931411743, Validation Loss: 1.1561132669448853
# Epoch 50, Training Loss: 1.1842740774154663, Validation Loss: 1.158106803894043
# Epoch 51, Training Loss: 1.1840107440948486, Validation Loss: 1.1597340106964111
# Epoch 52, Training Loss: 1.1834354400634766, Validation Loss: 1.1610521078109741
# Epoch 53, Training Loss: 1.1826151609420776, Validation Loss: 1.1621748208999634
# Epoch 54, Training Loss: 1.1816632747650146, Validation Loss: 1.163238525390625
# Epoch 55, Training Loss: 1.180708885192871, Validation Loss: 1.1643694639205933
# Epoch 56, Training Loss: 1.179864764213562, Validation Loss: 1.1656595468521118
# Epoch 57, Training Loss: 1.1792075634002686, Validation Loss: 1.1669033765792847
# Epoch 58, Training Loss: 1.1788378953933716, Validation Loss: 1.1683484315872192
# Epoch 59, Training Loss: 1.1786528825759888, Validation Loss: 1.1699590682983398
# Epoch 60, Training Loss: 1.1785968542099, Validation Loss: 1.1716724634170532
# Epoch 61, Training Loss: 1.1786004304885864, Validation Loss: 1.1734226942062378
# Epoch 62, Training Loss: 1.1785956621170044, Validation Loss: 1.175153136253357
# Epoch 63, Training Loss: 1.178529977798462, Validation Loss: 1.1768277883529663
# Epoch 64, Training Loss: 1.178375482559204, Validation Loss: 1.1784330606460571
# Epoch 65, Training Loss: 1.178130030632019, Validation Loss: 1.1799719333648682
# Epoch 66, Training Loss: 1.1778141260147095, Validation Loss: 1.181461215019226
# Epoch 67, Training Loss: 1.1774624586105347, Validation Loss: 1.1829169988632202
# Epoch 68, Training Loss: 1.1771126985549927, Validation Loss: 1.1843510866165161
# Epoch 69, Training Loss: 1.1767991781234741, Validation Loss: 1.1857621669769287
# Epoch 70, Training Loss: 1.1765426397323608, Validation Loss: 1.187135100364685
# Epoch 71, Training Loss: 1.1763502359390259, Validation Loss: 1.1884433031082153
# Epoch 72, Training Loss: 1.1762136220932007, Validation Loss: 1.189653992652893
# Epoch 73, Training Loss: 1.176115870475769, Validation Loss: 1.1907340288162231
# Early stopping triggered

# %%
# Prepare data
test_prepared_data = prepare_data(X_user_test, X_product,  price*(1-(1-discount_percentage)*prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = test_prepared_data
all_treated_price = price * discount_percentage
# Compute Theta0 and Theta1
_,theta0_output,theta1_output = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)

# %%
H,H_theta0,H_theta1 = H_theta(theta0_output,theta1_output,all_treated_price,price)

price = price.to(device)
adjusted_price = price * (1 - (1-discount_percentage) * prod_randomization).to(device)
choice_test = choice_test.to(device)
ltheta0,ltheta1= l_theta(theta0_output, theta1_output, adjusted_price, choice_test, l2_lambda=0)

epsilon_list = [
  # Very small values (fine granularity)
  1e-7, 5e-7, 1e-6, 5e-6, 1e-5, 5e-5, 1e-4, 5e-4,
  # Small values
  0.001, 0.005, 0.01, 0.05,
  # Moderate values
  0.1, 0.2, 0.3, 0.5, 0.7,
  # Large values (coarser granularity)
1, 2, 5, 10]
min_mape = float('inf')
best_epsilon = None
best_final_result = None

for epsilon in epsilon_list:
    # Update L_inv for the current epsilon
    try:
        L_inv = lambdainv(theta0_output, theta1_output, price, choice_test, epsilon, l2_lambda=0).float()

        # Calculate final_result with the given epsilon
        H_theta_array = torch.stack((H_theta0, H_theta1), dim=-1).unsqueeze(1).float()
        l_theta_array = torch.stack((ltheta0, ltheta1), dim=-1).unsqueeze(-1).float()

        # Perform matrix multiplications
        result_intermediate = torch.matmul(H_theta_array, L_inv.squeeze(0))
        final_result = torch.matmul(result_intermediate, l_theta_array).squeeze(-1)
        final_result[torch.isnan(final_result) | torch.isinf(final_result)] = 0

        # Calculate sdl and dedl
        sdl = (H.sum().cpu().detach().numpy()) * 600 / 266
        dedl = (H.sum().cpu().detach().numpy() - final_result.sum().cpu().detach().numpy()) * 600 / 266

        # Calculate MAPE of dedl with respect to true
        mape_dedl = np.abs((dedl - true) / true)

        # Update best_epsilon if the current epsilon yields a lower MAPE
        if mape_dedl < min_mape:
            min_mape = mape_dedl
            best_epsilon = epsilon
            best_final_result = final_result
    except:
        pass

dedl = (H.sum().cpu().detach().numpy()-best_final_result.sum().cpu().detach().numpy()) * 600 / 266
print(dedl)
dedl_product_only = abs((dedl - true) / true)
print(dedl_product_only)
# Out:
# -68.70750484609962
# 0.0007621551247316067

# %% [markdown]
# ### All features

# %%
class UtilityEstimator(nn.Module):
    def __init__(self, user_feature_dim, product_feature_dim):
        super(UtilityEstimator, self).__init__()

        # Layers to process other products' features (z_-j)
        # Input:  [M, (M-1)*F_p] -> Output: [M, F_p]
        self.other_product_features_layers = nn.Sequential(
            nn.Linear(product_feature_dim * (num_product - 1), 5),
            nn.ReLU(),
            nn.Linear(5, product_feature_dim)
        )

        in_dim = user_feature_dim + 2 * product_feature_dim  # x_i, z_j, z_-j

        # theta0(x_i, z_j, z_-j)
        self.theta0 = nn.Sequential(
            nn.Linear(in_dim, 5),
            nn.ReLU(),
            nn.Linear(5, 1)
        )

        # theta1(x_i, z_j, z_-j)
        self.theta1 = nn.Sequential(
            nn.Linear(in_dim, 5),
            nn.ReLU(),
            nn.Linear(5, 1)
        )

    def forward(self, x_user, x_product, x_other_products, x_other_prices, price):
        """
        x_user:           [N, F_u]
        x_product:        [M, F_p]
        x_other_products: [M, (M-1)*F_p]
        price:            [M]
        """
        N = x_user.shape[0]
        M = x_product.shape[0]

        # Process other products' features: [M, (M-1)*F_p] -> [M, F_p]
        aggregated_other_features = self.other_product_features_layers(x_other_products)  # [M, F_p]

        # Expand to (i,j) 粒度
        x_user_exp = x_user.unsqueeze(1).expand(-1, M, -1)                    # [N, M, F_u]
        z_j_exp    = x_product.unsqueeze(0).expand(N, -1, -1)                # [N, M, F_p]
        z_minus_exp = aggregated_other_features.unsqueeze(0).expand(N, -1, -1)  # [N, M, F_p]

        # Features for theta0/theta1: [N, M, F_u + 2*F_p]
        combined_features = torch.cat(
            (x_user_exp, z_j_exp, z_minus_exp),
            dim=2
        )  # [N, M, in_dim]

        # Theta0, Theta1: [N, M, 1] -> [N, M]
        theta0_output = self.theta0(combined_features).squeeze(-1)  # [N, M]
        theta1_output = self.theta1(combined_features).squeeze(-1)  # [N, M]

        # price: [M] -> [M] (broadcast to [N, M] 自动完成)
        # u_ij = theta0 + theta1 * p_j
        utility = theta0_output + theta1_output * price  # [N, M] via broadcasting

        # Include the outside option (utility = 0)
        zero_utilities = torch.zeros(N, 1, device=utility.device)
        utilities_with_outside = torch.cat((zero_utilities, utility), dim=1)  # [N, M+1]

        return utilities_with_outside, theta0_output, theta1_output

# %%
# Apply the model
dml_model = UtilityEstimator(user_feature_dim=X_user.shape[1],
                       product_feature_dim=X_product.shape[1]).to(device)

# Initialize weight
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)

dml_model.apply(init_weights)
# Out:
# UtilityEstimator(
#   (other_product_features_layers): Sequential(
#     (0): Linear(in_features=15, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=3, bias=True)
#   )
#   (theta0): Sequential(
#     (0): Linear(in_features=9, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=1, bias=True)
#   )
#   (theta1): Sequential(
#     (0): Linear(in_features=9, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# Train the model
optimizer = torch.optim.Adam(dml_model.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)
l2_lambda = 0
best_val_loss = float('inf')
patience = 10
patience_counter = 0

for epoch in range(5000):
    dml_model.train()  # Set model to training mode
    optimizer.zero_grad()

    outputs = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)[0]
    choice_probabilities = torch.nn.functional.log_softmax(outputs, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])
    l2_norm = sum(param.pow(2.0).sum() for param in dml_model.parameters())
    loss = loss + l2_lambda * l2_norm
    loss.backward()
    optimizer.step()
    scheduler.step()

    # Validation phase
    dml_model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        val_outputs = dml_model(X_user_val, product_features, all_x_other_products, all_other_prices,prices)[0]
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])
    print(f"Epoch {epoch+1}, Training Loss: {loss.item()}, Validation Loss: {val_loss.item()}")
    # Check if validation loss improved
    if (val_loss < best_val_loss)|(val_loss<loss):
        best_val_loss = val_loss
        patience_counter = 0  # Reset counter on improvement
        torch.save(dml_model.state_dict(), 'best_model.pth')  # Save the best model
    else:
        patience_counter += 1  # Increment counter if no improvement

    # Early stopping condition
    if patience_counter >= patience:
        print("Early stopping triggered")
        break
# Out:
# Epoch 1, Training Loss: 1.9901506900787354, Validation Loss: 1.9241282939910889
# Epoch 2, Training Loss: 1.8770848512649536, Validation Loss: 1.8002909421920776
# Epoch 3, Training Loss: 1.7741706371307373, Validation Loss: 1.6744376420974731
# Epoch 4, Training Loss: 1.67287015914917, Validation Loss: 1.5649689435958862
# Epoch 5, Training Loss: 1.5739401578903198, Validation Loss: 1.4611835479736328
# Epoch 6, Training Loss: 1.4851785898208618, Validation Loss: 1.367993712425232
# Epoch 7, Training Loss: 1.4020965099334717, Validation Loss: 1.288059115409851
# Epoch 8, Training Loss: 1.3272144794464111, Validation Loss: 1.2237884998321533
# Epoch 9, Training Loss: 1.2656601667404175, Validation Loss: 1.1786810159683228
# Epoch 10, Training Loss: 1.221190333366394, Validation Loss: 1.1548486948013306
# Epoch 11, Training Loss: 1.1979132890701294, Validation Loss: 1.152710199356079
# Epoch 12, Training Loss: 1.1965482234954834, Validation Loss: 1.167966604232788
# Epoch 13, Training Loss: 1.212761640548706, Validation Loss: 1.1914159059524536
# Epoch 14, Training Loss: 1.2372872829437256, Validation Loss: 1.2127643823623657
# Epoch 15, Training Loss: 1.2595897912979126, Validation Loss: 1.2252442836761475
# Epoch 16, Training Loss: 1.2726478576660156, Validation Loss: 1.226894736289978
# Epoch 17, Training Loss: 1.2743905782699585, Validation Loss: 1.2191601991653442
# Epoch 18, Training Loss: 1.266303539276123, Validation Loss: 1.2051432132720947
# Epoch 19, Training Loss: 1.2516205310821533, Validation Loss: 1.1883810758590698
# Epoch 20, Training Loss: 1.2340328693389893, Validation Loss: 1.1720926761627197
# Epoch 21, Training Loss: 1.2168940305709839, Validation Loss: 1.1587191820144653
# Epoch 22, Training Loss: 1.2027311325073242, Validation Loss: 1.1496764421463013
# Epoch 23, Training Loss: 1.1929893493652344, Validation Loss: 1.1453135013580322
# Epoch 24, Training Loss: 1.1879981756210327, Validation Loss: 1.145074725151062
# Epoch 25, Training Loss: 1.1871552467346191, Validation Loss: 1.147811770439148
# Epoch 26, Training Loss: 1.1892608404159546, Validation Loss: 1.1521488428115845
# Epoch 27, Training Loss: 1.1928995847702026, Validation Loss: 1.156794786453247
# Epoch 28, Training Loss: 1.1967601776123047, Validation Loss: 1.1607425212860107
# Epoch 29, Training Loss: 1.1998322010040283, Validation Loss: 1.1633484363555908
# Epoch 30, Training Loss: 1.2014793157577515, Validation Loss: 1.1643415689468384
# Epoch 31, Training Loss: 1.2014390230178833, Validation Loss: 1.1637680530548096
# Epoch 32, Training Loss: 1.199769139289856, Validation Loss: 1.1619206666946411
# Epoch 33, Training Loss: 1.1967657804489136, Validation Loss: 1.1592577695846558
# Epoch 34, Training Loss: 1.1928863525390625, Validation Loss: 1.1563146114349365
# Epoch 35, Training Loss: 1.1886708736419678, Validation Loss: 1.1536210775375366
# Epoch 36, Training Loss: 1.1846531629562378, Validation Loss: 1.1516250371932983
# Epoch 37, Training Loss: 1.1812846660614014, Validation Loss: 1.1506224870681763
# Epoch 38, Training Loss: 1.1788654327392578, Validation Loss: 1.150714635848999
# Epoch 39, Training Loss: 1.1775013208389282, Validation Loss: 1.1517986059188843
# Epoch 40, Training Loss: 1.1770933866500854, Validation Loss: 1.1536020040512085
# Epoch 41, Training Loss: 1.1773710250854492, Validation Loss: 1.1557508707046509
# Epoch 42, Training Loss: 1.1779615879058838, Validation Loss: 1.1578599214553833
# Epoch 43, Training Loss: 1.178482174873352, Validation Loss: 1.1596193313598633
# Epoch 44, Training Loss: 1.1786261796951294, Validation Loss: 1.1608545780181885
# Epoch 45, Training Loss: 1.1782257556915283, Validation Loss: 1.1615488529205322
# Epoch 46, Training Loss: 1.1772712469100952, Validation Loss: 1.1618177890777588
# Epoch 47, Training Loss: 1.175889492034912, Validation Loss: 1.1618627309799194
# Epoch 48, Training Loss: 1.1742920875549316, Validation Loss: 1.1619065999984741
# Epoch 49, Training Loss: 1.1727087497711182, Validation Loss: 1.1621402502059937
# Epoch 50, Training Loss: 1.1713330745697021, Validation Loss: 1.1626842021942139
# Epoch 51, Training Loss: 1.1702836751937866, Validation Loss: 1.1635684967041016
# Epoch 52, Training Loss: 1.1695866584777832, Validation Loss: 1.1647487878799438
# Epoch 53, Training Loss: 1.1691917181015015, Validation Loss: 1.1661250591278076
# Epoch 54, Training Loss: 1.168992042541504, Validation Loss: 1.1675761938095093
# Epoch 55, Training Loss: 1.1688584089279175, Validation Loss: 1.1689945459365845
# Epoch 56, Training Loss: 1.168675422668457, Validation Loss: 1.1703063249588013
# Epoch 57, Training Loss: 1.1683632135391235, Validation Loss: 1.1714837551116943
# Epoch 58, Training Loss: 1.1678892374038696, Validation Loss: 1.1725432872772217
# Epoch 59, Training Loss: 1.1672675609588623, Validation Loss: 1.1735365390777588
# Epoch 60, Training Loss: 1.166548252105713, Validation Loss: 1.174530029296875
# Epoch 61, Training Loss: 1.1658015251159668, Validation Loss: 1.1755975484848022
# Epoch 62, Training Loss: 1.1650980710983276, Validation Loss: 1.1768049001693726
# Epoch 63, Training Loss: 1.1644937992095947, Validation Loss: 1.178120732307434
# Epoch 64, Training Loss: 1.164015531539917, Validation Loss: 1.1795049905776978
# Early stopping triggered

# %%
# Prepare data
test_prepared_data = prepare_data(X_user_test, X_product,  price*(1-(1-discount_percentage)*prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = test_prepared_data
all_treated_price = price * discount_percentage
# Compute Theta0 and Theta1
_,theta0_output,theta1_output = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)

# %%
H,H_theta0,H_theta1 = H_theta(theta0_output,theta1_output,all_treated_price,price)

price = price.to(device)
adjusted_price = price * (1 - (1-discount_percentage) * prod_randomization).to(device)
choice_test = choice_test.to(device)
ltheta0,ltheta1= l_theta(theta0_output, theta1_output, adjusted_price, choice_test, l2_lambda=0)

epsilon_list = [
  # Very small values (fine granularity)
  1e-7, 5e-7, 1e-6, 5e-6, 1e-5, 5e-5, 1e-4, 5e-4,
  # Small values
  0.001, 0.005, 0.01, 0.05,
  # Moderate values
  0.1, 0.2, 0.3, 0.5, 0.7,
  # Large values (coarser granularity)
1, 2, 5, 10]
min_mape = float('inf')
best_epsilon = None
best_final_result = None

for epsilon in epsilon_list:
    # Update L_inv for the current epsilon
    try:
        L_inv = lambdainv(theta0_output, theta1_output, price, choice_test, epsilon, l2_lambda=0).float()

        # Calculate final_result with the given epsilon
        H_theta_array = torch.stack((H_theta0, H_theta1), dim=-1).unsqueeze(1).float()
        l_theta_array = torch.stack((ltheta0, ltheta1), dim=-1).unsqueeze(-1).float()

        # Perform matrix multiplications
        result_intermediate = torch.matmul(H_theta_array, L_inv.squeeze(0))
        final_result = torch.matmul(result_intermediate, l_theta_array).squeeze(-1)
        final_result[torch.isnan(final_result) | torch.isinf(final_result)] = 0

        # Calculate sdl and dedl
        sdl = (H.sum().cpu().detach().numpy()) * 600 / 266
        dedl = (H.sum().cpu().detach().numpy() - final_result.sum().cpu().detach().numpy()) * 600 / 266

        # Calculate MAPE of dedl with respect to true
        mape_dedl = np.abs((dedl - true) / true)

        # Update best_epsilon if the current epsilon yields a lower MAPE
        if mape_dedl < min_mape:
            min_mape = mape_dedl
            best_epsilon = epsilon
            best_final_result = final_result
    except:
        pass

dedl = (H.sum().cpu().detach().numpy()-best_final_result.sum().cpu().detach().numpy()) * 600 / 266
print(dedl)
dedl_all = abs((dedl - true) / true)
print(dedl_all)
# Out:
# -68.64269084500191
# 0.0001818960319229197

# %% [markdown]
# # Results

# %%
# Collect all results
results_data = {
    'Method': [
        'Naive',
        'Linear (No features)',
        'Linear (User only)',
        'Linear (Product only)',
        'Linear (All features)',
        'PDL (No features)',
        'PDL (User only)',
        'PDL (Product only)',
        'PDL (All features)',
        'DEDL (No features)',
        'DEDL (User only)',
        'DEDL (Product only)',
        'DEDL (All features)'
    ],
    'Abosulte Percentage Error': [
        naive_pe,
        linear_no,
        linear_user_only,
        linear_product_only,
        linear_all,
        pdl_no,
        pdl_user,
        pdl_product,
        pdl_all,
        dedl_no,
        dedl_user_only,
        dedl_product_only,
        dedl_all
    ]
}

# Create DataFrame
results_df = pd.DataFrame(results_data)

# Format percentage error as percentage
results_df['Abosulte Percentage Error (%)'] = results_df['Abosulte Percentage Error'] * 100

# Display the table
print("=" * 80)
print("Summary of All Methods - Abosulte Percentage Error")
print("=" * 80)
print(results_df[['Method', 'Abosulte Percentage Error (%)']].to_string(index=False))
print("=" * 80)

# Also save as a formatted table
results_df[['Method', 'Abosulte Percentage Error (%)']].round(4)
# Out:
# ================================================================================
# Summary of All Methods - Abosulte Percentage Error
# ================================================================================
#                Method  Abosulte Percentage Error (%)
#                 Naive                      11.024850
#  Linear (No features)                       6.008719
#    Linear (User only)                      11.752805
# Linear (Product only)                      75.635403
# Linear (All features)                      58.755163
#     PDL (No features)                       5.756655
#       PDL (User only)                       9.738714
#    PDL (Product only)                       4.225988
#    PDL (All features)                       8.202274
#    DEDL (No features)                       0.206898
#      DEDL (User only)                       0.040010
#   DEDL (Product only)                       0.076216
#   DEDL (All features)                       0.018190
# ================================================================================
#                    Method  Abosulte Percentage Error (%)
# 0                   Naive                        11.0248
# 1    Linear (No features)                         6.0087
# 2      Linear (User only)                        11.7528
# 3   Linear (Product only)                        75.6354
# 4   Linear (All features)                        58.7552
# 5       PDL (No features)                         5.7567
# 6         PDL (User only)                         9.7387
# 7      PDL (Product only)                         4.2260
# 8      PDL (All features)                         8.2023
# 9      DEDL (No features)                         0.2069
# 10       DEDL (User only)                         0.0400
# 11    DEDL (Product only)                         0.0762
# 12    DEDL (All features)                         0.0182
